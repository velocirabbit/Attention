# %%
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable
from transformer_attention import *

# %%
ntokens = 7
N = 3
n_heads = 8
embed_size = 512
seq_len = 11
dep_len = 6
smoothing = 0.001

epochs = 100
num_batches = 50
batch_size = 16
num_eval_batches = 20
log_interval = 10
warmup_steps = 5
decay_factor = 0.5
clip = 2
lr = .5

# %%
# Generate some token transition probabilities
probs = np.random.randint(1, 10*ntokens, size = tuple(ntokens for _ in range(dep_len+1)))
# Normalize
probs = probs / (probs.sum(axis = -1)[..., np.newaxis])
probs.shape
# Out:
# (7, 7, 7, 7, 7, 7, 7)

# %% [markdown]
# Trains a model that uses the Transformer Attention mechanism as described in ["Attention is All You Need" (Vaswani, et al.)](https://arxiv.org/abs/1706.03762)
#
# # Initialization and Setup
# The `TransformerAttention` class is defined in the file `transformer_attention.py`.
#
# ## Model definition

# %%
class TestModel(nn.Module):
    def __init__(self, src_vocab, tgt_vocab, N = 6,
                 embed_size = 512, ff_size = 2048,
                 num_attn_heads = 8, dropout = 0.1):
        super(TestModel, self).__init__()
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.N = N
        self.embed_size = embed_size
        self.ff_size = ff_size
        self.num_attn_heads = num_attn_heads
        
        self.dropout = nn.Dropout(dropout)
        self.src_embedding = nn.Embedding(src_vocab, embed_size)
        self.tgt_embedding = nn.Embedding(tgt_vocab, embed_size)
        self.attn = TransformerAttention(
            src_vocab, tgt_vocab, d_model = embed_size,
            d_ff = ff_size, h = num_attn_heads, N = N,
            dropout = dropout
        )
        self.projection = nn.Linear(embed_size, tgt_vocab)
        self.log_softmax = nn.LogSoftmax(-1)
        
        # Tie all embedding/projection weights
        self.src_embedding.weight = self.projection.weight
        self.tgt_embedding.weight = self.projection.weight
        
    def init(self):
        for p in self.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform(p)
            else:
                p.data.fill_(0)
                
    def forward(self, src, tgt, src_mask = None, tgt_mask = None):
        src_embeddings = self.dropout(self.src_embedding(src))
        tgt_embeddings = self.dropout(self.tgt_embedding(tgt))
        
        attentions = self.attn(src_embeddings, tgt_embeddings, src_mask, tgt_mask)
        
        logits = self.projection(self.dropout(attentions))
        # LabelSmoothing loss requires the model output log-softmax
        outputs = self.log_softmax(logits)
        return outputs

# %% [markdown]
# ## Loss function definition (with label smoothing regularization)

# %% [markdown]
# During training, we employ label smoothing of value $\epsilon_{\text{lr}} = 0.1$. This hurts perplexity as the model learns to be more unsure, but it improves accuracy and BLEU score.
#
# We implement label smoothing using the KL divergence loss. Instead of using a one-hot target distribution, we create a distribution that has `confidence` of the correct word and the rest of the `smoothing` mass distributed throughout the vocabulary.

# %%
class LabelSmoothing(nn.Module):
    def __init__(self, size, padding_idx = None, smoothing = 0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss()
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = torch.zeros_like(x.data)
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist.add_(self.smoothing / self.size)
        if self.padding_idx is not None:
            true_dist[:, self.padding_idx] = 0
            mask = torch.nonzero(target.data == self.padding_idx)
            if mask.dim() > 0:
                true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad = False)) * ntokens

# %% [markdown]
# Example of how the probability mass is distributed to the words based on confidence:

# %%
# Example of label smoothing.
crit = LabelSmoothing(5, None, 0.4)
predict = torch.FloatTensor([[0, 0.2, 0.7, 0.1, 0],
                             [0, 0.2, 0.7, 0.1, 0], 
                             [0, 0.2, 0.7, 0.1, 0]])
v = crit(Variable(predict.log()), 
         Variable(torch.LongTensor([2, 1, 0])))

# Show the target distributions expected by the system.
plt.imshow(crit.true_dist)

# %% [markdown]
# Label smoothing actually starts to penalize the model if it gets very confident about a given choice:

# %% [markdown]
# ## Optimizer
# Learning rate scheduler that sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
def get_lr_scheduler(h_size, warmup, optimizer):
    lrate = lambda e: h_size**(-0.5) * min((e+1)**(-decay_factor), (e+1) * warmup**(-(decay_factor+1)))
    return optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lrate)

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.1f:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.1f:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.1f:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.1f:%d:%d" % (lr, embed_size, warmup_steps),
])

# %% [markdown]
# # Initialization
# Initialize model, criterion, and optimizer

# %%
model = TestModel(ntokens, ntokens, embed_size = embed_size, N = N)
model.init()
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
optimizer = optim.Adam(model.parameters(), lr = lr)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, optimizer)
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 5639

# %% [markdown]
# ## Generate data

# %%
def gen_data(num_batches, batch_size, seq_len):
    num_data = num_batches * batch_size * seq_len
    # Initialize numpy array for the generated data
    data = np.zeros((num_data,), dtype = int)
    # Randomly generate a series of starting tokens
    ts = [np.random.randint(ntokens, size = 1) for _ in range(dep_len)]
    # Generate the data
    for i in range(num_data):
        pr = probs[ts].squeeze()
        data[i] = np.random.choice(ntokens, p = pr)
        ts.pop(0)
        ts.append(data[i].reshape(1,1))
    return torch.from_numpy(data).type(torch.LongTensor)

# %% [markdown]
# # Train and evaluate
# ## Training helpers
# Classes and functions that handle generating batches of test data and running a single training iteration.

# %%
def batchify(data, batch_size):
    nbatches = data.size(0) // batch_size
    data = data.narrow(0, 0, nbatches * batch_size)
    data = data.view(batch_size, -1).contiguous()
    return data

# %%
train_data = batchify(gen_data(num_batches, batch_size, seq_len), batch_size)
test_data = batchify(gen_data(num_eval_batches, batch_size, seq_len), batch_size)
val_data = batchify(gen_data(num_eval_batches, batch_size, seq_len), batch_size)
train_data.shape, test_data.shape, val_data.shape
# Out:
# (torch.Size([16, 550]), torch.Size([16, 220]), torch.Size([16, 220]))

# %%
def get_batch(src, i, seq_len, evaluate = False):
    seq_len = min(seq_len, src.size(1) - 2 - i)
    data = Variable(src[:, i+1 : i+seq_len+1].contiguous(), volatile = evaluate)
    prev = Variable(src[:, i : i+seq_len].contiguous(), volatile = evaluate)
    targets = Variable(src[:, i+2 : i+seq_len+2].contiguous(), volatile = evaluate)
    return data, prev, targets

# %%
# Training loop
def train():
    # Use random length sequences
    seq_lens = []
    tot_len = 0
    jitter = 0.05 * seq_len
    num_data = train_data.size(1)
    while tot_len < num_data - 3:
        if num_data - tot_len - 3 < seq_len + jitter:
            slen = num_data - tot_len - 3
        else:
            slen = int(np.random.normal(seq_len, jitter))
            if slen <= 0:
                slen = seq_len    # eh
            if tot_len + slen >= num_data - jitter - 3:
                slen = num_data - tot_len - 3
        seq_lens.append(slen)
        tot_len += slen
    i_cumseq = [0] + list(np.cumsum(seq_lens)[:-1])
    idx = np.arange(len(seq_lens))
    np.random.shuffle(idx)
    # Turn on training mode
    model.train()
    # Pre metainfo
    total_loss = 0
    start_time = time.time()
    for batch, i in enumerate(idx):
        # Get training data
        data, prev, targets = get_batch(train_data, i_cumseq[i], seq_lens[i])
        # Zero out gradients
        model.zero_grad()
        
        # Run the model forward
        output = model(data, prev)
        if np.isnan(output.data).any():
            return 0, data, prev, targets
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets.view(-1))
        if np.isnan(loss.data[0]):
            return 1, data, prev, targets
        # Propagate loss gradient backwards
        loss.backward()
        # Clip gradients
        if batch % log_interval == 0 and batch > 0:
            # Save gradient statistics before they're changed cuz we'll be logging this batch
            parameters = [p for p in model.parameters() if p.grad is not None]
            # Calculate the largest (absolute) gradient of all elements in the model parameters
            max_grad = max([p.grad.data.abs().max() for p in parameters])
        total_norm = nn.utils.clip_grad_norm(model.parameters(), clip)
        # Scale the batch learning rate so that shorter sequences aren't "stronger"
        scaled_lr = lr_scheduler.get_lr()[0] * np.sqrt(seq_lens[i] / seq_len)
        for param_group in optimizer.param_groups:
            param_group['lr'] = scaled_lr
        # Update parameters
        optimizer.step()
        
        # Metainfo logging
        total_loss += loss.data
        if batch % log_interval == 0 and batch > 0:
            elapsed = time.time() - start_time
            cur_loss = total_loss[0] / log_interval
            print(' b {:3d}/{:3d} >> {:6.1f} ms/b | lr: {:4.2f} | grad norm: {:4.2f} | max abs grad: {:4.2f} | loss: {:4.2f} | perp.: {:5.2f}'.format(
                batch, len(seq_lens), elapsed * 1000/log_interval, scaled_lr, total_norm, max_grad, cur_loss, np.exp(cur_loss)
            ))
            total_loss = 0
            start_time = time.time()
    return -1, None, None, None

# %%
def evaluate(data_src):
    model.eval()
    total_loss = 0
    for i in range(0, data_src.size(1) - 2, seq_len):
        # Get data
        data, prev, targets = get_batch(data_src, i, seq_len, evaluate = True)
        # Zero out gradients
        model.zero_grad()
        
        # Run model forward
        output = model(data, prev)
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets.view(-1))
        total_loss += loss.data * data.size(1)
    return total_loss[0] / (data.size(1) - 2)

# %% [markdown]
# Train and evaluate

# %%
WIDTH = 104
CAUSES = ['output', 'grad']
for epoch in range(epochs):
    lr_scheduler.step()
    print('Epoch {:3d}/{:3d}) lr = {:.4g}{}'.format(epoch+1, epochs, np.mean(lr_scheduler.get_lr()[0]), ' (warmup)' if epoch < warmup_steps else ''))
    start_time = time.time()
    stat, data, prev, targets = train()
    if stat in list(range(len(CAUSES))):
        c = CAUSES[stat]
        n = (WIDTH - len(c) - 4) // 2
        print('\n' + (' '*n) + 'NaN ' + c)
        break
    elapsed = time.time() - start_time
    val_loss = evaluate(val_data)
    max_param = max([p.data.abs().max() for p in model.parameters() if p.grad is not None])
    print('-' * WIDTH)
    print('Elapsed time: {:5.2f} sec | max abs wt: {:5.2f} | valid_loss: {:5.2f} | valid_perplexity: {:5.2f}'.format(
        elapsed, max_param, val_loss, np.exp(val_loss)
    ))
    print('=' * WIDTH)
    print('\n')
# Out:
# Epoch   1/100) lr = 0.001976 (warmup)
#  b  10/ 52 >>  559.5 ms/b | lr: 0.00 | grad norm: 0.12 | max abs grad: 0.03 | loss: 2.13 | perp.:  8.44
#  b  20/ 52 >>  504.4 ms/b | lr: 0.00 | grad norm: 0.16 | max abs grad: 0.06 | loss: 1.94 | perp.:  6.96
#  b  30/ 52 >>  521.0 ms/b | lr: 0.00 | grad norm: 0.15 | max abs grad: 0.05 | loss: 1.94 | perp.:  6.96
#  b  40/ 52 >>  506.7 ms/b | lr: 0.00 | grad norm: 0.17 | max abs grad: 0.04 | loss: 1.94 | perp.:  6.95
#  b  50/ 52 >>  485.1 ms/b | lr: 0.00 | grad norm: 0.17 | max abs grad: 0.05 | loss: 1.94 | perp.:  6.95
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.90 sec | max abs wt:  0.15 | valid_loss:  3.87 | valid_perplexity: 47.77
# ========================================================================================================
#
#
# Epoch   2/100) lr = 0.003953 (warmup)
#  b  10/ 52 >>  532.1 ms/b | lr: 0.00 | grad norm: 0.12 | max abs grad: 0.03 | loss: 2.13 | perp.:  8.42
#  b  20/ 52 >>  512.0 ms/b | lr: 0.00 | grad norm: 0.14 | max abs grad: 0.05 | loss: 1.94 | perp.:  6.97
#  b  30/ 52 >>  506.7 ms/b | lr: 0.00 | grad norm: 0.10 | max abs grad: 0.02 | loss: 1.94 | perp.:  6.98
#  b  40/ 52 >>  508.6 ms/b | lr: 0.00 | grad norm: 0.15 | max abs grad: 0.04 | loss: 1.94 | perp.:  6.96
#  b  50/ 52 >>  480.7 ms/b | lr: 0.00 | grad norm: 0.15 | max abs grad: 0.04 | loss: 1.94 | perp.:  6.96
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.54 sec | max abs wt:  0.17 | valid_loss:  3.87 | valid_perplexity: 47.86
# ========================================================================================================
#
#
# Epoch   3/100) lr = 0.005929 (warmup)
#  b  10/ 52 >>  540.9 ms/b | lr: 0.01 | grad norm: 0.12 | max abs grad: 0.03 | loss: 2.13 | perp.:  8.42
#  b  20/ 52 >>  500.0 ms/b | lr: 0.01 | grad norm: 0.13 | max abs grad: 0.03 | loss: 1.94 | perp.:  6.98
#  b  30/ 52 >>  494.5 ms/b | lr: 0.01 | grad norm: 0.14 | max abs grad: 0.04 | loss: 1.94 | perp.:  6.99
#  b  40/ 52 >>  482.7 ms/b | lr: 0.01 | grad norm: 0.17 | max abs grad: 0.05 | loss: 1.94 | perp.:  6.96
#  b  50/ 52 >>  494.1 ms/b | lr: 0.01 | grad norm: 0.24 | max abs grad: 0.07 | loss: 1.94 | perp.:  6.95
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.26 sec | max abs wt:  0.41 | valid_loss:  3.86 | valid_perplexity: 47.53
# ========================================================================================================
#
#
# Epoch   4/100) lr = 0.007906 (warmup)
#  b  10/ 52 >>  538.2 ms/b | lr: 0.01 | grad norm: 0.18 | max abs grad: 0.06 | loss: 2.12 | perp.:  8.36
#  b  20/ 52 >>  481.9 ms/b | lr: 0.01 | grad norm: 0.17 | max abs grad: 0.03 | loss: 1.94 | perp.:  6.99
#  b  30/ 52 >>  506.2 ms/b | lr: 0.01 | grad norm: 0.21 | max abs grad: 0.04 | loss: 1.94 | perp.:  6.95
#  b  40/ 52 >>  509.4 ms/b | lr: 0.01 | grad norm: 0.24 | max abs grad: 0.05 | loss: 1.93 | perp.:  6.91
#  b  50/ 52 >>  471.8 ms/b | lr: 0.01 | grad norm: 0.49 | max abs grad: 0.07 | loss: 1.91 | perp.:  6.78
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.21 sec | max abs wt:  0.89 | valid_loss:  3.79 | valid_perplexity: 44.47
# ========================================================================================================
#
#
# Epoch   5/100) lr = 0.009882 (warmup)
#  b  10/ 52 >>  535.8 ms/b | lr: 0.01 | grad norm: 0.30 | max abs grad: 0.05 | loss: 2.09 | perp.:  8.08
#  b  20/ 52 >>  499.3 ms/b | lr: 0.01 | grad norm: 0.41 | max abs grad: 0.07 | loss: 1.90 | perp.:  6.69
#  b  30/ 52 >>  480.9 ms/b | lr: 0.01 | grad norm: 0.49 | max abs grad: 0.08 | loss: 1.90 | perp.:  6.71
#  b  40/ 52 >>  494.2 ms/b | lr: 0.01 | grad norm: 0.25 | max abs grad: 0.04 | loss: 1.88 | perp.:  6.56
#  b  50/ 52 >>  506.1 ms/b | lr: 0.01 | grad norm: 0.42 | max abs grad: 0.06 | loss: 1.88 | perp.:  6.54
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.30 sec | max abs wt:  1.52 | valid_loss:  3.61 | valid_perplexity: 36.88
# ========================================================================================================
#
#
# Epoch   6/100) lr = 0.009021
#  b  10/ 53 >>  537.7 ms/b | lr: 0.01 | grad norm: 0.52 | max abs grad: 0.06 | loss: 2.02 | perp.:  7.54
#  b  20/ 53 >>  498.7 ms/b | lr: 0.01 | grad norm: 0.71 | max abs grad: 0.08 | loss: 1.88 | perp.:  6.53
#  b  30/ 53 >>  483.0 ms/b | lr: 0.01 | grad norm: 0.62 | max abs grad: 0.08 | loss: 1.84 | perp.:  6.29
#  b  40/ 53 >>  479.1 ms/b | lr: 0.01 | grad norm: 0.55 | max abs grad: 0.07 | loss: 1.84 | perp.:  6.28
#  b  50/ 53 >>  490.1 ms/b | lr: 0.01 | grad norm: 0.42 | max abs grad: 0.04 | loss: 1.83 | perp.:  6.23
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.33 sec | max abs wt:  1.92 | valid_loss:  3.46 | valid_perplexity: 31.89
# ========================================================================================================
#
#
# Epoch   7/100) lr = 0.008352
#  b  10/ 53 >>  526.6 ms/b | lr: 0.01 | grad norm: 0.47 | max abs grad: 0.06 | loss: 1.98 | perp.:  7.27
#  b  20/ 53 >>  482.1 ms/b | lr: 0.01 | grad norm: 0.46 | max abs grad: 0.05 | loss: 1.81 | perp.:  6.12
#  b  30/ 53 >>  477.2 ms/b | lr: 0.01 | grad norm: 0.69 | max abs grad: 0.10 | loss: 1.82 | perp.:  6.19
#  b  40/ 53 >>  501.9 ms/b | lr: 0.01 | grad norm: 0.49 | max abs grad: 0.06 | loss: 1.82 | perp.:  6.15
#  b  50/ 53 >>  489.3 ms/b | lr: 0.01 | grad norm: 0.63 | max abs grad: 0.10 | loss: 1.77 | perp.:  5.86
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.25 sec | max abs wt:  2.20 | valid_loss:  3.38 | valid_perplexity: 29.48
# ========================================================================================================
#
#
# Epoch   8/100) lr = 0.007813
#  b  10/ 53 >>  551.7 ms/b | lr: 0.01 | grad norm: 0.46 | max abs grad: 0.06 | loss: 1.94 | perp.:  6.97
#  b  20/ 53 >>  485.4 ms/b | lr: 0.01 | grad norm: 0.53 | max abs grad: 0.07 | loss: 1.80 | perp.:  6.02
#  b  30/ 53 >>  481.3 ms/b | lr: 0.01 | grad norm: 0.55 | max abs grad: 0.07 | loss: 1.79 | perp.:  6.00
#  b  40/ 53 >>  517.5 ms/b | lr: 0.01 | grad norm: 0.54 | max abs grad: 0.08 | loss: 1.76 | perp.:  5.80
#  b  50/ 53 >>  497.5 ms/b | lr: 0.01 | grad norm: 0.46 | max abs grad: 0.05 | loss: 1.74 | perp.:  5.70
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.73 sec | max abs wt:  2.69 | valid_loss:  3.33 | valid_perplexity: 27.94
# ========================================================================================================
#
#
# Epoch   9/100) lr = 0.007366
#  b  10/ 53 >>  551.0 ms/b | lr: 0.01 | grad norm: 0.49 | max abs grad: 0.05 | loss: 1.89 | perp.:  6.61
#  b  20/ 53 >>  529.9 ms/b | lr: 0.01 | grad norm: 0.57 | max abs grad: 0.07 | loss: 1.74 | perp.:  5.68
#  b  30/ 53 >>  510.1 ms/b | lr: 0.01 | grad norm: 0.60 | max abs grad: 0.07 | loss: 1.73 | perp.:  5.65
#  b  40/ 53 >>  527.4 ms/b | lr: 0.01 | grad norm: 0.43 | max abs grad: 0.06 | loss: 1.76 | perp.:  5.81
#  b  50/ 53 >>  525.7 ms/b | lr: 0.01 | grad norm: 0.39 | max abs grad: 0.09 | loss: 1.71 | perp.:  5.51
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.84 sec | max abs wt:  2.99 | valid_loss:  3.27 | valid_perplexity: 26.41
# ========================================================================================================
#
#
# Epoch  10/100) lr = 0.006988
#  b  10/ 53 >>  563.6 ms/b | lr: 0.01 | grad norm: 0.61 | max abs grad: 0.10 | loss: 1.87 | perp.:  6.46
#  b  20/ 53 >>  503.0 ms/b | lr: 0.01 | grad norm: 0.48 | max abs grad: 0.07 | loss: 1.71 | perp.:  5.52
#  b  30/ 53 >>  497.4 ms/b | lr: 0.01 | grad norm: 0.38 | max abs grad: 0.06 | loss: 1.71 | perp.:  5.52
#  b  40/ 53 >>  470.7 ms/b | lr: 0.01 | grad norm: 0.43 | max abs grad: 0.09 | loss: 1.69 | perp.:  5.44
#  b  50/ 53 >>  526.0 ms/b | lr: 0.01 | grad norm: 0.48 | max abs grad: 0.08 | loss: 1.68 | perp.:  5.37
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.14 sec | max abs wt:  3.18 | valid_loss:  3.18 | valid_perplexity: 23.94
# ========================================================================================================
#
#
# Epoch  11/100) lr = 0.006663
#  b  10/ 52 >>  552.2 ms/b | lr: 0.01 | grad norm: 0.43 | max abs grad: 0.07 | loss: 1.83 | perp.:  6.22
#  b  20/ 52 >>  526.1 ms/b | lr: 0.01 | grad norm: 0.42 | max abs grad: 0.09 | loss: 1.69 | perp.:  5.39
#  b  30/ 52 >>  540.6 ms/b | lr: 0.01 | grad norm: 0.53 | max abs grad: 0.07 | loss: 1.69 | perp.:  5.44
#  b  40/ 52 >>  527.8 ms/b | lr: 0.01 | grad norm: 0.46 | max abs grad: 0.08 | loss: 1.68 | perp.:  5.36
#  b  50/ 52 >>  524.1 ms/b | lr: 0.01 | grad norm: 0.59 | max abs grad: 0.08 | loss: 1.67 | perp.:  5.31
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.86 sec | max abs wt:  3.35 | valid_loss:  3.13 | valid_perplexity: 22.86
# ========================================================================================================
#
#
# Epoch  12/100) lr = 0.006379
#  b  10/ 53 >>  601.2 ms/b | lr: 0.01 | grad norm: 0.54 | max abs grad: 0.08 | loss: 1.81 | perp.:  6.09
#  b  20/ 53 >>  583.9 ms/b | lr: 0.01 | grad norm: 0.42 | max abs grad: 0.07 | loss: 1.66 | perp.:  5.28
#  b  30/ 53 >>  511.2 ms/b | lr: 0.01 | grad norm: 0.46 | max abs grad: 0.08 | loss: 1.68 | perp.:  5.35
#  b  40/ 53 >>  540.5 ms/b | lr: 0.01 | grad norm: 0.42 | max abs grad: 0.07 | loss: 1.67 | perp.:  5.29
#  b  50/ 53 >>  512.0 ms/b | lr: 0.01 | grad norm: 0.66 | max abs grad: 0.08 | loss: 1.63 | perp.:  5.09
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 28.00 sec | max abs wt:  3.57 | valid_loss:  3.02 | valid_perplexity: 20.49
# ========================================================================================================
#
#
# Epoch  13/100) lr = 0.006129
#  b  10/ 53 >>  574.2 ms/b | lr: 0.01 | grad norm: 0.54 | max abs grad: 0.09 | loss: 1.76 | perp.:  5.79
#  b  20/ 53 >>  503.5 ms/b | lr: 0.01 | grad norm: 0.54 | max abs grad: 0.09 | loss: 1.62 | perp.:  5.06
#  b  30/ 53 >>  512.0 ms/b | lr: 0.01 | grad norm: 0.50 | max abs grad: 0.06 | loss: 1.61 | perp.:  5.00
#  b  40/ 53 >>  495.7 ms/b | lr: 0.01 | grad norm: 0.53 | max abs grad: 0.10 | loss: 1.61 | perp.:  5.01
#  b  50/ 53 >>  493.2 ms/b | lr: 0.01 | grad norm: 0.46 | max abs grad: 0.07 | loss: 1.57 | perp.:  4.78
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.13 sec | max abs wt:  3.87 | valid_loss:  2.94 | valid_perplexity: 18.90
# ========================================================================================================
#
#
# Epoch  14/100) lr = 0.005906
#  b  10/ 52 >>  562.2 ms/b | lr: 0.01 | grad norm: 0.52 | max abs grad: 0.08 | loss: 1.72 | perp.:  5.61
#  b  20/ 52 >>  531.8 ms/b | lr: 0.01 | grad norm: 0.66 | max abs grad: 0.10 | loss: 1.56 | perp.:  4.75
#  b  30/ 52 >>  537.3 ms/b | lr: 0.01 | grad norm: 0.42 | max abs grad: 0.08 | loss: 1.57 | perp.:  4.82
#  b  40/ 52 >>  493.7 ms/b | lr: 0.01 | grad norm: 0.55 | max abs grad: 0.09 | loss: 1.54 | perp.:  4.67
#  b  50/ 52 >>  488.6 ms/b | lr: 0.01 | grad norm: 0.57 | max abs grad: 0.13 | loss: 1.52 | perp.:  4.57
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.27 sec | max abs wt:  4.17 | valid_loss:  2.80 | valid_perplexity: 16.51
# ========================================================================================================
#
#
# Epoch  15/100) lr = 0.005705
#  b  10/ 52 >>  530.8 ms/b | lr: 0.01 | grad norm: 0.47 | max abs grad: 0.08 | loss: 1.64 | perp.:  5.15
#  b  20/ 52 >>  507.5 ms/b | lr: 0.01 | grad norm: 0.45 | max abs grad: 0.09 | loss: 1.54 | perp.:  4.65
#  b  30/ 52 >>  512.8 ms/b | lr: 0.01 | grad norm: 0.54 | max abs grad: 0.07 | loss: 1.52 | perp.:  4.57
#  b  40/ 52 >>  506.5 ms/b | lr: 0.01 | grad norm: 0.50 | max abs grad: 0.10 | loss: 1.50 | perp.:  4.46
#  b  50/ 52 >>  500.9 ms/b | lr: 0.01 | grad norm: 0.54 | max abs grad: 0.12 | loss: 1.48 | perp.:  4.39
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.73 sec | max abs wt:  4.37 | valid_loss:  2.66 | valid_perplexity: 14.30
# ========================================================================================================
#
#
# Epoch  16/100) lr = 0.005524
#  b  10/ 52 >>  544.9 ms/b | lr: 0.01 | grad norm: 0.42 | max abs grad: 0.13 | loss: 1.60 | perp.:  4.93
#  b  20/ 52 >>  507.7 ms/b | lr: 0.01 | grad norm: 0.45 | max abs grad: 0.06 | loss: 1.48 | perp.:  4.38
#  b  30/ 52 >>  501.0 ms/b | lr: 0.01 | grad norm: 0.47 | max abs grad: 0.09 | loss: 1.48 | perp.:  4.37
#  b  40/ 52 >>  495.6 ms/b | lr: 0.01 | grad norm: 0.43 | max abs grad: 0.11 | loss: 1.45 | perp.:  4.27
#  b  50/ 52 >>  487.6 ms/b | lr: 0.00 | grad norm: 0.54 | max abs grad: 0.08 | loss: 1.43 | perp.:  4.19
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.51 sec | max abs wt:  4.60 | valid_loss:  2.61 | valid_perplexity: 13.66
# ========================================================================================================
#
#
# Epoch  17/100) lr = 0.005359
#  b  10/ 53 >>  537.0 ms/b | lr: 0.01 | grad norm: 0.58 | max abs grad: 0.07 | loss: 1.56 | perp.:  4.78
#  b  20/ 53 >>  493.6 ms/b | lr: 0.01 | grad norm: 0.57 | max abs grad: 0.11 | loss: 1.42 | perp.:  4.15
#  b  30/ 53 >>  477.5 ms/b | lr: 0.01 | grad norm: 0.40 | max abs grad: 0.09 | loss: 1.42 | perp.:  4.14
#  b  40/ 53 >>  486.2 ms/b | lr: 0.01 | grad norm: 0.51 | max abs grad: 0.13 | loss: 1.41 | perp.:  4.09
#  b  50/ 53 >>  506.3 ms/b | lr: 0.01 | grad norm: 0.43 | max abs grad: 0.09 | loss: 1.37 | perp.:  3.95
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.39 sec | max abs wt:  4.78 | valid_loss:  2.53 | valid_perplexity: 12.59
# ========================================================================================================
#
#
# Epoch  18/100) lr = 0.005208
#  b  10/ 52 >>  541.8 ms/b | lr: 0.01 | grad norm: 0.57 | max abs grad: 0.10 | loss: 1.50 | perp.:  4.47
#  b  20/ 52 >>  486.9 ms/b | lr: 0.00 | grad norm: 0.54 | max abs grad: 0.14 | loss: 1.40 | perp.:  4.07
#  b  30/ 52 >>  493.4 ms/b | lr: 0.01 | grad norm: 0.53 | max abs grad: 0.08 | loss: 1.40 | perp.:  4.07
#  b  40/ 52 >>  499.9 ms/b | lr: 0.01 | grad norm: 0.49 | max abs grad: 0.12 | loss: 1.40 | perp.:  4.04
#  b  50/ 52 >>  502.2 ms/b | lr: 0.01 | grad norm: 0.51 | max abs grad: 0.09 | loss: 1.36 | perp.:  3.89
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.38 sec | max abs wt:  5.02 | valid_loss:  2.45 | valid_perplexity: 11.56
# ========================================================================================================
#
#
# Epoch  19/100) lr = 0.005069
#  b  10/ 52 >>  539.0 ms/b | lr: 0.01 | grad norm: 0.60 | max abs grad: 0.11 | loss: 1.48 | perp.:  4.40
#  b  20/ 52 >>  483.9 ms/b | lr: 0.00 | grad norm: 0.53 | max abs grad: 0.13 | loss: 1.38 | perp.:  3.96
#  b  30/ 52 >>  502.5 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.10 | loss: 1.37 | perp.:  3.92
#  b  40/ 52 >>  490.0 ms/b | lr: 0.01 | grad norm: 0.39 | max abs grad: 0.06 | loss: 1.35 | perp.:  3.84
#  b  50/ 52 >>  486.5 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.13 | loss: 1.32 | perp.:  3.76
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.16 sec | max abs wt:  5.24 | valid_loss:  2.30 | valid_perplexity: 10.00
# ========================================================================================================
#
#
# Epoch  20/100) lr = 0.004941
#  b  10/ 53 >>  571.7 ms/b | lr: 0.00 | grad norm: 0.61 | max abs grad: 0.10 | loss: 1.46 | perp.:  4.31
#  b  20/ 53 >>  499.4 ms/b | lr: 0.00 | grad norm: 0.56 | max abs grad: 0.13 | loss: 1.34 | perp.:  3.83
#  b  30/ 53 >>  492.6 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.09 | loss: 1.36 | perp.:  3.89
#  b  40/ 53 >>  489.0 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.07 | loss: 1.36 | perp.:  3.89
#  b  50/ 53 >>  486.8 ms/b | lr: 0.00 | grad norm: 0.53 | max abs grad: 0.09 | loss: 1.31 | perp.:  3.71
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.79 sec | max abs wt:  5.44 | valid_loss:  2.35 | valid_perplexity: 10.43
# ========================================================================================================
#
#
# Epoch  21/100) lr = 0.004822
#  b  10/ 53 >>  528.0 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.05 | loss: 1.40 | perp.:  4.07
#  b  20/ 53 >>  502.6 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.10 | loss: 1.32 | perp.:  3.76
#  b  30/ 53 >>  485.0 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.07 | loss: 1.32 | perp.:  3.74
#  b  40/ 53 >>  491.7 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.10 | loss: 1.33 | perp.:  3.79
#  b  50/ 53 >>  510.5 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.09 | loss: 1.29 | perp.:  3.61
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.63 sec | max abs wt:  5.61 | valid_loss:  2.19 | valid_perplexity:  8.96
# ========================================================================================================
#
#
# Epoch  22/100) lr = 0.004711
#  b  10/ 53 >>  552.9 ms/b | lr: 0.00 | grad norm: 0.63 | max abs grad: 0.09 | loss: 1.40 | perp.:  4.07
#  b  20/ 53 >>  482.9 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.05 | loss: 1.31 | perp.:  3.72
#  b  30/ 53 >>  494.7 ms/b | lr: 0.00 | grad norm: 0.67 | max abs grad: 0.12 | loss: 1.32 | perp.:  3.74
#  b  40/ 53 >>  486.1 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.11 | loss: 1.30 | perp.:  3.65
#  b  50/ 53 >>  499.7 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.05 | loss: 1.27 | perp.:  3.55
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.66 sec | max abs wt:  5.76 | valid_loss:  2.22 | valid_perplexity:  9.22
# ========================================================================================================
#
#
# Epoch  23/100) lr = 0.004608
#  b  10/ 53 >>  538.0 ms/b | lr: 0.00 | grad norm: 0.56 | max abs grad: 0.09 | loss: 1.43 | perp.:  4.18
#  b  20/ 53 >>  503.5 ms/b | lr: 0.00 | grad norm: 0.67 | max abs grad: 0.12 | loss: 1.29 | perp.:  3.62
#  b  30/ 53 >>  481.5 ms/b | lr: 0.00 | grad norm: 0.65 | max abs grad: 0.12 | loss: 1.29 | perp.:  3.64
#  b  40/ 53 >>  488.3 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.09 | loss: 1.29 | perp.:  3.65
#  b  50/ 53 >>  492.5 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.25 | perp.:  3.50
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.60 sec | max abs wt:  5.90 | valid_loss:  2.19 | valid_perplexity:  8.96
# ========================================================================================================
#
#
# Epoch  24/100) lr = 0.004511
#  b  10/ 53 >>  546.2 ms/b | lr: 0.00 | grad norm: 0.58 | max abs grad: 0.07 | loss: 1.40 | perp.:  4.04
#  b  20/ 53 >>  504.8 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.28 | perp.:  3.59
#  b  30/ 53 >>  497.2 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.29 | perp.:  3.62
#  b  40/ 53 >>  495.8 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.08 | loss: 1.26 | perp.:  3.52
#  b  50/ 53 >>  478.3 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.08 | loss: 1.25 | perp.:  3.48
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.60 sec | max abs wt:  6.04 | valid_loss:  2.17 | valid_perplexity:  8.72
# ========================================================================================================
#
#
# Epoch  25/100) lr = 0.004419
#  b  10/ 53 >>  529.5 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.08 | loss: 1.35 | perp.:  3.86
#  b  20/ 53 >>  496.0 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.08 | loss: 1.25 | perp.:  3.50
#  b  30/ 53 >>  505.5 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.06 | loss: 1.24 | perp.:  3.45
#  b  40/ 53 >>  486.6 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.08 | loss: 1.25 | perp.:  3.48
#  b  50/ 53 >>  512.2 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.05 | loss: 1.23 | perp.:  3.44
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.68 sec | max abs wt:  6.12 | valid_loss:  2.06 | valid_perplexity:  7.81
# ========================================================================================================
#
#
# Epoch  26/100) lr = 0.004334
#  b  10/ 52 >>  555.8 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.08 | loss: 1.33 | perp.:  3.78
#  b  20/ 52 >>  484.6 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.09 | loss: 1.25 | perp.:  3.50
#  b  30/ 52 >>  499.2 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.09 | loss: 1.25 | perp.:  3.49
#  b  40/ 52 >>  507.0 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.07 | loss: 1.23 | perp.:  3.43
#  b  50/ 52 >>  499.2 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.06 | loss: 1.20 | perp.:  3.33
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.60 sec | max abs wt:  6.21 | valid_loss:  2.07 | valid_perplexity:  7.90
# ========================================================================================================
#
#
# Epoch  27/100) lr = 0.004253
#  b  10/ 53 >>  536.2 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.11 | loss: 1.35 | perp.:  3.86
#  b  20/ 53 >>  488.6 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.06 | loss: 1.25 | perp.:  3.49
#  b  30/ 53 >>  498.4 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.09 | loss: 1.23 | perp.:  3.41
#  b  40/ 53 >>  485.9 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.12 | loss: 1.24 | perp.:  3.45
#  b  50/ 53 >>  501.4 ms/b | lr: 0.00 | grad norm: 0.56 | max abs grad: 0.09 | loss: 1.23 | perp.:  3.43
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.55 sec | max abs wt:  6.31 | valid_loss:  2.03 | valid_perplexity:  7.61
# ========================================================================================================
#
#
# Epoch  28/100) lr = 0.004176
#  b  10/ 51 >>  561.9 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.07 | loss: 1.33 | perp.:  3.79
#  b  20/ 51 >>  505.6 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.08 | loss: 1.25 | perp.:  3.48
#  b  30/ 51 >>  511.6 ms/b | lr: 0.00 | grad norm: 0.59 | max abs grad: 0.09 | loss: 1.23 | perp.:  3.43
#  b  40/ 51 >>  538.2 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.05 | loss: 1.22 | perp.:  3.37
#  b  50/ 51 >>  474.9 ms/b | lr: 0.00 | grad norm: 1.59 | max abs grad: 0.27 | loss: 1.29 | perp.:  3.63
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.92 sec | max abs wt:  6.41 | valid_loss:  1.97 | valid_perplexity:  7.19
# ========================================================================================================
#
#
# Epoch  29/100) lr = 0.004103
#  b  10/ 53 >>  551.9 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.08 | loss: 1.31 | perp.:  3.71
#  b  20/ 53 >>  481.3 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.07 | loss: 1.22 | perp.:  3.38
#  b  30/ 53 >>  496.8 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.09 | loss: 1.22 | perp.:  3.38
#  b  40/ 53 >>  485.3 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.06 | loss: 1.21 | perp.:  3.34
#  b  50/ 53 >>  489.8 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.07 | loss: 1.20 | perp.:  3.31
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.46 sec | max abs wt:  6.54 | valid_loss:  2.01 | valid_perplexity:  7.45
# ========================================================================================================
#
#
# Epoch  30/100) lr = 0.004034
#  b  10/ 52 >>  562.2 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.09 | loss: 1.29 | perp.:  3.63
#  b  20/ 52 >>  569.2 ms/b | lr: 0.00 | grad norm: 0.53 | max abs grad: 0.07 | loss: 1.22 | perp.:  3.39
#  b  30/ 52 >>  565.9 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.05 | loss: 1.24 | perp.:  3.45
#  b  40/ 52 >>  526.4 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.06 | loss: 1.21 | perp.:  3.34
#  b  50/ 52 >>  539.3 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.07 | loss: 1.20 | perp.:  3.33
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 27.78 sec | max abs wt:  6.66 | valid_loss:  1.97 | valid_perplexity:  7.15
# ========================================================================================================
#
#
# Epoch  31/100) lr = 0.003969
#  b  10/ 53 >>  578.8 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.06 | loss: 1.33 | perp.:  3.79
#  b  20/ 53 >>  510.9 ms/b | lr: 0.00 | grad norm: 0.53 | max abs grad: 0.09 | loss: 1.25 | perp.:  3.48
#  b  30/ 53 >>  522.8 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.07 | loss: 1.19 | perp.:  3.30
#  b  40/ 53 >>  490.9 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.06 | loss: 1.20 | perp.:  3.31
#  b  50/ 53 >>  506.0 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.08 | loss: 1.19 | perp.:  3.30
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.42 sec | max abs wt:  6.76 | valid_loss:  1.94 | valid_perplexity:  6.98
# ========================================================================================================
#
#
# Epoch  32/100) lr = 0.003906
#  b  10/ 51 >>  557.3 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.08 | loss: 1.30 | perp.:  3.66
#  b  20/ 51 >>  513.9 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.06 | loss: 1.20 | perp.:  3.33
#  b  30/ 51 >>  510.4 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.07 | loss: 1.19 | perp.:  3.28
#  b  40/ 51 >>  523.2 ms/b | lr: 0.00 | grad norm: 0.56 | max abs grad: 0.06 | loss: 1.20 | perp.:  3.30
#  b  50/ 51 >>  462.8 ms/b | lr: 0.00 | grad norm: 1.60 | max abs grad: 0.21 | loss: 1.27 | perp.:  3.57
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.68 sec | max abs wt:  6.87 | valid_loss:  1.93 | valid_perplexity:  6.88
# ========================================================================================================
#
#
# Epoch  33/100) lr = 0.003847
#  b  10/ 53 >>  553.2 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.06 | loss: 1.26 | perp.:  3.53
#  b  20/ 53 >>  519.8 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.10 | loss: 1.20 | perp.:  3.33
#  b  30/ 53 >>  494.4 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.08 | loss: 1.17 | perp.:  3.21
#  b  40/ 53 >>  479.8 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.06 | loss: 1.17 | perp.:  3.23
#  b  50/ 53 >>  492.7 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.06 | loss: 1.16 | perp.:  3.18
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.84 sec | max abs wt:  7.00 | valid_loss:  1.91 | valid_perplexity:  6.77
# ========================================================================================================
#
#
# Epoch  34/100) lr = 0.00379
#  b  10/ 53 >>  550.5 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.08 | loss: 1.26 | perp.:  3.54
#  b  20/ 53 >>  506.0 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.06 | loss: 1.18 | perp.:  3.25
#  b  30/ 53 >>  514.6 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.06 | loss: 1.15 | perp.:  3.15
#  b  40/ 53 >>  517.3 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.18 | perp.:  3.25
#  b  50/ 53 >>  507.8 ms/b | lr: 0.00 | grad norm: 0.38 | max abs grad: 0.06 | loss: 1.20 | perp.:  3.30
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.43 sec | max abs wt:  7.13 | valid_loss:  1.95 | valid_perplexity:  7.04
# ========================================================================================================
#
#
# Epoch  35/100) lr = 0.003735
#  b  10/ 52 >>  601.6 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.07 | loss: 1.28 | perp.:  3.61
#  b  20/ 52 >>  502.6 ms/b | lr: 0.00 | grad norm: 0.57 | max abs grad: 0.08 | loss: 1.21 | perp.:  3.36
#  b  30/ 52 >>  528.7 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.06 | loss: 1.18 | perp.:  3.25
#  b  40/ 52 >>  489.8 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.05 | loss: 1.17 | perp.:  3.23
#  b  50/ 52 >>  491.2 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.05 | loss: 1.17 | perp.:  3.22
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.29 sec | max abs wt:  7.22 | valid_loss:  1.91 | valid_perplexity:  6.72
# ========================================================================================================
#
#
# Epoch  36/100) lr = 0.003683
#  b  10/ 52 >>  553.4 ms/b | lr: 0.00 | grad norm: 0.53 | max abs grad: 0.09 | loss: 1.26 | perp.:  3.52
#  b  20/ 52 >>  497.9 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.06 | loss: 1.18 | perp.:  3.24
#  b  30/ 52 >>  481.6 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.18 | perp.:  3.25
#  b  40/ 52 >>  518.1 ms/b | lr: 0.00 | grad norm: 0.35 | max abs grad: 0.05 | loss: 1.16 | perp.:  3.19
#  b  50/ 52 >>  509.6 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.06 | loss: 1.15 | perp.:  3.15
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.75 sec | max abs wt:  7.33 | valid_loss:  1.89 | valid_perplexity:  6.59
# ========================================================================================================
#
#
# Epoch  37/100) lr = 0.003633
#  b  10/ 53 >>  558.5 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.06 | loss: 1.26 | perp.:  3.52
#  b  20/ 53 >>  491.5 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.07 | loss: 1.16 | perp.:  3.20
#  b  30/ 53 >>  520.7 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.06 | loss: 1.18 | perp.:  3.25
#  b  40/ 53 >>  507.2 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.08 | loss: 1.15 | perp.:  3.14
#  b  50/ 53 >>  484.4 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.08 | loss: 1.13 | perp.:  3.10
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.98 sec | max abs wt:  7.40 | valid_loss:  1.74 | valid_perplexity:  5.71
# ========================================================================================================
#
#
# Epoch  38/100) lr = 0.003585
#  b  10/ 53 >>  557.7 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.05 | loss: 1.23 | perp.:  3.43
#  b  20/ 53 >>  515.9 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.06 | loss: 1.16 | perp.:  3.19
#  b  30/ 53 >>  512.1 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.07 | loss: 1.16 | perp.:  3.18
#  b  40/ 53 >>  498.4 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.08 | loss: 1.16 | perp.:  3.19
#  b  50/ 53 >>  511.2 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.05 | loss: 1.14 | perp.:  3.14
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.40 sec | max abs wt:  7.49 | valid_loss:  1.84 | valid_perplexity:  6.31
# ========================================================================================================
#
#
# Epoch  39/100) lr = 0.003538
#  b  10/ 53 >>  553.5 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.06 | loss: 1.27 | perp.:  3.56
#  b  20/ 53 >>  515.7 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.09 | loss: 1.17 | perp.:  3.22
#  b  30/ 53 >>  494.8 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.05 | loss: 1.16 | perp.:  3.19
#  b  40/ 53 >>  487.2 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.16 | perp.:  3.19
#  b  50/ 53 >>  488.1 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.08
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.78 sec | max abs wt:  7.58 | valid_loss:  1.80 | valid_perplexity:  6.06
# ========================================================================================================
#
#
# Epoch  40/100) lr = 0.003494
#  b  10/ 52 >>  543.0 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.05 | loss: 1.25 | perp.:  3.51
#  b  20/ 52 >>  507.5 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.07 | loss: 1.17 | perp.:  3.21
#  b  30/ 52 >>  484.0 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.06 | loss: 1.15 | perp.:  3.17
#  b  40/ 52 >>  505.1 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.04 | loss: 1.16 | perp.:  3.18
#  b  50/ 52 >>  476.5 ms/b | lr: 0.00 | grad norm: 0.61 | max abs grad: 0.07 | loss: 1.15 | perp.:  3.15
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.30 sec | max abs wt:  7.65 | valid_loss:  1.85 | valid_perplexity:  6.34
# ========================================================================================================
#
#
# Epoch  41/100) lr = 0.003451
#  b  10/ 52 >>  549.4 ms/b | lr: 0.00 | grad norm: 0.38 | max abs grad: 0.04 | loss: 1.23 | perp.:  3.41
#  b  20/ 52 >>  496.2 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.07 | loss: 1.15 | perp.:  3.15
#  b  30/ 52 >>  500.6 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.06 | loss: 1.13 | perp.:  3.10
#  b  40/ 52 >>  497.3 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.04 | loss: 1.14 | perp.:  3.13
#  b  50/ 52 >>  502.9 ms/b | lr: 0.00 | grad norm: 0.93 | max abs grad: 0.12 | loss: 1.17 | perp.:  3.23
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.60 sec | max abs wt:  7.71 | valid_loss:  1.85 | valid_perplexity:  6.35
# ========================================================================================================
#
#
# Epoch  42/100) lr = 0.00341
#  b  10/ 53 >>  558.4 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.09 | loss: 1.22 | perp.:  3.39
#  b  20/ 53 >>  498.5 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.05 | loss: 1.13 | perp.:  3.10
#  b  30/ 53 >>  492.9 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.05 | loss: 1.15 | perp.:  3.15
#  b  40/ 53 >>  500.5 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.04 | loss: 1.12 | perp.:  3.07
#  b  50/ 53 >>  480.7 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.10 | loss: 1.12 | perp.:  3.08
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.73 sec | max abs wt:  7.80 | valid_loss:  1.80 | valid_perplexity:  6.08
# ========================================================================================================
#
#
# Epoch  43/100) lr = 0.00337
#  b  10/ 52 >>  546.6 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.07 | loss: 1.21 | perp.:  3.35
#  b  20/ 52 >>  503.1 ms/b | lr: 0.00 | grad norm: 0.36 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.06
#  b  30/ 52 >>  491.5 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.07 | loss: 1.14 | perp.:  3.12
#  b  40/ 52 >>  504.3 ms/b | lr: 0.00 | grad norm: 0.54 | max abs grad: 0.06 | loss: 1.14 | perp.:  3.11
#  b  50/ 52 >>  480.3 ms/b | lr: 0.00 | grad norm: 0.66 | max abs grad: 0.08 | loss: 1.15 | perp.:  3.17
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.40 sec | max abs wt:  7.87 | valid_loss:  1.75 | valid_perplexity:  5.74
# ========================================================================================================
#
#
# Epoch  44/100) lr = 0.003331
#  b  10/ 52 >>  536.7 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.05 | loss: 1.24 | perp.:  3.45
#  b  20/ 52 >>  495.4 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.04 | loss: 1.14 | perp.:  3.14
#  b  30/ 52 >>  490.4 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.05 | loss: 1.15 | perp.:  3.15
#  b  40/ 52 >>  507.9 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.05 | loss: 1.13 | perp.:  3.09
#  b  50/ 52 >>  491.0 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.06 | loss: 1.10 | perp.:  3.01
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.35 sec | max abs wt:  7.91 | valid_loss:  1.79 | valid_perplexity:  5.98
# ========================================================================================================
#
#
# Epoch  45/100) lr = 0.003294
#  b  10/ 53 >>  540.8 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.05 | loss: 1.22 | perp.:  3.40
#  b  20/ 53 >>  487.1 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.06 | loss: 1.17 | perp.:  3.21
#  b  30/ 53 >>  499.4 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.07 | loss: 1.17 | perp.:  3.22
#  b  40/ 53 >>  482.0 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.05 | loss: 1.13 | perp.:  3.09
#  b  50/ 53 >>  484.7 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.06
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.57 sec | max abs wt:  7.98 | valid_loss:  1.74 | valid_perplexity:  5.71
# ========================================================================================================
#
#
# Epoch  46/100) lr = 0.003258
#  b  10/ 52 >>  554.2 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.05 | loss: 1.23 | perp.:  3.42
#  b  20/ 52 >>  490.9 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.04 | loss: 1.12 | perp.:  3.05
#  b  30/ 52 >>  546.1 ms/b | lr: 0.00 | grad norm: 0.38 | max abs grad: 0.05 | loss: 1.13 | perp.:  3.08
#  b  40/ 52 >>  478.3 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.08 | loss: 1.14 | perp.:  3.11
#  b  50/ 52 >>  485.8 ms/b | lr: 0.00 | grad norm: 0.58 | max abs grad: 0.07 | loss: 1.11 | perp.:  3.04
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.69 sec | max abs wt:  8.05 | valid_loss:  1.75 | valid_perplexity:  5.75
# ========================================================================================================
#
#
# Epoch  47/100) lr = 0.003223
#  b  10/ 53 >>  541.1 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.06 | loss: 1.20 | perp.:  3.33
#  b  20/ 53 >>  536.0 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.08 | loss: 1.14 | perp.:  3.11
#  b  30/ 53 >>  568.0 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.07 | loss: 1.11 | perp.:  3.03
#  b  40/ 53 >>  529.7 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.06 | loss: 1.13 | perp.:  3.09
#  b  50/ 53 >>  491.6 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.06 | loss: 1.11 | perp.:  3.03
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.99 sec | max abs wt:  8.13 | valid_loss:  1.76 | valid_perplexity:  5.83
# ========================================================================================================
#
#
# Epoch  48/100) lr = 0.003189
#  b  10/ 53 >>  541.5 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.06 | loss: 1.22 | perp.:  3.39
#  b  20/ 53 >>  503.8 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.14 | perp.:  3.12
#  b  30/ 53 >>  509.6 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.09 | loss: 1.11 | perp.:  3.04
#  b  40/ 53 >>  486.1 ms/b | lr: 0.00 | grad norm: 0.53 | max abs grad: 0.07 | loss: 1.12 | perp.:  3.08
#  b  50/ 53 >>  500.1 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.06 | loss: 1.10 | perp.:  3.00
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.83 sec | max abs wt:  8.19 | valid_loss:  1.78 | valid_perplexity:  5.96
# ========================================================================================================
#
#
# Epoch  49/100) lr = 0.003157
#  b  10/ 53 >>  544.4 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.21 | perp.:  3.35
#  b  20/ 53 >>  476.0 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.06 | loss: 1.14 | perp.:  3.11
#  b  30/ 53 >>  502.0 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.06 | loss: 1.11 | perp.:  3.04
#  b  40/ 53 >>  489.6 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.10 | perp.:  3.00
#  b  50/ 53 >>  497.8 ms/b | lr: 0.00 | grad norm: 0.34 | max abs grad: 0.05 | loss: 1.09 | perp.:  2.98
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.41 sec | max abs wt:  8.20 | valid_loss:  1.76 | valid_perplexity:  5.82
# ========================================================================================================
#
#
# Epoch  50/100) lr = 0.003125
#  b  10/ 52 >>  530.5 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.09 | loss: 1.22 | perp.:  3.38
#  b  20/ 52 >>  523.9 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.05 | loss: 1.13 | perp.:  3.11
#  b  30/ 52 >>  498.6 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.06
#  b  40/ 52 >>  501.1 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.11 | perp.:  3.02
#  b  50/ 52 >>  496.5 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.05 | loss: 1.09 | perp.:  2.98
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.65 sec | max abs wt:  8.24 | valid_loss:  1.72 | valid_perplexity:  5.58
# ========================================================================================================
#
#
# Epoch  51/100) lr = 0.003094
#  b  10/ 53 >>  536.4 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.19 | perp.:  3.29
#  b  20/ 53 >>  522.8 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.06 | loss: 1.09 | perp.:  2.97
#  b  30/ 53 >>  504.9 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.06
#  b  40/ 53 >>  515.5 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.06 | loss: 1.10 | perp.:  3.00
#  b  50/ 53 >>  523.0 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.05 | loss: 1.09 | perp.:  2.99
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.42 sec | max abs wt:  8.30 | valid_loss:  1.72 | valid_perplexity:  5.58
# ========================================================================================================
#
#
# Epoch  52/100) lr = 0.003064
#  b  10/ 53 >>  554.2 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.08 | loss: 1.22 | perp.:  3.39
#  b  20/ 53 >>  494.1 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.07 | loss: 1.13 | perp.:  3.10
#  b  30/ 53 >>  489.2 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.04 | loss: 1.10 | perp.:  3.00
#  b  40/ 53 >>  508.0 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.05 | loss: 1.10 | perp.:  3.00
#  b  50/ 53 >>  519.2 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.07 | loss: 1.10 | perp.:  2.99
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.02 sec | max abs wt:  8.33 | valid_loss:  1.70 | valid_perplexity:  5.50
# ========================================================================================================
#
#
# Epoch  53/100) lr = 0.003035
#  b  10/ 52 >>  591.7 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.06 | loss: 1.21 | perp.:  3.36
#  b  20/ 52 >>  549.9 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.07 | loss: 1.10 | perp.:  2.99
#  b  30/ 52 >>  503.5 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.05 | loss: 1.09 | perp.:  2.98
#  b  40/ 52 >>  525.8 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.07 | loss: 1.09 | perp.:  2.97
#  b  50/ 52 >>  547.8 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.04 | loss: 1.10 | perp.:  3.01
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 27.36 sec | max abs wt:  8.36 | valid_loss:  1.70 | valid_perplexity:  5.48
# ========================================================================================================
#
#
# Epoch  54/100) lr = 0.003007
#  b  10/ 52 >>  616.7 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.06 | loss: 1.20 | perp.:  3.32
#  b  20/ 52 >>  522.3 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.07 | loss: 1.10 | perp.:  3.01
#  b  30/ 52 >>  542.0 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.06 | loss: 1.09 | perp.:  2.98
#  b  40/ 52 >>  558.6 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.05 | loss: 1.11 | perp.:  3.04
#  b  50/ 52 >>  554.5 ms/b | lr: 0.00 | grad norm: 0.54 | max abs grad: 0.08 | loss: 1.09 | perp.:  2.99
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 28.09 sec | max abs wt:  8.41 | valid_loss:  1.67 | valid_perplexity:  5.29
# ========================================================================================================
#
#
# Epoch  55/100) lr = 0.00298
#  b  10/ 53 >>  597.6 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.07 | loss: 1.18 | perp.:  3.24
#  b  20/ 53 >>  524.4 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.09 | loss: 1.09 | perp.:  2.99
#  b  30/ 53 >>  501.3 ms/b | lr: 0.00 | grad norm: 0.57 | max abs grad: 0.09 | loss: 1.12 | perp.:  3.07
#  b  40/ 53 >>  503.4 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.08 | loss: 1.10 | perp.:  3.00
#  b  50/ 53 >>  501.1 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.04 | loss: 1.09 | perp.:  2.99
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.59 sec | max abs wt:  8.46 | valid_loss:  1.71 | valid_perplexity:  5.55
# ========================================================================================================
#
#
# Epoch  56/100) lr = 0.002953
#  b  10/ 53 >>  544.9 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.07 | loss: 1.22 | perp.:  3.39
#  b  20/ 53 >>  498.3 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.04 | loss: 1.10 | perp.:  2.99
#  b  30/ 53 >>  506.4 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.07 | loss: 1.09 | perp.:  2.98
#  b  40/ 53 >>  504.6 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.06
#  b  50/ 53 >>  504.2 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.07 | loss: 1.07 | perp.:  2.91
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.15 sec | max abs wt:  8.50 | valid_loss:  1.73 | valid_perplexity:  5.64
# ========================================================================================================
#
#
# Epoch  57/100) lr = 0.002927
#  b  10/ 52 >>  577.0 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.07 | loss: 1.19 | perp.:  3.29
#  b  20/ 52 >>  535.2 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.06 | loss: 1.13 | perp.:  3.10
# ...
#  b  30/ 53 >>  498.9 ms/b | lr: 0.00 | grad norm: 0.38 | max abs grad: 0.04 | loss: 1.06 | perp.:  2.88
#  b  40/ 53 >>  533.9 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.04 | loss: 1.04 | perp.:  2.83
#  b  50/ 53 >>  512.1 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.05 | loss: 1.02 | perp.:  2.78
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.58 sec | max abs wt:  9.20 | valid_loss:  1.61 | valid_perplexity:  5.00
# ========================================================================================================
#
#
# Epoch  83/100) lr = 0.002425
#  b  10/ 53 >>  573.3 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.06 | loss: 1.14 | perp.:  3.13
#  b  20/ 53 >>  500.6 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.06 | loss: 1.07 | perp.:  2.93
#  b  30/ 53 >>  507.1 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.06 | loss: 1.03 | perp.:  2.79
#  b  40/ 53 >>  517.6 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.04 | loss: 1.03 | perp.:  2.81
#  b  50/ 53 >>  499.8 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.05 | loss: 1.03 | perp.:  2.81
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.44 sec | max abs wt:  9.21 | valid_loss:  1.61 | valid_perplexity:  4.99
# ========================================================================================================
#
#
# Epoch  84/100) lr = 0.002411
#  b  10/ 53 >>  523.6 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.08
#  b  20/ 53 >>  498.4 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.05 | loss: 1.09 | perp.:  2.96
#  b  30/ 53 >>  473.1 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.06 | perp.:  2.89
#  b  40/ 53 >>  484.9 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.05 | loss: 1.07 | perp.:  2.92
#  b  50/ 53 >>  532.2 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.04 | loss: 1.02 | perp.:  2.77
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.81 sec | max abs wt:  9.23 | valid_loss:  1.58 | valid_perplexity:  4.87
# ========================================================================================================
#
#
# Epoch  85/100) lr = 0.002397
#  b  10/ 52 >>  593.0 ms/b | lr: 0.00 | grad norm: 0.56 | max abs grad: 0.07 | loss: 1.15 | perp.:  3.17
#  b  20/ 52 >>  493.0 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.06 | perp.:  2.90
#  b  30/ 52 >>  487.0 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.05 | loss: 1.02 | perp.:  2.79
#  b  40/ 52 >>  493.5 ms/b | lr: 0.00 | grad norm: 0.54 | max abs grad: 0.06 | loss: 1.05 | perp.:  2.86
#  b  50/ 52 >>  490.2 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.04 | loss: 1.06 | perp.:  2.89
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.70 sec | max abs wt:  9.26 | valid_loss:  1.55 | valid_perplexity:  4.71
# ========================================================================================================
#
#
# Epoch  86/100) lr = 0.002383
#  b  10/ 52 >>  555.4 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.07 | loss: 1.14 | perp.:  3.14
#  b  20/ 52 >>  519.5 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.05 | loss: 1.07 | perp.:  2.92
#  b  30/ 52 >>  491.8 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.05 | loss: 1.08 | perp.:  2.93
#  b  40/ 52 >>  491.3 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.04 | loss: 1.03 | perp.:  2.81
#  b  50/ 52 >>  493.3 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.04 | loss: 1.05 | perp.:  2.85
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.66 sec | max abs wt:  9.27 | valid_loss:  1.64 | valid_perplexity:  5.17
# ========================================================================================================
#
#
# Epoch  87/100) lr = 0.002369
#  b  10/ 52 >>  542.6 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.15 | perp.:  3.17
#  b  20/ 52 >>  491.8 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.04 | loss: 1.06 | perp.:  2.89
#  b  30/ 52 >>  487.8 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.07 | loss: 1.07 | perp.:  2.92
#  b  40/ 52 >>  495.0 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.05 | loss: 1.05 | perp.:  2.85
#  b  50/ 52 >>  497.3 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.07 | loss: 1.05 | perp.:  2.87
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.28 sec | max abs wt:  9.28 | valid_loss:  1.56 | valid_perplexity:  4.76
# ========================================================================================================
#
#
# Epoch  88/100) lr = 0.002356
#  b  10/ 53 >>  525.2 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.05 | loss: 1.14 | perp.:  3.14
#  b  20/ 53 >>  492.8 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.04 | loss: 1.06 | perp.:  2.89
#  b  30/ 53 >>  498.2 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.02 | perp.:  2.78
#  b  40/ 53 >>  496.9 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.04 | perp.:  2.84
#  b  50/ 53 >>  484.8 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.07 | loss: 1.06 | perp.:  2.88
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.39 sec | max abs wt:  9.30 | valid_loss:  1.53 | valid_perplexity:  4.62
# ========================================================================================================
#
#
# Epoch  89/100) lr = 0.002342
#  b  10/ 52 >>  546.1 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.07
#  b  20/ 52 >>  496.7 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.05 | loss: 1.04 | perp.:  2.82
#  b  30/ 52 >>  496.0 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.06 | loss: 1.06 | perp.:  2.88
#  b  40/ 52 >>  493.9 ms/b | lr: 0.00 | grad norm: 0.37 | max abs grad: 0.04 | loss: 1.07 | perp.:  2.91
#  b  50/ 52 >>  489.5 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.05 | loss: 1.02 | perp.:  2.76
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.37 sec | max abs wt:  9.31 | valid_loss:  1.65 | valid_perplexity:  5.21
# ========================================================================================================
#
#
# Epoch  90/100) lr = 0.002329
#  b  10/ 52 >>  568.4 ms/b | lr: 0.00 | grad norm: 0.65 | max abs grad: 0.08 | loss: 1.15 | perp.:  3.16
#  b  20/ 52 >>  538.6 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.07 | loss: 1.05 | perp.:  2.85
#  b  30/ 52 >>  543.1 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.03 | perp.:  2.80
#  b  40/ 52 >>  497.8 ms/b | lr: 0.00 | grad norm: 0.53 | max abs grad: 0.06 | loss: 1.04 | perp.:  2.83
#  b  50/ 52 >>  494.7 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.01 | perp.:  2.76
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.56 sec | max abs wt:  9.33 | valid_loss:  1.61 | valid_perplexity:  5.02
# ========================================================================================================
#
#
# Epoch  91/100) lr = 0.002316
#  b  10/ 53 >>  550.7 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.04 | loss: 1.13 | perp.:  3.10
#  b  20/ 53 >>  486.2 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.04 | loss: 1.03 | perp.:  2.80
#  b  30/ 53 >>  488.9 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.05 | loss: 1.07 | perp.:  2.91
#  b  40/ 53 >>  517.0 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.04 | loss: 1.06 | perp.:  2.90
#  b  50/ 53 >>  492.5 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.04 | loss: 1.03 | perp.:  2.80
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.74 sec | max abs wt:  9.35 | valid_loss:  1.67 | valid_perplexity:  5.32
# ========================================================================================================
#
#
# Epoch  92/100) lr = 0.002304
#  b  10/ 52 >>  561.4 ms/b | lr: 0.00 | grad norm: 0.49 | max abs grad: 0.06 | loss: 1.12 | perp.:  3.06
#  b  20/ 52 >>  533.2 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.06 | loss: 1.06 | perp.:  2.89
#  b  30/ 52 >>  500.2 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.07 | loss: 1.06 | perp.:  2.88
#  b  40/ 52 >>  507.4 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.07 | perp.:  2.91
#  b  50/ 52 >>  471.8 ms/b | lr: 0.00 | grad norm: 0.57 | max abs grad: 0.09 | loss: 1.04 | perp.:  2.84
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.89 sec | max abs wt:  9.35 | valid_loss:  1.60 | valid_perplexity:  4.94
# ========================================================================================================
#
#
# Epoch  93/100) lr = 0.002291
#  b  10/ 53 >>  534.6 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.04 | loss: 1.13 | perp.:  3.08
#  b  20/ 53 >>  512.0 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.05 | loss: 1.05 | perp.:  2.87
#  b  30/ 53 >>  494.6 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.06 | loss: 1.05 | perp.:  2.85
#  b  40/ 53 >>  486.7 ms/b | lr: 0.00 | grad norm: 0.55 | max abs grad: 0.07 | loss: 1.06 | perp.:  2.87
#  b  50/ 53 >>  508.7 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.04 | loss: 1.03 | perp.:  2.81
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.73 sec | max abs wt:  9.36 | valid_loss:  1.52 | valid_perplexity:  4.57
# ========================================================================================================
#
#
# Epoch  94/100) lr = 0.002279
#  b  10/ 53 >>  542.4 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.04 | loss: 1.11 | perp.:  3.04
#  b  20/ 53 >>  482.9 ms/b | lr: 0.00 | grad norm: 0.55 | max abs grad: 0.07 | loss: 1.03 | perp.:  2.80
#  b  30/ 53 >>  490.1 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.05 | perp.:  2.86
#  b  40/ 53 >>  487.2 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.06 | loss: 1.04 | perp.:  2.84
#  b  50/ 53 >>  511.0 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.05 | loss: 1.04 | perp.:  2.83
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.57 sec | max abs wt:  9.37 | valid_loss:  1.55 | valid_perplexity:  4.73
# ========================================================================================================
#
#
# Epoch  95/100) lr = 0.002267
#  b  10/ 52 >>  542.6 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.12 | perp.:  3.06
#  b  20/ 52 >>  497.9 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.05 | loss: 1.06 | perp.:  2.88
#  b  30/ 52 >>  492.6 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.06 | loss: 1.04 | perp.:  2.83
#  b  40/ 52 >>  518.2 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.04 | loss: 1.06 | perp.:  2.87
#  b  50/ 52 >>  478.2 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.04 | loss: 1.04 | perp.:  2.82
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.44 sec | max abs wt:  9.39 | valid_loss:  1.55 | valid_perplexity:  4.71
# ========================================================================================================
#
#
# Epoch  96/100) lr = 0.002255
#  b  10/ 53 >>  535.1 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.05 | loss: 1.14 | perp.:  3.13
#  b  20/ 53 >>  500.8 ms/b | lr: 0.00 | grad norm: 0.48 | max abs grad: 0.05 | loss: 1.06 | perp.:  2.88
#  b  30/ 53 >>  492.3 ms/b | lr: 0.00 | grad norm: 0.50 | max abs grad: 0.04 | loss: 1.04 | perp.:  2.83
#  b  40/ 53 >>  495.9 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.04 | loss: 1.04 | perp.:  2.83
#  b  50/ 53 >>  478.7 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.05 | loss: 1.01 | perp.:  2.76
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.71 sec | max abs wt:  9.40 | valid_loss:  1.53 | valid_perplexity:  4.62
# ========================================================================================================
#
#
# Epoch  97/100) lr = 0.002244
#  b  10/ 52 >>  549.1 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.08 | loss: 1.14 | perp.:  3.12
#  b  20/ 52 >>  497.8 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.07 | loss: 1.03 | perp.:  2.81
#  b  30/ 52 >>  509.3 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.04 | loss: 1.04 | perp.:  2.82
#  b  40/ 52 >>  520.3 ms/b | lr: 0.00 | grad norm: 0.51 | max abs grad: 0.06 | loss: 1.06 | perp.:  2.88
#  b  50/ 52 >>  529.8 ms/b | lr: 0.00 | grad norm: 0.38 | max abs grad: 0.04 | loss: 1.04 | perp.:  2.84
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.21 sec | max abs wt:  9.41 | valid_loss:  1.51 | valid_perplexity:  4.51
# ========================================================================================================
#
#
# Epoch  98/100) lr = 0.002232
#  b  10/ 54 >>  549.4 ms/b | lr: 0.00 | grad norm: 0.46 | max abs grad: 0.04 | loss: 1.14 | perp.:  3.14
#  b  20/ 54 >>  527.4 ms/b | lr: 0.00 | grad norm: 0.44 | max abs grad: 0.06 | loss: 1.05 | perp.:  2.85
#  b  30/ 54 >>  520.0 ms/b | lr: 0.00 | grad norm: 0.42 | max abs grad: 0.06 | loss: 1.02 | perp.:  2.77
#  b  40/ 54 >>  482.6 ms/b | lr: 0.00 | grad norm: 0.52 | max abs grad: 0.07 | loss: 1.03 | perp.:  2.80
#  b  50/ 54 >>  507.6 ms/b | lr: 0.00 | grad norm: 0.38 | max abs grad: 0.04 | loss: 1.01 | perp.:  2.75
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.69 sec | max abs wt:  9.43 | valid_loss:  1.57 | valid_perplexity:  4.82
# ========================================================================================================
#
#
# Epoch  99/100) lr = 0.002221
#  b  10/ 52 >>  533.2 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.05 | loss: 1.11 | perp.:  3.03
#  b  20/ 52 >>  531.8 ms/b | lr: 0.00 | grad norm: 0.41 | max abs grad: 0.05 | loss: 1.04 | perp.:  2.83
#  b  30/ 52 >>  507.2 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.04 | loss: 1.07 | perp.:  2.93
#  b  40/ 52 >>  479.5 ms/b | lr: 0.00 | grad norm: 0.43 | max abs grad: 0.04 | loss: 1.02 | perp.:  2.78
#  b  50/ 52 >>  493.6 ms/b | lr: 0.00 | grad norm: 0.58 | max abs grad: 0.05 | loss: 1.04 | perp.:  2.82
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 25.60 sec | max abs wt:  9.43 | valid_loss:  1.63 | valid_perplexity:  5.10
# ========================================================================================================
#
#
# Epoch 100/100) lr = 0.00221
#  b  10/ 53 >>  572.2 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.06 | loss: 1.12 | perp.:  3.05
#  b  20/ 53 >>  512.2 ms/b | lr: 0.00 | grad norm: 0.47 | max abs grad: 0.06 | loss: 1.03 | perp.:  2.79
#  b  30/ 53 >>  505.9 ms/b | lr: 0.00 | grad norm: 0.40 | max abs grad: 0.05 | loss: 1.04 | perp.:  2.84
#  b  40/ 53 >>  509.2 ms/b | lr: 0.00 | grad norm: 0.39 | max abs grad: 0.04 | loss: 1.01 | perp.:  2.76
#  b  50/ 53 >>  503.6 ms/b | lr: 0.00 | grad norm: 0.45 | max abs grad: 0.05 | loss: 1.05 | perp.:  2.87
# --------------------------------------------------------------------------------------------------------
# Elapsed time: 26.49 sec | max abs wt:  9.45 | valid_loss:  1.50 | valid_perplexity:  4.49
# ========================================================================================================

# %%
test_loss = evaluate(test_data)
print('test_loss: {:5.2f} | test_perplexity: {:5.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss:  1.57 | test_perplexity:  4.81

# %% [markdown]
# ## Evaluation
# Check out the prediction quality

# %%
# Get a random sequence from the generated data starting from whatever point
data, prev, targets = get_batch(test_data, 120, seq_len)
# We'll just look at a few batches
nb = 4
data = data[:nb].contiguous()
prev = prev[:nb].contiguous()
targets = targets[:nb].contiguous()

# %%
# Run the model forward
output = model(data, prev)
# Convert to probabilities
output = output.exp()
# Get the max prob for each step
output_probs, output_idx = output.max(-1)

# %%
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 2 incorrectly predicted
#  Variable containing:
#     5     6     0     3     3     1     1     0     3     4     3
#     5     6     0     3     3     1     1     3     3     4     4
# [torch.LongTensor of size 2x11]
#
# 2 incorrectly predicted
#  Variable containing:
#     2     4     0     5     5     5     6     6     2     1     4
#     2     4     0     5     5     5     6     6     2     2     1
# [torch.LongTensor of size 2x11]
#
# 5 incorrectly predicted
#  Variable containing:
#     4     3     0     0     0     5     1     0     5     3     2
#     0     3     0     0     0     5     5     0     0     0     3
# [torch.LongTensor of size 2x11]
#
# 4 incorrectly predicted
#  Variable containing:
#     4     1     3     1     3     4     2     4     0     5     1
#     1     1     3     3     3     4     2     4     0     0     5
# [torch.LongTensor of size 2x11]

# %% [markdown]
# ## Visualizations

# %%
modules = list(model.modules())
list(enumerate(modules))
# Out:
# [(0, TestModel(
#     (dropout): Dropout(p=0.1)
#     (src_embedding): Embedding(7, 512)
#     (tgt_embedding): Embedding(7, 512)
#     (attn): TransformerAttention(
#       (dropout): Dropout(p=0.1)
#       (src_position): PositionalEncoding(
#         (dropout): Dropout(p=0.1)
#       )
#       (tgt_position): PositionalEncoding(
#         (dropout): Dropout(p=0.1)
#       )
#       (enc_norm): LayerNorm(
#       )
#       (dec_norm): LayerNorm(
#       )
#     )
#     (projection): Linear(in_features=512, out_features=7)
#     (log_softmax): LogSoftmax()
#   )),
#  (1, Dropout(p=0.1)),
#  (2, Embedding(7, 512)),
#  (3, Embedding(7, 512)),
#  (4, TransformerAttention(
#     (dropout): Dropout(p=0.1)
#     (src_position): PositionalEncoding(
#       (dropout): Dropout(p=0.1)
#     )
#     (tgt_position): PositionalEncoding(
#       (dropout): Dropout(p=0.1)
#     )
#     (enc_norm): LayerNorm(
#     )
#     (dec_norm): LayerNorm(
#     )
#   )),
#  (5, Dropout(p=0.1)),
#  (6, PositionalEncoding(
#     (dropout): Dropout(p=0.1)
#   )),
#  (7, Dropout(p=0.1)),
#  (8, PositionalEncoding(
#     (dropout): Dropout(p=0.1)
#   )),
#  (9, Dropout(p=0.1)),
#  (10, LayerNorm(
#   )),
#  (11, LayerNorm(
#   )),
#  (12, Linear(in_features=512, out_features=7)),
#  (13, LogSoftmax())]

# %%
attn_module = modules[4]

# %% [markdown]
# Visualize attention weights for the first sequence:

# %% [markdown]
# **Encoder attention weights**

# %%
for layer in range(N):
    cols = 4
    rows = n_heads//cols
    fig, axs = plt.subplots(rows, cols, figsize = (20, 10))
    wts = attn_module.encoder_stack[layer].attn.attn.data[:seq_len]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    print("\nEncoder layer %d (mean = %g, min = %g, max = %g)" % (layer+1, wts_mean, wts_min, wts_max))
    for h in range(n_heads):
        r = h // cols
        c = h % cols
        ax = axs[r, c]
        ax.imshow(norm[0, h], aspect = 'auto', cmap = 'jet')
        # Fix labels
        s = list(targets[0].data)
        ax.set_xticks(range(seq_len))
        ax.set_xticklabels(s if r == rows-1 else [])
        ax.set_yticks(range(seq_len))
        ax.set_yticklabels(s if c == 0 else [])
    plt.show()
# Out:
# Encoder layer 1 (mean = 0.0897006, min = 0, max = 0.820962)
# Encoder layer 2 (mean = 0.0902969, min = 0, max = 0.752434)
# Encoder layer 3 (mean = 0.0923137, min = 0, max = 0.811446)

# %% [markdown]
# **Decoder self-attention weights**

# %%
for layer in range(N):
    cols = 4
    rows = n_heads//cols
    # Self-attention weights
    fig, axs = plt.subplots(rows, cols, figsize = (20, 10))
    wts = attn_module.decoder_stack[layer].self_attn.attn.data[:seq_len]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    print("\nDecoder self-attention %d (mean = %g, min = %g, max = %g)" % (layer+1, wts_mean, wts_min, wts_max))
    for h in range(n_heads):
        r = h // cols
        c = h % cols
        ax = axs[r, c]
        ax.imshow(norm[0, h], aspect = 'auto', cmap = 'jet')
        # Fix labels
        s = list(targets[0].data)
        ax.set_xticks(range(seq_len))
        ax.set_xticklabels(s if r == rows-1 else [])
        ax.set_yticks(range(seq_len))
        ax.set_yticklabels(s if c == 0 else [])
    plt.show()
# Out:
# Decoder self-attention 1 (mean = 0.0908098, min = 0, max = 0.739354)
# Decoder self-attention 2 (mean = 0.0930872, min = 0, max = 0.693365)
# Decoder self-attention 3 (mean = 0.0915779, min = 0, max = 0.680359)

# %% [markdown]
# **Decoder source-attention weights**

# %%
for layer in range(N):
    cols = 4
    rows = n_heads//cols
    # Self-attention weights
    fig, axs = plt.subplots(rows, cols, figsize = (20, 10))
    wts = attn_module.decoder_stack[layer].src_attn.attn.data[:seq_len]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    print("\nDecoder src-attention %d (mean = %g, min = %g, max = %g)" % (layer+1, wts_mean, wts_min, wts_max))
    for h in range(n_heads):
        r = h // cols
        c = h % cols
        ax = axs[r, c]
        ax.imshow(norm[0, h], aspect = 'auto', cmap = 'jet')
        # Fix labels
        s = list(targets[0].data)
        ax.set_xticks(range(seq_len))
        ax.set_xticklabels(s if r == rows-1 else [])
        ax.set_yticks(range(seq_len))
        ax.set_yticklabels(s if c == 0 else [])
    plt.show()
# Out:
# Decoder src-attention 1 (mean = 0.0920473, min = 0, max = 1.06875)
# Decoder src-attention 2 (mean = 0.090251, min = 0, max = 0.913575)
# Decoder src-attention 3 (mean = 0.0913245, min = 0, max = 0.899989)
