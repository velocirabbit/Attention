# %%
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from recurrent_attention import RecurrentAttention

# %% [markdown]
# ## Overhead stuff
#
# Helper functions for batching, resetting hidden states, etc.

# %%
# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 2
lr = 0.02
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 50
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
encode_size = 256
h_size = 256
loc_align_size = 256
loc_align_kernel = 5
decode_size = 256
decode_out_size = 512
n_enc_layers = 2
attn_rnn_layers = 1
n_dec_layers = 2
smooth_align = True
align_location = True
bidirectional_attn = False

# %%
# Starting from sequential data, `batchify` arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.
def batchify(data, batch_size):
    # Work out how cleanly we can divide the dataset into batches
    nbatches = data.size(0) // batch_size
    # Trim off any extra elements that wouldn't cleanly fit
    data = data.narrow(0, 0, nbatches * batch_size)
    # Evenly divide the data across the batches
    data = data.view(batch_size, -1).t().contiguous()
    return data

# Wraps hidden states into new Variables to detach them from their history
def repackage_hidden(h):
    if type(h) == Variable:
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)
    
# `get_batch` subdivides the source data into chunks of the specified length.
# E.g., using the example for the `batchify` function above and a length of 2,
# we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the `batchify` function. The chunks are along dimension 0, corresponding
# to the `seq_len` dimension in the LSTM.
def get_batch(source, i, seq_len, evaluate = False):
    seq_len = min(seq_len, len(source) - 1 - i)
    data = Variable(source[i : i+seq_len], volatile = evaluate)
    target = Variable(source[i+1 : i+1+seq_len].view(-1), volatile = evaluate)
    return data, target

# %% [markdown]
# Label smoothing class for regularization.

# %%
class LabelSmoothing(nn.Module):
    def __init__(self, size, padding_idx = None, smoothing = 0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss()
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = torch.zeros_like(x.data)
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist.add_(self.smoothing / self.size)
        if self.padding_idx is not None:
            true_dist[:, self.padding_idx] = 0
            mask = torch.nonzero(target.data == self.padding_idx)
            if mask.dim() > 0:
                true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad = False)) * ntokens

# %% [markdown]
# Learning rate scheduler that sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
def get_lr_scheduler(h_size, warmup, optimizer):
    lrate = lambda e: h_size**(-0.5) * min((e+1)**(-decay_factor), (e+1) * warmup**(-(decay_factor+1)))
    return optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lrate)

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Model class

# %%
class RNNModel(nn.Module):
    def __init__(self, src_vocab, tgt_vocab, embed_size, encode_size, h_size,
                 decode_size, decode_out_size, n_enc_layers, attn_rnn_layers,
                 n_dec_layers, align_location = False, loc_align_size = 1,
                 loc_align_kernel = 1, smooth_align = False, bidirectional_attn = False,
                 tie_wts = True, dropout = 0.1):
        super(RNNModel, self).__init__()
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.embed_size = embed_size
        self.encode_size = encode_size
        self.h_size = h_size
        self.decode_size = decode_size
        self.decode_out_size = decode_out_size
        self.n_enc_layers = n_enc_layers
        self.attn_rnn_layers = attn_rnn_layers
        self.n_dec_layers = n_dec_layers
        self.align_location = align_location
        self.loc_align_size = loc_align_size
        self.loc_align_kernel = loc_align_kernel
        self.smooth_align = smooth_align
        self.bidirectional_attn = bidirectional_attn
        self.tie_wts = tie_wts
        self.dropout = dropout
        
        self.drop = nn.Dropout(dropout)
        self.relu = nn.ReLU()
        
        self.embedding = nn.Embedding(src_vocab, embed_size)
        self.encoders = nn.ModuleList([
            nn.LSTM(
                input_size = embed_size if i == 0 else encode_size,
                hidden_size = encode_size, dropout = dropout
            ) for i in range(n_enc_layers)
        ])
        self.attn = RecurrentAttention(
            in_size = encode_size, h_size = h_size, out_size = decode_size,
            align_location = align_location, loc_align_size = loc_align_size,
            loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
            num_rnn_layers = attn_rnn_layers, attn_act_fn = 'ReLU',
            dropout = dropout, bidirectional = bidirectional_attn
        )
        self.decoders = nn.ModuleList([
            nn.LSTM(
                input_size = decode_size, dropout = dropout,
                hidden_size = decode_size if i < n_dec_layers-1 else decode_out_size,
            ) for i in range(n_dec_layers)
        ])
        self.projection = nn.Linear(decode_out_size, tgt_vocab)
        if tie_wts and src_vocab == tgt_vocab and embed_size == decode_out_size:
            self.embedding.weight = self.projection.weight
        self.log_softmax = nn.LogSoftmax(dim = -1)
            
        # For visualizations
        self.save_wts = False
        self.enc_out = None
        self.dec_out = None
        
    def init(self):
        for subnet in [self.encoders, self.decoders]:
            for layer in subnet:
                for p in layer.parameters():
                    if p.dim() > 1:
                        nn.init.xavier_normal(p)
                    else:
                        p.data.fill_(0)
        for p in self.projection.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform(p)
            else:
                p.data.fill_(0)
        self.attn.init()
        
    def init_states(self, batch_size):
        encoder_states = [
            (
                Variable(torch.zeros(1, batch_size, self.encode_size)),
                Variable(torch.zeros(1, batch_size, self.encode_size))
            ) for _ in range(self.n_enc_layers)
        ]
        attn_states = self.attn.init_rnn_states(batch_size)
        decoder_states = [
            (
                Variable(torch.zeros(
                    1, batch_size, self.decode_size if i < self.n_dec_layers-1 else self.decode_out_size
                )),
                Variable(torch.zeros(
                    1, batch_size, self.decode_size if i < self.n_dec_layers-1 else self.decode_out_size
                ))
            ) for i in range(self.n_dec_layers)
        ]
        return encoder_states, attn_states, decoder_states
    
    def forward(self, inputs, states):
        enc_states, attn_states, dec_states = states
        if self.save_wts:
            self.enc_out = []
            self.dec_out = []
        
        # Embedding layer
        embeddings = self.embedding(inputs) * np.sqrt(self.embed_size)
        
        # Encoder stack
        new_enc_states = []
        enc_in = self.drop(self.relu(embeddings))
        for states, encoder in zip(enc_states, self.encoders):
            enc_out, new_enc_state = encoder(enc_in, states)
            new_enc_states.append(new_enc_state)
            if self.save_wts:
                self.enc_out.append(enc_out.data.clone())
            enc_in = enc_out
                
        # Attention mechanism
        attn_out, new_attn_states = self.attn(enc_out, attn_states)

        # Decoder stack
        new_dec_states = []
        dec_in = attn_out
        for states, decoder in zip(dec_states, self.decoders):
            dec_out, new_dec_state = decoder(dec_in, states)
            new_dec_states.append(new_dec_state)
            if self.save_wts:
                self.dec_out.append(dec_out.data.clone())
            dec_in = dec_out
        
        # Projection layer
        logits = self.projection(dec_out)
        output = self.log_softmax(logits)
        
        return output, (new_enc_states, new_attn_states, new_dec_states)
    
    def train(self, mode = True, save_wts = False):
        super(RNNModel, self).train(mode)
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts
        
    def eval(self, save_wts = True):
        super(RNNModel, self).eval()
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    encode_size = encode_size, h_size = h_size, decode_size = decode_size,
    decode_out_size = decode_out_size, n_enc_layers = n_enc_layers,
    attn_rnn_layers = attn_rnn_layers, n_dec_layers = n_dec_layers,
    align_location = align_location, loc_align_size = loc_align_size,
    loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
    dropout = dropout
)
model.init()
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 9535761

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Define training and validation loops

# %%
def train():
    # Use random length sequences
    seq_lens = []
    tot_len = 0
    jitter = 0.15 * seq_len
    num_data = train_data.size(0)
    while tot_len < num_data - 2:
        if num_data - tot_len - 2 <= seq_len + jitter:
            slen = num_data - tot_len - 2
        else:
            slen = int(np.random.normal(seq_len, jitter))
            if slen <= 0:
                slen = seq_len    # eh
            if tot_len + slen >= num_data - jitter - 2:
                slen = num_data - tot_len - 2
        seq_lens.append(slen)
        tot_len += slen
    i_cumseq = [0] + list(np.cumsum(seq_lens)[:-1])
    idx = np.arange(len(seq_lens))
    np.random.shuffle(idx)
    # Turn on training mode
    model.train(save_wts = False)
    # Initialize RNN states
    states = model.init_states(batch_size)
    # Prep metainfo
    total_loss = 0
    total_epoch_loss = 0
    start_time = time.time()
    for batch, i in enumerate(idx):
        # Get training data
        data, targets = get_batch(train_data, i_cumseq[i], seq_lens[i])
        # Repackage the hidden states
        states = repackage_hidden(states)
        # Zero out gradients
        model.zero_grad()
        
        # Run the model forward
        output, _states = model(data, states)
        if np.isnan(output.data).any():
            return 0, total_epoch_loss[0], data, targets, states, _states
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        if np.isnan(loss.data[0]):
            return 1, total_epoch_loss[0], data, targets, states, _states
        states = _states
        # Propagate loss gradient backwards
        loss.backward()
        # Clip gradients
        if batch % log_interval == 0 and batch > 0:
            # Save gradient statistics before they're changed cuz we'll be logging this batch
            parameters = [p for p in model.parameters() if p.grad is not None]
            # Calculate the largest (absolute) gradient of all elements in the model parameters
            max_grad = max([p.grad.data.abs().max() for p in parameters])
        total_norm = nn.utils.clip_grad_norm(model.parameters(), clip)
        # Scale the batch learning rate so that shorter sequences aren't "stronger"
        scaled_lr = lr_scheduler.get_lr()[0] * np.sqrt(seq_lens[i] / seq_len)
        for param_group in optimizer.param_groups:
            param_group['lr'] = scaled_lr
        # Update parameters
        optimizer.step()
        
        # Get some metainfo
        total_loss += loss.data
        total_epoch_loss += loss.data * data.size(0)
        if batch % log_interval == 0 and batch > 0:
            elapsed = time.time() - start_time
            cur_loss = total_loss[0] / log_interval
            print(' b {:3d}/{:3d} >> {:6.1f} ms/b | lr: {:8.2g} | grad norm: {:4.2f} | max abs grad: {:7.3f} | loss: {:4.2f} | perp.: {:6.2f}'.format(
                batch, len(seq_lens), elapsed * 1000/log_interval, scaled_lr, total_norm, max_grad, cur_loss, np.exp(cur_loss)
            ))
            total_loss = 0
            start_time = time.time()
    return -1, total_epoch_loss[0] / num_data, None, None, None, None

# %%
def evaluate(data_src, save_wts = True):
    model.eval(save_wts = save_wts)
    total_loss = 0
    states = model.init_states(eval_batch_size)
    for i in range(0, data_src.size(0) - 1, seq_len):
        # Get data
        data, targets = get_batch(data_src, i, seq_len, evaluate = True)
        # Repackage the hidden states
        states = repackage_hidden(states)
        # Evaluate
        output, states = model(data, states)
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        total_loss += loss.data * data.size(0)
    return total_loss[0] / data_src.size(0)

# %% [markdown]
# Train and evaluate

# %%
WIDTH = 112
CAUSES = ['output', 'grad']
for epoch in range(epochs):
    lr_scheduler.step()
    print('Epoch {:3d}/{:3d}) lr = {:0.4g}{}'.format(epoch+1, epochs, np.mean(lr_scheduler.get_lr()[0]), ' (warmup)' if epoch < warmup_steps else ''))
    start_time = time.time()
    stat, train_loss, data, targets, states, nstates = train()
    if stat in list(range(len(CAUSES))):
        c = CAUSES[stat]
        n = (WIDTH - len(c) - 4) // 2
        print('\n' + (' '*n) + 'NaN ' + c)
        break
    elapsed = time.time() - start_time
    val_loss = evaluate(val_data, save_wts = False)
    max_param = max([p.data.abs().max() for p in model.parameters() if p.grad is not None])
    print('-' * WIDTH)
    print('Elapsed time: {:6.2f} sec | train_loss: {:5.2f} | train_perp: {:6.2f} | valid_loss: {:5.2f} | valid_perp.: {:6.2f}'.format(
        elapsed, train_loss, np.exp(train_loss), val_loss, np.exp(val_loss)
    ))
    print('=' * WIDTH)
    print('\n')
# Out:
# Epoch   1/ 50) lr = 2.795e-05 (warmup)
#  b 150/720 >> 3058.2 ms/b | lr:  2.9e-05 | grad norm: 1.81 | max abs grad:   0.045 | loss: 7.83 | perp.: 2517.16
#  b 300/720 >> 2841.9 ms/b | lr:  2.6e-05 | grad norm: 0.58 | max abs grad:   0.009 | loss: 6.29 | perp.: 541.35
#  b 450/720 >> 2755.7 ms/b | lr:  2.9e-05 | grad norm: 0.75 | max abs grad:   0.021 | loss: 6.18 | perp.: 481.70
#  b 600/720 >> 2873.0 ms/b | lr:  2.6e-05 | grad norm: 0.67 | max abs grad:   0.010 | loss: 6.17 | perp.: 477.08
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2061.61 sec | train_loss:  6.54 | train_perp: 691.69 | valid_loss:  6.13 | valid_perp.: 459.04
# ================================================================================================================
#
#
# Epoch   2/ 50) lr = 5.59e-05 (warmup)
#  b 150/713 >> 3042.1 ms/b | lr:    6e-05 | grad norm: 0.54 | max abs grad:   0.010 | loss: 6.21 | perp.: 495.51
#  b 300/713 >> 3398.9 ms/b | lr:  5.3e-05 | grad norm: 0.50 | max abs grad:   0.007 | loss: 6.17 | perp.: 476.82
#  b 450/713 >> 3060.8 ms/b | lr:  5.7e-05 | grad norm: 0.56 | max abs grad:   0.017 | loss: 6.18 | perp.: 480.77
#  b 600/713 >> 2991.7 ms/b | lr:  4.9e-05 | grad norm: 0.61 | max abs grad:   0.013 | loss: 6.17 | perp.: 476.94
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2206.14 sec | train_loss:  6.16 | train_perp: 474.56 | valid_loss:  6.10 | valid_perp.: 444.45
# ================================================================================================================
#
#
# Epoch   3/ 50) lr = 8.385e-05 (warmup)
#  b 150/722 >> 2987.8 ms/b | lr:  8.6e-05 | grad norm: 0.60 | max abs grad:   0.018 | loss: 6.15 | perp.: 466.43
#  b 300/722 >> 2818.3 ms/b | lr:  8.4e-05 | grad norm: 0.78 | max abs grad:   0.025 | loss: 6.08 | perp.: 438.14
#  b 450/722 >> 2929.2 ms/b | lr:  8.4e-05 | grad norm: 0.76 | max abs grad:   0.024 | loss: 6.07 | perp.: 431.26
#  b 600/722 >> 2810.8 ms/b | lr:  9.3e-05 | grad norm: 0.44 | max abs grad:   0.009 | loss: 6.05 | perp.: 422.71
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2067.08 sec | train_loss:  6.07 | train_perp: 431.95 | valid_loss:  5.98 | valid_perp.: 396.01
# ================================================================================================================
#
#
# Epoch   4/ 50) lr = 0.0001118 (warmup)
#  b 150/716 >> 2785.2 ms/b | lr:   0.0001 | grad norm: 0.57 | max abs grad:   0.022 | loss: 6.05 | perp.: 422.56
#  b 300/716 >> 2863.5 ms/b | lr:  0.00012 | grad norm: 0.50 | max abs grad:   0.013 | loss: 5.99 | perp.: 399.76
#  b 450/716 >> 2864.9 ms/b | lr:  0.00012 | grad norm: 0.39 | max abs grad:   0.008 | loss: 5.98 | perp.: 395.63
#  b 600/716 >> 2881.2 ms/b | lr:  0.00011 | grad norm: 0.62 | max abs grad:   0.014 | loss: 5.97 | perp.: 389.57
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2028.59 sec | train_loss:  5.98 | train_perp: 397.21 | valid_loss:  5.93 | valid_perp.: 376.38
# ================================================================================================================
#
#
# Epoch   5/ 50) lr = 0.0001398 (warmup)
#  b 150/719 >> 2759.7 ms/b | lr:  0.00014 | grad norm: 0.63 | max abs grad:   0.016 | loss: 6.00 | perp.: 401.81
#  b 300/719 >> 2820.5 ms/b | lr:   0.0001 | grad norm: 0.76 | max abs grad:   0.019 | loss: 5.93 | perp.: 374.99
#  b 450/719 >> 2795.6 ms/b | lr:  0.00015 | grad norm: 0.73 | max abs grad:   0.015 | loss: 5.92 | perp.: 371.39
#  b 600/719 >> 2740.1 ms/b | lr:  0.00015 | grad norm: 0.97 | max abs grad:   0.022 | loss: 5.89 | perp.: 360.25
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1998.82 sec | train_loss:  5.92 | train_perp: 371.22 | valid_loss:  5.84 | valid_perp.: 344.82
# ================================================================================================================
#
#
# Epoch   6/ 50) lr = 0.0001677 (warmup)
#  b 150/722 >> 2817.3 ms/b | lr:  0.00018 | grad norm: 0.78 | max abs grad:   0.016 | loss: 5.89 | perp.: 359.97
#  b 300/722 >> 2742.1 ms/b | lr:  0.00017 | grad norm: 0.61 | max abs grad:   0.011 | loss: 5.84 | perp.: 342.20
#  b 450/722 >> 2781.6 ms/b | lr:  0.00016 | grad norm: 0.66 | max abs grad:   0.014 | loss: 5.82 | perp.: 337.56
#  b 600/722 >> 2757.4 ms/b | lr:  0.00015 | grad norm: 0.92 | max abs grad:   0.023 | loss: 5.80 | perp.: 329.12
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1997.51 sec | train_loss:  5.82 | train_perp: 337.56 | valid_loss:  5.75 | valid_perp.: 313.27
# ================================================================================================================
#
#
# Epoch   7/ 50) lr = 0.0001957 (warmup)
#  b 150/716 >> 2789.8 ms/b | lr:  0.00019 | grad norm: 0.63 | max abs grad:   0.014 | loss: 5.80 | perp.: 329.12
#  b 300/716 >> 2806.1 ms/b | lr:  0.00017 | grad norm: 0.80 | max abs grad:   0.023 | loss: 5.75 | perp.: 314.51
#  b 450/716 >> 2763.3 ms/b | lr:  0.00017 | grad norm: 0.87 | max abs grad:   0.017 | loss: 5.72 | perp.: 306.36
#  b 600/716 >> 2821.5 ms/b | lr:  0.00021 | grad norm: 0.66 | max abs grad:   0.016 | loss: 5.73 | perp.: 306.89
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2001.88 sec | train_loss:  5.73 | train_perp: 309.49 | valid_loss:  5.69 | valid_perp.: 294.86
# ================================================================================================================
#
#
# Epoch   8/ 50) lr = 0.0002236 (warmup)
#  b 150/714 >> 2771.6 ms/b | lr:  0.00022 | grad norm: 0.76 | max abs grad:   0.021 | loss: 5.70 | perp.: 299.92
#  b 300/714 >> 2848.2 ms/b | lr:  0.00022 | grad norm: 0.68 | max abs grad:   0.015 | loss: 5.64 | perp.: 282.68
#  b 450/714 >> 2750.1 ms/b | lr:  0.00022 | grad norm: 0.78 | max abs grad:   0.016 | loss: 5.61 | perp.: 272.84
#  b 600/714 >> 2859.7 ms/b | lr:  0.00024 | grad norm: 0.99 | max abs grad:   0.023 | loss: 5.61 | perp.: 274.02
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1995.66 sec | train_loss:  5.63 | train_perp: 278.34 | valid_loss:  5.56 | valid_perp.: 260.18
# ================================================================================================================
#
#
# Epoch   9/ 50) lr = 0.0002516 (warmup)
#  b 150/717 >> 2961.0 ms/b | lr:  0.00025 | grad norm: 0.99 | max abs grad:   0.022 | loss: 5.58 | perp.: 265.11
#  b 300/717 >> 3038.9 ms/b | lr:  0.00026 | grad norm: 1.02 | max abs grad:   0.029 | loss: 5.52 | perp.: 250.31
#  b 450/717 >> 2854.1 ms/b | lr:  0.00025 | grad norm: 0.88 | max abs grad:   0.029 | loss: 5.49 | perp.: 242.67
#  b 600/717 >> 2736.7 ms/b | lr:  0.00028 | grad norm: 0.93 | max abs grad:   0.027 | loss: 5.46 | perp.: 233.93
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2063.04 sec | train_loss:  5.50 | train_perp: 245.61 | valid_loss:  5.42 | valid_perp.: 225.75
# ================================================================================================================
#
#
# Epoch  10/ 50) lr = 0.0002795 (warmup)
#  b 150/727 >> 2794.1 ms/b | lr:  0.00028 | grad norm: 1.03 | max abs grad:   0.032 | loss: 5.44 | perp.: 231.46
#  b 300/727 >> 2748.7 ms/b | lr:  0.00028 | grad norm: 1.08 | max abs grad:   0.045 | loss: 5.38 | perp.: 217.59
#  b 450/727 >> 2705.9 ms/b | lr:  0.00027 | grad norm: 1.07 | max abs grad:   0.034 | loss: 5.33 | perp.: 206.46
#  b 600/727 >> 2758.1 ms/b | lr:  0.00027 | grad norm: 1.15 | max abs grad:   0.029 | loss: 5.29 | perp.: 198.99
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1994.88 sec | train_loss:  5.34 | train_perp: 209.19 | valid_loss:  5.20 | valid_perp.: 180.88
# ================================================================================================================
#
#
# Epoch  11/ 50) lr = 0.0002665
#  b 150/716 >> 2902.6 ms/b | lr:  0.00024 | grad norm: 1.56 | max abs grad:   0.077 | loss: 5.23 | perp.: 186.41
#  b 300/716 >> 2897.5 ms/b | lr:  0.00027 | grad norm: 1.39 | max abs grad:   0.078 | loss: 5.16 | perp.: 173.78
#  b 450/716 >> 2747.5 ms/b | lr:  0.00027 | grad norm: 1.34 | max abs grad:   0.061 | loss: 5.11 | perp.: 165.65
#  b 600/716 >> 2835.5 ms/b | lr:  0.00024 | grad norm: 1.59 | max abs grad:   0.090 | loss: 5.08 | perp.: 160.89
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2029.73 sec | train_loss:  5.13 | train_perp: 169.50 | valid_loss:  4.92 | valid_perp.: 137.14
# ================================================================================================================
#
#
# Epoch  12/ 50) lr = 0.0002552
#  b 150/720 >> 2765.1 ms/b | lr:  0.00028 | grad norm: 3.41 | max abs grad:   0.245 | loss: 5.00 | perp.: 148.24
#  b 300/720 >> 2775.2 ms/b | lr:  0.00026 | grad norm: 1.56 | max abs grad:   0.037 | loss: 4.92 | perp.: 136.81
#  b 450/720 >> 2760.7 ms/b | lr:  0.00026 | grad norm: 2.09 | max abs grad:   0.084 | loss: 4.89 | perp.: 132.84
#  b 600/720 >> 2720.5 ms/b | lr:  0.00025 | grad norm: 1.86 | max abs grad:   0.107 | loss: 4.84 | perp.: 126.10
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1991.86 sec | train_loss:  4.91 | train_perp: 135.32 | valid_loss:  4.65 | valid_perp.: 104.80
# ================================================================================================================
#
#
# Epoch  13/ 50) lr = 0.0002451
#  b 150/719 >> 2783.4 ms/b | lr:  0.00025 | grad norm: 2.24 | max abs grad:   0.059 | loss: 4.80 | perp.: 120.95
#  b 300/719 >> 2746.8 ms/b | lr:  0.00019 | grad norm: 2.08 | max abs grad:   0.113 | loss: 4.71 | perp.: 111.02
#  b 450/719 >> 2767.5 ms/b | lr:  0.00025 | grad norm: 12.36 | max abs grad:   0.630 | loss: 4.73 | perp.: 113.60
#  b 600/719 >> 2826.9 ms/b | lr:  0.00022 | grad norm: 2.24 | max abs grad:   0.166 | loss: 4.70 | perp.: 109.47
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1993.36 sec | train_loss:  4.73 | train_perp: 112.88 | valid_loss:  4.43 | valid_perp.:  83.83
# ================================================================================================================
#
#
# Epoch  14/ 50) lr = 0.0002362
#  b 150/711 >> 2861.5 ms/b | lr:  0.00027 | grad norm: 5.08 | max abs grad:   0.206 | loss: 4.63 | perp.: 102.94
#  b 300/711 >> 2750.8 ms/b | lr:  0.00022 | grad norm: 2.95 | max abs grad:   0.172 | loss: 4.57 | perp.:  96.53
#  b 450/711 >> 2808.8 ms/b | lr:  0.00025 | grad norm: 12.96 | max abs grad:   0.494 | loss: 4.54 | perp.:  94.08
#  b 600/711 >> 2816.4 ms/b | lr:  0.00022 | grad norm: 3.31 | max abs grad:   0.212 | loss: 4.54 | perp.:  93.34
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1999.21 sec | train_loss:  4.58 | train_perp:  97.60 | valid_loss:  4.24 | valid_perp.:  69.51
# ================================================================================================================
#
#
# Epoch  15/ 50) lr = 0.0002282
#  b 150/719 >> 2812.0 ms/b | lr:  0.00022 | grad norm: 3.96 | max abs grad:   0.111 | loss: 4.47 | perp.:  87.72
#  b 300/719 >> 2708.2 ms/b | lr:  0.00024 | grad norm: 4.47 | max abs grad:   0.307 | loss: 4.39 | perp.:  80.38
#  b 450/719 >> 2778.8 ms/b | lr:   0.0002 | grad norm: 3.43 | max abs grad:   0.175 | loss: 4.34 | perp.:  76.81
#  b 600/719 >> 2784.8 ms/b | lr:  0.00022 | grad norm: 4.94 | max abs grad:   0.260 | loss: 4.31 | perp.:  74.78
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1996.17 sec | train_loss:  4.40 | train_perp:  81.39 | valid_loss:  4.21 | valid_perp.:  67.37
# ================================================================================================================
#
#
# Epoch  16/ 50) lr = 0.000221
#  b 150/718 >> 2840.7 ms/b | lr:  0.00021 | grad norm: 3.89 | max abs grad:   0.156 | loss: 4.34 | perp.:  76.88
#  b 300/718 >> 2786.7 ms/b | lr:  0.00022 | grad norm: 7.08 | max abs grad:   0.263 | loss: 4.28 | perp.:  72.21
#  b 450/718 >> 2763.7 ms/b | lr:  0.00023 | grad norm: 4.00 | max abs grad:   0.166 | loss: 4.21 | perp.:  67.50
#  b 600/718 >> 2770.5 ms/b | lr:  0.00022 | grad norm: 2.75 | max abs grad:   0.097 | loss: 4.23 | perp.:  68.86
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2000.18 sec | train_loss:  4.27 | train_perp:  71.58 | valid_loss:  3.91 | valid_perp.:  49.87
# ================================================================================================================
#
#
# Epoch  17/ 50) lr = 0.0002144
#  b 150/716 >> 2707.9 ms/b | lr:   0.0002 | grad norm: 25.78 | max abs grad:   1.043 | loss: 4.21 | perp.:  67.26
#  b 300/716 >> 2736.4 ms/b | lr:  0.00021 | grad norm: 5.68 | max abs grad:   0.331 | loss: 4.11 | perp.:  61.10
#  b 450/716 >> 2819.1 ms/b | lr:  0.00021 | grad norm: 4.44 | max abs grad:   0.170 | loss: 4.10 | perp.:  60.42
#  b 600/716 >> 2860.5 ms/b | lr:  0.00021 | grad norm: 27.69 | max abs grad:   0.765 | loss: 4.08 | perp.:  59.32
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2002.05 sec | train_loss:  4.14 | train_perp:  63.06 | valid_loss:  3.69 | valid_perp.:  39.95
# ================================================================================================================
#
#
# Epoch  18/ 50) lr = 0.0002083
#  b 150/721 >> 2751.3 ms/b | lr:  0.00023 | grad norm: 9.23 | max abs grad:   0.412 | loss: 4.06 | perp.:  58.20
#  b 300/721 >> 2787.9 ms/b | lr:  0.00023 | grad norm: 5.75 | max abs grad:   0.181 | loss: 3.98 | perp.:  53.77
#  b 450/721 >> 2738.8 ms/b | lr:  0.00021 | grad norm: 5.56 | max abs grad:   0.289 | loss: 3.96 | perp.:  52.21
#  b 600/721 >> 2872.5 ms/b | lr:   0.0002 | grad norm: 7.81 | max abs grad:   0.369 | loss: 3.98 | perp.:  53.62
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1997.42 sec | train_loss:  4.00 | train_perp:  54.57 | valid_loss:  3.70 | valid_perp.:  40.43
# ================================================================================================================
#
#
# Epoch  19/ 50) lr = 0.0002028
#  b 150/717 >> 2744.0 ms/b | lr:  0.00021 | grad norm: 8.23 | max abs grad:   0.429 | loss: 3.91 | perp.:  49.68
#  b 300/717 >> 2870.5 ms/b | lr:  0.00022 | grad norm: 21.41 | max abs grad:   0.685 | loss: 3.89 | perp.:  48.84
#  b 450/717 >> 2826.9 ms/b | lr:  0.00019 | grad norm: 62.05 | max abs grad:   2.217 | loss: 3.87 | perp.:  48.11
#  b 600/717 >> 2720.5 ms/b | lr:  0.00021 | grad norm: 8.30 | max abs grad:   0.267 | loss: 3.81 | perp.:  45.24
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1995.77 sec | train_loss:  3.88 | train_perp:  48.27 | valid_loss:  3.48 | valid_perp.:  32.56
# ================================================================================================================
#
#
# Epoch  20/ 50) lr = 0.0001976
#  b 150/712 >> 2787.0 ms/b | lr:  0.00019 | grad norm: 29.75 | max abs grad:   1.494 | loss: 3.77 | perp.:  43.50
#  b 300/712 >> 2788.3 ms/b | lr:   0.0002 | grad norm: 2.73 | max abs grad:   0.069 | loss: 3.74 | perp.:  42.18
#  b 450/712 >> 2789.6 ms/b | lr:   0.0002 | grad norm: 27.19 | max abs grad:   1.240 | loss: 3.71 | perp.:  40.95
#  b 600/712 >> 2858.2 ms/b | lr:  0.00018 | grad norm: 6.19 | max abs grad:   0.167 | loss: 3.77 | perp.:  43.33
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1995.93 sec | train_loss:  3.75 | train_perp:  42.40 | valid_loss:  3.32 | valid_perp.:  27.72
# ================================================================================================================
#
#
# Epoch  21/ 50) lr = 0.0001929
#  b 150/727 >> 2790.9 ms/b | lr:  0.00018 | grad norm: 9.15 | max abs grad:   0.300 | loss: 3.70 | perp.:  40.41
#  b 300/727 >> 2719.7 ms/b | lr:  0.00019 | grad norm: 10.39 | max abs grad:   0.974 | loss: 3.59 | perp.:  36.31
#  b 450/727 >> 2730.5 ms/b | lr:  0.00016 | grad norm: 3.93 | max abs grad:   0.184 | loss: 3.58 | perp.:  35.84
#  b 600/727 >> 2709.2 ms/b | lr:  0.00017 | grad norm: 4.14 | max abs grad:   0.123 | loss: 3.55 | perp.:  34.89
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2035.42 sec | train_loss:  3.63 | train_perp:  37.60 | valid_loss:  3.19 | valid_perp.:  24.37
# ================================================================================================================
#
#
# Epoch  22/ 50) lr = 0.0001884
#  b 150/717 >> 3106.7 ms/b | lr:  0.00019 | grad norm: 6.92 | max abs grad:   0.447 | loss: 3.65 | perp.:  38.29
#  b 300/717 >> 3286.6 ms/b | lr:   0.0002 | grad norm: 4.08 | max abs grad:   0.230 | loss: 3.52 | perp.:  33.74
#  b 450/717 >> 3090.2 ms/b | lr:  0.00017 | grad norm: 5.50 | max abs grad:   0.225 | loss: 3.50 | perp.:  33.20
#  b 600/717 >> 3053.1 ms/b | lr:  0.00019 | grad norm: 6.26 | max abs grad:   0.190 | loss: 3.50 | perp.:  33.27
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2235.59 sec | train_loss:  3.55 | train_perp:  34.92 | valid_loss:  3.41 | valid_perp.:  30.22
# ================================================================================================================
#
#
# Epoch  23/ 50) lr = 0.0001843
#  b 150/719 >> 3056.5 ms/b | lr:  0.00017 | grad norm: 6.72 | max abs grad:   0.243 | loss: 3.49 | perp.:  32.67
#  b 300/719 >> 2782.9 ms/b | lr:  0.00017 | grad norm: 14.33 | max abs grad:   0.498 | loss: 3.43 | perp.:  30.75
#  b 450/719 >> 2692.4 ms/b | lr:  0.00016 | grad norm: 5.99 | max abs grad:   0.152 | loss: 3.43 | perp.:  30.84
#  b 600/719 >> 2776.1 ms/b | lr:  0.00018 | grad norm: 22.55 | max abs grad:   0.942 | loss: 3.42 | perp.:  30.56
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2025.91 sec | train_loss:  3.44 | train_perp:  31.04 | valid_loss:  3.05 | valid_perp.:  21.17
# ================================================================================================================
#
#
# Epoch  24/ 50) lr = 0.0001804
#  b 150/723 >> 2714.1 ms/b | lr:  0.00018 | grad norm: 5.31 | max abs grad:   0.184 | loss: 3.39 | perp.:  29.57
#  b 300/723 >> 2790.6 ms/b | lr:  0.00017 | grad norm: 13.44 | max abs grad:   0.400 | loss: 3.34 | perp.:  28.24
#  b 450/723 >> 2794.2 ms/b | lr:  0.00017 | grad norm: 20.87 | max abs grad:   0.994 | loss: 3.36 | perp.:  28.78
#  b 600/723 >> 2702.6 ms/b | lr:  0.00018 | grad norm: 5.74 | max abs grad:   0.325 | loss: 3.37 | perp.:  28.96
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1990.11 sec | train_loss:  3.37 | train_perp:  28.96 | valid_loss:  2.94 | valid_perp.:  19.00
# ================================================================================================================
#
#
# Epoch  25/ 50) lr = 0.0001768
#  b 150/717 >> 2821.5 ms/b | lr:   0.0002 | grad norm: 24.44 | max abs grad:   1.563 | loss: 3.26 | perp.:  26.03
#  b 300/717 >> 3005.7 ms/b | lr:  0.00018 | grad norm: 13.55 | max abs grad:   0.859 | loss: 3.26 | perp.:  26.07
#  b 450/717 >> 3048.6 ms/b | lr:  0.00017 | grad norm: 4.77 | max abs grad:   0.198 | loss: 3.33 | perp.:  28.00
#  b 600/717 >> 3131.9 ms/b | lr:  0.00015 | grad norm: 8.22 | max abs grad:   0.411 | loss: 3.31 | perp.:  27.33
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2150.10 sec | train_loss:  3.28 | train_perp:  26.68 | valid_loss:  2.84 | valid_perp.:  17.04
# ================================================================================================================
#
#
# Epoch  26/ 50) lr = 0.0001733
#  b 150/714 >> 3132.0 ms/b | lr:  0.00012 | grad norm: 8.39 | max abs grad:   0.545 | loss: 3.24 | perp.:  25.65
#  b 300/714 >> 2789.9 ms/b | lr:  0.00015 | grad norm: 6.86 | max abs grad:   0.357 | loss: 3.16 | perp.:  23.64
#  b 450/714 >> 2806.7 ms/b | lr:  0.00017 | grad norm: 7.41 | max abs grad:   0.288 | loss: 3.17 | perp.:  23.73
#  b 600/714 >> 2832.5 ms/b | lr:  0.00019 | grad norm: 6.49 | max abs grad:   0.248 | loss: 3.19 | perp.:  24.40
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2087.85 sec | train_loss:  3.20 | train_perp:  24.50 | valid_loss:  2.78 | valid_perp.:  16.09
# ================================================================================================================
#
#
# Epoch  27/ 50) lr = 0.0001701
#  b 150/723 >> 2934.3 ms/b | lr:  0.00017 | grad norm: 5.92 | max abs grad:   0.339 | loss: 3.22 | perp.:  25.13
#  b 300/723 >> 2780.1 ms/b | lr:  0.00016 | grad norm: 4.79 | max abs grad:   0.113 | loss: 3.13 | perp.:  22.86
#  b 450/723 >> 2734.7 ms/b | lr:  0.00017 | grad norm: 3.31 | max abs grad:   0.078 | loss: 3.16 | perp.:  23.46
#  b 600/723 >> 3025.1 ms/b | lr:  0.00018 | grad norm: 5.65 | max abs grad:   0.182 | loss: 3.05 | perp.:  21.20
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2103.66 sec | train_loss:  3.15 | train_perp:  23.22 | valid_loss:  2.80 | valid_perp.:  16.45
# ================================================================================================================
#
#
# Epoch  28/ 50) lr = 0.000167
#  b 150/710 >> 3006.8 ms/b | lr:  0.00017 | grad norm: 3.09 | max abs grad:   0.089 | loss: 3.19 | perp.:  24.25
#  b 300/710 >> 2932.9 ms/b | lr:  0.00018 | grad norm: 88.53 | max abs grad:   4.277 | loss: 3.06 | perp.:  21.42
#  b 450/710 >> 2993.5 ms/b | lr:  0.00014 | grad norm: 4.04 | max abs grad:   0.243 | loss: 3.04 | perp.:  20.83
#  b 600/710 >> 2915.6 ms/b | lr:  0.00016 | grad norm: 6.56 | max abs grad:   0.152 | loss: 2.99 | perp.:  19.80
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2083.71 sec | train_loss:  3.07 | train_perp:  21.62 | valid_loss:  2.65 | valid_perp.:  14.21
# ================================================================================================================
#
#
# Epoch  29/ 50) lr = 0.0001641
#  b 150/713 >> 2804.8 ms/b | lr:  0.00017 | grad norm: 8.52 | max abs grad:   0.445 | loss: 3.01 | perp.:  20.35
#  b 300/713 >> 2817.2 ms/b | lr:  0.00019 | grad norm: 43.21 | max abs grad:   1.592 | loss: 3.04 | perp.:  20.82
#  b 450/713 >> 2929.6 ms/b | lr:  0.00016 | grad norm: 3.49 | max abs grad:   0.112 | loss: 2.99 | perp.:  19.91
#  b 600/713 >> 2947.9 ms/b | lr:  0.00017 | grad norm: 7.32 | max abs grad:   0.291 | loss: 3.04 | perp.:  20.80
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2049.96 sec | train_loss:  3.02 | train_perp:  20.41 | valid_loss:  2.62 | valid_perp.:  13.71
# ================================================================================================================
#
#
# Epoch  30/ 50) lr = 0.0001614
#  b 150/719 >> 2790.9 ms/b | lr:  0.00015 | grad norm: 4.15 | max abs grad:   0.191 | loss: 2.93 | perp.:  18.67
#  b 300/719 >> 2887.6 ms/b | lr:  0.00016 | grad norm: 2.94 | max abs grad:   0.108 | loss: 2.96 | perp.:  19.24
#  b 450/719 >> 3019.5 ms/b | lr:  0.00016 | grad norm: 5.03 | max abs grad:   0.217 | loss: 2.98 | perp.:  19.61
#  b 600/719 >> 2915.6 ms/b | lr:  0.00014 | grad norm: 16.02 | max abs grad:   0.988 | loss: 3.06 | perp.:  21.35
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2075.28 sec | train_loss:  2.97 | train_perp:  19.55 | valid_loss:  2.72 | valid_perp.:  15.20
# ================================================================================================================
#
#
# Epoch  31/ 50) lr = 0.0001588
#  b 150/715 >> 2871.8 ms/b | lr:  0.00018 | grad norm: 31.61 | max abs grad:   1.787 | loss: 2.96 | perp.:  19.38
#  b 300/715 >> 2763.7 ms/b | lr:  0.00015 | grad norm: 6.60 | max abs grad:   0.233 | loss: 2.84 | perp.:  17.08
#  b 450/715 >> 2808.6 ms/b | lr:  0.00015 | grad norm: 18.44 | max abs grad:   0.451 | loss: 2.92 | perp.:  18.49
#  b 600/715 >> 2751.0 ms/b | lr:  0.00014 | grad norm: 2.50 | max abs grad:   0.084 | loss: 2.84 | perp.:  17.05
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2014.92 sec | train_loss:  2.89 | train_perp:  18.05 | valid_loss:  2.54 | valid_perp.:  12.72
# ================================================================================================================
#
#
# Epoch  32/ 50) lr = 0.0001563
#  b 150/713 >> 2952.8 ms/b | lr:  0.00013 | grad norm: 9.88 | max abs grad:   0.520 | loss: 2.89 | perp.:  17.93
#  b 300/713 >> 2903.3 ms/b | lr:  0.00014 | grad norm: 5.25 | max abs grad:   0.290 | loss: 2.73 | perp.:  15.28
#  b 450/713 >> 3002.6 ms/b | lr:  0.00016 | grad norm: 3.53 | max abs grad:   0.096 | loss: 2.83 | perp.:  17.01
#  b 600/713 >> 2896.8 ms/b | lr:  0.00016 | grad norm: 9.97 | max abs grad:   0.353 | loss: 2.78 | perp.:  16.13
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2103.18 sec | train_loss:  2.81 | train_perp:  16.55 | valid_loss:  2.48 | valid_perp.:  11.95
# ================================================================================================================
#
#
# Epoch  33/ 50) lr = 0.0001539
#  b 150/717 >> 2900.6 ms/b | lr:  0.00015 | grad norm: 31.76 | max abs grad:   1.333 | loss: 2.76 | perp.:  15.75
#  b 300/717 >> 3195.8 ms/b | lr:  0.00014 | grad norm: 14.24 | max abs grad:   0.426 | loss: 2.84 | perp.:  17.15
#  b 450/717 >> 2931.7 ms/b | lr:  0.00015 | grad norm: 11.17 | max abs grad:   0.278 | loss: 2.69 | perp.:  14.79
#  b 600/717 >> 2826.8 ms/b | lr:  0.00015 | grad norm: 30.69 | max abs grad:   1.078 | loss: 2.74 | perp.:  15.43
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2111.01 sec | train_loss:  2.77 | train_perp:  15.92 | valid_loss:  2.45 | valid_perp.:  11.60
# ================================================================================================================
#
#
# Epoch  34/ 50) lr = 0.0001516
#  b 150/720 >> 2803.5 ms/b | lr:  0.00015 | grad norm: 11.14 | max abs grad:   0.531 | loss: 2.76 | perp.:  15.73
#  b 300/720 >> 2828.0 ms/b | lr:  0.00016 | grad norm: 9.03 | max abs grad:   0.345 | loss: 2.75 | perp.:  15.66
#  b 450/720 >> 2686.9 ms/b | lr:  0.00014 | grad norm: 49.59 | max abs grad:   1.478 | loss: 2.66 | perp.:  14.30
#  b 600/720 >> 2823.7 ms/b | lr:  0.00013 | grad norm: 2.98 | max abs grad:   0.102 | loss: 2.67 | perp.:  14.40
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2003.07 sec | train_loss:  2.71 | train_perp:  15.04 | valid_loss:  2.39 | valid_perp.:  10.90
# ================================================================================================================
#
#
# Epoch  35/ 50) lr = 0.0001494
#  b 150/715 >> 2869.0 ms/b | lr:  0.00016 | grad norm: 4.70 | max abs grad:   0.097 | loss: 2.69 | perp.:  14.79
#  b 300/715 >> 2840.0 ms/b | lr:  0.00015 | grad norm: 5.72 | max abs grad:   0.285 | loss: 2.64 | perp.:  13.96
#  b 450/715 >> 2722.0 ms/b | lr:  0.00015 | grad norm: 8.24 | max abs grad:   0.319 | loss: 2.66 | perp.:  14.30
#  b 600/715 >> 2818.8 ms/b | lr:  0.00015 | grad norm: 4.65 | max abs grad:   0.110 | loss: 2.68 | perp.:  14.58
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2002.68 sec | train_loss:  2.66 | train_perp:  14.25 | valid_loss:  2.32 | valid_perp.:  10.18
# ================================================================================================================
#
#
# Epoch  36/ 50) lr = 0.0001473
#  b 150/713 >> 2765.9 ms/b | lr:  0.00015 | grad norm: 5.17 | max abs grad:   0.120 | loss: 2.65 | perp.:  14.12
#  b 300/713 >> 2837.6 ms/b | lr:  0.00015 | grad norm: 9.34 | max abs grad:   0.265 | loss: 2.59 | perp.:  13.33
#  b 450/713 >> 2799.0 ms/b | lr:  0.00017 | grad norm: 6.09 | max abs grad:   0.537 | loss: 2.66 | perp.:  14.29
#  b 600/713 >> 2832.2 ms/b | lr:  0.00014 | grad norm: 46.77 | max abs grad:   2.017 | loss: 2.78 | perp.:  16.15
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1999.14 sec | train_loss:  2.66 | train_perp:  14.31 | valid_loss:  2.31 | valid_perp.:  10.06
# ================================================================================================================
#
#
# Epoch  37/ 50) lr = 0.0001453
#  b 150/722 >> 2754.7 ms/b | lr:  0.00014 | grad norm: 4.55 | max abs grad:   0.125 | loss: 2.63 | perp.:  13.92
#  b 300/722 >> 2771.4 ms/b | lr:  0.00012 | grad norm: 7.79 | max abs grad:   0.420 | loss: 2.59 | perp.:  13.36
#  b 450/722 >> 2785.7 ms/b | lr:  0.00015 | grad norm: 8.49 | max abs grad:   0.356 | loss: 2.56 | perp.:  12.98
#  b 600/722 >> 2749.4 ms/b | lr:  0.00014 | grad norm: 4.06 | max abs grad:   0.150 | loss: 2.62 | perp.:  13.80
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1999.63 sec | train_loss:  2.60 | train_perp:  13.43 | valid_loss:  2.34 | valid_perp.:  10.38
# ================================================================================================================
#
#
# Epoch  38/ 50) lr = 0.0001434
#  b 150/718 >> 2784.7 ms/b | lr:  0.00014 | grad norm: 3.27 | max abs grad:   0.121 | loss: 2.65 | perp.:  14.19
#  b 300/718 >> 2766.2 ms/b | lr:  0.00012 | grad norm: 6.30 | max abs grad:   0.364 | loss: 2.50 | perp.:  12.23
#  b 450/718 >> 2849.4 ms/b | lr:  0.00014 | grad norm: 12.42 | max abs grad:   0.442 | loss: 2.55 | perp.:  12.85
#  b 600/718 >> 2822.7 ms/b | lr:  0.00014 | grad norm: 104.85 | max abs grad:   3.814 | loss: 2.55 | perp.:  12.75
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1998.29 sec | train_loss:  2.55 | train_perp:  12.85 | valid_loss:  2.39 | valid_perp.:  10.92
# ================================================================================================================
#
#
# Epoch  39/ 50) lr = 0.0001415
#  b 150/714 >> 2827.5 ms/b | lr:  0.00013 | grad norm: 3.91 | max abs grad:   0.115 | loss: 2.61 | perp.:  13.54
#  b 300/714 >> 2799.5 ms/b | lr:  0.00015 | grad norm: 14.94 | max abs grad:   0.509 | loss: 2.45 | perp.:  11.61
#  b 450/714 >> 2741.8 ms/b | lr:  0.00016 | grad norm: 33.47 | max abs grad:   1.487 | loss: 2.52 | perp.:  12.38
#  b 600/714 >> 2890.4 ms/b | lr:  0.00015 | grad norm: 3.63 | max abs grad:   0.096 | loss: 2.57 | perp.:  13.02
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2006.86 sec | train_loss:  2.54 | train_perp:  12.63 | valid_loss:  2.19 | valid_perp.:   8.96
# ================================================================================================================
#
#
# Epoch  40/ 50) lr = 0.0001398
#  b 150/711 >> 2790.1 ms/b | lr:  0.00012 | grad norm: 14.58 | max abs grad:   1.115 | loss: 2.68 | perp.:  14.61
#  b 300/711 >> 2747.2 ms/b | lr:  0.00015 | grad norm: 6.38 | max abs grad:   0.206 | loss: 2.59 | perp.:  13.35
#  b 450/711 >> 2908.3 ms/b | lr:  0.00014 | grad norm: 2.57 | max abs grad:   0.070 | loss: 2.51 | perp.:  12.28
#  b 600/711 >> 2820.4 ms/b | lr:  0.00014 | grad norm: 6.35 | max abs grad:   0.210 | loss: 2.48 | perp.:  11.93
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2001.73 sec | train_loss:  2.56 | train_perp:  12.96 | valid_loss:  2.17 | valid_perp.:   8.77
# ================================================================================================================
#
#
# Epoch  41/ 50) lr = 0.000138
#  b 150/715 >> 2871.9 ms/b | lr:  0.00014 | grad norm: 4.62 | max abs grad:   0.155 | loss: 2.46 | perp.:  11.72
#  b 300/715 >> 2835.3 ms/b | lr:  0.00015 | grad norm: 54.38 | max abs grad:   3.941 | loss: 2.36 | perp.:  10.60
#  b 450/715 >> 2752.2 ms/b | lr:  0.00014 | grad norm: 39.70 | max abs grad:   1.468 | loss: 2.42 | perp.:  11.24
#  b 600/715 >> 2745.0 ms/b | lr:  0.00013 | grad norm: 5.58 | max abs grad:   0.309 | loss: 2.38 | perp.:  10.78
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2001.54 sec | train_loss:  2.40 | train_perp:  11.06 | valid_loss:  2.13 | valid_perp.:   8.41
# ================================================================================================================
#
#
# Epoch  42/ 50) lr = 0.0001364
#  b 150/721 >> 2821.3 ms/b | lr:  0.00012 | grad norm: 4.38 | max abs grad:   0.214 | loss: 2.46 | perp.:  11.73
#  b 300/721 >> 2764.9 ms/b | lr:  0.00015 | grad norm: 27.89 | max abs grad:   1.371 | loss: 2.48 | perp.:  11.94
#  b 450/721 >> 2731.2 ms/b | lr:  0.00013 | grad norm: 9.77 | max abs grad:   0.219 | loss: 2.38 | perp.:  10.82
#  b 600/721 >> 2936.9 ms/b | lr:  0.00013 | grad norm: 3.19 | max abs grad:   0.128 | loss: 2.39 | perp.:  10.92
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2027.21 sec | train_loss:  2.41 | train_perp:  11.19 | valid_loss:  2.11 | valid_perp.:   8.27
# ================================================================================================================
#
#
# Epoch  43/ 50) lr = 0.0001348
#  b 150/717 >> 3010.4 ms/b | lr:  0.00013 | grad norm: 4.86 | max abs grad:   0.232 | loss: 2.42 | perp.:  11.26
#  b 300/717 >> 2864.6 ms/b | lr:  0.00015 | grad norm: 13.32 | max abs grad:   0.523 | loss: 2.43 | perp.:  11.32
#  b 450/717 >> 2855.7 ms/b | lr:  0.00014 | grad norm: 10.66 | max abs grad:   0.504 | loss: 2.31 | perp.:  10.05
#  b 600/717 >> 2754.2 ms/b | lr:  0.00013 | grad norm: 10.38 | max abs grad:   0.364 | loss: 2.40 | perp.:  11.02
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2042.81 sec | train_loss:  2.39 | train_perp:  10.96 | valid_loss:  2.08 | valid_perp.:   7.98
# ================================================================================================================
#
#
# Epoch  44/ 50) lr = 0.0001333
#  b 150/720 >> 2778.6 ms/b | lr:  0.00014 | grad norm: 7.05 | max abs grad:   0.291 | loss: 2.41 | perp.:  11.15
#  b 300/720 >> 2747.9 ms/b | lr:  0.00013 | grad norm: 347.56 | max abs grad:  26.361 | loss: 2.35 | perp.:  10.52
#  b 450/720 >> 2848.0 ms/b | lr:  0.00012 | grad norm: 88.74 | max abs grad:   2.371 | loss: 2.25 | perp.:   9.49
#  b 600/720 >> 2901.3 ms/b | lr:  0.00014 | grad norm: 4.24 | max abs grad:   0.146 | loss: 2.25 | perp.:   9.53
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2022.50 sec | train_loss:  2.31 | train_perp:  10.12 | valid_loss:  2.04 | valid_perp.:   7.71
# ================================================================================================================
#
#
# Epoch  45/ 50) lr = 0.0001318
#  b 150/716 >> 2869.0 ms/b | lr:  0.00011 | grad norm: 5.89 | max abs grad:   0.312 | loss: 2.37 | perp.:  10.75
#  b 300/716 >> 2892.3 ms/b | lr:  0.00014 | grad norm: 4.12 | max abs grad:   0.107 | loss: 2.26 | perp.:   9.63
#  b 450/716 >> 2756.0 ms/b | lr:  0.00014 | grad norm: 34.13 | max abs grad:   1.814 | loss: 2.25 | perp.:   9.47
#  b 600/716 >> 2747.0 ms/b | lr:  0.00013 | grad norm: 4.11 | max abs grad:   0.179 | loss: 2.22 | perp.:   9.22
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2012.99 sec | train_loss:  2.26 | train_perp:   9.61 | valid_loss:  2.05 | valid_perp.:   7.76
# ================================================================================================================
#
#
# Epoch  46/ 50) lr = 0.0001303
#  b 150/721 >> 2696.9 ms/b | lr:  0.00014 | grad norm: 30.31 | max abs grad:   1.180 | loss: 2.38 | perp.:  10.76
#  b 300/721 >> 2787.2 ms/b | lr:  0.00014 | grad norm: 3.23 | max abs grad:   0.135 | loss: 2.27 | perp.:   9.72
#  b 450/721 >> 2746.0 ms/b | lr:  0.00011 | grad norm: 15.31 | max abs grad:   0.401 | loss: 2.17 | perp.:   8.79
#  b 600/721 >> 2810.6 ms/b | lr:  0.00013 | grad norm: 3.98 | max abs grad:   0.222 | loss: 2.31 | perp.:  10.09
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1989.23 sec | train_loss:  2.29 | train_perp:   9.86 | valid_loss:  2.30 | valid_perp.:   9.98
# ================================================================================================================
#
#
# Epoch  47/ 50) lr = 0.0001289
#  b 150/722 >> 2713.3 ms/b | lr:  0.00014 | grad norm: 6.86 | max abs grad:   0.254 | loss: 2.34 | perp.:  10.42
#  b 300/722 >> 2751.2 ms/b | lr:  0.00013 | grad norm: 189.13 | max abs grad:  10.789 | loss: 2.19 | perp.:   8.96
#  b 450/722 >> 2718.3 ms/b | lr:  0.00014 | grad norm: 2.42 | max abs grad:   0.065 | loss: 2.14 | perp.:   8.51
#  b 600/722 >> 2789.6 ms/b | lr:  0.00011 | grad norm: 9.57 | max abs grad:   0.871 | loss: 2.20 | perp.:   8.99
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1990.51 sec | train_loss:  2.21 | train_perp:   9.13 | valid_loss:  1.96 | valid_perp.:   7.06
# ================================================================================================================
#
#
# Epoch  48/ 50) lr = 0.0001276
#  b 150/719 >> 2772.6 ms/b | lr:  0.00013 | grad norm: 50.71 | max abs grad:   2.813 | loss: 2.20 | perp.:   9.07
#  b 300/719 >> 2784.9 ms/b | lr:  0.00012 | grad norm: 8.36 | max abs grad:   0.311 | loss: 2.13 | perp.:   8.37
#  b 450/719 >> 2750.4 ms/b | lr:  0.00013 | grad norm: 9.44 | max abs grad:   0.300 | loss: 2.12 | perp.:   8.32
#  b 600/719 >> 2875.6 ms/b | lr:  0.00013 | grad norm: 7.68 | max abs grad:   0.381 | loss: 2.15 | perp.:   8.60
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1973.40 sec | train_loss:  2.16 | train_perp:   8.70 | valid_loss:  1.96 | valid_perp.:   7.06
# ================================================================================================================
#
#
# Epoch  49/ 50) lr = 0.0001263
#  b 150/720 >> 2582.4 ms/b | lr:  0.00012 | grad norm: 3.25 | max abs grad:   0.138 | loss: 2.30 | perp.:   9.95
#  b 300/720 >> 2467.7 ms/b | lr:  0.00011 | grad norm: 61.00 | max abs grad:   1.918 | loss: 2.18 | perp.:   8.83
#  b 450/720 >> 2506.4 ms/b | lr:  0.00013 | grad norm: 2.32 | max abs grad:   0.075 | loss: 2.18 | perp.:   8.81
#  b 600/720 >> 2592.8 ms/b | lr:  0.00014 | grad norm: 5.65 | max abs grad:   0.257 | loss: 2.13 | perp.:   8.44
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1854.88 sec | train_loss:  2.19 | train_perp:   8.90 | valid_loss:  1.92 | valid_perp.:   6.82
# ================================================================================================================
#
#
# Epoch  50/ 50) lr = 0.000125
#  b 150/720 >> 2888.7 ms/b | lr:  0.00013 | grad norm: 7.32 | max abs grad:   0.274 | loss: 2.16 | perp.:   8.70
#  b 300/720 >> 2835.4 ms/b | lr:  0.00013 | grad norm: 3.00 | max abs grad:   0.105 | loss: 2.12 | perp.:   8.37
#  b 450/720 >> 2886.0 ms/b | lr:  0.00013 | grad norm: 12.74 | max abs grad:   0.498 | loss: 2.13 | perp.:   8.43
#  b 600/720 >> 2963.7 ms/b | lr:  0.00013 | grad norm: 4.32 | max abs grad:   0.170 | loss: 2.12 | perp.:   8.30
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2091.88 sec | train_loss:  2.17 | train_perp:   8.78 | valid_loss:  1.94 | valid_perp.:   6.94
# ================================================================================================================

# %%
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    enc_states, attn_states, dec_states = states
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])

# %%
test_loss = evaluate(test_data, save_wts = True)
print('test_loss: {:5.2f} | test_perplexity: {:5.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss:  1.85 | test_perplexity:  6.38

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#   935   935    64    42  1890  3257   674    24   804   804   289   252   230
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#  1038   119  4561    64  1890
# [torch.LongTensor of size 2x18]
#
# 13 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#    27    27    64    64    64   133    27    27    27    27   549    24  1041
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#    24  5941  2300    40    64
# [torch.LongTensor of size 2x18]
#
# 15 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   119   119    32    32    32  1847  1847   734   734    35  3509  2680  2680
#
# Columns 13 to 17
#    26  5463   119    26    26
#  3885   119    26    32    32
# [torch.LongTensor of size 2x18]
#
# 15 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#   553    99   311   311   311   312    42  4467    26    99   227   448    35
#
# Columns 13 to 17
#    35    27    27  1479   108
#    27    27  1479    35   311
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
# List of modules in the model for reference:

# %%
modules = list(model.modules())
list(enumerate(modules))
# Out:
# [(0, RNNModel(
#     (drop): Dropout(p=0.1)
#     (relu): ReLU()
#     (embedding): Embedding(10000, 512)
#     (encoders): ModuleList(
#       (0): LSTM(512, 256, dropout=0.1)
#       (1): LSTM(256, 256, dropout=0.1)
#     )
#     (attn): RecurrentAttention(
#       (drop): Dropout(p=0.1)
#       (softmax): Softmax()
#       (sigmoid): Sigmoid()
#       (rnn_stack): ModuleList(
#         (0): LSTMCell(512, 256)
#       )
#       (loc_align): Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#       (alignment): Linear(in_features=768, out_features=1)
#       (attention): Linear(in_features=768, out_features=256)
#       (attn_act_fn): ReLU()
#     )
#     (decoders): ModuleList(
#       (0): LSTM(256, 256, dropout=0.1)
#       (1): LSTM(256, 512, dropout=0.1)
#     )
#     (projection): Linear(in_features=512, out_features=10000)
#     (log_softmax): LogSoftmax()
#   )),
#  (1, Dropout(p=0.1)),
#  (2, ReLU()),
#  (3, Embedding(10000, 512)),
#  (4, ModuleList(
#     (0): LSTM(512, 256, dropout=0.1)
#     (1): LSTM(256, 256, dropout=0.1)
#   )),
#  (5, LSTM(512, 256, dropout=0.1)),
#  (6, LSTM(256, 256, dropout=0.1)),
#  (7, RecurrentAttention(
#     (drop): Dropout(p=0.1)
#     (softmax): Softmax()
#     (sigmoid): Sigmoid()
#     (rnn_stack): ModuleList(
#       (0): LSTMCell(512, 256)
#     )
#     (loc_align): Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (alignment): Linear(in_features=768, out_features=1)
#     (attention): Linear(in_features=768, out_features=256)
#     (attn_act_fn): ReLU()
#   )),
#  (8, Dropout(p=0.1)),
#  (9, Softmax()),
#  (10, Sigmoid()),
#  (11, ModuleList(
#     (0): LSTMCell(512, 256)
#   )),
#  (12, LSTMCell(512, 256)),
#  (13, Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))),
#  (14, Linear(in_features=768, out_features=1)),
#  (15, Linear(in_features=768, out_features=256)),
#  (16, ReLU()),
#  (17, ModuleList(
#     (0): LSTM(256, 256, dropout=0.1)
#     (1): LSTM(256, 512, dropout=0.1)
#   )),
#  (18, LSTM(256, 256, dropout=0.1)),
#  (19, LSTM(256, 512, dropout=0.1)),
#  (20, Linear(in_features=512, out_features=10000)),
#  (21, LogSoftmax())]

# %% [markdown]
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(modules[3].weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = modules[7]

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Output attention sublayer (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 768)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# The addition of the convolutional location alignment certainly seems to cause the attention mechanism to attend to the input sequence in a pretty linear fashion (i.e. it mostly looks at the previous input to get the next output), but actual model performance is very low. Oddly, the focal point of the sequence when predicting the last few items in the sequence wraps back to near the start of the input sequence (but NOT the actual start! For whatever reason, the attention mechanism never focuses on the first few items of the input sequence!)
#
# Actually, when predicting the first couple items, the attention mechanism is looking at every item in the input sequence equally, so it seems like it's considering the first couple of items in its output sequence to require attention of the entire input sequence, but after that, the first couple items of the input sequence aren't of much use ever again. Odd! Does the implementation of the encoder and decoder have anything to do with that (namely that there are 2 LSTMs in each)? Would skip/highway connections be beneficial here?
