# %%
import os
import pickle
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from model import *
from trainer import *

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Hyperparameters

# %%
model_test_name = 'no_encoder_decoder_with_localign'

# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 4
lr = 0.02
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 150
early_stopping = 10
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
h_size = 256
align_size = 256
loc_align_size = 256
loc_align_kernel = 5
decode_size = 256
n_enc_layers = 0
attn_rnn_layers = 1
n_dec_layers = 0
smooth_align = True
align_location = True
skip_connections = False

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler
#
# The learning rate scheduler sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    h_size = h_size, align_size = align_size, decode_size = decode_size,
    n_enc_layers = n_enc_layers, attn_rnn_layers = attn_rnn_layers,
    n_dec_layers = n_dec_layers, align_location = align_location,
    loc_align_size = loc_align_size, loc_align_kernel = loc_align_kernel,
    smooth_align = smooth_align, skip_connections = skip_connections,
    dropout = dropout
)
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
eval_criterion = LabelSmoothing(ntokens, smoothing = 0)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, decay_factor, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 9257217

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Train and evaluate

# %%
train_stats, stat, train_loss, data, targets, states, nstates = train_eval_loop(
    model, train_data, val_data, batch_size, eval_batch_size,
    seq_len, ntokens, criterion, eval_criterion, optimizer,
    lr_scheduler, epochs, warmup_steps, early_stopping,
    clip, log_interval
)
# Out:
# Epoch   1/150) lr = 2.795e-05 (warmup)
#  b 150/717 >> 2456.3 ms/b | lr: 3.019e-05 | grad norm:  2.82 | inf norm:  0.227 | loss: 7.59 | perp: 1978.54
#  b 300/717 >> 2369.9 ms/b | lr: 2.795e-05 | grad norm:  2.54 | inf norm:  0.154 | loss: 6.26 | perp: 521.89
#  b 450/717 >> 2310.1 ms/b | lr: 2.635e-05 | grad norm:  2.47 | inf norm:  0.146 | loss: 6.06 | perp: 428.46
#  b 600/717 >> 2368.0 ms/b | lr: 2.795e-05 | grad norm:  2.06 | inf norm:  0.131 | loss: 5.94 | perp: 378.87
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1687.76 sec | train loss, perp: 6.351, 573.18    | valid loss, perp: 6.142, 464.80
# Grad norm:  1.845 | Grad inf. norm: 0.08785 | Max abs param:   5.016
# ============================================================================================================
#
#
# Epoch   2/150) lr = 5.59e-05 (warmup)
#  b 150/718 >> 2415.6 ms/b | lr: 5.433e-05 | grad norm:  1.93 | inf norm:  0.102 | loss: 5.75 | perp: 314.72
#  b 300/718 >> 2332.2 ms/b | lr:  6.18e-05 | grad norm:  1.83 | inf norm: 0.0939 | loss: 5.61 | perp: 272.94
#  b 450/718 >> 2309.2 ms/b | lr:  5.27e-05 | grad norm:  2.00 | inf norm: 0.0871 | loss: 5.50 | perp: 243.76
#  b 600/718 >> 2362.1 ms/b | lr:  5.27e-05 | grad norm:  1.95 | inf norm: 0.0978 | loss: 5.42 | perp: 225.70
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1666.38 sec | train loss, perp: 5.529, 251.87    | valid loss, perp: 5.630, 278.70
# Grad norm:  2.104 | Grad inf. norm:  0.0955 | Max abs param:   5.013
# ============================================================================================================
#
#
# Epoch   3/150) lr = 8.385e-05 (warmup)
#  b 150/716 >> 2378.0 ms/b | lr: 8.839e-05 | grad norm:  1.65 | inf norm: 0.0971 | loss: 5.24 | perp: 189.08
#  b 300/716 >> 2328.0 ms/b | lr: 9.057e-05 | grad norm:  1.77 | inf norm:  0.139 | loss: 5.11 | perp: 165.04
#  b 450/716 >> 2360.8 ms/b | lr: 7.655e-05 | grad norm:  2.29 | inf norm: 0.0966 | loss: 5.03 | perp: 152.54
#  b 600/716 >> 2356.0 ms/b | lr: 8.839e-05 | grad norm:  1.88 | inf norm:  0.133 | loss: 4.94 | perp: 139.76
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1677.36 sec | train loss, perp: 5.052, 156.34    | valid loss, perp: 5.185, 178.56
# Grad norm:  4.216 | Grad inf. norm:   0.257 | Max abs param:   5.014
# ============================================================================================================
#
#
# Epoch   4/150) lr = 0.0001118 (warmup)
#  b 150/719 >> 2340.0 ms/b | lr: 0.0001149 | grad norm:  2.04 | inf norm:  0.136 | loss: 4.76 | perp: 116.56
#  b 300/719 >> 2296.2 ms/b | lr: 0.0001149 | grad norm:  2.13 | inf norm:  0.105 | loss: 4.64 | perp: 103.87
#  b 450/719 >> 2393.3 ms/b | lr: 0.0001087 | grad norm:  2.38 | inf norm:  0.162 | loss: 4.60 | perp:  99.29
#  b 600/719 >> 2361.1 ms/b | lr: 0.0001021 | grad norm:  2.92 | inf norm:  0.203 | loss: 4.52 | perp:  92.04
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1673.38 sec | train loss, perp: 4.614, 100.85    | valid loss, perp: 4.823, 124.29
# Grad norm:  2.652 | Grad inf. norm:   0.194 | Max abs param:   5.016
# ============================================================================================================
#
#
# Epoch   5/150) lr = 0.0001398 (warmup)
#  b 150/710 >> 2359.5 ms/b | lr: 0.0001398 | grad norm:  2.94 | inf norm:  0.258 | loss: 4.36 | perp:  78.50
#  b 300/710 >> 2364.4 ms/b | lr: 0.0001473 | grad norm:  2.13 | inf norm:  0.112 | loss: 4.31 | perp:  74.42
#  b 450/710 >> 2380.6 ms/b | lr: 0.0001398 | grad norm:  2.72 | inf norm:   0.22 | loss: 4.26 | perp:  70.99
#  b 600/710 >> 2425.0 ms/b | lr: 0.0001358 | grad norm:  2.55 | inf norm:   0.13 | loss: 4.25 | perp:  70.28
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1680.65 sec | train loss, perp: 4.294,  73.25    | valid loss, perp: 4.587,  98.23
# Grad norm:  2.324 | Grad inf. norm:  0.1351 | Max abs param:   5.016
# ============================================================================================================
#
#
# Epoch   6/150) lr = 0.0001677 (warmup)
#  b 150/718 >> 2341.0 ms/b | lr: 0.0001581 | grad norm:  3.07 | inf norm:  0.277 | loss: 4.12 | perp:  61.44
#  b 300/718 >> 2287.9 ms/b | lr: 0.0001531 | grad norm:  3.07 | inf norm:  0.173 | loss: 4.08 | perp:  59.17
#  b 450/718 >> 2382.6 ms/b | lr: 0.0001723 | grad norm:  2.34 | inf norm:  0.088 | loss: 4.07 | perp:  58.59
#  b 600/718 >> 2323.1 ms/b | lr:  0.000163 | grad norm:  3.01 | inf norm:  0.207 | loss: 4.05 | perp:  57.60
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1674.62 sec | train loss, perp: 4.089,  59.68    | valid loss, perp: 4.457,  86.22
# Grad norm:  3.031 | Grad inf. norm:  0.1708 | Max abs param:   5.021
# ============================================================================================================
#
#
# Epoch   7/150) lr = 0.0001957 (warmup)
#  b 150/718 >> 2328.4 ms/b | lr: 0.0001957 | grad norm:  2.52 | inf norm:  0.129 | loss: 3.98 | perp:  53.42
#  b 300/718 >> 2285.0 ms/b | lr:  0.000201 | grad norm:  2.22 | inf norm:  0.108 | loss: 3.93 | perp:  50.72
#  b 450/718 >> 2361.4 ms/b | lr: 0.0002163 | grad norm:  2.09 | inf norm:  0.104 | loss: 3.95 | perp:  51.94
#  b 600/718 >> 2317.6 ms/b | lr: 0.0001786 | grad norm:  3.19 | inf norm:  0.227 | loss: 3.95 | perp:  51.97
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1672.38 sec | train loss, perp: 3.965,  52.74    | valid loss, perp: 4.380,  79.81
# Grad norm:  2.351 | Grad inf. norm:  0.1341 | Max abs param:   5.029
# ============================================================================================================
#
#
# Epoch   8/150) lr = 0.0002236 (warmup)
#  b 150/717 >> 2352.8 ms/b | lr: 0.0002528 | grad norm:  2.58 | inf norm:  0.173 | loss: 3.88 | perp:  48.31
#  b 300/717 >> 2287.2 ms/b | lr:   0.00019 | grad norm:  3.87 | inf norm:  0.274 | loss: 3.86 | perp:  47.59
#  b 450/717 >> 2302.5 ms/b | lr: 0.0001826 | grad norm:  3.98 | inf norm:  0.345 | loss: 3.87 | perp:  47.91
#  b 600/717 >> 2402.4 ms/b | lr: 0.0002357 | grad norm:  2.28 | inf norm:  0.142 | loss: 3.89 | perp:  48.88
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1668.25 sec | train loss, perp: 3.893,  49.06    | valid loss, perp: 4.326,  75.67
# Grad norm:  2.539 | Grad inf. norm:  0.2261 | Max abs param:   5.035
# ============================================================================================================
#
#
# Epoch   9/150) lr = 0.0002516 (warmup)
#  b 150/724 >> 2298.5 ms/b | lr: 0.0002652 | grad norm:  2.44 | inf norm:  0.214 | loss: 3.81 | perp:  45.36
#  b 300/724 >> 2260.0 ms/b | lr: 0.0002372 | grad norm:  3.29 | inf norm:  0.341 | loss: 3.78 | perp:  43.82
#  b 450/724 >> 2287.0 ms/b | lr: 0.0002516 | grad norm:  2.94 | inf norm:  0.228 | loss: 3.81 | perp:  45.26
#  b 600/724 >> 2348.4 ms/b | lr: 0.0002219 | grad norm:  3.39 | inf norm:  0.332 | loss: 3.83 | perp:  46.03
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1664.54 sec | train loss, perp: 3.830,  46.07    | valid loss, perp: 4.291,  73.06
# Grad norm:  2.200 | Grad inf. norm:  0.1284 | Max abs param:   5.041
# ============================================================================================================
#
#
# Epoch  10/150) lr = 0.0002795 (warmup)
#  b 150/715 >> 2326.1 ms/b | lr:  0.000316 | grad norm:  2.43 | inf norm:   0.25 | loss: 3.77 | perp:  43.53
#  b 300/715 >> 2317.6 ms/b | lr: 0.0002946 | grad norm:  2.83 | inf norm:  0.304 | loss: 3.77 | perp:  43.33
#  b 450/715 >> 2338.1 ms/b | lr: 0.0002795 | grad norm:  2.84 | inf norm:  0.359 | loss: 3.79 | perp:  44.06
#  b 600/715 >> 2408.7 ms/b | lr: 0.0002552 | grad norm:  3.72 | inf norm:  0.367 | loss: 3.80 | perp:  44.80
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1676.78 sec | train loss, perp: 3.802,  44.79    | valid loss, perp: 4.229,  68.66
# Grad norm:  3.337 | Grad inf. norm:   0.338 | Max abs param:   5.049
# ============================================================================================================
#
#
# Epoch  11/150) lr = 0.0002665
#  b 150/718 >> 2310.5 ms/b | lr: 0.0002665 | grad norm:  2.98 | inf norm:  0.245 | loss: 3.70 | perp:  40.61
#  b 300/718 >> 2436.0 ms/b | lr:  0.000259 | grad norm:  4.55 | inf norm:  0.476 | loss: 3.72 | perp:  41.39
#  b 450/718 >> 2319.8 ms/b | lr: 0.0002738 | grad norm:  3.39 | inf norm:  0.364 | loss: 3.68 | perp:  39.82
#  b 600/718 >> 2284.0 ms/b | lr:  0.000259 | grad norm:  3.43 | inf norm:  0.341 | loss: 3.70 | perp:  40.38
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1683.62 sec | train loss, perp: 3.723,  41.39    | valid loss, perp: 4.151,  63.48
# Grad norm:  5.018 | Grad inf. norm:  0.6093 | Max abs param:   5.051
# ============================================================================================================
#
#
# Epoch  12/150) lr = 0.0002552
#  b 150/719 >> 2400.8 ms/b | lr: 0.0002621 | grad norm:  3.64 | inf norm:  0.398 | loss: 3.65 | perp:  38.66
#  b 300/719 >> 2285.2 ms/b | lr:  0.000248 | grad norm:  4.18 | inf norm:  0.601 | loss: 3.63 | perp:  37.60
#  b 450/719 >> 2373.5 ms/b | lr: 0.0002406 | grad norm:  4.37 | inf norm:  0.625 | loss: 3.63 | perp:  37.63
#  b 600/719 >> 2317.5 ms/b | lr: 0.0002552 | grad norm:  4.49 | inf norm:  0.474 | loss: 3.63 | perp:  37.67
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1678.64 sec | train loss, perp: 3.643,  38.21    | valid loss, perp: 4.069,  58.51
# Grad norm:  3.977 | Grad inf. norm:  0.4248 | Max abs param:   5.052
# ============================================================================================================
#
#
# Epoch  13/150) lr = 0.0002451
#  b 150/715 >> 2336.2 ms/b | lr: 0.0002162 | grad norm:  5.31 | inf norm:  0.834 | loss: 3.58 | perp:  35.80
#  b 300/715 >> 2351.2 ms/b | lr: 0.0002519 | grad norm:  3.77 | inf norm:  0.505 | loss: 3.56 | perp:  35.17
#  b 450/715 >> 2398.3 ms/b | lr: 0.0002382 | grad norm:  4.70 | inf norm:  0.627 | loss: 3.57 | perp:  35.46
#  b 600/715 >> 2301.4 ms/b | lr: 0.0002648 | grad norm:  4.39 | inf norm:  0.682 | loss: 3.57 | perp:  35.42
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1683.34 sec | train loss, perp: 3.588,  36.16    | valid loss, perp: 4.024,  55.94
# Grad norm:  4.605 | Grad inf. norm:  0.6773 | Max abs param:   5.056
# ============================================================================================================
#
#
# Epoch  14/150) lr = 0.0002362
#  b 150/715 >> 2334.1 ms/b | lr: 0.0002839 | grad norm:  6.78 | inf norm:  0.874 | loss: 3.54 | perp:  34.40
#  b 300/715 >> 2415.0 ms/b | lr: 0.0002612 | grad norm:  6.38 | inf norm:  0.733 | loss: 3.54 | perp:  34.40
#  b 450/715 >> 2446.9 ms/b | lr: 0.0002552 | grad norm:  5.04 | inf norm:  0.712 | loss: 3.54 | perp:  34.59
#  b 600/715 >> 2319.4 ms/b | lr: 0.0002296 | grad norm:  5.60 | inf norm:  0.488 | loss: 3.52 | perp:  33.85
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1687.57 sec | train loss, perp: 3.545,  34.64    | valid loss, perp: 4.005,  54.85
# Grad norm:  7.985 | Grad inf. norm:    0.63 | Max abs param:    5.06
# ============================================================================================================
#
#
# Epoch  15/150) lr = 0.0002282
#  b 150/711 >> 2353.1 ms/b | lr: 0.0002406 | grad norm:  4.76 | inf norm:  0.439 | loss: 3.51 | perp:  33.50
#  b 300/711 >> 2309.6 ms/b | lr: 0.0002152 | grad norm:  5.68 | inf norm:  0.614 | loss: 3.51 | perp:  33.38
#  b 450/711 >> 2246.7 ms/b | lr: 0.0002465 | grad norm:  8.10 | inf norm:   1.05 | loss: 3.51 | perp:  33.48
#  b 600/711 >> 2284.1 ms/b | lr:  0.000258 | grad norm:  6.50 | inf norm:  0.558 | loss: 3.51 | perp:  33.58
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1624.42 sec | train loss, perp: 3.529,  34.10    | valid loss, perp: 3.954,  52.13
# Grad norm:  6.951 | Grad inf. norm:   1.114 | Max abs param:    5.06
# ============================================================================================================
#
#
# Epoch  16/150) lr = 0.000221
#  b 150/720 >> 2199.4 ms/b | lr:  0.000227 | grad norm:  5.84 | inf norm:  0.738 | loss: 3.49 | perp:  32.66
#  b 300/720 >> 2222.8 ms/b | lr: 0.0002083 | grad norm:  6.90 | inf norm:   1.43 | loss: 3.46 | perp:  31.70
#  b 450/720 >> 2256.9 ms/b | lr: 0.0002017 | grad norm:  7.69 | inf norm:  0.991 | loss: 3.49 | perp:  32.89
#  b 600/720 >> 2251.1 ms/b | lr:  0.000227 | grad norm:  5.74 | inf norm:  0.732 | loss: 3.49 | perp:  32.93
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1599.96 sec | train loss, perp: 3.503,  33.21    | valid loss, perp: 3.960,  52.48 :(
# Grad norm:  7.354 | Grad inf. norm:  0.9033 | Max abs param:   5.057
# ============================================================================================================
#
#
# Epoch  17/150) lr = 0.0002144
#  b 150/713 >> 2229.2 ms/b | lr: 0.0002021 | grad norm:  6.79 | inf norm:    1.1 | loss: 3.46 | perp:  31.91
#  b 300/713 >> 2248.1 ms/b | lr: 0.0002083 | grad norm:  6.36 | inf norm:  0.644 | loss: 3.46 | perp:  31.81
#  b 450/713 >> 2345.1 ms/b | lr: 0.0002202 | grad norm:  7.79 | inf norm:  0.959 | loss: 3.49 | perp:  32.83
#  b 600/713 >> 2315.2 ms/b | lr:  0.000226 | grad norm:  7.69 | inf norm:  0.831 | loss: 3.48 | perp:  32.39
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1623.24 sec | train loss, perp: 3.493,  32.87    | valid loss, perp: 3.924,  50.58
# Grad norm:  8.639 | Grad inf. norm:    1.32 | Max abs param:   5.059
# ============================================================================================================
#
#
# Epoch  18/150) lr = 0.0002083
#  b 150/714 >> 2385.2 ms/b | lr: 0.0002355 | grad norm:  8.92 | inf norm:  0.817 | loss: 3.50 | perp:  33.18
#  b 300/714 >> 2273.1 ms/b | lr: 0.0001837 | grad norm: 10.29 | inf norm:   1.31 | loss: 3.43 | perp:  30.73
#  b 450/714 >> 2268.2 ms/b | lr: 0.0002196 | grad norm:  6.90 | inf norm:   0.89 | loss: 3.43 | perp:  30.94
#  b 600/714 >> 2298.3 ms/b | lr:  0.000225 | grad norm:  8.85 | inf norm:  0.866 | loss: 3.44 | perp:  31.16
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1645.18 sec | train loss, perp: 3.473,  32.23    | valid loss, perp: 3.895,  49.16
# Grad norm: 14.252 | Grad inf. norm:    1.86 | Max abs param:   5.062
# ============================================================================================================
#
#
# Epoch  19/150) lr = 0.0002028
#  b 150/723 >> 2365.6 ms/b | lr: 0.0001851 | grad norm:  8.94 | inf norm:   0.87 | loss: 3.44 | perp:  31.21
#  b 300/723 >> 2236.5 ms/b | lr: 0.0001851 | grad norm: 10.06 | inf norm:   1.41 | loss: 3.41 | perp:  30.18
#  b 450/723 >> 2303.8 ms/b | lr: 0.0002083 | grad norm:  7.28 | inf norm:   0.73 | loss: 3.40 | perp:  30.03
#  b 600/723 >> 2332.7 ms/b | lr: 0.0001788 | grad norm: 10.56 | inf norm:   1.44 | loss: 3.41 | perp:  30.24
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1672.51 sec | train loss, perp: 3.433,  30.96    | valid loss, perp: 3.843,  46.69
# Grad norm: 12.804 | Grad inf. norm:  0.9317 | Max abs param:   5.063
# ============================================================================================================
#
#
# Epoch  20/150) lr = 0.0001976
#  b 150/719 >> 2325.1 ms/b | lr: 0.0001976 | grad norm:  8.03 | inf norm:  0.967 | loss: 3.41 | perp:  30.41
#  b 300/719 >> 2336.3 ms/b | lr: 0.0002031 | grad norm:  9.36 | inf norm:  0.826 | loss: 3.38 | perp:  29.43
#  b 450/719 >> 2305.8 ms/b | lr: 0.0001743 | grad norm: 10.52 | inf norm:  0.785 | loss: 3.38 | perp:  29.38
#  b 600/719 >> 2359.3 ms/b | lr: 0.0001921 | grad norm: 10.93 | inf norm:   1.95 | loss: 3.40 | perp:  29.93
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1682.01 sec | train loss, perp: 3.413,  30.35    | valid loss, perp: 3.787,  44.10
# Grad norm: 25.219 | Grad inf. norm:   1.055 | Max abs param:   5.063
# ============================================================================================================
#
#
# Epoch  21/150) lr = 0.0001929
#  b 150/722 >> 2374.4 ms/b | lr: 0.0001761 | grad norm: 11.00 | inf norm:   1.74 | loss: 3.41 | perp:  30.27
#  b 300/722 >> 2350.1 ms/b | lr: 0.0002132 | grad norm: 11.63 | inf norm:   1.16 | loss: 3.34 | perp:  28.31
#  b 450/722 >> 2290.5 ms/b | lr: 0.0001761 | grad norm: 10.38 | inf norm:   1.83 | loss: 3.36 | perp:  28.77
#  b 600/722 >> 2362.8 ms/b | lr: 0.0001761 | grad norm: 11.44 | inf norm:   1.52 | loss: 3.34 | perp:  28.31
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1690.40 sec | train loss, perp: 3.381,  29.40    | valid loss, perp: 3.738,  41.99
# Grad norm: 10.617 | Grad inf. norm:  0.9776 | Max abs param:    5.06
# ============================================================================================================
#
#
# Epoch  22/150) lr = 0.0001884
#  b 150/718 >> 2376.5 ms/b | lr: 0.0001777 | grad norm: 12.04 | inf norm:   1.91 | loss: 3.34 | perp:  28.12
#  b 300/718 >> 2377.3 ms/b | lr: 0.0001986 | grad norm: 12.58 | inf norm:  0.925 | loss: 3.32 | perp:  27.62
#  b 450/718 >> 2396.2 ms/b | lr: 0.0001473 | grad norm: 15.18 | inf norm:   1.26 | loss: 3.35 | perp:  28.45
#  b 600/718 >> 2435.4 ms/b | lr: 0.0001936 | grad norm: 11.42 | inf norm:      2 | loss: 3.32 | perp:  27.76
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1711.23 sec | train loss, perp: 3.348,  28.44    | valid loss, perp: 3.688,  39.95
# Grad norm: 12.552 | Grad inf. norm:  0.9354 | Max abs param:   5.063
# ============================================================================================================
#
#
# Epoch  23/150) lr = 0.0001843
#  b 150/704 >> 2499.0 ms/b | lr: 0.0001791 | grad norm:  9.07 | inf norm:  0.948 | loss: 3.32 | perp:  27.70
#  b 300/704 >> 2498.1 ms/b | lr: 0.0001943 | grad norm: 12.01 | inf norm:   1.43 | loss: 3.31 | perp:  27.29
#  b 450/704 >> 2385.0 ms/b | lr: 0.0001894 | grad norm: 11.27 | inf norm:   1.21 | loss: 3.29 | perp:  26.84
#  b 600/704 >> 2436.9 ms/b | lr: 0.0001843 | grad norm:  9.96 | inf norm:  0.939 | loss: 3.31 | perp:  27.35
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1732.69 sec | train loss, perp: 3.332,  27.99    | valid loss, perp: 3.725,  41.46 :(
# Grad norm: 10.601 | Grad inf. norm:   1.365 | Max abs param:   5.063
# ============================================================================================================
#
#
# Epoch  24/150) lr = 0.0001804
#  b 150/714 >> 2453.9 ms/b | lr: 0.0001701 | grad norm: 10.39 | inf norm:   1.27 | loss: 3.31 | perp:  27.37
#  b 300/714 >> 2418.9 ms/b | lr: 0.0001753 | grad norm: 11.10 | inf norm:   1.16 | loss: 3.26 | perp:  26.02
#  b 450/714 >> 2440.1 ms/b | lr: 0.0001701 | grad norm: 12.54 | inf norm:   1.44 | loss: 3.28 | perp:  26.51
#  b 600/714 >> 2436.5 ms/b | lr: 0.0001647 | grad norm: 12.44 | inf norm:   1.85 | loss: 3.30 | perp:  27.04
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1740.04 sec | train loss, perp: 3.306,  27.27    | valid loss, perp: 3.676,  39.49
# Grad norm: 11.928 | Grad inf. norm:  0.9846 | Max abs param:   5.061
# ============================================================================================================
#
#
# Epoch  25/150) lr = 0.0001768
#  b 150/719 >> 2374.9 ms/b | lr: 0.0001909 | grad norm: 17.24 | inf norm:   1.11 | loss: 3.27 | perp:  26.21
#  b 300/719 >> 2500.3 ms/b | lr: 0.0001998 | grad norm: 22.55 | inf norm:   1.59 | loss: 3.29 | perp:  26.74
#  b 450/719 >> 2355.5 ms/b | lr: 0.0001909 | grad norm: 20.28 | inf norm:   1.72 | loss: 3.25 | perp:  25.69
#  b 600/719 >> 2406.1 ms/b | lr: 0.0001718 | grad norm: 11.73 | inf norm:    1.7 | loss: 3.25 | perp:  25.80
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1738.44 sec | train loss, perp: 3.285,  26.72    | valid loss, perp: 3.649,  38.43
# Grad norm: 11.459 | Grad inf. norm:   1.687 | Max abs param:    5.06
# ============================================================================================================
#
#
# Epoch  26/150) lr = 0.0001733
#  b 150/721 >> 2445.7 ms/b | lr: 0.0001916 | grad norm: 15.41 | inf norm:   2.13 | loss: 3.28 | perp:  26.55
#  b 300/721 >> 2454.9 ms/b | lr: 0.0001916 | grad norm: 16.37 | inf norm:   1.36 | loss: 3.26 | perp:  25.95
#  b 450/721 >> 2416.0 ms/b | lr: 0.0001582 | grad norm: 11.41 | inf norm:   2.57 | loss: 3.24 | perp:  25.65
#  b 600/721 >> 2366.9 ms/b | lr: 0.0001685 | grad norm: 11.48 | inf norm:   1.34 | loss: 3.24 | perp:  25.47
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1740.63 sec | train loss, perp: 3.267,  26.24    | valid loss, perp: 3.649,  38.45 :(
# Grad norm: 20.031 | Grad inf. norm:  0.9851 | Max abs param:   5.063
# ============================================================================================================
#
#
# Epoch  27/150) lr = 0.0001701
#  b 150/721 >> 2450.5 ms/b | lr: 0.0001553 | grad norm: 12.71 | inf norm:    1.3 | loss: 3.26 | perp:  26.13
#  b 300/721 >> 2423.5 ms/b | lr: 0.0001837 | grad norm: 23.84 | inf norm:   1.71 | loss: 3.22 | perp:  25.02
#  b 450/721 >> 2484.1 ms/b | lr: 0.0001923 | grad norm: 27.39 | inf norm:   1.76 | loss: 3.26 | perp:  25.94
#  b 600/721 >> 2398.7 ms/b | lr: 0.0001793 | grad norm: 16.34 | inf norm:   1.96 | loss: 3.23 | perp:  25.40
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1754.41 sec | train loss, perp: 3.265,  26.19    | valid loss, perp: 3.656,  38.70 :(
# Grad norm: 12.907 | Grad inf. norm:   1.864 | Max abs param:   5.064
# ============================================================================================================
#
#
# Epoch  28/150) lr = 0.000167
#  b 150/719 >> 2484.7 ms/b | lr:  0.000167 | grad norm: 13.51 | inf norm:   1.09 | loss: 3.24 | perp:  25.64
#  b 300/719 >> 2467.8 ms/b | lr: 0.0001525 | grad norm: 13.67 | inf norm:   1.44 | loss: 3.22 | perp:  24.92
#  b 450/719 >> 2456.1 ms/b | lr: 0.0001575 | grad norm: 13.54 | inf norm:   1.01 | loss: 3.22 | perp:  25.14
#  b 600/719 >> 2487.5 ms/b | lr: 0.0001525 | grad norm: 14.18 | inf norm:    1.7 | loss: 3.25 | perp:  25.69
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1764.58 sec | train loss, perp: 3.251,  25.82    | valid loss, perp: 3.628,  37.65
# Grad norm: 12.379 | Grad inf. norm:   1.451 | Max abs param:   5.071
# ============================================================================================================
#
#
# Epoch  29/150) lr = 0.0001641
#  b 150/712 >> 2524.9 ms/b | lr: 0.0001595 | grad norm: 13.24 | inf norm:   1.41 | loss: 3.25 | perp:  25.75
#  b 300/712 >> 2514.2 ms/b | lr: 0.0001498 | grad norm: 13.31 | inf norm:   1.71 | loss: 3.24 | perp:  25.63
#  b 450/712 >> 2509.2 ms/b | lr: 0.0001498 | grad norm: 12.80 | inf norm:   1.38 | loss: 3.22 | perp:  25.09
#  b 600/712 >> 2490.7 ms/b | lr: 0.0001547 | grad norm: 12.89 | inf norm:   1.47 | loss: 3.23 | perp:  25.38
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1776.23 sec | train loss, perp: 3.252,  25.83 :( | valid loss, perp: 3.616,  37.20
# Grad norm: 14.273 | Grad inf. norm:   1.723 | Max abs param:   5.069
# ============================================================================================================
#
#
# Epoch  30/150) lr = 0.0001614
#  b 150/718 >> 2500.2 ms/b | lr: 0.0001658 | grad norm: 15.61 | inf norm:    1.6 | loss: 3.24 | perp:  25.49
#  b 300/718 >> 2454.2 ms/b | lr: 0.0001614 | grad norm: 11.88 | inf norm:   1.23 | loss: 3.20 | perp:  24.49
#  b 450/718 >> 2414.5 ms/b | lr: 0.0001658 | grad norm: 25.42 | inf norm:   2.38 | loss: 3.18 | perp:  23.98
#  b 600/718 >> 2498.7 ms/b | lr: 0.0001473 | grad norm: 16.96 | inf norm:   2.28 | loss: 3.21 | perp:  24.71
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1781.17 sec | train loss, perp: 3.226,  25.18    | valid loss, perp: 3.609,  36.92
# Grad norm: 13.455 | Grad inf. norm:   1.628 | Max abs param:   5.072
# ============================================================================================================
#
#
# Epoch  31/150) lr = 0.0001588
#  b 150/722 >> 2877.0 ms/b | lr: 0.0001755 | grad norm: 33.75 | inf norm:   1.66 | loss: 3.21 | perp:  24.75
#  b 300/722 >> 2640.0 ms/b | lr: 0.0001497 | grad norm: 10.86 | inf norm:   1.03 | loss: 3.18 | perp:  24.13
#  b 450/722 >> 2717.5 ms/b | lr: 0.0001673 | grad norm: 62.87 | inf norm:   3.81 | loss: 3.19 | perp:  24.33
#  b 600/722 >> 2609.6 ms/b | lr: 0.0001588 | grad norm: 16.37 | inf norm:   1.74 | loss: 3.18 | perp:  24.04
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1947.95 sec | train loss, perp: 3.219,  25.00    | valid loss, perp: 3.700,  40.45 :(
# Grad norm: 16.952 | Grad inf. norm:   1.958 | Max abs param:    5.07
# ============================================================================================================
#
#
# Epoch  32/150) lr = 0.0001563
#  b 150/722 >> 2635.3 ms/b | lr: 0.0001605 | grad norm: 15.04 | inf norm:   1.22 | loss: 3.21 | perp:  24.72
#  b 300/722 >> 2676.7 ms/b | lr: 0.0001647 | grad norm: 21.08 | inf norm:   1.45 | loss: 3.20 | perp:  24.51
#  b 450/722 >> 2590.1 ms/b | lr: 0.0001518 | grad norm: 13.68 | inf norm:   2.94 | loss: 3.19 | perp:  24.20
#  b 600/722 >> 2631.2 ms/b | lr: 0.0001605 | grad norm: 15.87 | inf norm:   2.72 | loss: 3.20 | perp:  24.43
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1902.22 sec | train loss, perp: 3.222,  25.07 :( | valid loss, perp: 3.597,  36.48
# Grad norm: 16.093 | Grad inf. norm:   1.133 | Max abs param:   5.075
# ============================================================================================================
#
#
# Epoch  33/150) lr = 0.0001539
#  b 150/716 >> 2735.6 ms/b | lr: 0.0001539 | grad norm: 20.75 | inf norm:   1.42 | loss: 3.22 | perp:  25.11
#  b 300/716 >> 2634.6 ms/b | lr: 0.0001357 | grad norm: 16.70 | inf norm:   2.06 | loss: 3.20 | perp:  24.60
#  b 450/716 >> 2707.6 ms/b | lr: 0.0001405 | grad norm: 12.55 | inf norm:    1.1 | loss: 3.20 | perp:  24.61
#  b 600/716 >> 2624.4 ms/b | lr: 0.0001357 | grad norm: 16.98 | inf norm:   2.21 | loss: 3.18 | perp:  24.07
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1912.56 sec | train loss, perp: 3.223,  25.11 :( | valid loss, perp: 3.623,  37.44 :(
# Grad norm: 16.345 | Grad inf. norm:    1.31 | Max abs param:   5.079
# ============================================================================================================
#
#
# Epoch  34/150) lr = 0.0001516
#  b 150/715 >> 2778.4 ms/b | lr: 0.0001557 | grad norm: 13.36 | inf norm:   1.07 | loss: 3.22 | perp:  25.05
#  b 300/715 >> 2705.8 ms/b | lr: 0.0001384 | grad norm: 16.16 | inf norm:   1.56 | loss: 3.20 | perp:  24.42
#  b 450/715 >> 2688.4 ms/b | lr: 0.0001557 | grad norm: 14.28 | inf norm:   1.35 | loss: 3.16 | perp:  23.62
#  b 600/715 >> 2699.9 ms/b | lr:  0.000175 | grad norm: 20.96 | inf norm:   1.63 | loss: 3.18 | perp:  24.09
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1943.87 sec | train loss, perp: 3.211,  24.80    | valid loss, perp: 3.552,  34.89
# Grad norm: 12.971 | Grad inf. norm:   1.414 | Max abs param:   5.081
# ============================================================================================================
#
#
# Epoch  35/150) lr = 0.0001494
#  b 150/723 >> 2698.5 ms/b | lr: 0.0001409 | grad norm: 13.38 | inf norm:   1.33 | loss: 3.18 | perp:  24.03
#  b 300/723 >> 2708.3 ms/b | lr:  0.000122 | grad norm: 25.08 | inf norm:   2.04 | loss: 3.15 | perp:  23.29
#  b 450/723 >> 2666.7 ms/b | lr: 0.0001614 | grad norm: 53.61 | inf norm:   3.59 | loss: 3.16 | perp:  23.49
#  b 600/723 >> 2687.9 ms/b | lr: 0.0001652 | grad norm: 40.82 | inf norm:   2.24 | loss: 3.18 | perp:  23.99
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1949.15 sec | train loss, perp: 3.184,  24.14    | valid loss, perp: 3.560,  35.16 :(
# Grad norm: 78.124 | Grad inf. norm:   5.003 | Max abs param:   5.082
# ============================================================================================================
#
#
# Epoch  36/150) lr = 0.0001473
#  b 150/715 >> 2797.8 ms/b | lr: 0.0001389 | grad norm: 15.90 | inf norm:   2.42 | loss: 3.18 | perp:  24.03
#  b 300/715 >> 2666.3 ms/b | lr: 0.0001591 | grad norm: 23.17 | inf norm:   4.44 | loss: 3.15 | perp:  23.27
#  b 450/715 >> 2764.7 ms/b | lr: 0.0001389 | grad norm: 20.52 | inf norm:   1.89 | loss: 3.18 | perp:  24.12
#  b 600/715 >> 2699.3 ms/b | lr: 0.0001432 | grad norm: 22.27 | inf norm:   2.88 | loss: 3.16 | perp:  23.45
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1942.62 sec | train loss, perp: 3.192,  24.33 :( | valid loss, perp: 3.573,  35.64 :(
# Grad norm: 14.445 | Grad inf. norm:   1.401 | Max abs param:   5.083
# ============================================================================================================
#
#
# Epoch  37/150) lr = 0.0001453
#  b 150/720 >> 2747.4 ms/b | lr: 0.0001326 | grad norm: 15.50 | inf norm:   1.81 | loss: 3.18 | perp:  23.98
#  b 300/720 >> 2705.2 ms/b | lr:  0.000137 | grad norm: 14.50 | inf norm:   1.75 | loss: 3.15 | perp:  23.27
#  b 450/720 >> 2666.6 ms/b | lr: 0.0001282 | grad norm: 13.23 | inf norm:   1.92 | loss: 3.15 | perp:  23.41
#  b 600/720 >> 2728.6 ms/b | lr:  0.000157 | grad norm: 47.93 | inf norm:    4.7 | loss: 3.17 | perp:  23.74
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1957.79 sec | train loss, perp: 3.184,  24.14    | valid loss, perp: 3.607,  36.85 :(
# Grad norm: 26.854 | Grad inf. norm:   1.446 | Max abs param:   5.084
# ============================================================================================================
#
#
# Epoch  38/150) lr = 0.0001434
#  b 150/727 >> 2639.4 ms/b | lr: 0.0001434 | grad norm: 25.91 | inf norm:   1.89 | loss: 3.14 | perp:  23.13
#  b 300/727 >> 2717.6 ms/b | lr: 0.0001352 | grad norm: 22.68 | inf norm:   2.05 | loss: 3.17 | perp:  23.74
#  b 450/727 >> 2664.7 ms/b | lr: 0.0001511 | grad norm: 41.00 | inf norm:   2.56 | loss: 3.16 | perp:  23.68
#  b 600/727 >> 2690.8 ms/b | lr: 0.0001434 | grad norm: 16.33 | inf norm:   1.39 | loss: 3.18 | perp:  24.16
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1944.76 sec | train loss, perp: 3.194,  24.38 :( | valid loss, perp: 3.574,  35.67 :(
# Grad norm: 21.550 | Grad inf. norm:   1.973 | Max abs param:   5.084
# ============================================================================================================
#
#
# Epoch  39/150) lr = 0.0001415
#  b 150/713 >> 2780.7 ms/b | lr: 0.0001292 | grad norm: 19.21 | inf norm:   2.71 | loss: 3.20 | perp:  24.60
#  b 300/713 >> 2755.9 ms/b | lr: 0.0001248 | grad norm: 13.79 | inf norm:   1.25 | loss: 3.17 | perp:  23.92
#  b 450/713 >> 2710.9 ms/b | lr: 0.0001375 | grad norm: 19.22 | inf norm:   1.73 | loss: 3.15 | perp:  23.32
#  b 600/713 >> 2754.0 ms/b | lr:   0.00016 | grad norm: 71.32 | inf norm:   5.43 | loss: 3.16 | perp:  23.48
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1954.30 sec | train loss, perp: 3.196,  24.43 :( | valid loss, perp: 3.551,  34.84
# Grad norm: 16.906 | Grad inf. norm:   1.659 | Max abs param:   5.084
# ============================================================================================================
#
#
# Epoch  40/150) lr = 0.0001398
#  b 150/723 >> 2732.3 ms/b | lr: 0.0001398 | grad norm: 20.54 | inf norm:   2.02 | loss: 3.17 | perp:  23.75
#  b 300/723 >> 2651.5 ms/b | lr: 0.0001436 | grad norm: 29.50 | inf norm:   2.97 | loss: 3.17 | perp:  23.86
#  b 450/723 >> 2677.0 ms/b | lr: 0.0001398 | grad norm: 16.22 | inf norm:   2.05 | loss: 3.15 | perp:  23.33
#  b 600/723 >> 2688.2 ms/b | lr: 0.0001233 | grad norm: 14.94 | inf norm:   1.59 | loss: 3.16 | perp:  23.66
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1944.23 sec | train loss, perp: 3.192,  24.34 :( | valid loss, perp: 3.582,  35.96 :(
# Grad norm: 16.123 | Grad inf. norm:   2.089 | Max abs param:   5.086
# ============================================================================================================
#
#
# Epoch  41/150) lr = 0.000138
#  b 150/720 >> 2681.2 ms/b | lr: 0.0001301 | grad norm: 15.76 | inf norm:   3.43 | loss: 3.16 | perp:  23.47
#  b 300/720 >> 2731.0 ms/b | lr:  0.000138 | grad norm: 17.23 | inf norm:   1.74 | loss: 3.14 | perp:  23.01
#  b 450/720 >> 2743.5 ms/b | lr:  0.000126 | grad norm: 19.04 | inf norm:   2.03 | loss: 3.15 | perp:  23.36
#  b 600/720 >> 2684.4 ms/b | lr: 0.0001217 | grad norm: 19.36 | inf norm:   2.15 | loss: 3.15 | perp:  23.23
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1954.68 sec | train loss, perp: 3.174,  23.90    | valid loss, perp: 3.587,  36.14 :(
# Grad norm: 17.094 | Grad inf. norm:   1.742 | Max abs param:   5.088
# ============================================================================================================
#
#
# Epoch  42/150) lr = 0.0001364
#  b 150/718 >> 2723.3 ms/b | lr: 0.0001203 | grad norm: 16.47 | inf norm:   2.61 | loss: 3.18 | perp:  24.05
#  b 300/718 >> 2807.1 ms/b | lr: 0.0001473 | grad norm: 20.92 | inf norm:   1.88 | loss: 3.18 | perp:  24.14
#  b 450/718 >> 2820.4 ms/b | lr: 0.0001508 | grad norm: 37.32 | inf norm:      2 | loss: 3.17 | perp:  23.87
#  b 600/718 >> 2703.6 ms/b | lr: 0.0001473 | grad norm: 40.50 | inf norm:   2.16 | loss: 3.14 | perp:  23.12
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1973.22 sec | train loss, perp: 3.187,  24.22 :( | valid loss, perp: 3.585,  36.06 :(
# Grad norm: 17.824 | Grad inf. norm:   2.171 | Max abs param:   5.086
# ============================================================================================================
#
#
# Epoch  43/150) lr = 0.0001348
#  b 150/716 >> 2754.3 ms/b | lr: 0.0001385 | grad norm: 18.49 | inf norm:   1.76 | loss: 3.16 | perp:  23.56
#  b 300/716 >> 2745.2 ms/b | lr: 0.0001189 | grad norm: 20.08 | inf norm:   1.68 | loss: 3.14 | perp:  23.17
#  b 450/716 >> 2732.8 ms/b | lr: 0.0001421 | grad norm: 46.19 | inf norm:   3.59 | loss: 3.15 | perp:  23.28
#  b 600/716 >> 2734.1 ms/b | lr: 0.0001271 | grad norm: 15.47 | inf norm:   1.54 | loss: 3.17 | perp:  23.91
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1963.85 sec | train loss, perp: 3.185,  24.17 :( | valid loss, perp: 3.560,  35.16 :(
# Grad norm: 23.089 | Grad inf. norm:   1.957 | Max abs param:   5.086
# ============================================================================================================
#
#
# Epoch  44/150) lr = 0.0001333
#  b 150/718 >> 2630.5 ms/b | lr: 0.0001333 | grad norm: 27.56 | inf norm:   2.54 | loss: 3.15 | perp:  23.26
#  b 300/718 >> 2750.9 ms/b | lr: 0.0001256 | grad norm: 20.62 | inf norm:      2 | loss: 3.16 | perp:  23.49
#  b 450/718 >> 2765.9 ms/b | lr: 0.0001369 | grad norm: 132.73 | inf norm:   11.2 | loss: 3.18 | perp:  23.93
#  b 600/718 >> 2708.0 ms/b | lr: 0.0001333 | grad norm: 22.35 | inf norm:   2.12 | loss: 3.15 | perp:  23.27
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1947.13 sec | train loss, perp: 3.182,  24.11 :( | valid loss, perp: 3.549,  34.78
# Grad norm: 16.354 | Grad inf. norm:   1.349 | Max abs param:   5.089
# ============================================================================================================
#
#
# Epoch  45/150) lr = 0.0001318
#  b 150/723 >> 2705.0 ms/b | lr: 0.0001423 | grad norm: 51.82 | inf norm:   2.82 | loss: 3.17 | perp:  23.87
#  b 300/723 >> 2592.0 ms/b | lr: 0.0001389 | grad norm: 27.37 | inf norm:   1.91 | loss: 3.13 | perp:  22.96
#  b 450/723 >> 2726.8 ms/b | lr: 0.0001242 | grad norm: 15.65 | inf norm:   2.15 | loss: 3.22 | perp:  24.92
#  b 600/723 >> 2622.5 ms/b | lr: 0.0001076 | grad norm: 20.61 | inf norm:    3.1 | loss: 3.15 | perp:  23.35
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1928.81 sec | train loss, perp: 3.203,  24.60 :( | valid loss, perp: 3.552,  34.90 :(
# Grad norm: 20.584 | Grad inf. norm:   1.418 | Max abs param:    5.09
# ============================================================================================================
#
#
# Epoch  46/150) lr = 0.0001303
#  b 150/719 >> 2763.1 ms/b | lr: 0.0001229 | grad norm: 18.11 | inf norm:   2.53 | loss: 3.15 | perp:  23.32
#  b 300/719 >> 2807.3 ms/b | lr:  0.000119 | grad norm: 16.45 | inf norm:   1.92 | loss: 3.12 | perp:  22.70
#  b 450/719 >> 2773.3 ms/b | lr: 0.0001108 | grad norm: 23.22 | inf norm:   3.19 | loss: 3.17 | perp:  23.88
#  b 600/719 >> 2866.5 ms/b | lr: 0.0001266 | grad norm: 17.17 | inf norm:   1.39 | loss: 3.15 | perp:  23.45
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2018.42 sec | train loss, perp: 3.174,  23.90 :( | valid loss, perp: 3.545,  34.63
# Grad norm: 27.969 | Grad inf. norm:   1.608 | Max abs param:    5.09
# ============================================================================================================
#
#
# Epoch  47/150) lr = 0.0001289
#  b 150/711 >> 2759.7 ms/b | lr: 0.0001253 | grad norm: 31.11 | inf norm:   4.39 | loss: 3.16 | perp:  23.51
#  b 300/711 >> 2924.7 ms/b | lr: 0.0001177 | grad norm: 18.19 | inf norm:   1.92 | loss: 3.16 | perp:  23.46
#  b 450/711 >> 3090.0 ms/b | lr: 0.0001393 | grad norm: 72.89 | inf norm:    4.9 | loss: 3.18 | perp:  24.15
#  b 600/711 >> 2910.6 ms/b | lr: 0.0001216 | grad norm: 16.86 | inf norm:    2.1 | loss: 3.17 | perp:  23.75
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2051.60 sec | train loss, perp: 3.184,  24.14 :( | valid loss, perp: 3.539,  34.44
# Grad norm: 17.838 | Grad inf. norm:   1.265 | Max abs param:   5.088
# ============================================================================================================
#
#
# Epoch  48/150) lr = 0.0001276
#  b 150/718 >> 3002.7 ms/b | lr: 0.0001125 | grad norm: 16.95 | inf norm:   2.17 | loss: 3.13 | perp:  22.96
#  b 300/718 >> 2771.4 ms/b | lr: 0.0001345 | grad norm: 182.76 | inf norm:   10.9 | loss: 3.18 | perp:  24.07
#  b 450/718 >> 2613.4 ms/b | lr: 0.0001378 | grad norm: 69.20 | inf norm:   4.45 | loss: 3.17 | perp:  23.77
#  b 600/718 >> 2718.7 ms/b | lr: 0.0001378 | grad norm: 22.09 | inf norm:   1.73 | loss: 3.14 | perp:  23.11
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1993.20 sec | train loss, perp: 3.178,  23.99 :( | valid loss, perp: 3.537,  34.35
# Grad norm: 17.319 | Grad inf. norm:   2.278 | Max abs param:   5.084
# ============================================================================================================
#
#
# Epoch  49/150) lr = 0.0001263
#  b 150/715 >> 2657.2 ms/b | lr: 0.0001227 | grad norm: 15.18 | inf norm:    1.1 | loss: 3.14 | perp:  23.14
#  b 300/715 >> 2735.0 ms/b | lr: 0.0001331 | grad norm: 276.63 | inf norm:   14.3 | loss: 3.19 | perp:  24.29
#  b 450/715 >> 2634.0 ms/b | lr: 0.0001153 | grad norm: 18.09 | inf norm:   2.28 | loss: 3.13 | perp:  22.83
#  b 600/715 >> 2737.0 ms/b | lr: 0.0001331 | grad norm: 20.70 | inf norm:   1.43 | loss: 3.16 | perp:  23.55
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1934.14 sec | train loss, perp: 3.183,  24.11 :( | valid loss, perp: 3.547,  34.71 :(
# Grad norm: 18.872 | Grad inf. norm:   2.203 | Max abs param:   5.083
# ============================================================================================================
#
#
# Epoch  50/150) lr = 0.000125
#  b 150/717 >> 2763.7 ms/b | lr: 0.0001318 | grad norm: 73.72 | inf norm:   4.16 | loss: 3.14 | perp:  23.07
#  b 300/717 >> 2622.2 ms/b | lr: 0.0001284 | grad norm: 187.55 | inf norm:   12.5 | loss: 3.13 | perp:  22.83
#  b 450/717 >> 2682.5 ms/b | lr: 0.0001141 | grad norm: 19.26 | inf norm:   3.54 | loss: 3.12 | perp:  22.63
#  b 600/717 >> 2759.1 ms/b | lr: 0.0001284 | grad norm: 19.83 | inf norm:    1.8 | loss: 3.16 | perp:  23.61
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1939.26 sec | train loss, perp: 3.167,  23.73    | valid loss, perp: 3.540,  34.47 :(
# Grad norm: 18.293 | Grad inf. norm:   1.877 | Max abs param:   5.082
# ============================================================================================================
#
#
# Epoch  51/150) lr = 0.0001238
#  b 150/713 >> 2798.8 ms/b | lr: 0.0001368 | grad norm: 73.28 | inf norm:   4.22 | loss: 3.17 | perp:  23.70
#  b 300/713 >> 2677.7 ms/b | lr: 0.0001238 | grad norm: 24.04 | inf norm:   2.71 | loss: 3.10 | perp:  22.16
#  b 450/713 >> 2732.1 ms/b | lr: 0.0001092 | grad norm: 18.69 | inf norm:   3.03 | loss: 3.13 | perp:  22.84
#  b 600/713 >> 2757.4 ms/b | lr: 0.0001305 | grad norm: 135.24 | inf norm:   6.95 | loss: 3.15 | perp:  23.40
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1957.15 sec | train loss, perp: 3.155,  23.46    | valid loss, perp: 3.500,  33.11
# Grad norm: 18.375 | Grad inf. norm:   2.438 | Max abs param:   5.083
# ============================================================================================================
#
#
# Epoch  52/150) lr = 0.0001226
#  b 150/718 >> 2714.7 ms/b | lr: 0.0001191 | grad norm: 19.37 | inf norm:   1.79 | loss: 3.17 | perp:  23.90
#  b 300/718 >> 2728.6 ms/b | lr: 0.0001324 | grad norm: 29.61 | inf norm:   2.28 | loss: 3.13 | perp:  22.87
#  b 450/718 >> 2699.7 ms/b | lr: 0.0001191 | grad norm: 16.98 | inf norm:    2.4 | loss: 3.12 | perp:  22.68
#  b 600/718 >> 2755.0 ms/b | lr: 0.0001259 | grad norm: 41.05 | inf norm:   3.59 | loss: 3.16 | perp:  23.68
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1953.80 sec | train loss, perp: 3.167,  23.73 :( | valid loss, perp: 3.542,  34.55 :(
# Grad norm: 19.009 | Grad inf. norm:   2.893 | Max abs param:   5.083
# ============================================================================================================
#
#
# Epoch  53/150) lr = 0.0001214
#  b 150/718 >> 2709.7 ms/b | lr: 0.0001214 | grad norm: 18.24 | inf norm:   1.97 | loss: 3.13 | perp:  22.92
#  b 300/718 >> 2670.3 ms/b | lr:  0.000128 | grad norm: 19.37 | inf norm:   1.42 | loss: 3.14 | perp:  23.03
#  b 450/718 >> 2722.5 ms/b | lr: 0.0001247 | grad norm: 26.40 | inf norm:   2.34 | loss: 3.11 | perp:  22.39
#  b 600/718 >> 2779.3 ms/b | lr: 0.0001032 | grad norm: 23.29 | inf norm:   2.15 | loss: 3.15 | perp:  23.45
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1950.58 sec | train loss, perp: 3.165,  23.69 :( | valid loss, perp: 3.540,  34.45 :(
# Grad norm: 46.276 | Grad inf. norm:   3.844 | Max abs param:   5.085
# ============================================================================================================
#
#
# Epoch  54/150) lr = 0.0001203
#  b 150/717 >> 2840.7 ms/b | lr: 0.0001268 | grad norm: 29.13 | inf norm:   2.16 | loss: 3.18 | perp:  23.95
#  b 300/717 >> 2737.3 ms/b | lr: 0.0001236 | grad norm: 28.41 | inf norm:   2.29 | loss: 3.12 | perp:  22.69
#  b 450/717 >> 2692.5 ms/b | lr: 0.0001061 | grad norm: 19.03 | inf norm:   2.08 | loss: 3.13 | perp:  22.97
#  b 600/717 >> 2714.3 ms/b | lr:  0.000133 | grad norm: 37.27 | inf norm:   3.02 | loss: 3.14 | perp:  23.17
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1962.72 sec | train loss, perp: 3.165,  23.68 :( | valid loss, perp: 3.541,  34.50 :(
# Grad norm: 20.432 | Grad inf. norm:   3.023 | Max abs param:   5.087
# ============================================================================================================
#
#
# Epoch  55/150) lr = 0.0001192
#  b 150/722 >> 2723.1 ms/b | lr: 0.0001287 | grad norm: 116.59 | inf norm:   6.71 | loss: 3.15 | perp:  23.41
#  b 300/722 >> 2748.7 ms/b | lr: 0.0001158 | grad norm: 22.05 | inf norm:   1.67 | loss: 3.11 | perp:  22.46
#  b 450/722 >> 2652.4 ms/b | lr: 0.0001192 | grad norm: 17.59 | inf norm:    1.6 | loss: 3.12 | perp:  22.64
#  b 600/722 >> 2704.4 ms/b | lr: 0.0001192 | grad norm: 27.72 | inf norm:   2.62 | loss: 3.11 | perp:  22.31
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1957.94 sec | train loss, perp: 3.151,  23.37    | valid loss, perp: 3.551,  34.86 :(
# Grad norm: 60.749 | Grad inf. norm:   3.934 | Max abs param:   5.088
# ============================================================================================================
#
#
# Epoch  56/150) lr = 0.0001181
#  b 150/712 >> 2790.6 ms/b | lr: 0.0001181 | grad norm: 31.46 | inf norm:   3.15 | loss: 3.15 | perp:  23.40
#  b 300/712 >> 2752.5 ms/b | lr: 9.644e-05 | grad norm: 37.91 | inf norm:    4.2 | loss: 3.13 | perp:  22.78
#  b 450/712 >> 2797.2 ms/b | lr: 0.0001148 | grad norm: 16.25 | inf norm:   1.74 | loss: 3.15 | perp:  23.29
#  b 600/712 >> 2813.9 ms/b | lr: 0.0001181 | grad norm: 29.30 | inf norm:   2.21 | loss: 3.12 | perp:  22.60
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1983.39 sec | train loss, perp: 3.155,  23.46 :( | valid loss, perp: 3.556,  35.01 :(
# Grad norm: 70.728 | Grad inf. norm:   5.132 | Max abs param:   5.086
# ============================================================================================================
#
#
# Epoch  57/150) lr = 0.0001171
#  b 150/715 >> 2843.3 ms/b | lr: 0.0001265 | grad norm: 48.14 | inf norm:   2.81 | loss: 3.17 | perp:  23.92
#  b 300/715 >> 2718.2 ms/b | lr: 9.949e-05 | grad norm: 19.47 | inf norm:    1.9 | loss: 3.09 | perp:  22.03
# ...
#  b 450/720 >> 2762.8 ms/b | lr: 9.251e-05 | grad norm: 34.45 | inf norm:   3.33 | loss: 3.18 | perp:  24.15
#  b 600/720 >> 2824.9 ms/b | lr: 9.576e-05 | grad norm: 20.84 | inf norm:   2.99 | loss: 3.14 | perp:  23.07
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2032.25 sec | train loss, perp: 3.165,  23.69 :( | valid loss, perp: 3.535,  34.29 :(
# Grad norm: 23.725 | Grad inf. norm:    4.08 | Max abs param:   5.094
# ============================================================================================================
#
#
# Epoch  72/150) lr = 0.0001042
#  b 150/720 >> 2856.9 ms/b | lr: 9.821e-05 | grad norm: 29.14 | inf norm:   3.33 | loss: 3.11 | perp:  22.35
#  b 300/720 >> 2896.1 ms/b | lr:  0.000107 | grad norm: 22.42 | inf norm:   2.35 | loss: 3.17 | perp:  23.91
#  b 450/720 >> 2859.4 ms/b | lr: 0.0001042 | grad norm: 27.07 | inf norm:   3.99 | loss: 3.16 | perp:  23.58
#  b 600/720 >> 2815.6 ms/b | lr: 9.509e-05 | grad norm: 29.86 | inf norm:   2.96 | loss: 3.13 | perp:  22.98
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2045.92 sec | train loss, perp: 3.158,  23.51 :( | valid loss, perp: 3.576,  35.74 :(
# Grad norm: 23.937 | Grad inf. norm:   3.837 | Max abs param:   5.094
# ============================================================================================================
#
#
# Epoch  73/150) lr = 0.0001035
#  b 150/718 >> 2825.1 ms/b | lr: 0.0001005 | grad norm: 18.66 | inf norm:   1.69 | loss: 3.13 | perp:  22.89
#  b 300/718 >> 2898.2 ms/b | lr: 9.444e-05 | grad norm: 24.11 | inf norm:   3.62 | loss: 3.16 | perp:  23.61
#  b 450/718 >> 2893.6 ms/b | lr: 0.0001035 | grad norm: 19.95 | inf norm:   2.05 | loss: 3.14 | perp:  23.16
#  b 600/718 >> 2896.7 ms/b | lr: 0.0001117 | grad norm: 39.64 | inf norm:   2.67 | loss: 3.14 | perp:  23.05
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2060.49 sec | train loss, perp: 3.161,  23.60 :( | valid loss, perp: 3.495,  32.96
# Grad norm: 23.731 | Grad inf. norm:   2.941 | Max abs param:   5.096
# ============================================================================================================
#
#
# Epoch  74/150) lr = 0.0001027
#  b 150/716 >> 2956.3 ms/b | lr: 0.0001056 | grad norm: 61.89 | inf norm:   7.18 | loss: 3.20 | perp:  24.52
#  b 300/716 >> 2866.8 ms/b | lr: 0.0001027 | grad norm: 29.36 | inf norm:   4.45 | loss: 3.15 | perp:  23.45
#  b 450/716 >> 2869.4 ms/b | lr: 0.0001027 | grad norm: 32.42 | inf norm:   2.45 | loss: 3.15 | perp:  23.34
#  b 600/716 >> 2928.7 ms/b | lr: 0.0001136 | grad norm: 146.07 | inf norm:   13.6 | loss: 3.15 | perp:  23.42
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2075.60 sec | train loss, perp: 3.189,  24.27 :( | valid loss, perp: 3.614,  37.10 :(
# Grad norm: 38.777 | Grad inf. norm:   3.149 | Max abs param:   5.097
# ============================================================================================================
#
#
# Epoch  75/150) lr = 0.0001021
#  b 150/724 >> 2799.3 ms/b | lr: 9.919e-05 | grad norm: 48.94 | inf norm:   3.22 | loss: 3.33 | perp:  27.81
#  b 300/724 >> 2787.8 ms/b | lr: 9.317e-05 | grad norm: 26.87 | inf norm:   2.43 | loss: 3.13 | perp:  22.78
#  b 450/724 >> 2913.0 ms/b | lr: 0.0001021 | grad norm: 25.78 | inf norm:   2.76 | loss: 3.13 | perp:  22.87
#  b 600/724 >> 2945.2 ms/b | lr: 9.919e-05 | grad norm: 23.82 | inf norm:   2.75 | loss: 3.11 | perp:  22.35
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2065.30 sec | train loss, perp: 3.184,  24.15 :( | valid loss, perp: 3.532,  34.18 :(
# Grad norm: 45.468 | Grad inf. norm:   3.738 | Max abs param:   5.097
# ============================================================================================================
#
#
# Epoch  76/150) lr = 0.0001014
#  b 150/715 >> 2924.5 ms/b | lr: 0.0001095 | grad norm: 56.76 | inf norm:   3.51 | loss: 3.16 | perp:  23.54
#  b 300/715 >> 2905.2 ms/b | lr: 0.0001042 | grad norm: 51.01 | inf norm:   3.91 | loss: 3.10 | perp:  22.14
#  b 450/715 >> 2932.1 ms/b | lr: 8.942e-05 | grad norm: 18.90 | inf norm:    2.2 | loss: 3.11 | perp:  22.41
#  b 600/715 >> 2962.5 ms/b | lr: 9.559e-05 | grad norm: 19.92 | inf norm:   2.23 | loss: 3.20 | perp:  24.53
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2095.26 sec | train loss, perp: 3.164,  23.66 :( | valid loss, perp: 3.503,  33.21 :(
# Grad norm: 29.726 | Grad inf. norm:   2.019 | Max abs param:   5.095
# ============================================================================================================
#
#
# Epoch  77/150) lr = 0.0001007
#  b 150/716 >> 2884.8 ms/b | lr: 0.0001062 | grad norm: 28.72 | inf norm:    2.6 | loss: 3.11 | perp:  22.49
#  b 300/716 >> 2891.5 ms/b | lr: 9.789e-05 | grad norm: 23.04 | inf norm:   2.23 | loss: 3.12 | perp:  22.57
#  b 450/716 >> 2930.3 ms/b | lr: 0.0001062 | grad norm: 47.45 | inf norm:   3.62 | loss: 3.10 | perp:  22.21
#  b 600/716 >> 2958.6 ms/b | lr: 0.0001062 | grad norm: 51.51 | inf norm:   4.48 | loss: 3.10 | perp:  22.27
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2086.08 sec | train loss, perp: 3.125,  22.76    | valid loss, perp: 3.466,  32.00
# Grad norm: 30.681 | Grad inf. norm:   3.512 | Max abs param:   5.098
# ============================================================================================================
#
#
# Epoch  78/150) lr = 0.0001001
#  b 150/717 >> 2956.8 ms/b | lr: 9.726e-05 | grad norm: 132.24 | inf norm:   9.53 | loss: 3.15 | perp:  23.41
#  b 300/717 >> 2953.6 ms/b | lr: 0.0001055 | grad norm: 33.81 | inf norm:   2.52 | loss: 3.21 | perp:  24.72
#  b 450/717 >> 2860.2 ms/b | lr: 9.436e-05 | grad norm: 23.14 | inf norm:   2.15 | loss: 3.16 | perp:  23.51
#  b 600/717 >> 2864.6 ms/b | lr: 8.505e-05 | grad norm: 25.94 | inf norm:   3.31 | loss: 3.14 | perp:  23.01
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2092.81 sec | train loss, perp: 3.190,  24.29 :( | valid loss, perp: 3.625,  37.54 :(
# Grad norm: 42.591 | Grad inf. norm:   3.924 | Max abs param:   5.099
# ============================================================================================================
#
#
# Epoch  79/150) lr = 9.944e-05
#  b 150/723 >> 2924.6 ms/b | lr: 9.944e-05 | grad norm: 25.20 | inf norm:   2.39 | loss: 3.13 | perp:  22.98
#  b 300/723 >> 2900.7 ms/b | lr: 9.944e-05 | grad norm: 29.38 | inf norm:   2.45 | loss: 3.08 | perp:  21.81
#  b 450/723 >> 2873.8 ms/b | lr: 9.078e-05 | grad norm: 22.33 | inf norm:   2.75 | loss: 3.09 | perp:  21.95
#  b 600/723 >> 2913.8 ms/b | lr: 0.0001022 | grad norm: 23.51 | inf norm:   2.07 | loss: 3.11 | perp:  22.35
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2100.47 sec | train loss, perp: 3.123,  22.72    | valid loss, perp: 3.495,  32.94 :(
# Grad norm: 29.189 | Grad inf. norm:   2.914 | Max abs param:   5.096
# ============================================================================================================
#
#
# Epoch  80/150) lr = 9.882e-05
#  b 150/717 >> 2863.3 ms/b | lr: 9.604e-05 | grad norm: 26.51 | inf norm:   2.72 | loss: 3.12 | perp:  22.70
#  b 300/717 >> 2893.2 ms/b | lr: 0.0001015 | grad norm: 24.41 | inf norm:   2.75 | loss: 3.12 | perp:  22.55
#  b 450/717 >> 2884.4 ms/b | lr: 9.317e-05 | grad norm: 26.25 | inf norm:   3.09 | loss: 3.07 | perp:  21.61
#  b 600/717 >> 2937.1 ms/b | lr: 9.604e-05 | grad norm: 31.46 | inf norm:   2.76 | loss: 3.18 | perp:  23.96
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2076.51 sec | train loss, perp: 3.139,  23.08 :( | valid loss, perp: 3.489,  32.74 :(
# Grad norm: 43.554 | Grad inf. norm:   3.995 | Max abs param:   5.096
# ============================================================================================================
#
#
# Epoch  81/150) lr = 9.821e-05
#  b 150/716 >> 2961.5 ms/b | lr: 0.0001035 | grad norm: 52.91 | inf norm:    3.3 | loss: 3.12 | perp:  22.64
#  b 300/716 >> 2888.2 ms/b | lr: 9.259e-05 | grad norm: 23.92 | inf norm:   2.38 | loss: 3.14 | perp:  23.11
#  b 450/716 >> 2858.1 ms/b | lr: 9.259e-05 | grad norm: 23.49 | inf norm:   2.61 | loss: 3.16 | perp:  23.61
#  b 600/716 >> 2936.0 ms/b | lr: 9.821e-05 | grad norm: 21.31 | inf norm:      3 | loss: 3.14 | perp:  23.07
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2085.93 sec | train loss, perp: 3.160,  23.57 :( | valid loss, perp: 3.503,  33.22 :(
# Grad norm: 25.705 | Grad inf. norm:   2.649 | Max abs param:   5.097
# ============================================================================================================
#
#
# Epoch  82/150) lr = 9.761e-05
#  b 150/712 >> 3001.6 ms/b | lr: 9.203e-05 | grad norm: 31.45 | inf norm:   3.17 | loss: 3.21 | perp:  24.75
#  b 300/712 >> 2872.6 ms/b | lr: 9.761e-05 | grad norm: 30.16 | inf norm:   2.94 | loss: 3.12 | perp:  22.75
#  b 450/712 >> 2985.8 ms/b | lr: 0.0001079 | grad norm: 33.06 | inf norm:    2.9 | loss: 3.20 | perp:  24.57
#  b 600/712 >> 2954.8 ms/b | lr: 0.0001003 | grad norm: 45.25 | inf norm:   2.88 | loss: 3.10 | perp:  22.19
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2091.46 sec | train loss, perp: 3.177,  23.97 :( | valid loss, perp: 3.546,  34.69 :(
# Grad norm: 23.755 | Grad inf. norm:   2.332 | Max abs param:   5.097
# ============================================================================================================
#
#
# Epoch  83/150) lr = 9.702e-05
#  b 150/716 >> 2892.4 ms/b | lr: 9.429e-05 | grad norm: 20.22 | inf norm:   2.26 | loss: 3.14 | perp:  23.02
#  b 300/716 >> 2946.5 ms/b | lr: 9.968e-05 | grad norm: 25.18 | inf norm:   3.39 | loss: 3.12 | perp:  22.63
#  b 450/716 >> 3089.9 ms/b | lr: 9.968e-05 | grad norm: 45.12 | inf norm:   2.84 | loss: 3.13 | perp:  22.89
#  b 600/716 >> 3033.4 ms/b | lr: 8.857e-05 | grad norm: 24.44 | inf norm:   3.27 | loss: 3.15 | perp:  23.42
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2143.25 sec | train loss, perp: 3.163,  23.64 :( | valid loss, perp: 3.550,  34.83 :(
# Grad norm: 79.691 | Grad inf. norm:   6.579 | Max abs param:   5.098
# ============================================================================================================
#
#
# Epoch  84/150) lr = 9.644e-05
#  b 150/722 >> 3023.7 ms/b | lr: 9.908e-05 | grad norm: 68.17 | inf norm:   5.07 | loss: 3.10 | perp:  22.22
#  b 300/722 >> 3033.5 ms/b | lr: 8.505e-05 | grad norm: 33.00 | inf norm:   3.22 | loss: 3.12 | perp:  22.57
#  b 450/722 >> 3086.1 ms/b | lr: 0.0001042 | grad norm: 3864.84 | inf norm:    386 | loss: 3.09 | perp:  22.06
#  b 600/722 >> 3035.8 ms/b | lr: 0.0001017 | grad norm: 25.35 | inf norm:   2.18 | loss: 3.16 | perp:  23.50
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2193.96 sec | train loss, perp: 3.146,  23.25 :( | valid loss, perp: 3.556,  35.03 :(
# Grad norm: 23.597 | Grad inf. norm:   3.701 | Max abs param:     5.1
# ============================================================================================================
#
#
# Epoch  85/150) lr = 9.587e-05
#  b 150/714 >> 3083.3 ms/b | lr: 9.587e-05 | grad norm: 35.46 | inf norm:   3.14 | loss: 3.14 | perp:  23.07
#  b 300/714 >> 3075.8 ms/b | lr: 9.587e-05 | grad norm: 46.35 | inf norm:   5.27 | loss: 3.10 | perp:  22.18
#  b 450/714 >> 3132.1 ms/b | lr: 9.587e-05 | grad norm: 32.67 | inf norm:   1.96 | loss: 3.12 | perp:  22.70
#  b 600/714 >> 3110.2 ms/b | lr: 9.587e-05 | grad norm: 26.50 | inf norm:   2.38 | loss: 3.16 | perp:  23.50
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2203.94 sec | train loss, perp: 3.146,  23.25 :( | valid loss, perp: 3.482,  32.52 :(
# Grad norm: 30.129 | Grad inf. norm:   3.079 | Max abs param:     5.1
# ============================================================================================================
#
#
# Epoch  86/150) lr = 9.531e-05
#  b 150/722 >> 3062.7 ms/b | lr: 9.531e-05 | grad norm: 36.43 | inf norm:   3.25 | loss: 3.13 | perp:  22.98
#  b 300/722 >> 2997.1 ms/b | lr: 9.531e-05 | grad norm: 24.46 | inf norm:   2.34 | loss: 3.11 | perp:  22.51
#  b 450/722 >> 3059.9 ms/b | lr: 0.0001029 | grad norm: 49.07 | inf norm:    3.1 | loss: 3.10 | perp:  22.29
#  b 600/722 >> 3024.7 ms/b | lr: 9.263e-05 | grad norm: 21.54 | inf norm:   2.23 | loss: 3.13 | perp:  22.89
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2189.16 sec | train loss, perp: 3.137,  23.03 :( | valid loss, perp: 3.474,  32.26 :(
# Grad norm: 25.384 | Grad inf. norm:   4.474 | Max abs param:   5.102
# ============================================================================================================
#
#
# Epoch  87/150) lr = 9.476e-05
#  b 150/717 >> 3023.2 ms/b | lr: 9.209e-05 | grad norm: 21.65 | inf norm:   3.21 | loss: 3.13 | perp:  22.88
#  b 300/717 >> 3095.2 ms/b | lr: 0.0001024 | grad norm: 63.52 | inf norm:   4.47 | loss: 3.12 | perp:  22.56
#  b 450/717 >> 3171.3 ms/b | lr: 9.476e-05 | grad norm: 283.70 | inf norm:   18.5 | loss: 3.32 | perp:  27.60
#  b 600/717 >> 2932.3 ms/b | lr: 8.357e-05 | grad norm: 40.22 | inf norm:   4.42 | loss: 3.12 | perp:  22.65
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2199.74 sec | train loss, perp: 3.206,  24.68 :( | valid loss, perp: 4.308,  74.27 :(
# Grad norm: 58.521 | Grad inf. norm:   4.415 | Max abs param:   5.105
# ============================================================================================================
#
#
# Epoch  88/150) lr = 9.422e-05
#  b 150/723 >> 2765.6 ms/b | lr: 9.422e-05 | grad norm: 25.37 | inf norm:   2.24 | loss: 3.41 | perp:  30.19
#  b 300/723 >> 2889.5 ms/b | lr: 0.0001065 | grad norm: 39.88 | inf norm:   3.19 | loss: 3.22 | perp:  25.07
#  b 450/723 >> 3026.1 ms/b | lr:  9.68e-05 | grad norm: 33.38 | inf norm:   2.53 | loss: 3.12 | perp:  22.57
#  b 600/723 >> 3076.8 ms/b | lr: 9.422e-05 | grad norm: 55.45 | inf norm:   5.29 | loss: 3.10 | perp:  22.31
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2135.29 sec | train loss, perp: 3.211,  24.81 :( | valid loss, perp: 3.481,  32.50 :(
# Grad norm: 40.002 | Grad inf. norm:   4.728 | Max abs param:   5.105
# ============================================================================================================
#
#
# Epoch  89/150) lr = 9.369e-05
#  b 150/720 >> 3112.6 ms/b | lr: 0.0001012 | grad norm: 30.44 | inf norm:   2.27 | loss: 3.15 | perp:  23.34
#  b 300/720 >> 3024.0 ms/b | lr: 9.369e-05 | grad norm: 39.14 | inf norm:   4.04 | loss: 3.09 | perp:  22.02
#  b 450/720 >> 3049.0 ms/b | lr: 8.833e-05 | grad norm: 35.94 | inf norm:   3.97 | loss: 3.14 | perp:  23.11
#  b 600/720 >> 2915.1 ms/b | lr: 9.626e-05 | grad norm: 56.23 | inf norm:   4.92 | loss: 3.11 | perp:  22.41
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2155.52 sec | train loss, perp: 3.152,  23.38 :( | valid loss, perp: 3.769,  43.34 :(
# Grad norm: 36.284 | Grad inf. norm:   4.871 | Max abs param:   5.105
# ============================================================================================================

# %%
CAUSES = ['output', 'grad']
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    _states = states
    if model.n_enc_layers > 0:
        enc_states = states[0]
        states = states[1:]
    if model.n_dec_layers > 0:
        dec_states = states[-1]
        states = states[:-1]
    attn_states = states[0]
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])
else:
    # Save training stats
    with open(os.path.join('stats', model_test_name+'.pkl'), 'wb') as f:
        pickle.dump(train_stats, f)
    with open(os.path.join('models', model_test_name+'.pt'), 'wb') as f:
        torch.save(model.state_dict(), f)

# %%
test_loss = evaluate(
    model, test_data, eval_batch_size, seq_len,
    ntokens, eval_criterion, save_wts = True
)
print('test_loss: {:5.3f} | test_perplexity: {:7.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss: 3.706 | test_perplexity:   40.71

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#   935   812  3257    42   804   804  3257    42   252   252   252   252   252
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#   252    42  1038    42    42
# [torch.LongTensor of size 2x18]
#
# 14 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#    27    27    27    27    27    27    27    27    27    27    27    27    27
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#    27    27    27    27    27
# [torch.LongTensor of size 2x18]
#
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   119    26  5463  5463  5463  5463  5463  5463  5463  5463  5463  5463  5463
#
# Columns 13 to 17
#    26  5463   119    26    26
#  5463  5463  5463  5463  5463
# [torch.LongTensor of size 2x18]
#
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#    27    27   448   448   448   448  3790    27   448   448   448   448   448
#
# Columns 13 to 17
#    35    27    27  1479   108
#   448   448   448    26    26
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
#
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(model.embedding.weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = model.attn

# %%
align_wts = np.array(attn.alignment.weight.data)
plt.imshow(align_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_align_in'); plt.ylabel('d_align_out')
plt.title('Alignment sublayer weights')
plt.colorbar()
align_wts.shape
# Out:
# (256, 1024)

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Attention sublayer weights (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 1024)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# ## Plot training stat curves

# %%
epoch_range = range(1, train_stats['epochs']+1)
train_stats.keys()
# Out:
# dict_keys(['epochs', 'train_loss', 'val_loss', 'grad_norm', 'grad_inf_norm', 'max_param', 'best_losses'])

# %%
plt.plot(epoch_range, train_stats['train_loss'])
plt.plot(epoch_range, train_stats['val_loss'])
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('Loss over training time')
plt.legend(['Train loss', 'Validation loss'])

# %%
plt.plot(epoch_range, train_stats['max_param'])
plt.xlabel('Epoch'); plt.ylabel('Largest parameter magnitude')
plt.title('Largest parameter magnitude over training time')
# Out:
# Text(0.5,1,'Largest parameter magnitude over training time')

# %%
fig, pnorm_ax = plt.subplots()
pnorm_ax.plot(epoch_range, train_stats['grad_norm'], 'b')
pnorm_ax.set_xlabel('Epoch');
pnorm_ax.set_ylabel('2-norm', color = 'b')

infnorm_ax = pnorm_ax.twinx()
infnorm_ax.plot(epoch_range, train_stats['grad_inf_norm'], 'r')
infnorm_ax.set_ylabel('infinite norm', color = 'r')

plt.title('Gradient norms over training time')
#fig.tight_layout()
# Out:
# Text(0.5,1,'Gradient norms over training time')
