# %%
import os
import pickle
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from model import *
from trainer import *

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Hyperparameters

# %%
model_test_name = 'no_encoder_decoder'

# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 4
lr = 0.02
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 150
early_stopping = 10
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
h_size = 256
align_size = 256
decode_size = 256
n_enc_layers = 0
attn_rnn_layers = 1
n_dec_layers = 0
smooth_align = True
align_location = False
skip_connections = False

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler
#
# The learning rate scheduler sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    h_size = h_size, align_size = align_size, decode_size = decode_size,
    n_enc_layers = n_enc_layers, attn_rnn_layers = attn_rnn_layers,
    n_dec_layers = n_dec_layers, align_location = align_location,
    skip_connections = skip_connections, smooth_align = smooth_align,
    dropout = dropout
)
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
eval_criterion = LabelSmoothing(ntokens, smoothing = 0)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, decay_factor, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 9190145

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Train and evaluate

# %%
train_stats, stat, train_loss, data, targets, states, nstates = train_eval_loop(
    model, train_data, val_data, batch_size, eval_batch_size,
    seq_len, ntokens, criterion, eval_criterion, optimizer,
    lr_scheduler, epochs, warmup_steps, early_stopping,
    clip, log_interval
)
# Out:
# Epoch   1/150) lr = 2.795e-05 (warmup)
#  b 150/716 >> 2151.7 ms/b | lr: 2.716e-05 | grad norm:  2.91 | inf norm:  0.128 | loss: 7.57 | perp: 1933.73
#  b 300/716 >> 2059.6 ms/b | lr: 2.635e-05 | grad norm:  2.71 | inf norm:  0.186 | loss: 6.25 | perp: 517.31
#  b 450/716 >> 2051.6 ms/b | lr: 2.716e-05 | grad norm:  2.25 | inf norm:  0.122 | loss: 6.07 | perp: 430.52
#  b 600/716 >> 2134.8 ms/b | lr: 2.946e-05 | grad norm:  2.09 | inf norm:  0.133 | loss: 5.95 | perp: 385.13
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1500.10 sec | train loss, perp: 6.347, 570.55    | valid loss, perp: 6.155, 471.15
# Grad norm:  2.149 | Grad inf. norm:  0.1129 | Max abs param:   5.015
# ============================================================================================================
#
#
# Epoch   2/150) lr = 5.59e-05 (warmup)
#  b 150/715 >> 2105.2 ms/b | lr: 5.893e-05 | grad norm:  1.69 | inf norm:  0.097 | loss: 5.79 | perp: 326.81
#  b 300/715 >> 2091.4 ms/b | lr: 5.743e-05 | grad norm:  1.72 | inf norm: 0.0742 | loss: 5.63 | perp: 277.97
#  b 450/715 >> 2084.1 ms/b | lr:  5.27e-05 | grad norm:  1.88 | inf norm: 0.0893 | loss: 5.50 | perp: 243.64
#  b 600/715 >> 2023.6 ms/b | lr: 5.433e-05 | grad norm:  1.71 | inf norm: 0.0714 | loss: 5.40 | perp: 221.11
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1483.17 sec | train loss, perp: 5.540, 254.55    | valid loss, perp: 5.639, 281.26
# Grad norm:  1.807 | Grad inf. norm: 0.08278 | Max abs param:   5.014
# ============================================================================================================
#
#
# Epoch   3/150) lr = 8.385e-05 (warmup)
#  b 150/723 >> 2019.5 ms/b | lr: 9.479e-05 | grad norm:  1.74 | inf norm: 0.0784 | loss: 5.25 | perp: 190.89
#  b 300/723 >> 2081.1 ms/b | lr: 7.395e-05 | grad norm:  2.63 | inf norm:  0.192 | loss: 5.11 | perp: 165.44
#  b 450/723 >> 2060.2 ms/b | lr: 8.839e-05 | grad norm:  1.61 | inf norm: 0.0729 | loss: 5.03 | perp: 153.53
#  b 600/723 >> 2065.2 ms/b | lr: 5.929e-05 | grad norm:  4.88 | inf norm:  0.296 | loss: 4.93 | perp: 139.01
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1478.17 sec | train loss, perp: 5.052, 156.39    | valid loss, perp: 5.186, 178.67
# Grad norm:  2.352 | Grad inf. norm:  0.1219 | Max abs param:   5.015
# ============================================================================================================
#
#
# Epoch   4/150) lr = 0.0001118 (warmup)
#  b 150/722 >> 2118.7 ms/b | lr: 0.0001054 | grad norm:  2.41 | inf norm:  0.115 | loss: 4.77 | perp: 118.23
#  b 300/722 >> 2026.7 ms/b | lr:  9.86e-05 | grad norm:  2.83 | inf norm:  0.236 | loss: 4.65 | perp: 104.94
#  b 450/722 >> 2076.5 ms/b | lr: 0.0001118 | grad norm:  2.24 | inf norm:  0.128 | loss: 4.58 | perp:  97.59
#  b 600/722 >> 2049.8 ms/b | lr:  8.74e-05 | grad norm:  4.60 | inf norm:  0.267 | loss: 4.53 | perp:  93.17
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1484.81 sec | train loss, perp: 4.616, 101.08    | valid loss, perp: 4.827, 124.89
# Grad norm:  2.331 | Grad inf. norm:  0.1557 | Max abs param:   5.013
# ============================================================================================================
#
#
# Epoch   5/150) lr = 0.0001398 (warmup)
#  b 150/713 >> 2053.7 ms/b | lr: 0.0001233 | grad norm:  2.75 | inf norm:  0.137 | loss: 4.38 | perp:  79.66
#  b 300/713 >> 2108.4 ms/b | lr: 0.0001318 | grad norm:  2.76 | inf norm:  0.175 | loss: 4.31 | perp:  74.52
#  b 450/713 >> 2049.6 ms/b | lr: 0.0001358 | grad norm:  2.48 | inf norm:  0.119 | loss: 4.28 | perp:  72.11
#  b 600/713 >> 2115.4 ms/b | lr: 0.0001318 | grad norm:  2.78 | inf norm:  0.164 | loss: 4.25 | perp:  70.24
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1482.43 sec | train loss, perp: 4.308,  74.30    | valid loss, perp: 4.622, 101.74
# Grad norm:  2.599 | Grad inf. norm:  0.2108 | Max abs param:   5.009
# ============================================================================================================
#
#
# Epoch   6/150) lr = 0.0001677 (warmup)
#  b 150/719 >> 2140.2 ms/b | lr: 0.0001581 | grad norm:  3.14 | inf norm:   0.17 | loss: 4.15 | perp:  63.29
#  b 300/719 >> 2058.1 ms/b | lr: 0.0001677 | grad norm:  2.95 | inf norm:  0.267 | loss: 4.09 | perp:  59.60
#  b 450/719 >> 2069.5 ms/b | lr: 0.0001479 | grad norm:  3.52 | inf norm:  0.303 | loss: 4.07 | perp:  58.49
#  b 600/719 >> 2005.4 ms/b | lr: 0.0001723 | grad norm:  2.64 | inf norm:  0.226 | loss: 4.05 | perp:  57.59
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1485.74 sec | train loss, perp: 4.099,  60.30    | valid loss, perp: 4.477,  87.95
# Grad norm:  2.931 | Grad inf. norm:  0.3406 | Max abs param:   5.006
# ============================================================================================================
#
#
# Epoch   7/150) lr = 0.0001957 (warmup)
#  b 150/722 >> 2016.2 ms/b | lr: 0.0002212 | grad norm:  2.15 | inf norm:  0.162 | loss: 3.96 | perp:  52.71
#  b 300/722 >> 2108.9 ms/b | lr: 0.0002062 | grad norm:  2.53 | inf norm:  0.335 | loss: 3.96 | perp:  52.44
#  b 450/722 >> 2029.6 ms/b | lr: 0.0001726 | grad norm:  4.21 | inf norm:  0.426 | loss: 3.94 | perp:  51.61
#  b 600/722 >> 2038.8 ms/b | lr:  0.000201 | grad norm:  2.50 | inf norm:  0.253 | loss: 3.94 | perp:  51.23
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1478.06 sec | train loss, perp: 3.967,  52.85    | valid loss, perp: 4.388,  80.45
# Grad norm:  2.458 | Grad inf. norm:  0.1805 | Max abs param:   5.001
# ============================================================================================================
#
#
# Epoch   8/150) lr = 0.0002236 (warmup)
#  b 150/715 >> 2068.2 ms/b | lr: 0.0002108 | grad norm:  3.08 | inf norm:  0.354 | loss: 3.88 | perp:  48.58
#  b 300/715 >> 2069.4 ms/b | lr: 0.0002528 | grad norm:  2.19 | inf norm:  0.208 | loss: 3.89 | perp:  49.04
#  b 450/715 >> 2094.9 ms/b | lr: 0.0001748 | grad norm:  5.08 | inf norm:  0.551 | loss: 3.88 | perp:  48.64
#  b 600/715 >> 2084.2 ms/b | lr: 0.0002357 | grad norm:  2.87 | inf norm:  0.443 | loss: 3.90 | perp:  49.17
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1486.59 sec | train loss, perp: 3.902,  49.48    | valid loss, perp: 4.349,  77.37
# Grad norm:  4.945 | Grad inf. norm:  0.8524 | Max abs param:   4.996
# ============================================================================================================
#
#
# Epoch   9/150) lr = 0.0002516 (warmup)
#  b 150/717 >> 2037.0 ms/b | lr: 0.0002781 | grad norm:  2.94 | inf norm:  0.579 | loss: 3.82 | perp:  45.47
#  b 300/717 >> 2037.5 ms/b | lr: 0.0002445 | grad norm:  3.03 | inf norm:  0.489 | loss: 3.81 | perp:  44.96
#  b 450/717 >> 2073.5 ms/b | lr: 0.0002652 | grad norm:  3.38 | inf norm:  0.708 | loss: 3.83 | perp:  45.95
#  b 600/717 >> 2110.8 ms/b | lr: 0.0002445 | grad norm:  3.71 | inf norm:  0.613 | loss: 3.85 | perp:  46.77
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1480.68 sec | train loss, perp: 3.844,  46.71    | valid loss, perp: 4.292,  73.14
# Grad norm:  3.740 | Grad inf. norm:  0.5316 | Max abs param:    4.99
# ============================================================================================================
#
#
# Epoch  10/150) lr = 0.0002795 (warmup)
#  b 150/720 >> 2044.0 ms/b | lr: 0.0002872 | grad norm:  2.98 | inf norm:  0.422 | loss: 3.79 | perp:  44.04
#  b 300/720 >> 2074.8 ms/b | lr: 0.0002716 | grad norm:  3.59 | inf norm:  0.594 | loss: 3.79 | perp:  44.28
#  b 450/720 >> 2043.6 ms/b | lr: 0.0003019 | grad norm:  2.79 | inf norm:  0.408 | loss: 3.78 | perp:  43.88
#  b 600/720 >> 2102.3 ms/b | lr: 0.0002795 | grad norm:  3.02 | inf norm:  0.495 | loss: 3.83 | perp:  45.85
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1485.83 sec | train loss, perp: 3.815,  45.39    | valid loss, perp: 4.286,  72.71
# Grad norm:  4.161 | Grad inf. norm:  0.6343 | Max abs param:    4.99
# ============================================================================================================
#
#
# Epoch  11/150) lr = 0.0002665
#  b 150/712 >> 2103.6 ms/b | lr:  0.000259 | grad norm:  4.08 | inf norm:  0.669 | loss: 3.77 | perp:  43.28
#  b 300/712 >> 2126.7 ms/b | lr: 0.0002879 | grad norm:  3.58 | inf norm:  0.636 | loss: 3.77 | perp:  43.40
#  b 450/712 >> 2067.5 ms/b | lr: 0.0002809 | grad norm:  3.42 | inf norm:  0.588 | loss: 3.76 | perp:  42.76
#  b 600/712 >> 2069.7 ms/b | lr: 0.0002738 | grad norm:  3.90 | inf norm:  0.724 | loss: 3.77 | perp:  43.50
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1486.65 sec | train loss, perp: 3.783,  43.94    | valid loss, perp: 4.244,  69.71
# Grad norm:  6.404 | Grad inf. norm:   1.209 | Max abs param:   4.977
# ============================================================================================================
#
#
# Epoch  12/150) lr = 0.0002552
#  b 150/727 >> 2021.8 ms/b | lr: 0.0002168 | grad norm:  7.40 | inf norm:   1.56 | loss: 3.72 | perp:  41.46
#  b 300/727 >> 2029.3 ms/b | lr:  0.000225 | grad norm:  5.65 | inf norm:   1.09 | loss: 3.70 | perp:  40.27
#  b 450/727 >> 2067.7 ms/b | lr:  0.000248 | grad norm:  5.31 | inf norm:   1.06 | loss: 3.72 | perp:  41.42
#  b 600/727 >> 2071.4 ms/b | lr: 0.0002083 | grad norm:  8.62 | inf norm:   2.58 | loss: 3.72 | perp:  41.14
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1485.94 sec | train loss, perp: 3.732,  41.77    | valid loss, perp: 4.227,  68.54
# Grad norm:  7.613 | Grad inf. norm:   1.688 | Max abs param:   4.973
# ============================================================================================================
#
#
# Epoch  13/150) lr = 0.0002451
#  b 150/717 >> 2148.9 ms/b | lr: 0.0002584 | grad norm:  4.29 | inf norm:   0.87 | loss: 3.71 | perp:  40.91
#  b 300/717 >> 2057.7 ms/b | lr: 0.0002002 | grad norm:  7.32 | inf norm:   1.71 | loss: 3.68 | perp:  39.83
#  b 450/717 >> 2121.8 ms/b | lr: 0.0002238 | grad norm:  5.76 | inf norm:  0.655 | loss: 3.70 | perp:  40.49
#  b 600/717 >> 2009.9 ms/b | lr: 0.0002831 | grad norm:  4.27 | inf norm:  0.734 | loss: 3.70 | perp:  40.44
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1490.30 sec | train loss, perp: 3.714,  41.02    | valid loss, perp: 4.193,  66.22
# Grad norm:  5.688 | Grad inf. norm:   1.211 | Max abs param:   4.973
# ============================================================================================================
#
#
# Epoch  14/150) lr = 0.0002362
#  b 150/721 >> 2021.9 ms/b | lr:  0.000249 | grad norm:  5.74 | inf norm:   1.12 | loss: 3.72 | perp:  41.40
#  b 300/721 >> 2125.8 ms/b | lr: 0.0002083 | grad norm:  7.86 | inf norm:   1.35 | loss: 3.68 | perp:  39.61
#  b 450/721 >> 1995.5 ms/b | lr: 0.0002427 | grad norm:  4.94 | inf norm:  0.881 | loss: 3.65 | perp:  38.44
#  b 600/721 >> 2135.8 ms/b | lr: 0.0002362 | grad norm:  6.58 | inf norm:   1.06 | loss: 3.70 | perp:  40.28
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1487.37 sec | train loss, perp: 3.694,  40.21    | valid loss, perp: 4.179,  65.30
# Grad norm:  6.369 | Grad inf. norm:   1.074 | Max abs param:   4.973
# ============================================================================================================
#
#
# Epoch  15/150) lr = 0.0002282
#  b 150/726 >> 2105.4 ms/b | lr: 0.0002465 | grad norm:  5.22 | inf norm:   1.24 | loss: 3.67 | perp:  39.18
#  b 300/726 >> 2008.5 ms/b | lr: 0.0002152 | grad norm:  7.06 | inf norm:   1.26 | loss: 3.63 | perp:  37.86
#  b 450/726 >> 2091.3 ms/b | lr: 0.0002152 | grad norm:  7.35 | inf norm:   1.32 | loss: 3.65 | perp:  38.61
#  b 600/726 >> 2018.9 ms/b | lr: 0.0002282 | grad norm:  6.57 | inf norm:    1.9 | loss: 3.66 | perp:  38.74
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1494.88 sec | train loss, perp: 3.671,  39.31    | valid loss, perp: 4.175,  65.04
# Grad norm:  6.617 | Grad inf. norm:   1.444 | Max abs param:   4.969
# ============================================================================================================
#
#
# Epoch  16/150) lr = 0.000221
#  b 150/718 >> 2032.4 ms/b | lr: 0.0002083 | grad norm:  7.61 | inf norm:   1.96 | loss: 3.64 | perp:  38.00
#  b 300/718 >> 2120.9 ms/b | lr: 0.0002083 | grad norm:  8.80 | inf norm:   1.76 | loss: 3.64 | perp:  38.09
#  b 450/718 >> 2078.3 ms/b | lr:  0.000221 | grad norm:  7.54 | inf norm:   2.13 | loss: 3.65 | perp:  38.54
#  b 600/718 >> 2106.5 ms/b | lr: 0.0002083 | grad norm:  9.76 | inf norm:   2.97 | loss: 3.66 | perp:  38.74
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1497.62 sec | train loss, perp: 3.665,  39.05    | valid loss, perp: 4.169,  64.64
# Grad norm:  7.966 | Grad inf. norm:   1.461 | Max abs param:   4.969
# ============================================================================================================
#
#
# Epoch  17/150) lr = 0.0002144
#  b 150/711 >> 2110.2 ms/b | lr: 0.0002202 | grad norm:  7.54 | inf norm:   1.54 | loss: 3.66 | perp:  38.75
#  b 300/711 >> 1956.9 ms/b | lr:  0.000237 | grad norm:  8.43 | inf norm:    1.2 | loss: 3.62 | perp:  37.39
#  b 450/711 >> 1998.7 ms/b | lr: 0.0001822 | grad norm: 13.80 | inf norm:   2.38 | loss: 3.64 | perp:  37.95
#  b 600/711 >> 1995.6 ms/b | lr: 0.0002202 | grad norm:  7.86 | inf norm:   1.59 | loss: 3.65 | perp:  38.52
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1431.38 sec | train loss, perp: 3.657,  38.75    | valid loss, perp: 4.143,  63.00
# Grad norm:  6.599 | Grad inf. norm:   1.122 | Max abs param:   4.964
# ============================================================================================================
#
#
# Epoch  18/150) lr = 0.0002083
#  b 150/711 >> 2031.3 ms/b | lr: 0.0001964 | grad norm:  9.75 | inf norm:   1.86 | loss: 3.65 | perp:  38.32
#  b 300/711 >> 2024.5 ms/b | lr: 0.0002025 | grad norm:  9.81 | inf norm:   2.18 | loss: 3.62 | perp:  37.25
#  b 450/711 >> 2004.3 ms/b | lr: 0.0001964 | grad norm:  7.80 | inf norm:   1.37 | loss: 3.63 | perp:  37.78
#  b 600/711 >> 1984.5 ms/b | lr: 0.0002025 | grad norm:  8.07 | inf norm:    1.9 | loss: 3.62 | perp:  37.39
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1428.87 sec | train loss, perp: 3.644,  38.23    | valid loss, perp: 4.136,  62.55
# Grad norm:  8.553 | Grad inf. norm:   1.424 | Max abs param:   4.968
# ============================================================================================================
#
#
# Epoch  19/150) lr = 0.0002028
#  b 150/719 >> 1954.0 ms/b | lr: 0.0001851 | grad norm: 10.58 | inf norm:   2.35 | loss: 3.59 | perp:  36.37
#  b 300/719 >> 1960.5 ms/b | lr: 0.0001788 | grad norm: 11.13 | inf norm:   1.54 | loss: 3.59 | perp:  36.22
#  b 450/719 >> 1973.5 ms/b | lr: 0.0001912 | grad norm: 10.19 | inf norm:   2.58 | loss: 3.60 | perp:  36.50
#  b 600/719 >> 2025.5 ms/b | lr: 0.0002137 | grad norm:  9.56 | inf norm:   1.96 | loss: 3.62 | perp:  37.44
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1432.81 sec | train loss, perp: 3.621,  37.37    | valid loss, perp: 4.124,  61.80
# Grad norm: 12.161 | Grad inf. norm:   2.097 | Max abs param:   4.968
# ============================================================================================================
#
#
# Epoch  20/150) lr = 0.0001976
#  b 150/711 >> 1985.9 ms/b | lr: 0.0002234 | grad norm: 14.81 | inf norm:    3.1 | loss: 3.61 | perp:  37.03
#  b 300/711 >> 2111.4 ms/b | lr: 0.0001863 | grad norm:  9.67 | inf norm:   2.18 | loss: 3.62 | perp:  37.22
#  b 450/711 >> 2008.7 ms/b | lr: 0.0001804 | grad norm:  9.96 | inf norm:   1.49 | loss: 3.60 | perp:  36.61
#  b 600/711 >> 1961.4 ms/b | lr: 0.0002083 | grad norm:  8.09 | inf norm:   1.13 | loss: 3.57 | perp:  35.69
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1438.68 sec | train loss, perp: 3.618,  37.26    | valid loss, perp: 4.123,  61.77
# Grad norm: 10.737 | Grad inf. norm:   2.181 | Max abs param:   4.965
# ============================================================================================================
#
#
# Epoch  21/150) lr = 0.0001929
#  b 150/719 >> 2008.2 ms/b | lr: 0.0001639 | grad norm: 17.43 | inf norm:   2.99 | loss: 3.60 | perp:  36.47
#  b 300/719 >> 2011.7 ms/b | lr: 0.0001874 | grad norm:  9.27 | inf norm:    1.4 | loss: 3.59 | perp:  36.13
#  b 450/719 >> 1986.3 ms/b | lr: 0.0001701 | grad norm: 12.30 | inf norm:   3.81 | loss: 3.58 | perp:  35.76
#  b 600/719 >> 1972.5 ms/b | lr: 0.0001874 | grad norm: 10.18 | inf norm:   1.78 | loss: 3.59 | perp:  36.25
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1441.03 sec | train loss, perp: 3.608,  36.88    | valid loss, perp: 4.120,  61.56
# Grad norm: 18.263 | Grad inf. norm:   2.266 | Max abs param:   4.968
# ============================================================================================================
#
#
# Epoch  22/150) lr = 0.0001884
#  b 150/713 >> 2032.8 ms/b | lr: 0.0001831 | grad norm:  8.31 | inf norm:  0.942 | loss: 3.60 | perp:  36.62
#  b 300/713 >> 2064.5 ms/b | lr: 0.0001884 | grad norm: 11.21 | inf norm:   2.46 | loss: 3.58 | perp:  35.73
#  b 450/713 >> 1985.2 ms/b | lr: 0.0001884 | grad norm: 11.07 | inf norm:   1.58 | loss: 3.58 | perp:  35.89
#  b 600/713 >> 2032.9 ms/b | lr:  0.000172 | grad norm: 12.03 | inf norm:   1.88 | loss: 3.59 | perp:  36.38
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1447.05 sec | train loss, perp: 3.602,  36.66    | valid loss, perp: 4.096,  60.12
# Grad norm:  9.053 | Grad inf. norm:   1.268 | Max abs param:   4.969
# ============================================================================================================
#
#
# Epoch  23/150) lr = 0.0001843
#  b 150/718 >> 2042.0 ms/b | lr: 0.0001566 | grad norm: 15.52 | inf norm:   1.67 | loss: 3.58 | perp:  35.93
#  b 300/718 >> 1983.7 ms/b | lr: 0.0001791 | grad norm: 12.32 | inf norm:   2.44 | loss: 3.55 | perp:  34.80
#  b 450/718 >> 2049.5 ms/b | lr: 0.0002038 | grad norm: 12.35 | inf norm:   1.52 | loss: 3.57 | perp:  35.55
#  b 600/718 >> 1997.0 ms/b | lr: 0.0001991 | grad norm: 10.85 | inf norm:   2.76 | loss: 3.57 | perp:  35.40
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1447.09 sec | train loss, perp: 3.582,  35.96    | valid loss, perp: 4.107,  60.77 :(
# Grad norm: 10.845 | Grad inf. norm:   2.199 | Max abs param:   4.969
# ============================================================================================================
#
#
# Epoch  24/150) lr = 0.0001804
#  b 150/714 >> 2019.1 ms/b | lr: 0.0001995 | grad norm: 13.33 | inf norm:   1.49 | loss: 3.57 | perp:  35.44
#  b 300/714 >> 2062.5 ms/b | lr: 0.0001647 | grad norm: 16.15 | inf norm:   1.81 | loss: 3.56 | perp:  35.17
#  b 450/714 >> 2059.7 ms/b | lr: 0.0001591 | grad norm: 11.71 | inf norm:   1.56 | loss: 3.57 | perp:  35.42
#  b 600/714 >> 2094.0 ms/b | lr: 0.0002126 | grad norm: 12.81 | inf norm:   0.98 | loss: 3.58 | perp:  36.04
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1461.20 sec | train loss, perp: 3.584,  36.00 :( | valid loss, perp: 4.096,  60.09
# Grad norm:  9.864 | Grad inf. norm:   2.217 | Max abs param:   4.967
# ============================================================================================================
#
#
# Epoch  25/150) lr = 0.0001768
#  b 150/719 >> 2084.0 ms/b | lr: 0.0001768 | grad norm:  9.21 | inf norm:  0.974 | loss: 3.57 | perp:  35.64
#  b 300/719 >> 2015.7 ms/b | lr: 0.0001816 | grad norm: 10.54 | inf norm:   1.36 | loss: 3.54 | perp:  34.55
#  b 450/719 >> 2107.6 ms/b | lr: 0.0001614 | grad norm: 14.78 | inf norm:   2.71 | loss: 3.57 | perp:  35.69
#  b 600/719 >> 1995.1 ms/b | lr: 0.0001667 | grad norm: 14.62 | inf norm:   2.57 | loss: 3.54 | perp:  34.44
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1469.52 sec | train loss, perp: 3.566,  35.38    | valid loss, perp: 4.093,  59.90
# Grad norm: 10.143 | Grad inf. norm:   1.812 | Max abs param:   4.966
# ============================================================================================================
#
#
# Epoch  26/150) lr = 0.0001733
#  b 150/722 >> 2068.9 ms/b | lr: 0.0001473 | grad norm: 19.72 | inf norm:   2.11 | loss: 3.56 | perp:  35.02
#  b 300/722 >> 2019.6 ms/b | lr: 0.0001634 | grad norm: 13.81 | inf norm:   2.51 | loss: 3.52 | perp:  33.91
#  b 450/722 >> 1996.5 ms/b | lr: 0.0001685 | grad norm: 11.42 | inf norm:   1.69 | loss: 3.53 | perp:  34.14
#  b 600/722 >> 2050.3 ms/b | lr: 0.0001685 | grad norm: 14.46 | inf norm:   1.52 | loss: 3.56 | perp:  35.19
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1471.56 sec | train loss, perp: 3.559,  35.12    | valid loss, perp: 4.077,  58.99
# Grad norm: 12.897 | Grad inf. norm:   1.574 | Max abs param:    4.96
# ============================================================================================================
#
#
# Epoch  27/150) lr = 0.0001701
#  b 150/717 >> 2066.1 ms/b | lr: 0.0001653 | grad norm: 15.28 | inf norm:    5.5 | loss: 3.56 | perp:  35.04
#  b 300/717 >> 2082.5 ms/b | lr: 0.0001653 | grad norm: 10.65 | inf norm:   1.36 | loss: 3.53 | perp:  34.15
#  b 450/717 >> 2054.1 ms/b | lr: 0.0001701 | grad norm: 13.42 | inf norm:   2.35 | loss: 3.54 | perp:  34.47
#  b 600/717 >> 2044.8 ms/b | lr: 0.0001604 | grad norm: 16.31 | inf norm:   2.26 | loss: 3.53 | perp:  34.21
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1474.38 sec | train loss, perp: 3.553,  34.90    | valid loss, perp: 4.082,  59.24 :(
# Grad norm: 13.774 | Grad inf. norm:    3.25 | Max abs param:    4.96
# ============================================================================================================
#
#
# Epoch  28/150) lr = 0.000167
#  b 150/718 >> 2080.3 ms/b | lr: 0.0001623 | grad norm: 10.90 | inf norm:   1.42 | loss: 3.55 | perp:  34.95
#  b 300/718 >> 2100.1 ms/b | lr: 0.0001623 | grad norm: 13.58 | inf norm:   2.28 | loss: 3.56 | perp:  35.06
#  b 450/718 >> 2060.7 ms/b | lr:  0.000167 | grad norm: 12.20 | inf norm:   1.73 | loss: 3.53 | perp:  34.04
#  b 600/718 >> 2097.3 ms/b | lr: 0.0001716 | grad norm: 17.64 | inf norm:   1.87 | loss: 3.54 | perp:  34.39
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1489.40 sec | train loss, perp: 3.556,  35.02 :( | valid loss, perp: 4.061,  58.04
# Grad norm: 11.255 | Grad inf. norm:   1.018 | Max abs param:   4.961
# ============================================================================================================
#
#
# Epoch  29/150) lr = 0.0001641
#  b 150/724 >> 2096.3 ms/b | lr: 0.0001448 | grad norm: 17.56 | inf norm:   1.92 | loss: 3.54 | perp:  34.46
#  b 300/724 >> 2047.2 ms/b | lr: 0.0001395 | grad norm: 20.88 | inf norm:   3.04 | loss: 3.52 | perp:  33.64
#  b 450/724 >> 2043.6 ms/b | lr: 0.0001895 | grad norm: 15.09 | inf norm:   1.25 | loss: 3.53 | perp:  34.10
#  b 600/724 >> 2103.1 ms/b | lr: 0.0001686 | grad norm: 13.75 | inf norm:   2.48 | loss: 3.54 | perp:  34.38
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1497.02 sec | train loss, perp: 3.539,  34.42    | valid loss, perp: 4.060,  57.95
# Grad norm: 13.824 | Grad inf. norm:   2.236 | Max abs param:   4.959
# ============================================================================================================
#
#
# Epoch  30/150) lr = 0.0001614
#  b 150/724 >> 2081.6 ms/b | lr: 0.0001521 | grad norm: 14.67 | inf norm:   2.18 | loss: 3.53 | perp:  34.23
#  b 300/724 >> 2097.4 ms/b | lr: 0.0001521 | grad norm: 12.28 | inf norm:   1.67 | loss: 3.51 | perp:  33.39
#  b 450/724 >> 2078.3 ms/b | lr: 0.0001701 | grad norm: 12.13 | inf norm:   1.79 | loss: 3.51 | perp:  33.40
#  b 600/724 >> 2078.8 ms/b | lr: 0.0001423 | grad norm: 14.92 | inf norm:    2.6 | loss: 3.51 | perp:  33.43
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1508.04 sec | train loss, perp: 3.531,  34.15    | valid loss, perp: 4.057,  57.79
# Grad norm: 18.678 | Grad inf. norm:   1.844 | Max abs param:   4.958
# ============================================================================================================
#
#
# Epoch  31/150) lr = 0.0001588
#  b 150/722 >> 2097.8 ms/b | lr: 0.0001588 | grad norm: 14.49 | inf norm:   2.46 | loss: 3.54 | perp:  34.40
#  b 300/722 >> 2091.8 ms/b | lr: 0.0001588 | grad norm: 11.60 | inf norm:   1.22 | loss: 3.52 | perp:  33.63
#  b 450/722 >> 2144.4 ms/b | lr: 0.0001755 | grad norm: 16.80 | inf norm:   2.18 | loss: 3.51 | perp:  33.61
#  b 600/722 >> 2106.4 ms/b | lr:   0.00014 | grad norm: 18.43 | inf norm:   3.82 | loss: 3.51 | perp:  33.53
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1520.86 sec | train loss, perp: 3.534,  34.25 :( | valid loss, perp: 4.051,  57.48
# Grad norm: 23.910 | Grad inf. norm:   6.443 | Max abs param:   4.959
# ============================================================================================================
#
#
# Epoch  32/150) lr = 0.0001563
#  b 150/719 >> 2129.3 ms/b | lr: 0.0001518 | grad norm: 12.41 | inf norm:   1.57 | loss: 3.55 | perp:  34.69
#  b 300/719 >> 2141.1 ms/b | lr: 0.0001727 | grad norm: 16.97 | inf norm:   1.77 | loss: 3.51 | perp:  33.60
#  b 450/719 >> 2110.1 ms/b | lr: 0.0001727 | grad norm: 25.96 | inf norm:   2.13 | loss: 3.51 | perp:  33.43
#  b 600/719 >> 2147.1 ms/b | lr: 0.0001727 | grad norm: 15.14 | inf norm:   1.77 | loss: 3.52 | perp:  33.70
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1522.72 sec | train loss, perp: 3.535,  34.29 :( | valid loss, perp: 4.050,  57.38
# Grad norm: 17.302 | Grad inf. norm:   2.026 | Max abs param:   4.957
# ============================================================================================================
#
#
# Epoch  33/150) lr = 0.0001539
#  b 150/717 >> 2148.2 ms/b | lr: 0.0001701 | grad norm: 13.56 | inf norm:   2.55 | loss: 3.52 | perp:  33.76
#  b 300/717 >> 2123.6 ms/b | lr: 0.0001495 | grad norm: 12.84 | inf norm:   1.12 | loss: 3.50 | perp:  33.18
#  b 450/717 >> 2141.7 ms/b | lr: 0.0001581 | grad norm: 17.06 | inf norm:   1.45 | loss: 3.52 | perp:  33.62
#  b 600/717 >> 2120.4 ms/b | lr: 0.0001622 | grad norm: 12.44 | inf norm:   1.99 | loss: 3.51 | perp:  33.60
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1523.73 sec | train loss, perp: 3.525,  33.97    | valid loss, perp: 4.047,  57.21
# Grad norm: 32.032 | Grad inf. norm:   3.818 | Max abs param:   4.957
# ============================================================================================================
#
#
# Epoch  34/150) lr = 0.0001516
#  b 150/723 >> 2129.0 ms/b | lr: 0.0001557 | grad norm: 12.12 | inf norm:   1.69 | loss: 3.53 | perp:  34.14
#  b 300/723 >> 2081.3 ms/b | lr: 0.0001238 | grad norm: 43.23 | inf norm:   4.06 | loss: 3.49 | perp:  32.83
#  b 450/723 >> 2096.8 ms/b | lr: 0.0001429 | grad norm: 18.30 | inf norm:    2.6 | loss: 3.50 | perp:  33.00
#  b 600/723 >> 2082.1 ms/b | lr: 0.0001598 | grad norm: 14.12 | inf norm:   1.79 | loss: 3.50 | perp:  33.26
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1516.45 sec | train loss, perp: 3.517,  33.69    | valid loss, perp: 4.042,  56.95
# Grad norm: 13.014 | Grad inf. norm:   1.284 | Max abs param:   4.957
# ============================================================================================================
#
#
# Epoch  35/150) lr = 0.0001494
#  b 150/714 >> 2167.0 ms/b | lr: 0.0001318 | grad norm: 20.29 | inf norm:   1.69 | loss: 3.51 | perp:  33.61
#  b 300/714 >> 2384.8 ms/b | lr: 0.0001409 | grad norm: 15.92 | inf norm:   2.03 | loss: 3.49 | perp:  32.74
#  b 450/714 >> 2390.6 ms/b | lr: 0.0001535 | grad norm: 13.63 | inf norm:   1.91 | loss: 3.51 | perp:  33.33
#  b 600/714 >> 2357.2 ms/b | lr: 0.0001575 | grad norm: 13.62 | inf norm:   1.36 | loss: 3.51 | perp:  33.55
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1653.75 sec | train loss, perp: 3.517,  33.67    | valid loss, perp: 4.046,  57.18 :(
# Grad norm: 26.399 | Grad inf. norm:   2.262 | Max abs param:   4.957
# ============================================================================================================
#
#
# Epoch  36/150) lr = 0.0001473
#  b 150/721 >> 2225.1 ms/b | lr: 0.0001432 | grad norm: 15.78 | inf norm:   1.77 | loss: 3.50 | perp:  32.96
#  b 300/721 >> 2300.3 ms/b | lr: 0.0001389 | grad norm: 15.36 | inf norm:   1.81 | loss: 3.49 | perp:  32.92
#  b 450/721 >> 2179.5 ms/b | lr: 0.0001389 | grad norm: 18.41 | inf norm:   2.06 | loss: 3.48 | perp:  32.44
#  b 600/721 >> 2238.4 ms/b | lr: 0.0001389 | grad norm: 28.88 | inf norm:   4.14 | loss: 3.50 | perp:  33.08
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1611.28 sec | train loss, perp: 3.506,  33.33    | valid loss, perp: 4.036,  56.59
# Grad norm: 20.610 | Grad inf. norm:   2.617 | Max abs param:   4.957
# ============================================================================================================
#
#
# Epoch  37/150) lr = 0.0001453
#  b 150/725 >> 2266.4 ms/b | lr: 0.0001532 | grad norm: 18.67 | inf norm:   1.79 | loss: 3.52 | perp:  33.94
#  b 300/725 >> 2232.3 ms/b | lr: 0.0001412 | grad norm: 15.53 | inf norm:   2.59 | loss: 3.49 | perp:  32.62
#  b 450/725 >> 2195.3 ms/b | lr: 0.0001412 | grad norm: 14.12 | inf norm:   2.05 | loss: 3.47 | perp:  32.22
#  b 600/725 >> 2179.9 ms/b | lr: 0.0001412 | grad norm: 19.67 | inf norm:   1.77 | loss: 3.47 | perp:  31.98
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1612.48 sec | train loss, perp: 3.502,  33.17    | valid loss, perp: 4.031,  56.33
# Grad norm: 25.991 | Grad inf. norm:   3.058 | Max abs param:    4.96
# ============================================================================================================
#
#
# Epoch  38/150) lr = 0.0001434
#  b 150/715 >> 2331.1 ms/b | lr: 0.0001434 | grad norm: 16.56 | inf norm:   3.15 | loss: 3.51 | perp:  33.44
#  b 300/715 >> 2259.8 ms/b | lr: 0.0001352 | grad norm: 14.73 | inf norm:   1.48 | loss: 3.49 | perp:  32.80
#  b 450/715 >> 2210.2 ms/b | lr: 0.0001434 | grad norm: 15.67 | inf norm:   1.61 | loss: 3.48 | perp:  32.39
#  b 600/715 >> 2278.1 ms/b | lr: 0.0001549 | grad norm: 23.74 | inf norm:   1.73 | loss: 3.48 | perp:  32.56
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1618.46 sec | train loss, perp: 3.500,  33.12    | valid loss, perp: 4.029,  56.18
# Grad norm: 13.841 | Grad inf. norm:   1.801 | Max abs param:   4.958
# ============================================================================================================
#
#
# Epoch  39/150) lr = 0.0001415
#  b 150/712 >> 2317.9 ms/b | lr: 0.0001334 | grad norm: 14.35 | inf norm:   1.64 | loss: 3.51 | perp:  33.45
#  b 300/712 >> 2219.6 ms/b | lr: 0.0001375 | grad norm: 15.64 | inf norm:   1.76 | loss: 3.48 | perp:  32.38
#  b 450/712 >> 2321.7 ms/b | lr: 0.0001492 | grad norm: 16.01 | inf norm:   2.05 | loss: 3.47 | perp:  32.25
#  b 600/712 >> 2240.6 ms/b | lr: 0.0001055 | grad norm: 46.14 | inf norm:   3.38 | loss: 3.49 | perp:  32.66
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1620.12 sec | train loss, perp: 3.502,  33.17 :( | valid loss, perp: 4.023,  55.87
# Grad norm: 18.129 | Grad inf. norm:   2.201 | Max abs param:   4.961
# ============================================================================================================
#
#
# Epoch  40/150) lr = 0.0001398
#  b 150/720 >> 2181.7 ms/b | lr: 0.0001318 | grad norm: 16.23 | inf norm:   1.95 | loss: 3.48 | perp:  32.31
#  b 300/720 >> 2248.3 ms/b | lr: 0.0001473 | grad norm: 17.32 | inf norm:   1.44 | loss: 3.48 | perp:  32.43
#  b 450/720 >> 2172.8 ms/b | lr: 0.0001473 | grad norm: 13.42 | inf norm:   1.28 | loss: 3.47 | perp:  32.01
#  b 600/720 >> 2249.2 ms/b | lr: 0.0001473 | grad norm: 19.74 | inf norm:   2.74 | loss: 3.48 | perp:  32.37
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1596.91 sec | train loss, perp: 3.489,  32.77    | valid loss, perp: 4.027,  56.09 :(
# Grad norm: 15.887 | Grad inf. norm:   1.485 | Max abs param:   4.963
# ============================================================================================================
#
#
# Epoch  41/150) lr = 0.000138
#  b 150/712 >> 2235.3 ms/b | lr: 0.0001342 | grad norm: 19.34 | inf norm:    2.9 | loss: 3.48 | perp:  32.43
#  b 300/712 >> 2278.3 ms/b | lr:  0.000138 | grad norm: 14.04 | inf norm:   1.81 | loss: 3.47 | perp:  32.15
#  b 450/712 >> 2262.5 ms/b | lr: 0.0001301 | grad norm: 20.43 | inf norm:   1.79 | loss: 3.48 | perp:  32.32
#  b 600/712 >> 2329.2 ms/b | lr: 0.0001301 | grad norm: 23.26 | inf norm:    2.4 | loss: 3.49 | perp:  32.70
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1617.31 sec | train loss, perp: 3.491,  32.83 :( | valid loss, perp: 4.049,  57.35 :(
# Grad norm: 21.525 | Grad inf. norm:   3.654 | Max abs param:   4.962
# ============================================================================================================
#
#
# Epoch  42/150) lr = 0.0001364
#  b 150/718 >> 2263.2 ms/b | lr: 0.0001438 | grad norm: 14.51 | inf norm:   1.96 | loss: 3.49 | perp:  32.74
#  b 300/718 >> 2225.3 ms/b | lr: 0.0001364 | grad norm: 18.03 | inf norm:   2.37 | loss: 3.48 | perp:  32.42
#  b 450/718 >> 2289.8 ms/b | lr: 0.0001325 | grad norm: 21.54 | inf norm:   1.96 | loss: 3.47 | perp:  32.15
#  b 600/718 >> 2283.0 ms/b | lr: 0.0001245 | grad norm: 23.25 | inf norm:   3.19 | loss: 3.49 | perp:  32.65
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1632.62 sec | train loss, perp: 3.492,  32.86 :( | valid loss, perp: 4.017,  55.56
# Grad norm: 15.000 | Grad inf. norm:    1.45 | Max abs param:   4.966
# ============================================================================================================
#
#
# Epoch  43/150) lr = 0.0001348
#  b 150/726 >> 2249.6 ms/b | lr:  0.000149 | grad norm: 16.31 | inf norm:   1.29 | loss: 3.47 | perp:  32.09
#  b 300/726 >> 2206.7 ms/b | lr:  0.000149 | grad norm: 21.76 | inf norm:   2.56 | loss: 3.45 | perp:  31.51
#  b 450/726 >> 2259.6 ms/b | lr: 0.0001456 | grad norm: 23.12 | inf norm:   1.72 | loss: 3.47 | perp:  32.26
#  b 600/726 >> 2243.1 ms/b | lr: 0.0001421 | grad norm: 18.50 | inf norm:   2.29 | loss: 3.48 | perp:  32.42
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1628.95 sec | train loss, perp: 3.478,  32.41    | valid loss, perp: 4.023,  55.85 :(
# Grad norm: 23.871 | Grad inf. norm:   2.869 | Max abs param:   4.968
# ============================================================================================================
#
#
# Epoch  44/150) lr = 0.0001333
#  b 150/721 >> 2234.5 ms/b | lr: 0.0001405 | grad norm: 15.09 | inf norm:   1.93 | loss: 3.47 | perp:  32.17
#  b 300/721 >> 2286.1 ms/b | lr: 0.0001333 | grad norm: 18.23 | inf norm:   1.58 | loss: 3.46 | perp:  31.73
#  b 450/721 >> 2272.2 ms/b | lr: 0.0001333 | grad norm: 14.45 | inf norm:   1.27 | loss: 3.46 | perp:  31.70
#  b 600/721 >> 2267.4 ms/b | lr: 0.0001175 | grad norm: 20.17 | inf norm:   2.85 | loss: 3.47 | perp:  31.98
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1632.26 sec | train loss, perp: 3.476,  32.33    | valid loss, perp: 4.023,  55.86 :(
# Grad norm: 27.334 | Grad inf. norm:   2.303 | Max abs param:   4.965
# ============================================================================================================
#
#
# Epoch  45/150) lr = 0.0001318
#  b 150/717 >> 2276.2 ms/b | lr: 0.0001203 | grad norm: 33.49 | inf norm:   2.87 | loss: 3.48 | perp:  32.59
#  b 300/717 >> 2334.9 ms/b | lr: 0.0001354 | grad norm: 17.97 | inf norm:    1.7 | loss: 3.47 | perp:  32.09
#  b 450/717 >> 2251.3 ms/b | lr: 0.0001318 | grad norm: 51.52 | inf norm:   4.08 | loss: 3.46 | perp:  31.70
#  b 600/717 >> 2309.2 ms/b | lr: 0.0001318 | grad norm: 18.61 | inf norm:   1.78 | loss: 3.47 | perp:  31.99
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1637.71 sec | train loss, perp: 3.480,  32.45 :( | valid loss, perp: 4.016,  55.45
# Grad norm: 14.392 | Grad inf. norm:   1.626 | Max abs param:   4.963
# ============================================================================================================
#
#
# Epoch  46/150) lr = 0.0001303
#  b 150/713 >> 2329.8 ms/b | lr: 0.0001374 | grad norm: 15.70 | inf norm:   2.51 | loss: 3.47 | perp:  32.27
#  b 300/713 >> 2231.5 ms/b | lr: 0.0001339 | grad norm: 23.47 | inf norm:   2.91 | loss: 3.45 | perp:  31.48
#  b 450/713 >> 2308.7 ms/b | lr: 0.0001408 | grad norm: 30.23 | inf norm:   2.33 | loss: 3.46 | perp:  31.66
#  b 600/713 >> 2364.1 ms/b | lr: 0.0001266 | grad norm: 20.33 | inf norm:   2.09 | loss: 3.47 | perp:  32.28
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1640.77 sec | train loss, perp: 3.476,  32.32    | valid loss, perp: 4.006,  54.93
# Grad norm: 16.237 | Grad inf. norm:   1.561 | Max abs param:   4.962
# ============================================================================================================
#
#
# Epoch  47/150) lr = 0.0001289
#  b 150/718 >> 2300.1 ms/b | lr: 0.0001253 | grad norm: 16.03 | inf norm:   1.45 | loss: 3.47 | perp:  32.06
#  b 300/718 >> 2234.5 ms/b | lr: 0.0001096 | grad norm: 21.52 | inf norm:   1.81 | loss: 3.44 | perp:  31.28
#  b 450/718 >> 2373.7 ms/b | lr: 0.0001177 | grad norm: 24.91 | inf norm:    2.7 | loss: 3.47 | perp:  32.23
#  b 600/718 >> 2203.3 ms/b | lr: 0.0001325 | grad norm: 14.26 | inf norm:   1.49 | loss: 3.43 | perp:  31.03
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1629.79 sec | train loss, perp: 3.467,  32.06    | valid loss, perp: 4.029,  56.20 :(
# Grad norm: 34.095 | Grad inf. norm:   2.495 | Max abs param:   4.964
# ============================================================================================================
#
#
# Epoch  48/150) lr = 0.0001276
#  b 150/724 >> 2211.6 ms/b | lr: 0.0001203 | grad norm: 17.55 | inf norm:   1.74 | loss: 3.46 | perp:  31.95
#  b 300/724 >> 2214.0 ms/b | lr: 0.0001276 | grad norm: 17.40 | inf norm:   2.05 | loss: 3.43 | perp:  30.84
#  b 450/724 >> 2223.6 ms/b | lr: 0.0001203 | grad norm: 19.30 | inf norm:   2.71 | loss: 3.45 | perp:  31.49
#  b 600/724 >> 2279.2 ms/b | lr:  0.000124 | grad norm: 22.55 | inf norm:    3.3 | loss: 3.45 | perp:  31.62
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1621.18 sec | train loss, perp: 3.462,  31.89    | valid loss, perp: 4.019,  55.64 :(
# Grad norm: 26.427 | Grad inf. norm:   3.143 | Max abs param:   4.968
# ============================================================================================================
#
#
# Epoch  49/150) lr = 0.0001263
#  b 150/713 >> 2248.9 ms/b | lr: 0.0001263 | grad norm: 15.62 | inf norm:   1.22 | loss: 3.47 | perp:  32.19
#  b 300/713 >> 2280.5 ms/b | lr: 0.0001227 | grad norm: 18.31 | inf norm:   1.83 | loss: 3.44 | perp:  31.21
#  b 450/713 >> 2298.6 ms/b | lr: 0.0001263 | grad norm: 14.63 | inf norm:    2.2 | loss: 3.46 | perp:  31.96
#  b 600/713 >> 2292.6 ms/b | lr: 0.0001364 | grad norm: 26.77 | inf norm:   1.81 | loss: 3.46 | perp:  31.78
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1625.26 sec | train loss, perp: 3.472,  32.21 :( | valid loss, perp: 4.000,  54.59
# Grad norm: 19.534 | Grad inf. norm:   1.808 | Max abs param:   4.968
# ============================================================================================================
#
#
# Epoch  50/150) lr = 0.000125
#  b 150/719 >> 2235.9 ms/b | lr: 0.0001284 | grad norm: 15.58 | inf norm:   2.25 | loss: 3.46 | perp:  31.81
#  b 300/719 >> 2257.5 ms/b | lr: 0.0001021 | grad norm: 37.49 | inf norm:   3.95 | loss: 3.43 | perp:  30.78
#  b 450/719 >> 2266.8 ms/b | lr: 0.0001284 | grad norm: 16.97 | inf norm:    1.9 | loss: 3.45 | perp:  31.56
#  b 600/719 >> 2268.1 ms/b | lr: 0.0001318 | grad norm: 17.63 | inf norm:   1.87 | loss: 3.44 | perp:  31.28
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1620.33 sec | train loss, perp: 3.456,  31.68    | valid loss, perp: 4.007,  54.99 :(
# Grad norm: 27.144 | Grad inf. norm:   2.183 | Max abs param:   4.967
# ============================================================================================================
#
#
# Epoch  51/150) lr = 0.0001238
#  b 150/716 >> 2292.0 ms/b | lr: 0.0001272 | grad norm: 36.56 | inf norm:   2.54 | loss: 3.47 | perp:  32.29
#  b 300/716 >> 2220.7 ms/b | lr: 0.0001011 | grad norm: 27.30 | inf norm:   2.63 | loss: 3.44 | perp:  31.27
#  b 450/716 >> 2300.8 ms/b | lr: 0.0001238 | grad norm: 19.92 | inf norm:   2.29 | loss: 3.45 | perp:  31.44
#  b 600/716 >> 2191.7 ms/b | lr: 0.0001203 | grad norm: 17.48 | inf norm:    2.2 | loss: 3.43 | perp:  30.79
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1619.13 sec | train loss, perp: 3.461,  31.85 :( | valid loss, perp: 4.003,  54.78 :(
# Grad norm: 17.985 | Grad inf. norm:   2.979 | Max abs param:   4.967
# ============================================================================================================
#
#
# Epoch  52/150) lr = 0.0001226
#  b 150/714 >> 2231.0 ms/b | lr: 0.0001156 | grad norm: 20.14 | inf norm:   2.14 | loss: 3.45 | perp:  31.44
#  b 300/714 >> 2255.5 ms/b | lr: 0.0001226 | grad norm: 18.51 | inf norm:   2.26 | loss: 3.44 | perp:  31.21
#  b 450/714 >> 2337.6 ms/b | lr: 0.0001355 | grad norm: 19.91 | inf norm:    1.7 | loss: 3.44 | perp:  31.32
#  b 600/714 >> 2244.1 ms/b | lr: 0.0001001 | grad norm: 29.50 | inf norm:   3.03 | loss: 3.44 | perp:  31.19
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1625.35 sec | train loss, perp: 3.459,  31.78 :( | valid loss, perp: 3.995,  54.32
# Grad norm: 23.380 | Grad inf. norm:   1.774 | Max abs param:    4.97
# ============================================================================================================
#
#
# Epoch  53/150) lr = 0.0001214
#  b 150/719 >> 2188.7 ms/b | lr: 0.0001214 | grad norm: 26.74 | inf norm:   3.88 | loss: 3.44 | perp:  31.23
#  b 300/719 >> 2317.5 ms/b | lr: 0.0001108 | grad norm: 19.22 | inf norm:    1.8 | loss: 3.43 | perp:  30.95
#  b 450/719 >> 2389.6 ms/b | lr: 0.0001487 | grad norm: 25.88 | inf norm:   2.98 | loss: 3.44 | perp:  31.32
#  b 600/719 >> 2443.8 ms/b | lr: 0.0001214 | grad norm: 17.80 | inf norm:   1.86 | loss: 3.45 | perp:  31.48
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1682.40 sec | train loss, perp: 3.453,  31.59    | valid loss, perp: 3.986,  53.83
# Grad norm: 26.299 | Grad inf. norm:   1.974 | Max abs param:    4.97
# ============================================================================================================
#
#
# Epoch  54/150) lr = 0.0001203
#  b 150/722 >> 2291.8 ms/b | lr: 8.965e-05 | grad norm: 37.57 | inf norm:   3.23 | loss: 3.43 | perp:  31.00
#  b 300/722 >> 2369.0 ms/b | lr: 0.0001203 | grad norm: 17.01 | inf norm:   1.69 | loss: 3.43 | perp:  30.91
#  b 450/722 >> 2344.0 ms/b | lr: 0.0001203 | grad norm: 18.64 | inf norm:   1.71 | loss: 3.48 | perp:  32.47
#  b 600/722 >> 2377.0 ms/b | lr: 0.0001389 | grad norm: 24.07 | inf norm:   2.42 | loss: 3.44 | perp:  31.29
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1704.85 sec | train loss, perp: 3.455,  31.66 :( | valid loss, perp: 3.995,  54.30 :(
# Grad norm: 33.560 | Grad inf. norm:   7.181 | Max abs param:   4.972
# ============================================================================================================
#
#
# Epoch  55/150) lr = 0.0001192
#  b 150/716 >> 2483.8 ms/b | lr: 0.0001224 | grad norm: 60.42 | inf norm:   3.77 | loss: 3.45 | perp:  31.48
#  b 300/716 >> 2427.0 ms/b | lr: 0.0001192 | grad norm: 25.13 | inf norm:   2.69 | loss: 3.43 | perp:  30.81
#  b 450/716 >> 2311.3 ms/b | lr: 0.0001124 | grad norm: 20.54 | inf norm:   1.74 | loss: 3.42 | perp:  30.68
#  b 600/716 >> 2540.6 ms/b | lr: 0.0001224 | grad norm: 20.47 | inf norm:   2.67 | loss: 3.44 | perp:  31.17
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1734.35 sec | train loss, perp: 3.451,  31.54    | valid loss, perp: 4.000,  54.59 :(
# Grad norm: 23.550 | Grad inf. norm:   3.126 | Max abs param:   4.969
# ============================================================================================================
#
#
# Epoch  56/150) lr = 0.0001181
#  b 150/716 >> 2271.3 ms/b | lr: 0.0001148 | grad norm: 17.13 | inf norm:   1.34 | loss: 3.45 | perp:  31.44
#  b 300/716 >> 2278.3 ms/b | lr: 0.0001114 | grad norm: 17.02 | inf norm:   1.62 | loss: 3.42 | perp:  30.65
#  b 450/716 >> 2263.8 ms/b | lr: 0.0001181 | grad norm: 23.05 | inf norm:   2.23 | loss: 3.44 | perp:  31.18
#  b 600/716 >> 2294.6 ms/b | lr: 0.0001214 | grad norm: 18.58 | inf norm:   2.27 | loss: 3.43 | perp:  30.90
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1617.60 sec | train loss, perp: 3.444,  31.30    | valid loss, perp: 3.985,  53.77
# Grad norm: 21.617 | Grad inf. norm:   1.815 | Max abs param:   4.972
# ============================================================================================================
#
#
# Epoch  57/150) lr = 0.0001171
#  b 150/710 >> 2299.8 ms/b | lr: 0.0001265 | grad norm: 24.94 | inf norm:   1.94 | loss: 3.45 | perp:  31.62
#  b 300/710 >> 2269.0 ms/b | lr: 0.0001138 | grad norm: 29.69 | inf norm:   2.05 | loss: 3.43 | perp:  30.95
# ...
#  b 450/715 >> 2049.1 ms/b | lr: 7.693e-05 | grad norm: 73.26 | inf norm:   5.91 | loss: 3.34 | perp:  28.28
#  b 600/715 >> 2079.8 ms/b | lr: 7.253e-05 | grad norm: 42.32 | inf norm:   5.37 | loss: 3.35 | perp:  28.42
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1463.92 sec | train loss, perp: 3.361,  28.83 :( | valid loss, perp: 3.920,  50.41 :(
# Grad norm: 43.255 | Grad inf. norm:   3.981 | Max abs param:   4.982
# ============================================================================================================
#
#
# Epoch 133/150) lr = 7.664e-05
#  b 150/722 >> 2033.0 ms/b | lr: 7.874e-05 | grad norm: 39.59 | inf norm:   3.58 | loss: 3.36 | perp:  28.83
#  b 300/722 >> 2110.4 ms/b | lr: 7.874e-05 | grad norm: 36.29 | inf norm:   4.18 | loss: 3.34 | perp:  28.32
#  b 450/722 >> 2005.6 ms/b | lr: 7.664e-05 | grad norm: 31.00 | inf norm:   3.47 | loss: 3.32 | perp:  27.70
#  b 600/722 >> 2001.6 ms/b | lr: 7.664e-05 | grad norm: 33.13 | inf norm:   4.83 | loss: 3.34 | perp:  28.25
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1465.40 sec | train loss, perp: 3.353,  28.60    | valid loss, perp: 3.926,  50.69 :(
# Grad norm: 38.741 | Grad inf. norm:   3.699 | Max abs param:   4.983
# ============================================================================================================
#
#
# Epoch 134/150) lr = 7.636e-05
#  b 150/725 >> 2051.3 ms/b | lr: 7.636e-05 | grad norm: 28.81 | inf norm:   4.26 | loss: 3.37 | perp:  29.09
#  b 300/725 >> 1951.2 ms/b | lr: 8.441e-05 | grad norm: 35.69 | inf norm:   3.89 | loss: 3.32 | perp:  27.73
#  b 450/725 >> 1998.2 ms/b | lr: 7.636e-05 | grad norm: 48.40 | inf norm:   8.07 | loss: 3.34 | perp:  28.17
#  b 600/725 >> 1959.9 ms/b | lr: 8.247e-05 | grad norm: 32.53 | inf norm:    3.9 | loss: 3.32 | perp:  27.76
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1438.26 sec | train loss, perp: 3.349,  28.48    | valid loss, perp: 3.933,  51.04 :(
# Grad norm: 41.337 | Grad inf. norm:   4.934 | Max abs param:   4.984
# ============================================================================================================
#
#
# Epoch 135/150) lr = 7.607e-05
#  b 150/717 >> 2000.8 ms/b | lr: 7.607e-05 | grad norm: 49.58 | inf norm:   5.56 | loss: 3.35 | perp:  28.56
#  b 300/717 >> 1999.8 ms/b | lr: 8.217e-05 | grad norm: 55.13 | inf norm:   4.97 | loss: 3.33 | perp:  27.84
#  b 450/717 >> 2029.9 ms/b | lr: 7.393e-05 | grad norm: 64.78 | inf norm:   5.97 | loss: 3.35 | perp:  28.40
#  b 600/717 >> 1998.7 ms/b | lr: 6.709e-05 | grad norm: 61.84 | inf norm:   5.88 | loss: 3.34 | perp:  28.12
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1445.27 sec | train loss, perp: 3.355,  28.63 :( | valid loss, perp: 3.918,  50.32
# Grad norm: 37.019 | Grad inf. norm:     5.7 | Max abs param:   4.984
# ============================================================================================================
#
#
# Epoch 136/150) lr = 7.579e-05
#  b 150/715 >> 2068.5 ms/b | lr: 6.441e-05 | grad norm: 42.87 | inf norm:   4.61 | loss: 3.36 | perp:  28.90
#  b 300/715 >> 2021.8 ms/b | lr: 7.787e-05 | grad norm: 31.37 | inf norm:   3.78 | loss: 3.35 | perp:  28.56
#  b 450/715 >> 1976.7 ms/b | lr: 7.579e-05 | grad norm: 33.71 | inf norm:   3.59 | loss: 3.32 | perp:  27.77
#  b 600/715 >> 2022.1 ms/b | lr: 7.146e-05 | grad norm: 64.72 | inf norm:   5.76 | loss: 3.34 | perp:  28.16
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1446.32 sec | train loss, perp: 3.353,  28.59 :( | valid loss, perp: 3.918,  50.29
# Grad norm: 35.823 | Grad inf. norm:   3.955 | Max abs param:   4.984
# ============================================================================================================
#
#
# Epoch 137/150) lr = 7.552e-05
#  b 150/728 >> 1959.8 ms/b | lr: 6.894e-05 | grad norm: 87.51 | inf norm:   7.33 | loss: 3.34 | perp:  28.10
#  b 300/728 >> 1982.9 ms/b | lr: 7.339e-05 | grad norm: 67.92 | inf norm:   6.18 | loss: 3.33 | perp:  28.01
#  b 450/728 >> 2043.0 ms/b | lr: 8.349e-05 | grad norm: 64.87 | inf norm:   5.22 | loss: 3.34 | perp:  28.34
#  b 600/728 >> 1983.1 ms/b | lr: 7.552e-05 | grad norm: 32.67 | inf norm:   4.18 | loss: 3.31 | perp:  27.50
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1443.44 sec | train loss, perp: 3.343,  28.30    | valid loss, perp: 3.931,  50.95 :(
# Grad norm: 39.517 | Grad inf. norm:   4.045 | Max abs param:   4.984
# ============================================================================================================
#
#
# Epoch 138/150) lr = 7.524e-05
#  b 150/723 >> 1993.5 ms/b | lr: 7.524e-05 | grad norm: 47.18 | inf norm:   5.98 | loss: 3.35 | perp:  28.61
#  b 300/723 >> 1979.8 ms/b | lr: 7.312e-05 | grad norm: 49.76 | inf norm:   5.16 | loss: 3.33 | perp:  27.82
#  b 450/723 >> 2009.9 ms/b | lr: 6.636e-05 | grad norm: 65.87 | inf norm:   6.44 | loss: 3.33 | perp:  27.95
#  b 600/723 >> 2018.7 ms/b | lr: 7.312e-05 | grad norm: 40.12 | inf norm:   4.67 | loss: 3.34 | perp:  28.09
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1447.14 sec | train loss, perp: 3.348,  28.44 :( | valid loss, perp: 3.914,  50.12
# Grad norm: 37.998 | Grad inf. norm:   4.686 | Max abs param:   4.984
# ============================================================================================================
#
#
# Epoch 139/150) lr = 7.497e-05
#  b 150/717 >> 2039.5 ms/b | lr: 6.371e-05 | grad norm: 52.97 | inf norm:   5.18 | loss: 3.36 | perp:  28.89
#  b 300/717 >> 1995.0 ms/b | lr: 7.068e-05 | grad norm: 35.12 | inf norm:   5.07 | loss: 3.33 | perp:  27.80
#  b 450/717 >> 2009.3 ms/b | lr: 7.702e-05 | grad norm: 46.34 | inf norm:   4.28 | loss: 3.35 | perp:  28.46
#  b 600/717 >> 2043.9 ms/b | lr: 7.903e-05 | grad norm: 36.08 | inf norm:   4.58 | loss: 3.34 | perp:  28.25
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1448.57 sec | train loss, perp: 3.354,  28.62 :( | valid loss, perp: 3.913,  50.05
# Grad norm: 80.232 | Grad inf. norm:   7.919 | Max abs param:   4.984
# ============================================================================================================
#
#
# Epoch 140/150) lr = 7.47e-05
#  b 150/714 >> 2089.0 ms/b | lr: 8.069e-05 | grad norm: 65.71 | inf norm:   7.41 | loss: 3.37 | perp:  29.07
#  b 300/714 >> 1990.9 ms/b | lr:  7.26e-05 | grad norm: 45.29 | inf norm:   6.27 | loss: 3.33 | perp:  27.88
#  b 450/714 >> 2023.3 ms/b | lr: 8.259e-05 | grad norm: 60.65 | inf norm:   6.35 | loss: 3.33 | perp:  28.00
#  b 600/714 >> 2043.9 ms/b | lr: 6.819e-05 | grad norm: 72.43 | inf norm:   6.34 | loss: 3.34 | perp:  28.12
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1452.13 sec | train loss, perp: 3.353,  28.59 :( | valid loss, perp: 3.916,  50.21 :(
# Grad norm: 43.883 | Grad inf. norm:   4.889 | Max abs param:   4.985
# ============================================================================================================
#
#
# Epoch 141/150) lr = 7.444e-05
#  b 150/712 >> 2036.4 ms/b | lr: 7.018e-05 | grad norm: 64.63 | inf norm:   5.76 | loss: 3.36 | perp:  28.76
#  b 300/712 >> 2010.2 ms/b | lr: 7.234e-05 | grad norm: 46.17 | inf norm:   4.86 | loss: 3.33 | perp:  27.99
#  b 450/712 >> 2038.5 ms/b | lr: 7.018e-05 | grad norm: 49.36 | inf norm:   4.16 | loss: 3.34 | perp:  28.28
#  b 600/712 >> 2086.2 ms/b | lr: 7.648e-05 | grad norm: 49.03 | inf norm:   6.96 | loss: 3.35 | perp:  28.43
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1451.84 sec | train loss, perp: 3.358,  28.74 :( | valid loss, perp: 3.912,  49.99
# Grad norm: 44.516 | Grad inf. norm:    6.73 | Max abs param:   4.988
# ============================================================================================================
#
#
# Epoch 142/150) lr = 7.417e-05
#  b 150/717 >> 2039.4 ms/b | lr: 7.208e-05 | grad norm: 71.38 | inf norm:   6.89 | loss: 3.36 | perp:  28.70
#  b 300/717 >> 2012.3 ms/b | lr: 6.771e-05 | grad norm: 45.42 | inf norm:   4.05 | loss: 3.32 | perp:  27.73
#  b 450/717 >> 2025.3 ms/b | lr:   8.2e-05 | grad norm: 52.15 | inf norm:   5.14 | loss: 3.35 | perp:  28.52
#  b 600/717 >> 2018.5 ms/b | lr: 6.056e-05 | grad norm: 69.58 | inf norm:   7.94 | loss: 3.36 | perp:  28.89
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1454.16 sec | train loss, perp: 3.357,  28.71 :( | valid loss, perp: 3.907,  49.74
# Grad norm: 77.988 | Grad inf. norm:   9.124 | Max abs param:   4.988
# ============================================================================================================
#
#
# Epoch 143/150) lr = 7.391e-05
#  b 150/717 >> 2050.4 ms/b | lr: 6.747e-05 | grad norm: 39.00 | inf norm:   4.12 | loss: 3.36 | perp:  28.66
#  b 300/717 >> 1997.4 ms/b | lr: 6.519e-05 | grad norm: 70.36 | inf norm:   7.39 | loss: 3.33 | perp:  27.90
#  b 450/717 >> 2041.3 ms/b | lr: 7.391e-05 | grad norm: 37.98 | inf norm:   3.99 | loss: 3.34 | perp:  28.12
#  b 600/717 >> 2056.6 ms/b | lr: 7.183e-05 | grad norm: 82.30 | inf norm:   7.57 | loss: 3.34 | perp:  28.22
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1457.21 sec | train loss, perp: 3.356,  28.66 :( | valid loss, perp: 3.914,  50.12 :(
# Grad norm: 35.389 | Grad inf. norm:   4.607 | Max abs param:   4.989
# ============================================================================================================
#
#
# Epoch 144/150) lr = 7.366e-05
#  b 150/719 >> 2024.4 ms/b | lr: 7.956e-05 | grad norm: 99.07 | inf norm:   8.28 | loss: 3.36 | perp:  28.75
#  b 300/719 >> 2019.3 ms/b | lr: 7.568e-05 | grad norm: 90.04 | inf norm:     10 | loss: 3.32 | perp:  27.64
#  b 450/719 >> 2078.1 ms/b | lr: 6.496e-05 | grad norm: 47.77 | inf norm:   5.76 | loss: 3.34 | perp:  28.11
#  b 600/719 >> 1990.7 ms/b | lr: 7.158e-05 | grad norm: 36.43 | inf norm:   3.52 | loss: 3.34 | perp:  28.18
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1459.33 sec | train loss, perp: 3.352,  28.55 :( | valid loss, perp: 3.928,  50.78 :(
# Grad norm: 56.611 | Grad inf. norm:   6.035 | Max abs param:   4.992
# ============================================================================================================
#
#
# Epoch 145/150) lr = 7.34e-05
#  b 150/717 >> 2030.5 ms/b | lr: 6.701e-05 | grad norm: 60.79 | inf norm:   7.45 | loss: 3.35 | perp:  28.63
#  b 300/717 >> 2033.7 ms/b | lr: 7.133e-05 | grad norm: 33.16 | inf norm:   4.44 | loss: 3.33 | perp:  27.96
#  b 450/717 >> 2015.5 ms/b | lr: 7.133e-05 | grad norm: 52.83 | inf norm:   6.27 | loss: 3.31 | perp:  27.43
#  b 600/717 >> 2069.1 ms/b | lr: 5.993e-05 | grad norm: 69.78 | inf norm:   8.44 | loss: 3.34 | perp:  28.23
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1465.98 sec | train loss, perp: 3.348,  28.45 :( | valid loss, perp: 3.914,  50.08 :(
# Grad norm: 31.055 | Grad inf. norm:    3.68 | Max abs param:   4.994
# ============================================================================================================
#
#
# Epoch 146/150) lr = 7.315e-05
#  b 150/718 >> 2085.5 ms/b | lr: 8.269e-05 | grad norm: 39.56 | inf norm:   4.67 | loss: 3.36 | perp:  28.76
#  b 300/718 >> 2070.7 ms/b | lr: 7.711e-05 | grad norm: 47.16 | inf norm:   4.83 | loss: 3.34 | perp:  28.12
#  b 450/718 >> 2002.4 ms/b | lr: 6.897e-05 | grad norm: 39.79 | inf norm:   3.64 | loss: 3.32 | perp:  27.77
#  b 600/718 >> 2030.5 ms/b | lr: 7.516e-05 | grad norm: 39.90 | inf norm:    4.7 | loss: 3.33 | perp:  28.07
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1470.19 sec | train loss, perp: 3.349,  28.47 :( | valid loss, perp: 3.904,  49.61
# Grad norm: 36.113 | Grad inf. norm:   5.062 | Max abs param:   4.995
# ============================================================================================================
#
#
# Epoch 147/150) lr = 7.29e-05
#  b 150/717 >> 2058.2 ms/b | lr:  8.06e-05 | grad norm: 44.86 | inf norm:   5.05 | loss: 3.34 | perp:  28.24
#  b 300/717 >> 2082.0 ms/b | lr:  7.29e-05 | grad norm: 52.83 | inf norm:   6.28 | loss: 3.34 | perp:  28.12
#  b 450/717 >> 2043.7 ms/b | lr:  7.29e-05 | grad norm: 44.14 | inf norm:   4.65 | loss: 3.33 | perp:  27.91
#  b 600/717 >> 2029.1 ms/b | lr:  7.49e-05 | grad norm: 39.40 | inf norm:    4.4 | loss: 3.33 | perp:  27.96
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1488.93 sec | train loss, perp: 3.347,  28.42 :( | valid loss, perp: 3.910,  49.91 :(
# Grad norm: 35.111 | Grad inf. norm:   3.502 | Max abs param:   4.997
# ============================================================================================================
#
#
# Epoch 148/150) lr = 7.265e-05
#  b 150/721 >> 2207.9 ms/b | lr:  6.85e-05 | grad norm: 37.73 | inf norm:    4.8 | loss: 3.35 | perp:  28.63
#  b 300/721 >> 2249.8 ms/b | lr: 7.465e-05 | grad norm: 81.37 | inf norm:   7.29 | loss: 3.34 | perp:  28.25
#  b 450/721 >> 2135.4 ms/b | lr: 7.658e-05 | grad norm: 36.79 | inf norm:   5.61 | loss: 3.32 | perp:  27.73
#  b 600/721 >> 2119.9 ms/b | lr: 7.061e-05 | grad norm: 108.08 | inf norm:   10.6 | loss: 3.32 | perp:  27.64
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1556.65 sec | train loss, perp: 3.346,  28.38 :( | valid loss, perp: 3.905,  49.66 :(
# Grad norm: 40.488 | Grad inf. norm:   6.508 | Max abs param:   4.999
# ============================================================================================================
#
#
# Epoch 149/150) lr = 7.241e-05
#  b 150/713 >> 2161.8 ms/b | lr: 7.037e-05 | grad norm: 34.93 | inf norm:   3.51 | loss: 3.35 | perp:  28.56
#  b 300/713 >> 2161.9 ms/b | lr: 7.821e-05 | grad norm: 50.19 | inf norm:   6.28 | loss: 3.34 | perp:  28.11
#  b 450/713 >> 2114.1 ms/b | lr: 7.439e-05 | grad norm: 33.57 | inf norm:   4.32 | loss: 3.33 | perp:  27.88
#  b 600/713 >> 2210.2 ms/b | lr: 7.241e-05 | grad norm: 34.32 | inf norm:   5.77 | loss: 3.34 | perp:  28.26
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1538.58 sec | train loss, perp: 3.349,  28.48 :( | valid loss, perp: 3.912,  50.00 :(
# Grad norm: 37.609 | Grad inf. norm:   4.068 | Max abs param:   4.998
# ============================================================================================================
#
#
# Epoch 150/150) lr = 7.217e-05
#  b 150/720 >> 2171.7 ms/b | lr: 6.133e-05 | grad norm: 48.98 | inf norm:   5.05 | loss: 3.35 | perp:  28.57
#  b 300/720 >> 2104.9 ms/b | lr: 7.014e-05 | grad norm: 39.84 | inf norm:   4.65 | loss: 3.31 | perp:  27.32
#  b 450/720 >> 2151.8 ms/b | lr: 7.217e-05 | grad norm: 53.11 | inf norm:   4.56 | loss: 3.33 | perp:  28.07
#  b 600/720 >> 2167.4 ms/b | lr: 7.014e-05 | grad norm: 68.90 | inf norm:   8.99 | loss: 3.34 | perp:  28.24
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1537.03 sec | train loss, perp: 3.343,  28.30    | valid loss, perp: 3.925,  50.64 :(
# Grad norm: 38.713 | Grad inf. norm:   4.197 | Max abs param:   4.998
# ============================================================================================================

# %%
CAUSES = ['output', 'grad']
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    _states = states
    if model.n_enc_layers > 0:
        enc_states = states[0]
        states = states[1:]
    if model.n_dec_layers > 0:
        dec_states = states[-1]
        states = states[:-1]
    attn_states = states[0]
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])
else:
    # Save training stats
    with open(os.path.join('stats', model_test_name+'.pkl'), 'wb') as f:
        pickle.dump(train_stats, f)
    with open(os.path.join('models', model_test_name+'.pt'), 'wb') as f:
        torch.save(model.state_dict(), f)

# %%
test_loss = evaluate(
    model, eval_data = test_data, eval_batch_size = eval_batch_size,
    seq_len = seq_len, ntokens = ntokens, criterion = eval_criterion,
    save_wts = True
)
print('test_loss: {:5.3f} | test_perplexity: {:7.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss: 3.867 | test_perplexity:   47.80

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#   229  3257  3257  3257  3257  3257  3257  3257  3257  3257  3257  3257  3257
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#  3257  3257  3257  3257  3257
# [torch.LongTensor of size 2x18]
#
# 14 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#    27    27    27    27    27    27    27    27    27    27    27    27    27
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#    27    27    27    27    27
# [torch.LongTensor of size 2x18]
#
# 17 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   204   204    26    26    26    26   204   204   204   204   204   204   204
#
# Columns 13 to 17
#    26  5463   119    26    26
#   204   204   204   204   204
# [torch.LongTensor of size 2x18]
#
# 17 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#    27    27    27  3790  3790  3790  3790  3790  3790  3790  3790  3790  3790
#
# Columns 13 to 17
#    35    27    27  1479   108
#  3790  3790  3790  3790  3790
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
#
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(model.embedding.weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = model.attn

# %%
align_wts = np.array(attn.alignment.weight.data)
plt.imshow(align_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_align_in'); plt.ylabel('d_align_out')
plt.title('Alignment sublayer weights')
plt.colorbar()
align_wts.shape
# Out:
# (256, 768)

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Attention sublayer weight (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 1024)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# ## Plot training stat curves

# %%
epoch_range = range(1, train_stats['epochs']+1)
train_stats.keys()
# Out:
# dict_keys(['epochs', 'train_loss', 'val_loss', 'grad_norm', 'grad_inf_norm', 'max_param', 'best_losses'])

# %%
plt.plot(epoch_range, train_stats['train_loss'])
plt.plot(epoch_range, train_stats['val_loss'])
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('Loss over training time')
plt.legend(['Train loss', 'Validation loss'])

# %%
plt.plot(epoch_range, train_stats['max_param'])
plt.xlabel('Epoch'); plt.ylabel('Largest parameter magnitude')
plt.title('Largest parameter magnitude over training time')
# Out:
# Text(0.5,1,'Largest parameter magnitude over training time')

# %%
fig, pnorm_ax = plt.subplots()
pnorm_ax.plot(epoch_range, train_stats['grad_norm'], 'b')
pnorm_ax.set_xlabel('Epoch');
pnorm_ax.set_ylabel('2-norm', color = 'b')

infnorm_ax = pnorm_ax.twinx()
infnorm_ax.plot(epoch_range, train_stats['grad_inf_norm'], 'r')
infnorm_ax.set_ylabel('infinite norm', color = 'r')

plt.title('Gradient norms over training time')
#fig.tight_layout()
# Out:
# Text(0.5,1,'Gradient norms over training time')
