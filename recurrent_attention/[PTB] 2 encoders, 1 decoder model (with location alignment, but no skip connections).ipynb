# %%
import os
import pickle
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from model import *
from trainer import *

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Hyperparameters

# %%
model_test_name = '2_encoder_1_decoder_with_localign'
ckpt_loc = os.path.join('checkpoints', model_test_name+'.pt')

# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 2
lr = 0.005
warmup_steps = 3
decay_factor = 0.5
smoothing = 0.05

epochs = 150
early_stopping = 10
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
encode_size = 256
h_size = 256
align_size = 256
loc_align_size = 256
loc_align_kernel = 5
decode_size = 256
decode_out_size = 512
n_enc_layers = 2
attn_rnn_layers = 1
n_dec_layers = 1
smooth_align = True
align_location = True
skip_connections = False

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler
#
# The learning rate scheduler sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    encode_size = encode_size, h_size = h_size, align_size = align_size,
    decode_size = decode_size, decode_out_size = decode_out_size,
    n_enc_layers = n_enc_layers, attn_rnn_layers = attn_rnn_layers,
    n_dec_layers = n_dec_layers, align_location = align_location,
    loc_align_size = loc_align_size, loc_align_kernel = loc_align_kernel,
    smooth_align = smooth_align, skip_connections = skip_connections,
    dropout = dropout
)
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
eval_criterion = LabelSmoothing(ntokens, smoothing = 0)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, decay_factor, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 9468689

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Train and evaluate

# %%
train_stats, stat, train_loss, data, targets, states, nstates = train_eval_loop(
    model, train_data, val_data, batch_size, eval_batch_size,
    seq_len, ntokens, criterion, eval_criterion, optimizer,
    lr_scheduler, epochs, warmup_steps, early_stopping,
    clip, log_interval, ckpt_loc
)
# Out:
# Epoch   1/150) lr = 4.253e-05 (warmup)
#  b 150/719 >> 3030.6 ms/b | lr: 4.483e-05 | grad norm:  0.95 | inf norm:   0.021 | loss: 7.32 | perp: 1507.56
#  b 300/719 >> 3153.7 ms/b | lr: 4.253e-05 | grad norm:  0.66 | inf norm:  0.0094 | loss: 6.18 | perp:  482.07
#  b 450/719 >> 2996.0 ms/b | lr: 3.614e-05 | grad norm:  0.63 | inf norm:  0.0072 | loss: 6.17 | perp:  478.09
#  b 600/719 >> 3022.1 ms/b | lr: 4.253e-05 | grad norm:  0.64 | inf norm:   0.012 | loss: 6.17 | perp:  479.12
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2175.21 sec | train loss, perp: 6.405,  605.10 | valid loss, perp: 6.541,  692.78
# Grad norm:  0.597 | Grad inf. norm:  0.009572 | Max abs param:    0.4502
# ==============================================================================================================
#
#
# Epoch   2/150) lr = 8.505e-05 (warmup)
#  b 150/717 >> 3264.6 ms/b | lr: 7.764e-05 | grad norm:  0.60 | inf norm:  0.0092 | loss: 6.22 | perp:  500.83
#  b 300/717 >> 2943.4 ms/b | lr: 7.501e-05 | grad norm:  0.62 | inf norm:   0.011 | loss: 6.17 | perp:  478.23
#  b 450/717 >> 2838.9 ms/b | lr: 8.019e-05 | grad norm:  0.60 | inf norm:   0.013 | loss: 6.17 | perp:  479.46
#  b 600/717 >> 3082.4 ms/b | lr: 7.764e-05 | grad norm:  0.49 | inf norm:   0.012 | loss: 6.16 | perp:  472.98
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2169.15 sec | train loss, perp: 6.160,  473.50 | valid loss, perp: 6.460,  639.04
# Grad norm:  0.548 | Grad inf. norm:   0.01339 | Max abs param:    0.4646
# ==============================================================================================================
#
#
# Epoch   3/150) lr = 0.0001276 (warmup)
#  b 150/715 >> 2980.5 ms/b | lr: 0.0001203 | grad norm:  0.53 | inf norm:    0.01 | loss: 6.12 | perp:  453.81
#  b 300/715 >> 2969.1 ms/b | lr: 0.0001165 | grad norm:  0.53 | inf norm:   0.015 | loss: 6.05 | perp:  422.31
#  b 450/715 >> 2923.8 ms/b | lr: 0.0001276 | grad norm:  0.43 | inf norm:  0.0083 | loss: 6.01 | perp:  408.59
#  b 600/715 >> 3026.1 ms/b | lr: 0.0001276 | grad norm:  0.55 | inf norm:   0.013 | loss: 6.00 | perp:  402.13
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2126.40 sec | train loss, perp: 6.024,  413.31 | valid loss, perp: 6.329,  560.48
# Grad norm:  0.528 | Grad inf. norm:    0.0152 | Max abs param:    0.4864
# ==============================================================================================================
#
#
# Epoch   4/150) lr = 0.0001105
#  b 150/713 >> 3017.9 ms/b | lr: 0.0001105 | grad norm:  0.53 | inf norm:   0.012 | loss: 5.98 | perp:  396.72
#  b 300/713 >> 3064.4 ms/b | lr: 0.0001193 | grad norm:  0.50 | inf norm:   0.012 | loss: 5.94 | perp:  381.07
#  b 450/713 >> 2967.7 ms/b | lr: 0.0001009 | grad norm:  0.66 | inf norm:   0.013 | loss: 5.94 | perp:  379.15
#  b 600/713 >> 2788.9 ms/b | lr: 0.0001105 | grad norm:  0.54 | inf norm:   0.011 | loss: 5.90 | perp:  365.50
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2111.52 sec | train loss, perp: 5.924,  373.95 | valid loss, perp: 6.226,  505.93
# Grad norm:  0.499 | Grad inf. norm:   0.01161 | Max abs param:    0.5419
# ==============================================================================================================
#
#
# Epoch   5/150) lr = 9.882e-05
#  b 150/713 >> 2908.8 ms/b | lr: 0.0001042 | grad norm:  0.94 | inf norm:   0.016 | loss: 5.89 | perp:  362.45
#  b 300/713 >> 2861.7 ms/b | lr: 9.317e-05 | grad norm:  0.54 | inf norm:   0.021 | loss: 5.83 | perp:  341.04
#  b 450/713 >> 2890.2 ms/b | lr: 9.882e-05 | grad norm:  0.61 | inf norm:   0.045 | loss: 5.81 | perp:  333.61
#  b 600/713 >> 2974.3 ms/b | lr: 0.0001042 | grad norm:  0.74 | inf norm:    0.02 | loss: 5.80 | perp:  329.16
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2075.01 sec | train loss, perp: 5.817,  335.97 | valid loss, perp: 6.095,  443.68
# Grad norm:  0.847 | Grad inf. norm:   0.04516 | Max abs param:    0.5734
# ==============================================================================================================
#
#
# Epoch   6/150) lr = 9.021e-05
#  b 150/719 >> 2892.2 ms/b | lr: 9.021e-05 | grad norm:  0.66 | inf norm:   0.014 | loss: 5.75 | perp:  315.37
#  b 300/719 >> 2820.3 ms/b | lr:  0.000102 | grad norm:  1.73 | inf norm:    0.26 | loss: 5.70 | perp:  299.47
#  b 450/719 >> 2886.9 ms/b | lr: 7.956e-05 | grad norm:  1.12 | inf norm:    0.16 | loss: 5.68 | perp:  293.53
#  b 600/719 >> 2857.6 ms/b | lr: 9.509e-05 | grad norm:  4.57 | inf norm:    0.88 | loss: 5.64 | perp:  280.13
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2066.03 sec | train loss, perp: 5.672,  290.60 | valid loss, perp: 5.849,  347.05
# Grad norm:  7.070 | Grad inf. norm:     1.287 | Max abs param:    0.5753
# ==============================================================================================================
#
#
# Epoch   7/150) lr = 8.352e-05
#  b 150/720 >> 2859.5 ms/b | lr: 8.581e-05 | grad norm:  1.10 | inf norm:    0.12 | loss: 5.60 | perp:  270.42
#  b 300/720 >> 2884.0 ms/b | lr: 7.874e-05 | grad norm:  1.56 | inf norm:    0.24 | loss: 5.52 | perp:  250.11
#  b 450/720 >> 2834.4 ms/b | lr: 7.366e-05 | grad norm:  1.45 | inf norm:    0.24 | loss: 5.47 | perp:  237.15
#  b 600/720 >> 2852.9 ms/b | lr: 7.098e-05 | grad norm:  1.78 | inf norm:    0.28 | loss: 5.44 | perp:  229.64
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2068.83 sec | train loss, perp: 5.482,  240.23 | valid loss, perp: 5.629,  278.29
# Grad norm:  1.255 | Grad inf. norm:   0.08465 | Max abs param:    0.5754
# ==============================================================================================================
#
#
# Epoch   8/150) lr = 7.813e-05
#  b 150/719 >> 2885.2 ms/b | lr: 8.438e-05 | grad norm:  1.31 | inf norm:   0.093 | loss: 5.38 | perp:  216.85
#  b 300/719 >> 2863.4 ms/b | lr: 7.366e-05 | grad norm:  0.99 | inf norm:     0.1 | loss: 5.32 | perp:  204.54
#  b 450/719 >> 2920.7 ms/b | lr: 7.592e-05 | grad norm:  1.10 | inf norm:   0.061 | loss: 5.26 | perp:  193.44
#  b 600/719 >> 2956.0 ms/b | lr:  6.89e-05 | grad norm:  1.02 | inf norm:   0.082 | loss: 5.25 | perp:  190.74
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2072.25 sec | train loss, perp: 5.290,  198.42 | valid loss, perp: 5.459,  234.75
# Grad norm:  1.304 | Grad inf. norm:   0.03172 | Max abs param:    0.5751
# ==============================================================================================================
#
#
# Epoch   9/150) lr = 7.366e-05
#  b 150/714 >> 3003.7 ms/b | lr: 6.944e-05 | grad norm:  1.42 | inf norm:    0.17 | loss: 5.23 | perp:  186.27
#  b 300/714 >> 2887.0 ms/b | lr: 7.764e-05 | grad norm:  1.61 | inf norm:   0.037 | loss: 5.18 | perp:  176.95
#  b 450/714 >> 2892.2 ms/b | lr: 6.724e-05 | grad norm:  1.49 | inf norm:    0.04 | loss: 5.12 | perp:  166.86
#  b 600/714 >> 2874.6 ms/b | lr: 7.158e-05 | grad norm:  1.39 | inf norm:    0.14 | loss: 5.11 | perp:  166.12
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2074.97 sec | train loss, perp: 5.150,  172.36 | valid loss, perp: 5.311,  202.48
# Grad norm:  1.615 | Grad inf. norm:   0.07749 | Max abs param:    0.5861
# ==============================================================================================================
#
#
# Epoch  10/150) lr = 6.988e-05
#  b 150/719 >> 2908.5 ms/b | lr: 7.548e-05 | grad norm:  1.51 | inf norm:    0.13 | loss: 5.10 | perp:  164.23
#  b 300/719 >> 2853.7 ms/b | lr: 5.705e-05 | grad norm:  2.49 | inf norm:    0.44 | loss: 5.06 | perp:  157.24
#  b 450/719 >> 2953.7 ms/b | lr: 6.791e-05 | grad norm:  1.12 | inf norm:    0.13 | loss: 4.98 | perp:  146.00
#  b 600/719 >> 2817.1 ms/b | lr: 6.791e-05 | grad norm:  0.97 | inf norm:   0.063 | loss: 4.97 | perp:  143.63
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2068.75 sec | train loss, perp: 5.013,  150.40 | valid loss, perp: 5.183,  178.14
# Grad norm:  1.249 | Grad inf. norm:    0.1573 | Max abs param:    0.5968
# ==============================================================================================================
#
#
# Epoch  11/150) lr = 6.663e-05
#  b 150/722 >> 2937.7 ms/b | lr: 6.845e-05 | grad norm:  2.67 | inf norm:    0.27 | loss: 4.98 | perp:  146.19
#  b 300/722 >> 2863.5 ms/b | lr: 6.281e-05 | grad norm:  1.54 | inf norm:   0.088 | loss: 4.92 | perp:  137.36
#  b 450/722 >> 2832.7 ms/b | lr: 7.023e-05 | grad norm:  4.92 | inf norm:    0.78 | loss: 4.89 | perp:  133.18
#  b 600/722 >> 2871.7 ms/b | lr: 6.281e-05 | grad norm:  1.12 | inf norm:    0.12 | loss: 4.88 | perp:  131.59
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2070.06 sec | train loss, perp: 4.911,  135.75 | valid loss, perp: 5.070,  159.15
# Grad norm:  1.386 | Grad inf. norm:    0.1074 | Max abs param:     0.606
# ==============================================================================================================
#
#
# Epoch  12/150) lr = 6.379e-05
#  b 150/723 >> 2825.7 ms/b | lr: 6.014e-05 | grad norm:  1.31 | inf norm:   0.032 | loss: 4.87 | perp:  129.91
#  b 300/723 >> 2845.5 ms/b | lr: 6.199e-05 | grad norm:  2.01 | inf norm:    0.13 | loss: 4.83 | perp:  125.79
#  b 450/723 >> 2969.9 ms/b | lr: 6.199e-05 | grad norm:  3.12 | inf norm:    0.44 | loss: 4.81 | perp:  122.57
#  b 600/723 >> 2952.0 ms/b | lr: 5.626e-05 | grad norm:  1.71 | inf norm:    0.16 | loss: 4.78 | perp:  119.02
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2102.84 sec | train loss, perp: 4.809,  122.67 | valid loss, perp: 4.966,  143.46
# Grad norm:  1.563 | Grad inf. norm:    0.1524 | Max abs param:    0.6144
# ==============================================================================================================
#
#
# Epoch  13/150) lr = 6.129e-05
#  b 150/720 >> 3009.3 ms/b | lr: 5.956e-05 | grad norm:  1.32 | inf norm:    0.13 | loss: 4.79 | perp:  120.69
#  b 300/720 >> 2886.3 ms/b | lr: 5.595e-05 | grad norm:  1.66 | inf norm:   0.049 | loss: 4.72 | perp:  112.17
#  b 450/720 >> 3001.1 ms/b | lr: 5.778e-05 | grad norm:  1.31 | inf norm:   0.065 | loss: 4.73 | perp:  112.79
#  b 600/720 >> 2956.2 ms/b | lr: 5.405e-05 | grad norm:  3.46 | inf norm:    0.61 | loss: 4.69 | perp:  108.78
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2139.55 sec | train loss, perp: 4.727,  113.00 | valid loss, perp: 4.876,  131.12
# Grad norm:  6.082 | Grad inf. norm:    0.8942 | Max abs param:    0.6218
# ==============================================================================================================
#
#
# Epoch  14/150) lr = 5.906e-05
#  b 150/711 >> 3060.7 ms/b | lr: 5.739e-05 | grad norm:  1.15 | inf norm:   0.026 | loss: 4.70 | perp:  110.05
#  b 300/711 >> 2943.4 ms/b | lr: 5.568e-05 | grad norm:  1.37 | inf norm:   0.057 | loss: 4.64 | perp:  103.50
#  b 450/711 >> 2935.9 ms/b | lr: 5.391e-05 | grad norm:  1.68 | inf norm:    0.19 | loss: 4.64 | perp:  103.28
#  b 600/711 >> 2946.6 ms/b | lr: 5.568e-05 | grad norm:  1.75 | inf norm:    0.11 | loss: 4.64 | perp:  103.81
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2104.55 sec | train loss, perp: 4.643,  103.87 | valid loss, perp: 4.787,  119.97
# Grad norm:  2.284 | Grad inf. norm:    0.2513 | Max abs param:    0.6282
# ==============================================================================================================
#
#
# Epoch  15/150) lr = 5.705e-05
#  b 150/722 >> 2883.0 ms/b | lr: 5.379e-05 | grad norm:  1.71 | inf norm:    0.13 | loss: 4.64 | perp:  103.21
#  b 300/722 >> 2811.0 ms/b | lr: 5.545e-05 | grad norm:  1.66 | inf norm:    0.13 | loss: 4.57 | perp:   96.82
#  b 450/722 >> 2928.5 ms/b | lr: 5.545e-05 | grad norm:  1.69 | inf norm:    0.07 | loss: 4.55 | perp:   94.99
#  b 600/722 >> 2926.7 ms/b | lr: 5.208e-05 | grad norm:  2.32 | inf norm:     0.1 | loss: 4.51 | perp:   91.37
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2080.75 sec | train loss, perp: 4.568,   96.31 | valid loss, perp: 4.694,  109.25
# Grad norm: 21.046 | Grad inf. norm:     4.552 | Max abs param:    0.6341
# ==============================================================================================================
#
#
# Epoch  16/150) lr = 5.524e-05
#  b 150/725 >> 2925.2 ms/b | lr: 4.872e-05 | grad norm:  1.66 | inf norm:    0.15 | loss: 4.55 | perp:   94.63
#  b 300/725 >> 2832.9 ms/b | lr: 5.524e-05 | grad norm:  3.78 | inf norm:    0.61 | loss: 4.49 | perp:   88.88
#  b 450/725 >> 2833.3 ms/b | lr: 5.524e-05 | grad norm:  1.95 | inf norm:    0.22 | loss: 4.48 | perp:   88.17
#  b 600/725 >> 2822.2 ms/b | lr: 5.043e-05 | grad norm:  1.78 | inf norm:    0.12 | loss: 4.45 | perp:   85.41
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2060.00 sec | train loss, perp: 4.482,   88.40 | valid loss, perp: 4.604,   99.86
# Grad norm:  1.630 | Grad inf. norm:    0.1137 | Max abs param:    0.6389
# ==============================================================================================================
#
#
# Epoch  17/150) lr = 5.359e-05
#  b 150/715 >> 2930.5 ms/b | lr: 5.053e-05 | grad norm:  2.32 | inf norm:    0.13 | loss: 4.48 | perp:   88.09
#  b 300/715 >> 2868.4 ms/b | lr: 5.925e-05 | grad norm:  1.70 | inf norm:   0.054 | loss: 4.42 | perp:   82.93
#  b 450/715 >> 2915.6 ms/b | lr: 6.058e-05 | grad norm:  2.69 | inf norm:    0.54 | loss: 4.43 | perp:   83.78
#  b 600/715 >> 2871.8 ms/b | lr: 5.359e-05 | grad norm:  2.46 | inf norm:    0.15 | loss: 4.37 | perp:   78.82
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2066.74 sec | train loss, perp: 4.406,   81.93 | valid loss, perp: 4.502,   90.24
# Grad norm:  1.576 | Grad inf. norm:    0.1396 | Max abs param:    0.6433
# ==============================================================================================================
#
#
# Epoch  18/150) lr = 5.208e-05
#  b 150/717 >> 2881.8 ms/b | lr: 4.593e-05 | grad norm:  2.17 | inf norm:    0.08 | loss: 4.39 | perp:   80.44
#  b 300/717 >> 2868.8 ms/b | lr: 5.351e-05 | grad norm:  1.98 | inf norm:    0.15 | loss: 4.35 | perp:   77.09
#  b 450/717 >> 2900.5 ms/b | lr: 5.062e-05 | grad norm:  2.02 | inf norm:     0.1 | loss: 4.32 | perp:   74.94
#  b 600/717 >> 2899.8 ms/b | lr: 5.208e-05 | grad norm:  2.71 | inf norm:   0.091 | loss: 4.32 | perp:   74.89
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2070.60 sec | train loss, perp: 4.333,   76.15 | valid loss, perp: 4.407,   82.01
# Grad norm:  2.579 | Grad inf. norm:    0.3451 | Max abs param:    0.6464
# ==============================================================================================================
#
#
# Epoch  19/150) lr = 5.069e-05
#  b 150/728 >> 2854.5 ms/b | lr: 4.308e-05 | grad norm:  2.66 | inf norm:    0.42 | loss: 4.32 | perp:   75.04
#  b 300/728 >> 2823.1 ms/b | lr: 4.471e-05 | grad norm:  2.15 | inf norm:    0.25 | loss: 4.27 | perp:   71.60
#  b 450/728 >> 2840.8 ms/b | lr: 5.069e-05 | grad norm:  5.77 | inf norm:     1.2 | loss: 4.23 | perp:   68.81
#  b 600/728 >> 2882.5 ms/b | lr: 4.779e-05 | grad norm:  3.85 | inf norm:    0.65 | loss: 4.22 | perp:   67.92
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2079.18 sec | train loss, perp: 4.252,   70.25 | valid loss, perp: 4.331,   75.98
# Grad norm:  2.301 | Grad inf. norm:    0.1242 | Max abs param:    0.6488
# ==============================================================================================================
#
#
# Epoch  20/150) lr = 4.941e-05
#  b 150/717 >> 2986.0 ms/b | lr: 4.802e-05 | grad norm:  2.03 | inf norm:    0.14 | loss: 4.27 | perp:   71.59
#  b 300/717 >> 2944.3 ms/b | lr: 4.802e-05 | grad norm:  1.90 | inf norm:    0.18 | loss: 4.15 | perp:   63.52
#  b 450/717 >> 2892.9 ms/b | lr: 5.208e-05 | grad norm:  3.01 | inf norm:    0.49 | loss: 4.16 | perp:   64.33
#  b 600/717 >> 2983.9 ms/b | lr: 5.463e-05 | grad norm:  3.09 | inf norm:     0.7 | loss: 4.18 | perp:   65.22
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2116.85 sec | train loss, perp: 4.178,   65.20 | valid loss, perp: 4.240,   69.39
# Grad norm:  1.926 | Grad inf. norm:   0.07442 | Max abs param:    0.6513
# ==============================================================================================================
#
#
# Epoch  21/150) lr = 4.822e-05
#  b 150/715 >> 3004.7 ms/b | lr: 5.083e-05 | grad norm:  1.90 | inf norm:    0.06 | loss: 4.18 | perp:   65.20
#  b 300/715 >> 2962.0 ms/b | lr: 4.402e-05 | grad norm:  1.70 | inf norm:   0.082 | loss: 4.11 | perp:   60.67
#  b 450/715 >> 2872.9 ms/b | lr: 4.546e-05 | grad norm:  1.57 | inf norm:   0.049 | loss: 4.10 | perp:   60.10
#  b 600/715 >> 3009.8 ms/b | lr: 4.822e-05 | grad norm:  3.31 | inf norm:    0.54 | loss: 4.11 | perp:   61.01
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2118.98 sec | train loss, perp: 4.113,   61.13 | valid loss, perp: 4.170,   64.70
# Grad norm:  2.045 | Grad inf. norm:    0.1913 | Max abs param:    0.6532
# ==============================================================================================================
#
#
# Epoch  22/150) lr = 4.711e-05
#  b 150/717 >> 3061.3 ms/b | lr:  4.84e-05 | grad norm:  1.94 | inf norm:   0.094 | loss: 4.11 | perp:   61.04
#  b 300/717 >> 2965.5 ms/b | lr: 4.711e-05 | grad norm:  2.27 | inf norm:   0.091 | loss: 4.17 | perp:   64.59
#  b 450/717 >> 2805.1 ms/b | lr: 4.711e-05 | grad norm:  1.86 | inf norm:   0.073 | loss: 4.02 | perp:   55.45
#  b 600/717 >> 2928.9 ms/b | lr: 4.578e-05 | grad norm:  2.20 | inf norm:   0.075 | loss: 4.03 | perp:   56.04
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2115.28 sec | train loss, perp: 4.066,   58.34 | valid loss, perp: 4.108,   60.81
# Grad norm:  2.261 | Grad inf. norm:    0.1125 | Max abs param:    0.6546
# ==============================================================================================================
#
#
# Epoch  23/150) lr = 4.608e-05
#  b 150/718 >> 2974.7 ms/b | lr: 4.734e-05 | grad norm:  2.76 | inf norm:    0.12 | loss: 4.05 | perp:   57.21
#  b 300/718 >> 2985.0 ms/b | lr: 4.206e-05 | grad norm:  3.10 | inf norm:    0.28 | loss: 3.99 | perp:   54.00
#  b 450/718 >> 2991.7 ms/b | lr: 4.734e-05 | grad norm:  2.25 | inf norm:    0.27 | loss: 4.00 | perp:   54.77
#  b 600/718 >> 2813.1 ms/b | lr: 4.063e-05 | grad norm:  1.99 | inf norm:   0.075 | loss: 3.96 | perp:   52.53
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2096.89 sec | train loss, perp: 3.985,   53.79 | valid loss, perp: 4.051,   57.48
# Grad norm:  2.611 | Grad inf. norm:    0.1283 | Max abs param:    0.6558
# ==============================================================================================================
#
#
# Epoch  24/150) lr = 4.511e-05
#  b 150/714 >> 2849.0 ms/b | lr: 4.511e-05 | grad norm:  1.85 | inf norm:   0.077 | loss: 3.99 | perp:   54.17
#  b 300/714 >> 2807.1 ms/b | lr: 5.208e-05 | grad norm:  5.83 | inf norm:     1.1 | loss: 3.93 | perp:   50.82
#  b 450/714 >> 2703.5 ms/b | lr: 4.511e-05 | grad norm:  1.86 | inf norm:    0.17 | loss: 3.93 | perp:   51.13
#  b 600/714 >> 2813.6 ms/b | lr: 4.511e-05 | grad norm: 17.56 | inf norm:     3.4 | loss: 3.98 | perp:   53.34
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1982.00 sec | train loss, perp: 3.944,   51.63 | valid loss, perp: 3.992,   54.15
# Grad norm:  2.595 | Grad inf. norm:    0.5025 | Max abs param:    0.6571
# ==============================================================================================================
#
#
# Epoch  25/150) lr = 4.419e-05
#  b 150/719 >> 2790.0 ms/b | lr: 4.996e-05 | grad norm: 10.92 | inf norm:     2.3 | loss: 3.94 | perp:   51.47
#  b 300/719 >> 2808.2 ms/b | lr: 4.167e-05 | grad norm:  9.39 | inf norm:     2.1 | loss: 3.89 | perp:   49.05
#  b 450/719 >> 2702.7 ms/b | lr: 4.886e-05 | grad norm:  2.99 | inf norm:    0.54 | loss: 3.90 | perp:   49.37
#  b 600/719 >> 2666.0 ms/b | lr: 4.034e-05 | grad norm:  3.06 | inf norm:    0.48 | loss: 3.86 | perp:   47.63
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1959.30 sec | train loss, perp: 3.886,   48.70 | valid loss, perp: 3.932,   50.99
# Grad norm:  7.008 | Grad inf. norm:     1.723 | Max abs param:    0.6583
# ==============================================================================================================
#
#
# Epoch  26/150) lr = 4.334e-05
#  b 150/728 >> 2640.6 ms/b | lr: 4.791e-05 | grad norm:  5.90 | inf norm:     1.4 | loss: 3.87 | perp:   48.09
#  b 300/728 >> 2712.3 ms/b | lr: 4.452e-05 | grad norm:  5.65 | inf norm:    0.76 | loss: 3.83 | perp:   45.99
#  b 450/728 >> 2729.3 ms/b | lr: 4.211e-05 | grad norm:  2.65 | inf norm:    0.11 | loss: 3.83 | perp:   46.26
#  b 600/728 >> 2707.8 ms/b | lr: 4.791e-05 | grad norm:  2.57 | inf norm:    0.12 | loss: 3.81 | perp:   45.30
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1959.90 sec | train loss, perp: 3.826,   45.87 | valid loss, perp: 3.875,   48.18
# Grad norm:  1.875 | Grad inf. norm:   0.07484 | Max abs param:    0.6777
# ==============================================================================================================
#
#
# Epoch  27/150) lr = 4.253e-05
#  b 150/723 >> 2691.6 ms/b | lr: 4.369e-05 | grad norm: 11.17 | inf norm:     2.5 | loss: 3.82 | perp:   45.63
#  b 300/723 >> 2702.3 ms/b | lr: 4.133e-05 | grad norm: 56.63 | inf norm:      12 | loss: 3.81 | perp:   44.95
#  b 450/723 >> 2676.6 ms/b | lr: 3.882e-05 | grad norm:  3.82 | inf norm:    0.68 | loss: 3.78 | perp:   43.64
#  b 600/723 >> 2703.4 ms/b | lr: 3.882e-05 | grad norm:  2.62 | inf norm:     0.1 | loss: 3.78 | perp:   43.90
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1958.45 sec | train loss, perp: 3.792,   44.34 | valid loss, perp: 3.831,   46.12
# Grad norm:  2.838 | Grad inf. norm:    0.1417 | Max abs param:    0.7013
# ==============================================================================================================
#
#
# Epoch  28/150) lr = 4.176e-05
#  b 150/719 >> 2778.7 ms/b | lr: 3.683e-05 | grad norm:  2.99 | inf norm:    0.14 | loss: 3.81 | perp:   45.11
#  b 300/719 >> 2706.4 ms/b | lr: 3.812e-05 | grad norm:  1.82 | inf norm:    0.15 | loss: 3.72 | perp:   41.21
#  b 450/719 >> 2734.0 ms/b | lr: 3.937e-05 | grad norm:  3.66 | inf norm:    0.66 | loss: 3.70 | perp:   40.53
#  b 600/719 >> 2700.8 ms/b | lr: 4.176e-05 | grad norm:  3.80 | inf norm:    0.33 | loss: 3.72 | perp:   41.34
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1961.05 sec | train loss, perp: 3.723,   41.37 | valid loss, perp: 3.759,   42.91
# Grad norm:  3.028 | Grad inf. norm:     0.378 | Max abs param:    0.7143
# ==============================================================================================================
#
#
# Epoch  29/150) lr = 4.103e-05
#  b 150/716 >> 2679.7 ms/b | lr: 4.325e-05 | grad norm:  3.98 | inf norm:    0.71 | loss: 3.73 | perp:   41.85
#  b 300/716 >> 2727.6 ms/b | lr: 3.619e-05 | grad norm:  2.19 | inf norm:   0.094 | loss: 3.67 | perp:   39.44
#  b 450/716 >> 2743.1 ms/b | lr: 4.325e-05 | grad norm:  3.10 | inf norm:    0.16 | loss: 3.75 | perp:   42.61
#  b 600/716 >> 2813.7 ms/b | lr: 4.216e-05 | grad norm:  2.55 | inf norm:    0.17 | loss: 3.69 | perp:   39.92
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1960.82 sec | train loss, perp: 3.723,   41.40 | valid loss, perp: 3.723,   41.37
# Grad norm:  2.011 | Grad inf. norm:   0.07653 | Max abs param:    0.7202
# ==============================================================================================================
# Epoch  30/150) lr = 4.034e-05
#  b 150/725 >> 2774.3 ms/b | lr: 3.558e-05 | grad norm:  2.36 | inf norm:   0.097 | loss: 3.70 | perp:   40.60
#  b 300/725 >> 2713.8 ms/b | lr: 4.253e-05 | grad norm:  2.66 | inf norm:    0.19 | loss: 3.67 | perp:   39.14
#  b 450/725 >> 2671.9 ms/b | lr: 4.145e-05 | grad norm:  2.92 | inf norm:    0.39 | loss: 3.67 | perp:   39.36
#  b 600/725 >> 2679.4 ms/b | lr: 3.804e-05 | grad norm:  2.41 | inf norm:    0.12 | loss: 3.59 | perp:   36.36
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1956.21 sec | train loss, perp: 3.651,   38.50 | valid loss, perp: 3.671,   39.27
# Grad norm:  2.358 | Grad inf. norm:   0.09608 | Max abs param:    0.7442
# ==============================================================================================================
#
#
# Epoch  31/150) lr = 3.969e-05
#  b 150/718 >> 2712.0 ms/b | lr: 4.287e-05 | grad norm:  3.05 | inf norm:    0.33 | loss: 3.62 | perp:   37.43
#  b 300/718 >> 2764.6 ms/b | lr: 3.623e-05 | grad norm:  2.54 | inf norm:    0.11 | loss: 3.63 | perp:   37.90
#  b 450/718 >> 2744.2 ms/b | lr:   3.5e-05 | grad norm:  3.57 | inf norm:    0.53 | loss: 3.55 | perp:   34.84
#  b 600/718 >> 2709.0 ms/b | lr: 3.969e-05 | grad norm:  2.57 | inf norm:    0.23 | loss: 3.57 | perp:   35.39
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1961.96 sec | train loss, perp: 3.581,   35.89 | valid loss, perp: 3.622,   37.40
# Grad norm:  2.519 | Grad inf. norm:    0.1028 | Max abs param:    0.7697
# ==============================================================================================================
#
#
# Epoch  32/150) lr = 3.906e-05
#  b 150/727 >> 2690.2 ms/b | lr:  3.32e-05 | grad norm:  1.97 | inf norm:   0.061 | loss: 3.56 | perp:   35.17
#  b 300/727 >> 2691.3 ms/b | lr: 4.416e-05 | grad norm: 29.04 | inf norm:     6.1 | loss: 3.54 | perp:   34.32
#  b 450/727 >> 2711.6 ms/b | lr: 3.683e-05 | grad norm:  5.34 | inf norm:    0.94 | loss: 3.59 | perp:   36.08
#  b 600/727 >> 2649.7 ms/b | lr: 3.445e-05 | grad norm:  2.49 | inf norm:    0.15 | loss: 3.53 | perp:   34.04
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1955.76 sec | train loss, perp: 3.546,   34.66 | valid loss, perp: 3.583,   35.99
# Grad norm:  3.197 | Grad inf. norm:    0.4943 | Max abs param:    0.7927
# ==============================================================================================================
#
#
# Epoch  33/150) lr = 3.847e-05
#  b 150/713 >> 2784.8 ms/b | lr: 3.627e-05 | grad norm:  2.01 | inf norm:   0.095 | loss: 3.57 | perp:   35.56
#  b 300/713 >> 2757.5 ms/b | lr: 3.847e-05 | grad norm:  2.09 | inf norm:   0.085 | loss: 3.50 | perp:   32.97
#  b 450/713 >> 2719.2 ms/b | lr: 3.738e-05 | grad norm:  2.08 | inf norm:   0.082 | loss: 3.47 | perp:   32.11
#  b 600/713 >> 2823.7 ms/b | lr: 4.155e-05 | grad norm:  6.64 | inf norm:     1.2 | loss: 3.52 | perp:   33.63
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1965.67 sec | train loss, perp: 3.510,   33.44 | valid loss, perp: 3.527,   34.02
# Grad norm:  2.299 | Grad inf. norm:    0.1219 | Max abs param:    0.8171
# ==============================================================================================================
#
#
# Epoch  34/150) lr = 3.79e-05
#  b 150/723 >> 2700.1 ms/b | lr: 3.995e-05 | grad norm:  2.75 | inf norm:    0.13 | loss: 3.52 | perp:   33.81
#  b 300/723 >> 2725.0 ms/b | lr: 4.093e-05 | grad norm: 17.37 | inf norm:     3.8 | loss: 3.52 | perp:   33.92
#  b 450/723 >> 2755.5 ms/b | lr:  3.79e-05 | grad norm:  2.94 | inf norm:    0.18 | loss: 3.45 | perp:   31.44
#  b 600/723 >> 2695.9 ms/b | lr: 3.995e-05 | grad norm:  2.78 | inf norm:   0.069 | loss: 3.47 | perp:   32.05
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1959.98 sec | train loss, perp: 3.477,   32.36 | valid loss, perp: 3.492,   32.85
# Grad norm:  3.243 | Grad inf. norm:    0.1164 | Max abs param:    0.8345
# ==============================================================================================================
#
#
# Epoch  35/150) lr = 3.735e-05
#  b 150/719 >> 2798.7 ms/b | lr: 3.837e-05 | grad norm:  2.88 | inf norm:   0.066 | loss: 3.49 | perp:   32.65
#  b 300/719 >> 2670.3 ms/b | lr: 4.034e-05 | grad norm:  4.68 | inf norm:    0.41 | loss: 3.41 | perp:   30.17
#  b 450/719 >> 2703.3 ms/b | lr:  3.41e-05 | grad norm:  2.75 | inf norm:    0.12 | loss: 3.40 | perp:   30.05
#  b 600/719 >> 2711.5 ms/b | lr: 3.937e-05 | grad norm:  7.74 | inf norm:     1.1 | loss: 3.44 | perp:   31.27
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1957.23 sec | train loss, perp: 3.420,   30.57 | valid loss, perp: 3.442,   31.24
# Grad norm:  1.728 | Grad inf. norm:    0.0584 | Max abs param:    0.8551
# ==============================================================================================================
#
#
# Epoch  36/150) lr = 3.683e-05
#  b 150/727 >> 2735.0 ms/b | lr: 3.362e-05 | grad norm:  2.58 | inf norm:    0.14 | loss: 3.44 | perp:   31.27
#  b 300/727 >> 2649.1 ms/b | lr: 3.978e-05 | grad norm:  3.00 | inf norm:    0.18 | loss: 3.38 | perp:   29.33
#  b 450/727 >> 2660.6 ms/b | lr: 3.882e-05 | grad norm:  7.13 | inf norm:    0.74 | loss: 3.41 | perp:   30.38
#  b 600/727 >> 2676.5 ms/b | lr: 3.683e-05 | grad norm:  2.86 | inf norm:    0.45 | loss: 3.40 | perp:   30.07
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1955.28 sec | train loss, perp: 3.411,   30.31 | valid loss, perp: 3.413,   30.34
# Grad norm:  2.295 | Grad inf. norm:    0.1445 | Max abs param:    0.8725
# ==============================================================================================================
#
#
# Epoch  37/150) lr = 3.633e-05
#  b 150/727 >> 2806.8 ms/b | lr: 3.829e-05 | grad norm:  3.20 | inf norm:    0.12 | loss: 3.41 | perp:   30.26
#  b 300/727 >> 2671.9 ms/b | lr:  3.53e-05 | grad norm:  3.35 | inf norm:    0.28 | loss: 3.34 | perp:   28.23
#  b 450/727 >> 2753.5 ms/b | lr: 3.633e-05 | grad norm:  2.11 | inf norm:    0.16 | loss: 3.35 | perp:   28.55
#  b 600/727 >> 2733.5 ms/b | lr:  3.53e-05 | grad norm:  2.26 | inf norm:   0.069 | loss: 3.33 | perp:   27.95
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1997.11 sec | train loss, perp: 3.355,   28.65 | valid loss, perp: 3.363,   28.87
# Grad norm:  2.915 | Grad inf. norm:    0.1095 | Max abs param:    0.8915
# ==============================================================================================================
#
#
# Epoch  38/150) lr = 3.585e-05
#  b 150/716 >> 2781.3 ms/b | lr: 3.484e-05 | grad norm:  2.18 | inf norm:    0.17 | loss: 3.35 | perp:   28.48
#  b 300/716 >> 2768.9 ms/b | lr: 3.872e-05 | grad norm:  9.94 | inf norm:     2.1 | loss: 3.36 | perp:   28.91
#  b 450/716 >> 2715.5 ms/b | lr: 2.927e-05 | grad norm: 71.33 | inf norm:      12 | loss: 3.30 | perp:   27.20
#  b 600/716 >> 2789.7 ms/b | lr: 3.272e-05 | grad norm:  3.03 | inf norm:    0.32 | loss: 3.28 | perp:   26.63
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1979.30 sec | train loss, perp: 3.309,   27.35 | valid loss, perp: 3.319,   27.63
# Grad norm:  2.847 | Grad inf. norm:    0.1925 | Max abs param:    0.9118
# ==============================================================================================================
#
#
# Epoch  39/150) lr = 3.538e-05
#  b 150/722 >> 2682.7 ms/b | lr: 3.336e-05 | grad norm: 23.50 | inf norm:     4.1 | loss: 3.42 | perp:   30.44
#  b 300/722 >> 2699.0 ms/b | lr: 3.635e-05 | grad norm:  2.55 | inf norm:    0.15 | loss: 3.26 | perp:   26.14
#  b 450/722 >> 2770.7 ms/b | lr: 3.336e-05 | grad norm:  4.25 | inf norm:    0.88 | loss: 3.27 | perp:   26.37
#  b 600/722 >> 2666.7 ms/b | lr:  3.23e-05 | grad norm:  4.18 | inf norm:    0.67 | loss: 3.27 | perp:   26.35
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1959.25 sec | train loss, perp: 3.293,   26.92 | valid loss, perp: 3.288,   26.78
# Grad norm:  2.568 | Grad inf. norm:    0.1138 | Max abs param:    0.9254
# ==============================================================================================================
#
#
# Epoch  40/150) lr = 3.494e-05
#  b 150/720 >> 2775.3 ms/b | lr: 3.395e-05 | grad norm:  2.91 | inf norm:    0.36 | loss: 3.34 | perp:   28.34
#  b 300/720 >> 2752.3 ms/b | lr: 3.494e-05 | grad norm:  2.87 | inf norm:   0.087 | loss: 3.28 | perp:   26.57
#  b 450/720 >> 2770.4 ms/b | lr: 3.081e-05 | grad norm:  3.25 | inf norm:    0.52 | loss: 3.31 | perp:   27.40
#  b 600/720 >> 2725.5 ms/b | lr: 3.683e-05 | grad norm:  2.86 | inf norm:    0.33 | loss: 3.20 | perp:   24.49
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1964.65 sec | train loss, perp: 3.276,   26.48 | valid loss, perp: 3.254,   25.89
# Grad norm:  1.974 | Grad inf. norm:   0.05171 | Max abs param:     0.945
# ==============================================================================================================
#
#
# Epoch  41/150) lr = 3.451e-05
#  b 150/715 >> 2741.7 ms/b | lr: 3.727e-05 | grad norm:  9.55 | inf norm:     1.4 | loss: 3.28 | perp:   26.54
#  b 300/715 >> 2821.1 ms/b | lr: 3.638e-05 | grad norm:  3.99 | inf norm:    0.54 | loss: 3.21 | perp:   24.75
#  b 450/715 >> 2817.8 ms/b | lr: 3.546e-05 | grad norm:  3.44 | inf norm:    0.47 | loss: 3.18 | perp:   24.14
#  b 600/715 >> 2703.2 ms/b | lr: 3.254e-05 | grad norm:  2.53 | inf norm:    0.11 | loss: 3.17 | perp:   23.85
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1992.24 sec | train loss, perp: 3.208,   24.73 | valid loss, perp: 3.215,   24.91
# Grad norm:  2.104 | Grad inf. norm:    0.1804 | Max abs param:    0.9615
# ==============================================================================================================
#
#
# Epoch  42/150) lr = 3.41e-05
#  b 150/717 >> 2767.3 ms/b | lr: 3.594e-05 | grad norm:  3.39 | inf norm:    0.36 | loss: 3.20 | perp:   24.60
#  b 300/717 >> 2781.8 ms/b | lr: 3.215e-05 | grad norm:  3.04 | inf norm:    0.38 | loss: 3.17 | perp:   23.80
#  b 450/717 >> 2727.3 ms/b | lr: 3.594e-05 | grad norm: 11.65 | inf norm:       2 | loss: 3.16 | perp:   23.47
#  b 600/717 >> 2687.3 ms/b | lr: 2.665e-05 | grad norm:  5.16 | inf norm:     1.1 | loss: 3.21 | perp:   24.81
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1980.31 sec | train loss, perp: 3.172,   23.85 | valid loss, perp: 3.167,   23.73
# Grad norm:  2.834 | Grad inf. norm:    0.1735 | Max abs param:    0.9803
# ==============================================================================================================
#
#
# Epoch  43/150) lr = 3.37e-05
#  b 150/718 >> 2730.0 ms/b | lr: 3.462e-05 | grad norm:  3.11 | inf norm:    0.46 | loss: 3.24 | perp:   25.60
#  b 300/718 >> 2727.9 ms/b | lr: 3.177e-05 | grad norm:  3.19 | inf norm:    0.16 | loss: 3.13 | perp:   22.86
#  b 450/718 >> 2905.2 ms/b | lr: 3.177e-05 | grad norm:  3.09 | inf norm:    0.28 | loss: 3.11 | perp:   22.49
#  b 600/718 >> 2851.0 ms/b | lr: 2.972e-05 | grad norm:  3.39 | inf norm:     0.2 | loss: 3.18 | perp:   23.99
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2021.69 sec | train loss, perp: 3.151,   23.36 | valid loss, perp: 3.134,   22.98
# Grad norm:  8.955 | Grad inf. norm:     1.704 | Max abs param:     1.001
# ==============================================================================================================
#
#
# Epoch  44/150) lr = 3.331e-05
#  b 150/714 >> 2810.7 ms/b | lr: 2.938e-05 | grad norm:  2.53 | inf norm:    0.18 | loss: 3.18 | perp:   23.98
#  b 300/714 >> 2748.5 ms/b | lr: 3.511e-05 | grad norm:  2.52 | inf norm:    0.14 | loss: 3.14 | perp:   23.21
#  b 450/714 >> 2798.4 ms/b | lr: 3.683e-05 | grad norm:  2.58 | inf norm:    0.26 | loss: 3.07 | perp:   21.51
#  b 600/714 >> 2733.4 ms/b | lr: 3.423e-05 | grad norm:  3.70 | inf norm:    0.62 | loss: 3.08 | perp:   21.74
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1984.40 sec | train loss, perp: 3.116,   22.55 | valid loss, perp: 3.099,   22.18
# Grad norm:  2.640 | Grad inf. norm:    0.2274 | Max abs param:     1.019
# ==============================================================================================================
#
#
# Epoch  45/150) lr = 3.294e-05
#  b 150/721 >> 2843.8 ms/b | lr: 3.384e-05 | grad norm:  2.97 | inf norm:    0.16 | loss: 3.10 | perp:   22.21
#  b 300/721 >> 2739.1 ms/b | lr: 3.294e-05 | grad norm:  2.39 | inf norm:    0.21 | loss: 3.11 | perp:   22.46
#  b 450/721 >> 2623.9 ms/b | lr: 3.384e-05 | grad norm:  3.45 | inf norm:    0.17 | loss: 3.06 | perp:   21.34
#  b 600/721 >> 2641.5 ms/b | lr: 3.201e-05 | grad norm:  2.38 | inf norm:   0.074 | loss: 3.05 | perp:   21.10
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1958.46 sec | train loss, perp: 3.066,   21.45 | valid loss, perp: 3.071,   21.57
# Grad norm:  3.764 | Grad inf. norm:    0.2997 | Max abs param:     1.035
# ==============================================================================================================
#
#
# Epoch  46/150) lr = 3.258e-05
#  b 150/724 >> 2893.1 ms/b | lr: 3.434e-05 | grad norm:  2.19 | inf norm:   0.076 | loss: 3.14 | perp:   23.20
#  b 300/724 >> 2984.9 ms/b | lr: 2.974e-05 | grad norm:  3.40 | inf norm:    0.26 | loss: 3.06 | perp:   21.41
#  b 450/724 >> 3019.3 ms/b | lr: 3.347e-05 | grad norm:  3.47 | inf norm:    0.21 | loss: 3.10 | perp:   22.18
#  b 600/724 >> 2875.2 ms/b | lr: 3.166e-05 | grad norm:  4.01 | inf norm:    0.59 | loss: 3.03 | perp:   20.69
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2132.08 sec | train loss, perp: 3.080,   21.77 | valid loss, perp: 3.034,   20.79
# Grad norm:  3.873 | Grad inf. norm:    0.3335 | Max abs param:      1.05
# ==============================================================================================================
#
#
# Epoch  47/150) lr = 3.223e-05
#  b 150/717 >> 2969.7 ms/b | lr: 3.132e-05 | grad norm:  3.26 | inf norm:    0.22 | loss: 3.12 | perp:   22.61
#  b 300/717 >> 2953.7 ms/b | lr: 3.223e-05 | grad norm:  2.47 | inf norm:   0.099 | loss: 3.01 | perp:   20.35
#  b 450/717 >> 2980.8 ms/b | lr: 3.132e-05 | grad norm:  3.26 | inf norm:    0.11 | loss: 3.02 | perp:   20.53
#  b 600/717 >> 3019.2 ms/b | lr: 3.039e-05 | grad norm:  4.67 | inf norm:    0.67 | loss: 2.96 | perp:   19.37
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2129.92 sec | train loss, perp: 3.023,   20.55 | valid loss, perp: 3.022,   20.52
# Grad norm:  8.693 | Grad inf. norm:     2.043 | Max abs param:     1.067
# ==============================================================================================================
#
#
# Epoch  48/150) lr = 3.189e-05
#  b 150/719 >> 2872.9 ms/b | lr: 3.189e-05 | grad norm:  1.91 | inf norm:   0.094 | loss: 3.08 | perp:   21.83
#  b 300/719 >> 2964.2 ms/b | lr: 3.445e-05 | grad norm:  3.71 | inf norm:    0.58 | loss: 3.05 | perp:   21.03
#  b 450/719 >> 2875.5 ms/b | lr: 2.813e-05 | grad norm:  3.65 | inf norm:     0.4 | loss: 2.96 | perp:   19.24
#  b 600/719 >> 2845.2 ms/b | lr: 2.711e-05 | grad norm:  2.70 | inf norm:   0.099 | loss: 3.00 | perp:   20.14
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2089.90 sec | train loss, perp: 3.023,   20.56 | valid loss, perp: 2.980,   19.69
# Grad norm:  3.819 | Grad inf. norm:    0.6218 | Max abs param:     1.083
# ==============================================================================================================
#
#
# Epoch  49/150) lr = 3.157e-05
#  b 150/717 >> 2889.7 ms/b | lr:  3.41e-05 | grad norm:  2.62 | inf norm:    0.11 | loss: 3.04 | perp:   21.00
#  b 300/717 >> 2862.6 ms/b | lr: 3.243e-05 | grad norm:  2.97 | inf norm:    0.15 | loss: 2.96 | perp:   19.26
#  b 450/717 >> 2859.8 ms/b | lr: 2.882e-05 | grad norm:  3.19 | inf norm:    0.12 | loss: 2.93 | perp:   18.80
#  b 600/717 >> 3074.4 ms/b | lr: 3.157e-05 | grad norm:  2.62 | inf norm:    0.29 | loss: 2.95 | perp:   19.06
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2131.56 sec | train loss, perp: 2.971,   19.50 | valid loss, perp: 2.955,   19.21
# Grad norm: 102.258 | Grad inf. norm:     18.21 | Max abs param:       1.1
# ==============================================================================================================
#
#
# Epoch  50/150) lr = 3.125e-05
#  b 150/719 >> 2972.2 ms/b | lr: 3.037e-05 | grad norm:  3.43 | inf norm:    0.47 | loss: 3.00 | perp:   20.13
#  b 300/719 >> 2811.3 ms/b | lr: 2.853e-05 | grad norm:  9.92 | inf norm:     2.2 | loss: 2.97 | perp:   19.42
#  b 450/719 >> 2964.7 ms/b | lr: 3.375e-05 | grad norm:  2.58 | inf norm:    0.29 | loss: 3.05 | perp:   21.07
#  b 600/719 >> 2888.3 ms/b | lr: 3.037e-05 | grad norm:  3.15 | inf norm:    0.16 | loss: 2.94 | perp:   18.94
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2105.49 sec | train loss, perp: 2.993,   19.95 | valid loss, perp: 2.931,   18.74
# Grad norm:  3.156 | Grad inf. norm:    0.4026 | Max abs param:     1.116
# ==============================================================================================================
#
#
# Epoch  51/150) lr = 3.094e-05
#  b 150/719 >> 2975.2 ms/b | lr: 3.647e-05 | grad norm:  4.66 | inf norm:    0.15 | loss: 2.97 | perp:   19.50
#  b 300/719 >> 2826.9 ms/b | lr: 2.917e-05 | grad norm:  3.23 | inf norm:    0.19 | loss: 2.91 | perp:   18.41
#  b 450/719 >> 2955.5 ms/b | lr: 2.917e-05 | grad norm: 10.10 | inf norm:       2 | loss: 2.95 | perp:   19.14
#  b 600/719 >> 2922.1 ms/b | lr: 2.729e-05 | grad norm:  2.84 | inf norm:    0.17 | loss: 2.92 | perp:   18.54
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2101.79 sec | train loss, perp: 2.919,   18.51 | valid loss, perp: 2.895,   18.08
# Grad norm:  4.886 | Grad inf. norm:    0.8611 | Max abs param:     1.125
# ==============================================================================================================
#
#
# Epoch  52/150) lr = 3.064e-05
#  b 150/718 >> 2952.9 ms/b | lr: 2.604e-05 | grad norm:  3.52 | inf norm:    0.38 | loss: 2.92 | perp:   18.53
#  b 300/718 >> 3038.1 ms/b | lr: 2.978e-05 | grad norm:  2.51 | inf norm:    0.11 | loss: 2.93 | perp:   18.80
#  b 450/718 >> 2819.1 ms/b | lr: 3.064e-05 | grad norm:  2.93 | inf norm:    0.12 | loss: 2.91 | perp:   18.35
#  b 600/718 >> 2946.1 ms/b | lr: 2.978e-05 | grad norm:  2.63 | inf norm:   0.092 | loss: 2.89 | perp:   17.95
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2115.99 sec | train loss, perp: 2.899,   18.16 | valid loss, perp: 2.869,   17.62
# Grad norm: 60.277 | Grad inf. norm:      12.4 | Max abs param:     1.141
# ==============================================================================================================
#
#
# Epoch  53/150) lr = 3.035e-05
#  b 150/724 >> 2903.1 ms/b | lr: 3.118e-05 | grad norm: 15.31 | inf norm:    0.42 | loss: 2.91 | perp:   18.38
#  b 300/724 >> 2908.2 ms/b | lr: 2.677e-05 | grad norm:  2.76 | inf norm:     0.1 | loss: 2.87 | perp:   17.71
#  b 450/724 >> 2882.7 ms/b | lr: 3.199e-05 | grad norm:  3.26 | inf norm:    0.19 | loss: 2.86 | perp:   17.43
#  b 600/724 >> 2931.1 ms/b | lr:  2.95e-05 | grad norm:  3.46 | inf norm:    0.13 | loss: 2.82 | perp:   16.71
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2101.52 sec | train loss, perp: 2.860,   17.47 | valid loss, perp: 2.837,   17.07
# Grad norm:  2.971 | Grad inf. norm:    0.2603 | Max abs param:     1.155
# ==============================================================================================================
#
#
# Epoch  54/150) lr = 3.007e-05
#  b 150/718 >> 3087.1 ms/b | lr: 2.455e-05 | grad norm:  5.87 | inf norm:     1.1 | loss: 3.00 | perp:   20.03
#  b 300/718 >> 3057.7 ms/b | lr: 2.922e-05 | grad norm:  2.68 | inf norm:     0.3 | loss: 2.86 | perp:   17.43
#  b 450/718 >> 3059.6 ms/b | lr: 3.007e-05 | grad norm:  2.72 | inf norm:    0.13 | loss: 2.85 | perp:   17.33
#  b 600/718 >> 3175.6 ms/b | lr: 2.745e-05 | grad norm:  2.83 | inf norm:    0.37 | loss: 2.82 | perp:   16.79
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2220.31 sec | train loss, perp: 2.873,   17.70 | valid loss, perp: 2.816,   16.71
# Grad norm:  5.487 | Grad inf. norm:      1.12 | Max abs param:     1.169
# ==============================================================================================================
#
#
# Epoch  55/150) lr = 2.98e-05
#  b 150/719 >> 3057.3 ms/b | lr: 2.628e-05 | grad norm:  4.16 | inf norm:    0.49 | loss: 2.83 | perp:   16.94
#  b 300/719 >> 2974.8 ms/b | lr: 2.896e-05 | grad norm:  2.59 | inf norm:    0.26 | loss: 2.82 | perp:   16.71
#  b 450/719 >> 2911.5 ms/b | lr: 3.061e-05 | grad norm:  4.09 | inf norm:    0.49 | loss: 2.78 | perp:   16.18
#  b 600/719 >> 2716.7 ms/b | lr: 2.896e-05 | grad norm:  3.13 | inf norm:    0.14 | loss: 2.83 | perp:   16.92
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2080.37 sec | train loss, perp: 2.797,   16.40 | valid loss, perp: 2.788,   16.24
# Grad norm: 15.802 | Grad inf. norm:      3.26 | Max abs param:     1.186
# ==============================================================================================================
#
#
# Epoch  56/150) lr = 2.953e-05
#  b 150/722 >> 2755.3 ms/b | lr:  2.87e-05 | grad norm:  2.99 | inf norm:    0.22 | loss: 2.82 | perp:   16.79
#  b 300/722 >> 2697.8 ms/b | lr: 3.264e-05 | grad norm:  5.74 | inf norm:    0.77 | loss: 2.81 | perp:   16.67
#  b 450/722 >> 2658.3 ms/b | lr: 3.264e-05 | grad norm:  3.59 | inf norm:    0.13 | loss: 2.81 | perp:   16.55
#  b 600/722 >> 2698.8 ms/b | lr: 2.953e-05 | grad norm:  3.87 | inf norm:    0.53 | loss: 2.76 | perp:   15.79
# ...
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2253.89 sec | train loss, perp: 1.800,    6.05 | valid loss, perp: 1.734,    5.66
# Grad norm:  2.649 | Grad inf. norm:   0.08077 | Max abs param:     2.112
# ==============================================================================================================
#
#
# Epoch 133/150) lr = 1.916e-05
#  b 150/714 >> 3145.5 ms/b | lr: 1.969e-05 | grad norm:  5.66 | inf norm:    0.74 | loss: 1.88 | perp:    6.55
#  b 300/714 >> 3097.2 ms/b | lr:  2.02e-05 | grad norm: 18.37 | inf norm:     2.5 | loss: 1.77 | perp:    5.89
#  b 450/714 >> 3206.9 ms/b | lr:  2.02e-05 | grad norm:  4.05 | inf norm:    0.13 | loss: 1.89 | perp:    6.60
#  b 600/714 >> 3130.4 ms/b | lr:  1.69e-05 | grad norm:  2.70 | inf norm:   0.092 | loss: 1.84 | perp:    6.33
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2249.46 sec | train loss, perp: 1.862,    6.43 | valid loss, perp: 1.736,    5.68
# Grad norm:  2.990 | Grad inf. norm:    0.2212 | Max abs param:     2.124
# ==============================================================================================================
#
#
# Epoch 134/150) lr = 1.909e-05
#  b 150/720 >> 3169.6 ms/b | lr: 1.961e-05 | grad norm:  2.70 | inf norm:    0.11 | loss: 1.81 | perp:    6.11
#  b 300/720 >> 3147.2 ms/b | lr:  2.11e-05 | grad norm: 106.97 | inf norm:     8.6 | loss: 1.83 | perp:    6.20
#  b 450/720 >> 3103.1 ms/b | lr: 1.855e-05 | grad norm:  3.98 | inf norm:    0.39 | loss: 1.78 | perp:    5.91
#  b 600/720 >> 3075.3 ms/b | lr: 1.683e-05 | grad norm:  3.02 | inf norm:    0.15 | loss: 1.75 | perp:    5.77
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2246.67 sec | train loss, perp: 1.785,    5.96 | valid loss, perp: 1.721,    5.59
# Grad norm:  2.781 | Grad inf. norm:     0.187 | Max abs param:     2.134
# ==============================================================================================================
#
#
# Epoch 135/150) lr = 1.902e-05
#  b 150/725 >> 3067.2 ms/b | lr: 1.793e-05 | grad norm:  2.02 | inf norm:    0.07 | loss: 1.82 | perp:    6.17
#  b 300/725 >> 3049.0 ms/b | lr: 1.616e-05 | grad norm:  4.35 | inf norm:    0.27 | loss: 1.78 | perp:    5.96
#  b 450/725 >> 3173.2 ms/b | lr: 1.902e-05 | grad norm:  4.05 | inf norm:    0.49 | loss: 1.77 | perp:    5.89
#  b 600/725 >> 3090.4 ms/b | lr: 2.005e-05 | grad norm:  4.26 | inf norm:    0.48 | loss: 1.79 | perp:    6.02
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2248.90 sec | train loss, perp: 1.778,    5.92 | valid loss, perp: 1.715,    5.56
# Grad norm:  4.039 | Grad inf. norm:    0.1483 | Max abs param:     2.146
# ==============================================================================================================
#
#
# Epoch 136/150) lr = 1.895e-05
#  b 150/722 >> 3144.9 ms/b | lr: 1.786e-05 | grad norm:  7.59 | inf norm:     1.1 | loss: 1.80 | perp:    6.05
#  b 300/722 >> 3149.0 ms/b | lr: 1.841e-05 | grad norm:  2.90 | inf norm:    0.17 | loss: 1.75 | perp:    5.75
#  b 450/722 >> 3151.9 ms/b | lr: 2.142e-05 | grad norm: 50.43 | inf norm:     2.6 | loss: 1.84 | perp:    6.29
#  b 600/722 >> 2912.2 ms/b | lr: 1.947e-05 | grad norm:  3.81 | inf norm:    0.52 | loss: 1.74 | perp:    5.70
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2220.03 sec | train loss, perp: 1.781,    5.93 | valid loss, perp: 1.709,    5.53
# Grad norm: 10.777 | Grad inf. norm:      1.46 | Max abs param:     2.157
# ==============================================================================================================
#
#
# Epoch 137/150) lr = 1.888e-05
#  b 150/713 >> 3045.1 ms/b | lr:  1.99e-05 | grad norm:  6.71 | inf norm:       1 | loss: 1.79 | perp:    5.98
#  b 300/713 >> 3009.4 ms/b | lr: 2.134e-05 | grad norm: 69.38 | inf norm:     3.4 | loss: 1.74 | perp:    5.72
#  b 450/713 >> 2948.7 ms/b | lr:  1.78e-05 | grad norm:  2.41 | inf norm:     0.1 | loss: 1.78 | perp:    5.95
#  b 600/713 >> 3007.5 ms/b | lr: 1.888e-05 | grad norm:  7.00 | inf norm:     1.1 | loss: 1.72 | perp:    5.56
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2140.02 sec | train loss, perp: 1.757,    5.79 | valid loss, perp: 1.695,    5.45
# Grad norm: 15.528 | Grad inf. norm:    0.6436 | Max abs param:     2.169
# ==============================================================================================================
#
#
# Epoch 138/150) lr = 1.881e-05
#  b 150/718 >> 2994.0 ms/b | lr: 1.881e-05 | grad norm:  3.58 | inf norm:    0.19 | loss: 1.87 | perp:    6.47
#  b 300/718 >> 2920.3 ms/b | lr: 1.717e-05 | grad norm:  4.79 | inf norm:     0.5 | loss: 1.86 | perp:    6.40
#  b 450/718 >> 3034.9 ms/b | lr: 1.773e-05 | grad norm:  4.38 | inf norm:    0.24 | loss: 1.72 | perp:    5.61
#  b 600/718 >> 2959.6 ms/b | lr: 1.659e-05 | grad norm:  3.60 | inf norm:    0.31 | loss: 1.77 | perp:    5.86
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2129.15 sec | train loss, perp: 1.778,    5.92 | valid loss, perp: 1.684,    5.39
# Grad norm:  2.373 | Grad inf. norm:    0.1375 | Max abs param:     2.179
# ==============================================================================================================
#
#
# Epoch 139/150) lr = 1.874e-05
#  b 150/710 >> 2986.8 ms/b | lr: 1.821e-05 | grad norm: 34.31 | inf norm:     4.1 | loss: 1.80 | perp:    6.02
#  b 300/710 >> 2993.0 ms/b | lr: 1.711e-05 | grad norm:  3.74 | inf norm:    0.21 | loss: 1.72 | perp:    5.59
#  b 450/710 >> 3004.2 ms/b | lr: 1.821e-05 | grad norm:  5.29 | inf norm:    0.62 | loss: 1.73 | perp:    5.65
#  b 600/710 >> 3067.6 ms/b | lr: 1.821e-05 | grad norm:  2.76 | inf norm:    0.12 | loss: 1.70 | perp:    5.49
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2135.89 sec | train loss, perp: 1.726,    5.62 | valid loss, perp: 1.681,    5.37
# Grad norm:  3.758 | Grad inf. norm:    0.3148 | Max abs param:     2.188
# ==============================================================================================================
#
#
# Epoch 140/150) lr = 1.868e-05
#  b 150/723 >> 3082.1 ms/b | lr: 1.868e-05 | grad norm:  3.48 | inf norm:    0.11 | loss: 1.83 | perp:    6.26
#  b 300/723 >> 2825.7 ms/b | lr: 1.815e-05 | grad norm:  3.40 | inf norm:    0.16 | loss: 1.73 | perp:    5.63
#  b 450/723 >> 2902.8 ms/b | lr: 1.815e-05 | grad norm:  4.81 | inf norm:    0.44 | loss: 1.80 | perp:    6.05
#  b 600/723 >> 2923.5 ms/b | lr: 1.705e-05 | grad norm:  2.96 | inf norm:    0.26 | loss: 1.74 | perp:    5.70
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2131.72 sec | train loss, perp: 1.768,    5.86 | valid loss, perp: 1.674,    5.33
# Grad norm:  3.625 | Grad inf. norm:    0.2623 | Max abs param:     2.198
# ==============================================================================================================
#
#
# Epoch 141/150) lr = 1.861e-05
#  b 150/713 >> 3014.6 ms/b | lr: 1.861e-05 | grad norm:  6.24 | inf norm:    0.48 | loss: 1.79 | perp:    6.01
#  b 300/713 >> 2943.0 ms/b | lr: 1.861e-05 | grad norm:  4.26 | inf norm:     0.2 | loss: 1.73 | perp:    5.66
#  b 450/713 >> 2916.9 ms/b | lr: 1.962e-05 | grad norm:  2.83 | inf norm:    0.11 | loss: 1.74 | perp:    5.71
#  b 600/713 >> 3064.8 ms/b | lr:  2.01e-05 | grad norm:  4.75 | inf norm:    0.44 | loss: 1.75 | perp:    5.76
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2129.92 sec | train loss, perp: 1.764,    5.84 | valid loss, perp: 1.666,    5.29
# Grad norm:  5.383 | Grad inf. norm:    0.7898 | Max abs param:     2.208
# ==============================================================================================================
#
#
# Epoch 142/150) lr = 1.854e-05
#  b 150/716 >> 2981.1 ms/b | lr:  1.45e-05 | grad norm: 20.20 | inf norm:       3 | loss: 1.79 | perp:    6.01
#  b 300/716 >> 3028.2 ms/b | lr: 1.748e-05 | grad norm:  2.53 | inf norm:   0.099 | loss: 1.67 | perp:    5.30
#  b 450/716 >> 2999.5 ms/b | lr: 1.854e-05 | grad norm:  3.70 | inf norm:    0.21 | loss: 1.69 | perp:    5.43
#  b 600/716 >> 2942.6 ms/b | lr: 1.802e-05 | grad norm:  4.43 | inf norm:    0.42 | loss: 1.72 | perp:    5.59
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2138.09 sec | train loss, perp: 1.711,    5.54 | valid loss, perp: 1.656,    5.24
# Grad norm:  4.827 | Grad inf. norm:    0.5086 | Max abs param:     2.219
# ==============================================================================================================
#
#
# Epoch 143/150) lr = 1.848e-05
#  b 150/710 >> 3004.0 ms/b | lr: 1.898e-05 | grad norm:  3.09 | inf norm:    0.15 | loss: 1.75 | perp:    5.75
#  b 300/710 >> 3006.1 ms/b | lr: 1.848e-05 | grad norm:  5.70 | inf norm:    0.61 | loss: 1.69 | perp:    5.44
#  b 450/710 >> 3010.3 ms/b | lr: 1.687e-05 | grad norm:  2.56 | inf norm:    0.11 | loss: 1.70 | perp:    5.48
#  b 600/710 >> 3039.2 ms/b | lr: 1.796e-05 | grad norm:  5.41 | inf norm:    0.61 | loss: 1.71 | perp:    5.54
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2137.53 sec | train loss, perp: 1.708,    5.52 | valid loss, perp: 1.649,    5.20
# Grad norm:  2.353 | Grad inf. norm:   0.08647 | Max abs param:     2.228
# ==============================================================================================================
#
#
# Epoch 144/150) lr = 1.841e-05
#  b 150/719 >> 3029.4 ms/b | lr:  1.79e-05 | grad norm:  9.08 | inf norm:     1.2 | loss: 1.76 | perp:    5.80
#  b 300/719 >> 2961.0 ms/b | lr: 1.941e-05 | grad norm:  3.89 | inf norm:    0.17 | loss: 1.73 | perp:    5.61
#  b 450/719 >> 2930.2 ms/b | lr: 1.736e-05 | grad norm:  2.98 | inf norm:    0.24 | loss: 1.73 | perp:    5.66
#  b 600/719 >> 2954.2 ms/b | lr: 1.841e-05 | grad norm:  3.47 | inf norm:    0.17 | loss: 1.70 | perp:    5.49
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2130.32 sec | train loss, perp: 1.715,    5.56 | valid loss, perp: 1.645,    5.18
# Grad norm: 34.412 | Grad inf. norm:     1.252 | Max abs param:     2.238
# ==============================================================================================================
#
#
# Epoch 145/150) lr = 1.835e-05
#  b 150/713 >> 3004.5 ms/b | lr: 2.029e-05 | grad norm:  3.70 | inf norm:    0.17 | loss: 1.79 | perp:    5.99
#  b 300/713 >> 3001.2 ms/b | lr:  1.56e-05 | grad norm:  7.79 | inf norm:    0.74 | loss: 1.72 | perp:    5.59
#  b 450/713 >> 2945.2 ms/b | lr: 1.675e-05 | grad norm:  3.15 | inf norm:    0.23 | loss: 1.67 | perp:    5.32
#  b 600/713 >> 3075.5 ms/b | lr:  1.73e-05 | grad norm:  3.12 | inf norm:    0.17 | loss: 1.76 | perp:    5.82
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2138.86 sec | train loss, perp: 1.748,    5.74 | valid loss, perp: 1.639,    5.15
# Grad norm:  4.624 | Grad inf. norm:    0.2337 | Max abs param:     2.248
# ==============================================================================================================
# Epoch 146/150) lr = 1.829e-05
#  b 150/718 >> 2945.7 ms/b | lr: 1.669e-05 | grad norm:  3.99 | inf norm:     0.3 | loss: 1.72 | perp:    5.56
#  b 300/718 >> 2935.9 ms/b | lr: 1.829e-05 | grad norm:  3.61 | inf norm:     0.3 | loss: 1.66 | perp:    5.28
#  b 450/718 >> 2982.7 ms/b | lr: 1.777e-05 | grad norm:  6.14 | inf norm:    0.45 | loss: 1.68 | perp:    5.34
#  b 600/718 >> 2986.7 ms/b | lr: 1.829e-05 | grad norm:  3.93 | inf norm:    0.19 | loss: 1.71 | perp:    5.53
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2135.85 sec | train loss, perp: 1.673,    5.33 | valid loss, perp: 1.627,    5.09
# Grad norm: 38.211 | Grad inf. norm:     7.464 | Max abs param:     2.258
# ==============================================================================================================
#
#
# Epoch 147/150) lr = 1.823e-05
#  b 150/713 >> 3002.2 ms/b | lr: 1.664e-05 | grad norm:  2.83 | inf norm:    0.15 | loss: 1.77 | perp:    5.85
#  b 300/713 >> 3010.5 ms/b | lr: 1.823e-05 | grad norm:  3.49 | inf norm:    0.27 | loss: 1.63 | perp:    5.08
#  b 450/713 >> 3011.8 ms/b | lr: 1.872e-05 | grad norm:  4.10 | inf norm:    0.41 | loss: 1.62 | perp:    5.08
#  b 600/713 >> 2984.8 ms/b | lr: 1.823e-05 | grad norm:  4.16 | inf norm:    0.28 | loss: 1.71 | perp:    5.54
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2133.49 sec | train loss, perp: 1.682,    5.37 | valid loss, perp: 1.617,    5.04
# Grad norm:  2.659 | Grad inf. norm:   0.08349 | Max abs param:     2.265
# ==============================================================================================================
#
#
# Epoch 148/150) lr = 1.816e-05
#  b 150/720 >> 2875.5 ms/b | lr: 1.658e-05 | grad norm:  2.72 | inf norm:    0.22 | loss: 1.71 | perp:    5.53
#  b 300/720 >> 3015.7 ms/b | lr: 1.866e-05 | grad norm:  3.67 | inf norm:    0.26 | loss: 1.66 | perp:    5.24
#  b 450/720 >> 2964.2 ms/b | lr: 1.712e-05 | grad norm:  2.95 | inf norm:    0.19 | loss: 1.70 | perp:    5.46
#  b 600/720 >> 2914.3 ms/b | lr: 1.765e-05 | grad norm:  9.62 | inf norm:    0.46 | loss: 1.70 | perp:    5.45
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2123.93 sec | train loss, perp: 1.673,    5.33 | valid loss, perp: 1.627,    5.09
# Grad norm:  7.175 | Grad inf. norm:    0.8077 | Max abs param:     2.274
# ==============================================================================================================
#
#
# Epoch 149/150) lr = 1.81e-05
#  b 150/725 >> 2933.0 ms/b | lr: 1.759e-05 | grad norm:  5.14 | inf norm:    0.65 | loss: 1.73 | perp:    5.66
#  b 300/725 >> 2924.1 ms/b | lr: 1.955e-05 | grad norm:  3.19 | inf norm:    0.15 | loss: 1.66 | perp:    5.25
#  b 450/725 >> 2927.7 ms/b | lr:  1.81e-05 | grad norm:  3.38 | inf norm:     0.2 | loss: 1.65 | perp:    5.18
#  b 600/725 >> 2928.2 ms/b | lr: 1.759e-05 | grad norm:  3.17 | inf norm:    0.22 | loss: 1.63 | perp:    5.10
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2121.06 sec | train loss, perp: 1.660,    5.26 | valid loss, perp: 1.604,    4.97
# Grad norm:  3.370 | Grad inf. norm:    0.1307 | Max abs param:     2.281
# ==============================================================================================================
#
#
# Epoch 150/150) lr = 1.804e-05
#  b 150/721 >> 2950.9 ms/b | lr: 1.473e-05 | grad norm: 11.09 | inf norm:     1.6 | loss: 1.70 | perp:    5.49
#  b 300/721 >> 2908.2 ms/b | lr: 1.804e-05 | grad norm:  2.24 | inf norm:   0.082 | loss: 1.72 | perp:    5.60
#  b 450/721 >> 2977.5 ms/b | lr: 1.949e-05 | grad norm:  8.72 | inf norm:    0.77 | loss: 1.67 | perp:    5.33
#  b 600/721 >> 2986.9 ms/b | lr: 1.647e-05 | grad norm:  5.06 | inf norm:    0.67 | loss: 1.67 | perp:    5.30
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2124.01 sec | train loss, perp: 1.669,    5.31 | valid loss, perp: 1.598,    4.94
# Grad norm:  3.176 | Grad inf. norm:    0.2222 | Max abs param:     2.288
# ==============================================================================================================

# %%
CAUSES = ['output', 'grad']
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    _states = states
    if model.n_enc_layers > 0:
        enc_states = states[0]
        states = states[1:]
    if model.n_dec_layers > 0:
        dec_states = states[-1]
        states = states[:-1]
    attn_states = states[0]
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])
else:
    # Save training stats
    with open(os.path.join('stats', model_test_name+'.pkl'), 'wb') as f:
        pickle.dump(train_stats, f)
    with open(os.path.join('models', model_test_name+'.pt'), 'wb') as f:
        torch.save(model.state_dict(), f)

# %%
test_loss = evaluate(
    model, test_data, eval_batch_size, seq_len,
    ntokens, eval_criterion, save_wts = True
)
print('test_loss: {:5.3f} | test_perplexity: {:7.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss: 1.511 | test_perplexity:    4.53

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 12 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#   119   119   119    42    32   935  3257   674   229   229  2373    42   252
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#  4115   119   938    32   119
# [torch.LongTensor of size 2x18]
#
# 14 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#    27    27    27    27    27    27    27    27    27   169    27   933   549
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#    24    32    32    24    27
# [torch.LongTensor of size 2x18]
#
# 14 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   119   119   119    32   119  1847   119  5463  6801  6801    83    35   639
#
# Columns 13 to 17
#    26  5463   119    26    26
#    54    26  1847    24    26
# [torch.LongTensor of size 2x18]
#
# 10 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#    26    26    26    26   311   312  3462   108  3454    24    99    30   448
#
# Columns 13 to 17
#    35    27    27  1479   108
#    35    27    27    24    26
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
#
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(model.embedding.weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_norm, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = model.attn

# %%
align_wts = np.array(attn.alignment.weight.data)
plt.imshow(align_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_align_in'); plt.ylabel('d_align_out')
plt.title('Alignment sublayer weights')
plt.colorbar()
align_wts.shape
# Out:
# (256, 768)

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Attention sublayer weights (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 768)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# ## Plot training stat curves

# %%
epoch_range = range(1, train_stats['epochs']+1)
train_stats.keys()
# Out:
# dict_keys(['epochs', 'train_loss', 'val_loss', 'grad_norm', 'grad_inf_norm', 'max_param'])

# %%
plt.plot(epoch_range, train_stats['train_loss'])
plt.plot(epoch_range, train_stats['val_loss'])
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('Loss over training time')
plt.legend(['Train loss', 'Validation loss'])

# %%
plt.plot(epoch_range, train_stats['max_param'])
plt.xlabel('Epoch'); plt.ylabel('Largest parameter magnitude')
plt.title('Largest parameter magnitude over training time')
# Out:
# Text(0.5,1,'Largest parameter magnitude over training time')

# %%
fig, pnorm_ax = plt.subplots()
pnorm_ax.plot(epoch_range, train_stats['grad_norm'], 'b')
pnorm_ax.set_xlabel('Epoch');
pnorm_ax.set_ylabel('2-norm', color = 'b')

infnorm_ax = pnorm_ax.twinx()
infnorm_ax.plot(epoch_range, train_stats['grad_inf_norm'], 'r')
infnorm_ax.set_ylabel('infinite norm', color = 'r')

plt.title('Gradient norms over training time')
#fig.tight_layout()
# Out:
# Text(0.5,1,'Gradient norms over training time')
