# %%
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from recurrent_attention import RecurrentAttention

# %% [markdown]
# ## Overhead stuff
#
# Helper functions for batching, resetting hidden states, etc.

# %%
# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 4
lr = 0.02
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 50
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
encode_size = 256
h_size = 256
loc_align_size = 256
loc_align_kernel = 5
decode_size = 256
decode_out_size = 512
n_enc_layers = 2
attn_rnn_layers = 1
n_dec_layers = 2
smooth_align = True
align_location = True
bidirectional_attn = False
skip_connections = True

# %%
# Starting from sequential data, `batchify` arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.
def batchify(data, batch_size):
    # Work out how cleanly we can divide the dataset into batches
    nbatches = data.size(0) // batch_size
    # Trim off any extra elements that wouldn't cleanly fit
    data = data.narrow(0, 0, nbatches * batch_size)
    # Evenly divide the data across the batches
    data = data.view(batch_size, -1).t().contiguous()
    return data

# Wraps hidden states into new Variables to detach them from their history
def repackage_hidden(h):
    if type(h) == Variable:
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)
    
# `get_batch` subdivides the source data into chunks of the specified length.
# E.g., using the example for the `batchify` function above and a length of 2,
# we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the `batchify` function. The chunks are along dimension 0, corresponding
# to the `seq_len` dimension in the LSTM.
def get_batch(source, i, seq_len, evaluate = False):
    seq_len = min(seq_len, len(source) - 1 - i)
    data = Variable(source[i : i+seq_len], volatile = evaluate)
    target = Variable(source[i+1 : i+1+seq_len].view(-1), volatile = evaluate)
    return data, target

# %% [markdown]
# Label smoothing class for regularization.

# %%
class LabelSmoothing(nn.Module):
    def __init__(self, size, padding_idx = None, smoothing = 0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss()
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = torch.zeros_like(x.data)
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist.add_(self.smoothing / self.size)
        if self.padding_idx is not None:
            true_dist[:, self.padding_idx] = 0
            mask = torch.nonzero(target.data == self.padding_idx)
            if mask.dim() > 0:
                true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad = False)) * ntokens

# %% [markdown]
# Learning rate scheduler that sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
def get_lr_scheduler(h_size, warmup, optimizer):
    lrate = lambda e: h_size**(-0.5) * min((e+1)**(-decay_factor), (e+1) * warmup**(-(decay_factor+1)))
    return optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lrate)

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Model class

# %%
class RNNModel(nn.Module):
    def __init__(self, src_vocab, tgt_vocab, embed_size, encode_size, h_size,
                 decode_size, decode_out_size, n_enc_layers, attn_rnn_layers,
                 n_dec_layers, align_location = False, loc_align_size = 1,
                 loc_align_kernel = 1, smooth_align = False, bidirectional_attn = False,
                 tie_wts = True, skip_connections = False, dropout = 0.1):
        super(RNNModel, self).__init__()
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.embed_size = embed_size
        self.encode_size = encode_size
        self.h_size = h_size
        self.decode_size = decode_size
        self.decode_out_size = decode_out_size
        self.n_enc_layers = n_enc_layers
        self.attn_rnn_layers = attn_rnn_layers
        self.n_dec_layers = n_dec_layers
        self.align_location = align_location
        self.loc_align_size = loc_align_size
        self.loc_align_kernel = loc_align_kernel
        self.smooth_align = smooth_align
        self.bidirectional_attn = bidirectional_attn
        self.tie_wts = tie_wts
        self.skip_connections = skip_connections
        self.dropout = dropout
        
        self.drop = nn.Dropout(dropout)
        self.relu = nn.ReLU()
        
        self.embedding = nn.Embedding(src_vocab, embed_size)
        self.encoders = nn.ModuleList([
            nn.LSTM(
                input_size = embed_size if i == 0 else encode_size,
                hidden_size = encode_size, dropout = dropout
            ) for i in range(n_enc_layers)
        ])
        self.attn = RecurrentAttention(
            in_size = encode_size, h_size = h_size, out_size = decode_size,
            align_location = align_location, loc_align_size = loc_align_size,
            loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
            num_rnn_layers = attn_rnn_layers, attn_act_fn = 'ReLU',
            dropout = dropout, bidirectional = bidirectional_attn
        )
        # Maybe try skip connections in the decoder from the attention mechanism?
        self.decoders = nn.ModuleList([
            nn.LSTM(
                input_size = decode_size, dropout = dropout,
                hidden_size = decode_size if i < n_dec_layers-1 else decode_out_size,
            ) for i in range(n_dec_layers)
        ])
        
        if skip_connections:
            # Create a linear layer to transform the embedding output to be
            # of encode_size so that it can be used in the skip connections
            self.embed_skip = nn.Linear(embed_size, encode_size)
            
            # Do the same for the output of the second-to-last decoder layer
            # to the output of the last decoder layer
            self.decode_skip = nn.Linear(decode_size, decode_out_size)
        
        self.projection = nn.Linear(decode_out_size, tgt_vocab)
        if tie_wts and src_vocab == tgt_vocab and embed_size == decode_out_size:
            self.embedding.weight = self.projection.weight
        self.log_softmax = nn.LogSoftmax(dim = -1)
            
        # For visualizations
        self.save_wts = False
        self.enc_out = None
        self.dec_out = None
        
    def init(self):
        for subnet in [self.encoders, self.decoders]:
            for layer in subnet:
                for p in layer.parameters():
                    if p.dim() > 1:
                        nn.init.xavier_normal(p)
                    else:
                        p.data.fill_(0)
        for p in self.projection.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform(p)
            else:
                p.data.fill_(0)
        self.attn.init()
        
    def init_states(self, batch_size):
        encoder_states = [
            (
                Variable(torch.zeros(1, batch_size, self.encode_size)),
                Variable(torch.zeros(1, batch_size, self.encode_size))
            ) for _ in range(self.n_enc_layers)
        ]
        attn_states = self.attn.init_rnn_states(batch_size)
        decoder_states = [
            (
                Variable(torch.zeros(
                    1, batch_size, self.decode_size if i < self.n_dec_layers-1 else self.decode_out_size
                )),
                Variable(torch.zeros(
                    1, batch_size, self.decode_size if i < self.n_dec_layers-1 else self.decode_out_size
                ))
            ) for i in range(self.n_dec_layers)
        ]
        return encoder_states, attn_states, decoder_states
    
    def forward(self, inputs, states):
        enc_states, attn_states, dec_states = states
        if self.save_wts:
            self.enc_out = []
            self.dec_out = []
        
        # Embedding layer
        embeddings = self.embedding(inputs) * np.sqrt(self.embed_size)
        
        # Encoder stack
        new_enc_states = []
        enc_in = self.drop(self.relu(embeddings))
        for i, (states, encoder) in enumerate(zip(enc_states, self.encoders)):
            enc_out, new_enc_state = encoder(enc_in, states)
            new_enc_states.append(new_enc_state)
            if self.save_wts:
                self.enc_out.append(enc_out.data.clone())
            enc_out = self.drop(enc_out)
            if self.skip_connections:
                if i == 0:
                    enc_in = self.embed_skip(enc_in)
                enc_out = enc_out + enc_in
            enc_in = enc_out
        
        # Attention mechanism
        attn_out, new_attn_states = self.attn(enc_out, attn_states)
        
        # Decoder stack
        new_dec_states = []
        dec_in = attn_out
        for i, (states, decoder) in enumerate(zip(dec_states, self.decoders)):
            dec_out, new_dec_state = decoder(dec_in, states)
            new_dec_states.append(new_dec_state)
            if self.save_wts:
                self.dec_out.append(dec_out.data.clone())
            dec_out = self.drop(dec_out)
            if self.skip_connections:
                if i == len(self.decoders) - 1:
                    dec_in = self.decode_skip(dec_in)
                dec_out = dec_out + dec_in
            dec_in = dec_out
            
        # Projection layer
        logits = self.projection(dec_out)
        output = self.log_softmax(logits)
        
        return output, (new_enc_states, new_attn_states, new_dec_states)
    
    def train(self, mode = True, save_wts = False):
        super(RNNModel, self).train(mode)
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts
        
    def eval(self, save_wts = True):
        super(RNNModel, self).eval()
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    encode_size = encode_size, h_size = h_size, decode_size = decode_size,
    decode_out_size = decode_out_size, n_enc_layers = n_enc_layers,
    attn_rnn_layers = attn_rnn_layers, n_dec_layers = n_dec_layers,
    align_location = align_location, loc_align_size = loc_align_size,
    loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
    skip_connections = skip_connections, dropout = dropout
)
model.init()
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 9798673

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Define training and validation loops

# %%
def train():
    # Use random length sequences
    seq_lens = []
    tot_len = 0
    jitter = 0.15 * seq_len
    num_data = train_data.size(0)
    while tot_len < num_data - 2:
        if num_data - tot_len - 2 <= seq_len + jitter:
            slen = num_data - tot_len - 2
        else:
            slen = int(np.random.normal(seq_len, jitter))
            if slen <= 0:
                slen = seq_len    # eh
            if tot_len + slen >= num_data - jitter - 2:
                slen = num_data - tot_len - 2
        seq_lens.append(slen)
        tot_len += slen
    i_cumseq = [0] + list(np.cumsum(seq_lens)[:-1])
    idx = np.arange(len(seq_lens))
    np.random.shuffle(idx)
    # Turn on training mode
    model.train(save_wts = False)
    # Initialize RNN states
    states = model.init_states(batch_size)
    # Prep metainfo
    total_loss = 0
    total_epoch_loss = 0
    start_time = time.time()
    for batch, i in enumerate(idx):
        # Get training data
        data, targets = get_batch(train_data, i_cumseq[i], seq_lens[i])
        # Repackage the hidden states
        states = repackage_hidden(states)
        # Zero out gradients
        model.zero_grad()
        
        # Run the model forward
        output, _states = model(data, states)
        if np.isnan(output.data).any():
            return 0, total_epoch_loss[0], data, targets, states, _states
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        if np.isnan(loss.data[0]):
            return 1, total_epoch_loss[0], data, targets, states, _states
        states = _states
        # Propagate loss gradient backwards
        loss.backward()
        # Clip gradients
        if batch % log_interval == 0 and batch > 0:
            # Save gradient statistics before they're changed cuz we'll be logging this batch
            parameters = [p for p in model.parameters() if p.grad is not None]
            # Calculate the largest (absolute) gradient of all elements in the model parameters
            max_grad = max([p.grad.data.abs().max() for p in parameters])
        total_norm = nn.utils.clip_grad_norm(model.parameters(), clip)
        # Scale the batch learning rate so that shorter sequences aren't "stronger"
        scaled_lr = lr_scheduler.get_lr()[0] * np.sqrt(seq_lens[i] / seq_len)
        for param_group in optimizer.param_groups:
            param_group['lr'] = scaled_lr
        # Update parameters
        optimizer.step()
        
        # Get some metainfo
        total_loss += loss.data
        total_epoch_loss += loss.data * data.size(0)
        if batch % log_interval == 0 and batch > 0:
            elapsed = time.time() - start_time
            cur_loss = total_loss[0] / log_interval
            print(' b {:3d}/{:3d} >> {:6.1f} ms/b | lr: {:8.2g} | grad norm: {:4.2f} | max abs grad: {:7.3f} | loss: {:4.2f} | perp.: {:6.2f}'.format(
                batch, len(seq_lens), elapsed * 1000/log_interval, scaled_lr, total_norm, max_grad, cur_loss, np.exp(cur_loss)
            ))
            total_loss = 0
            start_time = time.time()
    return -1, total_epoch_loss[0] / num_data, None, None, None, None

# %%
def evaluate(data_src, save_wts = True):
    model.eval(save_wts = save_wts)
    total_loss = 0
    states = model.init_states(eval_batch_size)
    for i in range(0, data_src.size(0) - 1, seq_len):
        # Get data
        data, targets = get_batch(data_src, i, seq_len, evaluate = True)
        # Repackage the hidden states
        states = repackage_hidden(states)
        # Evaluate
        output, states = model(data, states)
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        total_loss += loss.data * data.size(0)
    return total_loss[0] / data_src.size(0)

# %% [markdown]
# Train and evaluate

# %%
WIDTH = 112
CAUSES = ['output', 'grad']
for epoch in range(epochs):
    lr_scheduler.step()
    print('Epoch {:3d}/{:3d}) lr = {:0.4g}{}'.format(epoch+1, epochs, np.mean(lr_scheduler.get_lr()[0]), ' (warmup)' if epoch < warmup_steps else ''))
    start_time = time.time()
    stat, train_loss, data, targets, states, nstates = train()
    if stat in list(range(len(CAUSES))):
        c = CAUSES[stat]
        n = (WIDTH - len(c) - 4) // 2
        print('\n' + (' '*n) + 'NaN ' + c)
        break
    elapsed = time.time() - start_time
    val_loss = evaluate(val_data, save_wts = False)
    max_param = max([p.data.abs().max() for p in model.parameters() if p.grad is not None])
    print('-' * WIDTH)
    print('Elapsed time: {:6.2f} sec | train_loss: {:5.2f} | train_perp: {:6.2f} | valid_loss: {:5.2f} | valid_perp.: {:6.2f}'.format(
        elapsed, train_loss, np.exp(train_loss), val_loss, np.exp(val_loss)
    ))
    print('=' * WIDTH)
    print('\n')
# Out:
# Epoch   1/ 50) lr = 2.795e-05 (warmup)
#  b 150/711 >> 2875.0 ms/b | lr:  2.5e-05 | grad norm: 1.58 | max abs grad:   0.038 | loss: 7.20 | perp.: 1340.05
#  b 300/711 >> 2888.6 ms/b | lr:  2.9e-05 | grad norm: 1.23 | max abs grad:   0.041 | loss: 6.18 | perp.: 482.00
#  b 450/711 >> 2930.5 ms/b | lr:  2.9e-05 | grad norm: 1.38 | max abs grad:   0.064 | loss: 6.16 | perp.: 473.41
#  b 600/711 >> 2818.5 ms/b | lr:  2.6e-05 | grad norm: 1.24 | max abs grad:   0.046 | loss: 6.12 | perp.: 454.39
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2046.31 sec | train_loss:  6.35 | train_perp: 572.48 | valid_loss:  6.03 | valid_perp.: 416.87
# ================================================================================================================
#
#
# Epoch   2/ 50) lr = 5.59e-05 (warmup)
#  b 150/719 >> 2883.0 ms/b | lr:  5.7e-05 | grad norm: 1.18 | max abs grad:   0.053 | loss: 6.11 | perp.: 450.51
#  b 300/719 >> 2763.6 ms/b | lr:  4.9e-05 | grad norm: 1.17 | max abs grad:   0.041 | loss: 6.01 | perp.: 406.57
#  b 450/719 >> 2841.4 ms/b | lr:  5.1e-05 | grad norm: 1.27 | max abs grad:   0.047 | loss: 5.98 | perp.: 396.26
#  b 600/719 >> 2776.6 ms/b | lr:  5.1e-05 | grad norm: 1.16 | max abs grad:   0.034 | loss: 5.95 | perp.: 382.13
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2030.83 sec | train_loss:  5.99 | train_perp: 398.56 | valid_loss:  5.86 | valid_perp.: 350.37
# ================================================================================================================
#
#
# Epoch   3/ 50) lr = 8.385e-05 (warmup)
#  b 150/718 >> 2916.8 ms/b | lr:  8.8e-05 | grad norm: 1.08 | max abs grad:   0.030 | loss: 5.91 | perp.: 367.17
#  b 300/718 >> 2872.7 ms/b | lr:  7.9e-05 | grad norm: 1.15 | max abs grad:   0.028 | loss: 5.84 | perp.: 344.31
#  b 450/718 >> 2774.8 ms/b | lr:  7.9e-05 | grad norm: 1.07 | max abs grad:   0.029 | loss: 5.79 | perp.: 325.59
#  b 600/718 >> 2798.5 ms/b | lr:  6.6e-05 | grad norm: 1.42 | max abs grad:   0.066 | loss: 5.75 | perp.: 313.14
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2034.12 sec | train_loss:  5.80 | train_perp: 330.20 | valid_loss:  5.66 | valid_perp.: 286.01
# ================================================================================================================
#
#
# Epoch   4/ 50) lr = 0.0001118 (warmup)
#  b 150/716 >> 2806.1 ms/b | lr:  9.9e-05 | grad norm: 1.35 | max abs grad:   0.037 | loss: 5.69 | perp.: 295.94
#  b 300/716 >> 2900.9 ms/b | lr:  0.00012 | grad norm: 1.07 | max abs grad:   0.024 | loss: 5.61 | perp.: 272.74
#  b 450/716 >> 2915.1 ms/b | lr:  0.00012 | grad norm: 1.16 | max abs grad:   0.028 | loss: 5.55 | perp.: 258.41
#  b 600/716 >> 2809.5 ms/b | lr:   0.0001 | grad norm: 1.37 | max abs grad:   0.041 | loss: 5.49 | perp.: 243.08
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2036.92 sec | train_loss:  5.56 | train_perp: 261.01 | valid_loss:  5.39 | valid_perp.: 219.67
# ================================================================================================================
#
#
# Epoch   5/ 50) lr = 0.0001398 (warmup)
#  b 150/720 >> 2855.0 ms/b | lr:  0.00012 | grad norm: 1.51 | max abs grad:   0.037 | loss: 5.41 | perp.: 224.38
#  b 300/720 >> 2846.7 ms/b | lr:  0.00015 | grad norm: 1.63 | max abs grad:   0.034 | loss: 5.34 | perp.: 207.93
#  b 450/720 >> 2793.7 ms/b | lr:  0.00012 | grad norm: 1.41 | max abs grad:   0.043 | loss: 5.28 | perp.: 195.81
#  b 600/720 >> 2862.7 ms/b | lr:  0.00014 | grad norm: 1.32 | max abs grad:   0.037 | loss: 5.22 | perp.: 185.71
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2034.92 sec | train_loss:  5.29 | train_perp: 198.76 | valid_loss:  5.13 | valid_perp.: 169.39
# ================================================================================================================
#
#
# Epoch   6/ 50) lr = 0.0001677 (warmup)
#  b 150/718 >> 2878.4 ms/b | lr:  0.00019 | grad norm: 1.79 | max abs grad:   0.033 | loss: 5.15 | perp.: 173.02
#  b 300/718 >> 2844.4 ms/b | lr:  0.00015 | grad norm: 1.73 | max abs grad:   0.040 | loss: 5.08 | perp.: 160.88
#  b 450/718 >> 2856.7 ms/b | lr:  0.00018 | grad norm: 1.74 | max abs grad:   0.046 | loss: 5.04 | perp.: 154.56
#  b 600/718 >> 2741.5 ms/b | lr:  0.00015 | grad norm: 2.29 | max abs grad:   0.064 | loss: 4.98 | perp.: 145.68
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2041.17 sec | train_loss:  5.06 | train_perp: 157.14 | valid_loss:  4.89 | valid_perp.: 133.45
# ================================================================================================================
#
#
# Epoch   7/ 50) lr = 0.0001957 (warmup)
#  b 150/719 >> 2858.1 ms/b | lr:  0.00019 | grad norm: 2.43 | max abs grad:   0.043 | loss: 4.94 | perp.: 139.77
#  b 300/719 >> 2807.8 ms/b | lr:  0.00018 | grad norm: 2.02 | max abs grad:   0.041 | loss: 4.85 | perp.: 127.57
#  b 450/719 >> 2823.3 ms/b | lr:  0.00017 | grad norm: 2.14 | max abs grad:   0.052 | loss: 4.84 | perp.: 126.12
#  b 600/719 >> 2836.8 ms/b | lr:   0.0002 | grad norm: 1.82 | max abs grad:   0.043 | loss: 4.79 | perp.: 120.55
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2036.14 sec | train_loss:  4.86 | train_perp: 128.55 | valid_loss:  4.69 | valid_perp.: 109.06
# ================================================================================================================
#
#
# Epoch   8/ 50) lr = 0.0002236 (warmup)
#  b 150/714 >> 2906.2 ms/b | lr:  0.00022 | grad norm: 3.24 | max abs grad:   0.080 | loss: 4.74 | perp.: 115.01
#  b 300/714 >> 2955.9 ms/b | lr:   0.0002 | grad norm: 1.82 | max abs grad:   0.053 | loss: 4.71 | perp.: 110.96
#  b 450/714 >> 2823.4 ms/b | lr:  0.00022 | grad norm: 1.94 | max abs grad:   0.068 | loss: 4.66 | perp.: 105.38
#  b 600/714 >> 2772.3 ms/b | lr:  0.00021 | grad norm: 2.49 | max abs grad:   0.065 | loss: 4.60 | perp.:  99.04
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2043.42 sec | train_loss:  4.68 | train_perp: 107.43 | valid_loss:  4.53 | valid_perp.:  93.16
# ================================================================================================================
#
#
# Epoch   9/ 50) lr = 0.0002516 (warmup)
#  b 150/720 >> 2857.4 ms/b | lr:  0.00022 | grad norm: 2.37 | max abs grad:   0.058 | loss: 4.55 | perp.:  94.42
#  b 300/720 >> 2799.4 ms/b | lr:  0.00024 | grad norm: 2.71 | max abs grad:   0.064 | loss: 4.48 | perp.:  88.28
#  b 450/720 >> 2840.4 ms/b | lr:  0.00025 | grad norm: 2.47 | max abs grad:   0.068 | loss: 4.44 | perp.:  84.42
#  b 600/720 >> 2855.6 ms/b | lr:  0.00029 | grad norm: 3.37 | max abs grad:   0.096 | loss: 4.45 | perp.:  85.71
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2039.84 sec | train_loss:  4.48 | train_perp:  87.95 | valid_loss:  4.27 | valid_perp.:  71.64
# ================================================================================================================
#
#
# Epoch  10/ 50) lr = 0.0002795 (warmup)
#  b 150/717 >> 2904.2 ms/b | lr:   0.0003 | grad norm: 2.49 | max abs grad:   0.056 | loss: 4.36 | perp.:  78.14
#  b 300/717 >> 2830.7 ms/b | lr:  0.00026 | grad norm: 2.36 | max abs grad:   0.055 | loss: 4.22 | perp.:  67.72
#  b 450/717 >> 2777.8 ms/b | lr:   0.0003 | grad norm: 3.58 | max abs grad:   0.146 | loss: 4.18 | perp.:  65.27
#  b 600/717 >> 2863.0 ms/b | lr:  0.00029 | grad norm: 3.00 | max abs grad:   0.064 | loss: 4.16 | perp.:  64.06
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2043.62 sec | train_loss:  4.23 | train_perp:  68.60 | valid_loss:  4.05 | valid_perp.:  57.48
# ================================================================================================================
#
#
# Epoch  11/ 50) lr = 0.0002665
#  b 150/717 >> 2953.7 ms/b | lr:  0.00025 | grad norm: 3.08 | max abs grad:   0.095 | loss: 4.07 | perp.:  58.43
#  b 300/717 >> 2831.7 ms/b | lr:  0.00029 | grad norm: 5.81 | max abs grad:   0.212 | loss: 3.95 | perp.:  51.80
#  b 450/717 >> 2807.8 ms/b | lr:  0.00027 | grad norm: 3.90 | max abs grad:   0.118 | loss: 3.88 | perp.:  48.29
#  b 600/717 >> 2881.5 ms/b | lr:  0.00025 | grad norm: 5.48 | max abs grad:   0.253 | loss: 3.89 | perp.:  49.02
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2042.94 sec | train_loss:  3.95 | train_perp:  51.85 | valid_loss:  3.63 | valid_perp.:  37.54
# ================================================================================================================
#
#
# Epoch  12/ 50) lr = 0.0002552
#  b 150/719 >> 2836.7 ms/b | lr:  0.00023 | grad norm: 4.36 | max abs grad:   0.192 | loss: 3.77 | perp.:  43.57
#  b 300/719 >> 2829.5 ms/b | lr:  0.00028 | grad norm: 3.25 | max abs grad:   0.085 | loss: 3.72 | perp.:  41.22
#  b 450/719 >> 2889.7 ms/b | lr:  0.00023 | grad norm: 3.78 | max abs grad:   0.195 | loss: 3.64 | perp.:  38.09
#  b 600/719 >> 2987.9 ms/b | lr:  0.00025 | grad norm: 4.53 | max abs grad:   0.284 | loss: 3.68 | perp.:  39.55
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2094.25 sec | train_loss:  3.73 | train_perp:  41.86 | valid_loss:  3.37 | valid_perp.:  29.10
# ================================================================================================================
#
#
# Epoch  13/ 50) lr = 0.0002451
#  b 150/722 >> 2852.1 ms/b | lr:  0.00026 | grad norm: 6.43 | max abs grad:   0.348 | loss: 3.62 | perp.:  37.31
#  b 300/722 >> 2921.4 ms/b | lr:  0.00024 | grad norm: 4.67 | max abs grad:   0.297 | loss: 3.57 | perp.:  35.59
#  b 450/722 >> 2781.9 ms/b | lr:  0.00025 | grad norm: 4.76 | max abs grad:   0.269 | loss: 3.51 | perp.:  33.59
#  b 600/722 >> 2867.8 ms/b | lr:  0.00024 | grad norm: 2.89 | max abs grad:   0.180 | loss: 3.59 | perp.:  36.37
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2064.37 sec | train_loss:  3.60 | train_perp:  36.63 | valid_loss:  3.23 | valid_perp.:  25.38
# ================================================================================================================
#
#
# Epoch  14/ 50) lr = 0.0002362
#  b 150/710 >> 2895.6 ms/b | lr:  0.00023 | grad norm: 4.05 | max abs grad:   0.378 | loss: 3.49 | perp.:  32.93
#  b 300/710 >> 2908.7 ms/b | lr:  0.00026 | grad norm: 11.88 | max abs grad:   0.630 | loss: 3.49 | perp.:  32.85
#  b 450/710 >> 2893.9 ms/b | lr:  0.00022 | grad norm: 3.73 | max abs grad:   0.235 | loss: 3.41 | perp.:  30.17
#  b 600/710 >> 2898.9 ms/b | lr:  0.00023 | grad norm: 3.80 | max abs grad:   0.372 | loss: 3.38 | perp.:  29.42
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2042.66 sec | train_loss:  3.46 | train_perp:  31.80 | valid_loss:  3.02 | valid_perp.:  20.47
# ================================================================================================================
#
#
# Epoch  15/ 50) lr = 0.0002282
#  b 150/714 >> 2863.0 ms/b | lr:  0.00022 | grad norm: 3.63 | max abs grad:   0.336 | loss: 3.35 | perp.:  28.48
#  b 300/714 >> 2857.5 ms/b | lr:  0.00023 | grad norm: 6.49 | max abs grad:   0.766 | loss: 3.28 | perp.:  26.57
#  b 450/714 >> 2876.4 ms/b | lr:  0.00023 | grad norm: 3.91 | max abs grad:   0.289 | loss: 3.30 | perp.:  26.99
#  b 600/714 >> 2800.0 ms/b | lr:  0.00023 | grad norm: 9.94 | max abs grad:   0.851 | loss: 3.18 | perp.:  23.99
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2041.56 sec | train_loss:  3.30 | train_perp:  27.18 | valid_loss:  3.00 | valid_perp.:  20.03
# ================================================================================================================
#
#
# Epoch  16/ 50) lr = 0.000221
#  b 150/715 >> 2883.7 ms/b | lr:  0.00019 | grad norm: 5.01 | max abs grad:   0.415 | loss: 3.21 | perp.:  24.75
#  b 300/715 >> 2871.4 ms/b | lr:  0.00022 | grad norm: 5.10 | max abs grad:   0.468 | loss: 3.14 | perp.:  23.20
#  b 450/715 >> 2923.5 ms/b | lr:  0.00024 | grad norm: 9.20 | max abs grad:   0.748 | loss: 3.12 | perp.:  22.60
#  b 600/715 >> 3076.3 ms/b | lr:  0.00024 | grad norm: 9.99 | max abs grad:   0.923 | loss: 3.13 | perp.:  22.77
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2107.07 sec | train_loss:  3.17 | train_perp:  23.82 | valid_loss:  2.83 | valid_perp.:  16.89
# ================================================================================================================
#
#
# Epoch  17/ 50) lr = 0.0002144
#  b 150/717 >> 2942.6 ms/b | lr:  0.00023 | grad norm: 78.59 | max abs grad:   6.305 | loss: 3.12 | perp.:  22.68
#  b 300/717 >> 2966.1 ms/b | lr:  0.00023 | grad norm: 9.46 | max abs grad:   0.762 | loss: 3.03 | perp.:  20.68
#  b 450/717 >> 2844.1 ms/b | lr:  0.00025 | grad norm: 7.43 | max abs grad:   0.581 | loss: 3.09 | perp.:  21.97
#  b 600/717 >> 2802.9 ms/b | lr:  0.00021 | grad norm: 7.10 | max abs grad:   0.535 | loss: 3.07 | perp.:  21.64
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2067.78 sec | train_loss:  3.12 | train_perp:  22.59 | valid_loss:  2.83 | valid_perp.:  16.88
# ================================================================================================================
#
#
# Epoch  18/ 50) lr = 0.0002083
#  b 150/713 >> 2865.9 ms/b | lr:   0.0002 | grad norm: 14.75 | max abs grad:   1.276 | loss: 3.08 | perp.:  21.70
#  b 300/713 >> 2850.5 ms/b | lr:  0.00023 | grad norm: 112.48 | max abs grad:   4.245 | loss: 2.98 | perp.:  19.69
#  b 450/713 >> 2848.4 ms/b | lr:  0.00018 | grad norm: 733.06 | max abs grad:  62.707 | loss: 3.03 | perp.:  20.70
#  b 600/713 >> 2887.1 ms/b | lr:  0.00021 | grad norm: 6.80 | max abs grad:   0.457 | loss: 3.05 | perp.:  21.13
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2038.38 sec | train_loss:  3.08 | train_perp:  21.74 | valid_loss:  2.74 | valid_perp.:  15.44
# ================================================================================================================
#
#
# Epoch  19/ 50) lr = 0.0002028
#  b 150/725 >> 2813.5 ms/b | lr:  0.00019 | grad norm: 16.03 | max abs grad:   1.353 | loss: 2.97 | perp.:  19.52
#  b 300/725 >> 2844.9 ms/b | lr:  0.00022 | grad norm: 38.53 | max abs grad:   3.365 | loss: 2.96 | perp.:  19.39
#  b 450/725 >> 2829.4 ms/b | lr:   0.0002 | grad norm: 10.08 | max abs grad:   0.463 | loss: 2.93 | perp.:  18.75
#  b 600/725 >> 2731.0 ms/b | lr:   0.0002 | grad norm: 15.07 | max abs grad:   0.840 | loss: 2.90 | perp.:  18.17
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2038.36 sec | train_loss:  2.98 | train_perp:  19.60 | valid_loss:  2.70 | valid_perp.:  14.89
# ================================================================================================================
#
#
# Epoch  20/ 50) lr = 0.0001976
#  b 150/717 >> 2832.2 ms/b | lr:  0.00019 | grad norm: 4.24 | max abs grad:   0.479 | loss: 2.89 | perp.:  17.96
#  b 300/717 >> 2863.7 ms/b | lr:   0.0002 | grad norm: 12.15 | max abs grad:   0.855 | loss: 2.91 | perp.:  18.41
#  b 450/717 >> 2785.9 ms/b | lr:   0.0002 | grad norm: 5.37 | max abs grad:   0.293 | loss: 2.86 | perp.:  17.53
#  b 600/717 >> 2902.9 ms/b | lr:  0.00019 | grad norm: 4.69 | max abs grad:   0.306 | loss: 2.92 | perp.:  18.56
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2036.91 sec | train_loss:  2.94 | train_perp:  18.82 | valid_loss:  2.60 | valid_perp.:  13.51
# ================================================================================================================
#
#
# Epoch  21/ 50) lr = 0.0001929
#  b 150/709 >> 2885.5 ms/b | lr:  0.00019 | grad norm: 18.85 | max abs grad:   1.901 | loss: 2.94 | perp.:  19.01
#  b 300/709 >> 2914.0 ms/b | lr:  0.00017 | grad norm: 5.13 | max abs grad:   0.490 | loss: 2.90 | perp.:  18.08
#  b 450/709 >> 2844.4 ms/b | lr:   0.0002 | grad norm: 12.72 | max abs grad:   0.461 | loss: 2.85 | perp.:  17.29
#  b 600/709 >> 2916.7 ms/b | lr:   0.0002 | grad norm: 9.27 | max abs grad:   0.628 | loss: 2.87 | perp.:  17.72
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2076.53 sec | train_loss:  2.92 | train_perp:  18.53 | valid_loss:  2.50 | valid_perp.:  12.13
# ================================================================================================================
#
#
# Epoch  22/ 50) lr = 0.0001884
#  b 150/716 >> 3236.9 ms/b | lr:  0.00018 | grad norm: 4.28 | max abs grad:   0.340 | loss: 2.93 | perp.:  18.76
#  b 300/716 >> 3034.8 ms/b | lr:  0.00019 | grad norm: 11.30 | max abs grad:   0.769 | loss: 2.75 | perp.:  15.61
#  b 450/716 >> 3069.2 ms/b | lr:  0.00017 | grad norm: 7.98 | max abs grad:   0.757 | loss: 2.75 | perp.:  15.69
#  b 600/716 >> 2974.5 ms/b | lr:  0.00018 | grad norm: 5.03 | max abs grad:   0.374 | loss: 2.81 | perp.:  16.54
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2193.24 sec | train_loss:  2.86 | train_perp:  17.39 | valid_loss:  2.39 | valid_perp.:  10.95
# ================================================================================================================
#
#
# Epoch  23/ 50) lr = 0.0001843
#  b 150/718 >> 2939.9 ms/b | lr:  0.00017 | grad norm: 24.62 | max abs grad:   3.141 | loss: 2.81 | perp.:  16.64
#  b 300/718 >> 2756.5 ms/b | lr:  0.00018 | grad norm: 6.96 | max abs grad:   0.388 | loss: 2.76 | perp.:  15.82
#  b 450/718 >> 2867.1 ms/b | lr:  0.00018 | grad norm: 9.65 | max abs grad:   0.653 | loss: 2.72 | perp.:  15.24
#  b 600/718 >> 2870.9 ms/b | lr:  0.00017 | grad norm: 5.09 | max abs grad:   0.446 | loss: 2.76 | perp.:  15.79
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2049.48 sec | train_loss:  2.81 | train_perp:  16.53 | valid_loss:  2.50 | valid_perp.:  12.13
# ================================================================================================================
#
#
# Epoch  24/ 50) lr = 0.0001804
#  b 150/721 >> 2819.5 ms/b | lr:  0.00018 | grad norm: 5.23 | max abs grad:   0.232 | loss: 2.74 | perp.:  15.51
#  b 300/721 >> 2797.6 ms/b | lr:   0.0002 | grad norm: 7.56 | max abs grad:   0.550 | loss: 2.73 | perp.:  15.34
#  b 450/721 >> 2852.1 ms/b | lr:  0.00018 | grad norm: 17.32 | max abs grad:   2.116 | loss: 2.73 | perp.:  15.26
#  b 600/721 >> 2876.8 ms/b | lr:  0.00017 | grad norm: 4.65 | max abs grad:   0.420 | loss: 2.71 | perp.:  14.98
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2045.82 sec | train_loss:  2.78 | train_perp:  16.04 | valid_loss:  2.35 | valid_perp.:  10.47
# ================================================================================================================
#
#
# Epoch  25/ 50) lr = 0.0001768
#  b 150/722 >> 2833.6 ms/b | lr:  0.00017 | grad norm: 9.52 | max abs grad:   0.865 | loss: 2.70 | perp.:  14.82
#  b 300/722 >> 2829.3 ms/b | lr:  0.00014 | grad norm: 9.13 | max abs grad:   0.950 | loss: 2.73 | perp.:  15.37
#  b 450/722 >> 2874.4 ms/b | lr:  0.00019 | grad norm: 18.32 | max abs grad:   1.123 | loss: 2.76 | perp.:  15.75
#  b 600/722 >> 2780.6 ms/b | lr:  0.00017 | grad norm: 4.45 | max abs grad:   0.349 | loss: 2.63 | perp.:  13.86
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2038.58 sec | train_loss:  2.74 | train_perp:  15.51 | valid_loss:  3.04 | valid_perp.:  20.89
# ================================================================================================================
#
#
# Epoch  26/ 50) lr = 0.0001733
#  b 150/717 >> 2865.5 ms/b | lr:  0.00016 | grad norm: 5.00 | max abs grad:   0.519 | loss: 2.79 | perp.:  16.23
#  b 300/717 >> 2897.8 ms/b | lr:  0.00017 | grad norm: 8.35 | max abs grad:   0.484 | loss: 2.73 | perp.:  15.32
#  b 450/717 >> 2786.7 ms/b | lr:  0.00019 | grad norm: 13.26 | max abs grad:   1.064 | loss: 2.67 | perp.:  14.43
#  b 600/717 >> 2914.2 ms/b | lr:  0.00019 | grad norm: 17.15 | max abs grad:   1.043 | loss: 2.71 | perp.:  15.06
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2047.98 sec | train_loss:  2.75 | train_perp:  15.65 | valid_loss:  2.67 | valid_perp.:  14.41
# ================================================================================================================
#
#
# Epoch  27/ 50) lr = 0.0001701
#  b 150/716 >> 2844.9 ms/b | lr:  0.00017 | grad norm: 118.01 | max abs grad:   9.552 | loss: 2.59 | perp.:  13.28
#  b 300/716 >> 2873.3 ms/b | lr:  0.00017 | grad norm: 14.21 | max abs grad:   0.638 | loss: 2.74 | perp.:  15.47
#  b 450/716 >> 2852.3 ms/b | lr:  0.00017 | grad norm: 9.51 | max abs grad:   1.075 | loss: 2.56 | perp.:  12.99
#  b 600/716 >> 2858.0 ms/b | lr:  0.00017 | grad norm: 9.08 | max abs grad:   0.666 | loss: 2.64 | perp.:  14.02
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2043.08 sec | train_loss:  2.66 | train_perp:  14.25 | valid_loss:  2.18 | valid_perp.:   8.83
# ================================================================================================================
#
#
# Epoch  28/ 50) lr = 0.000167
#  b 150/720 >> 2852.8 ms/b | lr:  0.00017 | grad norm: 6.03 | max abs grad:   0.731 | loss: 2.63 | perp.:  13.87
#  b 300/720 >> 2858.0 ms/b | lr:  0.00015 | grad norm: 4.17 | max abs grad:   0.370 | loss: 2.60 | perp.:  13.45
#  b 450/720 >> 2875.5 ms/b | lr:  0.00015 | grad norm: 4.55 | max abs grad:   0.419 | loss: 2.56 | perp.:  12.93
#  b 600/720 >> 2858.6 ms/b | lr:  0.00017 | grad norm: 6.71 | max abs grad:   0.700 | loss: 2.51 | perp.:  12.34
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2046.57 sec | train_loss:  2.60 | train_perp:  13.44 | valid_loss:  2.13 | valid_perp.:   8.45
# ================================================================================================================
#
#
# Epoch  29/ 50) lr = 0.0001641
#  b 150/708 >> 2941.5 ms/b | lr:  0.00016 | grad norm: 4.55 | max abs grad:   0.250 | loss: 2.52 | perp.:  12.38
#  b 300/708 >> 2874.9 ms/b | lr:  0.00017 | grad norm: 11.28 | max abs grad:   0.617 | loss: 2.56 | perp.:  12.90
#  b 450/708 >> 2898.1 ms/b | lr:  0.00015 | grad norm: 5.39 | max abs grad:   0.436 | loss: 2.51 | perp.:  12.28
#  b 600/708 >> 2820.7 ms/b | lr:  0.00015 | grad norm: 7.99 | max abs grad:   0.953 | loss: 2.55 | perp.:  12.75
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2047.58 sec | train_loss:  2.56 | train_perp:  12.88 | valid_loss:  2.19 | valid_perp.:   8.92
# ================================================================================================================
#
#
# Epoch  30/ 50) lr = 0.0001614
#  b 150/727 >> 2805.9 ms/b | lr:  0.00017 | grad norm: 166.83 | max abs grad:  19.721 | loss: 2.52 | perp.:  12.42
#  b 300/727 >> 2811.0 ms/b | lr:  0.00014 | grad norm: 17.50 | max abs grad:   0.976 | loss: 2.45 | perp.:  11.59
#  b 450/727 >> 2817.3 ms/b | lr:  0.00017 | grad norm: 11.54 | max abs grad:   1.130 | loss: 2.48 | perp.:  11.94
#  b 600/727 >> 2787.3 ms/b | lr:  0.00016 | grad norm: 5.27 | max abs grad:   0.270 | loss: 2.44 | perp.:  11.49
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2044.85 sec | train_loss:  2.50 | train_perp:  12.21 | valid_loss:  2.15 | valid_perp.:   8.60
# ================================================================================================================
#
#
# Epoch  31/ 50) lr = 0.0001588
#  b 150/714 >> 2862.4 ms/b | lr:  0.00015 | grad norm: 4.30 | max abs grad:   0.290 | loss: 2.39 | perp.:  10.96
#  b 300/714 >> 2838.8 ms/b | lr:  0.00018 | grad norm: 10.83 | max abs grad:   0.798 | loss: 2.45 | perp.:  11.62
#  b 450/714 >> 2855.0 ms/b | lr:  0.00016 | grad norm: 11.90 | max abs grad:   1.054 | loss: 2.48 | perp.:  11.99
#  b 600/714 >> 2891.5 ms/b | lr:  0.00014 | grad norm: 3.23 | max abs grad:   0.182 | loss: 2.44 | perp.:  11.42
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2050.02 sec | train_loss:  2.48 | train_perp:  11.91 | valid_loss:  2.06 | valid_perp.:   7.86
# ================================================================================================================
#
#
# Epoch  32/ 50) lr = 0.0001563
#  b 150/723 >> 2808.3 ms/b | lr:  0.00015 | grad norm: 6.56 | max abs grad:   0.734 | loss: 2.49 | perp.:  12.12
#  b 300/723 >> 2915.6 ms/b | lr:  0.00016 | grad norm: 5.74 | max abs grad:   0.548 | loss: 2.41 | perp.:  11.09
#  b 450/723 >> 2890.2 ms/b | lr:  0.00012 | grad norm: 7.45 | max abs grad:   0.863 | loss: 2.37 | perp.:  10.69
#  b 600/723 >> 2846.4 ms/b | lr:  0.00015 | grad norm: 5.32 | max abs grad:   0.453 | loss: 2.34 | perp.:  10.39
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2069.35 sec | train_loss:  2.43 | train_perp:  11.36 | valid_loss:  2.03 | valid_perp.:   7.65
# ================================================================================================================
#
#
# Epoch  33/ 50) lr = 0.0001539
#  b 150/719 >> 2774.6 ms/b | lr:  0.00015 | grad norm: 9.75 | max abs grad:   1.080 | loss: 2.42 | perp.:  11.23
#  b 300/719 >> 2831.5 ms/b | lr:  0.00015 | grad norm: 4.25 | max abs grad:   0.381 | loss: 2.44 | perp.:  11.46
#  b 450/719 >> 2858.2 ms/b | lr:  0.00015 | grad norm: 28.42 | max abs grad:   1.268 | loss: 2.42 | perp.:  11.26
#  b 600/719 >> 2834.4 ms/b | lr:  0.00012 | grad norm: 5.75 | max abs grad:   0.451 | loss: 2.37 | perp.:  10.73
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2041.71 sec | train_loss:  2.44 | train_perp:  11.49 | valid_loss:  2.07 | valid_perp.:   7.96
# ================================================================================================================
#
#
# Epoch  34/ 50) lr = 0.0001516
#  b 150/719 >> 2867.2 ms/b | lr:  0.00014 | grad norm: 6.60 | max abs grad:   0.689 | loss: 2.47 | perp.:  11.77
#  b 300/719 >> 2907.7 ms/b | lr:  0.00015 | grad norm: 16.58 | max abs grad:   1.685 | loss: 2.41 | perp.:  11.11
#  b 450/719 >> 2762.5 ms/b | lr:  0.00013 | grad norm: 17.83 | max abs grad:   2.769 | loss: 2.30 | perp.:   9.95
#  b 600/719 >> 2862.3 ms/b | lr:  0.00015 | grad norm: 4.59 | max abs grad:   0.257 | loss: 2.40 | perp.:  11.01
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2038.23 sec | train_loss:  2.41 | train_perp:  11.16 | valid_loss:  1.97 | valid_perp.:   7.14
# ================================================================================================================
#
#
# Epoch  35/ 50) lr = 0.0001494
#  b 150/720 >> 2834.6 ms/b | lr:  0.00015 | grad norm: 5.69 | max abs grad:   0.247 | loss: 2.40 | perp.:  11.04
#  b 300/720 >> 2804.0 ms/b | lr:  0.00014 | grad norm: 5.95 | max abs grad:   0.567 | loss: 2.36 | perp.:  10.61
#  b 450/720 >> 2886.5 ms/b | lr:  0.00014 | grad norm: 101.40 | max abs grad:  10.918 | loss: 2.36 | perp.:  10.64
#  b 600/720 >> 2839.5 ms/b | lr:  0.00015 | grad norm: 9.04 | max abs grad:   0.746 | loss: 2.29 | perp.:   9.83
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2042.01 sec | train_loss:  2.37 | train_perp:  10.70 | valid_loss:  2.01 | valid_perp.:   7.44
# ================================================================================================================
#
#
# Epoch  36/ 50) lr = 0.0001473
#  b 150/715 >> 2814.2 ms/b | lr:  0.00013 | grad norm: 6.61 | max abs grad:   0.599 | loss: 2.22 | perp.:   9.24
#  b 300/715 >> 2844.4 ms/b | lr:  0.00013 | grad norm: 6.10 | max abs grad:   0.554 | loss: 2.30 | perp.:   9.94
#  b 450/715 >> 2891.2 ms/b | lr:  0.00014 | grad norm: 92.78 | max abs grad:   4.324 | loss: 2.38 | perp.:  10.79
#  b 600/715 >> 2846.7 ms/b | lr:  0.00015 | grad norm: 6.14 | max abs grad:   0.504 | loss: 2.32 | perp.:  10.18
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2040.95 sec | train_loss:  2.33 | train_perp:  10.28 | valid_loss:  1.91 | valid_perp.:   6.76
# ================================================================================================================
#
#
# Epoch  37/ 50) lr = 0.0001453
#  b 150/719 >> 2953.3 ms/b | lr:  0.00014 | grad norm: 4.97 | max abs grad:   0.461 | loss: 2.33 | perp.:  10.23
#  b 300/719 >> 2847.6 ms/b | lr:  0.00011 | grad norm: 7.07 | max abs grad:   0.652 | loss: 2.25 | perp.:   9.45
#  b 450/719 >> 2829.5 ms/b | lr:  0.00013 | grad norm: 9.43 | max abs grad:   0.825 | loss: 2.35 | perp.:  10.43
#  b 600/719 >> 2777.7 ms/b | lr:  0.00016 | grad norm: 18.21 | max abs grad:   0.932 | loss: 2.24 | perp.:   9.38
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2043.76 sec | train_loss:  2.31 | train_perp:  10.08 | valid_loss:  2.01 | valid_perp.:   7.49
# ================================================================================================================
#
#
# Epoch  38/ 50) lr = 0.0001434
#  b 150/709 >> 2884.2 ms/b | lr:  0.00011 | grad norm: 16.08 | max abs grad:   1.934 | loss: 2.32 | perp.:  10.13
#  b 300/709 >> 2885.0 ms/b | lr:  0.00011 | grad norm: 6.57 | max abs grad:   0.466 | loss: 2.28 | perp.:   9.79
#  b 450/709 >> 2903.6 ms/b | lr:  0.00014 | grad norm: 3.79 | max abs grad:   0.260 | loss: 2.31 | perp.:  10.08
#  b 600/709 >> 2907.0 ms/b | lr:  0.00013 | grad norm: 4.65 | max abs grad:   0.410 | loss: 2.43 | perp.:  11.37
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2051.89 sec | train_loss:  2.38 | train_perp:  10.80 | valid_loss:  2.18 | valid_perp.:   8.81
# ================================================================================================================
#
#
# Epoch  39/ 50) lr = 0.0001415
#  b 150/718 >> 2828.5 ms/b | lr:  0.00015 | grad norm: 21.45 | max abs grad:   2.017 | loss: 2.31 | perp.:  10.03
#  b 300/718 >> 2838.7 ms/b | lr:  0.00014 | grad norm: 8.96 | max abs grad:   0.539 | loss: 2.32 | perp.:  10.19
#  b 450/718 >> 2806.9 ms/b | lr:  0.00016 | grad norm: 25.93 | max abs grad:   1.589 | loss: 2.27 | perp.:   9.64
#  b 600/718 >> 2910.0 ms/b | lr:  0.00011 | grad norm: 13.52 | max abs grad:   1.710 | loss: 2.28 | perp.:   9.74
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2046.88 sec | train_loss:  2.31 | train_perp:  10.04 | valid_loss:  1.87 | valid_perp.:   6.49
# ================================================================================================================
#
#
# Epoch  40/ 50) lr = 0.0001398
#  b 150/716 >> 2832.4 ms/b | lr:  0.00013 | grad norm: 13.29 | max abs grad:   0.745 | loss: 2.31 | perp.:  10.03
#  b 300/716 >> 2837.8 ms/b | lr:  0.00014 | grad norm: 44.15 | max abs grad:   2.209 | loss: 2.21 | perp.:   9.09
#  b 450/716 >> 2864.1 ms/b | lr:  0.00014 | grad norm: 6.36 | max abs grad:   0.586 | loss: 2.21 | perp.:   9.10
#  b 600/716 >> 2875.7 ms/b | lr:  0.00014 | grad norm: 5.19 | max abs grad:   0.475 | loss: 2.17 | perp.:   8.73
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2045.67 sec | train_loss:  2.24 | train_perp:   9.42 | valid_loss:  1.87 | valid_perp.:   6.51
# ================================================================================================================
#
#
# Epoch  41/ 50) lr = 0.000138
#  b 150/726 >> 2753.4 ms/b | lr:  0.00012 | grad norm: 19.09 | max abs grad:   2.487 | loss: 2.16 | perp.:   8.71
#  b 300/726 >> 2864.7 ms/b | lr:  0.00013 | grad norm: 8.78 | max abs grad:   0.339 | loss: 2.13 | perp.:   8.39
#  b 450/726 >> 2819.3 ms/b | lr:  0.00015 | grad norm: 17.13 | max abs grad:   0.502 | loss: 2.19 | perp.:   8.98
#  b 600/726 >> 2866.6 ms/b | lr:  0.00012 | grad norm: 4.76 | max abs grad:   0.263 | loss: 2.23 | perp.:   9.30
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2044.04 sec | train_loss:  2.20 | train_perp:   9.07 | valid_loss:  1.81 | valid_perp.:   6.11
# ================================================================================================================
#
#
# Epoch  42/ 50) lr = 0.0001364
#  b 150/716 >> 2895.3 ms/b | lr:  0.00015 | grad norm: 23.14 | max abs grad:   0.895 | loss: 2.25 | perp.:   9.45
#  b 300/716 >> 2854.5 ms/b | lr:  0.00016 | grad norm: 17.93 | max abs grad:   0.700 | loss: 2.10 | perp.:   8.20
#  b 450/716 >> 2836.6 ms/b | lr:  0.00014 | grad norm: 23.22 | max abs grad:   1.283 | loss: 2.22 | perp.:   9.25
#  b 600/716 >> 2864.9 ms/b | lr:  0.00014 | grad norm: 17.12 | max abs grad:   1.423 | loss: 2.14 | perp.:   8.53
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2046.58 sec | train_loss:  2.19 | train_perp:   8.95 | valid_loss:  1.81 | valid_perp.:   6.12
# ================================================================================================================
#
#
# Epoch  43/ 50) lr = 0.0001348
#  b 150/727 >> 2814.4 ms/b | lr:  0.00013 | grad norm: 11.71 | max abs grad:   0.735 | loss: 2.19 | perp.:   8.97
#  b 300/727 >> 2835.2 ms/b | lr:  0.00015 | grad norm: 7.92 | max abs grad:   0.928 | loss: 2.22 | perp.:   9.25
#  b 450/727 >> 2775.7 ms/b | lr:  0.00014 | grad norm: 4.52 | max abs grad:   0.309 | loss: 2.20 | perp.:   9.05
#  b 600/727 >> 2781.1 ms/b | lr:  0.00012 | grad norm: 3.82 | max abs grad:   0.422 | loss: 2.16 | perp.:   8.70
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2043.47 sec | train_loss:  2.23 | train_perp:   9.26 | valid_loss:  1.80 | valid_perp.:   6.06
# ================================================================================================================
#
#
# Epoch  44/ 50) lr = 0.0001333
#  b 150/710 >> 2860.5 ms/b | lr:  0.00012 | grad norm: 6.02 | max abs grad:   0.579 | loss: 2.18 | perp.:   8.82
#  b 300/710 >> 2926.5 ms/b | lr:  0.00015 | grad norm: 14.48 | max abs grad:   0.614 | loss: 2.13 | perp.:   8.40
#  b 450/710 >> 2823.7 ms/b | lr:  0.00014 | grad norm: 20.24 | max abs grad:   0.863 | loss: 2.25 | perp.:   9.44
#  b 600/710 >> 2879.2 ms/b | lr:  0.00011 | grad norm: 3.60 | max abs grad:   0.219 | loss: 2.13 | perp.:   8.45
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2016.28 sec | train_loss:  2.19 | train_perp:   8.92 | valid_loss:  1.84 | valid_perp.:   6.28
# ================================================================================================================
#
#
# Epoch  45/ 50) lr = 0.0001318
#  b 150/718 >> 2648.7 ms/b | lr:  0.00014 | grad norm: 3.83 | max abs grad:   0.243 | loss: 2.20 | perp.:   9.03
#  b 300/718 >> 2604.9 ms/b | lr:  0.00012 | grad norm: 4.62 | max abs grad:   0.287 | loss: 2.10 | perp.:   8.19
#  b 450/718 >> 2649.2 ms/b | lr:  0.00014 | grad norm: 15.33 | max abs grad:   0.896 | loss: 2.07 | perp.:   7.92
#  b 600/718 >> 2692.1 ms/b | lr:  0.00013 | grad norm: 15.49 | max abs grad:   2.194 | loss: 2.09 | perp.:   8.08
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1900.83 sec | train_loss:  2.15 | train_perp:   8.57 | valid_loss:  1.80 | valid_perp.:   6.02
# ================================================================================================================
#
#
# Epoch  46/ 50) lr = 0.0001303
#  b 150/719 >> 2651.0 ms/b | lr:  0.00013 | grad norm: 4.05 | max abs grad:   0.280 | loss: 2.10 | perp.:   8.20
#  b 300/719 >> 2831.2 ms/b | lr:  0.00014 | grad norm: 11.47 | max abs grad:   0.639 | loss: 2.11 | perp.:   8.24
#  b 450/719 >> 2940.4 ms/b | lr:  0.00015 | grad norm: 26.23 | max abs grad:   0.939 | loss: 2.01 | perp.:   7.46
#  b 600/719 >> 2920.8 ms/b | lr:  0.00013 | grad norm: 81.58 | max abs grad:   7.207 | loss: 2.07 | perp.:   7.94
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2040.04 sec | train_loss:  2.09 | train_perp:   8.07 | valid_loss:  1.81 | valid_perp.:   6.09
# ================================================================================================================
#
#
# Epoch  47/ 50) lr = 0.0001289
#  b 150/717 >> 2875.3 ms/b | lr:  0.00013 | grad norm: 48.25 | max abs grad:   2.624 | loss: 2.10 | perp.:   8.20
#  b 300/717 >> 2881.5 ms/b | lr:  0.00013 | grad norm: 10.66 | max abs grad:   0.735 | loss: 2.12 | perp.:   8.29
#  b 450/717 >> 2847.4 ms/b | lr:  0.00011 | grad norm: 4.66 | max abs grad:   0.248 | loss: 2.06 | perp.:   7.86
#  b 600/717 >> 2890.5 ms/b | lr:  0.00012 | grad norm: 4.41 | max abs grad:   0.382 | loss: 2.11 | perp.:   8.23
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2044.17 sec | train_loss:  2.11 | train_perp:   8.27 | valid_loss:  2.36 | valid_perp.:  10.64
# ================================================================================================================
#
#
# Epoch  48/ 50) lr = 0.0001276
#  b 150/713 >> 2936.3 ms/b | lr:  0.00012 | grad norm: 8.33 | max abs grad:   0.822 | loss: 2.13 | perp.:   8.42
#  b 300/713 >> 2933.7 ms/b | lr:  0.00013 | grad norm: 233.67 | max abs grad:  22.326 | loss: 2.06 | perp.:   7.82
#  b 450/713 >> 2886.9 ms/b | lr:  0.00013 | grad norm: 15.43 | max abs grad:   1.619 | loss: 2.04 | perp.:   7.72
#  b 600/713 >> 2763.8 ms/b | lr:  0.00014 | grad norm: 5.69 | max abs grad:   0.516 | loss: 2.02 | perp.:   7.56
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2051.55 sec | train_loss:  2.09 | train_perp:   8.06 | valid_loss:  1.67 | valid_perp.:   5.32
# ================================================================================================================
#
#
# Epoch  49/ 50) lr = 0.0001263
#  b 150/715 >> 2851.6 ms/b | lr:  0.00013 | grad norm: 13.53 | max abs grad:   0.581 | loss: 2.02 | perp.:   7.54
#  b 300/715 >> 2845.6 ms/b | lr:  0.00011 | grad norm: 5.38 | max abs grad:   0.372 | loss: 2.03 | perp.:   7.62
#  b 450/715 >> 2880.7 ms/b | lr:  0.00013 | grad norm: 9.14 | max abs grad:   0.588 | loss: 2.05 | perp.:   7.81
#  b 600/715 >> 2904.5 ms/b | lr:  0.00012 | grad norm: 5.71 | max abs grad:   0.294 | loss: 2.06 | perp.:   7.87
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2044.89 sec | train_loss:  2.06 | train_perp:   7.83 | valid_loss:  1.68 | valid_perp.:   5.37
# ================================================================================================================
#
#
# Epoch  50/ 50) lr = 0.000125
#  b 150/712 >> 2845.8 ms/b | lr:  0.00011 | grad norm: 8.52 | max abs grad:   0.331 | loss: 2.03 | perp.:   7.58
#  b 300/712 >> 2851.9 ms/b | lr:  0.00013 | grad norm: 7.72 | max abs grad:   0.393 | loss: 2.04 | perp.:   7.67
#  b 450/712 >> 2958.9 ms/b | lr:  0.00012 | grad norm: 6.31 | max abs grad:   0.479 | loss: 2.02 | perp.:   7.58
#  b 600/712 >> 2892.1 ms/b | lr:  0.00013 | grad norm: 4.74 | max abs grad:   0.510 | loss: 1.98 | perp.:   7.26
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2083.20 sec | train_loss:  2.03 | train_perp:   7.64 | valid_loss:  1.74 | valid_perp.:   5.70
# ================================================================================================================

# %%
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    enc_states, attn_states, dec_states = states
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])

# %%
test_loss = evaluate(test_data, save_wts = True)
print('test_loss: {:5.2f} | test_perplexity: {:5.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss:  1.65 | test_perplexity:  5.21

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 7 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#   804    42    42    42    42   935  3257   674    24   804  2373    42   230
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#   230  1038   119   119   935
# [torch.LongTensor of size 2x18]
#
# 5 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#    27    27   109    27    64   133    27    27   169    27    27    24    24
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#  1041    32  5941  1256    64
# [torch.LongTensor of size 2x18]
#
# 5 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   148   119   119    42    32   119   119  5463  1656  1656    35  3509  2680
#
# Columns 13 to 17
#    26  5463   119    26    26
#    26  5463   119    26    26
# [torch.LongTensor of size 2x18]
#
# 3 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#   955   955    26   535   311   312    42    42  4467    26    99   227   448
#
# Columns 13 to 17
#    35    27    27  1479   108
#    35    27    27  1479   955
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
# List of modules in the model for reference:

# %%
modules = list(model.modules())
list(enumerate(modules))
# Out:
# [(0, RNNModel(
#     (drop): Dropout(p=0.1)
#     (relu): ReLU()
#     (embedding): Embedding(10000, 512)
#     (encoders): ModuleList(
#       (0): LSTM(512, 256, dropout=0.1)
#       (1): LSTM(256, 256, dropout=0.1)
#     )
#     (attn): RecurrentAttention(
#       (drop): Dropout(p=0.1)
#       (softmax): Softmax()
#       (sigmoid): Sigmoid()
#       (rnn_stack): ModuleList(
#         (0): LSTMCell(512, 256)
#       )
#       (loc_align): Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#       (alignment): Linear(in_features=768, out_features=1)
#       (attention): Linear(in_features=768, out_features=256)
#       (attn_act_fn): ReLU()
#     )
#     (decoders): ModuleList(
#       (0): LSTM(256, 256, dropout=0.1)
#       (1): LSTM(256, 512, dropout=0.1)
#     )
#     (embed_skip): Linear(in_features=512, out_features=256)
#     (decode_skip): Linear(in_features=256, out_features=512)
#     (projection): Linear(in_features=512, out_features=10000)
#     (log_softmax): LogSoftmax()
#   )),
#  (1, Dropout(p=0.1)),
#  (2, ReLU()),
#  (3, Embedding(10000, 512)),
#  (4, ModuleList(
#     (0): LSTM(512, 256, dropout=0.1)
#     (1): LSTM(256, 256, dropout=0.1)
#   )),
#  (5, LSTM(512, 256, dropout=0.1)),
#  (6, LSTM(256, 256, dropout=0.1)),
#  (7, RecurrentAttention(
#     (drop): Dropout(p=0.1)
#     (softmax): Softmax()
#     (sigmoid): Sigmoid()
#     (rnn_stack): ModuleList(
#       (0): LSTMCell(512, 256)
#     )
#     (loc_align): Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (alignment): Linear(in_features=768, out_features=1)
#     (attention): Linear(in_features=768, out_features=256)
#     (attn_act_fn): ReLU()
#   )),
#  (8, Dropout(p=0.1)),
#  (9, Softmax()),
#  (10, Sigmoid()),
#  (11, ModuleList(
#     (0): LSTMCell(512, 256)
#   )),
#  (12, LSTMCell(512, 256)),
#  (13, Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))),
#  (14, Linear(in_features=768, out_features=1)),
#  (15, Linear(in_features=768, out_features=256)),
#  (16, ReLU()),
#  (17, ModuleList(
#     (0): LSTM(256, 256, dropout=0.1)
#     (1): LSTM(256, 512, dropout=0.1)
#   )),
#  (18, LSTM(256, 256, dropout=0.1)),
#  (19, LSTM(256, 512, dropout=0.1)),
#  (20, Linear(in_features=512, out_features=256)),
#  (21, Linear(in_features=256, out_features=512)),
#  (22, Linear(in_features=512, out_features=10000)),
#  (23, LogSoftmax())]

# %% [markdown]
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(modules[3].weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = modules[7]

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Output attention sublayer (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 768)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()
