# %%
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from recurrent_attention import RecurrentAttention

# %% [markdown]
# ## Overhead stuff
#
# Helper functions for batching, resetting hidden states, etc.

# %%
# Data gen parameters
num_batches = 500
num_eval_batches = 20
ntokens = 7
dep_len = 6

# Training hyperparameters
eval_batch_size = 20
batch_size = 50
seq_len = 11
dropout = 0.1
clip = 1
lr = 0.05
warmup_steps = 5
decay_factor = 0.5  # Higher => faster learning rate decay
smoothing = 0.001

epochs = 50
log_interval = 100   # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 64
encode_size = 32
h_size = 16
decode_size = 64
n_enc_layers = 1
n_dec_layers = 1
smooth_align = True

bidirectional_attn = False

# %% [markdown]
# ## Generate data

# %%
# Generate some token transition probabilities
probs = np.random.randint(1, 10*ntokens, size = tuple(ntokens for _ in range(dep_len+1)))
# Normalize
probs = probs / (probs.sum(axis = -1)[..., np.newaxis])
probs.shape
# Out:
# (7, 7, 7, 7, 7, 7, 7)

# %%
def gen_data(num_batches, batch_size, seq_len):
    num_data = num_batches * batch_size * seq_len
    # Initialize numpy array for the generated data
    data = np.zeros((num_data,), dtype = int)
    # Randomly generate a series of starting tokens
    ts = [np.random.randint(ntokens, size = 1) for _ in range(dep_len)]
    # Generate the data
    for i in range(num_data):
        pr = probs[ts].squeeze()
        data[i] = np.random.choice(ntokens, p = pr)
        ts.pop(0)
        ts.append(data[i].reshape(1,1))
    return torch.from_numpy(data).type(torch.LongTensor)

# %% [markdown]
# ### Helper functions

# %%
# Starting from sequential data, `batchify` arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.
def batchify(data, batch_size):
    # Work out how cleanly we can divide the dataset into batches
    nbatches = data.size(0) // batch_size
    # Trim off any extra elements that wouldn't cleanly fit
    data = data.narrow(0, 0, nbatches * batch_size)
    # Evenly divide the data across the batches
    data = data.view(batch_size, -1).t().contiguous()
    return data  # [seq_len, batch_size]

# Wraps hidden states into new Variables to detach them from their history
def repackage_hidden(h):
    if type(h) == Variable:
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)
    
# `get_batch` subdivides the source data into chunks of the specified length.
# E.g., using the example for the `batchify` function above and a length of 2,
# we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the `batchify` function. The chunks are along dimension 0, corresponding
# to the `seq_len` dimension in the LSTM.
def get_batch(source, i, seq_len, evaluate = False):
    seq_len = min(seq_len, len(source) - 1 - i)
    data = Variable(source[i : i+seq_len], volatile = evaluate)
    target = Variable(source[i+1 : i+1+seq_len].view(-1), volatile = evaluate)
    return data, target

# %%
train_data = batchify(gen_data(num_batches, batch_size, seq_len), batch_size)
val_data = batchify(gen_data(num_eval_batches, batch_size, seq_len), eval_batch_size)
test_data = batchify(gen_data(num_eval_batches, batch_size, seq_len), eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([5500, 50]), torch.Size([550, 20]), torch.Size([550, 20]))

# %% [markdown]
# Label smoothing class for regularization.

# %%
class LabelSmoothing(nn.Module):
    def __init__(self, size, padding_idx = None, smoothing = 0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss()
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = torch.zeros_like(x.data)
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist.add_(self.smoothing / self.size)
        if self.padding_idx is not None:
            true_dist[:, self.padding_idx] = 0
            mask = torch.nonzero(target.data == self.padding_idx)
            if mask.dim() > 0:
                true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad = False)) * ntokens

# %% [markdown]
# Learning rate scheduler that sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
def get_lr_scheduler(h_size, warmup, optimizer):
    lrate = lambda e: h_size**(-0.5) * min((e+1)**(-decay_factor), (e+1) * warmup**(-(decay_factor+1)))
    return optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lrate)

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.1f:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.1f:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.1f:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.1f:%d:%d" % (lr, embed_size, warmup_steps),
])

# %% [markdown]
# ## Model class

# %%
class RNNModel(nn.Module):
    def __init__(self, src_vocab, tgt_vocab, embed_size, encode_size, h_size,
                 decode_size, n_enc_layers, n_dec_layers, align_location = False,
                 loc_align_size = 1, loc_align_kernel = 1, smooth_align = False,
                 bidirectional_attn = False, tie_wts = True, dropout = 0.1):
        super(RNNModel, self).__init__()
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.embed_size = embed_size
        self.encode_size = encode_size
        self.h_size = h_size
        self.decode_size = decode_size
        self.n_enc_layers = n_enc_layers
        self.n_dec_layers = n_dec_layers
        self.align_location = align_location
        self.loc_align_size = loc_align_size
        self.loc_align_kernel = loc_align_kernel
        self.smooth_align = smooth_align
        self.bidirectional_attn = bidirectional_attn
        self.tie_wts = tie_wts
        self.dropout = dropout
        
        self.drop = nn.Dropout(dropout)
        self.relu = nn.ReLU()
        
        self.embedding = nn.Embedding(src_vocab, embed_size)
        self.encoders = nn.ModuleList([
            nn.LSTM(
                input_size = embed_size if i == 0 else encode_size,
                hidden_size = encode_size, dropout = dropout
            ) for i in range(n_enc_layers)
        ])
        self.attn = RecurrentAttention(
            in_size = encode_size, h_size = h_size, out_size = decode_size,
            align_location = align_location, loc_align_size = loc_align_size,
            loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
            num_rnn_layers = n_dec_layers, attn_act_fn = 'ReLU',
            dropout = dropout, bidirectional = bidirectional_attn
        )
        self.projection = nn.Linear(decode_size, tgt_vocab)
        if tie_wts and src_vocab == tgt_vocab and embed_size == decode_size:
            self.embedding.weight = self.projection.weight
        self.log_softmax = nn.LogSoftmax(dim = -1)
            
        # For visualizations
        self.save_wts = False
        self.enc_out = None
        self.dec_out = None
        
    def init(self):
        for layer in self.encoders:
            for p in layer.parameters():
                if p.dim() > 1:
                    nn.init.xavier_normal(p)
                else:
                    p.data.fill_(0)
        for p in self.projection.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform(p)
            else:
                p.data.fill_(0)
        self.attn.init()
        
    def init_states(self, batch_size):
        encoder_states = [
            (
                Variable(torch.zeros(1, batch_size, self.encode_size)),
                Variable(torch.zeros(1, batch_size, self.encode_size))
            ) for _ in range(self.n_enc_layers)
        ]
        attn_states = self.attn.init_rnn_states(batch_size)
        return encoder_states, attn_states
    
    def forward(self, inputs, states):
        enc_states, attn_states = states
        if self.save_wts:
            self.enc_out = []
        
        embeddings = self.embedding(inputs) * np.sqrt(self.embed_size)
        
        new_enc_states = []
        enc_in = self.drop(self.relu(embeddings))
        for states, encoder in zip(enc_states, self.encoders):
            enc_out, new_enc_state = encoder(enc_in, states)
            new_enc_states.append(new_enc_state)
            if self.save_wts:
                self.enc_out.append(enc_out.data.clone())
            enc_in = enc_out
                
        attn_out, new_attn_states = self.attn(enc_out, attn_states)
        
        logits = self.projection(attn_out)
        output = self.log_softmax(logits)
        
        return output, (new_enc_states, new_attn_states)
    
    def train(self, mode = True, save_wts = False):
        super(RNNModel, self).train(mode)
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts
        
    def eval(self, save_wts = True):
        super(RNNModel, self).eval()
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler

# %%
model = RNNModel(
    ntokens, ntokens, embed_size, encode_size,
    h_size, decode_size, n_enc_layers, n_dec_layers,
    dropout = dropout, smooth_align = smooth_align
)
model.init()
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 27576

# %% [markdown]
# ## Train

# %% [markdown]
# Define training and validation loops

# %%
def train():
    # Use random length sequences
    seq_lens = []
    tot_len = 0
    jitter = 0.15 * seq_len
    num_data = train_data.size(0)
    while tot_len < num_data - 2:
        if num_data - tot_len - 2 <= seq_len + jitter:
            slen = num_data - tot_len - 2
        else:
            slen = int(np.random.normal(seq_len, jitter))
            if slen <= 0:
                slen = seq_len    # eh
            if tot_len + slen >= num_data - jitter - 2:
                slen = num_data - tot_len - 2
        seq_lens.append(slen)
        tot_len += slen
    i_cumseq = [0] + list(np.cumsum(seq_lens)[:-1])
    idx = np.arange(len(seq_lens))
    np.random.shuffle(idx)
    # Turn on training mode
    model.train(save_wts = False)
    # Initialize RNN states
    states = model.init_states(batch_size)
    # Prep metainfo
    total_loss = 0
    total_epoch_loss = 0
    start_time = time.time()
    for batch, i in enumerate(idx):
        # Get training data
        data, targets = get_batch(train_data, i_cumseq[i], seq_lens[i])
        # Repackage the hidden states
        states = model.init_states(batch_size)  #repackage_hidden(states)
        # Zero out gradients
        model.zero_grad()
        
        # Run the model forward
        output, _states = model(data, states)
        if np.isnan(output.data).any():
            return 0, total_epoch_loss[0], data, targets, states, _states
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        if np.isnan(loss.data[0]):
            return 1, total_epoch_loss[0], data, targets, states, _states
        states = _states
        # Propagate loss gradient backwards
        loss.backward()
        # Clip gradients
        if batch % log_interval == 0 and batch > 0:
            # Save gradient statistics before they're changed cuz we'll be logging this batch
            parameters = [p for p in model.parameters() if p.grad is not None]
            # Calculate the largest (absolute) gradient of all elements in the model parameters
            max_grad = max([p.grad.data.abs().max() for p in parameters])
        total_norm = nn.utils.clip_grad_norm(model.parameters(), clip)
        # Scale the batch learning rate so that shorter sequences aren't "stronger"
        scaled_lr = lr_scheduler.get_lr()[0] * np.sqrt(seq_lens[i] / seq_len)
        for param_group in optimizer.param_groups:
            param_group['lr'] = scaled_lr
        # Update parameters
        optimizer.step()
        
        # Get some metainfo
        total_loss += loss.data
        total_epoch_loss += loss.data * data.size(0)
        if batch % log_interval == 0 and batch > 0:
            elapsed = time.time() - start_time
            cur_loss = total_loss[0] / log_interval
            print(' b {:3d}/{:3d} >> {:6.1f} ms/b | lr: {:8.2g} | grad norm: {:4.2f} | max abs grad: {:7.3f} | loss: {:4.2f} | perp.: {:6.2f}'.format(
                batch, len(seq_lens), elapsed * 1000/log_interval, scaled_lr, total_norm, max_grad, cur_loss, np.exp(cur_loss)
            ))
            total_loss = 0
            start_time = time.time()
    return -1, total_epoch_loss[0] / num_data, None, None, None, None

# %%
def evaluate(data_src, save_wts = True):
    model.eval(save_wts = save_wts)
    total_loss = 0
    states = model.init_states(eval_batch_size)
    for i in range(0, data_src.size(0) - 1, seq_len):
        # Get data
        data, targets = get_batch(data_src, i, seq_len, evaluate = True)
        # Repackage the hidden states
        states = model.init_states(eval_batch_size)  #repackage_hidden(states)
        # Evaluate
        output, states = model(data, states)
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        total_loss += loss.data * data.size(0)
    return total_loss[0] / data_src.size(0)

# %% [markdown]
# Train and evaluate

# %%
WIDTH = 112
CAUSES = ['output', 'grad']
for epoch in range(epochs):
    lr_scheduler.step()
    print('Epoch {:3d}/{:3d}) lr = {:0.4g}{}'.format(epoch+1, epochs, np.mean(lr_scheduler.get_lr()[0]), ' (warmup)' if epoch < warmup_steps else ''))
    start_time = time.time()
    stat, train_loss, data, targets, states, nstates = train()
    if stat in list(range(len(CAUSES))):
        c = CAUSES[stat]
        n = (WIDTH - len(c) - 4) // 2
        print('\n' + (' '*n) + 'NaN ' + c)
        break
    elapsed = time.time() - start_time
    val_loss = evaluate(val_data, save_wts = False)
    max_param = max([p.data.abs().max() for p in model.parameters() if p.grad is not None])
    print('-' * WIDTH)
    print('Elapsed time: {:6.2f} sec | train_loss: {:5.2f} | train_perp: {:6.2f} | valid_loss: {:5.2f} | valid_perp.: {:6.2f}'.format(
        elapsed, train_loss, np.exp(train_loss), val_loss, np.exp(val_loss)
    ))
    print('=' * WIDTH)
    print('\n')
# Out:
# Epoch   1/ 50) lr = 0.000559 (warmup)
#  b 100/525 >>   21.1 ms/b | lr:  0.00041 | grad norm: 0.33 | max abs grad:   0.037 | loss: 1.88 | perp.:   6.55
#  b 200/525 >>   19.7 ms/b | lr:  0.00056 | grad norm: 0.32 | max abs grad:   0.030 | loss: 1.77 | perp.:   5.85
#  b 300/525 >>   19.8 ms/b | lr:  0.00056 | grad norm: 0.28 | max abs grad:   0.028 | loss: 1.73 | perp.:   5.66
#  b 400/525 >>   19.6 ms/b | lr:  0.00058 | grad norm: 0.29 | max abs grad:   0.022 | loss: 1.71 | perp.:   5.52
#  b 500/525 >>   22.1 ms/b | lr:  0.00058 | grad norm: 0.38 | max abs grad:   0.033 | loss: 1.70 | perp.:   5.48
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.75 sec | train_loss:  1.75 | train_perp:   5.78 | valid_loss:  1.68 | valid_perp.:   5.37
# ================================================================================================================
#
#
# Epoch   2/ 50) lr = 0.001118 (warmup)
#  b 100/532 >>   20.8 ms/b | lr:    0.001 | grad norm: 0.40 | max abs grad:   0.047 | loss: 1.70 | perp.:   5.45
#  b 200/532 >>   21.0 ms/b | lr:   0.0011 | grad norm: 0.58 | max abs grad:   0.085 | loss: 1.64 | perp.:   5.14
#  b 300/532 >>   21.4 ms/b | lr:   0.0011 | grad norm: 0.63 | max abs grad:   0.086 | loss: 1.62 | perp.:   5.06
#  b 400/532 >>   21.0 ms/b | lr:  0.00095 | grad norm: 0.70 | max abs grad:   0.063 | loss: 1.57 | perp.:   4.82
#  b 500/532 >>   23.7 ms/b | lr:   0.0011 | grad norm: 0.42 | max abs grad:   0.039 | loss: 1.54 | perp.:   4.66
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.43 sec | train_loss:  1.61 | train_perp:   5.01 | valid_loss:  1.47 | valid_perp.:   4.34
# ================================================================================================================
#
#
# Epoch   3/ 50) lr = 0.001677 (warmup)
#  b 100/527 >>   21.2 ms/b | lr:   0.0018 | grad norm: 0.70 | max abs grad:   0.103 | loss: 1.48 | perp.:   4.41
#  b 200/527 >>   22.6 ms/b | lr:   0.0015 | grad norm: 0.72 | max abs grad:   0.060 | loss: 1.41 | perp.:   4.11
#  b 300/527 >>   20.4 ms/b | lr:   0.0017 | grad norm: 0.71 | max abs grad:   0.072 | loss: 1.37 | perp.:   3.93
#  b 400/527 >>   22.2 ms/b | lr:   0.0016 | grad norm: 0.60 | max abs grad:   0.058 | loss: 1.34 | perp.:   3.84
#  b 500/527 >>   21.8 ms/b | lr:   0.0014 | grad norm: 1.90 | max abs grad:   0.133 | loss: 1.31 | perp.:   3.69
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.43 sec | train_loss:  1.38 | train_perp:   3.99 | valid_loss:  1.21 | valid_perp.:   3.36
# ================================================================================================================
#
#
# Epoch   4/ 50) lr = 0.002236 (warmup)
#  b 100/522 >>   21.3 ms/b | lr:   0.0022 | grad norm: 0.92 | max abs grad:   0.078 | loss: 1.29 | perp.:   3.62
#  b 200/522 >>   21.6 ms/b | lr:   0.0021 | grad norm: 0.75 | max abs grad:   0.069 | loss: 1.23 | perp.:   3.42
#  b 300/522 >>   21.3 ms/b | lr:    0.002 | grad norm: 1.16 | max abs grad:   0.084 | loss: 1.21 | perp.:   3.34
#  b 400/522 >>   19.5 ms/b | lr:    0.002 | grad norm: 0.93 | max abs grad:   0.076 | loss: 1.15 | perp.:   3.16
#  b 500/522 >>   21.4 ms/b | lr:   0.0021 | grad norm: 0.95 | max abs grad:   0.078 | loss: 1.12 | perp.:   3.07
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.94 sec | train_loss:  1.21 | train_perp:   3.35 | valid_loss:  1.04 | valid_perp.:   2.83
# ================================================================================================================
#
#
# Epoch   5/ 50) lr = 0.002795 (warmup)
#  b 100/529 >>   20.3 ms/b | lr:   0.0028 | grad norm: 0.92 | max abs grad:   0.077 | loss: 1.11 | perp.:   3.04
#  b 200/529 >>   19.5 ms/b | lr:   0.0027 | grad norm: 0.79 | max abs grad:   0.058 | loss: 1.07 | perp.:   2.90
#  b 300/529 >>   20.5 ms/b | lr:   0.0029 | grad norm: 0.73 | max abs grad:   0.083 | loss: 1.03 | perp.:   2.79
#  b 400/529 >>   19.7 ms/b | lr:   0.0024 | grad norm: 2.68 | max abs grad:   0.216 | loss: 1.01 | perp.:   2.75
#  b 500/529 >>   21.6 ms/b | lr:   0.0027 | grad norm: 0.99 | max abs grad:   0.117 | loss: 0.99 | perp.:   2.69
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.73 sec | train_loss:  1.05 | train_perp:   2.87 | valid_loss:  0.88 | valid_perp.:   2.41
# ================================================================================================================
#
#
# Epoch   6/ 50) lr = 0.002552
#  b 100/521 >>   20.3 ms/b | lr:   0.0029 | grad norm: 0.81 | max abs grad:   0.079 | loss: 0.99 | perp.:   2.69
#  b 200/521 >>   21.1 ms/b | lr:   0.0024 | grad norm: 1.39 | max abs grad:   0.118 | loss: 0.92 | perp.:   2.50
#  b 300/521 >>   19.8 ms/b | lr:   0.0022 | grad norm: 1.10 | max abs grad:   0.150 | loss: 0.93 | perp.:   2.53
#  b 400/521 >>   20.4 ms/b | lr:   0.0024 | grad norm: 1.20 | max abs grad:   0.175 | loss: 0.89 | perp.:   2.45
#  b 500/521 >>   20.2 ms/b | lr:   0.0027 | grad norm: 0.94 | max abs grad:   0.121 | loss: 0.89 | perp.:   2.42
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.60 sec | train_loss:  0.94 | train_perp:   2.55 | valid_loss:  0.75 | valid_perp.:   2.13
# ================================================================================================================
#
#
# Epoch   7/ 50) lr = 0.002362
#  b 100/522 >>   20.1 ms/b | lr:   0.0026 | grad norm: 1.09 | max abs grad:   0.114 | loss: 0.89 | perp.:   2.44
#  b 200/522 >>   19.2 ms/b | lr:   0.0021 | grad norm: 0.89 | max abs grad:   0.093 | loss: 0.84 | perp.:   2.32
#  b 300/522 >>   20.9 ms/b | lr:   0.0019 | grad norm: 3.60 | max abs grad:   0.385 | loss: 0.83 | perp.:   2.29
#  b 400/522 >>   19.5 ms/b | lr:    0.002 | grad norm: 2.31 | max abs grad:   0.213 | loss: 0.82 | perp.:   2.27
#  b 500/522 >>   19.6 ms/b | lr:   0.0023 | grad norm: 1.18 | max abs grad:   0.112 | loss: 0.80 | perp.:   2.22
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.34 sec | train_loss:  0.85 | train_perp:   2.34 | valid_loss:  0.66 | valid_perp.:   1.94
# ================================================================================================================
#
#
# Epoch   8/ 50) lr = 0.00221
#  b 100/524 >>   20.0 ms/b | lr:   0.0019 | grad norm: 1.87 | max abs grad:   0.213 | loss: 0.78 | perp.:   2.18
#  b 200/524 >>   19.9 ms/b | lr:   0.0023 | grad norm: 1.20 | max abs grad:   0.140 | loss: 0.78 | perp.:   2.17
#  b 300/524 >>   20.1 ms/b | lr:    0.002 | grad norm: 1.30 | max abs grad:   0.207 | loss: 0.76 | perp.:   2.14
#  b 400/524 >>   20.7 ms/b | lr:   0.0024 | grad norm: 1.32 | max abs grad:   0.126 | loss: 0.74 | perp.:   2.10
#  b 500/524 >>   18.7 ms/b | lr:    0.002 | grad norm: 2.14 | max abs grad:   0.240 | loss: 0.74 | perp.:   2.10
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.44 sec | train_loss:  0.78 | train_perp:   2.18 | valid_loss:  0.58 | valid_perp.:   1.79
# ================================================================================================================
#
#
# Epoch   9/ 50) lr = 0.002083
#  b 100/524 >>   20.2 ms/b | lr:   0.0019 | grad norm: 1.73 | max abs grad:   0.223 | loss: 0.74 | perp.:   2.10
#  b 200/524 >>   19.8 ms/b | lr:   0.0019 | grad norm: 1.48 | max abs grad:   0.162 | loss: 0.73 | perp.:   2.08
#  b 300/524 >>   21.0 ms/b | lr:   0.0021 | grad norm: 1.62 | max abs grad:   0.153 | loss: 0.71 | perp.:   2.03
#  b 400/524 >>   19.7 ms/b | lr:   0.0021 | grad norm: 1.45 | max abs grad:   0.165 | loss: 0.72 | perp.:   2.05
#  b 500/524 >>   20.8 ms/b | lr:    0.002 | grad norm: 1.56 | max abs grad:   0.150 | loss: 0.72 | perp.:   2.05
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.58 sec | train_loss:  0.74 | train_perp:   2.09 | valid_loss:  0.56 | valid_perp.:   1.75
# ================================================================================================================
#
#
# Epoch  10/ 50) lr = 0.001976
#  b 100/522 >>   20.3 ms/b | lr:   0.0019 | grad norm: 2.48 | max abs grad:   0.288 | loss: 0.70 | perp.:   2.01
#  b 200/522 >>   20.3 ms/b | lr:   0.0021 | grad norm: 1.05 | max abs grad:   0.139 | loss: 0.71 | perp.:   2.03
#  b 300/522 >>   19.3 ms/b | lr:   0.0017 | grad norm: 1.35 | max abs grad:   0.223 | loss: 0.66 | perp.:   1.93
#  b 400/522 >>   20.6 ms/b | lr:   0.0021 | grad norm: 1.79 | max abs grad:   0.219 | loss: 0.68 | perp.:   1.97
#  b 500/522 >>   20.3 ms/b | lr:   0.0017 | grad norm: 2.08 | max abs grad:   0.190 | loss: 0.67 | perp.:   1.96
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.47 sec | train_loss:  0.70 | train_perp:   2.01 | valid_loss:  0.50 | valid_perp.:   1.65
# ================================================================================================================
#
#
# Epoch  11/ 50) lr = 0.001884
#  b 100/520 >>   20.1 ms/b | lr:   0.0019 | grad norm: 1.37 | max abs grad:   0.147 | loss: 0.68 | perp.:   1.97
#  b 200/520 >>   19.5 ms/b | lr:    0.002 | grad norm: 1.24 | max abs grad:   0.194 | loss: 0.63 | perp.:   1.88
#  b 300/520 >>   20.0 ms/b | lr:    0.002 | grad norm: 1.42 | max abs grad:   0.215 | loss: 0.66 | perp.:   1.93
#  b 400/520 >>   20.3 ms/b | lr:    0.002 | grad norm: 1.26 | max abs grad:   0.145 | loss: 0.64 | perp.:   1.90
#  b 500/520 >>   19.5 ms/b | lr:   0.0018 | grad norm: 1.15 | max abs grad:   0.126 | loss: 0.65 | perp.:   1.92
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.32 sec | train_loss:  0.67 | train_perp:   1.95 | valid_loss:  0.47 | valid_perp.:   1.60
# ================================================================================================================
#
#
# Epoch  12/ 50) lr = 0.001804
#  b 100/525 >>   19.3 ms/b | lr:   0.0019 | grad norm: 1.21 | max abs grad:   0.124 | loss: 0.64 | perp.:   1.90
#  b 200/525 >>   20.0 ms/b | lr:   0.0016 | grad norm: 1.40 | max abs grad:   0.148 | loss: 0.64 | perp.:   1.90
#  b 300/525 >>   19.8 ms/b | lr:    0.002 | grad norm: 1.52 | max abs grad:   0.143 | loss: 0.61 | perp.:   1.84
#  b 400/525 >>   20.9 ms/b | lr:   0.0014 | grad norm: 2.17 | max abs grad:   0.202 | loss: 0.63 | perp.:   1.88
#  b 500/525 >>   20.1 ms/b | lr:   0.0017 | grad norm: 1.42 | max abs grad:   0.149 | loss: 0.60 | perp.:   1.82
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.59 sec | train_loss:  0.64 | train_perp:   1.90 | valid_loss:  0.46 | valid_perp.:   1.58
# ================================================================================================================
#
#
# Epoch  13/ 50) lr = 0.001733
#  b 100/517 >>   19.9 ms/b | lr:   0.0017 | grad norm: 1.03 | max abs grad:   0.149 | loss: 0.61 | perp.:   1.85
#  b 200/517 >>   22.8 ms/b | lr:   0.0017 | grad norm: 1.62 | max abs grad:   0.326 | loss: 0.61 | perp.:   1.84
#  b 300/517 >>   20.2 ms/b | lr:   0.0015 | grad norm: 1.88 | max abs grad:   0.171 | loss: 0.61 | perp.:   1.84
#  b 400/517 >>   21.2 ms/b | lr:    0.002 | grad norm: 1.62 | max abs grad:   0.244 | loss: 0.62 | perp.:   1.86
#  b 500/517 >>   21.5 ms/b | lr:   0.0017 | grad norm: 1.32 | max abs grad:   0.185 | loss: 0.61 | perp.:   1.84
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.84 sec | train_loss:  0.63 | train_perp:   1.88 | valid_loss:  0.49 | valid_perp.:   1.63
# ================================================================================================================
#
#
# Epoch  14/ 50) lr = 0.00167
#  b 100/520 >>   21.2 ms/b | lr:   0.0017 | grad norm: 1.30 | max abs grad:   0.156 | loss: 0.61 | perp.:   1.85
#  b 200/520 >>   21.1 ms/b | lr:   0.0016 | grad norm: 1.47 | max abs grad:   0.259 | loss: 0.60 | perp.:   1.82
#  b 300/520 >>   19.6 ms/b | lr:   0.0016 | grad norm: 1.67 | max abs grad:   0.167 | loss: 0.61 | perp.:   1.84
#  b 400/520 >>   20.1 ms/b | lr:   0.0018 | grad norm: 1.10 | max abs grad:   0.135 | loss: 0.58 | perp.:   1.78
#  b 500/520 >>   20.0 ms/b | lr:   0.0016 | grad norm: 1.17 | max abs grad:   0.144 | loss: 0.58 | perp.:   1.78
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.57 sec | train_loss:  0.61 | train_perp:   1.85 | valid_loss:  0.43 | valid_perp.:   1.53
# ================================================================================================================
#
#
# Epoch  15/ 50) lr = 0.001614
#  b 100/519 >>   22.7 ms/b | lr:   0.0015 | grad norm: 1.06 | max abs grad:   0.159 | loss: 0.58 | perp.:   1.79
#  b 200/519 >>   20.6 ms/b | lr:   0.0015 | grad norm: 1.05 | max abs grad:   0.103 | loss: 0.56 | perp.:   1.75
#  b 300/519 >>   21.1 ms/b | lr:   0.0017 | grad norm: 1.23 | max abs grad:   0.167 | loss: 0.58 | perp.:   1.79
#  b 400/519 >>   22.4 ms/b | lr:   0.0017 | grad norm: 1.38 | max abs grad:   0.197 | loss: 0.56 | perp.:   1.75
#  b 500/519 >>   19.1 ms/b | lr:   0.0014 | grad norm: 1.12 | max abs grad:   0.135 | loss: 0.57 | perp.:   1.76
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.95 sec | train_loss:  0.58 | train_perp:   1.79 | valid_loss:  0.40 | valid_perp.:   1.50
# ================================================================================================================
#
#
# Epoch  16/ 50) lr = 0.001563
#  b 100/527 >>   18.7 ms/b | lr:   0.0013 | grad norm: 1.14 | max abs grad:   0.172 | loss: 0.56 | perp.:   1.76
#  b 200/527 >>   21.1 ms/b | lr:   0.0016 | grad norm: 2.10 | max abs grad:   0.242 | loss: 0.58 | perp.:   1.78
#  b 300/527 >>   18.6 ms/b | lr:   0.0017 | grad norm: 1.31 | max abs grad:   0.194 | loss: 0.55 | perp.:   1.74
#  b 400/527 >>   20.5 ms/b | lr:   0.0016 | grad norm: 1.44 | max abs grad:   0.169 | loss: 0.56 | perp.:   1.75
#  b 500/527 >>   19.5 ms/b | lr:   0.0013 | grad norm: 1.10 | max abs grad:   0.125 | loss: 0.55 | perp.:   1.74
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.32 sec | train_loss:  0.57 | train_perp:   1.77 | valid_loss:  0.39 | valid_perp.:   1.48
# ================================================================================================================
#
#
# Epoch  17/ 50) lr = 0.001516
#  b 100/528 >>   19.6 ms/b | lr:   0.0014 | grad norm: 2.06 | max abs grad:   0.224 | loss: 0.56 | perp.:   1.75
#  b 200/528 >>   19.6 ms/b | lr:   0.0012 | grad norm: 1.64 | max abs grad:   0.273 | loss: 0.54 | perp.:   1.71
#  b 300/528 >>   20.0 ms/b | lr:   0.0017 | grad norm: 2.42 | max abs grad:   0.419 | loss: 0.54 | perp.:   1.71
#  b 400/528 >>   19.9 ms/b | lr:   0.0017 | grad norm: 1.51 | max abs grad:   0.231 | loss: 0.53 | perp.:   1.70
#  b 500/528 >>   19.0 ms/b | lr:   0.0013 | grad norm: 1.01 | max abs grad:   0.105 | loss: 0.53 | perp.:   1.70
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.36 sec | train_loss:  0.55 | train_perp:   1.74 | valid_loss:  0.38 | valid_perp.:   1.47
# ================================================================================================================
#
#
# Epoch  18/ 50) lr = 0.001473
#  b 100/523 >>   19.7 ms/b | lr:   0.0013 | grad norm: 1.23 | max abs grad:   0.151 | loss: 0.53 | perp.:   1.71
#  b 200/523 >>   19.4 ms/b | lr:   0.0015 | grad norm: 1.41 | max abs grad:   0.270 | loss: 0.53 | perp.:   1.71
#  b 300/523 >>   21.0 ms/b | lr:   0.0014 | grad norm: 1.87 | max abs grad:   0.206 | loss: 0.54 | perp.:   1.71
#  b 400/523 >>   18.7 ms/b | lr:   0.0014 | grad norm: 1.62 | max abs grad:   0.328 | loss: 0.50 | perp.:   1.65
#  b 500/523 >>   20.5 ms/b | lr:   0.0012 | grad norm: 1.65 | max abs grad:   0.192 | loss: 0.53 | perp.:   1.70
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.36 sec | train_loss:  0.54 | train_perp:   1.72 | valid_loss:  0.37 | valid_perp.:   1.45
# ================================================================================================================
#
#
# Epoch  19/ 50) lr = 0.001434
#  b 100/523 >>   20.0 ms/b | lr:   0.0016 | grad norm: 1.50 | max abs grad:   0.194 | loss: 0.53 | perp.:   1.70
#  b 200/523 >>   19.2 ms/b | lr:   0.0014 | grad norm: 1.15 | max abs grad:   0.157 | loss: 0.53 | perp.:   1.69
#  b 300/523 >>   21.0 ms/b | lr:   0.0016 | grad norm: 1.51 | max abs grad:   0.229 | loss: 0.52 | perp.:   1.68
#  b 400/523 >>   19.5 ms/b | lr:   0.0013 | grad norm: 1.71 | max abs grad:   0.270 | loss: 0.53 | perp.:   1.70
#  b 500/523 >>   19.3 ms/b | lr:   0.0016 | grad norm: 1.74 | max abs grad:   0.335 | loss: 0.52 | perp.:   1.68
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.32 sec | train_loss:  0.54 | train_perp:   1.72 | valid_loss:  0.36 | valid_perp.:   1.44
# ================================================================================================================
#
#
# Epoch  20/ 50) lr = 0.001398
#  b 100/521 >>   19.7 ms/b | lr:   0.0015 | grad norm: 1.64 | max abs grad:   0.291 | loss: 0.55 | perp.:   1.73
#  b 200/521 >>   19.9 ms/b | lr:   0.0015 | grad norm: 1.28 | max abs grad:   0.184 | loss: 0.50 | perp.:   1.65
#  b 300/521 >>   20.4 ms/b | lr:   0.0016 | grad norm: 1.83 | max abs grad:   0.292 | loss: 0.53 | perp.:   1.70
#  b 400/521 >>   19.9 ms/b | lr:   0.0015 | grad norm: 1.96 | max abs grad:   0.275 | loss: 0.53 | perp.:   1.71
#  b 500/521 >>   20.1 ms/b | lr:   0.0013 | grad norm: 1.61 | max abs grad:   0.262 | loss: 0.51 | perp.:   1.67
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.42 sec | train_loss:  0.54 | train_perp:   1.72 | valid_loss:  0.35 | valid_perp.:   1.42
# ================================================================================================================
#
#
# Epoch  21/ 50) lr = 0.001364
#  b 100/524 >>   21.2 ms/b | lr:   0.0014 | grad norm: 1.14 | max abs grad:   0.130 | loss: 0.52 | perp.:   1.68
#  b 200/524 >>   19.8 ms/b | lr:   0.0012 | grad norm: 1.72 | max abs grad:   0.205 | loss: 0.53 | perp.:   1.69
#  b 300/524 >>   18.7 ms/b | lr:   0.0013 | grad norm: 1.25 | max abs grad:   0.155 | loss: 0.50 | perp.:   1.64
#  b 400/524 >>   21.5 ms/b | lr:   0.0012 | grad norm: 1.68 | max abs grad:   0.208 | loss: 0.51 | perp.:   1.66
#  b 500/524 >>   19.3 ms/b | lr:   0.0014 | grad norm: 2.10 | max abs grad:   0.432 | loss: 0.49 | perp.:   1.64
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.49 sec | train_loss:  0.52 | train_perp:   1.68 | valid_loss:  0.36 | valid_perp.:   1.43
# ================================================================================================================
#
#
# Epoch  22/ 50) lr = 0.001333
#  b 100/524 >>   20.1 ms/b | lr:   0.0011 | grad norm: 1.77 | max abs grad:   0.234 | loss: 0.51 | perp.:   1.67
#  b 200/524 >>   19.9 ms/b | lr:   0.0013 | grad norm: 1.47 | max abs grad:   0.215 | loss: 0.49 | perp.:   1.64
#  b 300/524 >>   20.2 ms/b | lr:   0.0013 | grad norm: 1.11 | max abs grad:   0.140 | loss: 0.50 | perp.:   1.64
#  b 400/524 >>   22.5 ms/b | lr:   0.0013 | grad norm: 1.65 | max abs grad:   0.233 | loss: 0.52 | perp.:   1.69
#  b 500/524 >>   21.0 ms/b | lr:   0.0012 | grad norm: 1.24 | max abs grad:   0.221 | loss: 0.50 | perp.:   1.64
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.82 sec | train_loss:  0.52 | train_perp:   1.68 | valid_loss:  0.35 | valid_perp.:   1.42
# ================================================================================================================
#
#
# Epoch  23/ 50) lr = 0.001303
#  b 100/525 >>   21.0 ms/b | lr:   0.0012 | grad norm: 1.04 | max abs grad:   0.197 | loss: 0.49 | perp.:   1.64
#  b 200/525 >>   20.0 ms/b | lr:   0.0012 | grad norm: 1.19 | max abs grad:   0.183 | loss: 0.50 | perp.:   1.66
#  b 300/525 >>   21.0 ms/b | lr:   0.0013 | grad norm: 1.12 | max abs grad:   0.190 | loss: 0.51 | perp.:   1.67
#  b 400/525 >>   19.8 ms/b | lr:   0.0012 | grad norm: 1.81 | max abs grad:   0.228 | loss: 0.48 | perp.:   1.61
#  b 500/525 >>   19.4 ms/b | lr:   0.0012 | grad norm: 1.03 | max abs grad:   0.140 | loss: 0.49 | perp.:   1.63
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.60 sec | train_loss:  0.51 | train_perp:   1.67 | valid_loss:  0.36 | valid_perp.:   1.43
# ================================================================================================================
#
#
# Epoch  24/ 50) lr = 0.001276
#  b 100/527 >>   21.9 ms/b | lr:   0.0012 | grad norm: 1.52 | max abs grad:   0.178 | loss: 0.49 | perp.:   1.62
#  b 200/527 >>   20.0 ms/b | lr:   0.0012 | grad norm: 2.18 | max abs grad:   0.302 | loss: 0.49 | perp.:   1.63
#  b 300/527 >>   21.3 ms/b | lr:   0.0012 | grad norm: 1.05 | max abs grad:   0.146 | loss: 0.50 | perp.:   1.65
#  b 400/527 >>   19.8 ms/b | lr:   0.0013 | grad norm: 1.75 | max abs grad:   0.294 | loss: 0.49 | perp.:   1.63
#  b 500/527 >>   19.8 ms/b | lr:    0.001 | grad norm: 1.57 | max abs grad:   0.215 | loss: 0.46 | perp.:   1.59
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  10.84 sec | train_loss:  0.50 | train_perp:   1.65 | valid_loss:  0.35 | valid_perp.:   1.41
# ================================================================================================================
#
#
# Epoch  25/ 50) lr = 0.00125
#  b 100/522 >>   26.1 ms/b | lr:   0.0012 | grad norm: 1.99 | max abs grad:   0.254 | loss: 0.49 | perp.:   1.63
#  b 200/522 >>   24.0 ms/b | lr:   0.0013 | grad norm: 1.66 | max abs grad:   0.250 | loss: 0.48 | perp.:   1.61
#  b 300/522 >>   21.1 ms/b | lr:   0.0011 | grad norm: 1.56 | max abs grad:   0.215 | loss: 0.46 | perp.:   1.58
#  b 400/522 >>   22.1 ms/b | lr:   0.0013 | grad norm: 1.40 | max abs grad:   0.186 | loss: 0.48 | perp.:   1.62
#  b 500/522 >>   21.0 ms/b | lr:   0.0014 | grad norm: 1.41 | max abs grad:   0.323 | loss: 0.49 | perp.:   1.63
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.89 sec | train_loss:  0.50 | train_perp:   1.64 | valid_loss:  0.32 | valid_perp.:   1.38
# ================================================================================================================
#
#
# Epoch  26/ 50) lr = 0.001226
#  b 100/523 >>   22.9 ms/b | lr:  0.00098 | grad norm: 1.31 | max abs grad:   0.205 | loss: 0.49 | perp.:   1.63
#  b 200/523 >>   22.5 ms/b | lr:   0.0012 | grad norm: 2.05 | max abs grad:   0.512 | loss: 0.48 | perp.:   1.62
#  b 300/523 >>   22.5 ms/b | lr:   0.0013 | grad norm: 1.51 | max abs grad:   0.214 | loss: 0.48 | perp.:   1.62
#  b 400/523 >>   27.7 ms/b | lr:   0.0012 | grad norm: 2.09 | max abs grad:   0.369 | loss: 0.48 | perp.:   1.61
#  b 500/523 >>   23.8 ms/b | lr:    0.001 | grad norm: 1.45 | max abs grad:   0.262 | loss: 0.47 | perp.:   1.60
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  12.50 sec | train_loss:  0.50 | train_perp:   1.64 | valid_loss:  0.32 | valid_perp.:   1.38
# ================================================================================================================
#
#
# Epoch  27/ 50) lr = 0.001203
#  b 100/526 >>   22.4 ms/b | lr:   0.0013 | grad norm: 1.66 | max abs grad:   0.207 | loss: 0.47 | perp.:   1.60
#  b 200/526 >>   25.7 ms/b | lr:   0.0011 | grad norm: 2.08 | max abs grad:   0.253 | loss: 0.45 | perp.:   1.57
#  b 300/526 >>   23.4 ms/b | lr:   0.0013 | grad norm: 1.22 | max abs grad:   0.135 | loss: 0.48 | perp.:   1.61
#  b 400/526 >>   25.1 ms/b | lr:   0.0013 | grad norm: 1.37 | max abs grad:   0.169 | loss: 0.49 | perp.:   1.63
#  b 500/526 >>   23.4 ms/b | lr:   0.0012 | grad norm: 1.34 | max abs grad:   0.170 | loss: 0.46 | perp.:   1.59
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  12.61 sec | train_loss:  0.49 | train_perp:   1.63 | valid_loss:  0.32 | valid_perp.:   1.38
# ================================================================================================================
#
#
# Epoch  28/ 50) lr = 0.001181
#  b 100/520 >>   25.9 ms/b | lr:   0.0011 | grad norm: 1.44 | max abs grad:   0.168 | loss: 0.46 | perp.:   1.59
#  b 200/520 >>   25.4 ms/b | lr:   0.0012 | grad norm: 1.61 | max abs grad:   0.219 | loss: 0.45 | perp.:   1.57
#  b 300/520 >>   26.4 ms/b | lr:   0.0013 | grad norm: 1.50 | max abs grad:   0.294 | loss: 0.50 | perp.:   1.66
#  b 400/520 >>   25.4 ms/b | lr:   0.0012 | grad norm: 1.79 | max abs grad:   0.269 | loss: 0.45 | perp.:   1.57
#  b 500/520 >>   28.3 ms/b | lr:   0.0012 | grad norm: 1.96 | max abs grad:   0.234 | loss: 0.46 | perp.:   1.59
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  13.67 sec | train_loss:  0.48 | train_perp:   1.62 | valid_loss:  0.31 | valid_perp.:   1.37
# ================================================================================================================
#
#
# Epoch  29/ 50) lr = 0.001161
#  b 100/518 >>   27.8 ms/b | lr:   0.0013 | grad norm: 1.75 | max abs grad:   0.383 | loss: 0.45 | perp.:   1.57
#  b 200/518 >>   28.9 ms/b | lr:   0.0012 | grad norm: 1.30 | max abs grad:   0.193 | loss: 0.48 | perp.:   1.61
#  b 300/518 >>   28.1 ms/b | lr:   0.0012 | grad norm: 1.76 | max abs grad:   0.295 | loss: 0.49 | perp.:   1.63
#  b 400/518 >>   28.8 ms/b | lr:   0.0012 | grad norm: 1.67 | max abs grad:   0.256 | loss: 0.47 | perp.:   1.60
#  b 500/518 >>   28.2 ms/b | lr:  0.00093 | grad norm: 1.04 | max abs grad:   0.169 | loss: 0.48 | perp.:   1.61
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  14.60 sec | train_loss:  0.49 | train_perp:   1.63 | valid_loss:  0.32 | valid_perp.:   1.37
# ================================================================================================================
#
#
# Epoch  30/ 50) lr = 0.001141
#  b 100/519 >>   25.9 ms/b | lr:   0.0011 | grad norm: 2.01 | max abs grad:   0.345 | loss: 0.45 | perp.:   1.57
#  b 200/519 >>   24.9 ms/b | lr:  0.00091 | grad norm: 1.14 | max abs grad:   0.230 | loss: 0.46 | perp.:   1.58
#  b 300/519 >>   25.6 ms/b | lr:   0.0012 | grad norm: 1.46 | max abs grad:   0.145 | loss: 0.46 | perp.:   1.59
#  b 400/519 >>   26.7 ms/b | lr:   0.0012 | grad norm: 1.62 | max abs grad:   0.313 | loss: 0.50 | perp.:   1.65
#  b 500/519 >>   24.2 ms/b | lr:    0.001 | grad norm: 0.97 | max abs grad:   0.138 | loss: 0.47 | perp.:   1.59
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  13.22 sec | train_loss:  0.48 | train_perp:   1.62 | valid_loss:  0.31 | valid_perp.:   1.36
# ================================================================================================================
#
#
# Epoch  31/ 50) lr = 0.001123
#  b 100/530 >>   21.4 ms/b | lr:   0.0011 | grad norm: 0.81 | max abs grad:   0.120 | loss: 0.45 | perp.:   1.57
#  b 200/530 >>   27.7 ms/b | lr:   0.0012 | grad norm: 1.30 | max abs grad:   0.169 | loss: 0.47 | perp.:   1.60
#  b 300/530 >>   25.1 ms/b | lr:   0.0011 | grad norm: 1.58 | max abs grad:   0.411 | loss: 0.44 | perp.:   1.55
#  b 400/530 >>   28.6 ms/b | lr:   0.0011 | grad norm: 1.23 | max abs grad:   0.240 | loss: 0.45 | perp.:   1.57
#  b 500/530 >>   30.2 ms/b | lr:   0.0011 | grad norm: 2.21 | max abs grad:   0.302 | loss: 0.44 | perp.:   1.55
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  14.03 sec | train_loss:  0.46 | train_perp:   1.58 | valid_loss:  0.32 | valid_perp.:   1.38
# ================================================================================================================
#
#
# Epoch  32/ 50) lr = 0.001105
#  b 100/521 >>   26.7 ms/b | lr:   0.0011 | grad norm: 1.16 | max abs grad:   0.210 | loss: 0.44 | perp.:   1.56
#  b 200/521 >>   25.3 ms/b | lr:    0.001 | grad norm: 1.54 | max abs grad:   0.277 | loss: 0.46 | perp.:   1.59
#  b 300/521 >>   26.8 ms/b | lr:   0.0011 | grad norm: 1.58 | max abs grad:   0.221 | loss: 0.45 | perp.:   1.57
#  b 400/521 >>   25.9 ms/b | lr:   0.0011 | grad norm: 1.48 | max abs grad:   0.272 | loss: 0.44 | perp.:   1.55
#  b 500/521 >>   24.1 ms/b | lr:   0.0012 | grad norm: 1.74 | max abs grad:   0.591 | loss: 0.48 | perp.:   1.62
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  13.43 sec | train_loss:  0.47 | train_perp:   1.60 | valid_loss:  0.30 | valid_perp.:   1.35
# ================================================================================================================
#
#
# Epoch  33/ 50) lr = 0.001088
#  b 100/523 >>   23.6 ms/b | lr:    0.001 | grad norm: 1.14 | max abs grad:   0.177 | loss: 0.43 | perp.:   1.54
#  b 200/523 >>   25.6 ms/b | lr:   0.0011 | grad norm: 1.38 | max abs grad:   0.175 | loss: 0.44 | perp.:   1.55
#  b 300/523 >>   25.6 ms/b | lr:  0.00087 | grad norm: 3.73 | max abs grad:   0.569 | loss: 0.47 | perp.:   1.60
#  b 400/523 >>   28.2 ms/b | lr:  0.00098 | grad norm: 1.20 | max abs grad:   0.195 | loss: 0.47 | perp.:   1.61
#  b 500/523 >>   23.4 ms/b | lr:  0.00093 | grad norm: 1.49 | max abs grad:   0.418 | loss: 0.43 | perp.:   1.53
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  13.13 sec | train_loss:  0.46 | train_perp:   1.59 | valid_loss:  0.31 | valid_perp.:   1.36
# ================================================================================================================
#
#
# Epoch  34/ 50) lr = 0.001072
#  b 100/523 >>   23.0 ms/b | lr:   0.0011 | grad norm: 1.54 | max abs grad:   0.222 | loss: 0.45 | perp.:   1.57
#  b 200/523 >>   23.6 ms/b | lr:    0.001 | grad norm: 1.24 | max abs grad:   0.170 | loss: 0.44 | perp.:   1.55
#  b 300/523 >>   23.2 ms/b | lr:  0.00086 | grad norm: 1.49 | max abs grad:   0.200 | loss: 0.48 | perp.:   1.62
#  b 400/523 >>   22.2 ms/b | lr:   0.0011 | grad norm: 1.82 | max abs grad:   0.295 | loss: 0.44 | perp.:   1.55
#  b 500/523 >>   22.3 ms/b | lr:   0.0012 | grad norm: 1.33 | max abs grad:   0.194 | loss: 0.45 | perp.:   1.56
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.94 sec | train_loss:  0.46 | train_perp:   1.58 | valid_loss:  0.30 | valid_perp.:   1.35
# ================================================================================================================
#
#
# Epoch  35/ 50) lr = 0.001056
#  b 100/522 >>   24.8 ms/b | lr:   0.0011 | grad norm: 1.44 | max abs grad:   0.317 | loss: 0.45 | perp.:   1.56
#  b 200/522 >>   23.3 ms/b | lr:    0.001 | grad norm: 1.64 | max abs grad:   0.258 | loss: 0.43 | perp.:   1.54
#  b 300/522 >>   23.9 ms/b | lr:   0.0011 | grad norm: 1.55 | max abs grad:   0.255 | loss: 0.44 | perp.:   1.55
#  b 400/522 >>   23.1 ms/b | lr:   0.0009 | grad norm: 1.19 | max abs grad:   0.179 | loss: 0.45 | perp.:   1.56
#  b 500/522 >>   24.4 ms/b | lr:   0.0011 | grad norm: 1.74 | max abs grad:   0.204 | loss: 0.44 | perp.:   1.56
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  12.39 sec | train_loss:  0.46 | train_perp:   1.58 | valid_loss:  0.29 | valid_perp.:   1.34
# ================================================================================================================
#
#
# Epoch  36/ 50) lr = 0.001042
#  b 100/528 >>   21.8 ms/b | lr:  0.00089 | grad norm: 0.99 | max abs grad:   0.249 | loss: 0.44 | perp.:   1.55
#  b 200/528 >>   24.4 ms/b | lr:    0.001 | grad norm: 1.41 | max abs grad:   0.186 | loss: 0.46 | perp.:   1.58
#  b 300/528 >>   22.5 ms/b | lr:    0.001 | grad norm: 1.19 | max abs grad:   0.299 | loss: 0.45 | perp.:   1.57
#  b 400/528 >>   24.4 ms/b | lr:  0.00094 | grad norm: 1.19 | max abs grad:   0.218 | loss: 0.43 | perp.:   1.54
#  b 500/528 >>   22.5 ms/b | lr:    0.001 | grad norm: 1.38 | max abs grad:   0.192 | loss: 0.43 | perp.:   1.54
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  12.20 sec | train_loss:  0.45 | train_perp:   1.57 | valid_loss:  0.29 | valid_perp.:   1.34
# ================================================================================================================
#
#
# Epoch  37/ 50) lr = 0.001027
#  b 100/519 >>   21.9 ms/b | lr:  0.00098 | grad norm: 0.83 | max abs grad:   0.173 | loss: 0.45 | perp.:   1.56
#  b 200/519 >>   25.9 ms/b | lr:  0.00098 | grad norm: 1.54 | max abs grad:   0.180 | loss: 0.43 | perp.:   1.54
#  b 300/519 >>   23.4 ms/b | lr:  0.00098 | grad norm: 0.82 | max abs grad:   0.130 | loss: 0.44 | perp.:   1.55
#  b 400/519 >>   21.8 ms/b | lr:    0.001 | grad norm: 1.10 | max abs grad:   0.141 | loss: 0.45 | perp.:   1.56
#  b 500/519 >>   22.3 ms/b | lr:   0.0012 | grad norm: 1.73 | max abs grad:   0.366 | loss: 0.45 | perp.:   1.57
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.91 sec | train_loss:  0.45 | train_perp:   1.57 | valid_loss:  0.30 | valid_perp.:   1.35
# ================================================================================================================
#
#
# Epoch  38/ 50) lr = 0.001014
#  b 100/525 >>   25.6 ms/b | lr:  0.00097 | grad norm: 1.69 | max abs grad:   0.166 | loss: 0.45 | perp.:   1.57
#  b 200/525 >>   22.5 ms/b | lr:    0.001 | grad norm: 0.98 | max abs grad:   0.130 | loss: 0.42 | perp.:   1.53
#  b 300/525 >>   22.9 ms/b | lr:  0.00092 | grad norm: 1.37 | max abs grad:   0.196 | loss: 0.43 | perp.:   1.54
#  b 400/525 >>   22.7 ms/b | lr:   0.0011 | grad norm: 1.64 | max abs grad:   0.204 | loss: 0.44 | perp.:   1.55
#  b 500/525 >>   23.2 ms/b | lr:    0.001 | grad norm: 1.13 | max abs grad:   0.143 | loss: 0.43 | perp.:   1.53
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  12.21 sec | train_loss:  0.45 | train_perp:   1.56 | valid_loss:  0.30 | valid_perp.:   1.35
# ================================================================================================================
#
#
# Epoch  39/ 50) lr = 0.001001
#  b 100/523 >>   22.3 ms/b | lr:  0.00095 | grad norm: 0.90 | max abs grad:   0.186 | loss: 0.42 | perp.:   1.52
#  b 200/523 >>   22.7 ms/b | lr:    0.001 | grad norm: 1.22 | max abs grad:   0.203 | loss: 0.42 | perp.:   1.52
#  b 300/523 >>   21.4 ms/b | lr:  0.00095 | grad norm: 0.95 | max abs grad:   0.192 | loss: 0.42 | perp.:   1.52
#  b 400/523 >>   22.8 ms/b | lr:  0.00085 | grad norm: 1.65 | max abs grad:   0.241 | loss: 0.42 | perp.:   1.52
#  b 500/523 >>   22.7 ms/b | lr:    0.001 | grad norm: 1.33 | max abs grad:   0.260 | loss: 0.43 | perp.:   1.54
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.74 sec | train_loss:  0.44 | train_perp:   1.55 | valid_loss:  0.29 | valid_perp.:   1.34
# ================================================================================================================
#
#
# Epoch  40/ 50) lr = 0.0009882
#  b 100/523 >>   22.3 ms/b | lr:    0.001 | grad norm: 1.46 | max abs grad:   0.175 | loss: 0.43 | perp.:   1.54
#  b 200/523 >>   23.3 ms/b | lr:  0.00073 | grad norm: 4.07 | max abs grad:   0.490 | loss: 0.45 | perp.:   1.57
#  b 300/523 >>   22.2 ms/b | lr:  0.00084 | grad norm: 0.90 | max abs grad:   0.125 | loss: 0.41 | perp.:   1.50
#  b 400/523 >>   21.8 ms/b | lr:  0.00094 | grad norm: 1.16 | max abs grad:   0.191 | loss: 0.42 | perp.:   1.53
#  b 500/523 >>   22.2 ms/b | lr:  0.00099 | grad norm: 1.15 | max abs grad:   0.192 | loss: 0.43 | perp.:   1.53
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.70 sec | train_loss:  0.44 | train_perp:   1.55 | valid_loss:  0.31 | valid_perp.:   1.37
# ================================================================================================================
#
#
# Epoch  41/ 50) lr = 0.0009761
#  b 100/523 >>   21.4 ms/b | lr:  0.00093 | grad norm: 0.93 | max abs grad:   0.133 | loss: 0.41 | perp.:   1.51
#  b 200/523 >>   21.6 ms/b | lr:   0.0011 | grad norm: 1.89 | max abs grad:   0.248 | loss: 0.45 | perp.:   1.56
#  b 300/523 >>   22.2 ms/b | lr:  0.00098 | grad norm: 1.61 | max abs grad:   0.180 | loss: 0.42 | perp.:   1.53
#  b 400/523 >>   20.8 ms/b | lr:    0.001 | grad norm: 1.62 | max abs grad:   0.243 | loss: 0.42 | perp.:   1.52
#  b 500/523 >>   21.5 ms/b | lr:  0.00093 | grad norm: 1.24 | max abs grad:   0.236 | loss: 0.43 | perp.:   1.54
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.24 sec | train_loss:  0.44 | train_perp:   1.55 | valid_loss:  0.29 | valid_perp.:   1.34
# ================================================================================================================
#
#
# Epoch  42/ 50) lr = 0.0009644
#  b 100/524 >>   21.5 ms/b | lr:  0.00087 | grad norm: 0.97 | max abs grad:   0.157 | loss: 0.44 | perp.:   1.55
#  b 200/524 >>   22.5 ms/b | lr:  0.00096 | grad norm: 1.03 | max abs grad:   0.159 | loss: 0.44 | perp.:   1.55
#  b 300/524 >>   22.7 ms/b | lr:   0.0011 | grad norm: 1.64 | max abs grad:   0.220 | loss: 0.42 | perp.:   1.53
#  b 400/524 >>   20.6 ms/b | lr:  0.00096 | grad norm: 1.50 | max abs grad:   0.253 | loss: 0.42 | perp.:   1.52
#  b 500/524 >>   21.1 ms/b | lr:  0.00087 | grad norm: 1.35 | max abs grad:   0.210 | loss: 0.43 | perp.:   1.53
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.34 sec | train_loss:  0.44 | train_perp:   1.55 | valid_loss:  0.29 | valid_perp.:   1.34
# ================================================================================================================
#
#
# Epoch  43/ 50) lr = 0.0009531
#  b 100/525 >>   21.4 ms/b | lr:   0.0011 | grad norm: 1.78 | max abs grad:   0.251 | loss: 0.41 | perp.:   1.51
#  b 200/525 >>   22.1 ms/b | lr:  0.00081 | grad norm: 1.06 | max abs grad:   0.163 | loss: 0.42 | perp.:   1.52
#  b 300/525 >>   21.3 ms/b | lr:    0.001 | grad norm: 1.80 | max abs grad:   0.327 | loss: 0.40 | perp.:   1.49
#  b 400/525 >>   27.0 ms/b | lr:    0.001 | grad norm: 1.38 | max abs grad:   0.235 | loss: 0.44 | perp.:   1.55
#  b 500/525 >>   27.8 ms/b | lr:  0.00091 | grad norm: 1.66 | max abs grad:   0.394 | loss: 0.43 | perp.:   1.54
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  12.49 sec | train_loss:  0.43 | train_perp:   1.54 | valid_loss:  0.29 | valid_perp.:   1.34
# ================================================================================================================
#
#
# Epoch  44/ 50) lr = 0.0009422
#  b 100/529 >>   24.9 ms/b | lr:  0.00098 | grad norm: 1.29 | max abs grad:   0.215 | loss: 0.41 | perp.:   1.51
#  b 200/529 >>   26.8 ms/b | lr:  0.00094 | grad norm: 1.39 | max abs grad:   0.184 | loss: 0.43 | perp.:   1.54
#  b 300/529 >>   23.9 ms/b | lr:  0.00075 | grad norm: 1.46 | max abs grad:   0.235 | loss: 0.41 | perp.:   1.51
#  b 400/529 >>   27.1 ms/b | lr:  0.00098 | grad norm: 1.31 | max abs grad:   0.151 | loss: 0.43 | perp.:   1.54
#  b 500/529 >>   21.0 ms/b | lr:  0.00085 | grad norm: 1.01 | max abs grad:   0.247 | loss: 0.40 | perp.:   1.49
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  13.04 sec | train_loss:  0.43 | train_perp:   1.53 | valid_loss:  0.28 | valid_perp.:   1.32
# ================================================================================================================
#
#
# Epoch  45/ 50) lr = 0.0009317
#  b 100/533 >>   24.3 ms/b | lr:    0.001 | grad norm: 1.31 | max abs grad:   0.195 | loss: 0.43 | perp.:   1.54
#  b 200/533 >>   23.0 ms/b | lr:  0.00093 | grad norm: 1.07 | max abs grad:   0.109 | loss: 0.41 | perp.:   1.51
#  b 300/533 >>   21.4 ms/b | lr:  0.00089 | grad norm: 1.00 | max abs grad:   0.188 | loss: 0.40 | perp.:   1.49
#  b 400/533 >>   23.8 ms/b | lr:  0.00097 | grad norm: 2.27 | max abs grad:   0.277 | loss: 0.43 | perp.:   1.53
#  b 500/533 >>   24.4 ms/b | lr:  0.00089 | grad norm: 0.70 | max abs grad:   0.109 | loss: 0.41 | perp.:   1.51
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  12.32 sec | train_loss:  0.42 | train_perp:   1.53 | valid_loss:  0.31 | valid_perp.:   1.36
# ================================================================================================================
#
#
# Epoch  46/ 50) lr = 0.0009215
#  b 100/520 >>   24.4 ms/b | lr:    0.001 | grad norm: 1.89 | max abs grad:   0.246 | loss: 0.44 | perp.:   1.55
#  b 200/520 >>   21.8 ms/b | lr:  0.00096 | grad norm: 1.27 | max abs grad:   0.174 | loss: 0.43 | perp.:   1.54
#  b 300/520 >>   22.5 ms/b | lr:  0.00088 | grad norm: 1.27 | max abs grad:   0.159 | loss: 0.41 | perp.:   1.51
#  b 400/520 >>   21.2 ms/b | lr:  0.00079 | grad norm: 1.38 | max abs grad:   0.181 | loss: 0.42 | perp.:   1.52
#  b 500/520 >>   20.9 ms/b | lr:    0.001 | grad norm: 1.79 | max abs grad:   0.369 | loss: 0.41 | perp.:   1.50
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.49 sec | train_loss:  0.43 | train_perp:   1.54 | valid_loss:  0.30 | valid_perp.:   1.35
# ================================================================================================================
#
#
# Epoch  47/ 50) lr = 0.0009117
#  b 100/521 >>   24.2 ms/b | lr:  0.00099 | grad norm: 1.77 | max abs grad:   0.232 | loss: 0.44 | perp.:   1.55
#  b 200/521 >>   21.7 ms/b | lr:  0.00091 | grad norm: 1.84 | max abs grad:   0.210 | loss: 0.41 | perp.:   1.51
#  b 300/521 >>   21.7 ms/b | lr:  0.00078 | grad norm: 1.68 | max abs grad:   0.258 | loss: 0.44 | perp.:   1.56
#  b 400/521 >>   22.3 ms/b | lr:  0.00091 | grad norm: 1.59 | max abs grad:   0.268 | loss: 0.42 | perp.:   1.53
#  b 500/521 >>   20.5 ms/b | lr:  0.00082 | grad norm: 1.19 | max abs grad:   0.279 | loss: 0.41 | perp.:   1.51
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.55 sec | train_loss:  0.44 | train_perp:   1.55 | valid_loss:  0.27 | valid_perp.:   1.32
# ================================================================================================================
#
#
# Epoch  48/ 50) lr = 0.0009021
#  b 100/532 >>   20.4 ms/b | lr:  0.00086 | grad norm: 1.06 | max abs grad:   0.135 | loss: 0.39 | perp.:   1.48
#  b 200/532 >>   21.2 ms/b | lr:  0.00082 | grad norm: 0.96 | max abs grad:   0.149 | loss: 0.42 | perp.:   1.52
#  b 300/532 >>   21.0 ms/b | lr:  0.00086 | grad norm: 0.78 | max abs grad:   0.148 | loss: 0.41 | perp.:   1.51
#  b 400/532 >>   21.7 ms/b | lr:  0.00094 | grad norm: 2.56 | max abs grad:   0.552 | loss: 0.40 | perp.:   1.49
#  b 500/532 >>   20.9 ms/b | lr:  0.00086 | grad norm: 1.24 | max abs grad:   0.240 | loss: 0.40 | perp.:   1.50
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.22 sec | train_loss:  0.42 | train_perp:   1.52 | valid_loss:  0.28 | valid_perp.:   1.32
# ================================================================================================================
#
#
# Epoch  49/ 50) lr = 0.0008929
#  b 100/528 >>   22.2 ms/b | lr:  0.00089 | grad norm: 0.74 | max abs grad:   0.104 | loss: 0.42 | perp.:   1.52
#  b 200/528 >>   21.6 ms/b | lr:  0.00081 | grad norm: 0.64 | max abs grad:   0.100 | loss: 0.44 | perp.:   1.55
#  b 300/528 >>   20.8 ms/b | lr:  0.00093 | grad norm: 1.94 | max abs grad:   0.227 | loss: 0.41 | perp.:   1.50
#  b 400/528 >>   21.9 ms/b | lr:  0.00071 | grad norm: 1.57 | max abs grad:   0.251 | loss: 0.42 | perp.:   1.52
#  b 500/528 >>   21.0 ms/b | lr:  0.00081 | grad norm: 1.10 | max abs grad:   0.186 | loss: 0.39 | perp.:   1.48
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.32 sec | train_loss:  0.42 | train_perp:   1.53 | valid_loss:  0.28 | valid_perp.:   1.33
# ================================================================================================================
#
#
# Epoch  50/ 50) lr = 0.0008839
#  b 100/527 >>   21.6 ms/b | lr:  0.00096 | grad norm: 1.79 | max abs grad:   0.242 | loss: 0.42 | perp.:   1.52
#  b 200/527 >>   22.3 ms/b | lr:  0.00088 | grad norm: 1.17 | max abs grad:   0.183 | loss: 0.41 | perp.:   1.50
#  b 300/527 >>   21.5 ms/b | lr:   0.0008 | grad norm: 1.19 | max abs grad:   0.224 | loss: 0.40 | perp.:   1.50
#  b 400/527 >>   21.6 ms/b | lr:  0.00092 | grad norm: 1.33 | max abs grad:   0.239 | loss: 0.40 | perp.:   1.49
#  b 500/527 >>   22.9 ms/b | lr:  0.00096 | grad norm: 1.41 | max abs grad:   0.199 | loss: 0.40 | perp.:   1.50
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  11.58 sec | train_loss:  0.42 | train_perp:   1.52 | valid_loss:  0.29 | valid_perp.:   1.34
# ================================================================================================================

# %%
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    enc_states, attn_states, dec_states = states
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])

# %%
test_loss = evaluate(test_data, save_wts = True)
print('test_loss: {:5.2f} | test_perplexity: {:5.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss:  0.29 | test_perplexity:  1.34

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 1 incorrectly predicted
#  Variable containing:
#     0     2     3     4     4     3     2     5     0     6     1
#     0     2     3     4     4     3     2     5     0     6     2
# [torch.LongTensor of size 2x11]
#
# 2 incorrectly predicted
#  Variable containing:
#     5     5     3     4     2     4     3     4     1     1     6
#     5     5     3     4     2     4     4     4     1     1     2
# [torch.LongTensor of size 2x11]
#
# 3 incorrectly predicted
#  Variable containing:
#     2     5     0     1     3     6     6     1     3     6     1
#     2     5     0     1     3     6     3     3     3     6     5
# [torch.LongTensor of size 2x11]
#
# 1 incorrectly predicted
#  Variable containing:
#     6     5     3     5     6     3     4     0     6     2     4
#     6     5     3     5     6     3     4     0     6     2     2
# [torch.LongTensor of size 2x11]

# %% [markdown]
# ## Visualizations
# List of modules in the model for reference:

# %%
modules = list(model.modules())
list(enumerate(modules))
# Out:
# [(0, RNNModel(
#     (drop): Dropout(p=0.1)
#     (relu): ReLU()
#     (embedding): Embedding(7, 64)
#     (encoders): ModuleList(
#       (0): LSTM(64, 32, dropout=0.1)
#     )
#     (attn): RecurrentAttention(
#       (drop): Dropout(p=0.1)
#       (softmax): Softmax()
#       (sigmoid): Sigmoid()
#       (rnn_stack): ModuleList(
#         (0): LSTMCell(96, 16)
#       )
#       (alignment): Linear(in_features=48, out_features=1)
#       (attention): Linear(in_features=112, out_features=64)
#       (attn_act_fn): ReLU()
#     )
#     (projection): Linear(in_features=64, out_features=7)
#     (log_softmax): LogSoftmax()
#   )), (1, Dropout(p=0.1)), (2, ReLU()), (3, Embedding(7, 64)), (4, ModuleList(
#     (0): LSTM(64, 32, dropout=0.1)
#   )), (5, LSTM(64, 32, dropout=0.1)), (6, RecurrentAttention(
#     (drop): Dropout(p=0.1)
#     (softmax): Softmax()
#     (sigmoid): Sigmoid()
#     (rnn_stack): ModuleList(
#       (0): LSTMCell(96, 16)
#     )
#     (alignment): Linear(in_features=48, out_features=1)
#     (attention): Linear(in_features=112, out_features=64)
#     (attn_act_fn): ReLU()
#   )), (7, Dropout(p=0.1)), (8, Softmax()), (9, Sigmoid()), (10, ModuleList(
#     (0): LSTMCell(96, 16)
#   )), (11, LSTMCell(96, 16)), (12,
#   Linear(in_features=48, out_features=1)), (13,
#   Linear(in_features=112, out_features=64)), (14, ReLU()), (15,
#   Linear(in_features=64, out_features=7)), (16, LogSoftmax())]

# %% [markdown]
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(modules[3].weight.data)
plt.imshow(embed_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (7, 64)

# %%
attn = modules[6]

# %%
attn_wts = np.array(attn.attention.weight.data)
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Output attention sublayer (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (64, 112)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# The model output sequence is on the x-axis of each plot, with the weights summing to 1 along the y-axis, representing the input.
#
# The model seems to be considering all inputs in the sequence equally when making the first few predictions, but afterwards it only attends to the remaining items in the input sequence after each subsequent prediction is made; when predicting the second-to-last item, it even seems to most heavily consider only the last item in the input sequence. The exception is when the model attempts to predict the very last item in the sequence in which case it looks back at a few items right before; interestingly, the model incorrectly predicts this last item in each of these four examples.
#
#
# At least for the predictions on the items in the middle of the target sequence, you can tell that the model is trying to make the prediction mostly based on the conditional probablity of seeing the remaining items in the input sequence, which is interesting because this toy dataset was generated by using a conditional distribution conditioned on some number of items appearing before each item.
