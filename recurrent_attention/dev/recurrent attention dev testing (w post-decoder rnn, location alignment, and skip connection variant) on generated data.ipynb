# %%
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from recurrent_attention import RecurrentAttention

# %% [markdown]
# ## Overhead stuff
#
# Helper functions for batching, resetting hidden states, etc.

# %%
# Data gen parameters
num_batches = 500
num_eval_batches = 20
ntokens = 7
dep_len = 6

# Training hyperparameters
eval_batch_size = 20
batch_size = 50
seq_len = 11
dropout = 0.1
clip = 1
lr = 0.05
warmup_steps = 5
decay_factor = 0.5  # Higher => faster learning rate decay
smoothing = 0.001

epochs = 50
log_interval = 100   # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 64
encode_size = 32
h_size = 16
loc_align_size = 16
loc_align_kernel = 5
decode_size = 32
decode_out_size = 64
n_enc_layers = 1
attn_rnn_layers = 1
n_dec_layers = 1
smooth_align = True
align_location = True
bidirectional_attn = False
skip_connections = True

# %% [markdown]
# ## Generate data

# %%
# Generate some token transition probabilities
probs = np.random.randint(1, 10*ntokens, size = tuple(ntokens for _ in range(dep_len+1)))
# Normalize
probs = probs / (probs.sum(axis = -1)[..., np.newaxis])
probs.shape
# Out:
# (7, 7, 7, 7, 7, 7, 7)

# %%
def gen_data(num_batches, batch_size, seq_len):
    num_data = num_batches * batch_size * seq_len
    # Initialize numpy array for the generated data
    data = np.zeros((num_data,), dtype = int)
    # Randomly generate a series of starting tokens
    ts = [np.random.randint(ntokens, size = 1) for _ in range(dep_len)]
    # Generate the data
    for i in range(num_data):
        pr = probs[ts].squeeze()
        data[i] = np.random.choice(ntokens, p = pr)
        ts.pop(0)
        ts.append(data[i].reshape(1,1))
    return torch.from_numpy(data).type(torch.LongTensor)

# %% [markdown]
# ### Helper functions

# %%
# Starting from sequential data, `batchify` arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.
def batchify(data, batch_size):
    # Work out how cleanly we can divide the dataset into batches
    nbatches = data.size(0) // batch_size
    # Trim off any extra elements that wouldn't cleanly fit
    data = data.narrow(0, 0, nbatches * batch_size)
    # Evenly divide the data across the batches
    data = data.view(batch_size, -1).t().contiguous()
    return data  # [seq_len, batch_size]

# Wraps hidden states into new Variables to detach them from their history
def repackage_hidden(h):
    if type(h) == Variable:
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)
    
# `get_batch` subdivides the source data into chunks of the specified length.
# E.g., using the example for the `batchify` function above and a length of 2,
# we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the `batchify` function. The chunks are along dimension 0, corresponding
# to the `seq_len` dimension in the LSTM.
def get_batch(source, i, seq_len, evaluate = False):
    seq_len = min(seq_len, len(source) - 1 - i)
    data = Variable(source[i : i+seq_len], volatile = evaluate)
    target = Variable(source[i+1 : i+1+seq_len].view(-1), volatile = evaluate)
    return data, target

# %%
train_data = batchify(gen_data(num_batches, batch_size, seq_len), batch_size)
val_data = batchify(gen_data(num_eval_batches, batch_size, seq_len), eval_batch_size)
test_data = batchify(gen_data(num_eval_batches, batch_size, seq_len), eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([5500, 50]), torch.Size([550, 20]), torch.Size([550, 20]))

# %% [markdown]
# Label smoothing class for regularization.

# %%
class LabelSmoothing(nn.Module):
    def __init__(self, size, padding_idx = None, smoothing = 0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss()
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = torch.zeros_like(x.data)
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist.add_(self.smoothing / self.size)
        if self.padding_idx is not None:
            true_dist[:, self.padding_idx] = 0
            mask = torch.nonzero(target.data == self.padding_idx)
            if mask.dim() > 0:
                true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad = False)) * ntokens

# %% [markdown]
# Learning rate scheduler that sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
def get_lr_scheduler(h_size, warmup, optimizer):
    lrate = lambda e: h_size**(-0.5) * min((e+1)**(-decay_factor), (e+1) * warmup**(-(decay_factor+1)))
    return optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lrate)

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.1f:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.1f:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.1f:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.1f:%d:%d" % (lr, embed_size, warmup_steps),
])

# %% [markdown]
# ## Model class

# %%
class RNNModel(nn.Module):
    def __init__(self, src_vocab, tgt_vocab, embed_size, encode_size, h_size,
                 decode_size, decode_out_size, n_enc_layers, attn_rnn_layers,
                 n_dec_layers, align_location = False, loc_align_size = 1,
                 loc_align_kernel = 1, smooth_align = False, bidirectional_attn = False,
                 tie_wts = True, skip_connections = False, dropout = 0.1):
        super(RNNModel, self).__init__()
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.embed_size = embed_size
        self.encode_size = encode_size
        self.h_size = h_size
        self.decode_size = decode_size
        self.decode_out_size = decode_out_size
        self.n_enc_layers = n_enc_layers
        self.attn_rnn_layers = attn_rnn_layers
        self.n_dec_layers = n_dec_layers
        self.align_location = align_location
        self.loc_align_size = loc_align_size
        self.loc_align_kernel = loc_align_kernel
        self.smooth_align = smooth_align
        self.bidirectional_attn = bidirectional_attn
        self.tie_wts = tie_wts
        self.skip_connections = skip_connections
        self.dropout = dropout
        
        self.drop = nn.Dropout(dropout)
        self.relu = nn.ReLU()
        
        self.embedding = nn.Embedding(src_vocab, embed_size)
        self.encoders = nn.ModuleList([
            nn.LSTM(
                input_size = (embed_size if i == 0 else encode_size) + (embed_size if i > 0 and skip_connections else 0),
                hidden_size = encode_size, dropout = dropout
            ) for i in range(n_enc_layers)
        ])
        self.attn = RecurrentAttention(
            in_size = encode_size, h_size = h_size, out_size = decode_size,
            align_location = align_location, loc_align_size = loc_align_size,
            loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
            num_rnn_layers = attn_rnn_layers, attn_act_fn = 'ReLU',
            dropout = dropout, bidirectional = bidirectional_attn
        )
        # Maybe try skip connections in the decoder from the attention mechanism?
        self.decoders = nn.ModuleList([
            nn.LSTM(
                input_size = decode_size + (decode_size if i > 0 and skip_connections else 0), dropout = dropout,
                hidden_size = decode_size if i < n_dec_layers-1 else decode_out_size,
            ) for i in range(n_dec_layers)
        ])
        self.projection = nn.Linear(decode_out_size, tgt_vocab)
        if tie_wts and src_vocab == tgt_vocab and embed_size == decode_out_size:
            self.embedding.weight = self.projection.weight
        self.log_softmax = nn.LogSoftmax(dim = -1)
            
        # For visualizations
        self.save_wts = False
        self.enc_out = None
        self.dec_out = None
        
    def init(self):
        for subnet in [self.encoders, self.decoders]:
            for layer in subnet:
                for p in layer.parameters():
                    if p.dim() > 1:
                        nn.init.xavier_normal(p)
                    else:
                        p.data.fill_(0)
        for p in self.projection.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform(p)
            else:
                p.data.fill_(0)
        self.attn.init()
        
    def init_states(self, batch_size):
        encoder_states = [
            (
                Variable(torch.zeros(1, batch_size, self.encode_size)),
                Variable(torch.zeros(1, batch_size, self.encode_size))
            ) for _ in range(self.n_enc_layers)
        ]
        attn_states = self.attn.init_rnn_states(batch_size)
        decoder_states = [
            (
                Variable(torch.zeros(
                    1, batch_size, self.decode_size if i < self.n_dec_layers-1 else self.decode_out_size
                )),
                Variable(torch.zeros(
                    1, batch_size, self.decode_size if i < self.n_dec_layers-1 else self.decode_out_size
                ))
            ) for i in range(self.n_dec_layers)
        ]
        return encoder_states, attn_states, decoder_states
    
    def forward(self, inputs, states):
        enc_states, attn_states, dec_states = states
        if self.save_wts:
            self.enc_out = []
            self.dec_out = []
        
        embeddings = self.embedding(inputs) * np.sqrt(self.embed_size)
        
        new_enc_states = []
        enc_in = self.drop(self.relu(embeddings))
        enc_out = None
        for states, encoder in zip(enc_states, self.encoders):
            enc_rnn_in = enc_in if enc_out is None else (torch.cat([enc_in, enc_out], -1) if self.skip_connections else enc_out)
            enc_out, new_enc_state = encoder(enc_rnn_in, states)
            new_enc_states.append(new_enc_state)
            if self.save_wts:
                self.enc_out.append(enc_out.data.clone())
            enc_out = self.drop(enc_out)
                
        attn_out, new_attn_states = self.attn(enc_out, attn_states)
        
        new_dec_states = []
        dec_in = attn_out
        dec_out = None
        for states, decoder in zip(dec_states, self.decoders):
            dec_rnn_in = dec_in if dec_out is None else (torch.cat([dec_in, dec_out], -1) if self.skip_connections else dec_out)
            dec_out, new_dec_state = decoder(dec_rnn_in, states)
            new_dec_states.append(new_dec_state)
            if self.save_wts:
                self.dec_out.append(dec_out.data.clone())
            dec_out = self.drop(dec_out)
        
        logits = self.projection(dec_out)
        output = self.log_softmax(logits)
        
        return output, (new_enc_states, new_attn_states, new_dec_states)
    
    def train(self, mode = True, save_wts = False):
        super(RNNModel, self).train(mode)
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts
        
    def eval(self, save_wts = True):
        super(RNNModel, self).eval()
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    encode_size = encode_size, h_size = h_size, decode_size = decode_size,
    decode_out_size = decode_out_size, n_enc_layers = n_enc_layers,
    attn_rnn_layers = attn_rnn_layers, n_dec_layers = n_dec_layers,
    align_location = align_location, loc_align_size = loc_align_size,
    loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
    skip_connections = skip_connections, dropout = dropout
)
model.init()
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 46088

# %% [markdown]
# ## Train

# %% [markdown]
# Define training and validation loops

# %%
def train():
    # Use random length sequences
    seq_lens = []
    tot_len = 0
    jitter = 0.15 * seq_len
    num_data = train_data.size(0)
    while tot_len < num_data - 2:
        if num_data - tot_len - 2 <= seq_len + jitter:
            slen = num_data - tot_len - 2
        else:
            slen = int(np.random.normal(seq_len, jitter))
            if slen <= 0:
                slen = seq_len    # eh
            if tot_len + slen >= num_data - jitter - 2:
                slen = num_data - tot_len - 2
        seq_lens.append(slen)
        tot_len += slen
    i_cumseq = [0] + list(np.cumsum(seq_lens)[:-1])
    idx = np.arange(len(seq_lens))
    np.random.shuffle(idx)
    # Turn on training mode
    model.train(save_wts = False)
    # Initialize RNN states
    states = model.init_states(batch_size)
    # Prep metainfo
    total_loss = 0
    total_epoch_loss = 0
    start_time = time.time()
    for batch, i in enumerate(idx):
        # Get training data
        data, targets = get_batch(train_data, i_cumseq[i], seq_lens[i])
        # Repackage the hidden states
        states = model.init_states(batch_size)  #repackage_hidden(states)
        # Zero out gradients
        model.zero_grad()
        
        # Run the model forward
        output, _states = model(data, states)
        if np.isnan(output.data).any():
            return 0, total_epoch_loss[0], data, targets, states, _states
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        if np.isnan(loss.data[0]):
            return 1, total_epoch_loss[0], data, targets, states, _states
        states = _states
        # Propagate loss gradient backwards
        loss.backward()
        # Clip gradients
        if batch % log_interval == 0 and batch > 0:
            # Save gradient statistics before they're changed cuz we'll be logging this batch
            parameters = [p for p in model.parameters() if p.grad is not None]
            # Calculate the largest (absolute) gradient of all elements in the model parameters
            max_grad = max([p.grad.data.abs().max() for p in parameters])
        total_norm = nn.utils.clip_grad_norm(model.parameters(), clip)
        # Scale the batch learning rate so that shorter sequences aren't "stronger"
        scaled_lr = lr_scheduler.get_lr()[0] * np.sqrt(seq_lens[i] / seq_len)
        for param_group in optimizer.param_groups:
            param_group['lr'] = scaled_lr
        # Update parameters
        optimizer.step()
        
        # Get some metainfo
        total_loss += loss.data
        total_epoch_loss += loss.data * data.size(0)
        if batch % log_interval == 0 and batch > 0:
            elapsed = time.time() - start_time
            cur_loss = total_loss[0] / log_interval
            print(' b {:3d}/{:3d} >> {:6.1f} ms/b | lr: {:8.2g} | grad norm: {:4.2f} | max abs grad: {:7.3f} | loss: {:4.2f} | perp.: {:6.2f}'.format(
                batch, len(seq_lens), elapsed * 1000/log_interval, scaled_lr, total_norm, max_grad, cur_loss, np.exp(cur_loss)
            ))
            total_loss = 0
            start_time = time.time()
    return -1, total_epoch_loss[0] / num_data, None, None, None, None

# %%
def evaluate(data_src, save_wts = True):
    model.eval(save_wts = save_wts)
    total_loss = 0
    states = model.init_states(eval_batch_size)
    for i in range(0, data_src.size(0) - 1, seq_len):
        # Get data
        data, targets = get_batch(data_src, i, seq_len, evaluate = True)
        # Repackage the hidden states
        states = model.init_states(eval_batch_size)  #repackage_hidden(states)
        # Evaluate
        output, states = model(data, states)
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        total_loss += loss.data * data.size(0)
    return total_loss[0] / data_src.size(0)

# %% [markdown]
# Train and evaluate

# %%
WIDTH = 112
CAUSES = ['output', 'grad']
for epoch in range(epochs):
    lr_scheduler.step()
    print('Epoch {:3d}/{:3d}) lr = {:0.4g}{}'.format(epoch+1, epochs, np.mean(lr_scheduler.get_lr()[0]), ' (warmup)' if epoch < warmup_steps else ''))
    start_time = time.time()
    stat, train_loss, data, targets, states, nstates = train()
    if stat in list(range(len(CAUSES))):
        c = CAUSES[stat]
        n = (WIDTH - len(c) - 4) // 2
        print('\n' + (' '*n) + 'NaN ' + c)
        break
    elapsed = time.time() - start_time
    val_loss = evaluate(val_data, save_wts = False)
    max_param = max([p.data.abs().max() for p in model.parameters() if p.grad is not None])
    print('-' * WIDTH)
    print('Elapsed time: {:6.2f} sec | train_loss: {:5.2f} | train_perp: {:6.2f} | valid_loss: {:5.2f} | valid_perp.: {:6.2f}'.format(
        elapsed, train_loss, np.exp(train_loss), val_loss, np.exp(val_loss)
    ))
    print('=' * WIDTH)
    print('\n')
# Out:
# Epoch   1/ 50) lr = 0.000559 (warmup)
#  b 100/525 >>   36.8 ms/b | lr:  0.00051 | grad norm: 0.18 | max abs grad:   0.028 | loss: 1.90 | perp.:   6.71
#  b 200/525 >>   37.0 ms/b | lr:  0.00053 | grad norm: 0.30 | max abs grad:   0.029 | loss: 1.79 | perp.:   6.02
#  b 300/525 >>   34.0 ms/b | lr:  0.00056 | grad norm: 0.36 | max abs grad:   0.031 | loss: 1.74 | perp.:   5.70
#  b 400/525 >>   32.1 ms/b | lr:  0.00051 | grad norm: 0.30 | max abs grad:   0.025 | loss: 1.72 | perp.:   5.58
#  b 500/525 >>   33.3 ms/b | lr:  0.00051 | grad norm: 0.37 | max abs grad:   0.027 | loss: 1.71 | perp.:   5.51
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  18.10 sec | train_loss:  1.77 | train_perp:   5.86 | valid_loss:  1.67 | valid_perp.:   5.34
# ================================================================================================================
#
#
# Epoch   2/ 50) lr = 0.001118 (warmup)
#  b 100/527 >>   36.5 ms/b | lr:   0.0012 | grad norm: 0.35 | max abs grad:   0.022 | loss: 1.70 | perp.:   5.48
#  b 200/527 >>   33.2 ms/b | lr:    0.001 | grad norm: 0.78 | max abs grad:   0.057 | loss: 1.66 | perp.:   5.24
#  b 300/527 >>   31.9 ms/b | lr:   0.0013 | grad norm: 0.56 | max abs grad:   0.054 | loss: 1.63 | perp.:   5.11
#  b 400/527 >>   32.5 ms/b | lr:  0.00095 | grad norm: 0.87 | max abs grad:   0.073 | loss: 1.58 | perp.:   4.87
#  b 500/527 >>   32.4 ms/b | lr:   0.0011 | grad norm: 0.69 | max abs grad:   0.054 | loss: 1.55 | perp.:   4.69
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.50 sec | train_loss:  1.62 | train_perp:   5.07 | valid_loss:  1.47 | valid_perp.:   4.37
# ================================================================================================================
#
#
# Epoch   3/ 50) lr = 0.001677 (warmup)
#  b 100/525 >>   32.9 ms/b | lr:   0.0016 | grad norm: 0.61 | max abs grad:   0.051 | loss: 1.53 | perp.:   4.60
#  b 200/525 >>   31.1 ms/b | lr:   0.0014 | grad norm: 1.06 | max abs grad:   0.087 | loss: 1.45 | perp.:   4.28
#  b 300/525 >>   32.6 ms/b | lr:   0.0017 | grad norm: 0.76 | max abs grad:   0.044 | loss: 1.42 | perp.:   4.12
#  b 400/525 >>   33.0 ms/b | lr:   0.0015 | grad norm: 1.18 | max abs grad:   0.079 | loss: 1.39 | perp.:   4.03
#  b 500/525 >>   32.1 ms/b | lr:   0.0015 | grad norm: 1.27 | max abs grad:   0.087 | loss: 1.35 | perp.:   3.84
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.89 sec | train_loss:  1.43 | train_perp:   4.17 | valid_loss:  1.24 | valid_perp.:   3.45
# ================================================================================================================
#
#
# Epoch   4/ 50) lr = 0.002236 (warmup)
#  b 100/523 >>   33.0 ms/b | lr:   0.0023 | grad norm: 0.91 | max abs grad:   0.063 | loss: 1.34 | perp.:   3.84
#  b 200/523 >>   32.6 ms/b | lr:   0.0021 | grad norm: 1.11 | max abs grad:   0.087 | loss: 1.28 | perp.:   3.61
#  b 300/523 >>   30.7 ms/b | lr:    0.002 | grad norm: 1.21 | max abs grad:   0.132 | loss: 1.24 | perp.:   3.47
#  b 400/523 >>   31.8 ms/b | lr:   0.0022 | grad norm: 1.49 | max abs grad:   0.095 | loss: 1.20 | perp.:   3.33
#  b 500/523 >>   33.6 ms/b | lr:   0.0021 | grad norm: 1.48 | max abs grad:   0.091 | loss: 1.18 | perp.:   3.26
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.90 sec | train_loss:  1.26 | train_perp:   3.52 | valid_loss:  1.02 | valid_perp.:   2.78
# ================================================================================================================
#
#
# Epoch   5/ 50) lr = 0.002795 (warmup)
#  b 100/527 >>   31.7 ms/b | lr:   0.0033 | grad norm: 1.01 | max abs grad:   0.091 | loss: 1.17 | perp.:   3.21
#  b 200/527 >>   32.3 ms/b | lr:   0.0028 | grad norm: 1.31 | max abs grad:   0.092 | loss: 1.11 | perp.:   3.04
#  b 300/527 >>   31.9 ms/b | lr:   0.0025 | grad norm: 1.92 | max abs grad:   0.139 | loss: 1.10 | perp.:   3.00
#  b 400/527 >>   31.7 ms/b | lr:   0.0028 | grad norm: 1.88 | max abs grad:   0.139 | loss: 1.04 | perp.:   2.83
#  b 500/527 >>   32.0 ms/b | lr:    0.003 | grad norm: 1.53 | max abs grad:   0.125 | loss: 1.03 | perp.:   2.80
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.80 sec | train_loss:  1.10 | train_perp:   3.00 | valid_loss:  0.87 | valid_perp.:   2.39
# ================================================================================================================
#
#
# Epoch   6/ 50) lr = 0.002552
#  b 100/520 >>   35.4 ms/b | lr:   0.0027 | grad norm: 1.79 | max abs grad:   0.120 | loss: 1.00 | perp.:   2.72
#  b 200/520 >>   33.6 ms/b | lr:   0.0029 | grad norm: 1.59 | max abs grad:   0.147 | loss: 0.97 | perp.:   2.63
#  b 300/520 >>   32.9 ms/b | lr:   0.0024 | grad norm: 1.53 | max abs grad:   0.100 | loss: 0.95 | perp.:   2.59
#  b 400/520 >>   35.5 ms/b | lr:   0.0022 | grad norm: 2.17 | max abs grad:   0.186 | loss: 0.95 | perp.:   2.58
#  b 500/520 >>   34.0 ms/b | lr:   0.0026 | grad norm: 1.79 | max abs grad:   0.126 | loss: 0.91 | perp.:   2.48
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.75 sec | train_loss:  0.97 | train_perp:   2.63 | valid_loss:  0.70 | valid_perp.:   2.01
# ================================================================================================================
#
#
# Epoch   7/ 50) lr = 0.002362
#  b 100/521 >>   33.3 ms/b | lr:   0.0021 | grad norm: 1.91 | max abs grad:   0.199 | loss: 0.90 | perp.:   2.46
#  b 200/521 >>   33.0 ms/b | lr:   0.0023 | grad norm: 1.94 | max abs grad:   0.171 | loss: 0.86 | perp.:   2.36
#  b 300/521 >>   33.1 ms/b | lr:   0.0025 | grad norm: 1.90 | max abs grad:   0.165 | loss: 0.87 | perp.:   2.39
#  b 400/521 >>   35.5 ms/b | lr:   0.0023 | grad norm: 1.49 | max abs grad:   0.114 | loss: 0.85 | perp.:   2.34
#  b 500/521 >>   32.9 ms/b | lr:   0.0025 | grad norm: 1.43 | max abs grad:   0.115 | loss: 0.83 | perp.:   2.29
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.54 sec | train_loss:  0.88 | train_perp:   2.40 | valid_loss:  0.60 | valid_perp.:   1.82
# ================================================================================================================
#
#
# Epoch   8/ 50) lr = 0.00221
#  b 100/526 >>   33.6 ms/b | lr:   0.0022 | grad norm: 1.85 | max abs grad:   0.158 | loss: 0.81 | perp.:   2.25
#  b 200/526 >>   32.9 ms/b | lr:   0.0021 | grad norm: 1.62 | max abs grad:   0.145 | loss: 0.78 | perp.:   2.18
#  b 300/526 >>   30.9 ms/b | lr:   0.0022 | grad norm: 1.69 | max abs grad:   0.128 | loss: 0.76 | perp.:   2.14
#  b 400/526 >>   32.1 ms/b | lr:   0.0019 | grad norm: 2.86 | max abs grad:   0.207 | loss: 0.76 | perp.:   2.13
#  b 500/526 >>   32.6 ms/b | lr:   0.0021 | grad norm: 2.30 | max abs grad:   0.193 | loss: 0.77 | perp.:   2.16
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.07 sec | train_loss:  0.79 | train_perp:   2.20 | valid_loss:  0.52 | valid_perp.:   1.69
# ================================================================================================================
#
#
# Epoch   9/ 50) lr = 0.002083
#  b 100/522 >>   33.4 ms/b | lr:   0.0021 | grad norm: 1.60 | max abs grad:   0.116 | loss: 0.74 | perp.:   2.09
#  b 200/522 >>   32.4 ms/b | lr:    0.002 | grad norm: 1.49 | max abs grad:   0.101 | loss: 0.73 | perp.:   2.07
#  b 300/522 >>   32.9 ms/b | lr:   0.0019 | grad norm: 1.99 | max abs grad:   0.169 | loss: 0.71 | perp.:   2.03
#  b 400/522 >>   34.0 ms/b | lr:    0.002 | grad norm: 1.38 | max abs grad:   0.102 | loss: 0.69 | perp.:   1.99
#  b 500/522 >>   32.4 ms/b | lr:    0.002 | grad norm: 1.81 | max abs grad:   0.153 | loss: 0.67 | perp.:   1.95
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.25 sec | train_loss:  0.72 | train_perp:   2.06 | valid_loss:  0.41 | valid_perp.:   1.51
# ================================================================================================================
#
#
# Epoch  10/ 50) lr = 0.001976
#  b 100/524 >>   34.6 ms/b | lr:    0.002 | grad norm: 1.55 | max abs grad:   0.128 | loss: 0.66 | perp.:   1.94
#  b 200/524 >>   35.7 ms/b | lr:   0.0019 | grad norm: 1.38 | max abs grad:   0.118 | loss: 0.64 | perp.:   1.89
#  b 300/524 >>   37.5 ms/b | lr:   0.0019 | grad norm: 2.71 | max abs grad:   0.398 | loss: 0.64 | perp.:   1.90
#  b 400/524 >>   36.6 ms/b | lr:   0.0019 | grad norm: 1.32 | max abs grad:   0.120 | loss: 0.61 | perp.:   1.84
#  b 500/524 >>   42.9 ms/b | lr:   0.0019 | grad norm: 1.33 | max abs grad:   0.115 | loss: 0.61 | perp.:   1.84
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  19.51 sec | train_loss:  0.65 | train_perp:   1.91 | valid_loss:  0.43 | valid_perp.:   1.53
# ================================================================================================================
#
#
# Epoch  11/ 50) lr = 0.001884
#  b 100/523 >>   36.3 ms/b | lr:   0.0018 | grad norm: 2.15 | max abs grad:   0.181 | loss: 0.63 | perp.:   1.87
#  b 200/523 >>   40.1 ms/b | lr:   0.0018 | grad norm: 2.90 | max abs grad:   0.306 | loss: 0.59 | perp.:   1.81
#  b 300/523 >>   38.8 ms/b | lr:   0.0019 | grad norm: 1.66 | max abs grad:   0.156 | loss: 0.59 | perp.:   1.81
#  b 400/523 >>   36.0 ms/b | lr:   0.0018 | grad norm: 1.97 | max abs grad:   0.184 | loss: 0.57 | perp.:   1.77
#  b 500/523 >>   33.9 ms/b | lr:   0.0018 | grad norm: 4.06 | max abs grad:   0.357 | loss: 0.57 | perp.:   1.77
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  19.25 sec | train_loss:  0.60 | train_perp:   1.83 | valid_loss:  0.29 | valid_perp.:   1.34
# ================================================================================================================
#
#
# Epoch  12/ 50) lr = 0.001804
#  b 100/523 >>   34.0 ms/b | lr:   0.0019 | grad norm: 2.18 | max abs grad:   0.180 | loss: 0.54 | perp.:   1.72
#  b 200/523 >>   35.3 ms/b | lr:   0.0016 | grad norm: 3.18 | max abs grad:   0.312 | loss: 0.56 | perp.:   1.75
#  b 300/523 >>   34.9 ms/b | lr:   0.0016 | grad norm: 2.80 | max abs grad:   0.707 | loss: 0.52 | perp.:   1.68
#  b 400/523 >>   34.3 ms/b | lr:   0.0018 | grad norm: 1.29 | max abs grad:   0.132 | loss: 0.53 | perp.:   1.69
#  b 500/523 >>   34.1 ms/b | lr:   0.0017 | grad norm: 2.18 | max abs grad:   0.709 | loss: 0.56 | perp.:   1.74
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.96 sec | train_loss:  0.55 | train_perp:   1.73 | valid_loss:  0.27 | valid_perp.:   1.31
# ================================================================================================================
#
#
# Epoch  13/ 50) lr = 0.001733
#  b 100/521 >>   35.4 ms/b | lr:   0.0017 | grad norm: 2.17 | max abs grad:   0.193 | loss: 0.52 | perp.:   1.69
#  b 200/521 >>   33.1 ms/b | lr:   0.0017 | grad norm: 1.88 | max abs grad:   0.174 | loss: 0.50 | perp.:   1.65
#  b 300/521 >>   33.4 ms/b | lr:   0.0018 | grad norm: 1.74 | max abs grad:   0.190 | loss: 0.50 | perp.:   1.64
#  b 400/521 >>   34.3 ms/b | lr:   0.0017 | grad norm: 3.35 | max abs grad:   0.935 | loss: 0.49 | perp.:   1.63
#  b 500/521 >>   36.8 ms/b | lr:   0.0015 | grad norm: 1.53 | max abs grad:   0.331 | loss: 0.51 | perp.:   1.66
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  18.21 sec | train_loss:  0.52 | train_perp:   1.68 | valid_loss:  0.22 | valid_perp.:   1.25
# ================================================================================================================
#
#
# Epoch  14/ 50) lr = 0.00167
#  b 100/525 >>   43.2 ms/b | lr:   0.0016 | grad norm: 1.32 | max abs grad:   0.118 | loss: 0.48 | perp.:   1.62
#  b 200/525 >>   37.9 ms/b | lr:   0.0017 | grad norm: 1.69 | max abs grad:   0.222 | loss: 0.48 | perp.:   1.62
#  b 300/525 >>   33.8 ms/b | lr:   0.0017 | grad norm: 1.76 | max abs grad:   0.276 | loss: 0.48 | perp.:   1.62
#  b 400/525 >>   34.8 ms/b | lr:   0.0017 | grad norm: 1.13 | max abs grad:   0.112 | loss: 0.46 | perp.:   1.58
#  b 500/525 >>   33.2 ms/b | lr:   0.0015 | grad norm: 3.29 | max abs grad:   0.363 | loss: 0.44 | perp.:   1.56
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  19.15 sec | train_loss:  0.48 | train_perp:   1.61 | valid_loss:  0.22 | valid_perp.:   1.24
# ================================================================================================================
#
#
# Epoch  15/ 50) lr = 0.001614
#  b 100/529 >>   35.5 ms/b | lr:   0.0016 | grad norm: 3.01 | max abs grad:   0.310 | loss: 0.47 | perp.:   1.60
#  b 200/529 >>   33.0 ms/b | lr:   0.0015 | grad norm: 1.47 | max abs grad:   0.128 | loss: 0.43 | perp.:   1.54
#  b 300/529 >>   34.3 ms/b | lr:   0.0015 | grad norm: 0.98 | max abs grad:   0.072 | loss: 0.42 | perp.:   1.53
#  b 400/529 >>   32.9 ms/b | lr:   0.0016 | grad norm: 1.60 | max abs grad:   0.173 | loss: 0.41 | perp.:   1.51
#  b 500/529 >>   31.6 ms/b | lr:   0.0016 | grad norm: 2.42 | max abs grad:   0.261 | loss: 0.41 | perp.:   1.51
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.71 sec | train_loss:  0.44 | train_perp:   1.55 | valid_loss:  0.20 | valid_perp.:   1.23
# ================================================================================================================
#
#
# Epoch  16/ 50) lr = 0.001563
#  b 100/526 >>   33.6 ms/b | lr:   0.0015 | grad norm: 1.30 | max abs grad:   0.096 | loss: 0.41 | perp.:   1.51
#  b 200/526 >>   34.5 ms/b | lr:   0.0017 | grad norm: 7.83 | max abs grad:   1.844 | loss: 0.43 | perp.:   1.54
#  b 300/526 >>   32.9 ms/b | lr:   0.0013 | grad norm: 1.12 | max abs grad:   0.102 | loss: 0.41 | perp.:   1.50
#  b 400/526 >>   32.7 ms/b | lr:   0.0016 | grad norm: 5.35 | max abs grad:   0.726 | loss: 0.41 | perp.:   1.51
#  b 500/526 >>   32.1 ms/b | lr:   0.0014 | grad norm: 1.01 | max abs grad:   0.086 | loss: 0.40 | perp.:   1.50
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.53 sec | train_loss:  0.42 | train_perp:   1.52 | valid_loss:  0.19 | valid_perp.:   1.22
# ================================================================================================================
#
#
# Epoch  17/ 50) lr = 0.001516
#  b 100/526 >>   32.4 ms/b | lr:   0.0016 | grad norm: 3.06 | max abs grad:   0.415 | loss: 0.39 | perp.:   1.47
#  b 200/526 >>   32.1 ms/b | lr:   0.0016 | grad norm: 1.65 | max abs grad:   0.179 | loss: 0.45 | perp.:   1.57
#  b 300/526 >>   31.0 ms/b | lr:   0.0017 | grad norm: 3.98 | max abs grad:   1.351 | loss: 0.40 | perp.:   1.49
#  b 400/526 >>   34.4 ms/b | lr:   0.0014 | grad norm: 0.99 | max abs grad:   0.075 | loss: 0.40 | perp.:   1.49
#  b 500/526 >>   32.7 ms/b | lr:   0.0015 | grad norm: 1.43 | max abs grad:   0.166 | loss: 0.37 | perp.:   1.45
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.04 sec | train_loss:  0.40 | train_perp:   1.50 | valid_loss:  0.19 | valid_perp.:   1.21
# ================================================================================================================
#
#
# Epoch  18/ 50) lr = 0.001473
#  b 100/527 >>   31.8 ms/b | lr:   0.0012 | grad norm: 1.55 | max abs grad:   0.126 | loss: 0.39 | perp.:   1.47
#  b 200/527 >>   32.1 ms/b | lr:   0.0014 | grad norm: 1.48 | max abs grad:   0.176 | loss: 0.41 | perp.:   1.51
#  b 300/527 >>   31.0 ms/b | lr:   0.0015 | grad norm: 1.27 | max abs grad:   0.105 | loss: 0.37 | perp.:   1.45
#  b 400/527 >>   33.8 ms/b | lr:   0.0014 | grad norm: 1.03 | max abs grad:   0.082 | loss: 0.38 | perp.:   1.46
#  b 500/527 >>   32.7 ms/b | lr:   0.0015 | grad norm: 1.70 | max abs grad:   0.270 | loss: 0.38 | perp.:   1.47
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.87 sec | train_loss:  0.39 | train_perp:   1.48 | valid_loss:  0.19 | valid_perp.:   1.21
# ================================================================================================================
#
#
# Epoch  19/ 50) lr = 0.001434
#  b 100/523 >>   33.6 ms/b | lr:   0.0011 | grad norm: 1.56 | max abs grad:   0.402 | loss: 0.39 | perp.:   1.47
#  b 200/523 >>   33.4 ms/b | lr:   0.0014 | grad norm: 1.45 | max abs grad:   0.133 | loss: 0.36 | perp.:   1.43
#  b 300/523 >>   32.5 ms/b | lr:   0.0014 | grad norm: 1.35 | max abs grad:   0.221 | loss: 0.36 | perp.:   1.43
#  b 400/523 >>   33.1 ms/b | lr:   0.0014 | grad norm: 0.90 | max abs grad:   0.112 | loss: 0.37 | perp.:   1.45
#  b 500/523 >>   32.2 ms/b | lr:   0.0014 | grad norm: 1.05 | max abs grad:   0.130 | loss: 0.35 | perp.:   1.42
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.18 sec | train_loss:  0.37 | train_perp:   1.45 | valid_loss:  0.19 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  20/ 50) lr = 0.001398
#  b 100/521 >>   34.2 ms/b | lr:   0.0011 | grad norm: 3.93 | max abs grad:   0.386 | loss: 0.36 | perp.:   1.44
#  b 200/521 >>   32.0 ms/b | lr:   0.0016 | grad norm: 9.33 | max abs grad:   3.174 | loss: 0.37 | perp.:   1.45
#  b 300/521 >>   32.7 ms/b | lr:   0.0015 | grad norm: 1.69 | max abs grad:   0.255 | loss: 0.37 | perp.:   1.45
#  b 400/521 >>   31.9 ms/b | lr:   0.0015 | grad norm: 1.02 | max abs grad:   0.090 | loss: 0.34 | perp.:   1.40
#  b 500/521 >>   32.5 ms/b | lr:   0.0014 | grad norm: 1.03 | max abs grad:   0.109 | loss: 0.34 | perp.:   1.41
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.03 sec | train_loss:  0.36 | train_perp:   1.44 | valid_loss:  0.19 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  21/ 50) lr = 0.001364
#  b 100/518 >>   32.3 ms/b | lr:   0.0014 | grad norm: 1.35 | max abs grad:   0.124 | loss: 0.36 | perp.:   1.43
#  b 200/518 >>   33.4 ms/b | lr:   0.0011 | grad norm: 15.50 | max abs grad:   3.551 | loss: 0.35 | perp.:   1.42
#  b 300/518 >>   32.7 ms/b | lr:   0.0012 | grad norm: 1.25 | max abs grad:   0.139 | loss: 0.34 | perp.:   1.41
#  b 400/518 >>   33.3 ms/b | lr:   0.0014 | grad norm: 2.29 | max abs grad:   0.317 | loss: 0.33 | perp.:   1.39
#  b 500/518 >>   34.7 ms/b | lr:   0.0012 | grad norm: 1.11 | max abs grad:   0.157 | loss: 0.36 | perp.:   1.44
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.22 sec | train_loss:  0.35 | train_perp:   1.42 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  22/ 50) lr = 0.001333
#  b 100/526 >>   31.9 ms/b | lr:   0.0012 | grad norm: 3.64 | max abs grad:   0.978 | loss: 0.33 | perp.:   1.39
#  b 200/526 >>   32.6 ms/b | lr:   0.0011 | grad norm: 0.91 | max abs grad:   0.079 | loss: 0.33 | perp.:   1.39
#  b 300/526 >>   33.0 ms/b | lr:   0.0014 | grad norm: 1.19 | max abs grad:   0.196 | loss: 0.34 | perp.:   1.41
#  b 400/526 >>   31.4 ms/b | lr:   0.0013 | grad norm: 0.79 | max abs grad:   0.073 | loss: 0.35 | perp.:   1.42
#  b 500/526 >>   30.7 ms/b | lr:   0.0013 | grad norm: 1.41 | max abs grad:   0.268 | loss: 0.32 | perp.:   1.38
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.74 sec | train_loss:  0.33 | train_perp:   1.39 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  23/ 50) lr = 0.001303
#  b 100/526 >>   32.5 ms/b | lr:   0.0013 | grad norm: 1.18 | max abs grad:   0.256 | loss: 0.36 | perp.:   1.43
#  b 200/526 >>   32.1 ms/b | lr:   0.0012 | grad norm: 2.34 | max abs grad:   0.258 | loss: 0.33 | perp.:   1.39
#  b 300/526 >>   32.7 ms/b | lr:   0.0012 | grad norm: 0.92 | max abs grad:   0.088 | loss: 0.33 | perp.:   1.40
#  b 400/526 >>   31.6 ms/b | lr:   0.0012 | grad norm: 0.52 | max abs grad:   0.051 | loss: 0.32 | perp.:   1.38
#  b 500/526 >>   32.4 ms/b | lr:   0.0013 | grad norm: 0.96 | max abs grad:   0.084 | loss: 0.34 | perp.:   1.40
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.99 sec | train_loss:  0.34 | train_perp:   1.40 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  24/ 50) lr = 0.001276
#  b 100/527 >>   31.5 ms/b | lr:   0.0011 | grad norm: 0.83 | max abs grad:   0.118 | loss: 0.33 | perp.:   1.40
#  b 200/527 >>   31.0 ms/b | lr:   0.0014 | grad norm: 1.27 | max abs grad:   0.139 | loss: 0.31 | perp.:   1.37
#  b 300/527 >>   36.0 ms/b | lr:   0.0013 | grad norm: 1.06 | max abs grad:   0.147 | loss: 0.35 | perp.:   1.42
#  b 400/527 >>   37.0 ms/b | lr:   0.0013 | grad norm: 0.72 | max abs grad:   0.054 | loss: 0.32 | perp.:   1.37
#  b 500/527 >>   36.5 ms/b | lr:   0.0012 | grad norm: 0.77 | max abs grad:   0.081 | loss: 0.34 | perp.:   1.40
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  18.12 sec | train_loss:  0.33 | train_perp:   1.39 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  25/ 50) lr = 0.00125
#  b 100/527 >>   32.2 ms/b | lr:   0.0012 | grad norm: 0.72 | max abs grad:   0.113 | loss: 0.32 | perp.:   1.38
#  b 200/527 >>   30.0 ms/b | lr:   0.0013 | grad norm: 3.74 | max abs grad:   1.583 | loss: 0.31 | perp.:   1.37
#  b 300/527 >>   32.1 ms/b | lr:   0.0012 | grad norm: 1.06 | max abs grad:   0.092 | loss: 0.31 | perp.:   1.36
#  b 400/527 >>   32.6 ms/b | lr:    0.001 | grad norm: 2.79 | max abs grad:   0.544 | loss: 0.32 | perp.:   1.38
#  b 500/527 >>   35.2 ms/b | lr:   0.0012 | grad norm: 0.99 | max abs grad:   0.088 | loss: 0.31 | perp.:   1.36
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.31 sec | train_loss:  0.32 | train_perp:   1.37 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  26/ 50) lr = 0.001226
#  b 100/522 >>   35.9 ms/b | lr:   0.0012 | grad norm: 0.80 | max abs grad:   0.071 | loss: 0.31 | perp.:   1.37
#  b 200/522 >>   36.5 ms/b | lr:   0.0013 | grad norm: 3.84 | max abs grad:   0.574 | loss: 0.30 | perp.:   1.35
#  b 300/522 >>   37.0 ms/b | lr:   0.0012 | grad norm: 0.75 | max abs grad:   0.059 | loss: 0.33 | perp.:   1.39
#  b 400/522 >>   35.0 ms/b | lr:   0.0011 | grad norm: 0.67 | max abs grad:   0.059 | loss: 0.29 | perp.:   1.34
#  b 500/522 >>   32.5 ms/b | lr:   0.0013 | grad norm: 1.31 | max abs grad:   0.177 | loss: 0.33 | perp.:   1.39
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  18.45 sec | train_loss:  0.31 | train_perp:   1.36 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  27/ 50) lr = 0.001203
#  b 100/521 >>   32.5 ms/b | lr:   0.0011 | grad norm: 2.01 | max abs grad:   0.504 | loss: 0.30 | perp.:   1.35
#  b 200/521 >>   33.5 ms/b | lr:   0.0013 | grad norm: 1.44 | max abs grad:   0.210 | loss: 0.34 | perp.:   1.41
#  b 300/521 >>   34.1 ms/b | lr:   0.0011 | grad norm: 0.81 | max abs grad:   0.076 | loss: 0.29 | perp.:   1.34
#  b 400/521 >>   34.1 ms/b | lr:   0.0012 | grad norm: 0.78 | max abs grad:   0.078 | loss: 0.30 | perp.:   1.35
#  b 500/521 >>   34.8 ms/b | lr:   0.0011 | grad norm: 0.48 | max abs grad:   0.056 | loss: 0.30 | perp.:   1.35
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.59 sec | train_loss:  0.30 | train_perp:   1.35 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  28/ 50) lr = 0.001181
#  b 100/527 >>   33.5 ms/b | lr:   0.0011 | grad norm: 0.84 | max abs grad:   0.117 | loss: 0.31 | perp.:   1.36
#  b 200/527 >>   36.4 ms/b | lr:    0.001 | grad norm: 0.58 | max abs grad:   0.047 | loss: 0.30 | perp.:   1.36
#  b 300/527 >>   34.2 ms/b | lr:   0.0011 | grad norm: 0.95 | max abs grad:   0.087 | loss: 0.30 | perp.:   1.35
#  b 400/527 >>   36.5 ms/b | lr:   0.0012 | grad norm: 0.92 | max abs grad:   0.141 | loss: 0.31 | perp.:   1.37
#  b 500/527 >>   32.4 ms/b | lr:   0.0012 | grad norm: 0.59 | max abs grad:   0.052 | loss: 0.32 | perp.:   1.38
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  18.09 sec | train_loss:  0.31 | train_perp:   1.36 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  29/ 50) lr = 0.001161
#  b 100/523 >>   34.2 ms/b | lr:    0.001 | grad norm: 0.95 | max abs grad:   0.125 | loss: 0.29 | perp.:   1.33
#  b 200/523 >>   33.1 ms/b | lr:  0.00099 | grad norm: 0.94 | max abs grad:   0.087 | loss: 0.33 | perp.:   1.39
#  b 300/523 >>   33.8 ms/b | lr:   0.0012 | grad norm: 2.99 | max abs grad:   0.547 | loss: 0.28 | perp.:   1.33
#  b 400/523 >>   33.3 ms/b | lr:   0.0012 | grad norm: 1.05 | max abs grad:   0.102 | loss: 0.28 | perp.:   1.32
#  b 500/523 >>   33.6 ms/b | lr:   0.0011 | grad norm: 0.54 | max abs grad:   0.081 | loss: 0.30 | perp.:   1.35
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.57 sec | train_loss:  0.30 | train_perp:   1.35 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  30/ 50) lr = 0.001141
#  b 100/524 >>   33.4 ms/b | lr:   0.0011 | grad norm: 0.43 | max abs grad:   0.047 | loss: 0.30 | perp.:   1.35
#  b 200/524 >>   33.3 ms/b | lr:   0.0013 | grad norm: 6.00 | max abs grad:   1.452 | loss: 0.29 | perp.:   1.34
#  b 300/524 >>   32.5 ms/b | lr:   0.0011 | grad norm: 0.57 | max abs grad:   0.050 | loss: 0.29 | perp.:   1.34
#  b 400/524 >>   33.4 ms/b | lr:   0.0013 | grad norm: 2.61 | max abs grad:   0.367 | loss: 0.29 | perp.:   1.33
#  b 500/524 >>   32.7 ms/b | lr:   0.0012 | grad norm: 0.97 | max abs grad:   0.114 | loss: 0.29 | perp.:   1.34
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.28 sec | train_loss:  0.29 | train_perp:   1.34 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  31/ 50) lr = 0.001123
#  b 100/524 >>   35.1 ms/b | lr:   0.0013 | grad norm: 3.48 | max abs grad:   0.690 | loss: 0.32 | perp.:   1.38
#  b 200/524 >>   33.1 ms/b | lr:   0.0011 | grad norm: 0.87 | max abs grad:   0.091 | loss: 0.29 | perp.:   1.33
#  b 300/524 >>   32.5 ms/b | lr:  0.00096 | grad norm: 1.82 | max abs grad:   0.279 | loss: 0.30 | perp.:   1.35
#  b 400/524 >>   32.4 ms/b | lr:   0.0011 | grad norm: 0.68 | max abs grad:   0.126 | loss: 0.28 | perp.:   1.33
#  b 500/524 >>   32.3 ms/b | lr:   0.0011 | grad norm: 0.65 | max abs grad:   0.088 | loss: 0.28 | perp.:   1.32
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.31 sec | train_loss:  0.30 | train_perp:   1.34 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  32/ 50) lr = 0.001105
#  b 100/533 >>   32.4 ms/b | lr:   0.0011 | grad norm: 0.71 | max abs grad:   0.068 | loss: 0.28 | perp.:   1.32
#  b 200/533 >>   33.1 ms/b | lr:   0.0012 | grad norm: 1.36 | max abs grad:   0.353 | loss: 0.28 | perp.:   1.33
#  b 300/533 >>   32.7 ms/b | lr:    0.001 | grad norm: 0.51 | max abs grad:   0.053 | loss: 0.28 | perp.:   1.33
#  b 400/533 >>   32.4 ms/b | lr:  0.00094 | grad norm: 6.19 | max abs grad:   1.029 | loss: 0.28 | perp.:   1.32
#  b 500/533 >>   31.7 ms/b | lr:   0.0012 | grad norm: 1.07 | max abs grad:   0.090 | loss: 0.29 | perp.:   1.33
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.20 sec | train_loss:  0.28 | train_perp:   1.32 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  33/ 50) lr = 0.001088
#  b 100/527 >>   33.1 ms/b | lr:   0.0011 | grad norm: 0.51 | max abs grad:   0.045 | loss: 0.28 | perp.:   1.32
#  b 200/527 >>   32.5 ms/b | lr:   0.0011 | grad norm: 0.63 | max abs grad:   0.060 | loss: 0.31 | perp.:   1.36
#  b 300/527 >>   33.0 ms/b | lr:   0.0012 | grad norm: 0.95 | max abs grad:   0.113 | loss: 0.29 | perp.:   1.34
#  b 400/527 >>   32.0 ms/b | lr:   0.0011 | grad norm: 0.68 | max abs grad:   0.051 | loss: 0.28 | perp.:   1.32
#  b 500/527 >>   32.6 ms/b | lr:  0.00098 | grad norm: 0.66 | max abs grad:   0.065 | loss: 0.28 | perp.:   1.33
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.20 sec | train_loss:  0.29 | train_perp:   1.34 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  34/ 50) lr = 0.001072
#  b 100/523 >>   32.6 ms/b | lr:    0.001 | grad norm: 1.40 | max abs grad:   0.299 | loss: 0.27 | perp.:   1.32
#  b 200/523 >>   32.4 ms/b | lr:   0.0012 | grad norm: 2.79 | max abs grad:   0.538 | loss: 0.28 | perp.:   1.32
#  b 300/523 >>   32.9 ms/b | lr:   0.0011 | grad norm: 0.62 | max abs grad:   0.067 | loss: 0.27 | perp.:   1.31
#  b 400/523 >>   32.6 ms/b | lr:   0.0011 | grad norm: 92.52 | max abs grad:  23.503 | loss: 0.26 | perp.:   1.30
#  b 500/523 >>   32.7 ms/b | lr:    0.001 | grad norm: 0.89 | max abs grad:   0.080 | loss: 0.27 | perp.:   1.31
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.15 sec | train_loss:  0.28 | train_perp:   1.32 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  35/ 50) lr = 0.001056
#  b 100/520 >>   31.2 ms/b | lr:   0.0011 | grad norm: 0.44 | max abs grad:   0.047 | loss: 0.29 | perp.:   1.33
#  b 200/520 >>   32.2 ms/b | lr:  0.00096 | grad norm: 0.54 | max abs grad:   0.064 | loss: 0.27 | perp.:   1.31
#  b 300/520 >>   33.4 ms/b | lr:   0.0011 | grad norm: 0.93 | max abs grad:   0.088 | loss: 0.28 | perp.:   1.32
#  b 400/520 >>   34.0 ms/b | lr:   0.0011 | grad norm: 0.42 | max abs grad:   0.059 | loss: 0.27 | perp.:   1.30
#  b 500/520 >>   32.4 ms/b | lr:    0.001 | grad norm: 0.76 | max abs grad:   0.074 | loss: 0.28 | perp.:   1.33
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.95 sec | train_loss:  0.28 | train_perp:   1.32 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  36/ 50) lr = 0.001042
#  b 100/530 >>   32.0 ms/b | lr:  0.00094 | grad norm: 0.69 | max abs grad:   0.083 | loss: 0.28 | perp.:   1.32
#  b 200/530 >>   33.8 ms/b | lr:  0.00099 | grad norm: 0.58 | max abs grad:   0.076 | loss: 0.28 | perp.:   1.32
#  b 300/530 >>   32.1 ms/b | lr:    0.001 | grad norm: 1.94 | max abs grad:   0.317 | loss: 0.27 | perp.:   1.31
#  b 400/530 >>   31.5 ms/b | lr:   0.0011 | grad norm: 0.75 | max abs grad:   0.082 | loss: 0.29 | perp.:   1.34
#  b 500/530 >>   31.0 ms/b | lr:  0.00089 | grad norm: 0.56 | max abs grad:   0.073 | loss: 0.31 | perp.:   1.36
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.92 sec | train_loss:  0.28 | train_perp:   1.32 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  37/ 50) lr = 0.001027
#  b 100/525 >>   33.4 ms/b | lr:  0.00098 | grad norm: 0.39 | max abs grad:   0.049 | loss: 0.28 | perp.:   1.32
#  b 200/525 >>   32.9 ms/b | lr:  0.00098 | grad norm: 0.67 | max abs grad:   0.079 | loss: 0.27 | perp.:   1.31
#  b 300/525 >>   32.4 ms/b | lr:   0.0011 | grad norm: 1.08 | max abs grad:   0.101 | loss: 0.31 | perp.:   1.36
#  b 400/525 >>   33.0 ms/b | lr:    0.001 | grad norm: 0.74 | max abs grad:   0.083 | loss: 0.29 | perp.:   1.33
#  b 500/525 >>   32.9 ms/b | lr:   0.0011 | grad norm: 1.04 | max abs grad:   0.143 | loss: 0.27 | perp.:   1.31
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.12 sec | train_loss:  0.28 | train_perp:   1.32 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  38/ 50) lr = 0.001014
#  b 100/523 >>   32.9 ms/b | lr:   0.0011 | grad norm: 0.84 | max abs grad:   0.085 | loss: 0.27 | perp.:   1.30
#  b 200/523 >>   33.0 ms/b | lr:    0.001 | grad norm: 0.55 | max abs grad:   0.048 | loss: 0.29 | perp.:   1.34
#  b 300/523 >>   32.8 ms/b | lr:   0.0011 | grad norm: 1.34 | max abs grad:   0.174 | loss: 0.28 | perp.:   1.32
#  b 400/523 >>   33.9 ms/b | lr:   0.0011 | grad norm: 0.60 | max abs grad:   0.067 | loss: 0.30 | perp.:   1.35
#  b 500/523 >>   31.8 ms/b | lr:   0.0011 | grad norm: 1.17 | max abs grad:   0.111 | loss: 0.27 | perp.:   1.31
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.18 sec | train_loss:  0.28 | train_perp:   1.33 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  39/ 50) lr = 0.001001
#  b 100/531 >>   31.2 ms/b | lr:  0.00095 | grad norm: 0.56 | max abs grad:   0.106 | loss: 0.28 | perp.:   1.32
#  b 200/531 >>   32.8 ms/b | lr:    0.001 | grad norm: 0.58 | max abs grad:   0.051 | loss: 0.30 | perp.:   1.35
#  b 300/531 >>   31.7 ms/b | lr:    0.001 | grad norm: 0.86 | max abs grad:   0.123 | loss: 0.27 | perp.:   1.30
#  b 400/531 >>   33.2 ms/b | lr:   0.0011 | grad norm: 1.27 | max abs grad:   0.140 | loss: 0.26 | perp.:   1.30
#  b 500/531 >>   33.2 ms/b | lr:  0.00095 | grad norm: 0.47 | max abs grad:   0.059 | loss: 0.27 | perp.:   1.32
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.36 sec | train_loss:  0.28 | train_perp:   1.32 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  40/ 50) lr = 0.0009882
#  b 100/522 >>   35.1 ms/b | lr:  0.00084 | grad norm: 1.39 | max abs grad:   0.217 | loss: 0.28 | perp.:   1.32
#  b 200/522 >>   32.1 ms/b | lr:  0.00084 | grad norm: 0.64 | max abs grad:   0.105 | loss: 0.28 | perp.:   1.32
#  b 300/522 >>   32.2 ms/b | lr:  0.00099 | grad norm: 0.55 | max abs grad:   0.095 | loss: 0.29 | perp.:   1.34
#  b 400/522 >>   32.7 ms/b | lr:  0.00099 | grad norm: 0.70 | max abs grad:   0.067 | loss: 0.26 | perp.:   1.29
#  b 500/522 >>   32.6 ms/b | lr:  0.00094 | grad norm: 0.49 | max abs grad:   0.114 | loss: 0.26 | perp.:   1.29
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.22 sec | train_loss:  0.27 | train_perp:   1.31 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  41/ 50) lr = 0.0009761
#  b 100/521 >>   32.8 ms/b | lr:  0.00098 | grad norm: 0.62 | max abs grad:   0.086 | loss: 0.26 | perp.:   1.30
#  b 200/521 >>   34.7 ms/b | lr:    0.001 | grad norm: 1.35 | max abs grad:   0.206 | loss: 0.29 | perp.:   1.33
#  b 300/521 >>   33.8 ms/b | lr:    0.001 | grad norm: 0.90 | max abs grad:   0.092 | loss: 0.26 | perp.:   1.29
#  b 400/521 >>   41.2 ms/b | lr:   0.0011 | grad norm: 2.78 | max abs grad:   0.465 | loss: 0.27 | perp.:   1.30
#  b 500/521 >>   39.3 ms/b | lr:    0.001 | grad norm: 0.97 | max abs grad:   0.147 | loss: 0.26 | perp.:   1.30
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  18.98 sec | train_loss:  0.27 | train_perp:   1.31 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  42/ 50) lr = 0.0009644
#  b 100/527 >>   37.8 ms/b | lr:  0.00092 | grad norm: 0.66 | max abs grad:   0.081 | loss: 0.28 | perp.:   1.32
#  b 200/527 >>   33.4 ms/b | lr:  0.00096 | grad norm: 0.66 | max abs grad:   0.166 | loss: 0.26 | perp.:   1.30
#  b 300/527 >>   33.7 ms/b | lr:    0.001 | grad norm: 1.33 | max abs grad:   0.162 | loss: 0.27 | perp.:   1.31
#  b 400/527 >>   42.9 ms/b | lr:  0.00096 | grad norm: 0.59 | max abs grad:   0.064 | loss: 0.26 | perp.:   1.30
#  b 500/527 >>   46.1 ms/b | lr:  0.00087 | grad norm: 0.52 | max abs grad:   0.056 | loss: 0.28 | perp.:   1.33
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  20.44 sec | train_loss:  0.27 | train_perp:   1.31 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  43/ 50) lr = 0.0009531
#  b 100/527 >>   33.7 ms/b | lr:  0.00091 | grad norm: 0.36 | max abs grad:   0.033 | loss: 0.27 | perp.:   1.31
#  b 200/527 >>   32.9 ms/b | lr:  0.00091 | grad norm: 16.17 | max abs grad:   3.747 | loss: 0.26 | perp.:   1.30
#  b 300/527 >>   33.2 ms/b | lr:  0.00091 | grad norm: 0.70 | max abs grad:   0.129 | loss: 0.29 | perp.:   1.33
#  b 400/527 >>   32.6 ms/b | lr:  0.00091 | grad norm: 0.59 | max abs grad:   0.060 | loss: 0.26 | perp.:   1.29
#  b 500/527 >>   32.3 ms/b | lr:    0.001 | grad norm: 0.65 | max abs grad:   0.092 | loss: 0.26 | perp.:   1.29
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.32 sec | train_loss:  0.26 | train_perp:   1.30 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  44/ 50) lr = 0.0009422
#  b 100/526 >>   32.3 ms/b | lr:   0.0008 | grad norm: 1.09 | max abs grad:   0.185 | loss: 0.26 | perp.:   1.30
#  b 200/526 >>   32.4 ms/b | lr:  0.00094 | grad norm: 0.45 | max abs grad:   0.058 | loss: 0.26 | perp.:   1.29
#  b 300/526 >>   31.3 ms/b | lr:  0.00098 | grad norm: 0.64 | max abs grad:   0.062 | loss: 0.30 | perp.:   1.35
#  b 400/526 >>   34.8 ms/b | lr:    0.001 | grad norm: 1.06 | max abs grad:   0.144 | loss: 0.26 | perp.:   1.30
#  b 500/526 >>   33.9 ms/b | lr:  0.00098 | grad norm: 0.50 | max abs grad:   0.051 | loss: 0.28 | perp.:   1.32
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.36 sec | train_loss:  0.26 | train_perp:   1.30 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  45/ 50) lr = 0.0009317
#  b 100/520 >>   32.2 ms/b | lr:    0.001 | grad norm: 0.78 | max abs grad:   0.070 | loss: 0.30 | perp.:   1.35
#  b 200/520 >>   32.2 ms/b | lr:  0.00084 | grad norm: 8.35 | max abs grad:   2.447 | loss: 0.25 | perp.:   1.28
#  b 300/520 >>   33.0 ms/b | lr:  0.00097 | grad norm: 0.75 | max abs grad:   0.089 | loss: 0.27 | perp.:   1.31
#  b 400/520 >>   31.4 ms/b | lr:  0.00084 | grad norm: 0.25 | max abs grad:   0.034 | loss: 0.28 | perp.:   1.32
#  b 500/520 >>   34.2 ms/b | lr:  0.00089 | grad norm: 0.45 | max abs grad:   0.065 | loss: 0.26 | perp.:   1.29
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.98 sec | train_loss:  0.26 | train_perp:   1.30 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  46/ 50) lr = 0.0009215
#  b 100/531 >>   31.7 ms/b | lr:  0.00096 | grad norm: 0.53 | max abs grad:   0.057 | loss: 0.26 | perp.:   1.30
#  b 200/531 >>   32.9 ms/b | lr:  0.00088 | grad norm: 0.72 | max abs grad:   0.094 | loss: 0.28 | perp.:   1.32
#  b 300/531 >>   31.1 ms/b | lr:  0.00092 | grad norm: 0.64 | max abs grad:   0.074 | loss: 0.27 | perp.:   1.32
#  b 400/531 >>   32.7 ms/b | lr:  0.00083 | grad norm: 0.38 | max abs grad:   0.046 | loss: 0.27 | perp.:   1.30
#  b 500/531 >>   30.6 ms/b | lr:  0.00083 | grad norm: 0.72 | max abs grad:   0.112 | loss: 0.28 | perp.:   1.32
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.97 sec | train_loss:  0.26 | train_perp:   1.30 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  47/ 50) lr = 0.0009117
#  b 100/524 >>   32.4 ms/b | lr:    0.001 | grad norm: 2.04 | max abs grad:   0.336 | loss: 0.30 | perp.:   1.35
#  b 200/524 >>   32.2 ms/b | lr:  0.00082 | grad norm: 1.15 | max abs grad:   0.144 | loss: 0.25 | perp.:   1.29
#  b 300/524 >>   32.0 ms/b | lr:  0.00087 | grad norm: 1.84 | max abs grad:   0.342 | loss: 0.26 | perp.:   1.30
#  b 400/524 >>   33.1 ms/b | lr:   0.0011 | grad norm: 20.76 | max abs grad:   7.967 | loss: 0.26 | perp.:   1.29
#  b 500/524 >>   33.0 ms/b | lr:  0.00091 | grad norm: 13.42 | max abs grad:   4.285 | loss: 0.26 | perp.:   1.29
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.00 sec | train_loss:  0.26 | train_perp:   1.30 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================
#
#
# Epoch  48/ 50) lr = 0.0009021
#  b 100/521 >>   34.3 ms/b | lr:   0.0009 | grad norm: 0.42 | max abs grad:   0.055 | loss: 0.26 | perp.:   1.30
#  b 200/521 >>   32.5 ms/b | lr:   0.0009 | grad norm: 0.47 | max abs grad:   0.056 | loss: 0.27 | perp.:   1.31
#  b 300/521 >>   33.4 ms/b | lr:  0.00086 | grad norm: 0.66 | max abs grad:   0.065 | loss: 0.26 | perp.:   1.30
#  b 400/521 >>   33.3 ms/b | lr:   0.0009 | grad norm: 0.51 | max abs grad:   0.080 | loss: 0.26 | perp.:   1.29
#  b 500/521 >>   32.7 ms/b | lr:  0.00086 | grad norm: 2.11 | max abs grad:   0.484 | loss: 0.26 | perp.:   1.29
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.29 sec | train_loss:  0.26 | train_perp:   1.30 | valid_loss:  0.18 | valid_perp.:   1.19
# ================================================================================================================
#
#
# Epoch  49/ 50) lr = 0.0008929
#  b 100/524 >>   31.5 ms/b | lr:  0.00089 | grad norm: 0.48 | max abs grad:   0.048 | loss: 0.26 | perp.:   1.29
#  b 200/524 >>   33.3 ms/b | lr:  0.00097 | grad norm: 0.80 | max abs grad:   0.141 | loss: 0.25 | perp.:   1.29
#  b 300/524 >>   32.2 ms/b | lr:  0.00081 | grad norm: 0.63 | max abs grad:   0.072 | loss: 0.25 | perp.:   1.28
#  b 400/524 >>   32.3 ms/b | lr:  0.00093 | grad norm: 1.02 | max abs grad:   0.167 | loss: 0.26 | perp.:   1.30
#  b 500/524 >>   32.3 ms/b | lr:  0.00081 | grad norm: 1.41 | max abs grad:   0.174 | loss: 0.26 | perp.:   1.30
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  16.91 sec | train_loss:  0.25 | train_perp:   1.29 | valid_loss:  0.18 | valid_perp.:   1.19
# ================================================================================================================
#
#
# Epoch  50/ 50) lr = 0.0008839
#  b 100/522 >>   34.1 ms/b | lr:   0.0008 | grad norm: 0.59 | max abs grad:   0.063 | loss: 0.25 | perp.:   1.29
#  b 200/522 >>   32.7 ms/b | lr:  0.00088 | grad norm: 0.71 | max abs grad:   0.085 | loss: 0.26 | perp.:   1.30
#  b 300/522 >>   32.4 ms/b | lr:    0.001 | grad norm: 1.49 | max abs grad:   0.304 | loss: 0.26 | perp.:   1.29
#  b 400/522 >>   32.5 ms/b | lr:  0.00096 | grad norm: 0.97 | max abs grad:   0.109 | loss: 0.26 | perp.:   1.30
#  b 500/522 >>   32.0 ms/b | lr:  0.00071 | grad norm: 3.41 | max abs grad:   0.834 | loss: 0.26 | perp.:   1.30
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time:  17.11 sec | train_loss:  0.26 | train_perp:   1.30 | valid_loss:  0.18 | valid_perp.:   1.20
# ================================================================================================================

# %%
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    enc_states, attn_states, dec_states = states
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])

# %%
test_loss = evaluate(test_data, save_wts = True)
print('test_loss: {:5.2f} | test_perplexity: {:5.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss:  0.18 | test_perplexity:  1.20

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 1 incorrectly predicted
#  Variable containing:
#     0     4     2     3     0     0     2     6     2     6     4
#     0     4     2     3     0     0     2     6     2     6     5
# [torch.LongTensor of size 2x11]
#
# 1 incorrectly predicted
#  Variable containing:
#     5     0     2     6     2     0     4     4     1     2     1
#     5     0     2     6     2     0     4     4     1     2     4
# [torch.LongTensor of size 2x11]
#
# 1 incorrectly predicted
#  Variable containing:
#     4     0     6     6     5     3     1     4     5     2     1
#     4     0     6     6     5     3     1     4     5     2     5
# [torch.LongTensor of size 2x11]
#
# 1 incorrectly predicted
#  Variable containing:
#     6     6     1     3     0     6     0     6     5     6     2
#     6     6     1     3     0     6     0     6     5     6     5
# [torch.LongTensor of size 2x11]

# %% [markdown]
# ## Visualizations
# List of modules in the model for reference:

# %%
modules = list(model.modules())
list(enumerate(modules))
# Out:
# [(0, RNNModel(
#     (drop): Dropout(p=0.1)
#     (relu): ReLU()
#     (embedding): Embedding(7, 64)
#     (encoders): ModuleList(
#       (0): LSTM(64, 32, dropout=0.1)
#     )
#     (attn): RecurrentAttention(
#       (drop): Dropout(p=0.1)
#       (softmax): Softmax()
#       (sigmoid): Sigmoid()
#       (rnn_stack): ModuleList(
#         (0): LSTMCell(64, 16)
#       )
#       (loc_align): Conv1d (1, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#       (alignment): Linear(in_features=64, out_features=1)
#       (attention): Linear(in_features=80, out_features=32)
#       (attn_act_fn): ReLU()
#     )
#     (decoders): ModuleList(
#       (0): LSTM(32, 64, dropout=0.1)
#     )
#     (projection): Linear(in_features=64, out_features=7)
#     (log_softmax): LogSoftmax()
#   )), (1, Dropout(p=0.1)), (2, ReLU()), (3, Embedding(7, 64)), (4, ModuleList(
#     (0): LSTM(64, 32, dropout=0.1)
#   )), (5, LSTM(64, 32, dropout=0.1)), (6, RecurrentAttention(
#     (drop): Dropout(p=0.1)
#     (softmax): Softmax()
#     (sigmoid): Sigmoid()
#     (rnn_stack): ModuleList(
#       (0): LSTMCell(64, 16)
#     )
#     (loc_align): Conv1d (1, 16, kernel_size=(5,), stride=(1,), padding=(2,))
#     (alignment): Linear(in_features=64, out_features=1)
#     (attention): Linear(in_features=80, out_features=32)
#     (attn_act_fn): ReLU()
#   )), (7, Dropout(p=0.1)), (8, Softmax()), (9, Sigmoid()), (10, ModuleList(
#     (0): LSTMCell(64, 16)
#   )), (11, LSTMCell(64, 16)), (12,
#   Conv1d (1, 16, kernel_size=(5,), stride=(1,), padding=(2,))), (13,
#   Linear(in_features=64, out_features=1)), (14,
#   Linear(in_features=80, out_features=32)), (15, ReLU()), (16, ModuleList(
#     (0): LSTM(32, 64, dropout=0.1)
#   )), (17, LSTM(32, 64, dropout=0.1)), (18,
#   Linear(in_features=64, out_features=7)), (19, LogSoftmax())]

# %% [markdown]
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(modules[3].weight.data)
plt.imshow(embed_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (7, 64)

# %%
attn = modules[6]

# %%
attn_wts = np.array(attn.attention.weight.data)
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Output attention sublayer (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (32, 80)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# The model output sequence is on the x-axis of each plot, with the weights summing to 1 along the y-axis, representing the input.
#
# The model seems to be considering all inputs in the sequence equally when making the first prediction in the sequence, but afterwards it only attends to the remaining items in the input sequence after each subsequent prediction is made. However, this trend is broken when making predictions for the last couple of outputs where it returns to looking at all of the items in the input sequence equally. It's therefore interesting to note that the only item the model predicts incorrectly in each of the examples is the very last one. The other two test models that were trained on a similar toy generated dataset also predicted each of the final items in the target sequence incorrectly, meaning the added highway connections and location alignment probably don't help with that final prediction (at least when the data is generated from a basic semi-Markov CRF like this one).
#
# At least for the predictions on the items in the middle of the target sequence, you can tell that the model is trying to make the prediction mostly based on the conditional probablity of seeing the remaining items in the input sequence, which is interesting because this toy dataset was generated by using a conditional distribution conditioned on some number of items appearing before each item.
#
# Anyways, this dataset seems too simple for any benefits from the location alignment and this skip connection variant to really show, so it'll be interesting to see how the various models perform on the PTB dataset.
