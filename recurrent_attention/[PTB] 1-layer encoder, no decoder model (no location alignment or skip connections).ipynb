# %%
import os
import pickle
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from model import *
from trainer import *

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Hyperparameters

# %%
model_test_name = '1_encoder_no_decoder'
ckpt_loc = os.path.join('checkpoints', model_test_name+'.pt')

# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 4
lr = 0.02
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 150
early_stopping = 10
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
encode_size = 256
h_size = 256
align_size = 256
decode_size = 256
n_enc_layers = 1
attn_rnn_layers = 1
n_dec_layers = 0
smooth_align = True
align_location = False
skip_connections = False

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler
#
# The learning rate scheduler sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    h_size = h_size, align_size = align_size, encode_size = encode_size,
    decode_size = decode_size, n_enc_layers = n_enc_layers,
    attn_rnn_layers = attn_rnn_layers, n_dec_layers = n_dec_layers,
    align_location = align_location, skip_connections = skip_connections,
    smooth_align = smooth_align, dropout = dropout
)
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
eval_criterion = LabelSmoothing(ntokens, smoothing = 0)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, decay_factor, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 9585409

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Train and evaluate

# %%
train_stats, stat, train_loss, data, targets, states, nstates = train_eval_loop(
    model, train_data, val_data, batch_size, eval_batch_size,
    seq_len, ntokens, criterion, eval_criterion, optimizer,
    lr_scheduler, epochs, warmup_steps, early_stopping,
    clip, log_interval, ckpt_loc
)
# Out:
# Epoch   1/150) lr = 2.795e-05 (warmup)
#  b 150/718 >> 2074.6 ms/b | lr: 2.465e-05 | grad norm:  2.69 | inf norm:    0.22 | loss: 7.60 | perp: 1991.28
#  b 300/718 >> 2071.0 ms/b | lr: 2.635e-05 | grad norm:  2.45 | inf norm:    0.24 | loss: 6.22 | perp:  501.43
#  b 450/718 >> 2126.0 ms/b | lr: 3.019e-05 | grad norm:  1.54 | inf norm:   0.088 | loss: 6.16 | perp:  472.48
#  b 600/718 >> 2084.9 ms/b | lr: 2.552e-05 | grad norm:  1.64 | inf norm:   0.079 | loss: 6.13 | perp:  459.43
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1503.13 sec | train loss, perp: 6.448,  631.55 | valid loss, perp: 6.434,  622.92
# Grad norm:  1.311 | Grad inf. norm:   0.04073 | Max abs param:     5.264
# ==============================================================================================================
#
#
# Epoch   2/150) lr = 5.59e-05 (warmup)
#  b 150/728 >> 2126.4 ms/b | lr: 5.103e-05 | grad norm:  1.32 | inf norm:    0.06 | loss: 6.14 | perp:  463.13
#  b 300/728 >> 2097.9 ms/b | lr:  5.59e-05 | grad norm:  1.29 | inf norm:   0.072 | loss: 6.06 | perp:  426.48
#  b 450/728 >> 2089.7 ms/b | lr:  5.59e-05 | grad norm:  1.04 | inf norm:   0.039 | loss: 6.03 | perp:  413.76
#  b 600/728 >> 2090.0 ms/b | lr:  5.27e-05 | grad norm:  1.03 | inf norm:   0.037 | loss: 6.00 | perp:  403.35
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1521.06 sec | train loss, perp: 6.031,  416.09 | valid loss, perp: 6.291,  539.85
# Grad norm:  0.964 | Grad inf. norm:   0.03934 | Max abs param:     5.265
# ==============================================================================================================
#
#
# Epoch   3/150) lr = 8.385e-05 (warmup)
#  b 150/716 >> 2173.1 ms/b | lr: 8.385e-05 | grad norm:  0.82 | inf norm:   0.022 | loss: 5.98 | perp:  394.68
#  b 300/716 >> 2174.6 ms/b | lr: 8.385e-05 | grad norm:  0.83 | inf norm:   0.027 | loss: 5.92 | perp:  371.11
#  b 450/716 >> 2279.8 ms/b | lr: 6.555e-05 | grad norm:  1.10 | inf norm:   0.046 | loss: 5.91 | perp:  367.11
#  b 600/716 >> 2335.8 ms/b | lr: 7.655e-05 | grad norm:  0.81 | inf norm:   0.033 | loss: 5.87 | perp:  354.58
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1624.77 sec | train loss, perp: 5.902,  365.81 | valid loss, perp: 6.169,  477.81
# Grad norm:  0.847 | Grad inf. norm:   0.03084 | Max abs param:     5.266
# ==============================================================================================================
#
#
# Epoch   4/150) lr = 0.0001118 (warmup)
#  b 150/723 >> 2063.9 ms/b | lr: 0.0001179 | grad norm:  0.66 | inf norm:    0.02 | loss: 5.87 | perp:  353.42
#  b 300/723 >> 2101.7 ms/b | lr:  9.86e-05 | grad norm:  0.87 | inf norm:   0.016 | loss: 5.81 | perp:  332.61
#  b 450/723 >> 2001.8 ms/b | lr: 0.0001054 | grad norm:  0.72 | inf norm:   0.023 | loss: 5.77 | perp:  319.59
#  b 600/723 >> 2085.6 ms/b | lr: 9.501e-05 | grad norm:  0.86 | inf norm:   0.024 | loss: 5.74 | perp:  311.81
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1484.01 sec | train loss, perp: 5.778,  323.22 | valid loss, perp: 6.039,  419.41
# Grad norm:  0.759 | Grad inf. norm:    0.0302 | Max abs param:     5.265
# ==============================================================================================================
#
#
# Epoch   5/150) lr = 0.0001398 (warmup)
#  b 150/726 >> 2129.8 ms/b | lr: 0.0001473 | grad norm:  0.69 | inf norm:   0.017 | loss: 5.72 | perp:  305.54
#  b 300/726 >> 2048.2 ms/b | lr: 0.0001276 | grad norm:  0.81 | inf norm:   0.023 | loss: 5.66 | perp:  287.93
#  b 450/726 >> 2013.7 ms/b | lr: 0.0001436 | grad norm:  0.69 | inf norm:   0.012 | loss: 5.64 | perp:  282.83
#  b 600/726 >> 1999.4 ms/b | lr: 0.0001276 | grad norm:  0.76 | inf norm:   0.017 | loss: 5.63 | perp:  278.76
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1480.52 sec | train loss, perp: 5.654,  285.35 | valid loss, perp: 5.918,  371.82
# Grad norm:  0.875 | Grad inf. norm:   0.02048 | Max abs param:     5.264
# ==============================================================================================================
#
#
# Epoch   6/150) lr = 0.0001677 (warmup)
#  b 150/726 >> 2045.6 ms/b | lr: 0.0001531 | grad norm:  0.82 | inf norm:   0.017 | loss: 5.61 | perp:  273.15
#  b 300/726 >> 2020.5 ms/b | lr: 0.0001723 | grad norm:  0.73 | inf norm:   0.015 | loss: 5.54 | perp:  255.21
#  b 450/726 >> 2049.5 ms/b | lr: 0.0001677 | grad norm:  0.75 | inf norm:   0.019 | loss: 5.54 | perp:  253.61
#  b 600/726 >> 2000.7 ms/b | lr: 0.0001479 | grad norm:  0.87 | inf norm:   0.022 | loss: 5.52 | perp:  248.93
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1468.66 sec | train loss, perp: 5.541,  254.85 | valid loss, perp: 5.809,  333.34
# Grad norm:  0.712 | Grad inf. norm:   0.01952 | Max abs param:     5.267
# ==============================================================================================================
#
#
# Epoch   7/150) lr = 0.0001957 (warmup)
#  b 150/719 >> 2055.6 ms/b | lr:  0.000201 | grad norm:  0.69 | inf norm:   0.012 | loss: 5.50 | perp:  245.75
#  b 300/719 >> 2067.2 ms/b | lr: 0.0001957 | grad norm:  0.75 | inf norm:   0.015 | loss: 5.45 | perp:  232.67
#  b 450/719 >> 2073.6 ms/b | lr: 0.0002062 | grad norm:  0.71 | inf norm:   0.016 | loss: 5.44 | perp:  229.99
#  b 600/719 >> 2059.9 ms/b | lr: 0.0002062 | grad norm:  0.74 | inf norm:   0.013 | loss: 5.42 | perp:  225.22
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1476.76 sec | train loss, perp: 5.442,  230.91 | valid loss, perp: 5.717,  304.08
# Grad norm:  0.757 | Grad inf. norm:   0.01818 | Max abs param:     5.267
# ==============================================================================================================
#
#
# Epoch   8/150) lr = 0.0002236 (warmup)
#  b 150/718 >> 2117.3 ms/b | lr: 0.0002297 | grad norm:  0.79 | inf norm:   0.016 | loss: 5.42 | perp:  226.00
#  b 300/718 >> 2043.5 ms/b | lr: 0.0002472 | grad norm:  0.72 | inf norm:   0.018 | loss: 5.35 | perp:  211.24
#  b 450/718 >> 2054.8 ms/b | lr: 0.0002357 | grad norm:  0.78 | inf norm:   0.015 | loss: 5.33 | perp:  207.05
#  b 600/718 >> 2057.5 ms/b | lr: 0.0002173 | grad norm:  0.85 | inf norm:   0.038 | loss: 5.33 | perp:  205.79
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1483.85 sec | train loss, perp: 5.352,  210.93 | valid loss, perp: 5.635,  279.99
# Grad norm:  1.022 | Grad inf. norm:   0.02806 | Max abs param:     5.267
# ==============================================================================================================
#
#
# Epoch   9/150) lr = 0.0002516 (warmup)
#  b 150/720 >> 2041.2 ms/b | lr: 0.0002781 | grad norm:  0.75 | inf norm:   0.013 | loss: 5.30 | perp:  201.00
#  b 300/720 >> 2098.0 ms/b | lr: 0.0002372 | grad norm:  0.99 | inf norm:   0.021 | loss: 5.27 | perp:  193.79
#  b 450/720 >> 2071.7 ms/b | lr: 0.0001569 | grad norm:  1.96 | inf norm:    0.08 | loss: 5.25 | perp:  191.39
#  b 600/720 >> 2088.8 ms/b | lr: 0.0002516 | grad norm:  0.86 | inf norm:   0.024 | loss: 5.25 | perp:  190.03
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1489.08 sec | train loss, perp: 5.263,  192.99 | valid loss, perp: 5.557,  258.92
# Grad norm:  0.932 | Grad inf. norm:     0.028 | Max abs param:     5.269
# ==============================================================================================================
#
#
# Epoch  10/150) lr = 0.0002795 (warmup)
#  b 150/720 >> 2164.4 ms/b | lr: 0.0003019 | grad norm:  0.76 | inf norm:   0.016 | loss: 5.22 | perp:  185.59
#  b 300/720 >> 2124.0 ms/b | lr: 0.0002552 | grad norm:  1.03 | inf norm:   0.021 | loss: 5.19 | perp:  180.04
#  b 450/720 >> 2122.3 ms/b | lr: 0.0002946 | grad norm:  0.86 | inf norm:   0.022 | loss: 5.17 | perp:  175.22
#  b 600/720 >> 2033.1 ms/b | lr: 0.0002716 | grad norm:  0.98 | inf norm:   0.032 | loss: 5.15 | perp:  171.80
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1514.92 sec | train loss, perp: 5.179,  177.58 | valid loss, perp: 5.484,  240.76
# Grad norm:  0.934 | Grad inf. norm:   0.02449 | Max abs param:     5.266
# ==============================================================================================================
#
#
# Epoch  11/150) lr = 0.0002665
#  b 150/715 >> 2098.1 ms/b | lr:  0.000259 | grad norm:  0.93 | inf norm:   0.034 | loss: 5.14 | perp:  170.24
#  b 300/715 >> 2337.2 ms/b | lr: 0.0002665 | grad norm:  0.94 | inf norm:   0.022 | loss: 5.09 | perp:  162.93
#  b 450/715 >> 2095.5 ms/b | lr: 0.0002513 | grad norm:  1.02 | inf norm:   0.022 | loss: 5.10 | perp:  163.88
#  b 600/715 >> 2161.8 ms/b | lr: 0.0002809 | grad norm:  0.84 | inf norm:   0.027 | loss: 5.09 | perp:  163.02
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1538.08 sec | train loss, perp: 5.102,  164.33 | valid loss, perp: 5.416,  224.96
# Grad norm:  1.080 | Grad inf. norm:   0.02555 | Max abs param:      5.26
# ==============================================================================================================
#
#
# Epoch  12/150) lr = 0.0002552
#  b 150/718 >> 2060.0 ms/b | lr: 0.0002406 | grad norm:  1.02 | inf norm:   0.024 | loss: 5.06 | perp:  157.15
#  b 300/718 >> 2072.3 ms/b | lr: 0.0002621 | grad norm:  0.98 | inf norm:    0.02 | loss: 5.02 | perp:  150.93
#  b 450/718 >> 2104.0 ms/b | lr: 0.0002406 | grad norm:  1.05 | inf norm:   0.021 | loss: 5.02 | perp:  151.69
#  b 600/718 >> 2133.4 ms/b | lr: 0.0002621 | grad norm:  1.01 | inf norm:   0.019 | loss: 5.01 | perp:  150.57
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1496.55 sec | train loss, perp: 5.030,  152.97 | valid loss, perp: 5.359,  212.48
# Grad norm:  0.993 | Grad inf. norm:   0.02534 | Max abs param:     5.262
# ==============================================================================================================
#
#
# Epoch  13/150) lr = 0.0002451
#  b 150/714 >> 2177.0 ms/b | lr: 0.0002889 | grad norm:  0.91 | inf norm:   0.029 | loss: 5.00 | perp:  148.34
#  b 300/714 >> 2102.1 ms/b | lr: 0.0002519 | grad norm:  1.01 | inf norm:   0.032 | loss: 4.97 | perp:  144.17
#  b 450/714 >> 2105.0 ms/b | lr: 0.0002162 | grad norm:  1.28 | inf norm:   0.032 | loss: 4.96 | perp:  143.16
#  b 600/714 >> 2113.6 ms/b | lr: 0.0002382 | grad norm:  1.08 | inf norm:   0.027 | loss: 4.96 | perp:  142.13
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1506.33 sec | train loss, perp: 4.970,  144.08 | valid loss, perp: 5.306,  201.58
# Grad norm:  0.964 | Grad inf. norm:   0.02835 | Max abs param:     5.256
# ==============================================================================================================
#
#
# Epoch  14/150) lr = 0.0002362
#  b 150/715 >> 2127.6 ms/b | lr: 0.0002362 | grad norm:  1.03 | inf norm:   0.028 | loss: 4.95 | perp:  141.04
#  b 300/715 >> 2095.0 ms/b | lr: 0.0002427 | grad norm:  1.07 | inf norm:   0.026 | loss: 4.89 | perp:  133.40
#  b 450/715 >> 2035.5 ms/b | lr: 0.0002083 | grad norm:  1.23 | inf norm:   0.024 | loss: 4.89 | perp:  132.64
#  b 600/715 >> 2166.8 ms/b | lr: 0.0002156 | grad norm:  1.28 | inf norm:   0.032 | loss: 4.92 | perp:  136.72
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1501.94 sec | train loss, perp: 4.912,  135.95 | valid loss, perp: 5.263,  193.12
# Grad norm:  1.100 | Grad inf. norm:   0.02874 | Max abs param:     5.259
# ==============================================================================================================
#
#
# Epoch  15/150) lr = 0.0002282
#  b 150/713 >> 2124.0 ms/b | lr: 0.0001701 | grad norm:  1.82 | inf norm:   0.054 | loss: 4.88 | perp:  131.02
#  b 300/713 >> 2108.0 ms/b | lr: 0.0002523 | grad norm:  1.00 | inf norm:   0.031 | loss: 4.86 | perp:  129.14
#  b 450/713 >> 2184.2 ms/b | lr: 0.0002013 | grad norm:  1.41 | inf norm:   0.042 | loss: 4.87 | perp:  129.95
#  b 600/713 >> 2092.6 ms/b | lr: 0.0002345 | grad norm:  1.14 | inf norm:   0.043 | loss: 4.86 | perp:  129.28
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1512.69 sec | train loss, perp: 4.868,  130.11 | valid loss, perp: 5.227,  186.23
# Grad norm:  1.306 | Grad inf. norm:   0.04521 | Max abs param:     5.256
# ==============================================================================================================
#
#
# Epoch  16/150) lr = 0.000221
#  b 150/716 >> 2049.5 ms/b | lr: 0.0001878 | grad norm:  1.41 | inf norm:   0.043 | loss: 4.83 | perp:  124.91
#  b 300/716 >> 2146.0 ms/b | lr: 0.0001949 | grad norm:  1.46 | inf norm:   0.053 | loss: 4.82 | perp:  124.19
#  b 450/716 >> 2091.7 ms/b | lr: 0.0002329 | grad norm:  1.13 | inf norm:   0.041 | loss: 4.83 | perp:  124.73
#  b 600/716 >> 2055.1 ms/b | lr: 0.0002443 | grad norm:  1.17 | inf norm:   0.067 | loss: 4.80 | perp:  121.04
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1492.14 sec | train loss, perp: 4.826,  124.67 | valid loss, perp: 5.187,  178.96
# Grad norm:  1.533 | Grad inf. norm:   0.06117 | Max abs param:     5.251
# ==============================================================================================================
#
#
# Epoch  17/150) lr = 0.0002144
#  b 150/717 >> 2090.5 ms/b | lr:  0.000226 | grad norm:  1.23 | inf norm:   0.074 | loss: 4.81 | perp:  122.29
#  b 300/717 >> 2087.6 ms/b | lr: 0.0002021 | grad norm:  1.37 | inf norm:   0.071 | loss: 4.78 | perp:  119.30
#  b 450/717 >> 2122.6 ms/b | lr: 0.0002475 | grad norm:  1.11 | inf norm:   0.075 | loss: 4.77 | perp:  117.79
#  b 600/717 >> 2079.4 ms/b | lr: 0.0002315 | grad norm:  1.20 | inf norm:   0.062 | loss: 4.77 | perp:  118.39
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1496.56 sec | train loss, perp: 4.781,  119.26 | valid loss, perp: 5.154,  173.04
# Grad norm:  1.283 | Grad inf. norm:   0.07267 | Max abs param:     5.248
# ==============================================================================================================
#
#
# Epoch  18/150) lr = 0.0002083
#  b 150/711 >> 2124.0 ms/b | lr: 0.0001837 | grad norm:  1.47 | inf norm:    0.12 | loss: 4.77 | perp:  118.47
#  b 300/711 >> 2111.3 ms/b | lr: 0.0002303 | grad norm:  1.24 | inf norm:   0.068 | loss: 4.74 | perp:  114.10
#  b 450/711 >> 2109.6 ms/b | lr: 0.0001902 | grad norm:  1.51 | inf norm:     0.1 | loss: 4.74 | perp:  115.00
#  b 600/711 >> 2121.4 ms/b | lr: 0.0002025 | grad norm:  1.41 | inf norm:     0.1 | loss: 4.74 | perp:  114.77
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1495.87 sec | train loss, perp: 4.752,  115.86 | valid loss, perp: 5.127,  168.50
# Grad norm:  1.351 | Grad inf. norm:   0.09639 | Max abs param:     5.245
# ==============================================================================================================
#
#
# Epoch  19/150) lr = 0.0002028
#  b 150/722 >> 2102.9 ms/b | lr: 0.0001971 | grad norm:  1.61 | inf norm:    0.14 | loss: 4.73 | perp:  113.32
#  b 300/722 >> 2023.9 ms/b | lr: 0.0002083 | grad norm:  1.38 | inf norm:    0.12 | loss: 4.69 | perp:  108.78
#  b 450/722 >> 2097.4 ms/b | lr: 0.0001788 | grad norm:  1.83 | inf norm:    0.17 | loss: 4.70 | perp:  109.43
#  b 600/722 >> 2021.2 ms/b | lr: 0.0002083 | grad norm:  1.53 | inf norm:    0.12 | loss: 4.68 | perp:  108.30
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1492.98 sec | train loss, perp: 4.706,  110.65 | valid loss, perp: 5.103,  164.55
# Grad norm:  1.743 | Grad inf. norm:    0.1293 | Max abs param:     5.246
# ==============================================================================================================
# Epoch  20/150) lr = 0.0001976
#  b 150/717 >> 2071.7 ms/b | lr: 0.0001921 | grad norm:  1.73 | inf norm:    0.18 | loss: 4.68 | perp:  108.08
#  b 300/717 >> 2093.3 ms/b | lr: 0.0002083 | grad norm:  1.51 | inf norm:    0.15 | loss: 4.68 | perp:  108.02
#  b 450/717 >> 2073.3 ms/b | lr: 0.0001863 | grad norm:  1.77 | inf norm:     0.2 | loss: 4.66 | perp:  105.74
#  b 600/717 >> 2064.2 ms/b | lr: 0.0001921 | grad norm:  1.73 | inf norm:    0.14 | loss: 4.66 | perp:  105.67
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1492.10 sec | train loss, perp: 4.679,  107.65 | valid loss, perp: 5.073,  159.63
# Grad norm:  1.802 | Grad inf. norm:    0.2013 | Max abs param:     5.239
# ==============================================================================================================
#
#
# Epoch  21/150) lr = 0.0001929
#  b 150/718 >> 2099.2 ms/b | lr: 0.0001701 | grad norm:  2.28 | inf norm:    0.31 | loss: 4.66 | perp:  105.73
#  b 300/718 >> 2060.6 ms/b | lr: 0.0001929 | grad norm:  1.90 | inf norm:    0.27 | loss: 4.64 | perp:  103.27
#  b 450/718 >> 2072.5 ms/b | lr: 0.0001639 | grad norm:  2.36 | inf norm:    0.23 | loss: 4.64 | perp:  103.22
#  b 600/718 >> 2108.0 ms/b | lr: 0.0001575 | grad norm:  2.61 | inf norm:    0.27 | loss: 4.64 | perp:  103.99
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1495.70 sec | train loss, perp: 4.652,  104.74 | valid loss, perp: 5.048,  155.77
# Grad norm:  1.920 | Grad inf. norm:    0.2715 | Max abs param:     5.236
# ==============================================================================================================
#
#
# Epoch  22/150) lr = 0.0001884
#  b 150/722 >> 2069.1 ms/b | lr: 0.0001662 | grad norm:  2.49 | inf norm:    0.27 | loss: 4.64 | perp:  103.12
#  b 300/722 >> 2006.4 ms/b | lr: 0.0001777 | grad norm:  2.57 | inf norm:    0.28 | loss: 4.59 | perp:   98.56
#  b 450/722 >> 2044.5 ms/b | lr: 0.0001831 | grad norm:  2.38 | inf norm:    0.28 | loss: 4.60 | perp:   99.87
#  b 600/722 >> 2134.4 ms/b | lr: 0.0001884 | grad norm:  2.33 | inf norm:    0.28 | loss: 4.63 | perp:  102.05
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1494.12 sec | train loss, perp: 4.622,  101.67 | valid loss, perp: 5.036,  153.91
# Grad norm:  2.546 | Grad inf. norm:    0.3041 | Max abs param:     5.233
# ==============================================================================================================
#
#
# Epoch  23/150) lr = 0.0001843
#  b 150/712 >> 2154.7 ms/b | lr: 0.0001943 | grad norm:  2.36 | inf norm:    0.31 | loss: 4.63 | perp:  102.28
#  b 300/712 >> 2100.9 ms/b | lr: 0.0001566 | grad norm:  3.13 | inf norm:    0.37 | loss: 4.59 | perp:   98.58
#  b 450/712 >> 2107.6 ms/b | lr: 0.0001682 | grad norm:  2.90 | inf norm:    0.32 | loss: 4.61 | perp:  100.43
#  b 600/712 >> 2092.2 ms/b | lr: 0.0001625 | grad norm:  3.14 | inf norm:    0.53 | loss: 4.58 | perp:   97.71
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1499.24 sec | train loss, perp: 4.606,  100.06 | valid loss, perp: 5.017,  150.95
# Grad norm:  3.350 | Grad inf. norm:    0.5073 | Max abs param:     5.229
# ==============================================================================================================
#
#
# Epoch  24/150) lr = 0.0001804
#  b 150/720 >> 2128.7 ms/b | lr: 0.0001854 | grad norm:  2.98 | inf norm:    0.42 | loss: 4.60 | perp:   99.12
#  b 300/720 >> 2007.6 ms/b | lr: 0.0001854 | grad norm:  2.96 | inf norm:    0.37 | loss: 4.54 | perp:   93.72
#  b 450/720 >> 2114.0 ms/b | lr: 0.0001345 | grad norm:  4.78 | inf norm:    0.55 | loss: 4.56 | perp:   95.95
#  b 600/720 >> 2049.0 ms/b | lr: 0.0001804 | grad norm:  3.24 | inf norm:    0.47 | loss: 4.56 | perp:   95.21
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1501.38 sec | train loss, perp: 4.571,   96.68 | valid loss, perp: 4.995,  147.68
# Grad norm:  2.919 | Grad inf. norm:    0.3814 | Max abs param:     5.224
# ==============================================================================================================
#
#
# Epoch  25/150) lr = 0.0001768
#  b 150/724 >> 2046.7 ms/b | lr: 0.0001816 | grad norm:  3.23 | inf norm:    0.46 | loss: 4.57 | perp:   96.48
#  b 300/724 >> 2112.2 ms/b | lr: 0.0001614 | grad norm:  3.85 | inf norm:    0.53 | loss: 4.53 | perp:   92.69
#  b 450/724 >> 2022.0 ms/b | lr: 0.0001382 | grad norm:  5.10 | inf norm:    0.78 | loss: 4.53 | perp:   92.52
#  b 600/724 >> 2151.5 ms/b | lr: 0.0001768 | grad norm:  3.83 | inf norm:    0.47 | loss: 4.54 | perp:   94.16
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1499.77 sec | train loss, perp: 4.549,   94.56 | valid loss, perp: 4.969,  143.93
# Grad norm:  3.461 | Grad inf. norm:    0.4054 | Max abs param:     5.223
# ==============================================================================================================
#
#
# Epoch  26/150) lr = 0.0001733
#  b 150/720 >> 2123.8 ms/b | lr: 0.0001582 | grad norm:  3.93 | inf norm:    0.51 | loss: 4.54 | perp:   93.96
#  b 300/720 >> 2055.9 ms/b | lr: 0.0001634 | grad norm:  4.19 | inf norm:    0.63 | loss: 4.51 | perp:   90.56
#  b 450/720 >> 2084.8 ms/b | lr: 0.0001415 | grad norm:  5.77 | inf norm:    0.84 | loss: 4.52 | perp:   91.90
#  b 600/720 >> 2072.1 ms/b | lr: 0.0001582 | grad norm:  4.92 | inf norm:    0.99 | loss: 4.51 | perp:   91.34
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1510.08 sec | train loss, perp: 4.529,   92.69 | valid loss, perp: 4.947,  140.80
# Grad norm:  4.417 | Grad inf. norm:    0.5807 | Max abs param:     5.224
# ==============================================================================================================
#
#
# Epoch  27/150) lr = 0.0001701
#  b 150/714 >> 2103.9 ms/b | lr: 0.0001701 | grad norm:  4.67 | inf norm:    0.63 | loss: 4.50 | perp:   90.42
#  b 300/714 >> 2153.7 ms/b | lr: 0.0001653 | grad norm:  4.86 | inf norm:    0.88 | loss: 4.51 | perp:   90.67
#  b 450/714 >> 2128.2 ms/b | lr: 0.0001701 | grad norm:  4.87 | inf norm:    0.71 | loss: 4.51 | perp:   90.75
#  b 600/714 >> 2091.1 ms/b | lr: 0.0001553 | grad norm:  5.41 | inf norm:     0.9 | loss: 4.50 | perp:   89.75
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1517.10 sec | train loss, perp: 4.515,   91.40 | valid loss, perp: 4.938,  139.44
# Grad norm:  5.410 | Grad inf. norm:    0.7303 | Max abs param:     5.226
# ==============================================================================================================
#
#
# Epoch  28/150) lr = 0.000167
#  b 150/711 >> 2158.1 ms/b | lr: 0.0001623 | grad norm:  5.18 | inf norm:    0.71 | loss: 4.50 | perp:   90.27
#  b 300/711 >> 2151.8 ms/b | lr: 0.0001473 | grad norm:  5.74 | inf norm:    0.72 | loss: 4.49 | perp:   88.86
#  b 450/711 >> 2124.5 ms/b | lr:  0.000167 | grad norm:  5.68 | inf norm:    0.85 | loss: 4.50 | perp:   90.18
#  b 600/711 >> 2119.2 ms/b | lr: 0.0001473 | grad norm:  7.35 | inf norm:     1.1 | loss: 4.48 | perp:   88.15
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1511.42 sec | train loss, perp: 4.499,   89.92 | valid loss, perp: 4.917,  136.65
# Grad norm:  5.044 | Grad inf. norm:    0.6627 | Max abs param:     5.225
# ==============================================================================================================
#
#
# Epoch  29/150) lr = 0.0001641
#  b 150/715 >> 2129.6 ms/b | lr: 0.0001547 | grad norm:  5.63 | inf norm:    0.69 | loss: 4.47 | perp:   87.27
#  b 300/715 >> 2099.9 ms/b | lr: 0.0001547 | grad norm:  5.82 | inf norm:       1 | loss: 4.47 | perp:   87.31
#  b 450/715 >> 2132.0 ms/b | lr: 0.0001498 | grad norm:  6.77 | inf norm:    0.99 | loss: 4.45 | perp:   85.86
#  b 600/715 >> 2074.1 ms/b | lr: 0.0001686 | grad norm:  5.97 | inf norm:    0.81 | loss: 4.47 | perp:   87.70
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1513.05 sec | train loss, perp: 4.474,   87.73 | valid loss, perp: 4.902,  134.52
# Grad norm:  6.322 | Grad inf. norm:     1.082 | Max abs param:     5.222
# ==============================================================================================================
#
#
# Epoch  30/150) lr = 0.0001614
#  b 150/720 >> 2088.9 ms/b | lr: 0.0001473 | grad norm:  7.03 | inf norm:     1.1 | loss: 4.47 | perp:   87.49
#  b 300/720 >> 2108.4 ms/b | lr: 0.0001701 | grad norm:  6.44 | inf norm:    0.91 | loss: 4.44 | perp:   84.63
#  b 450/720 >> 2028.0 ms/b | lr: 0.0001521 | grad norm:  7.39 | inf norm:    0.98 | loss: 4.43 | perp:   83.56
#  b 600/720 >> 2126.0 ms/b | lr: 0.0001423 | grad norm:  8.86 | inf norm:     2.2 | loss: 4.44 | perp:   84.53
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1503.14 sec | train loss, perp: 4.455,   86.08 | valid loss, perp: 4.884,  132.19
# Grad norm:  7.478 | Grad inf. norm:     1.131 | Max abs param:     5.222
# ==============================================================================================================
#
#
# Epoch  31/150) lr = 0.0001588
#  b 150/718 >> 2186.7 ms/b | lr: 0.0001631 | grad norm:  7.55 | inf norm:     1.2 | loss: 4.45 | perp:   85.87
#  b 300/718 >> 2066.0 ms/b | lr:   0.00014 | grad norm:  8.87 | inf norm:     1.4 | loss: 4.41 | perp:   82.66
#  b 450/718 >> 2147.1 ms/b | lr: 0.0001755 | grad norm:  6.94 | inf norm:     1.4 | loss: 4.42 | perp:   83.38
#  b 600/718 >> 2136.3 ms/b | lr: 0.0001755 | grad norm:  6.81 | inf norm:    0.92 | loss: 4.44 | perp:   84.87
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1522.47 sec | train loss, perp: 4.441,   84.89 | valid loss, perp: 4.873,  130.67
# Grad norm:  7.030 | Grad inf. norm:     1.119 | Max abs param:     5.222
# ==============================================================================================================
#
#
# Epoch  32/150) lr = 0.0001563
#  b 150/711 >> 2270.5 ms/b | lr: 0.0001518 | grad norm:  7.64 | inf norm:     1.1 | loss: 4.45 | perp:   85.64
#  b 300/711 >> 2152.2 ms/b | lr: 0.0001727 | grad norm:  8.77 | inf norm:     1.3 | loss: 4.41 | perp:   82.00
#  b 450/711 >> 2190.1 ms/b | lr: 0.0001727 | grad norm:  8.11 | inf norm:     1.5 | loss: 4.42 | perp:   82.75
#  b 600/711 >> 2129.1 ms/b | lr: 0.0001473 | grad norm:  8.59 | inf norm:     1.4 | loss: 4.43 | perp:   83.90
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1548.90 sec | train loss, perp: 4.436,   84.42 | valid loss, perp: 4.863,  129.38
# Grad norm:  8.730 | Grad inf. norm:     1.097 | Max abs param:     5.223
# ==============================================================================================================
#
#
# Epoch  33/150) lr = 0.0001539
#  b 150/721 >> 2029.3 ms/b | lr: 0.0001622 | grad norm:  8.27 | inf norm:     1.3 | loss: 4.41 | perp:   82.06
#  b 300/721 >> 2055.8 ms/b | lr: 0.0001495 | grad norm:  9.20 | inf norm:     1.4 | loss: 4.38 | perp:   80.04
#  b 450/721 >> 2064.9 ms/b | lr: 0.0001539 | grad norm:  9.18 | inf norm:     1.3 | loss: 4.39 | perp:   80.98
#  b 600/721 >> 2191.4 ms/b | lr: 0.0001451 | grad norm:  9.18 | inf norm:     1.2 | loss: 4.42 | perp:   83.33
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1498.42 sec | train loss, perp: 4.411,   82.34 | valid loss, perp: 4.869,  130.20
# Grad norm:  8.607 | Grad inf. norm:     1.325 | Max abs param:     5.221
# ==============================================================================================================
#
#
# Epoch  34/150) lr = 0.0001516
#  b 150/724 >> 2154.3 ms/b | lr: 0.0001557 | grad norm:  9.83 | inf norm:     1.6 | loss: 4.42 | perp:   82.74
#  b 300/724 >> 2088.2 ms/b | lr: 0.0001473 | grad norm: 11.05 | inf norm:     1.7 | loss: 4.40 | perp:   81.43
#  b 450/724 >> 2094.0 ms/b | lr: 0.0001676 | grad norm:  9.99 | inf norm:     1.7 | loss: 4.38 | perp:   79.88
#  b 600/724 >> 2012.0 ms/b | lr: 0.0001473 | grad norm: 10.23 | inf norm:     2.1 | loss: 4.35 | perp:   77.77
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1508.62 sec | train loss, perp: 4.394,   80.93 | valid loss, perp: 4.849,  127.64
# Grad norm:  9.771 | Grad inf. norm:      1.49 | Max abs param:     5.218
# ==============================================================================================================
#
#
# Epoch  35/150) lr = 0.0001494
#  b 150/719 >> 2057.0 ms/b | lr: 0.0001535 | grad norm: 11.14 | inf norm:       2 | loss: 4.39 | perp:   80.46
#  b 300/719 >> 2213.6 ms/b | lr: 0.0001535 | grad norm:  9.46 | inf norm:     1.7 | loss: 4.38 | perp:   79.48
#  b 450/719 >> 2082.1 ms/b | lr: 0.0001575 | grad norm: 11.13 | inf norm:     1.7 | loss: 4.36 | perp:   78.49
#  b 600/719 >> 2159.8 ms/b | lr:  0.000122 | grad norm: 12.60 | inf norm:     1.9 | loss: 4.37 | perp:   79.28
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1522.79 sec | train loss, perp: 4.386,   80.29 | valid loss, perp: 4.823,  124.36
# Grad norm: 10.346 | Grad inf. norm:     1.503 | Max abs param:     5.221
# ==============================================================================================================
#
#
# Epoch  36/150) lr = 0.0001473
#  b 150/719 >> 2127.2 ms/b | lr: 0.0001203 | grad norm: 13.45 | inf norm:     2.6 | loss: 4.39 | perp:   81.01
#  b 300/719 >> 2094.8 ms/b | lr: 0.0001514 | grad norm: 11.36 | inf norm:       2 | loss: 4.36 | perp:   78.19
#  b 450/719 >> 2089.6 ms/b | lr: 0.0001389 | grad norm: 11.24 | inf norm:     2.1 | loss: 4.36 | perp:   78.02
#  b 600/719 >> 2143.9 ms/b | lr: 0.0001389 | grad norm: 10.96 | inf norm:     1.5 | loss: 4.37 | perp:   79.06
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1510.94 sec | train loss, perp: 4.374,   79.35 | valid loss, perp: 4.818,  123.70
# Grad norm: 10.770 | Grad inf. norm:     1.708 | Max abs param:      5.22
# ==============================================================================================================
#
#
# Epoch  37/150) lr = 0.0001453
#  b 150/724 >> 2105.5 ms/b | lr: 0.0001453 | grad norm: 11.19 | inf norm:     1.6 | loss: 4.38 | perp:   79.68
#  b 300/724 >> 2089.5 ms/b | lr:  0.000137 | grad norm: 11.79 | inf norm:     1.8 | loss: 4.34 | perp:   76.60
#  b 450/724 >> 2123.5 ms/b | lr: 0.0001186 | grad norm: 14.45 | inf norm:     2.2 | loss: 4.35 | perp:   77.82
#  b 600/724 >> 2044.1 ms/b | lr: 0.0001412 | grad norm: 12.77 | inf norm:     2.1 | loss: 4.33 | perp:   75.88
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1508.27 sec | train loss, perp: 4.360,   78.29 | valid loss, perp: 4.838,  126.17
# Grad norm: 28.782 | Grad inf. norm:     4.138 | Max abs param:      5.22
# ==============================================================================================================
#
#
# Epoch  38/150) lr = 0.0001434
#  b 150/719 >> 2058.4 ms/b | lr: 0.0001393 | grad norm: 13.31 | inf norm:     2.1 | loss: 4.35 | perp:   77.59
#  b 300/719 >> 2140.8 ms/b | lr: 0.0001621 | grad norm: 11.84 | inf norm:     1.6 | loss: 4.34 | perp:   76.38
#  b 450/719 >> 2090.8 ms/b | lr: 0.0001171 | grad norm: 19.65 | inf norm:     3.3 | loss: 4.35 | perp:   77.44
#  b 600/719 >> 2106.4 ms/b | lr: 0.0001069 | grad norm: 21.10 | inf norm:     3.4 | loss: 4.35 | perp:   77.10
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1510.86 sec | train loss, perp: 4.356,   77.96 | valid loss, perp: 4.801,  121.63
# Grad norm: 12.389 | Grad inf. norm:     2.086 | Max abs param:      5.22
# ==============================================================================================================
#
#
# Epoch  39/150) lr = 0.0001415
#  b 150/724 >> 2120.5 ms/b | lr: 0.0001292 | grad norm: 14.51 | inf norm:     2.2 | loss: 4.36 | perp:   77.88
#  b 300/724 >> 2093.4 ms/b | lr: 0.0001334 | grad norm: 13.92 | inf norm:     2.3 | loss: 4.33 | perp:   75.68
#  b 450/724 >> 2117.4 ms/b | lr: 0.0001334 | grad norm: 14.22 | inf norm:     1.8 | loss: 4.33 | perp:   75.90
#  b 600/724 >> 2040.0 ms/b | lr: 0.0001292 | grad norm: 13.64 | inf norm:     2.4 | loss: 4.31 | perp:   74.65
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1516.94 sec | train loss, perp: 4.338,   76.53 | valid loss, perp: 4.816,  123.51
# Grad norm: 15.541 | Grad inf. norm:     2.279 | Max abs param:     5.215
# ==============================================================================================================
#
#
# Epoch  40/150) lr = 0.0001398
#  b 150/721 >> 2112.9 ms/b | lr: 0.0001398 | grad norm: 14.33 | inf norm:     2.2 | loss: 4.34 | perp:   76.62
#  b 300/721 >> 2105.1 ms/b | lr: 0.0001436 | grad norm: 13.39 | inf norm:     2.1 | loss: 4.31 | perp:   74.51
#  b 450/721 >> 2103.5 ms/b | lr: 0.0001358 | grad norm: 13.82 | inf norm:     2.2 | loss: 4.32 | perp:   75.52
#  b 600/721 >> 2117.7 ms/b | lr: 0.0001358 | grad norm: 18.49 | inf norm:     3.9 | loss: 4.30 | perp:   73.70
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1524.34 sec | train loss, perp: 4.332,   76.08 | valid loss, perp: 4.780,  119.15
# Grad norm: 14.721 | Grad inf. norm:      2.83 | Max abs param:     5.214
# ==============================================================================================================
#
#
# Epoch  41/150) lr = 0.000138
#  b 150/714 >> 2151.6 ms/b | lr: 0.0001301 | grad norm: 15.06 | inf norm:     2.6 | loss: 4.33 | perp:   76.11
#  b 300/714 >> 2148.7 ms/b | lr:  0.000138 | grad norm: 15.31 | inf norm:     2.4 | loss: 4.31 | perp:   74.74
#  b 450/714 >> 2134.4 ms/b | lr: 0.0001342 | grad norm: 15.24 | inf norm:     2.4 | loss: 4.31 | perp:   74.70
#  b 600/714 >> 2133.5 ms/b | lr:  0.000138 | grad norm: 16.51 | inf norm:     2.8 | loss: 4.31 | perp:   74.31
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1534.01 sec | train loss, perp: 4.328,   75.83 | valid loss, perp: 4.772,  118.18
# Grad norm: 14.029 | Grad inf. norm:     2.118 | Max abs param:     5.214
# ==============================================================================================================
#
#
# Epoch  42/150) lr = 0.0001364
#  b 150/710 >> 2148.0 ms/b | lr: 0.0001438 | grad norm: 16.60 | inf norm:     2.5 | loss: 4.32 | perp:   75.14
#  b 300/710 >> 2170.9 ms/b | lr: 0.0001325 | grad norm: 19.62 | inf norm:     2.6 | loss: 4.29 | perp:   73.18
#  b 450/710 >> 2352.3 ms/b | lr: 0.0001364 | grad norm: 17.03 | inf norm:     2.7 | loss: 4.32 | perp:   75.19
#  b 600/710 >> 2243.3 ms/b | lr: 0.0001508 | grad norm: 18.03 | inf norm:     2.7 | loss: 4.31 | perp:   74.58
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1591.86 sec | train loss, perp: 4.326,   75.66 | valid loss, perp: 4.767,  117.56
# Grad norm: 16.438 | Grad inf. norm:     3.555 | Max abs param:     5.212
# ==============================================================================================================
#
#
# Epoch  43/150) lr = 0.0001348
#  b 150/720 >> 2262.1 ms/b | lr: 0.0001348 | grad norm: 18.27 | inf norm:     3.7 | loss: 4.32 | perp:   75.44
#  b 300/720 >> 2204.0 ms/b | lr: 0.0001146 | grad norm: 24.31 | inf norm:     4.7 | loss: 4.28 | perp:   72.39
#  b 450/720 >> 2178.7 ms/b | lr:  0.000123 | grad norm: 16.86 | inf norm:     2.8 | loss: 4.28 | perp:   72.01
#  b 600/720 >> 2218.6 ms/b | lr: 0.0001421 | grad norm: 16.51 | inf norm:     2.2 | loss: 4.29 | perp:   73.04
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1596.56 sec | train loss, perp: 4.305,   74.09 | valid loss, perp: 4.780,  119.13
# Grad norm: 23.113 | Grad inf. norm:      3.15 | Max abs param:      5.21
# ==============================================================================================================
#
#
# Epoch  44/150) lr = 0.0001333
#  b 150/716 >> 2275.9 ms/b | lr: 0.0001473 | grad norm: 16.87 | inf norm:     2.4 | loss: 4.31 | perp:   74.64
#  b 300/716 >> 2309.6 ms/b | lr: 0.0001295 | grad norm: 19.60 | inf norm:     2.8 | loss: 4.29 | perp:   72.91
#  b 450/716 >> 2220.5 ms/b | lr: 0.0001405 | grad norm: 17.66 | inf norm:     3.2 | loss: 4.27 | perp:   71.82
#  b 600/716 >> 2199.0 ms/b | lr: 0.0001369 | grad norm: 19.30 | inf norm:     2.9 | loss: 4.28 | perp:   72.24
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1607.57 sec | train loss, perp: 4.301,   73.78 | valid loss, perp: 4.767,  117.54
# Grad norm: 16.148 | Grad inf. norm:     3.241 | Max abs param:     5.209
# ==============================================================================================================
#
#
# Epoch  45/150) lr = 0.0001318
#  b 150/712 >> 2290.1 ms/b | lr:  0.000128 | grad norm: 19.61 | inf norm:     3.3 | loss: 4.32 | perp:   75.34
#  b 300/712 >> 2308.6 ms/b | lr: 0.0001318 | grad norm: 17.95 | inf norm:     2.1 | loss: 4.28 | perp:   72.17
#  b 450/712 >> 2275.1 ms/b | lr: 0.0001318 | grad norm: 21.47 | inf norm:     3.5 | loss: 4.27 | perp:   71.62
#  b 600/712 >> 2324.0 ms/b | lr: 0.0001354 | grad norm: 20.56 | inf norm:     2.5 | loss: 4.28 | perp:   72.43
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1628.45 sec | train loss, perp: 4.297,   73.50 | valid loss, perp: 4.770,  117.97
# Grad norm: 22.832 | Grad inf. norm:     3.406 | Max abs param:     5.209
# ==============================================================================================================
#
#
# Epoch  46/150) lr = 0.0001303
#  b 150/721 >> 2295.2 ms/b | lr: 0.0001303 | grad norm: 19.41 | inf norm:     3.2 | loss: 4.29 | perp:   72.82
#  b 300/721 >> 2256.6 ms/b | lr: 0.0001149 | grad norm: 22.20 | inf norm:     3.8 | loss: 4.27 | perp:   71.76
#  b 450/721 >> 2236.1 ms/b | lr: 0.0001374 | grad norm: 19.82 | inf norm:     3.4 | loss: 4.26 | perp:   70.69
#  b 600/721 >> 2255.5 ms/b | lr: 0.0001374 | grad norm: 18.22 | inf norm:     2.7 | loss: 4.27 | perp:   71.42
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1634.93 sec | train loss, perp: 4.280,   72.21 | valid loss, perp: 4.745,  114.98
# Grad norm: 23.557 | Grad inf. norm:     4.822 | Max abs param:     5.209
# ==============================================================================================================
#
#
# Epoch  47/150) lr = 0.0001289
#  b 150/721 >> 2322.7 ms/b | lr: 0.0001253 | grad norm: 25.09 | inf norm:     4.5 | loss: 4.29 | perp:   72.80
#  b 300/721 >> 2255.5 ms/b | lr: 0.0001177 | grad norm: 19.46 | inf norm:     3.3 | loss: 4.25 | perp:   69.81
#  b 450/721 >> 2309.3 ms/b | lr: 0.0001253 | grad norm: 18.33 | inf norm:     2.9 | loss: 4.27 | perp:   71.26
#  b 600/721 >> 2204.5 ms/b | lr: 0.0001289 | grad norm: 19.31 | inf norm:     3.2 | loss: 4.24 | perp:   69.42
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1639.01 sec | train loss, perp: 4.272,   71.67 | valid loss, perp: 4.736,  114.00
# Grad norm: 18.742 | Grad inf. norm:     3.233 | Max abs param:     5.211
# ==============================================================================================================
#
#
# Epoch  48/150) lr = 0.0001276
#  b 150/716 >> 2243.7 ms/b | lr: 0.0001125 | grad norm: 21.18 | inf norm:     3.4 | loss: 4.26 | perp:   70.99
#  b 300/716 >> 2330.0 ms/b | lr: 0.0001311 | grad norm: 22.11 | inf norm:     3.2 | loss: 4.26 | perp:   71.02
#  b 450/716 >> 2312.7 ms/b | lr: 0.0001311 | grad norm: 19.38 | inf norm:     3.9 | loss: 4.26 | perp:   70.98
#  b 600/716 >> 2286.8 ms/b | lr:  0.000124 | grad norm: 20.87 | inf norm:     2.9 | loss: 4.25 | perp:   69.96
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1642.12 sec | train loss, perp: 4.274,   71.79 | valid loss, perp: 4.716,  111.68
# Grad norm: 21.289 | Grad inf. norm:     2.796 | Max abs param:     5.211
# ==============================================================================================================
#
#
# Epoch  49/150) lr = 0.0001263
#  b 150/712 >> 2339.0 ms/b | lr: 0.0001297 | grad norm: 20.34 | inf norm:     3.7 | loss: 4.27 | perp:   71.38
#  b 300/712 >> 2353.8 ms/b | lr: 0.0001153 | grad norm: 24.66 | inf norm:       6 | loss: 4.25 | perp:   69.94
#  b 450/712 >> 2245.7 ms/b | lr: 0.0001263 | grad norm: 32.04 | inf norm:     5.9 | loss: 4.25 | perp:   70.04
#  b 600/712 >> 2363.8 ms/b | lr: 0.0001331 | grad norm: 25.33 | inf norm:     4.4 | loss: 4.27 | perp:   71.36
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1645.72 sec | train loss, perp: 4.271,   71.56 | valid loss, perp: 4.731,  113.37
# Grad norm: 21.442 | Grad inf. norm:      3.27 | Max abs param:     5.213
# ==============================================================================================================
#
#
# Epoch  50/150) lr = 0.000125
#  b 150/713 >> 2314.8 ms/b | lr: 0.0001215 | grad norm: 21.34 | inf norm:     3.1 | loss: 4.27 | perp:   71.67
#  b 300/713 >> 2350.2 ms/b | lr: 0.0001318 | grad norm: 21.72 | inf norm:     4.1 | loss: 4.25 | perp:   70.02
#  b 450/713 >> 2336.2 ms/b | lr: 0.0001318 | grad norm: 19.14 | inf norm:     3.4 | loss: 4.25 | perp:   70.30
#  b 600/713 >> 2250.0 ms/b | lr: 0.0001179 | grad norm: 23.48 | inf norm:     3.7 | loss: 4.23 | perp:   68.57
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1646.31 sec | train loss, perp: 4.262,   70.98 | valid loss, perp: 4.715,  111.60
# Grad norm: 22.083 | Grad inf. norm:     3.478 | Max abs param:      5.21
# ==============================================================================================================
#
#
# Epoch  51/150) lr = 0.0001238
#  b 150/724 >> 2386.5 ms/b | lr: 0.0001272 | grad norm: 22.95 | inf norm:     4.6 | loss: 4.26 | perp:   70.97
#  b 300/724 >> 2236.9 ms/b | lr:  0.000113 | grad norm: 29.81 | inf norm:     4.8 | loss: 4.21 | perp:   67.30
#  b 450/724 >> 2259.5 ms/b | lr: 0.0001272 | grad norm: 23.05 | inf norm:     3.6 | loss: 4.21 | perp:   67.36
#  b 600/724 >> 2277.5 ms/b | lr: 0.0001238 | grad norm: 22.33 | inf norm:     3.5 | loss: 4.24 | perp:   69.48
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1661.75 sec | train loss, perp: 4.244,   69.66 | valid loss, perp: 4.721,  112.32
# Grad norm: 40.405 | Grad inf. norm:     8.905 | Max abs param:      5.21
# ==============================================================================================================
#
#
# Epoch  52/150) lr = 0.0001226
#  b 150/714 >> 2364.9 ms/b | lr: 0.0001292 | grad norm: 26.68 | inf norm:     4.5 | loss: 4.27 | perp:   71.63
#  b 300/714 >> 2245.9 ms/b | lr: 0.0001119 | grad norm: 24.61 | inf norm:     3.5 | loss: 4.23 | perp:   68.39
#  b 450/714 >> 2269.0 ms/b | lr: 0.0001119 | grad norm: 23.06 | inf norm:     3.4 | loss: 4.22 | perp:   68.00
#  b 600/714 >> 2242.7 ms/b | lr: 0.0001226 | grad norm: 25.68 | inf norm:     4.7 | loss: 4.22 | perp:   68.03
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1634.88 sec | train loss, perp: 4.246,   69.83 | valid loss, perp: 4.710,  111.10
# Grad norm: 28.257 | Grad inf. norm:     4.766 | Max abs param:     5.211
# ==============================================================================================================
#
#
# Epoch  53/150) lr = 0.0001214
#  b 150/713 >> 2345.5 ms/b | lr: 0.0001214 | grad norm: 25.24 | inf norm:     4.2 | loss: 4.27 | perp:   71.58
#  b 300/713 >> 2332.0 ms/b | lr: 0.0001214 | grad norm: 26.74 | inf norm:     5.2 | loss: 4.22 | perp:   67.77
#  b 450/713 >> 2305.6 ms/b | lr: 0.0001311 | grad norm: 24.39 | inf norm:     3.9 | loss: 4.22 | perp:   67.76
#  b 600/713 >> 2281.9 ms/b | lr: 0.0001032 | grad norm: 36.31 | inf norm:     5.7 | loss: 4.23 | perp:   69.06
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1650.08 sec | train loss, perp: 4.244,   69.69 | valid loss, perp: 4.692,  109.06
# Grad norm: 23.895 | Grad inf. norm:     3.663 | Max abs param:     5.214
# ==============================================================================================================
#
#
# Epoch  54/150) lr = 0.0001203
#  b 150/716 >> 2241.8 ms/b | lr: 0.0001061 | grad norm: 23.63 | inf norm:     4.3 | loss: 4.23 | perp:   68.82
#  b 300/716 >> 2329.4 ms/b | lr: 0.0001236 | grad norm: 26.43 | inf norm:     3.9 | loss: 4.22 | perp:   67.72
#  b 450/716 >> 2272.3 ms/b | lr: 0.0001134 | grad norm: 22.52 | inf norm:     3.9 | loss: 4.22 | perp:   67.89
#  b 600/716 >> 2363.6 ms/b | lr: 0.0001389 | grad norm: 27.86 | inf norm:     4.2 | loss: 4.24 | perp:   69.59
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1644.27 sec | train loss, perp: 4.235,   69.04 | valid loss, perp: 4.689,  108.79
# Grad norm: 24.074 | Grad inf. norm:     3.803 | Max abs param:     5.211
# ==============================================================================================================
#
#
# Epoch  55/150) lr = 0.0001192
#  b 150/717 >> 2432.1 ms/b | lr: 0.0001318 | grad norm: 25.55 | inf norm:     4.3 | loss: 4.24 | perp:   69.20
#  b 300/717 >> 2464.7 ms/b | lr: 0.0001192 | grad norm: 28.37 | inf norm:     4.8 | loss: 4.21 | perp:   67.19
#  b 450/717 >> 2322.6 ms/b | lr: 0.0001088 | grad norm: 24.33 | inf norm:     5.4 | loss: 4.20 | perp:   66.39
#  b 600/717 >> 2353.0 ms/b | lr: 0.0001192 | grad norm: 28.07 | inf norm:     4.5 | loss: 4.22 | perp:   67.80
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1703.77 sec | train loss, perp: 4.224,   68.32 | valid loss, perp: 4.709,  110.96
# Grad norm: 31.445 | Grad inf. norm:     4.193 | Max abs param:     5.207
# ==============================================================================================================
#
#
# Epoch  56/150) lr = 0.0001181
#  b 150/724 >> 2380.7 ms/b | lr: 0.0001214 | grad norm: 25.23 | inf norm:     5.9 | loss: 4.23 | perp:   68.43
#  b 300/724 >> 2324.8 ms/b | lr: 0.0001181 | grad norm: 24.94 | inf norm:     3.4 | loss: 4.20 | perp:   66.68
#  b 450/724 >> 2297.2 ms/b | lr: 0.0001148 | grad norm: 36.78 | inf norm:     6.4 | loss: 4.20 | perp:   66.42
# ...
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1566.46 sec | train loss, perp: 4.017,   55.55 | valid loss, perp: 4.469,   87.30
# Grad norm: 98.522 | Grad inf. norm:     15.01 | Max abs param:     5.197
# ==============================================================================================================
#
#
# Epoch 133/150) lr = 7.664e-05
#  b 150/719 >> 2097.2 ms/b | lr: 5.419e-05 | grad norm: 91.26 | inf norm:      14 | loss: 3.99 | perp:   54.32
#  b 300/719 >> 2191.2 ms/b | lr: 8.079e-05 | grad norm: 72.63 | inf norm:      12 | loss: 4.01 | perp:   54.94
#  b 450/719 >> 2206.5 ms/b | lr: 6.996e-05 | grad norm: 66.01 | inf norm:     8.3 | loss: 4.01 | perp:   55.00
#  b 600/719 >> 2168.9 ms/b | lr: 7.448e-05 | grad norm: 90.68 | inf norm:      11 | loss: 4.00 | perp:   54.66
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1567.10 sec | train loss, perp: 4.018,   55.58 | valid loss, perp: 4.482,   88.37
# Grad norm: 57.504 | Grad inf. norm:     10.55 | Max abs param:     5.196
# ==============================================================================================================
#
#
# Epoch 134/150) lr = 7.636e-05
#  b 150/724 >> 2173.7 ms/b | lr: 7.845e-05 | grad norm: 80.65 | inf norm:      12 | loss: 4.03 | perp:   55.98
#  b 300/724 >> 2099.4 ms/b | lr: 8.817e-05 | grad norm: 114.10 | inf norm:      17 | loss: 3.99 | perp:   54.06
#  b 450/724 >> 2047.3 ms/b | lr:  7.42e-05 | grad norm: 80.90 | inf norm:     9.2 | loss: 3.97 | perp:   53.16
#  b 600/724 >> 2181.1 ms/b | lr: 7.636e-05 | grad norm: 64.80 | inf norm:      11 | loss: 4.01 | perp:   55.12
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1534.87 sec | train loss, perp: 4.011,   55.20 | valid loss, perp: 4.474,   87.68
# Grad norm: 100.819 | Grad inf. norm:      14.2 | Max abs param:     5.195
# ==============================================================================================================
#
#
# Epoch 135/150) lr = 7.607e-05
#  b 150/713 >> 2195.7 ms/b | lr: 8.019e-05 | grad norm: 116.50 | inf norm:      12 | loss: 4.03 | perp:   56.03
#  b 300/713 >> 2210.0 ms/b | lr: 6.709e-05 | grad norm: 121.40 | inf norm:      19 | loss: 4.01 | perp:   55.14
#  b 450/713 >> 2200.9 ms/b | lr: 7.393e-05 | grad norm: 71.68 | inf norm:      11 | loss: 4.00 | perp:   54.73
#  b 600/713 >> 2203.5 ms/b | lr: 7.393e-05 | grad norm: 69.98 | inf norm:     9.5 | loss: 4.00 | perp:   54.40
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1568.84 sec | train loss, perp: 4.024,   55.90 | valid loss, perp: 4.545,   94.20
# Grad norm: 164.574 | Grad inf. norm:     16.71 | Max abs param:     5.195
# ==============================================================================================================
#
#
# Epoch 136/150) lr = 7.579e-05
#  b 150/724 >> 2195.5 ms/b | lr: 6.188e-05 | grad norm: 115.86 | inf norm:      15 | loss: 4.03 | perp:   56.18
#  b 300/724 >> 2144.8 ms/b | lr: 6.919e-05 | grad norm: 94.99 | inf norm:      18 | loss: 3.98 | perp:   53.51
#  b 450/724 >> 2285.7 ms/b | lr: 7.146e-05 | grad norm: 96.11 | inf norm:      14 | loss: 3.99 | perp:   53.85
#  b 600/724 >> 2228.1 ms/b | lr: 7.787e-05 | grad norm: 84.07 | inf norm:      12 | loss: 3.97 | perp:   53.12
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1618.17 sec | train loss, perp: 4.008,   55.06 | valid loss, perp: 4.486,   88.78
# Grad norm: 72.980 | Grad inf. norm:     8.312 | Max abs param:     5.194
# ==============================================================================================================
#
#
# Epoch 137/150) lr = 7.552e-05
#  b 150/715 >> 2332.8 ms/b | lr:  7.96e-05 | grad norm: 76.42 | inf norm:      12 | loss: 4.04 | perp:   56.60
#  b 300/715 >> 2303.0 ms/b | lr: 7.758e-05 | grad norm: 81.46 | inf norm:      12 | loss: 4.01 | perp:   54.97
#  b 450/715 >> 2223.5 ms/b | lr: 7.758e-05 | grad norm: 65.43 | inf norm:      10 | loss: 3.97 | perp:   52.90
#  b 600/715 >> 2320.3 ms/b | lr: 8.349e-05 | grad norm: 67.58 | inf norm:      11 | loss: 4.01 | perp:   55.00
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1651.70 sec | train loss, perp: 4.017,   55.55 | valid loss, perp: 4.462,   86.69
# Grad norm: 187.350 | Grad inf. norm:     26.76 | Max abs param:     5.192
# ==============================================================================================================
#
#
# Epoch 138/150) lr = 7.524e-05
#  b 150/714 >> 2241.2 ms/b | lr: 6.869e-05 | grad norm: 77.32 | inf norm:      12 | loss: 4.00 | perp:   54.61
#  b 300/714 >> 2325.8 ms/b | lr: 7.524e-05 | grad norm: 67.83 | inf norm:     8.5 | loss: 4.00 | perp:   54.51
#  b 450/714 >> 2229.0 ms/b | lr: 7.312e-05 | grad norm: 111.69 | inf norm:      14 | loss: 3.98 | perp:   53.41
#  b 600/714 >> 2398.7 ms/b | lr: 6.869e-05 | grad norm: 103.99 | inf norm:      15 | loss: 4.01 | perp:   55.42
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1648.65 sec | train loss, perp: 4.010,   55.16 | valid loss, perp: 4.475,   87.83
# Grad norm: 94.110 | Grad inf. norm:     13.84 | Max abs param:     5.191
# ==============================================================================================================
#
#
# Epoch 139/150) lr = 7.497e-05
#  b 150/720 >> 2331.1 ms/b | lr: 6.371e-05 | grad norm: 90.31 | inf norm:      11 | loss: 4.02 | perp:   55.85
#  b 300/720 >> 2302.7 ms/b | lr: 7.702e-05 | grad norm: 67.25 | inf norm:      10 | loss: 4.00 | perp:   54.37
#  b 450/720 >> 2246.8 ms/b | lr: 7.497e-05 | grad norm: 84.46 | inf norm:      13 | loss: 3.98 | perp:   53.77
#  b 600/720 >> 2302.3 ms/b | lr: 6.612e-05 | grad norm: 70.21 | inf norm:      10 | loss: 3.98 | perp:   53.75
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1643.99 sec | train loss, perp: 4.010,   55.16 | valid loss, perp: 4.454,   85.99
# Grad norm: 67.662 | Grad inf. norm:     14.03 | Max abs param:     5.193
# ==============================================================================================================
#
#
# Epoch 140/150) lr = 7.47e-05
#  b 150/719 >> 2322.0 ms/b | lr: 7.675e-05 | grad norm: 65.08 | inf norm:     8.9 | loss: 4.01 | perp:   54.95
#  b 300/719 >> 2252.2 ms/b | lr: 7.675e-05 | grad norm: 76.26 | inf norm:     9.3 | loss: 3.98 | perp:   53.63
#  b 450/719 >> 2264.9 ms/b | lr: 8.444e-05 | grad norm: 87.92 | inf norm:      15 | loss: 3.99 | perp:   54.02
#  b 600/719 >> 2318.8 ms/b | lr: 8.069e-05 | grad norm: 108.01 | inf norm:      14 | loss: 3.99 | perp:   54.25
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1646.19 sec | train loss, perp: 4.007,   55.01 | valid loss, perp: 4.570,   96.51
# Grad norm: 122.958 | Grad inf. norm:     15.14 | Max abs param:     5.192
# ==============================================================================================================
#
#
# Epoch 141/150) lr = 7.444e-05
#  b 150/720 >> 2356.0 ms/b | lr: 7.846e-05 | grad norm: 100.67 | inf norm:      12 | loss: 4.03 | perp:   56.02
#  b 300/720 >> 2217.8 ms/b | lr: 7.648e-05 | grad norm: 95.04 | inf norm:      13 | loss: 3.97 | perp:   53.21
#  b 450/720 >> 2356.8 ms/b | lr: 6.795e-05 | grad norm: 104.65 | inf norm:      14 | loss: 4.00 | perp:   54.80
#  b 600/720 >> 2272.9 ms/b | lr: 7.234e-05 | grad norm: 73.48 | inf norm:      13 | loss: 3.97 | perp:   53.21
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1648.49 sec | train loss, perp: 4.008,   55.03 | valid loss, perp: 4.454,   85.95
# Grad norm: 129.167 | Grad inf. norm:     19.05 | Max abs param:     5.191
# ==============================================================================================================
#
#
# Epoch 142/150) lr = 7.417e-05
#  b 150/720 >> 2257.1 ms/b | lr: 6.771e-05 | grad norm: 117.16 | inf norm:      18 | loss: 4.00 | perp:   54.84
#  b 300/720 >> 2254.7 ms/b | lr: 7.819e-05 | grad norm: 73.91 | inf norm:      12 | loss: 3.99 | perp:   53.96
#  b 450/720 >> 2290.6 ms/b | lr: 7.819e-05 | grad norm: 104.88 | inf norm:      18 | loss: 3.99 | perp:   54.05
#  b 600/720 >> 2284.5 ms/b | lr: 7.819e-05 | grad norm: 106.79 | inf norm:      16 | loss: 3.98 | perp:   53.60
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1645.27 sec | train loss, perp: 4.005,   54.90 | valid loss, perp: 4.498,   89.82
# Grad norm: 107.556 | Grad inf. norm:     13.77 | Max abs param:      5.19
# ==============================================================================================================
#
#
# Epoch 143/150) lr = 7.391e-05
#  b 150/725 >> 2254.2 ms/b | lr: 8.172e-05 | grad norm: 77.42 | inf norm:      11 | loss: 4.00 | perp:   54.48
#  b 300/725 >> 2227.9 ms/b | lr: 7.791e-05 | grad norm: 88.24 | inf norm:      14 | loss: 3.97 | perp:   52.76
#  b 450/725 >> 2283.6 ms/b | lr: 7.594e-05 | grad norm: 83.25 | inf norm:      13 | loss: 3.99 | perp:   53.80
#  b 600/725 >> 2231.4 ms/b | lr: 7.594e-05 | grad norm: 59.49 | inf norm:     9.9 | loss: 3.97 | perp:   53.07
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1643.07 sec | train loss, perp: 3.998,   54.46 | valid loss, perp: 4.467,   87.08
# Grad norm: 106.691 | Grad inf. norm:     12.17 | Max abs param:      5.19
# ==============================================================================================================
#
#
# Epoch 144/150) lr = 7.366e-05
#  b 150/712 >> 2255.0 ms/b | lr: 7.764e-05 | grad norm: 113.89 | inf norm:      12 | loss: 4.00 | perp:   54.45
#  b 300/712 >> 2349.4 ms/b | lr: 7.366e-05 | grad norm: 101.90 | inf norm:      15 | loss: 3.99 | perp:   54.22
#  b 450/712 >> 2364.9 ms/b | lr: 7.956e-05 | grad norm: 130.90 | inf norm:      15 | loss: 4.02 | perp:   55.66
#  b 600/712 >> 2339.7 ms/b | lr: 6.724e-05 | grad norm: 93.59 | inf norm:      15 | loss: 4.00 | perp:   54.66
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1648.04 sec | train loss, perp: 4.010,   55.17 | valid loss, perp: 4.442,   84.92
# Grad norm: 100.757 | Grad inf. norm:        11 | Max abs param:     5.189
# ==============================================================================================================
#
#
# Epoch 145/150) lr = 7.34e-05
#  b 150/721 >> 2317.1 ms/b | lr: 5.993e-05 | grad norm: 119.97 | inf norm:      17 | loss: 4.01 | perp:   55.14
#  b 300/721 >> 2240.6 ms/b | lr: 6.473e-05 | grad norm: 111.01 | inf norm:      15 | loss: 3.95 | perp:   52.04
#  b 450/721 >> 2264.1 ms/b | lr: 7.133e-05 | grad norm: 81.83 | inf norm:      14 | loss: 3.99 | perp:   53.84
#  b 600/721 >> 2317.1 ms/b | lr:  7.34e-05 | grad norm: 111.61 | inf norm:      22 | loss: 3.98 | perp:   53.74
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1646.89 sec | train loss, perp: 3.999,   54.52 | valid loss, perp: 4.454,   85.97
# Grad norm: 77.120 | Grad inf. norm:     9.199 | Max abs param:     5.189
# ==============================================================================================================
#
#
# Epoch 146/150) lr = 7.315e-05
#  b 150/719 >> 2359.8 ms/b | lr: 8.087e-05 | grad norm: 170.77 | inf norm:      18 | loss: 4.01 | perp:   55.38
#  b 300/719 >> 2236.1 ms/b | lr: 7.711e-05 | grad norm: 118.25 | inf norm:      17 | loss: 3.97 | perp:   52.97
#  b 450/719 >> 2276.4 ms/b | lr: 6.897e-05 | grad norm: 116.79 | inf norm:      15 | loss: 3.97 | perp:   53.21
#  b 600/719 >> 2317.5 ms/b | lr: 8.792e-05 | grad norm: 93.10 | inf norm:      13 | loss: 3.98 | perp:   53.73
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1654.53 sec | train loss, perp: 4.001,   54.65 | valid loss, perp: 4.448,   85.46
# Grad norm: 98.900 | Grad inf. norm:     13.16 | Max abs param:     5.187
# ==============================================================================================================
#
#
# Epoch 147/150) lr = 7.29e-05
#  b 150/722 >> 2366.3 ms/b | lr: 7.684e-05 | grad norm: 101.64 | inf norm:      13 | loss: 4.01 | perp:   54.92
#  b 300/722 >> 2235.0 ms/b | lr:  7.49e-05 | grad norm: 111.96 | inf norm:      16 | loss: 3.97 | perp:   53.04
#  b 450/722 >> 2314.1 ms/b | lr: 7.085e-05 | grad norm: 74.12 | inf norm:      10 | loss: 3.99 | perp:   53.86
#  b 600/722 >> 2285.3 ms/b | lr: 6.873e-05 | grad norm: 113.12 | inf norm:      19 | loss: 3.97 | perp:   53.24
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1660.01 sec | train loss, perp: 3.996,   54.41 | valid loss, perp: 4.440,   84.79
# Grad norm: 79.345 | Grad inf. norm:     11.24 | Max abs param:     5.187
# ==============================================================================================================
#
#
# Epoch 148/150) lr = 7.265e-05
#  b 150/714 >> 2317.6 ms/b | lr: 7.465e-05 | grad norm: 77.19 | inf norm:      12 | loss: 4.02 | perp:   55.48
#  b 300/714 >> 2267.0 ms/b | lr: 7.465e-05 | grad norm: 150.40 | inf norm:      15 | loss: 3.97 | perp:   52.94
#  b 450/714 >> 2369.8 ms/b | lr:  5.68e-05 | grad norm: 163.21 | inf norm:      18 | loss: 3.99 | perp:   54.12
#  b 600/714 >> 2311.8 ms/b | lr: 7.658e-05 | grad norm: 173.14 | inf norm:      19 | loss: 3.99 | perp:   53.91
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1658.53 sec | train loss, perp: 4.005,   54.86 | valid loss, perp: 4.456,   86.12
# Grad norm: 76.783 | Grad inf. norm:     10.76 | Max abs param:     5.188
# ==============================================================================================================
#
#
# Epoch 149/150) lr = 7.241e-05
#  b 150/711 >> 2326.9 ms/b | lr: 6.827e-05 | grad norm: 120.42 | inf norm:      14 | loss: 4.01 | perp:   55.41
#  b 300/711 >> 2310.4 ms/b | lr: 7.439e-05 | grad norm: 83.50 | inf norm:      13 | loss: 3.98 | perp:   53.55
#  b 450/711 >> 2323.2 ms/b | lr: 7.037e-05 | grad norm: 81.89 | inf norm:      13 | loss: 3.98 | perp:   53.56
#  b 600/711 >> 2291.5 ms/b | lr: 7.633e-05 | grad norm: 125.00 | inf norm:      20 | loss: 3.98 | perp:   53.28
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1650.29 sec | train loss, perp: 4.000,   54.61 | valid loss, perp: 4.491,   89.24
# Grad norm: 98.806 | Grad inf. norm:     12.43 | Max abs param:     5.187
# ==============================================================================================================
#
#
# Epoch 150/150) lr = 7.217e-05
#  b 150/711 >> 2292.6 ms/b | lr: 7.014e-05 | grad norm: 124.68 | inf norm:      16 | loss: 4.00 | perp:   54.76
#  b 300/711 >> 2305.5 ms/b | lr: 6.588e-05 | grad norm: 95.39 | inf norm:      14 | loss: 3.97 | perp:   53.10
#  b 450/711 >> 2268.4 ms/b | lr: 6.365e-05 | grad norm: 83.45 | inf norm:      11 | loss: 3.98 | perp:   53.33
#  b 600/711 >> 2413.0 ms/b | lr: 7.415e-05 | grad norm: 81.99 | inf norm:      13 | loss: 3.99 | perp:   54.30
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1648.94 sec | train loss, perp: 4.001,   54.65 | valid loss, perp: 4.460,   86.49
# Grad norm: 84.024 | Grad inf. norm:     13.44 | Max abs param:     5.187
# ==============================================================================================================

# %%
CAUSES = ['output', 'grad']
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    _states = states
    if model.n_enc_layers > 0:
        enc_states = states[0]
        states = states[1:]
    if model.n_dec_layers > 0:
        dec_states = states[-1]
        states = states[:-1]
    attn_states = states[0]
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])
else:
    # Save training stats
    with open(os.path.join('stats', model_test_name+'.pkl'), 'wb') as f:
        pickle.dump(train_stats, f)
    with open(os.path.join('models', model_test_name+'.pt'), 'wb') as f:
        torch.save(model.state_dict(), f)

# %%
test_loss = evaluate(
    model, test_data, eval_batch_size, seq_len,
    ntokens, eval_criterion, save_wts = True
)
print('test_loss: {:5.3f} | test_perplexity: {:7.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss: 4.403 | test_perplexity:   81.69

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 17 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#  3257  3257  3257  3257  3257  3257  3257  3257  3257  3257  3257  3257  3257
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#  3257  3257  3257  3257  3257
# [torch.LongTensor of size 2x18]
#
# 14 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#   109    27    27    27    27    27    27    27    27    27    27    27    27
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#    27    27    27    27    27
# [torch.LongTensor of size 2x18]
#
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   119    26    26   119   119   119   119   119   119   119   119   119   119
#
# Columns 13 to 17
#    26  5463   119    26    26
#   119   119   119   119   119
# [torch.LongTensor of size 2x18]
#
# 18 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#    27    26    35    35    35    26    27    27    27   535   535   535   535
#
# Columns 13 to 17
#    35    27    27  1479   108
#   535   535   535   535   535
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
#
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(model.embedding.weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_norm, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = model.attn

# %%
align_wts = np.array(attn.alignment.weight.data)
plt.imshow(align_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_align_in'); plt.ylabel('d_align_out')
plt.title('Alignment sublayer weights')
plt.colorbar()
align_wts.shape
# Out:
# (256, 512)

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Attention sublayer weights (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 768)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# ## Plot training stat curves

# %%
epoch_range = range(1, train_stats['epochs']+1)
train_stats.keys()
# Out:
# dict_keys(['epochs', 'train_loss', 'val_loss', 'grad_norm', 'grad_inf_norm', 'max_param'])

# %%
plt.plot(epoch_range, train_stats['train_loss'])
plt.plot(epoch_range, train_stats['val_loss'])
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('Loss over training time')
plt.legend(['Train loss', 'Validation loss'])

# %%
plt.plot(epoch_range, train_stats['max_param'])
plt.xlabel('Epoch'); plt.ylabel('Largest parameter magnitude')
plt.title('Largest parameter magnitude over training time')
# Out:
# Text(0.5,1,'Largest parameter magnitude over training time')

# %%
fig, pnorm_ax = plt.subplots()
pnorm_ax.plot(epoch_range, train_stats['grad_norm'], 'b')
pnorm_ax.set_xlabel('Epoch');
pnorm_ax.set_ylabel('2-norm', color = 'b')

infnorm_ax = pnorm_ax.twinx()
infnorm_ax.plot(epoch_range, train_stats['grad_inf_norm'], 'r')
infnorm_ax.set_ylabel('infinite norm', color = 'r')

plt.title('Gradient norms over training time')
#fig.tight_layout()
# Out:
# Text(0.5,1,'Gradient norms over training time')
