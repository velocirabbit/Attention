# %%
import numpy as np
import time
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from recurrent_attention import RecurrentAttention

# %% [markdown]
# ## Overhead stuff
#
# Helper functions for batching, resetting hidden states, etc.

# %%
# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 2
lr = 0.02
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 50
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
encode_size = 256
h_size = 256
loc_align_size = 256
loc_align_kernel = 5
decode_size = 256
decode_out_size = 512
n_enc_layers = 1
attn_rnn_layers = 1
n_dec_layers = 1
smooth_align = True
align_location = True
bidirectional_attn = False

# %%
# Starting from sequential data, `batchify` arranges the dataset into columns.
# For instance, with the alphabet as the sequence and batch size 4, we'd get
# ┌ a g m s ┐
# │ b h n t │
# │ c i o u │
# │ d j p v │
# │ e k q w │
# └ f l r x ┘.
# These columns are treated as independent by the model, which means that the
# dependence of e. g. 'g' on 'f' can not be learned, but allows more efficient
# batch processing.
def batchify(data, batch_size):
    # Work out how cleanly we can divide the dataset into batches
    nbatches = data.size(0) // batch_size
    # Trim off any extra elements that wouldn't cleanly fit
    data = data.narrow(0, 0, nbatches * batch_size)
    # Evenly divide the data across the batches
    data = data.view(batch_size, -1).t().contiguous()
    return data

# Wraps hidden states into new Variables to detach them from their history
def repackage_hidden(h):
    if type(h) == Variable:
        return Variable(h.data)
    else:
        return tuple(repackage_hidden(v) for v in h)
    
# `get_batch` subdivides the source data into chunks of the specified length.
# E.g., using the example for the `batchify` function above and a length of 2,
# we'd get the following two Variables for i = 0:
# ┌ a g m s ┐ ┌ b h n t ┐
# └ b h n t ┘ └ c i o u ┘
# Note that despite the name of the function, the subdivison of data is not
# done along the batch dimension (i.e. dimension 1), since that was handled
# by the `batchify` function. The chunks are along dimension 0, corresponding
# to the `seq_len` dimension in the LSTM.
def get_batch(source, i, seq_len, evaluate = False):
    seq_len = min(seq_len, len(source) - 1 - i)
    data = Variable(source[i : i+seq_len], volatile = evaluate)
    target = Variable(source[i+1 : i+1+seq_len].view(-1), volatile = evaluate)
    return data, target

# %% [markdown]
# Label smoothing class for regularization.

# %%
class LabelSmoothing(nn.Module):
    def __init__(self, size, padding_idx = None, smoothing = 0.0):
        super(LabelSmoothing, self).__init__()
        self.criterion = nn.KLDivLoss()
        self.padding_idx = padding_idx
        self.confidence = 1.0 - smoothing
        self.smoothing = smoothing
        self.size = size
        self.true_dist = None
        
    def forward(self, x, target):
        assert x.size(1) == self.size
        true_dist = torch.zeros_like(x.data)
        true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
        true_dist.add_(self.smoothing / self.size)
        if self.padding_idx is not None:
            true_dist[:, self.padding_idx] = 0
            mask = torch.nonzero(target.data == self.padding_idx)
            if mask.dim() > 0:
                true_dist.index_fill_(0, mask.squeeze(), 0.0)
        self.true_dist = true_dist
        return self.criterion(x, Variable(true_dist, requires_grad = False)) * ntokens

# %% [markdown]
# Learning rate scheduler that sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
def get_lr_scheduler(h_size, warmup, optimizer):
    lrate = lambda e: h_size**(-0.5) * min((e+1)**(-decay_factor), (e+1) * warmup**(-(decay_factor+1)))
    return optim.lr_scheduler.LambdaLR(optimizer, lr_lambda = lrate)

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Model class

# %%
class RNNModel(nn.Module):
    def __init__(self, src_vocab, tgt_vocab, embed_size, encode_size, h_size,
                 decode_size, decode_out_size, n_enc_layers, attn_rnn_layers,
                 n_dec_layers, align_location = False, loc_align_size = 1,
                 loc_align_kernel = 1, smooth_align = False, bidirectional_attn = False,
                 tie_wts = True, dropout = 0.1):
        super(RNNModel, self).__init__()
        self.src_vocab = src_vocab
        self.tgt_vocab = tgt_vocab
        self.embed_size = embed_size
        self.encode_size = encode_size
        self.h_size = h_size
        self.decode_size = decode_size
        self.decode_out_size = decode_out_size
        self.n_enc_layers = n_enc_layers
        self.attn_rnn_layers = attn_rnn_layers
        self.n_dec_layers = n_dec_layers
        self.align_location = align_location
        self.loc_align_size = loc_align_size
        self.loc_align_kernel = loc_align_kernel
        self.smooth_align = smooth_align
        self.bidirectional_attn = bidirectional_attn
        self.tie_wts = tie_wts
        self.dropout = dropout
        
        self.drop = nn.Dropout(dropout)
        self.relu = nn.ReLU()
        
        self.embedding = nn.Embedding(src_vocab, embed_size)
        self.encoders = nn.ModuleList([
            nn.LSTM(
                input_size = embed_size if i == 0 else encode_size,
                hidden_size = encode_size, dropout = dropout
            ) for i in range(n_enc_layers)
        ])
        self.attn = RecurrentAttention(
            in_size = encode_size, h_size = h_size, out_size = decode_size,
            align_location = align_location, loc_align_size = loc_align_size,
            loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
            num_rnn_layers = attn_rnn_layers, attn_act_fn = 'ReLU',
            dropout = dropout, bidirectional = bidirectional_attn
        )
        self.decoders = nn.ModuleList([
            nn.LSTM(
                input_size = decode_size, dropout = dropout,
                hidden_size = decode_size if i < n_dec_layers-1 else decode_out_size,
            ) for i in range(n_dec_layers)
        ])
        self.projection = nn.Linear(decode_out_size, tgt_vocab)
        if tie_wts and src_vocab == tgt_vocab and embed_size == decode_out_size:
            self.embedding.weight = self.projection.weight
        self.log_softmax = nn.LogSoftmax(dim = -1)
            
        # For visualizations
        self.save_wts = False
        self.enc_out = None
        self.dec_out = None
        
    def init(self):
        for subnet in [self.encoders, self.decoders]:
            for layer in subnet:
                for p in layer.parameters():
                    if p.dim() > 1:
                        nn.init.xavier_normal(p)
                    else:
                        p.data.fill_(0)
        for p in self.projection.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform(p)
            else:
                p.data.fill_(0)
        self.attn.init()
        
    def init_states(self, batch_size):
        encoder_states = [
            (
                Variable(torch.zeros(1, batch_size, self.encode_size)),
                Variable(torch.zeros(1, batch_size, self.encode_size))
            ) for _ in range(self.n_enc_layers)
        ]
        attn_states = self.attn.init_rnn_states(batch_size)
        decoder_states = [
            (
                Variable(torch.zeros(
                    1, batch_size, self.decode_size if i < self.n_dec_layers-1 else self.decode_out_size
                )),
                Variable(torch.zeros(
                    1, batch_size, self.decode_size if i < self.n_dec_layers-1 else self.decode_out_size
                ))
            ) for i in range(self.n_dec_layers)
        ]
        return encoder_states, attn_states, decoder_states
    
    def forward(self, inputs, states):
        enc_states, attn_states, dec_states = states
        if self.save_wts:
            self.enc_out = []
            self.dec_out = []
        
        # Embedding layer
        embeddings = self.embedding(inputs) * np.sqrt(self.embed_size)
        
        # Encoder stack
        new_enc_states = []
        enc_in = self.drop(self.relu(embeddings))
        for states, encoder in zip(enc_states, self.encoders):
            enc_out, new_enc_state = encoder(enc_in, states)
            new_enc_states.append(new_enc_state)
            if self.save_wts:
                self.enc_out.append(enc_out.data.clone())
            enc_in = enc_out
                
        # Attention mechanism
        attn_out, new_attn_states = self.attn(enc_out, attn_states)
        
        # Decoder stack
        new_dec_states = []
        dec_in = attn_out
        for states, decoder in zip(dec_states, self.decoders):
            dec_out, new_dec_state = decoder(dec_in, states)
            new_dec_states.append(new_dec_state)
            if self.save_wts:
                self.dec_out.append(dec_out.data.clone())
            dec_in = dec_out
        
        # Projection layer
        logits = self.projection(dec_out)
        output = self.log_softmax(logits)
        
        return output, (new_enc_states, new_attn_states, new_dec_states)
    
    def train(self, mode = True, save_wts = False):
        super(RNNModel, self).train(mode)
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts
        
    def eval(self, save_wts = True):
        super(RNNModel, self).eval()
        self.attn.save_attn_wts = save_wts
        self.save_wts = save_wts

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    encode_size = encode_size, h_size = h_size, decode_size = decode_size,
    decode_out_size = decode_out_size, n_enc_layers = n_enc_layers,
    attn_rnn_layers = attn_rnn_layers, n_dec_layers = n_dec_layers,
    align_location = align_location, loc_align_size = loc_align_size,
    loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
    dropout = dropout
)
model.init()
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 8483089

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Define training and validation loops

# %%
def train():
    # Use random length sequences
    seq_lens = []
    tot_len = 0
    jitter = 0.15 * seq_len
    num_data = train_data.size(0)
    while tot_len < num_data - 2:
        if num_data - tot_len - 2 <= seq_len + jitter:
            slen = num_data - tot_len - 2
        else:
            slen = int(np.random.normal(seq_len, jitter))
            if slen <= 0:
                slen = seq_len    # eh
            if tot_len + slen >= num_data - jitter - 2:
                slen = num_data - tot_len - 2
        seq_lens.append(slen)
        tot_len += slen
    i_cumseq = [0] + list(np.cumsum(seq_lens)[:-1])
    idx = np.arange(len(seq_lens))
    np.random.shuffle(idx)
    # Turn on training mode
    model.train(save_wts = False)
    # Initialize RNN states
    states = model.init_states(batch_size)
    # Prep metainfo
    total_loss = 0
    total_epoch_loss = 0
    start_time = time.time()
    for batch, i in enumerate(idx):
        # Get training data
        data, targets = get_batch(train_data, i_cumseq[i], seq_lens[i])
        # Repackage the hidden states
        states = repackage_hidden(states)
        # Zero out gradients
        model.zero_grad()
        
        # Run the model forward
        output, _states = model(data, states)
        if np.isnan(output.data).any():
            return 0, total_epoch_loss[0], data, targets, states, _states
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        if np.isnan(loss.data[0]):
            return 1, total_epoch_loss[0], data, targets, states, _states
        states = _states
        # Propagate loss gradient backwards
        loss.backward()
        # Clip gradients
        if batch % log_interval == 0 and batch > 0:
            # Save gradient statistics before they're changed cuz we'll be logging this batch
            parameters = [p for p in model.parameters() if p.grad is not None]
            # Calculate the largest (absolute) gradient of all elements in the model parameters
            max_grad = max([p.grad.data.abs().max() for p in parameters])
        total_norm = nn.utils.clip_grad_norm(model.parameters(), clip)
        # Scale the batch learning rate so that shorter sequences aren't "stronger"
        scaled_lr = lr_scheduler.get_lr()[0] * np.sqrt(seq_lens[i] / seq_len)
        for param_group in optimizer.param_groups:
            param_group['lr'] = scaled_lr
        # Update parameters
        optimizer.step()
        
        # Get some metainfo
        total_loss += loss.data
        total_epoch_loss += loss.data * data.size(0)
        if batch % log_interval == 0 and batch > 0:
            elapsed = time.time() - start_time
            cur_loss = total_loss[0] / log_interval
            print(' b {:3d}/{:3d} >> {:6.1f} ms/b | lr: {:8.2g} | grad norm: {:4.2f} | max abs grad: {:7.3f} | loss: {:4.2f} | perp.: {:6.2f}'.format(
                batch, len(seq_lens), elapsed * 1000/log_interval, scaled_lr, total_norm, max_grad, cur_loss, np.exp(cur_loss)
            ))
            total_loss = 0
            start_time = time.time()
    return -1, total_epoch_loss[0] / num_data, None, None, None, None

# %%
def evaluate(data_src, save_wts = True):
    model.eval(save_wts = save_wts)
    total_loss = 0
    states = model.init_states(eval_batch_size)
    for i in range(0, data_src.size(0) - 1, seq_len):
        # Get data
        data, targets = get_batch(data_src, i, seq_len, evaluate = True)
        # Repackage the hidden states
        states = repackage_hidden(states)
        # Evaluate
        output, states = model(data, states)
        # Calculate loss
        loss = criterion(output.view(-1, ntokens), targets)
        total_loss += loss.data * data.size(0)
    return total_loss[0] / data_src.size(0)

# %% [markdown]
# Train and evaluate

# %%
WIDTH = 112
CAUSES = ['output', 'grad']
for epoch in range(epochs):
    lr_scheduler.step()
    print('Epoch {:3d}/{:3d}) lr = {:0.4g}{}'.format(epoch+1, epochs, np.mean(lr_scheduler.get_lr()[0]), ' (warmup)' if epoch < warmup_steps else ''))
    start_time = time.time()
    stat, train_loss, data, targets, states, nstates = train()
    if stat in list(range(len(CAUSES))):
        c = CAUSES[stat]
        n = (WIDTH - len(c) - 4) // 2
        print('\n' + (' '*n) + 'NaN ' + c)
        break
    elapsed = time.time() - start_time
    val_loss = evaluate(val_data, save_wts = False)
    max_param = max([p.data.abs().max() for p in model.parameters() if p.grad is not None])
    print('-' * WIDTH)
    print('Elapsed time: {:6.2f} sec | train_loss: {:5.2f} | train_perp: {:6.2f} | valid_loss: {:5.2f} | valid_perp.: {:6.2f}'.format(
        elapsed, train_loss, np.exp(train_loss), val_loss, np.exp(val_loss)
    ))
    print('=' * WIDTH)
    print('\n')
# Out:
# Epoch   1/ 50) lr = 2.795e-05 (warmup)
#  b 150/712 >> 2534.8 ms/b | lr:  2.7e-05 | grad norm: 1.69 | max abs grad:   0.039 | loss: 7.74 | perp.: 2287.52
#  b 300/712 >> 2571.2 ms/b | lr:  2.6e-05 | grad norm: 0.70 | max abs grad:   0.015 | loss: 6.29 | perp.: 537.41
#  b 450/712 >> 2560.1 ms/b | lr:  3.1e-05 | grad norm: 0.53 | max abs grad:   0.008 | loss: 6.18 | perp.: 483.17
#  b 600/712 >> 2594.4 ms/b | lr:  2.9e-05 | grad norm: 0.53 | max abs grad:   0.007 | loss: 6.17 | perp.: 476.71
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1831.18 sec | train_loss:  6.52 | train_perp: 675.65 | valid_loss:  6.13 | valid_perp.: 459.21
# ================================================================================================================
#
#
# Epoch   2/ 50) lr = 5.59e-05 (warmup)
#  b 150/721 >> 2873.1 ms/b | lr:  5.3e-05 | grad norm: 0.61 | max abs grad:   0.010 | loss: 6.21 | perp.: 497.42
#  b 300/721 >> 2905.6 ms/b | lr:    6e-05 | grad norm: 0.52 | max abs grad:   0.015 | loss: 6.18 | perp.: 481.26
#  b 450/721 >> 2851.5 ms/b | lr:  5.9e-05 | grad norm: 0.53 | max abs grad:   0.008 | loss: 6.16 | perp.: 474.51
#  b 600/721 >> 2759.5 ms/b | lr:  4.9e-05 | grad norm: 0.58 | max abs grad:   0.007 | loss: 6.16 | perp.: 475.76
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2035.51 sec | train_loss:  6.17 | train_perp: 477.20 | valid_loss:  6.13 | valid_perp.: 459.59
# ================================================================================================================
#
#
# Epoch   3/ 50) lr = 8.385e-05 (warmup)
#  b 150/716 >> 2553.2 ms/b | lr:  7.7e-05 | grad norm: 0.64 | max abs grad:   0.018 | loss: 6.19 | perp.: 490.13
#  b 300/716 >> 2437.3 ms/b | lr:  8.6e-05 | grad norm: 0.49 | max abs grad:   0.011 | loss: 6.11 | perp.: 448.18
#  b 450/716 >> 2427.5 ms/b | lr:  7.4e-05 | grad norm: 0.51 | max abs grad:   0.010 | loss: 6.08 | perp.: 436.89
#  b 600/716 >> 2476.6 ms/b | lr:  9.3e-05 | grad norm: 0.47 | max abs grad:   0.009 | loss: 6.05 | perp.: 422.60
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1763.75 sec | train_loss:  6.08 | train_perp: 438.38 | valid_loss:  5.98 | valid_perp.: 395.66
# ================================================================================================================
#
#
# Epoch   4/ 50) lr = 0.0001118 (warmup)
#  b 150/713 >> 2657.1 ms/b | lr:  0.00012 | grad norm: 0.48 | max abs grad:   0.010 | loss: 6.05 | perp.: 422.58
#  b 300/713 >> 2797.6 ms/b | lr:  9.1e-05 | grad norm: 0.53 | max abs grad:   0.012 | loss: 5.97 | perp.: 390.82
#  b 450/713 >> 3063.8 ms/b | lr:   0.0001 | grad norm: 0.50 | max abs grad:   0.009 | loss: 5.95 | perp.: 383.75
#  b 600/713 >> 2867.4 ms/b | lr:  0.00011 | grad norm: 0.48 | max abs grad:   0.012 | loss: 5.93 | perp.: 377.65
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2042.47 sec | train_loss:  5.96 | train_perp: 386.56 | valid_loss:  5.88 | valid_perp.: 356.15
# ================================================================================================================
#
#
# Epoch   5/ 50) lr = 0.0001398 (warmup)
#  b 150/717 >> 2813.2 ms/b | lr:  0.00014 | grad norm: 0.61 | max abs grad:   0.015 | loss: 5.93 | perp.: 377.26
#  b 300/717 >> 2818.0 ms/b | lr:  0.00014 | grad norm: 0.63 | max abs grad:   0.013 | loss: 5.86 | perp.: 351.30
#  b 450/717 >> 2952.6 ms/b | lr:  0.00013 | grad norm: 0.50 | max abs grad:   0.013 | loss: 5.85 | perp.: 345.87
#  b 600/717 >> 2894.7 ms/b | lr:  0.00011 | grad norm: 0.60 | max abs grad:   0.013 | loss: 5.82 | perp.: 335.97
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 2067.16 sec | train_loss:  5.85 | train_perp: 346.49 | valid_loss:  5.76 | valid_perp.: 317.53
# ================================================================================================================
#
#
# Epoch   6/ 50) lr = 0.0001677 (warmup)
#  b 150/713 >> 2901.4 ms/b | lr:  0.00015 | grad norm: 0.55 | max abs grad:   0.012 | loss: 5.80 | perp.: 331.85
#  b 300/713 >> 2712.7 ms/b | lr:  0.00018 | grad norm: 0.51 | max abs grad:   0.008 | loss: 5.75 | perp.: 315.22
#  b 450/713 >> 2434.4 ms/b | lr:  0.00018 | grad norm: 0.59 | max abs grad:   0.014 | loss: 5.72 | perp.: 306.18
#  b 600/713 >> 2473.0 ms/b | lr:  0.00016 | grad norm: 0.71 | max abs grad:   0.013 | loss: 5.72 | perp.: 306.32
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1856.50 sec | train_loss:  5.74 | train_perp: 310.20 | valid_loss:  5.65 | valid_perp.: 283.52
# ================================================================================================================
#
#
# Epoch   7/ 50) lr = 0.0001957 (warmup)
#  b 150/722 >> 2375.6 ms/b | lr:   0.0002 | grad norm: 0.70 | max abs grad:   0.011 | loss: 5.67 | perp.: 289.01
#  b 300/722 >> 2416.9 ms/b | lr:   0.0002 | grad norm: 0.76 | max abs grad:   0.014 | loss: 5.63 | perp.: 278.10
#  b 450/722 >> 2371.2 ms/b | lr:  0.00015 | grad norm: 0.78 | max abs grad:   0.021 | loss: 5.61 | perp.: 272.88
#  b 600/722 >> 2416.8 ms/b | lr:   0.0002 | grad norm: 0.68 | max abs grad:   0.013 | loss: 5.58 | perp.: 264.25
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1730.49 sec | train_loss:  5.60 | train_perp: 271.35 | valid_loss:  5.51 | valid_perp.: 246.51
# ================================================================================================================
#
#
# Epoch   8/ 50) lr = 0.0002236 (warmup)
#  b 150/712 >> 2436.9 ms/b | lr:   0.0002 | grad norm: 0.72 | max abs grad:   0.013 | loss: 5.53 | perp.: 251.06
#  b 300/712 >> 2429.6 ms/b | lr:  0.00023 | grad norm: 0.91 | max abs grad:   0.022 | loss: 5.46 | perp.: 235.84
#  b 450/712 >> 2424.0 ms/b | lr:  0.00023 | grad norm: 0.67 | max abs grad:   0.015 | loss: 5.44 | perp.: 230.83
#  b 600/712 >> 2438.0 ms/b | lr:  0.00023 | grad norm: 1.17 | max abs grad:   0.026 | loss: 5.41 | perp.: 222.70
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1738.92 sec | train_loss:  5.45 | train_perp: 232.59 | valid_loss:  5.35 | valid_perp.: 209.58
# ================================================================================================================
#
#
# Epoch   9/ 50) lr = 0.0002516 (warmup)
#  b 150/719 >> 2384.3 ms/b | lr:  0.00024 | grad norm: 0.83 | max abs grad:   0.021 | loss: 5.37 | perp.: 213.92
#  b 300/719 >> 2426.5 ms/b | lr:  0.00024 | grad norm: 1.13 | max abs grad:   0.035 | loss: 5.30 | perp.: 200.42
#  b 450/719 >> 2437.4 ms/b | lr:  0.00027 | grad norm: 1.66 | max abs grad:   0.042 | loss: 5.29 | perp.: 198.26
#  b 600/719 >> 2435.4 ms/b | lr:  0.00023 | grad norm: 0.93 | max abs grad:   0.022 | loss: 5.25 | perp.: 190.95
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1741.02 sec | train_loss:  5.30 | train_perp: 199.59 | valid_loss:  5.24 | valid_perp.: 189.38
# ================================================================================================================
#
#
# Epoch  10/ 50) lr = 0.0002795 (warmup)
#  b 150/715 >> 2435.0 ms/b | lr:  0.00029 | grad norm: 1.99 | max abs grad:   0.092 | loss: 5.23 | perp.: 186.03
#  b 300/715 >> 2429.4 ms/b | lr:  0.00029 | grad norm: 1.72 | max abs grad:   0.082 | loss: 5.17 | perp.: 175.67
#  b 450/715 >> 2400.3 ms/b | lr:  0.00027 | grad norm: 0.94 | max abs grad:   0.021 | loss: 5.14 | perp.: 170.47
#  b 600/715 >> 2433.7 ms/b | lr:  0.00028 | grad norm: 0.95 | max abs grad:   0.023 | loss: 5.13 | perp.: 168.42
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1733.98 sec | train_loss:  5.16 | train_perp: 174.11 | valid_loss:  5.08 | valid_perp.: 160.69
# ================================================================================================================
#
#
# Epoch  11/ 50) lr = 0.0002665
#  b 150/715 >> 2483.6 ms/b | lr:  0.00027 | grad norm: 1.27 | max abs grad:   0.031 | loss: 5.09 | perp.: 163.19
#  b 300/715 >> 2420.2 ms/b | lr:  0.00029 | grad norm: 1.59 | max abs grad:   0.046 | loss: 5.02 | perp.: 152.06
#  b 450/715 >> 2405.7 ms/b | lr:  0.00026 | grad norm: 1.53 | max abs grad:   0.090 | loss: 4.99 | perp.: 147.29
#  b 600/715 >> 2417.0 ms/b | lr:  0.00024 | grad norm: 1.25 | max abs grad:   0.034 | loss: 4.99 | perp.: 146.50
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1735.87 sec | train_loss:  5.02 | train_perp: 152.12 | valid_loss:  4.93 | valid_perp.: 138.56
# ================================================================================================================
#
#
# Epoch  12/ 50) lr = 0.0002552
#  b 150/720 >> 2464.9 ms/b | lr:  0.00022 | grad norm: 1.47 | max abs grad:   0.046 | loss: 4.95 | perp.: 140.56
#  b 300/720 >> 2450.7 ms/b | lr:  0.00028 | grad norm: 2.72 | max abs grad:   0.185 | loss: 4.89 | perp.: 133.21
#  b 450/720 >> 2374.0 ms/b | lr:  0.00024 | grad norm: 1.32 | max abs grad:   0.059 | loss: 4.87 | perp.: 130.59
#  b 600/720 >> 2391.3 ms/b | lr:  0.00026 | grad norm: 1.29 | max abs grad:   0.046 | loss: 4.84 | perp.: 126.34
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1739.08 sec | train_loss:  4.89 | train_perp: 132.61 | valid_loss:  4.84 | valid_perp.: 126.48
# ================================================================================================================
#
#
# Epoch  13/ 50) lr = 0.0002451
#  b 150/717 >> 2422.9 ms/b | lr:  0.00025 | grad norm: 1.62 | max abs grad:   0.063 | loss: 4.82 | perp.: 123.66
#  b 300/717 >> 2373.9 ms/b | lr:  0.00022 | grad norm: 2.03 | max abs grad:   0.099 | loss: 4.76 | perp.: 116.39
#  b 450/717 >> 2488.1 ms/b | lr:  0.00022 | grad norm: 1.89 | max abs grad:   0.077 | loss: 4.78 | perp.: 118.73
#  b 600/717 >> 2462.3 ms/b | lr:  0.00023 | grad norm: 1.64 | max abs grad:   0.061 | loss: 4.75 | perp.: 115.53
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1744.22 sec | train_loss:  4.77 | train_perp: 118.44 | valid_loss:  4.79 | valid_perp.: 120.35
# ================================================================================================================
#
#
# Epoch  14/ 50) lr = 0.0002362
#  b 150/713 >> 2445.2 ms/b | lr:  0.00022 | grad norm: 2.04 | max abs grad:   0.093 | loss: 4.72 | perp.: 111.72
#  b 300/713 >> 2499.2 ms/b | lr:  0.00026 | grad norm: 1.54 | max abs grad:   0.081 | loss: 4.68 | perp.: 107.54
#  b 450/713 >> 2414.8 ms/b | lr:  0.00019 | grad norm: 1.90 | max abs grad:   0.078 | loss: 4.66 | perp.: 106.10
#  b 600/713 >> 2447.7 ms/b | lr:  0.00019 | grad norm: 2.28 | max abs grad:   0.097 | loss: 4.67 | perp.: 106.80
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1743.55 sec | train_loss:  4.68 | train_perp: 108.05 | valid_loss:  4.57 | valid_perp.:  96.37
# ================================================================================================================
#
#
# Epoch  15/ 50) lr = 0.0002282
#  b 150/718 >> 2426.6 ms/b | lr:  0.00025 | grad norm: 5.16 | max abs grad:   0.340 | loss: 4.64 | perp.: 103.48
#  b 300/718 >> 2450.3 ms/b | lr:  0.00023 | grad norm: 2.46 | max abs grad:   0.176 | loss: 4.59 | perp.:  98.87
#  b 450/718 >> 2429.4 ms/b | lr:  0.00022 | grad norm: 2.45 | max abs grad:   0.128 | loss: 4.57 | perp.:  96.15
#  b 600/718 >> 2427.8 ms/b | lr:  0.00022 | grad norm: 5.41 | max abs grad:   0.352 | loss: 4.55 | perp.:  94.67
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1744.16 sec | train_loss:  4.59 | train_perp:  98.39 | valid_loss:  4.52 | valid_perp.:  91.54
# ================================================================================================================
#
#
# Epoch  16/ 50) lr = 0.000221
#  b 150/722 >> 2351.1 ms/b | lr:  0.00023 | grad norm: 1.99 | max abs grad:   0.087 | loss: 4.49 | perp.:  88.69
#  b 300/722 >> 2457.1 ms/b | lr:  0.00018 | grad norm: 2.56 | max abs grad:   0.152 | loss: 4.48 | perp.:  87.92
#  b 450/722 >> 2414.0 ms/b | lr:  0.00024 | grad norm: 1.98 | max abs grad:   0.103 | loss: 4.47 | perp.:  86.96
#  b 600/722 >> 2449.5 ms/b | lr:  0.00026 | grad norm: 7.72 | max abs grad:   0.494 | loss: 4.44 | perp.:  84.40
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1747.26 sec | train_loss:  4.48 | train_perp:  87.97 | valid_loss:  4.41 | valid_perp.:  82.46
# ================================================================================================================
#
#
# Epoch  17/ 50) lr = 0.0002144
#  b 150/716 >> 2450.4 ms/b | lr:  0.00018 | grad norm: 2.89 | max abs grad:   0.160 | loss: 4.45 | perp.:  85.35
#  b 300/716 >> 2423.7 ms/b | lr:   0.0002 | grad norm: 2.01 | max abs grad:   0.091 | loss: 4.39 | perp.:  80.62
#  b 450/716 >> 2413.8 ms/b | lr:  0.00021 | grad norm: 2.06 | max abs grad:   0.103 | loss: 4.39 | perp.:  80.34
#  b 600/716 >> 2453.9 ms/b | lr:  0.00021 | grad norm: 2.28 | max abs grad:   0.124 | loss: 4.36 | perp.:  78.65
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1747.98 sec | train_loss:  4.41 | train_perp:  81.88 | valid_loss:  4.38 | valid_perp.:  80.21
# ================================================================================================================
#
#
# Epoch  18/ 50) lr = 0.0002083
#  b 150/716 >> 2430.3 ms/b | lr:  0.00022 | grad norm: 3.66 | max abs grad:   0.209 | loss: 4.33 | perp.:  76.08
#  b 300/716 >> 2449.6 ms/b | lr:   0.0002 | grad norm: 2.52 | max abs grad:   0.178 | loss: 4.32 | perp.:  75.44
#  b 450/716 >> 2401.9 ms/b | lr:  0.00021 | grad norm: 2.43 | max abs grad:   0.158 | loss: 4.25 | perp.:  70.42
#  b 600/716 >> 2491.7 ms/b | lr:  0.00022 | grad norm: 2.30 | max abs grad:   0.170 | loss: 4.29 | perp.:  72.65
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1750.47 sec | train_loss:  4.31 | train_perp:  74.57 | valid_loss:  4.27 | valid_perp.:  71.30
# ================================================================================================================
#
#
# Epoch  19/ 50) lr = 0.0002028
#  b 150/718 >> 2499.0 ms/b | lr:   0.0002 | grad norm: 2.05 | max abs grad:   0.108 | loss: 4.41 | perp.:  82.12
#  b 300/718 >> 2415.1 ms/b | lr:  0.00018 | grad norm: 2.82 | max abs grad:   0.135 | loss: 4.19 | perp.:  66.10
#  b 450/718 >> 2435.4 ms/b | lr:   0.0002 | grad norm: 1.93 | max abs grad:   0.104 | loss: 4.23 | perp.:  68.43
#  b 600/718 >> 2439.4 ms/b | lr:   0.0002 | grad norm: 3.70 | max abs grad:   0.295 | loss: 4.17 | perp.:  64.60
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1749.54 sec | train_loss:  4.25 | train_perp:  70.32 | valid_loss:  5.01 | valid_perp.: 150.32
# ================================================================================================================
#
#
# Epoch  20/ 50) lr = 0.0001976
#  b 150/726 >> 2430.7 ms/b | lr:   0.0002 | grad norm: 2.53 | max abs grad:   0.142 | loss: 4.20 | perp.:  66.75
#  b 300/726 >> 2603.6 ms/b | lr:  0.00019 | grad norm: 3.90 | max abs grad:   0.286 | loss: 4.12 | perp.:  61.59
#  b 450/726 >> 2746.8 ms/b | lr:  0.00018 | grad norm: 2.49 | max abs grad:   0.141 | loss: 4.12 | perp.:  61.37
#  b 600/726 >> 2557.0 ms/b | lr:  0.00016 | grad norm: 2.83 | max abs grad:   0.173 | loss: 4.11 | perp.:  61.04
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1855.44 sec | train_loss:  4.14 | train_perp:  63.10 | valid_loss:  4.16 | valid_perp.:  63.86
# ================================================================================================================
#
#
# Epoch  21/ 50) lr = 0.0001929
#  b 150/722 >> 2530.0 ms/b | lr:  0.00018 | grad norm: 1.99 | max abs grad:   0.103 | loss: 4.22 | perp.:  68.01
#  b 300/722 >> 2340.3 ms/b | lr:  0.00021 | grad norm: 4.11 | max abs grad:   0.318 | loss: 4.00 | perp.:  54.39
#  b 450/722 >> 2534.8 ms/b | lr:  0.00021 | grad norm: 6.02 | max abs grad:   0.623 | loss: 4.05 | perp.:  57.38
#  b 600/722 >> 2584.5 ms/b | lr:  0.00019 | grad norm: 4.38 | max abs grad:   0.420 | loss: 4.06 | perp.:  58.15
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1795.78 sec | train_loss:  4.09 | train_perp:  59.73 | valid_loss:  4.00 | valid_perp.:  54.69
# ================================================================================================================
#
#
# Epoch  22/ 50) lr = 0.0001884
#  b 150/711 >> 2525.5 ms/b | lr:   0.0002 | grad norm: 3.62 | max abs grad:   0.316 | loss: 4.02 | perp.:  55.94
#  b 300/711 >> 2478.7 ms/b | lr:  0.00017 | grad norm: 2.30 | max abs grad:   0.133 | loss: 3.96 | perp.:  52.69
#  b 450/711 >> 2432.6 ms/b | lr:  0.00019 | grad norm: 3.19 | max abs grad:   0.280 | loss: 3.96 | perp.:  52.68
#  b 600/711 >> 2435.3 ms/b | lr:  0.00019 | grad norm: 3.26 | max abs grad:   0.247 | loss: 4.03 | perp.:  56.44
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1750.01 sec | train_loss:  4.00 | train_perp:  54.63 | valid_loss:  3.96 | valid_perp.:  52.34
# ================================================================================================================
#
#
# Epoch  23/ 50) lr = 0.0001843
#  b 150/726 >> 2398.1 ms/b | lr:  0.00018 | grad norm: 2.06 | max abs grad:   0.111 | loss: 3.96 | perp.:  52.64
#  b 300/726 >> 2365.3 ms/b | lr:  0.00018 | grad norm: 2.32 | max abs grad:   0.179 | loss: 3.89 | perp.:  48.99
#  b 450/726 >> 2414.3 ms/b | lr:  0.00016 | grad norm: 3.51 | max abs grad:   0.294 | loss: 3.92 | perp.:  50.44
#  b 600/726 >> 2375.7 ms/b | lr:  0.00017 | grad norm: 4.53 | max abs grad:   0.476 | loss: 3.87 | perp.:  47.90
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1738.23 sec | train_loss:  3.92 | train_perp:  50.61 | valid_loss:  4.34 | valid_perp.:  76.78
# ================================================================================================================
#
#
# Epoch  24/ 50) lr = 0.0001804
#  b 150/719 >> 2422.6 ms/b | lr:  0.00019 | grad norm: 2.61 | max abs grad:   0.133 | loss: 3.96 | perp.:  52.37
#  b 300/719 >> 2428.1 ms/b | lr:  0.00016 | grad norm: 2.43 | max abs grad:   0.116 | loss: 3.83 | perp.:  46.15
#  b 450/719 >> 2490.0 ms/b | lr:  0.00019 | grad norm: 2.39 | max abs grad:   0.135 | loss: 3.87 | perp.:  48.09
#  b 600/719 >> 2366.2 ms/b | lr:  0.00018 | grad norm: 2.12 | max abs grad:   0.082 | loss: 3.79 | perp.:  44.27
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1743.29 sec | train_loss:  3.87 | train_perp:  48.18 | valid_loss:  3.79 | valid_perp.:  44.41
# ================================================================================================================
#
#
# Epoch  25/ 50) lr = 0.0001768
#  b 150/722 >> 2446.7 ms/b | lr:  0.00018 | grad norm: 2.35 | max abs grad:   0.119 | loss: 3.84 | perp.:  46.35
#  b 300/722 >> 2426.4 ms/b | lr:  0.00016 | grad norm: 6.55 | max abs grad:   0.671 | loss: 3.71 | perp.:  40.87
#  b 450/722 >> 2479.1 ms/b | lr:  0.00018 | grad norm: 4.06 | max abs grad:   0.467 | loss: 3.72 | perp.:  41.15
#  b 600/722 >> 2484.9 ms/b | lr:  0.00018 | grad norm: 2.29 | max abs grad:   0.193 | loss: 3.70 | perp.:  40.58
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1771.52 sec | train_loss:  3.74 | train_perp:  42.15 | valid_loss:  3.70 | valid_perp.:  40.60
# ================================================================================================================
#
#
# Epoch  26/ 50) lr = 0.0001733
#  b 150/718 >> 2459.5 ms/b | lr:  0.00017 | grad norm: 2.31 | max abs grad:   0.108 | loss: 3.63 | perp.:  37.78
#  b 300/718 >> 2486.0 ms/b | lr:  0.00017 | grad norm: 2.89 | max abs grad:   0.253 | loss: 3.65 | perp.:  38.59
#  b 450/718 >> 2456.2 ms/b | lr:  0.00018 | grad norm: 2.48 | max abs grad:   0.161 | loss: 3.64 | perp.:  38.25
#  b 600/718 >> 2422.4 ms/b | lr:  0.00019 | grad norm: 4.05 | max abs grad:   0.331 | loss: 3.64 | perp.:  37.96
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1770.98 sec | train_loss:  3.66 | train_perp:  38.76 | valid_loss:  3.55 | valid_perp.:  34.81
# ================================================================================================================
#
#
# Epoch  27/ 50) lr = 0.0001701
#  b 150/715 >> 2520.1 ms/b | lr:  0.00017 | grad norm: 4.25 | max abs grad:   0.348 | loss: 3.61 | perp.:  36.91
#  b 300/715 >> 2489.2 ms/b | lr:  0.00016 | grad norm: 2.77 | max abs grad:   0.164 | loss: 3.59 | perp.:  36.18
#  b 450/715 >> 2476.8 ms/b | lr:  0.00018 | grad norm: 4.49 | max abs grad:   0.377 | loss: 3.58 | perp.:  35.84
#  b 600/715 >> 2405.4 ms/b | lr:  0.00014 | grad norm: 2.37 | max abs grad:   0.152 | loss: 3.53 | perp.:  34.12
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1771.21 sec | train_loss:  3.60 | train_perp:  36.72 | valid_loss:  3.82 | valid_perp.:  45.39
# ================================================================================================================
#
#
# Epoch  28/ 50) lr = 0.000167
#  b 150/719 >> 2421.3 ms/b | lr:  0.00014 | grad norm: 2.77 | max abs grad:   0.105 | loss: 3.50 | perp.:  33.25
#  b 300/719 >> 2463.4 ms/b | lr:  0.00016 | grad norm: 3.59 | max abs grad:   0.339 | loss: 3.47 | perp.:  32.11
#  b 450/719 >> 2416.6 ms/b | lr:  0.00014 | grad norm: 2.57 | max abs grad:   0.149 | loss: 3.48 | perp.:  32.39
#  b 600/719 >> 2387.2 ms/b | lr:  0.00015 | grad norm: 3.51 | max abs grad:   0.280 | loss: 3.44 | perp.:  31.05
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1745.01 sec | train_loss:  3.49 | train_perp:  32.73 | valid_loss:  3.37 | valid_perp.:  29.17
# ================================================================================================================
#
#
# Epoch  29/ 50) lr = 0.0001641
#  b 150/719 >> 2381.2 ms/b | lr:  0.00016 | grad norm: 8.69 | max abs grad:   0.897 | loss: 3.49 | perp.:  32.94
#  b 300/719 >> 2415.8 ms/b | lr:  0.00015 | grad norm: 3.45 | max abs grad:   0.256 | loss: 3.39 | perp.:  29.71
#  b 450/719 >> 2457.6 ms/b | lr:  0.00018 | grad norm: 3.74 | max abs grad:   0.303 | loss: 3.38 | perp.:  29.47
#  b 600/719 >> 2392.2 ms/b | lr:  0.00017 | grad norm: 6.21 | max abs grad:   0.401 | loss: 3.33 | perp.:  28.07
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1741.63 sec | train_loss:  3.44 | train_perp:  31.22 | valid_loss:  3.27 | valid_perp.:  26.32
# ================================================================================================================
#
#
# Epoch  30/ 50) lr = 0.0001614
#  b 150/714 >> 2426.1 ms/b | lr:  0.00017 | grad norm: 3.03 | max abs grad:   0.199 | loss: 3.43 | perp.:  30.91
#  b 300/714 >> 2412.7 ms/b | lr:  0.00011 | grad norm: 3.32 | max abs grad:   0.218 | loss: 3.31 | perp.:  27.32
#  b 450/714 >> 2462.4 ms/b | lr:  0.00017 | grad norm: 3.59 | max abs grad:   0.426 | loss: 3.33 | perp.:  27.92
#  b 600/714 >> 2476.5 ms/b | lr:  0.00016 | grad norm: 3.21 | max abs grad:   0.142 | loss: 3.33 | perp.:  27.93
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1755.08 sec | train_loss:  3.37 | train_perp:  29.06 | valid_loss:  3.16 | valid_perp.:  23.52
# ================================================================================================================
#
#
# Epoch  31/ 50) lr = 0.0001588
#  b 150/715 >> 2486.9 ms/b | lr:  0.00014 | grad norm: 23.65 | max abs grad:   1.404 | loss: 3.24 | perp.:  25.62
#  b 300/715 >> 2540.1 ms/b | lr:  0.00017 | grad norm: 6.87 | max abs grad:   0.689 | loss: 3.27 | perp.:  26.30
#  b 450/715 >> 2495.4 ms/b | lr:  0.00014 | grad norm: 3.51 | max abs grad:   0.313 | loss: 3.25 | perp.:  25.77
#  b 600/715 >> 2380.8 ms/b | lr:  0.00014 | grad norm: 3.42 | max abs grad:   0.193 | loss: 3.26 | perp.:  25.99
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1773.22 sec | train_loss:  3.28 | train_perp:  26.50 | valid_loss:  3.11 | valid_perp.:  22.36
# ================================================================================================================
#
#
# Epoch  32/ 50) lr = 0.0001563
#  b 150/711 >> 2501.5 ms/b | lr:  0.00016 | grad norm: 7.77 | max abs grad:   0.580 | loss: 3.32 | perp.:  27.69
#  b 300/711 >> 2464.6 ms/b | lr:  0.00014 | grad norm: 5.50 | max abs grad:   0.417 | loss: 3.22 | perp.:  25.13
#  b 450/711 >> 2446.4 ms/b | lr:  0.00016 | grad norm: 5.80 | max abs grad:   0.270 | loss: 3.23 | perp.:  25.28
#  b 600/711 >> 2409.9 ms/b | lr:  0.00014 | grad norm: 2.84 | max abs grad:   0.123 | loss: 3.21 | perp.:  24.68
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1755.10 sec | train_loss:  3.27 | train_perp:  26.43 | valid_loss:  3.09 | valid_perp.:  21.98
# ================================================================================================================
#
#
# Epoch  33/ 50) lr = 0.0001539
#  b 150/717 >> 2432.4 ms/b | lr:  0.00016 | grad norm: 4.00 | max abs grad:   0.382 | loss: 3.21 | perp.:  24.78
#  b 300/717 >> 2474.8 ms/b | lr:  0.00015 | grad norm: 3.05 | max abs grad:   0.151 | loss: 3.16 | perp.:  23.67
#  b 450/717 >> 2458.3 ms/b | lr:  0.00014 | grad norm: 3.86 | max abs grad:   0.262 | loss: 3.15 | perp.:  23.26
#  b 600/717 >> 2435.5 ms/b | lr:  0.00015 | grad norm: 2.98 | max abs grad:   0.253 | loss: 3.13 | perp.:  22.95
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1756.99 sec | train_loss:  3.18 | train_perp:  24.06 | valid_loss:  3.03 | valid_perp.:  20.64
# ================================================================================================================
#
#
# Epoch  34/ 50) lr = 0.0001516
#  b 150/712 >> 2427.9 ms/b | lr:  0.00012 | grad norm: 3.33 | max abs grad:   0.144 | loss: 3.25 | perp.:  25.82
#  b 300/712 >> 2441.4 ms/b | lr:  0.00015 | grad norm: 4.20 | max abs grad:   0.357 | loss: 3.10 | perp.:  22.13
#  b 450/712 >> 2503.7 ms/b | lr:  0.00016 | grad norm: 34.56 | max abs grad:   2.232 | loss: 3.13 | perp.:  22.98
#  b 600/712 >> 2453.9 ms/b | lr:  0.00017 | grad norm: 11.49 | max abs grad:   0.846 | loss: 3.15 | perp.:  23.28
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1754.84 sec | train_loss:  3.18 | train_perp:  24.10 | valid_loss:  3.07 | valid_perp.:  21.62
# ================================================================================================================
#
#
# Epoch  35/ 50) lr = 0.0001494
#  b 150/723 >> 2776.5 ms/b | lr:  0.00015 | grad norm: 2.89 | max abs grad:   0.098 | loss: 3.16 | perp.:  23.47
#  b 300/723 >> 2565.9 ms/b | lr:  0.00016 | grad norm: 5.55 | max abs grad:   0.223 | loss: 3.07 | perp.:  21.48
#  b 450/723 >> 2718.9 ms/b | lr:  0.00015 | grad norm: 2.56 | max abs grad:   0.177 | loss: 3.05 | perp.:  21.15
#  b 600/723 >> 2648.3 ms/b | lr:  0.00015 | grad norm: 4.89 | max abs grad:   0.249 | loss: 3.06 | perp.:  21.33
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1937.03 sec | train_loss:  3.10 | train_perp:  22.19 | valid_loss:  2.95 | valid_perp.:  19.14
# ================================================================================================================
#
#
# Epoch  36/ 50) lr = 0.0001473
#  b 150/712 >> 2757.2 ms/b | lr:  0.00016 | grad norm: 9.70 | max abs grad:   0.736 | loss: 3.11 | perp.:  22.51
#  b 300/712 >> 2527.5 ms/b | lr:  0.00014 | grad norm: 2.39 | max abs grad:   0.086 | loss: 3.02 | perp.:  20.42
#  b 450/712 >> 2596.6 ms/b | lr:  0.00013 | grad norm: 2.70 | max abs grad:   0.202 | loss: 3.08 | perp.:  21.73
#  b 600/712 >> 2674.9 ms/b | lr:  0.00014 | grad norm: 2.98 | max abs grad:   0.115 | loss: 2.98 | perp.:  19.65
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1882.84 sec | train_loss:  3.06 | train_perp:  21.30 | valid_loss:  2.94 | valid_perp.:  18.96
# ================================================================================================================
#
#
# Epoch  37/ 50) lr = 0.0001453
#  b 150/712 >> 2504.1 ms/b | lr:  0.00017 | grad norm: 5.39 | max abs grad:   0.467 | loss: 2.99 | perp.:  19.93
#  b 300/712 >> 2740.5 ms/b | lr:  0.00015 | grad norm: 6.30 | max abs grad:   0.429 | loss: 2.96 | perp.:  19.38
#  b 450/712 >> 2647.4 ms/b | lr:  0.00015 | grad norm: 3.56 | max abs grad:   0.308 | loss: 2.97 | perp.:  19.45
#  b 600/712 >> 2435.6 ms/b | lr:  0.00015 | grad norm: 5.80 | max abs grad:   0.475 | loss: 2.97 | perp.:  19.40
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1828.41 sec | train_loss:  2.99 | train_perp:  19.92 | valid_loss:  2.85 | valid_perp.:  17.21
# ================================================================================================================
#
#
# Epoch  38/ 50) lr = 0.0001434
#  b 150/721 >> 2440.3 ms/b | lr:  0.00014 | grad norm: 31.85 | max abs grad:   2.026 | loss: 3.01 | perp.:  20.19
#  b 300/721 >> 2407.1 ms/b | lr:  0.00015 | grad norm: 18.14 | max abs grad:   1.020 | loss: 2.91 | perp.:  18.40
#  b 450/721 >> 2510.2 ms/b | lr:  0.00015 | grad norm: 4.72 | max abs grad:   0.251 | loss: 2.97 | perp.:  19.40
#  b 600/721 >> 2719.2 ms/b | lr:  0.00013 | grad norm: 4.20 | max abs grad:   0.255 | loss: 2.87 | perp.:  17.72
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1829.12 sec | train_loss:  2.95 | train_perp:  19.08 | valid_loss:  2.80 | valid_perp.:  16.51
# ================================================================================================================
#
#
# Epoch  39/ 50) lr = 0.0001415
#  b 150/719 >> 2528.3 ms/b | lr:  0.00015 | grad norm: 5.50 | max abs grad:   0.317 | loss: 3.04 | perp.:  20.89
#  b 300/719 >> 2432.1 ms/b | lr:  0.00013 | grad norm: 3.78 | max abs grad:   0.267 | loss: 2.88 | perp.:  17.85
#  b 450/719 >> 2426.5 ms/b | lr:  0.00016 | grad norm: 9.10 | max abs grad:   0.406 | loss: 2.94 | perp.:  18.82
#  b 600/719 >> 2421.2 ms/b | lr:  0.00016 | grad norm: 9.26 | max abs grad:   0.461 | loss: 2.91 | perp.:  18.32
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1758.18 sec | train_loss:  2.96 | train_perp:  19.23 | valid_loss:  2.75 | valid_perp.:  15.69
# ================================================================================================================
#
#
# Epoch  40/ 50) lr = 0.0001398
#  b 150/724 >> 2344.7 ms/b | lr:  0.00013 | grad norm: 4.42 | max abs grad:   0.257 | loss: 2.85 | perp.:  17.23
#  b 300/724 >> 2381.9 ms/b | lr:  0.00012 | grad norm: 2.73 | max abs grad:   0.083 | loss: 2.88 | perp.:  17.77
#  b 450/724 >> 2487.4 ms/b | lr:  0.00016 | grad norm: 13.98 | max abs grad:   1.046 | loss: 2.85 | perp.:  17.21
#  b 600/724 >> 2457.7 ms/b | lr:  0.00014 | grad norm: 10.15 | max abs grad:   0.649 | loss: 2.86 | perp.:  17.53
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1758.99 sec | train_loss:  2.88 | train_perp:  17.81 | valid_loss:  2.84 | valid_perp.:  17.06
# ================================================================================================================
#
#
# Epoch  41/ 50) lr = 0.000138
#  b 150/715 >> 2463.7 ms/b | lr:  0.00013 | grad norm: 9.22 | max abs grad:   0.626 | loss: 2.85 | perp.:  17.29
#  b 300/715 >> 2405.4 ms/b | lr:  0.00015 | grad norm: 4.23 | max abs grad:   0.344 | loss: 2.86 | perp.:  17.40
#  b 450/715 >> 2404.7 ms/b | lr:  0.00015 | grad norm: 5.40 | max abs grad:   0.288 | loss: 2.78 | perp.:  16.16
#  b 600/715 >> 2442.2 ms/b | lr:  0.00015 | grad norm: 43.29 | max abs grad:   2.985 | loss: 2.82 | perp.:  16.74
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1735.97 sec | train_loss:  2.84 | train_perp:  17.17 | valid_loss:  2.67 | valid_perp.:  14.37
# ================================================================================================================
#
#
# Epoch  42/ 50) lr = 0.0001364
#  b 150/713 >> 2430.2 ms/b | lr:  0.00013 | grad norm: 2.77 | max abs grad:   0.122 | loss: 2.79 | perp.:  16.23
#  b 300/713 >> 2442.9 ms/b | lr:  0.00014 | grad norm: 4.31 | max abs grad:   0.142 | loss: 2.83 | perp.:  16.97
#  b 450/713 >> 2437.7 ms/b | lr:  0.00014 | grad norm: 4.02 | max abs grad:   0.219 | loss: 2.74 | perp.:  15.54
#  b 600/713 >> 2435.6 ms/b | lr:  0.00014 | grad norm: 5.03 | max abs grad:   0.254 | loss: 2.76 | perp.:  15.81
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1741.54 sec | train_loss:  2.81 | train_perp:  16.62 | valid_loss:  2.61 | valid_perp.:  13.57
# ================================================================================================================
#
#
# Epoch  43/ 50) lr = 0.0001348
#  b 150/723 >> 2364.5 ms/b | lr:  0.00013 | grad norm: 31.00 | max abs grad:   1.685 | loss: 2.76 | perp.:  15.88
#  b 300/723 >> 2390.3 ms/b | lr:  0.00013 | grad norm: 4.88 | max abs grad:   0.301 | loss: 2.78 | perp.:  16.11
#  b 450/723 >> 2432.0 ms/b | lr:  0.00014 | grad norm: 3.93 | max abs grad:   0.170 | loss: 2.78 | perp.:  16.19
#  b 600/723 >> 2472.2 ms/b | lr:  0.00015 | grad norm: 6.38 | max abs grad:   0.454 | loss: 2.77 | perp.:  15.98
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1742.88 sec | train_loss:  2.79 | train_perp:  16.35 | valid_loss:  2.59 | valid_perp.:  13.32
# ================================================================================================================
#
#
# Epoch  44/ 50) lr = 0.0001333
#  b 150/719 >> 2450.7 ms/b | lr:  0.00013 | grad norm: 13.60 | max abs grad:   0.975 | loss: 2.87 | perp.:  17.71
#  b 300/719 >> 2423.7 ms/b | lr:  0.00013 | grad norm: 3.20 | max abs grad:   0.172 | loss: 2.75 | perp.:  15.67
#  b 450/719 >> 2430.2 ms/b | lr:  0.00013 | grad norm: 15.33 | max abs grad:   1.369 | loss: 2.69 | perp.:  14.79
#  b 600/719 >> 2390.9 ms/b | lr:  0.00014 | grad norm: 8.32 | max abs grad:   0.670 | loss: 2.66 | perp.:  14.26
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1741.48 sec | train_loss:  2.76 | train_perp:  15.84 | valid_loss:  2.55 | valid_perp.:  12.77
# ================================================================================================================
#
#
# Epoch  45/ 50) lr = 0.0001318
#  b 150/720 >> 2434.3 ms/b | lr:  0.00013 | grad norm: 5.37 | max abs grad:   0.443 | loss: 2.72 | perp.:  15.12
#  b 300/720 >> 2421.8 ms/b | lr:  0.00013 | grad norm: 12.53 | max abs grad:   1.002 | loss: 2.68 | perp.:  14.58
#  b 450/720 >> 2441.1 ms/b | lr:  0.00013 | grad norm: 6.46 | max abs grad:   0.311 | loss: 2.67 | perp.:  14.41
#  b 600/720 >> 2381.2 ms/b | lr:  0.00014 | grad norm: 8.94 | max abs grad:   0.608 | loss: 2.62 | perp.:  13.70
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1746.79 sec | train_loss:  2.69 | train_perp:  14.73 | valid_loss:  2.47 | valid_perp.:  11.80
# ================================================================================================================
#
#
# Epoch  46/ 50) lr = 0.0001303
#  b 150/723 >> 2438.5 ms/b | lr:  0.00011 | grad norm: 5.30 | max abs grad:   0.342 | loss: 2.65 | perp.:  14.13
#  b 300/723 >> 2368.3 ms/b | lr:  0.00011 | grad norm: 6.61 | max abs grad:   0.813 | loss: 2.62 | perp.:  13.80
#  b 450/723 >> 2414.3 ms/b | lr:  0.00012 | grad norm: 6.44 | max abs grad:   0.326 | loss: 2.65 | perp.:  14.19
#  b 600/723 >> 2405.0 ms/b | lr:  0.00013 | grad norm: 21.91 | max abs grad:   1.646 | loss: 2.62 | perp.:  13.70
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1738.82 sec | train_loss:  2.66 | train_perp:  14.24 | valid_loss:  2.37 | valid_perp.:  10.66
# ================================================================================================================
#
#
# Epoch  47/ 50) lr = 0.0001289
#  b 150/720 >> 2245.5 ms/b | lr:  0.00013 | grad norm: 6.17 | max abs grad:   0.315 | loss: 2.64 | perp.:  13.95
#  b 300/720 >> 2288.1 ms/b | lr:  0.00012 | grad norm: 4.78 | max abs grad:   0.211 | loss: 2.60 | perp.:  13.48
#  b 450/720 >> 2183.4 ms/b | lr:  0.00012 | grad norm: 11.06 | max abs grad:   0.904 | loss: 2.56 | perp.:  12.99
#  b 600/720 >> 2218.3 ms/b | lr:  0.00011 | grad norm: 10.92 | max abs grad:   0.812 | loss: 2.51 | perp.:  12.34
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1609.07 sec | train_loss:  2.60 | train_perp:  13.40 | valid_loss:  2.38 | valid_perp.:  10.82
# ================================================================================================================
#
#
# Epoch  48/ 50) lr = 0.0001276
#  b 150/718 >> 2198.0 ms/b | lr:  0.00012 | grad norm: 17.62 | max abs grad:   1.050 | loss: 2.55 | perp.:  12.87
#  b 300/718 >> 2244.0 ms/b | lr:  0.00011 | grad norm: 3.44 | max abs grad:   0.163 | loss: 2.57 | perp.:  13.08
#  b 450/718 >> 2162.4 ms/b | lr:   0.0001 | grad norm: 4.73 | max abs grad:   0.409 | loss: 2.50 | perp.:  12.22
#  b 600/718 >> 2300.4 ms/b | lr:  0.00013 | grad norm: 5.95 | max abs grad:   0.255 | loss: 2.60 | perp.:  13.52
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1604.50 sec | train_loss:  2.58 | train_perp:  13.20 | valid_loss:  2.26 | valid_perp.:   9.59
# ================================================================================================================
#
#
# Epoch  49/ 50) lr = 0.0001263
#  b 150/720 >> 2196.8 ms/b | lr:  0.00013 | grad norm: 54.19 | max abs grad:   2.449 | loss: 2.51 | perp.:  12.35
#  b 300/720 >> 2195.9 ms/b | lr:  0.00013 | grad norm: 4.62 | max abs grad:   0.275 | loss: 2.51 | perp.:  12.35
#  b 450/720 >> 2299.4 ms/b | lr:  0.00013 | grad norm: 5.29 | max abs grad:   0.411 | loss: 2.60 | perp.:  13.43
#  b 600/720 >> 2222.9 ms/b | lr:  0.00012 | grad norm: 6.40 | max abs grad:   0.581 | loss: 2.44 | perp.:  11.46
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1604.65 sec | train_loss:  2.55 | train_perp:  12.77 | valid_loss:  2.19 | valid_perp.:   8.95
# ================================================================================================================
#
#
# Epoch  50/ 50) lr = 0.000125
#  b 150/718 >> 2299.9 ms/b | lr:  0.00013 | grad norm: 5.08 | max abs grad:   0.274 | loss: 2.53 | perp.:  12.58
#  b 300/718 >> 2259.5 ms/b | lr:  0.00013 | grad norm: 4.40 | max abs grad:   0.275 | loss: 2.46 | perp.:  11.70
#  b 450/718 >> 2166.2 ms/b | lr:  0.00012 | grad norm: 15.92 | max abs grad:   0.824 | loss: 2.45 | perp.:  11.62
#  b 600/718 >> 2223.0 ms/b | lr:  0.00012 | grad norm: 131.05 | max abs grad:   9.986 | loss: 2.44 | perp.:  11.45
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1606.14 sec | train_loss:  2.49 | train_perp:  12.09 | valid_loss:  2.20 | valid_perp.:   8.98
# ================================================================================================================

# %%
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    enc_states, attn_states, dec_states = states
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])

# %%
test_loss = evaluate(test_data, save_wts = True)
print('test_loss: {:5.2f} | test_perplexity: {:5.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss:  2.12 | test_perplexity:  8.33

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 15 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#   229  2373  1655   812    42    42    48  3257    24    24   804   252    42
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#    42   230    32   119    32
# [torch.LongTensor of size 2x18]
#
# 12 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#    64    64    64   109    64    64    27    27    27   169    27    27    24
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#    24    24    32   119   119
# [torch.LongTensor of size 2x18]
#
# 10 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#    39   204    42    42    32   119   119   119  1711  1656    35  3509  2680
#
# Columns 13 to 17
#    26  5463   119    26    26
#   119    26    24    24    26
# [torch.LongTensor of size 2x18]
#
# 8 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#    26    26    26   535   311   312    42    42    42    26    26    27    27
#
# Columns 13 to 17
#    35    27    27  1479   108
#    35    27    27    27   108
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
# List of modules in the model for reference:

# %%
modules = list(model.modules())
list(enumerate(modules))
# Out:
# [(0, RNNModel(
#     (drop): Dropout(p=0.1)
#     (relu): ReLU()
#     (embedding): Embedding(10000, 512)
#     (encoders): ModuleList(
#       (0): LSTM(512, 256, dropout=0.1)
#     )
#     (attn): RecurrentAttention(
#       (drop): Dropout(p=0.1)
#       (softmax): Softmax()
#       (sigmoid): Sigmoid()
#       (rnn_stack): ModuleList(
#         (0): LSTMCell(512, 256)
#       )
#       (loc_align): Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#       (alignment): Linear(in_features=768, out_features=1)
#       (attention): Linear(in_features=768, out_features=256)
#       (attn_act_fn): ReLU()
#     )
#     (decoders): ModuleList(
#       (0): LSTM(256, 512, dropout=0.1)
#     )
#     (projection): Linear(in_features=512, out_features=10000)
#     (log_softmax): LogSoftmax()
#   )),
#  (1, Dropout(p=0.1)),
#  (2, ReLU()),
#  (3, Embedding(10000, 512)),
#  (4, ModuleList(
#     (0): LSTM(512, 256, dropout=0.1)
#   )),
#  (5, LSTM(512, 256, dropout=0.1)),
#  (6, RecurrentAttention(
#     (drop): Dropout(p=0.1)
#     (softmax): Softmax()
#     (sigmoid): Sigmoid()
#     (rnn_stack): ModuleList(
#       (0): LSTMCell(512, 256)
#     )
#     (loc_align): Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#     (alignment): Linear(in_features=768, out_features=1)
#     (attention): Linear(in_features=768, out_features=256)
#     (attn_act_fn): ReLU()
#   )),
#  (7, Dropout(p=0.1)),
#  (8, Softmax()),
#  (9, Sigmoid()),
#  (10, ModuleList(
#     (0): LSTMCell(512, 256)
#   )),
#  (11, LSTMCell(512, 256)),
#  (12, Conv1d (1, 256, kernel_size=(5,), stride=(1,), padding=(2,))),
#  (13, Linear(in_features=768, out_features=1)),
#  (14, Linear(in_features=768, out_features=256)),
#  (15, ReLU()),
#  (16, ModuleList(
#     (0): LSTM(256, 512, dropout=0.1)
#   )),
#  (17, LSTM(256, 512, dropout=0.1)),
#  (18, Linear(in_features=512, out_features=10000)),
#  (19, LogSoftmax())]

# %% [markdown]
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(modules[3].weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = modules[6]

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Output attention sublayer (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 768)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()
