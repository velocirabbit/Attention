# %%
import os
import pickle
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from model import *
from trainer import *

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Hyperparameters

# %%
model_test_name = '1_encoder_no_decoder_with_skips_localign'
ckpt_loc = os.path.join('checkpoints', model_test_name+'.pt')

# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 4
lr = 0.02
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 150
early_stopping = 10
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
encode_size = 256
h_size = 256
align_size = 256
loc_align_size = 256
loc_align_kernel = 5
decode_size = 256
n_enc_layers = 1
attn_rnn_layers = 1
n_dec_layers = 0
smooth_align = True
align_location = True
skip_connections = True

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler
#
# The learning rate scheduler sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    encode_size = encode_size, h_size = h_size, align_size = align_size,
    decode_size = decode_size, n_enc_layers = n_enc_layers,
    attn_rnn_layers = attn_rnn_layers, n_dec_layers = n_dec_layers,
    align_location = align_location, loc_align_size = loc_align_size,
    loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
    skip_connections = skip_connections, dropout = dropout
)
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
eval_criterion = LabelSmoothing(ntokens, smoothing = 0)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, decay_factor, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 9783809

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Train and evaluate

# %%
train_stats, stat, train_loss, data, targets, states, nstates = train_eval_loop(
    model, train_data, val_data, batch_size, eval_batch_size,
    seq_len, ntokens, criterion, eval_criterion, optimizer,
    lr_scheduler, epochs, warmup_steps, early_stopping,
    clip, log_interval, ckpt_loc
)
# Out:
# Epoch   1/150) lr = 2.795e-05 (warmup)
#  b 150/717 >> 2424.9 ms/b | lr: 2.635e-05 | grad norm:  2.77 | inf norm:   0.098 | loss: 7.15 | perp: 1274.22
#  b 300/717 >> 2453.6 ms/b | lr: 2.872e-05 | grad norm:  2.42 | inf norm:    0.12 | loss: 6.16 | perp:  473.26
#  b 450/717 >> 2372.8 ms/b | lr: 2.465e-05 | grad norm:  2.33 | inf norm:   0.079 | loss: 6.06 | perp:  429.26
#  b 600/717 >> 2410.9 ms/b | lr: 2.716e-05 | grad norm:  2.08 | inf norm:    0.09 | loss: 6.00 | perp:  404.66
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1733.73 sec | train loss, perp: 6.274,  530.68 | valid loss, perp: 6.252,  518.80
# Grad norm:  1.813 | Grad inf. norm:   0.06897 | Max abs param:     5.672
# ==============================================================================================================
#
#
# Epoch   2/150) lr = 5.59e-05 (warmup)
#  b 150/714 >> 2421.6 ms/b | lr: 3.953e-05 | grad norm:  4.96 | inf norm:    0.18 | loss: 5.94 | perp:  379.88
#  b 300/714 >> 2491.8 ms/b | lr: 5.103e-05 | grad norm:  2.13 | inf norm:   0.063 | loss: 5.83 | perp:  339.59
#  b 450/714 >> 2528.3 ms/b | lr:  6.18e-05 | grad norm:  1.75 | inf norm:   0.059 | loss: 5.78 | perp:  325.36
#  b 600/714 >> 2419.4 ms/b | lr:  5.59e-05 | grad norm:  2.03 | inf norm:   0.073 | loss: 5.73 | perp:  309.44
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1761.95 sec | train loss, perp: 5.796,  329.05 | valid loss, perp: 5.969,  391.17
# Grad norm:  1.557 | Grad inf. norm:    0.0403 | Max abs param:     5.674
# ==============================================================================================================
#
#
# Epoch   3/150) lr = 8.385e-05 (warmup)
#  b 150/726 >> 2606.4 ms/b | lr: 7.655e-05 | grad norm:  1.83 | inf norm:   0.063 | loss: 5.67 | perp:  289.61
#  b 300/726 >> 2545.3 ms/b | lr: 8.615e-05 | grad norm:  2.14 | inf norm:   0.066 | loss: 5.59 | perp:  266.51
#  b 450/726 >> 2637.0 ms/b | lr: 9.057e-05 | grad norm:  2.08 | inf norm:   0.039 | loss: 5.53 | perp:  251.50
#  b 600/726 >> 2409.9 ms/b | lr: 7.395e-05 | grad norm:  2.37 | inf norm:   0.074 | loss: 5.50 | perp:  244.54
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1830.01 sec | train loss, perp: 5.551,  257.57 | valid loss, perp: 5.733,  308.81
# Grad norm:  1.927 | Grad inf. norm:   0.04736 | Max abs param:     5.676
# ==============================================================================================================
#
#
# Epoch   4/150) lr = 0.0001118 (warmup)
#  b 150/716 >> 2422.8 ms/b | lr: 0.0001054 | grad norm:  2.21 | inf norm:   0.075 | loss: 5.44 | perp:  229.90
#  b 300/716 >> 2343.0 ms/b | lr: 0.0001087 | grad norm:  2.02 | inf norm:   0.058 | loss: 5.36 | perp:  213.66
#  b 450/716 >> 2396.5 ms/b | lr: 0.0001118 | grad norm:  1.91 | inf norm:   0.047 | loss: 5.34 | perp:  207.89
#  b 600/716 >> 2387.9 ms/b | lr: 0.0001054 | grad norm:  2.05 | inf norm:   0.046 | loss: 5.31 | perp:  201.66
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1708.87 sec | train loss, perp: 5.346,  209.71 | valid loss, perp: 5.531,  252.38
# Grad norm:  2.335 | Grad inf. norm:   0.07528 | Max abs param:     5.681
# ==============================================================================================================
#
#
# Epoch   5/150) lr = 0.0001398 (warmup)
#  b 150/712 >> 2466.7 ms/b | lr: 0.0001318 | grad norm:  2.86 | inf norm:    0.13 | loss: 5.24 | perp:  188.75
#  b 300/712 >> 2347.8 ms/b | lr:  0.000151 | grad norm:  2.39 | inf norm:   0.039 | loss: 5.16 | perp:  173.60
#  b 450/712 >> 2403.1 ms/b | lr: 0.0001473 | grad norm:  2.06 | inf norm:   0.029 | loss: 5.12 | perp:  167.24
#  b 600/712 >> 2379.8 ms/b | lr: 0.0001398 | grad norm:  2.19 | inf norm:     0.1 | loss: 5.09 | perp:  162.55
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1702.13 sec | train loss, perp: 5.143,  171.19 | valid loss, perp: 5.337,  207.91
# Grad norm:  2.128 | Grad inf. norm:   0.07279 | Max abs param:     5.684
# ==============================================================================================================
#
#
# Epoch   6/150) lr = 0.0001677 (warmup)
#  b 150/715 >> 2423.7 ms/b | lr: 0.0001677 | grad norm:  2.38 | inf norm:   0.092 | loss: 5.02 | perp:  152.01
#  b 300/715 >> 2349.7 ms/b | lr: 0.0001581 | grad norm:  2.66 | inf norm:   0.095 | loss: 4.94 | perp:  139.49
#  b 450/715 >> 2456.2 ms/b | lr: 0.0001811 | grad norm:  2.47 | inf norm:   0.065 | loss: 4.93 | perp:  137.87
#  b 600/715 >> 2307.0 ms/b | lr:  0.000163 | grad norm:  2.61 | inf norm:   0.088 | loss: 4.86 | perp:  128.79
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1703.15 sec | train loss, perp: 4.930,  138.39 | valid loss, perp: 5.113,  166.15
# Grad norm:  3.144 | Grad inf. norm:   0.08693 | Max abs param:      5.69
# ==============================================================================================================
#
#
# Epoch   7/150) lr = 0.0001957 (warmup)
#  b 150/710 >> 2352.1 ms/b | lr: 0.0001726 | grad norm:  2.78 | inf norm:   0.068 | loss: 4.79 | perp:  119.84
#  b 300/710 >> 2418.6 ms/b | lr:  0.000201 | grad norm:  2.78 | inf norm:   0.058 | loss: 4.72 | perp:  112.69
#  b 450/710 >> 2376.1 ms/b | lr:  0.000153 | grad norm:  4.22 | inf norm:    0.13 | loss: 4.69 | perp:  109.13
#  b 600/710 >> 2433.7 ms/b | lr: 0.0002062 | grad norm:  3.05 | inf norm:   0.081 | loss: 4.66 | perp:  106.00
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1702.04 sec | train loss, perp: 4.715,  111.61 | valid loss, perp: 4.902,  134.61
# Grad norm:  3.280 | Grad inf. norm:   0.06758 | Max abs param:     5.694
# ==============================================================================================================
#
#
# Epoch   8/150) lr = 0.0002236 (warmup)
#  b 150/721 >> 2350.8 ms/b | lr: 0.0002041 | grad norm:  4.07 | inf norm:    0.17 | loss: 4.55 | perp:   94.97
#  b 300/721 >> 2357.4 ms/b | lr: 0.0002041 | grad norm:  3.70 | inf norm:     0.1 | loss: 4.50 | perp:   90.14
#  b 450/721 >> 2387.2 ms/b | lr: 0.0002108 | grad norm:  4.12 | inf norm:   0.068 | loss: 4.48 | perp:   88.05
#  b 600/721 >> 2410.0 ms/b | lr: 0.0002041 | grad norm:  4.76 | inf norm:    0.15 | loss: 4.45 | perp:   85.25
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1703.31 sec | train loss, perp: 4.497,   89.71 | valid loss, perp: 4.672,  106.95
# Grad norm:  4.764 | Grad inf. norm:    0.1065 | Max abs param:     5.695
# ==============================================================================================================
#
#
# Epoch   9/150) lr = 0.0002516 (warmup)
#  b 150/709 >> 2473.5 ms/b | lr: 0.0002372 | grad norm:  5.27 | inf norm:   0.097 | loss: 4.41 | perp:   82.29
#  b 300/709 >> 2418.8 ms/b | lr: 0.0002652 | grad norm: 12.26 | inf norm:    0.23 | loss: 4.35 | perp:   77.14
#  b 450/709 >> 2389.2 ms/b | lr: 0.0002717 | grad norm: 10.28 | inf norm:    0.17 | loss: 4.34 | perp:   76.84
#  b 600/709 >> 2432.4 ms/b | lr: 0.0002219 | grad norm:  4.23 | inf norm:    0.17 | loss: 4.36 | perp:   78.41
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1742.91 sec | train loss, perp: 4.387,   80.42 | valid loss, perp: 4.578,   97.36
# Grad norm:  5.206 | Grad inf. norm:   0.06724 | Max abs param:     5.707
# ==============================================================================================================
#
#
# Epoch  10/150) lr = 0.0002795 (warmup)
#  b 150/714 >> 2442.0 ms/b | lr: 0.0002635 | grad norm:  6.45 | inf norm:    0.14 | loss: 4.31 | perp:   74.26
#  b 300/714 >> 2505.6 ms/b | lr: 0.0002083 | grad norm:  5.46 | inf norm:    0.19 | loss: 4.34 | perp:   76.35
#  b 450/714 >> 2413.6 ms/b | lr: 0.0003019 | grad norm: 15.56 | inf norm:    0.29 | loss: 4.28 | perp:   72.45
#  b 600/714 >> 2287.9 ms/b | lr: 0.0002795 | grad norm: 11.86 | inf norm:    0.24 | loss: 4.27 | perp:   71.19
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1719.22 sec | train loss, perp: 4.320,   75.16 | valid loss, perp: 4.573,   96.82
# Grad norm: 10.528 | Grad inf. norm:    0.1735 | Max abs param:     5.715
# ==============================================================================================================
#
#
# Epoch  11/150) lr = 0.0002665
#  b 150/719 >> 2392.4 ms/b | lr: 0.0002513 | grad norm:  5.16 | inf norm:    0.13 | loss: 4.23 | perp:   68.58
#  b 300/719 >> 2453.0 ms/b | lr: 0.0002738 | grad norm: 14.32 | inf norm:    0.25 | loss: 4.21 | perp:   67.45
#  b 450/719 >> 2359.0 ms/b | lr: 0.0002738 | grad norm: 13.53 | inf norm:    0.22 | loss: 4.20 | perp:   66.80
#  b 600/719 >> 2406.9 ms/b | lr: 0.0002433 | grad norm:  5.02 | inf norm:    0.19 | loss: 4.20 | perp:   66.54
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1727.72 sec | train loss, perp: 4.234,   68.97 | valid loss, perp: 4.437,   84.52
# Grad norm:  5.207 | Grad inf. norm:    0.2347 | Max abs param:     5.727
# ==============================================================================================================
#
#
# Epoch  12/150) lr = 0.0002552
#  b 150/717 >> 2420.5 ms/b | lr:  0.000225 | grad norm:  5.12 | inf norm:    0.32 | loss: 4.17 | perp:   64.85
#  b 300/717 >> 2456.2 ms/b | lr: 0.0002552 | grad norm:  9.99 | inf norm:    0.19 | loss: 4.16 | perp:   63.84
#  b 450/717 >> 2411.2 ms/b | lr: 0.0002621 | grad norm: 11.89 | inf norm:    0.25 | loss: 4.14 | perp:   62.61
#  b 600/717 >> 2474.4 ms/b | lr:  0.000248 | grad norm: 11.53 | inf norm:    0.32 | loss: 4.14 | perp:   62.68
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1755.36 sec | train loss, perp: 4.173,   64.94 | valid loss, perp: 4.396,   81.15
# Grad norm: 14.476 | Grad inf. norm:    0.2926 | Max abs param:     5.738
# ==============================================================================================================
#
#
# Epoch  13/150) lr = 0.0002451
#  b 150/719 >> 2392.8 ms/b | lr: 0.0002238 | grad norm:  5.25 | inf norm:    0.45 | loss: 4.11 | perp:   61.08
#  b 300/719 >> 2490.9 ms/b | lr: 0.0002311 | grad norm:  5.26 | inf norm:    0.23 | loss: 4.14 | perp:   62.64
#  b 450/719 >> 2555.6 ms/b | lr: 0.0001916 | grad norm:  6.30 | inf norm:    0.42 | loss: 4.13 | perp:   62.38
#  b 600/719 >> 2543.3 ms/b | lr: 0.0002584 | grad norm:  9.22 | inf norm:     0.3 | loss: 4.12 | perp:   61.27
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1794.19 sec | train loss, perp: 4.144,   63.06 | valid loss, perp: 4.369,   78.98
# Grad norm:  5.578 | Grad inf. norm:    0.6411 | Max abs param:     5.748
# ==============================================================================================================
#
#
# Epoch  14/150) lr = 0.0002362
#  b 150/719 >> 2534.1 ms/b | lr: 0.0002227 | grad norm:  6.46 | inf norm:    0.29 | loss: 4.13 | perp:   62.04
#  b 300/719 >> 2475.2 ms/b | lr: 0.0002362 | grad norm: 17.97 | inf norm:    0.63 | loss: 4.03 | perp:   56.40
#  b 450/719 >> 2458.5 ms/b | lr: 0.0002156 | grad norm:  8.45 | inf norm:    0.58 | loss: 4.10 | perp:   60.39
#  b 600/719 >> 2571.1 ms/b | lr: 0.0002427 | grad norm: 14.15 | inf norm:    0.29 | loss: 4.11 | perp:   61.04
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1801.12 sec | train loss, perp: 4.120,   61.59 | valid loss, perp: 4.389,   80.60
# Grad norm:  6.791 | Grad inf. norm:    0.3463 | Max abs param:     5.762
# ==============================================================================================================
#
#
# Epoch  15/150) lr = 0.0002282
#  b 150/721 >> 2543.9 ms/b | lr: 0.0001863 | grad norm:  6.85 | inf norm:    0.51 | loss: 4.08 | perp:   59.39
#  b 300/721 >> 2575.8 ms/b | lr: 0.0002282 | grad norm: 10.96 | inf norm:    0.45 | loss: 4.07 | perp:   58.51
#  b 450/721 >> 2493.9 ms/b | lr: 0.0002345 | grad norm: 18.19 | inf norm:    0.37 | loss: 4.00 | perp:   54.71
#  b 600/721 >> 2499.0 ms/b | lr: 0.0002406 | grad norm: 34.60 | inf norm:    0.77 | loss: 4.02 | perp:   55.46
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1825.73 sec | train loss, perp: 4.073,   58.73 | valid loss, perp: 4.300,   73.70
# Grad norm:  6.855 | Grad inf. norm:    0.5425 | Max abs param:     5.765
# ==============================================================================================================
#
#
# Epoch  16/150) lr = 0.000221
#  b 150/719 >> 2512.9 ms/b | lr:  0.000227 | grad norm: 43.22 | inf norm:     0.8 | loss: 4.00 | perp:   54.57
#  b 300/719 >> 2563.1 ms/b | lr: 0.0001949 | grad norm:  6.62 | inf norm:    0.57 | loss: 4.01 | perp:   55.10
#  b 450/719 >> 2606.5 ms/b | lr: 0.0002443 | grad norm: 14.02 | inf norm:    0.62 | loss: 4.04 | perp:   56.64
#  b 600/719 >> 2575.8 ms/b | lr: 0.0002329 | grad norm: 13.87 | inf norm:    0.53 | loss: 4.02 | perp:   55.89
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1849.46 sec | train loss, perp: 4.053,   57.56 | valid loss, perp: 4.337,   76.46
# Grad norm: 33.234 | Grad inf. norm:    0.7248 | Max abs param:     5.779
# ==============================================================================================================
#
#
# Epoch  17/150) lr = 0.0002144
#  b 150/722 >> 2603.6 ms/b | lr: 0.0002315 | grad norm: 14.54 | inf norm:    0.59 | loss: 4.01 | perp:   55.11
#  b 300/722 >> 2553.3 ms/b | lr: 0.0002202 | grad norm: 54.00 | inf norm:    0.99 | loss: 3.99 | perp:   53.84
#  b 450/722 >> 2614.7 ms/b | lr: 0.0002083 | grad norm: 13.13 | inf norm:    0.87 | loss: 3.96 | perp:   52.29
#  b 600/722 >> 2605.4 ms/b | lr: 0.0001891 | grad norm:  8.00 | inf norm:     1.1 | loss: 3.99 | perp:   54.17
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1885.51 sec | train loss, perp: 4.025,   56.01 | valid loss, perp: 4.253,   70.28
# Grad norm: 35.895 | Grad inf. norm:    0.6386 | Max abs param:     5.784
# ==============================================================================================================
#
#
# Epoch  18/150) lr = 0.0002083
#  b 150/718 >> 2683.4 ms/b | lr: 0.0002083 | grad norm: 29.14 | inf norm:    0.84 | loss: 3.99 | perp:   54.00
#  b 300/718 >> 2626.2 ms/b | lr: 0.0001964 | grad norm:  7.91 | inf norm:    0.67 | loss: 3.96 | perp:   52.33
#  b 450/718 >> 2639.2 ms/b | lr: 0.0001902 | grad norm:  9.08 | inf norm:     1.6 | loss: 3.92 | perp:   50.48
#  b 600/718 >> 2697.5 ms/b | lr: 0.0001902 | grad norm:  8.38 | inf norm:    0.81 | loss: 3.96 | perp:   52.31
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1912.61 sec | train loss, perp: 3.987,   53.87 | valid loss, perp: 4.224,   68.33
# Grad norm: 14.218 | Grad inf. norm:    0.9689 | Max abs param:     5.799
# ==============================================================================================================
#
#
# Epoch  19/150) lr = 0.0002028
#  b 150/714 >> 2736.0 ms/b | lr: 0.0002083 | grad norm: 12.26 | inf norm:    0.84 | loss: 3.95 | perp:   52.06
#  b 300/714 >> 2693.9 ms/b | lr: 0.0002242 | grad norm: 26.05 | inf norm:     1.1 | loss: 3.93 | perp:   51.02
#  b 450/714 >> 2667.0 ms/b | lr: 0.0002083 | grad norm: 19.85 | inf norm:     1.9 | loss: 3.93 | perp:   50.84
#  b 600/714 >> 2701.2 ms/b | lr: 0.0001971 | grad norm: 16.17 | inf norm:    0.93 | loss: 3.96 | perp:   52.25
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1926.94 sec | train loss, perp: 3.967,   52.82 | valid loss, perp: 4.184,   65.62
# Grad norm: 17.880 | Grad inf. norm:     1.278 | Max abs param:     5.806
# ==============================================================================================================
#
#
# Epoch  20/150) lr = 0.0001976
#  b 150/725 >> 2700.7 ms/b | lr: 0.0001804 | grad norm:  9.68 | inf norm:     1.8 | loss: 3.95 | perp:   52.05
#  b 300/725 >> 2606.1 ms/b | lr: 0.0002083 | grad norm: 21.50 | inf norm:       2 | loss: 3.86 | perp:   47.68
#  b 450/725 >> 2640.3 ms/b | lr: 0.0001863 | grad norm: 10.68 | inf norm:       1 | loss: 3.91 | perp:   49.82
#  b 600/725 >> 2653.5 ms/b | lr: 0.0001614 | grad norm: 15.02 | inf norm:     4.5 | loss: 3.93 | perp:   50.68
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1927.05 sec | train loss, perp: 3.938,   51.29 | valid loss, perp: 4.181,   65.46
# Grad norm: 38.915 | Grad inf. norm:      1.33 | Max abs param:     5.812
# ==============================================================================================================
#
#
# Epoch  21/150) lr = 0.0001929
#  b 150/718 >> 2709.3 ms/b | lr: 0.0001818 | grad norm: 11.64 | inf norm:     1.8 | loss: 3.92 | perp:   50.35
#  b 300/718 >> 2673.9 ms/b | lr: 0.0001761 | grad norm: 11.86 | inf norm:     1.4 | loss: 3.88 | perp:   48.66
#  b 450/718 >> 2754.1 ms/b | lr: 0.0001761 | grad norm:  9.42 | inf norm:     1.8 | loss: 3.89 | perp:   49.05
#  b 600/718 >> 2792.5 ms/b | lr: 0.0001818 | grad norm: 11.49 | inf norm:     1.3 | loss: 3.91 | perp:   49.97
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1961.67 sec | train loss, perp: 3.927,   50.76 | valid loss, perp: 4.125,   61.89
# Grad norm: 16.884 | Grad inf. norm:     1.639 | Max abs param:     5.818
# ==============================================================================================================
#
#
# Epoch  22/150) lr = 0.0001884
#  b 150/719 >> 2755.6 ms/b | lr: 0.0002083 | grad norm: 52.79 | inf norm:       2 | loss: 3.87 | perp:   47.84
#  b 300/719 >> 2778.6 ms/b | lr: 0.0001986 | grad norm: 13.49 | inf norm:     2.8 | loss: 3.92 | perp:   50.48
#  b 450/719 >> 2733.6 ms/b | lr: 0.0001936 | grad norm: 25.91 | inf norm:       1 | loss: 3.92 | perp:   50.53
#  b 600/719 >> 2709.5 ms/b | lr:  0.000172 | grad norm: 10.53 | inf norm:     1.7 | loss: 3.88 | perp:   48.56
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1982.52 sec | train loss, perp: 3.935,   51.17 | valid loss, perp: 4.159,   64.03
# Grad norm: 11.298 | Grad inf. norm:     1.195 | Max abs param:     5.823
# ==============================================================================================================
#
#
# Epoch  23/150) lr = 0.0001843
#  b 150/718 >> 2795.6 ms/b | lr: 0.0001791 | grad norm: 12.28 | inf norm:     1.8 | loss: 3.92 | perp:   50.35
#  b 300/718 >> 2667.2 ms/b | lr: 0.0001566 | grad norm: 16.74 | inf norm:     2.2 | loss: 3.83 | perp:   46.24
#  b 450/718 >> 2783.0 ms/b | lr: 0.0001625 | grad norm: 12.40 | inf norm:     2.2 | loss: 3.88 | perp:   48.22
#  b 600/718 >> 2838.0 ms/b | lr: 0.0001894 | grad norm: 110.05 | inf norm:     2.1 | loss: 3.88 | perp:   48.26
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 1990.62 sec | train loss, perp: 3.905,   49.66 | valid loss, perp: 4.071,   58.60
# Grad norm: 15.293 | Grad inf. norm:     2.013 | Max abs param:     5.832
# ==============================================================================================================
#
#
# Epoch  24/150) lr = 0.0001804
#  b 150/723 >> 2736.2 ms/b | lr: 0.0001902 | grad norm: 37.36 | inf norm:     1.2 | loss: 3.83 | perp:   46.19
#  b 300/723 >> 2779.1 ms/b | lr: 0.0001949 | grad norm: 81.76 | inf norm:     2.2 | loss: 3.86 | perp:   47.50
#  b 450/723 >> 2752.1 ms/b | lr: 0.0001647 | grad norm: 17.02 | inf norm:     1.9 | loss: 3.84 | perp:   46.61
#  b 600/723 >> 2808.1 ms/b | lr: 0.0001949 | grad norm: 305.46 | inf norm:     9.3 | loss: 3.85 | perp:   47.20
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2015.19 sec | train loss, perp: 3.896,   49.21 | valid loss, perp: 4.085,   59.45
# Grad norm: 40.367 | Grad inf. norm:    0.9171 | Max abs param:     5.827
# ==============================================================================================================
#
#
# Epoch  25/150) lr = 0.0001768
#  b 150/717 >> 2865.3 ms/b | lr: 0.0001768 | grad norm: 44.45 | inf norm:     1.8 | loss: 3.89 | perp:   48.84
#  b 300/717 >> 2835.3 ms/b | lr: 0.0001909 | grad norm: 28.86 | inf norm:     2.2 | loss: 3.88 | perp:   48.32
#  b 450/717 >> 2750.4 ms/b | lr: 0.0001667 | grad norm: 20.33 | inf norm:     2.9 | loss: 3.86 | perp:   47.48
#  b 600/717 >> 2806.5 ms/b | lr: 0.0001667 | grad norm: 15.47 | inf norm:     1.5 | loss: 3.89 | perp:   48.86
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2028.95 sec | train loss, perp: 3.910,   49.89 | valid loss, perp: 4.119,   61.53
# Grad norm: 27.894 | Grad inf. norm:     2.996 | Max abs param:     5.829
# ==============================================================================================================
#
#
# Epoch  26/150) lr = 0.0001733
#  b 150/723 >> 2868.2 ms/b | lr: 0.0001781 | grad norm: 55.06 | inf norm:     2.1 | loss: 3.87 | perp:   48.00
#  b 300/723 >> 2838.9 ms/b | lr: 0.0001781 | grad norm: 27.76 | inf norm:     1.7 | loss: 4.05 | perp:   57.54
#  b 450/723 >> 2735.9 ms/b | lr: 0.0001685 | grad norm: 19.03 | inf norm:     2.2 | loss: 3.82 | perp:   45.78
#  b 600/723 >> 2930.7 ms/b | lr: 0.0001827 | grad norm: 34.04 | inf norm:     2.5 | loss: 3.82 | perp:   45.76
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2054.03 sec | train loss, perp: 3.914,   50.08 | valid loss, perp: 4.060,   57.98
# Grad norm: 15.017 | Grad inf. norm:     1.471 | Max abs param:     5.829
# ==============================================================================================================
#
#
# Epoch  27/150) lr = 0.0001701
#  b 150/716 >> 2886.4 ms/b | lr: 0.0001701 | grad norm: 15.12 | inf norm:     2.1 | loss: 3.87 | perp:   47.76
#  b 300/716 >> 2854.2 ms/b | lr: 0.0001653 | grad norm: 13.87 | inf norm:     1.6 | loss: 3.82 | perp:   45.78
#  b 450/716 >> 2819.5 ms/b | lr: 0.0002044 | grad norm: 48.38 | inf norm:     2.5 | loss: 3.83 | perp:   45.86
#  b 600/716 >> 2783.2 ms/b | lr: 0.0001604 | grad norm: 16.38 | inf norm:     1.8 | loss: 3.82 | perp:   45.64
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2027.76 sec | train loss, perp: 3.863,   47.59 | valid loss, perp: 4.111,   61.02
# Grad norm: 34.581 | Grad inf. norm:     2.524 | Max abs param:     5.829
# ==============================================================================================================
#
#
# Epoch  28/150) lr = 0.000167
#  b 150/722 >> 2831.4 ms/b | lr: 0.0001623 | grad norm: 17.41 | inf norm:     1.8 | loss: 3.81 | perp:   45.28
#  b 300/722 >> 2797.4 ms/b | lr: 0.0001525 | grad norm: 13.60 | inf norm:     2.5 | loss: 3.78 | perp:   43.98
#  b 450/722 >> 2737.2 ms/b | lr:  0.000167 | grad norm: 25.84 | inf norm:     1.2 | loss: 3.83 | perp:   46.06
#  b 600/722 >> 2870.4 ms/b | lr: 0.0001804 | grad norm: 24.29 | inf norm:     1.7 | loss: 3.82 | perp:   45.58
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2048.61 sec | train loss, perp: 3.843,   46.65 | valid loss, perp: 4.019,   55.62
# Grad norm: 13.489 | Grad inf. norm:     2.123 | Max abs param:     5.839
# ==============================================================================================================
#
#
# Epoch  29/150) lr = 0.0001641
#  b 150/717 >> 2846.6 ms/b | lr: 0.0001773 | grad norm: 31.09 | inf norm:     3.2 | loss: 3.84 | perp:   46.51
#  b 300/717 >> 2823.3 ms/b | lr: 0.0001395 | grad norm: 17.67 | inf norm:     1.7 | loss: 3.79 | perp:   44.43
#  b 450/717 >> 2883.5 ms/b | lr: 0.0001686 | grad norm: 21.40 | inf norm:     1.6 | loss: 3.84 | perp:   46.62
#  b 600/717 >> 2835.1 ms/b | lr: 0.0001815 | grad norm: 84.47 | inf norm:     2.9 | loss: 3.79 | perp:   44.38
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2051.42 sec | train loss, perp: 3.842,   46.64 | valid loss, perp: 3.989,   54.00
# Grad norm: 20.730 | Grad inf. norm:     2.796 | Max abs param:     5.841
# ==============================================================================================================
#
#
# Epoch  30/150) lr = 0.0001614
#  b 150/719 >> 2820.9 ms/b | lr: 0.0001658 | grad norm: 41.12 | inf norm:     2.9 | loss: 3.84 | perp:   46.31
#  b 300/719 >> 2842.7 ms/b | lr: 0.0001614 | grad norm: 15.73 | inf norm:     2.9 | loss: 3.80 | perp:   44.69
#  b 450/719 >> 2904.9 ms/b | lr: 0.0001568 | grad norm: 15.15 | inf norm:     2.1 | loss: 3.82 | perp:   45.79
#  b 600/719 >> 2851.9 ms/b | lr: 0.0001658 | grad norm: 56.84 | inf norm:     6.1 | loss: 3.83 | perp:   45.95
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2057.12 sec | train loss, perp: 3.858,   47.35 | valid loss, perp: 4.082,   59.28
# Grad norm: 17.764 | Grad inf. norm:     2.918 | Max abs param:     5.846
# ==============================================================================================================
#
#
# Epoch  31/150) lr = 0.0001588
#  b 150/721 >> 2843.9 ms/b | lr: 0.0001673 | grad norm: 32.00 | inf norm:     2.2 | loss: 3.81 | perp:   45.01
#  b 300/721 >> 2827.1 ms/b | lr: 0.0001497 | grad norm: 19.76 | inf norm:     2.6 | loss: 3.80 | perp:   44.83
#  b 450/721 >> 2867.9 ms/b | lr: 0.0001449 | grad norm: 14.82 | inf norm:     2.1 | loss: 3.78 | perp:   43.69
#  b 600/721 >> 2837.0 ms/b | lr: 0.0001497 | grad norm: 19.41 | inf norm:     2.3 | loss: 3.81 | perp:   45.35
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2069.14 sec | train loss, perp: 3.834,   46.25 | valid loss, perp: 3.938,   51.32
# Grad norm: 33.236 | Grad inf. norm:     1.897 | Max abs param:     5.853
# ==============================================================================================================
#
#
# Epoch  32/150) lr = 0.0001563
#  b 150/719 >> 2948.3 ms/b | lr: 0.0001563 | grad norm: 17.01 | inf norm:     1.3 | loss: 3.82 | perp:   45.69
#  b 300/719 >> 2866.3 ms/b | lr: 0.0001426 | grad norm: 17.95 | inf norm:     1.8 | loss: 3.76 | perp:   42.86
#  b 450/719 >> 2890.0 ms/b | lr: 0.0001605 | grad norm: 26.79 | inf norm:     4.6 | loss: 3.77 | perp:   43.52
#  b 600/719 >> 2893.7 ms/b | lr: 0.0001473 | grad norm: 17.80 | inf norm:       2 | loss: 3.80 | perp:   44.52
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2083.61 sec | train loss, perp: 3.810,   45.16 | valid loss, perp: 3.927,   50.75
# Grad norm: 21.868 | Grad inf. norm:     2.448 | Max abs param:     5.863
# ==============================================================================================================
#
#
# Epoch  33/150) lr = 0.0001539
#  b 150/719 >> 2922.7 ms/b | lr: 0.0001451 | grad norm: 22.76 | inf norm:       2 | loss: 3.79 | perp:   44.41
#  b 300/719 >> 2871.7 ms/b | lr: 0.0001451 | grad norm: 20.50 | inf norm:     1.9 | loss: 3.77 | perp:   43.35
#  b 450/719 >> 2933.8 ms/b | lr: 0.0001451 | grad norm: 52.12 | inf norm:     4.2 | loss: 3.78 | perp:   43.84
#  b 600/719 >> 2892.2 ms/b | lr: 0.0001662 | grad norm: 25.81 | inf norm:     1.7 | loss: 3.80 | perp:   44.79
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2099.17 sec | train loss, perp: 3.821,   45.66 | valid loss, perp: 4.114,   61.16
# Grad norm: 142.848 | Grad inf. norm:     3.725 | Max abs param:     5.869
# ==============================================================================================================
#
#
# Epoch  34/150) lr = 0.0001516
#  b 150/717 >> 2979.4 ms/b | lr: 0.0001713 | grad norm: 25.39 | inf norm:     1.6 | loss: 3.87 | perp:   48.10
#  b 300/717 >> 3117.9 ms/b | lr: 0.0001473 | grad norm: 16.55 | inf norm:     1.9 | loss: 3.82 | perp:   45.76
#  b 450/717 >> 3001.3 ms/b | lr: 0.0001473 | grad norm: 23.51 | inf norm:     3.4 | loss: 3.78 | perp:   44.03
#  b 600/717 >> 2969.7 ms/b | lr:  0.000113 | grad norm: 37.50 | inf norm:     3.8 | loss: 3.77 | perp:   43.31
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2167.57 sec | train loss, perp: 3.843,   46.65 | valid loss, perp: 3.925,   50.63
# Grad norm: 17.843 | Grad inf. norm:     2.047 | Max abs param:     5.871
# ==============================================================================================================
#
#
# Epoch  35/150) lr = 0.0001494
#  b 150/717 >> 3011.6 ms/b | lr: 0.0001725 | grad norm: 47.77 | inf norm:     3.8 | loss: 3.78 | perp:   43.72
#  b 300/717 >> 3022.6 ms/b | lr: 0.0001614 | grad norm: 112.45 | inf norm:     3.4 | loss: 3.78 | perp:   43.65
#  b 450/717 >> 3022.2 ms/b | lr: 0.0001575 | grad norm: 51.98 | inf norm:     3.3 | loss: 3.77 | perp:   43.24
#  b 600/717 >> 3100.6 ms/b | lr: 0.0001494 | grad norm: 17.96 | inf norm:     1.5 | loss: 3.77 | perp:   43.44
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2178.53 sec | train loss, perp: 3.802,   44.79 | valid loss, perp: 4.073,   58.71
# Grad norm: 22.292 | Grad inf. norm:      5.05 | Max abs param:     5.879
# ==============================================================================================================
#
#
# Epoch  36/150) lr = 0.0001473
#  b 150/716 >> 2989.8 ms/b | lr: 0.0001629 | grad norm: 285.08 | inf norm:      12 | loss: 3.83 | perp:   45.84
#  b 300/716 >> 2989.4 ms/b | lr: 0.0001432 | grad norm: 23.64 | inf norm:     2.6 | loss: 3.75 | perp:   42.68
#  b 450/716 >> 3093.9 ms/b | lr: 0.0001345 | grad norm: 20.24 | inf norm:     2.2 | loss: 3.78 | perp:   43.95
#  b 600/716 >> 3034.7 ms/b | lr: 0.0001473 | grad norm: 22.36 | inf norm:     1.8 | loss: 3.77 | perp:   43.59
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2172.52 sec | train loss, perp: 3.812,   45.26 | valid loss, perp: 3.895,   49.14
# Grad norm: 94.416 | Grad inf. norm:     4.497 | Max abs param:     5.879
# ==============================================================================================================
#
#
# Epoch  37/150) lr = 0.0001453
#  b 150/716 >> 2927.4 ms/b | lr: 0.0001412 | grad norm: 123.20 | inf norm:     4.2 | loss: 3.75 | perp:   42.45
#  b 300/716 >> 3058.3 ms/b | lr: 0.0001453 | grad norm: 26.03 | inf norm:     2.1 | loss: 3.79 | perp:   44.05
#  b 450/716 >> 3100.5 ms/b | lr: 0.0001453 | grad norm: 18.85 | inf norm:     1.8 | loss: 3.77 | perp:   43.40
#  b 600/716 >> 3178.2 ms/b | lr: 0.0001412 | grad norm: 33.04 | inf norm:     3.5 | loss: 3.77 | perp:   43.58
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2209.70 sec | train loss, perp: 3.808,   45.07 | valid loss, perp: 4.028,   56.17
# Grad norm: 27.701 | Grad inf. norm:     2.657 | Max abs param:     5.877
# ==============================================================================================================
#
#
# Epoch  38/150) lr = 0.0001434
#  b 150/723 >> 3044.6 ms/b | lr: 0.0001265 | grad norm: 23.65 | inf norm:     2.8 | loss: 3.77 | perp:   43.22
#  b 300/723 >> 2940.8 ms/b | lr: 0.0001265 | grad norm: 20.32 | inf norm:     3.3 | loss: 3.79 | perp:   44.29
#  b 450/723 >> 3034.2 ms/b | lr: 0.0001585 | grad norm: 35.26 | inf norm:     2.9 | loss: 3.77 | perp:   43.18
#  b 600/723 >> 3057.2 ms/b | lr: 0.0001511 | grad norm: 63.40 | inf norm:     2.2 | loss: 3.72 | perp:   41.36
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2190.35 sec | train loss, perp: 3.793,   44.38 | valid loss, perp: 4.015,   55.42
# Grad norm: 167.185 | Grad inf. norm:     5.708 | Max abs param:      5.88
# ==============================================================================================================
#
#
# Epoch  39/150) lr = 0.0001415
#  b 150/718 >> 2992.0 ms/b | lr: 0.0001375 | grad norm: 32.75 | inf norm:     4.1 | loss: 3.74 | perp:   42.23
#  b 300/718 >> 3024.1 ms/b | lr: 0.0001292 | grad norm: 25.70 | inf norm:     2.8 | loss: 3.75 | perp:   42.36
#  b 450/718 >> 2998.4 ms/b | lr: 0.0001492 | grad norm: 63.84 | inf norm:     4.9 | loss: 3.72 | perp:   41.47
#  b 600/718 >> 3010.4 ms/b | lr: 0.0001565 | grad norm: 36.33 | inf norm:     3.4 | loss: 3.72 | perp:   41.40
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2169.76 sec | train loss, perp: 3.767,   43.27 | valid loss, perp: 4.073,   58.72
# Grad norm: 19.928 | Grad inf. norm:      4.01 | Max abs param:     5.881
# ==============================================================================================================
#
#
# Epoch  40/150) lr = 0.0001398
#  b 150/720 >> 2943.4 ms/b | lr: 0.0001233 | grad norm: 19.81 | inf norm:     2.5 | loss: 3.76 | perp:   43.06
#  b 300/720 >> 2899.5 ms/b | lr: 0.0001276 | grad norm: 20.82 | inf norm:     2.8 | loss: 3.74 | perp:   41.94
#  b 450/720 >> 3071.1 ms/b | lr: 0.0001398 | grad norm: 21.76 | inf norm:       3 | loss: 3.78 | perp:   43.74
#  b 600/720 >> 3148.1 ms/b | lr: 0.0001473 | grad norm: 26.77 | inf norm:     2.3 | loss: 3.82 | perp:   45.43
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2175.67 sec | train loss, perp: 3.802,   44.79 | valid loss, perp: 3.970,   52.97
# Grad norm: 18.281 | Grad inf. norm:     1.801 | Max abs param:      5.88
# ==============================================================================================================
#
#
# Epoch  41/150) lr = 0.000138
#  b 150/719 >> 3068.8 ms/b | lr: 0.0001342 | grad norm: 53.52 | inf norm:       6 | loss: 3.79 | perp:   44.34
#  b 300/719 >> 2931.3 ms/b | lr: 0.0001342 | grad norm: 31.72 | inf norm:     3.6 | loss: 3.68 | perp:   39.78
#  b 450/719 >> 2975.7 ms/b | lr: 0.0001455 | grad norm: 41.12 | inf norm:       3 | loss: 3.75 | perp:   42.38
#  b 600/719 >> 2950.7 ms/b | lr: 0.0001173 | grad norm: 28.48 | inf norm:     3.2 | loss: 3.77 | perp:   43.57
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2148.77 sec | train loss, perp: 3.785,   44.02 | valid loss, perp: 3.879,   48.36
# Grad norm: 15.710 | Grad inf. norm:     1.734 | Max abs param:     5.884
# ==============================================================================================================
#
#
# Epoch  42/150) lr = 0.0001364
#  b 150/716 >> 3015.9 ms/b | lr: 0.0001364 | grad norm: 29.52 | inf norm:     4.5 | loss: 3.74 | perp:   41.94
#  b 300/716 >> 3020.8 ms/b | lr: 0.0001401 | grad norm: 66.62 | inf norm:     5.1 | loss: 3.79 | perp:   44.13
#  b 450/716 >> 3006.9 ms/b | lr: 0.0001245 | grad norm: 19.60 | inf norm:     2.4 | loss: 3.75 | perp:   42.50
#  b 600/716 >> 2956.8 ms/b | lr: 0.0001286 | grad norm: 18.27 | inf norm:     2.4 | loss: 3.75 | perp:   42.68
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2155.28 sec | train loss, perp: 3.779,   43.77 | valid loss, perp: 3.889,   48.89
# Grad norm: 40.497 | Grad inf. norm:     3.955 | Max abs param:     5.889
# ==============================================================================================================
#
#
# Epoch  43/150) lr = 0.0001348
#  b 150/722 >> 2945.5 ms/b | lr:  0.000123 | grad norm: 19.37 | inf norm:     2.1 | loss: 3.76 | perp:   42.92
#  b 300/722 >> 2935.7 ms/b | lr:  0.000123 | grad norm: 19.37 | inf norm:     3.6 | loss: 3.76 | perp:   43.05
#  b 450/722 >> 2954.9 ms/b | lr: 0.0001189 | grad norm: 20.40 | inf norm:       3 | loss: 3.77 | perp:   43.38
#  b 600/722 >> 3025.6 ms/b | lr: 0.0001348 | grad norm: 21.47 | inf norm:     2.2 | loss: 3.83 | perp:   45.92
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2160.84 sec | train loss, perp: 3.802,   44.80 | valid loss, perp: 4.113,   61.14
# Grad norm: 20.593 | Grad inf. norm:     2.858 | Max abs param:     5.891
# ==============================================================================================================
#
#
# Epoch  44/150) lr = 0.0001333
#  b 150/717 >> 3046.3 ms/b | lr: 0.0001175 | grad norm: 28.45 | inf norm:     5.5 | loss: 3.73 | perp:   41.49
#  b 300/717 >> 3105.0 ms/b | lr: 0.0001369 | grad norm: 31.45 | inf norm:       3 | loss: 3.82 | perp:   45.60
#  b 450/717 >> 3046.0 ms/b | lr: 0.0001333 | grad norm: 21.28 | inf norm:     2.7 | loss: 3.74 | perp:   42.29
#  b 600/717 >> 3114.2 ms/b | lr: 0.0001295 | grad norm: 18.95 | inf norm:     2.6 | loss: 3.76 | perp:   43.14
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2194.94 sec | train loss, perp: 3.781,   43.88 | valid loss, perp: 3.869,   47.88
# Grad norm: 46.260 | Grad inf. norm:     2.848 | Max abs param:     5.893
# ==============================================================================================================
#
#
# Epoch  45/150) lr = 0.0001318
#  b 150/720 >> 2931.0 ms/b | lr:  0.000112 | grad norm: 37.67 | inf norm:     3.7 | loss: 3.74 | perp:   41.89
#  b 300/720 >> 3057.8 ms/b | lr:  0.000128 | grad norm: 31.50 | inf norm:     3.4 | loss: 3.77 | perp:   43.35
#  b 450/720 >> 3040.5 ms/b | lr:  0.000128 | grad norm: 19.70 | inf norm:     2.5 | loss: 3.76 | perp:   43.05
#  b 600/720 >> 3092.9 ms/b | lr:  0.000128 | grad norm: 29.43 | inf norm:     3.1 | loss: 3.73 | perp:   41.67
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2188.22 sec | train loss, perp: 3.777,   43.69 | valid loss, perp: 3.833,   46.20
# Grad norm: 29.622 | Grad inf. norm:     3.049 | Max abs param:      5.89
# ==============================================================================================================
#
#
# Epoch  46/150) lr = 0.0001303
#  b 150/724 >> 3045.9 ms/b | lr: 0.0001303 | grad norm: 71.92 | inf norm:     4.2 | loss: 3.73 | perp:   41.80
#  b 300/724 >> 3087.0 ms/b | lr:  0.000119 | grad norm: 24.16 | inf norm:       3 | loss: 3.74 | perp:   41.91
#  b 450/724 >> 3074.9 ms/b | lr: 0.0001266 | grad norm: 107.69 | inf norm:      14 | loss: 3.70 | perp:   40.47
#  b 600/724 >> 3172.6 ms/b | lr:  0.000119 | grad norm: 18.33 | inf norm:     2.2 | loss: 3.75 | perp:   42.62
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2247.02 sec | train loss, perp: 3.761,   42.98 | valid loss, perp: 3.893,   49.05
# Grad norm: 23.751 | Grad inf. norm:     3.724 | Max abs param:     5.895
# ==============================================================================================================
#
#
# Epoch  47/150) lr = 0.0001289
#  b 150/717 >> 3180.5 ms/b | lr: 0.0001325 | grad norm: 131.08 | inf norm:      13 | loss: 3.74 | perp:   41.94
#  b 300/717 >> 2978.9 ms/b | lr: 0.0001096 | grad norm: 24.58 | inf norm:     2.7 | loss: 3.67 | perp:   39.44
#  b 450/717 >> 2966.9 ms/b | lr: 0.0001289 | grad norm: 23.36 | inf norm:     2.3 | loss: 3.71 | perp:   40.74
#  b 600/717 >> 3076.6 ms/b | lr: 0.0001177 | grad norm: 21.46 | inf norm:     2.6 | loss: 3.71 | perp:   40.71
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2190.29 sec | train loss, perp: 3.753,   42.63 | valid loss, perp: 4.678,  107.55
# Grad norm: 83.259 | Grad inf. norm:     9.852 | Max abs param:     5.894
# ==============================================================================================================
#
#
# Epoch  48/150) lr = 0.0001276
#  b 150/716 >> 2938.3 ms/b | lr: 0.0001378 | grad norm: 88.28 | inf norm:     3.6 | loss: 3.79 | perp:   44.39
#  b 300/716 >> 3025.7 ms/b | lr: 0.0001203 | grad norm: 17.60 | inf norm:     1.8 | loss: 3.75 | perp:   42.51
#  b 450/716 >> 2946.2 ms/b | lr: 0.0001203 | grad norm: 22.04 | inf norm:       3 | loss: 3.70 | perp:   40.42
#  b 600/716 >> 3112.5 ms/b | lr: 0.0001203 | grad norm: 28.02 | inf norm:     2.7 | loss: 3.76 | perp:   42.87
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2160.07 sec | train loss, perp: 3.770,   43.40 | valid loss, perp: 3.838,   46.43
# Grad norm: 110.330 | Grad inf. norm:      11.2 | Max abs param:     5.898
# ==============================================================================================================
#
#
# Epoch  49/150) lr = 0.0001263
#  b 150/715 >> 3091.2 ms/b | lr: 0.0001396 | grad norm: 32.97 | inf norm:     2.2 | loss: 3.74 | perp:   42.30
#  b 300/715 >> 2986.7 ms/b | lr: 0.0001227 | grad norm: 27.86 | inf norm:     2.3 | loss: 3.71 | perp:   40.96
#  b 450/715 >> 3071.7 ms/b | lr: 9.412e-05 | grad norm: 34.37 | inf norm:       6 | loss: 3.71 | perp:   40.92
#  b 600/715 >> 3057.7 ms/b | lr: 0.0001297 | grad norm: 30.12 | inf norm:       3 | loss: 3.75 | perp:   42.33
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2176.97 sec | train loss, perp: 3.751,   42.55 | valid loss, perp: 3.823,   45.75
# Grad norm: 39.879 | Grad inf. norm:     5.744 | Max abs param:     5.899
# ==============================================================================================================
#
#
# Epoch  50/150) lr = 0.000125
#  b 150/712 >> 3047.4 ms/b | lr: 0.0001284 | grad norm: 26.08 | inf norm:     2.3 | loss: 3.73 | perp:   41.89
#  b 300/712 >> 2963.7 ms/b | lr: 0.0001284 | grad norm: 152.76 | inf norm:     4.3 | loss: 3.76 | perp:   42.84
#  b 450/712 >> 2976.0 ms/b | lr:  0.000125 | grad norm: 21.93 | inf norm:     2.4 | loss: 3.68 | perp:   39.56
#  b 600/712 >> 3092.3 ms/b | lr:  0.000125 | grad norm: 40.88 | inf norm:       5 | loss: 3.73 | perp:   41.70
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2158.48 sec | train loss, perp: 3.761,   43.00 | valid loss, perp: 3.937,   51.25
# Grad norm: 38.046 | Grad inf. norm:     4.432 | Max abs param:     5.899
# ==============================================================================================================
#
#
# Epoch  51/150) lr = 0.0001238
#  b 150/712 >> 3042.2 ms/b | lr: 0.0001167 | grad norm: 27.20 | inf norm:     2.2 | loss: 3.74 | perp:   42.08
#  b 300/712 >> 3038.6 ms/b | lr: 0.0001092 | grad norm: 29.46 | inf norm:     3.2 | loss: 3.70 | perp:   40.34
#  b 450/712 >> 2972.9 ms/b | lr: 0.0001429 | grad norm: 56.07 | inf norm:     3.8 | loss: 3.93 | perp:   50.81
#  b 600/712 >> 3009.9 ms/b | lr: 0.0001488 | grad norm: 49.89 | inf norm:     5.2 | loss: 3.69 | perp:   40.22
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2152.47 sec | train loss, perp: 3.781,   43.84 | valid loss, perp: 3.765,   43.17
# Grad norm: 20.685 | Grad inf. norm:     3.208 | Max abs param:     5.904
# ==============================================================================================================
#
#
# Epoch  52/150) lr = 0.0001226
#  b 150/715 >> 3025.8 ms/b | lr: 0.0001324 | grad norm: 39.81 | inf norm:     3.2 | loss: 3.74 | perp:   41.94
#  b 300/715 >> 3062.2 ms/b | lr: 0.0001156 | grad norm: 21.23 | inf norm:     2.7 | loss: 3.71 | perp:   40.93
#  b 450/715 >> 3029.4 ms/b | lr: 0.0001191 | grad norm: 22.29 | inf norm:     2.5 | loss: 3.72 | perp:   41.20
#  b 600/715 >> 3055.2 ms/b | lr: 0.0001324 | grad norm: 32.74 | inf norm:     3.3 | loss: 3.76 | perp:   43.00
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2169.49 sec | train loss, perp: 3.757,   42.81 | valid loss, perp: 4.048,   57.30
# Grad norm: 40.273 | Grad inf. norm:     3.374 | Max abs param:     5.904
# ==============================================================================================================
#
#
# Epoch  53/150) lr = 0.0001214
#  b 150/713 >> 3038.8 ms/b | lr: 0.0001247 | grad norm: 31.55 | inf norm:     2.7 | loss: 3.71 | perp:   40.91
#  b 300/713 >> 2977.5 ms/b | lr: 0.0001214 | grad norm: 23.11 | inf norm:     2.6 | loss: 3.67 | perp:   39.39
#  b 450/713 >> 3003.6 ms/b | lr: 0.0001032 | grad norm: 26.77 | inf norm:     3.8 | loss: 3.69 | perp:   39.98
#  b 600/713 >> 3059.3 ms/b | lr: 0.0001108 | grad norm: 23.37 | inf norm:     2.4 | loss: 3.69 | perp:   40.22
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2168.12 sec | train loss, perp: 3.723,   41.40 | valid loss, perp: 3.920,   50.42
# Grad norm: 41.891 | Grad inf. norm:     3.586 | Max abs param:     5.904
# ==============================================================================================================
#
#
# Epoch  54/150) lr = 0.0001203
#  b 150/720 >> 2973.8 ms/b | lr: 0.0001268 | grad norm: 30.42 | inf norm:     2.4 | loss: 3.69 | perp:   40.08
#  b 300/720 >> 3068.7 ms/b | lr: 0.0001169 | grad norm: 36.94 | inf norm:     3.3 | loss: 3.72 | perp:   41.13
#  b 450/720 >> 3063.5 ms/b | lr: 0.0001169 | grad norm: 24.04 | inf norm:     2.4 | loss: 3.69 | perp:   39.91
#  b 600/720 >> 3146.6 ms/b | lr: 0.0001169 | grad norm: 58.05 | inf norm:     4.8 | loss: 3.69 | perp:   40.18
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2190.76 sec | train loss, perp: 3.714,   41.02 | valid loss, perp: 3.937,   51.27
# Grad norm: 31.530 | Grad inf. norm:     3.314 | Max abs param:     5.905
# ==============================================================================================================
#
#
# Epoch  55/150) lr = 0.0001192
#  b 150/715 >> 3133.1 ms/b | lr: 0.0001158 | grad norm: 40.66 | inf norm:     6.7 | loss: 3.79 | perp:   44.12
#  b 300/715 >> 2981.4 ms/b | lr: 0.0001287 | grad norm: 28.53 | inf norm:     6.3 | loss: 3.70 | perp:   40.46
#  b 450/715 >> 3151.1 ms/b | lr: 0.0001158 | grad norm: 39.29 | inf norm:     4.3 | loss: 3.70 | perp:   40.50
#  b 600/715 >> 3047.6 ms/b | lr: 0.0001376 | grad norm: 93.82 | inf norm:     9.9 | loss: 3.80 | perp:   44.84
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2210.26 sec | train loss, perp: 3.772,   43.45 | valid loss, perp: 3.815,   45.38
# Grad norm: 37.386 | Grad inf. norm:     2.876 | Max abs param:     5.906
# ==============================================================================================================
#
#
# Epoch  56/150) lr = 0.0001181
#  b 150/716 >> 3093.4 ms/b | lr: 0.0001042 | grad norm: 33.34 | inf norm:     3.3 | loss: 3.68 | perp:   39.73
#  b 300/716 >> 3084.0 ms/b | lr: 0.0001306 | grad norm: 48.20 | inf norm:     6.1 | loss: 3.75 | perp:   42.33
#  b 450/716 >> 3091.7 ms/b | lr: 0.0001114 | grad norm: 42.87 | inf norm:     3.8 | loss: 3.71 | perp:   40.97
#  b 600/716 >> 3039.0 ms/b | lr: 0.0001245 | grad norm: 27.01 | inf norm:       4 | loss: 3.69 | perp:   40.20
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2209.68 sec | train loss, perp: 3.737,   41.99 | valid loss, perp: 3.821,   45.63
# Grad norm: 22.439 | Grad inf. norm:     2.343 | Max abs param:     5.906
# ==============================================================================================================
#
#
# Epoch  57/150) lr = 0.0001171
#  b 150/722 >> 3046.4 ms/b | lr: 0.0001104 | grad norm: 116.69 | inf norm:      12 | loss: 3.72 | perp:   41.12
#  b 300/722 >> 2940.1 ms/b | lr: 0.0001069 | grad norm: 35.75 | inf norm:     4.9 | loss: 3.71 | perp:   40.80
#  b 450/722 >> 3013.5 ms/b | lr: 0.0001138 | grad norm: 22.09 | inf norm:       2 | loss: 3.95 | perp:   51.73
#  b 600/722 >> 3053.4 ms/b | lr: 0.0001234 | grad norm: 69.72 | inf norm:     5.9 | loss: 3.78 | perp:   43.97
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2184.91 sec | train loss, perp: 3.810,   45.17 | valid loss, perp: 3.856,   47.27
# Grad norm: 27.907 | Grad inf. norm:     3.034 | Max abs param:     5.907
# ==============================================================================================================
#
#
# Epoch  58/150) lr = 0.0001161
#  b 150/718 >> 3124.1 ms/b | lr: 0.0001094 | grad norm: 27.89 | inf norm:       3 | loss: 3.75 | perp:   42.68
#  b 300/718 >> 3021.3 ms/b | lr: 0.0001192 | grad norm: 86.78 | inf norm:     8.7 | loss: 3.80 | perp:   44.59
#  b 450/718 >> 3039.2 ms/b | lr: 0.0001094 | grad norm: 24.63 | inf norm:       3 | loss: 3.66 | perp:   39.01
#  b 600/718 >> 3125.7 ms/b | lr: 0.0001254 | grad norm: 64.94 | inf norm:     7.4 | loss: 3.69 | perp:   40.21
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2199.66 sec | train loss, perp: 3.783,   43.95 | valid loss, perp: 3.891,   48.96
# Grad norm: 34.808 | Grad inf. norm:     3.834 | Max abs param:     5.907
# ==============================================================================================================
#
#
# Epoch  59/150) lr = 0.0001151
#  b 150/715 >> 3104.8 ms/b | lr: 0.0001151 | grad norm: 28.81 | inf norm:     3.9 | loss: 3.72 | perp:   41.18
#  b 300/715 >> 3087.0 ms/b | lr: 0.0001243 | grad norm: 66.67 | inf norm:     6.7 | loss: 3.67 | perp:   39.36
#  b 450/715 >> 3112.0 ms/b | lr:  0.000105 | grad norm: 24.89 | inf norm:     3.8 | loss: 3.69 | perp:   40.23
#  b 600/715 >> 3086.4 ms/b | lr:  0.000105 | grad norm: 47.84 | inf norm:     4.4 | loss: 3.66 | perp:   39.06
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2224.69 sec | train loss, perp: 3.722,   41.35 | valid loss, perp: 3.821,   45.66
# Grad norm: 21.652 | Grad inf. norm:     2.367 | Max abs param:     5.907
# ==============================================================================================================
#
#
# Epoch  60/150) lr = 0.0001141
#  b 150/708 >> 3258.9 ms/b | lr: 0.0001172 | grad norm: 30.00 | inf norm:     3.5 | loss: 3.76 | perp:   42.90
#  b 300/708 >> 3085.8 ms/b | lr: 0.0001076 | grad norm: 21.99 | inf norm:     2.6 | loss: 3.70 | perp:   40.34
#  b 450/708 >> 3090.1 ms/b | lr: 0.0001076 | grad norm: 25.23 | inf norm:     3.3 | loss: 3.67 | perp:   39.17
#  b 600/708 >> 3112.6 ms/b | lr: 0.0001262 | grad norm: 64.98 | inf norm:     4.7 | loss: 3.72 | perp:   41.09
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2246.71 sec | train loss, perp: 3.741,   42.16 | valid loss, perp: 3.847,   46.86
# Grad norm: 44.918 | Grad inf. norm:      4.67 | Max abs param:     5.911
# ==============================================================================================================
#
#
# Epoch  61/150) lr = 0.0001132
#  b 150/717 >> 3118.1 ms/b | lr: 9.981e-05 | grad norm: 31.05 | inf norm:     3.4 | loss: 4.02 | perp:   55.84
#  b 300/717 >> 3027.2 ms/b | lr: 0.0001033 | grad norm: 51.73 | inf norm:     6.1 | loss: 3.70 | perp:   40.29
#  b 450/717 >> 3061.4 ms/b | lr: 0.0001279 | grad norm: 81.48 | inf norm:     6.7 | loss: 3.69 | perp:   40.06
#  b 600/717 >> 3173.8 ms/b | lr: 0.0001279 | grad norm: 35.55 | inf norm:     3.7 | loss: 3.69 | perp:   39.95
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2224.06 sec | train loss, perp: 3.789,   44.19 | valid loss, perp: 3.778,   43.73
# Grad norm: 57.073 | Grad inf. norm:     5.999 | Max abs param:      5.91
# ==============================================================================================================
#
#
# Epoch  62/150) lr = 0.0001123
#  b 150/715 >> 3093.2 ms/b | lr: 0.0001241 | grad norm: 408.60 | inf norm:      25 | loss: 3.80 | perp:   44.88
#  b 300/715 >> 3171.9 ms/b | lr: 8.367e-05 | grad norm: 70.57 | inf norm:     7.4 | loss: 3.72 | perp:   41.24
#  b 450/715 >> 3070.5 ms/b | lr: 0.0001212 | grad norm: 77.27 | inf norm:     8.1 | loss: 3.78 | perp:   43.89
#  b 600/715 >> 3118.4 ms/b | lr: 0.0001025 | grad norm: 24.22 | inf norm:     3.3 | loss: 3.75 | perp:   42.34
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2227.32 sec | train loss, perp: 3.778,   43.73 | valid loss, perp: 3.779,   43.75
# Grad norm: 42.790 | Grad inf. norm:     5.571 | Max abs param:      5.91
# ==============================================================================================================
#
#
# Epoch  63/150) lr = 0.0001114
#  b 150/721 >> 3087.9 ms/b | lr: 0.0001114 | grad norm: 62.26 | inf norm:     5.4 | loss: 3.74 | perp:   42.14
#  b 300/721 >> 3042.5 ms/b | lr: 9.464e-05 | grad norm: 55.39 | inf norm:     7.9 | loss: 3.78 | perp:   43.95
#  b 450/721 >> 3060.6 ms/b | lr: 0.0001114 | grad norm: 28.13 | inf norm:     3.5 | loss: 3.73 | perp:   41.75
#  b 600/721 >> 3082.0 ms/b | lr:  0.000105 | grad norm: 63.51 | inf norm:     5.9 | loss: 3.65 | perp:   38.43
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2218.87 sec | train loss, perp: 3.740,   42.11 | valid loss, perp: 3.841,   46.57
# Grad norm: 24.091 | Grad inf. norm:     2.697 | Max abs param:     5.916
# ==============================================================================================================
#
#
# Epoch  64/150) lr = 0.0001105
#  b 150/719 >> 3103.8 ms/b | lr: 0.0001009 | grad norm: 35.86 | inf norm:     3.6 | loss: 3.71 | perp:   40.81
#  b 300/719 >> 3218.9 ms/b | lr: 0.0001193 | grad norm: 49.10 | inf norm:     3.1 | loss: 3.69 | perp:   40.12
#  b 450/719 >> 3104.7 ms/b | lr: 9.744e-05 | grad norm: 34.76 | inf norm:     3.8 | loss: 3.67 | perp:   39.37
#  b 600/719 >> 3170.9 ms/b | lr: 9.744e-05 | grad norm: 40.83 | inf norm:     6.6 | loss: 3.96 | perp:   52.58
# --------------------------------------------------------------------------------------------------------------
# Elapsed time: 2240.53 sec | train loss, perp: 3.805,   44.94 | valid loss, perp: 3.940,   51.41
# Grad norm: 27.231 | Grad inf. norm:     2.716 | Max abs param:     5.915
# ==============================================================================================================

# %%
CAUSES = ['output', 'grad']
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    _states = states
    if model.n_enc_layers > 0:
        enc_states = states[0]
        states = states[1:]
    if model.n_dec_layers > 0:
        dec_states = states[-1]
        states = states[:-1]
    attn_states = states[0]
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])
else:
    # Save training stats
    with open(os.path.join('stats', model_test_name+'.pkl'), 'wb') as f:
        pickle.dump(train_stats, f)
    with open(os.path.join('models', model_test_name+'.pt'), 'wb') as f:
        torch.save(model.state_dict(), f)

# %%
test_loss = evaluate(
    model, test_data, eval_batch_size, seq_len,
    ntokens, eval_criterion, save_wts = True
)
print('test_loss: {:5.3f} | test_perplexity: {:7.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss: 3.879 | test_perplexity:   48.37

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#    24    42  3257  3257  3257  3257  3257    42    42  1038  1038  1038  1038
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#  1038  1038  1038  1038  1038
# [torch.LongTensor of size 2x18]
#
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#    27  1573  5941  5941  5941  5941  5941  5941  5941  5941  5941  5941  5941
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#  5941  5941  5941  5941  5941
# [torch.LongTensor of size 2x18]
#
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   119   119   119  5463  5463  5463  5463  5463  5463  5463  5463  5463  5463
#
# Columns 13 to 17
#    26  5463   119    26    26
#  5463  5463  5463  5463  5463
# [torch.LongTensor of size 2x18]
#
# 15 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#    27    99    42    26    26    26    99    26    26   448   448   448   448
#
# Columns 13 to 17
#    35    27    27  1479   108
#   448    27    27    27    27
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
#
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(model.embedding.weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_norm, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = model.attn

# %%
align_wts = np.array(attn.alignment.weight.data)
plt.imshow(align_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_align_in'); plt.ylabel('d_align_out')
plt.title('Alignment sublayer weights')
plt.colorbar()
align_wts.shape
# Out:
# (256, 768)

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Attention sublayer weights (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 768)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# ## Plot training stat curves

# %%
epoch_range = range(1, train_stats['epochs']+1)
train_stats.keys()
# Out:
# dict_keys(['epochs', 'train_loss', 'val_loss', 'grad_norm', 'grad_inf_norm', 'max_param'])

# %%
plt.plot(epoch_range, train_stats['train_loss'])
plt.plot(epoch_range, train_stats['val_loss'])
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('Loss over training time')
plt.legend(['Train loss', 'Validation loss'])

# %%
plt.plot(epoch_range, train_stats['max_param'])
plt.xlabel('Epoch'); plt.ylabel('Largest parameter magnitude')
plt.title('Largest parameter magnitude over training time')
# Out:
# Text(0.5,1,'Largest parameter magnitude over training time')

# %%
fig, pnorm_ax = plt.subplots()
pnorm_ax.plot(epoch_range, train_stats['grad_norm'], 'b')
pnorm_ax.set_xlabel('Epoch');
pnorm_ax.set_ylabel('2-norm', color = 'b')

infnorm_ax = pnorm_ax.twinx()
infnorm_ax.plot(epoch_range, train_stats['grad_inf_norm'], 'r')
infnorm_ax.set_ylabel('infinite norm', color = 'r')

plt.title('Gradient norms over training time')
#fig.tight_layout()
# Out:
# Text(0.5,1,'Gradient norms over training time')
