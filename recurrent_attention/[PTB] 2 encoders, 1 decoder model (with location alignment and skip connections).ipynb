# %%
import os
import pickle
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from model import *
from trainer import *

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Hyperparameters

# %%
model_test_name = '2_encoder_1_decoder_with_skips_localign'
ckpt_loc = os.path.join('checkpoints', model_test_name+'.pt')

# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 2
lr = 0.005
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 150
early_stopping = 10
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
encode_size = 256
h_size = 256
align_size = 256
loc_align_size = 256
loc_align_kernel = 5
decode_size = 256
decode_out_size = 512
n_enc_layers = 2
attn_rnn_layers = 1
n_dec_layers = 1
smooth_align = True
align_location = True
skip_connections = True

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler
#
# The learning rate scheduler sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    encode_size = encode_size, h_size = h_size, align_size = align_size,
    decode_size = decode_size, decode_out_size = decode_out_size,
    n_enc_layers = n_enc_layers, attn_rnn_layers = attn_rnn_layers,
    n_dec_layers = n_dec_layers, align_location = align_location,
    loc_align_size = loc_align_size, loc_align_kernel = loc_align_kernel,
    smooth_align = smooth_align, skip_connections = skip_connections,
    dropout = dropout
)
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
eval_criterion = LabelSmoothing(ntokens, smoothing = 0)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, decay_factor, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 9458689

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Train and evaluate

# %%
train_stats, stat, train_loss, data, targets, states, nstates = train_eval_loop(
    model, train_data, val_data, batch_size, eval_batch_size,
    seq_len, ntokens, criterion, eval_criterion, optimizer,
    lr_scheduler, epochs, warmup_steps, early_stopping,
    clip, log_interval, ckpt_loc
)
# Out:
# Epoch   1/150) lr = 6.988e-06 (warmup)
#  b 150/717 >> 2997.4 ms/b | lr: 7.725e-06 | grad norm:  1.26 | inf norm:  0.066 | loss: 8.69 | perp: 5934.52
#  b 300/717 >> 2991.2 ms/b | lr: 7.179e-06 | grad norm:  3.73 | inf norm:  0.193 | loss: 7.43 | perp: 1689.39
#  b 450/717 >> 2980.2 ms/b | lr: 6.163e-06 | grad norm:  2.03 | inf norm:  0.107 | loss: 6.37 | perp: 585.03
#  b 600/717 >> 3004.9 ms/b | lr: 5.938e-06 | grad norm:  2.03 | inf norm: 0.0736 | loss: 6.25 | perp: 520.55
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2139.11 sec | train loss, perp: 7.020, 1118.24    | valid loss, perp: 6.545, 695.85
# Grad norm:  1.646 | Grad inf. norm: 0.07911 | Max abs param:  0.4487
# ============================================================================================================
#
#
# Epoch   2/150) lr = 1.398e-05 (warmup)
#  b 150/709 >> 2964.5 ms/b | lr: 1.358e-05 | grad norm:  1.32 | inf norm: 0.0333 | loss: 6.26 | perp: 522.91
#  b 300/709 >> 2950.1 ms/b | lr: 1.358e-05 | grad norm:  1.57 | inf norm: 0.0689 | loss: 6.19 | perp: 490.24
#  b 450/709 >> 2982.2 ms/b | lr: 1.188e-05 | grad norm:  1.52 | inf norm: 0.0574 | loss: 6.18 | perp: 481.29
#  b 600/709 >> 2969.4 ms/b | lr: 1.233e-05 | grad norm:  1.33 | inf norm: 0.0509 | loss: 6.16 | perp: 473.00
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2103.32 sec | train loss, perp: 6.175, 480.51    | valid loss, perp: 6.460, 638.75
# Grad norm:  1.391 | Grad inf. norm: 0.03991 | Max abs param:  0.4547
# ============================================================================================================
#
#
# Epoch   3/150) lr = 2.096e-05 (warmup)
#  b 150/721 >> 2988.4 ms/b | lr: 2.096e-05 | grad norm:  1.04 | inf norm: 0.0279 | loss: 6.15 | perp: 466.96
#  b 300/721 >> 2929.2 ms/b | lr: 1.849e-05 | grad norm:  1.09 | inf norm: 0.0352 | loss: 6.10 | perp: 444.17
#  b 450/721 >> 2927.4 ms/b | lr: 1.976e-05 | grad norm:  1.05 | inf norm:  0.037 | loss: 6.06 | perp: 429.26
#  b 600/721 >> 2913.6 ms/b | lr: 2.154e-05 | grad norm:  1.01 | inf norm: 0.0357 | loss: 6.06 | perp: 427.60
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2103.73 sec | train loss, perp: 6.072, 433.63    | valid loss, perp: 6.371, 584.55
# Grad norm:  0.942 | Grad inf. norm: 0.03716 | Max abs param:  0.4623
# ============================================================================================================
#
#
# Epoch   4/150) lr = 2.795e-05 (warmup)
#  b 150/712 >> 3058.6 ms/b | lr: 3.019e-05 | grad norm:  0.94 | inf norm: 0.0415 | loss: 6.05 | perp: 425.52
#  b 300/712 >> 3221.6 ms/b | lr: 2.872e-05 | grad norm:  0.90 | inf norm: 0.0283 | loss: 6.00 | perp: 405.10
#  b 450/712 >> 3099.9 ms/b | lr: 2.795e-05 | grad norm:  0.94 | inf norm: 0.0344 | loss: 5.98 | perp: 396.73
#  b 600/712 >> 3066.7 ms/b | lr: 3.019e-05 | grad norm:  0.85 | inf norm: 0.0218 | loss: 5.97 | perp: 390.49
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2200.61 sec | train loss, perp: 5.987, 398.25    | valid loss, perp: 6.289, 538.46
# Grad norm:  0.848 | Grad inf. norm: 0.02942 | Max abs param:   0.479
# ============================================================================================================
#
#
# Epoch   5/150) lr = 3.494e-05 (warmup)
#  b 150/719 >> 2963.9 ms/b | lr: 3.294e-05 | grad norm:  0.90 | inf norm: 0.0249 | loss: 5.97 | perp: 390.33
#  b 300/719 >> 3127.1 ms/b | lr: 4.034e-05 | grad norm:  0.83 | inf norm: 0.0249 | loss: 5.92 | perp: 371.07
#  b 450/719 >> 3129.3 ms/b | lr: 3.189e-05 | grad norm:  1.16 | inf norm: 0.0321 | loss: 5.89 | perp: 362.43
#  b 600/719 >> 3061.3 ms/b | lr: 3.863e-05 | grad norm:  1.03 | inf norm:  0.023 | loss: 5.86 | perp: 351.71
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2197.42 sec | train loss, perp: 5.894, 362.84    | valid loss, perp: 6.173, 479.81
# Grad norm:  0.924 | Grad inf. norm: 0.01989 | Max abs param:  0.5034
# ============================================================================================================
#
#
# Epoch   6/150) lr = 4.193e-05 (warmup)
#  b 150/718 >> 3141.8 ms/b | lr: 3.827e-05 | grad norm:  1.00 | inf norm: 0.0284 | loss: 5.86 | perp: 349.03
#  b 300/718 >> 3141.1 ms/b | lr: 4.635e-05 | grad norm:  0.82 | inf norm: 0.0177 | loss: 5.79 | perp: 326.78
#  b 450/718 >> 2958.1 ms/b | lr: 3.953e-05 | grad norm:  1.09 | inf norm: 0.0244 | loss: 5.77 | perp: 319.78
#  b 600/718 >> 2853.4 ms/b | lr: 4.419e-05 | grad norm:  1.04 | inf norm: 0.0247 | loss: 5.75 | perp: 313.36
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2148.25 sec | train loss, perp: 5.777, 322.81    | valid loss, perp: 6.034, 417.27
# Grad norm:  1.356 | Grad inf. norm:  0.0539 | Max abs param:  0.5291
# ============================================================================================================
#
#
# Epoch   7/150) lr = 4.891e-05 (warmup)
#  b 150/721 >> 2880.6 ms/b | lr: 4.612e-05 | grad norm:  1.29 | inf norm: 0.0396 | loss: 5.71 | perp: 303.38
#  b 300/721 >> 2848.4 ms/b | lr: 5.408e-05 | grad norm:  1.20 | inf norm: 0.0453 | loss: 5.66 | perp: 287.14
#  b 450/721 >> 2788.6 ms/b | lr: 4.754e-05 | grad norm:  1.29 | inf norm: 0.0248 | loss: 5.62 | perp: 276.15
#  b 600/721 >> 2876.4 ms/b | lr: 5.283e-05 | grad norm:  2.49 | inf norm:   0.22 | loss: 5.60 | perp: 269.41
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2046.93 sec | train loss, perp: 5.632, 279.11    | valid loss, perp: 5.818, 336.20
# Grad norm:  1.388 | Grad inf. norm: 0.06887 | Max abs param:  0.5433
# ============================================================================================================
#
#
# Epoch   8/150) lr = 5.59e-05 (warmup)
#  b 150/719 >> 2848.6 ms/b | lr:  5.27e-05 | grad norm:  1.77 | inf norm:   0.15 | loss: 5.54 | perp: 253.98
#  b 300/719 >> 2841.2 ms/b | lr:  5.59e-05 | grad norm:  1.81 | inf norm:   0.12 | loss: 5.48 | perp: 239.23
#  b 450/719 >> 2868.0 ms/b | lr: 5.743e-05 | grad norm:  1.48 | inf norm: 0.0511 | loss: 5.43 | perp: 227.54
#  b 600/719 >> 2848.6 ms/b | lr: 5.103e-05 | grad norm:  2.01 | inf norm:   0.19 | loss: 5.36 | perp: 212.51
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2048.18 sec | train loss, perp: 5.430, 228.06    | valid loss, perp: 5.408, 223.18
# Grad norm:  1.917 | Grad inf. norm:  0.1695 | Max abs param:  0.5541
# ============================================================================================================
#
#
# Epoch   9/150) lr = 6.289e-05 (warmup)
#  b 150/720 >> 2877.4 ms/b | lr: 5.929e-05 | grad norm:  1.41 | inf norm: 0.0276 | loss: 5.26 | perp: 193.05
#  b 300/720 >> 2824.0 ms/b | lr: 6.629e-05 | grad norm: 10.85 | inf norm:   1.68 | loss: 5.19 | perp: 179.05
#  b 450/720 >> 2892.0 ms/b | lr: 5.929e-05 | grad norm:  2.62 | inf norm:  0.354 | loss: 5.12 | perp: 167.31
#  b 600/720 >> 2872.3 ms/b | lr: 6.793e-05 | grad norm:  1.95 | inf norm:  0.118 | loss: 5.03 | perp: 152.37
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2062.00 sec | train loss, perp: 5.135, 169.93    | valid loss, perp: 5.006, 149.35
# Grad norm: 24.540 | Grad inf. norm:   3.779 | Max abs param:  0.5621
# ============================================================================================================
#
#
# Epoch  10/150) lr = 6.988e-05 (warmup)
#  b 150/708 >> 2942.7 ms/b | lr: 6.588e-05 | grad norm:  2.57 | inf norm:  0.321 | loss: 4.99 | perp: 146.81
#  b 300/708 >> 2894.0 ms/b | lr: 6.163e-05 | grad norm:  4.05 | inf norm:  0.547 | loss: 4.84 | perp: 126.81
#  b 450/708 >> 2880.2 ms/b | lr: 6.791e-05 | grad norm:  1.86 | inf norm: 0.0989 | loss: 4.80 | perp: 121.76
#  b 600/708 >> 2914.9 ms/b | lr: 7.179e-05 | grad norm: 12.74 | inf norm:   1.83 | loss: 4.72 | perp: 111.95
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2069.99 sec | train loss, perp: 4.829, 125.14    | valid loss, perp: 4.664, 106.02
# Grad norm:  4.787 | Grad inf. norm:  0.6498 | Max abs param:  0.5703
# ============================================================================================================
#
#
# Epoch  11/150) lr = 6.663e-05
#  b 150/726 >> 2843.2 ms/b | lr: 6.281e-05 | grad norm:  2.31 | inf norm: 0.0751 | loss: 4.63 | perp: 102.10
#  b 300/726 >> 2804.3 ms/b | lr: 7.196e-05 | grad norm: 11.97 | inf norm:   1.37 | loss: 4.48 | perp:  88.67
#  b 450/726 >> 2811.7 ms/b | lr: 7.023e-05 | grad norm:  4.57 | inf norm:   0.32 | loss: 4.45 | perp:  85.69
#  b 600/726 >> 2860.0 ms/b | lr: 6.663e-05 | grad norm:  5.08 | inf norm:  0.561 | loss: 4.43 | perp:  84.11
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2057.97 sec | train loss, perp: 4.488,  88.99    | valid loss, perp: 4.421,  83.14
# Grad norm:  2.612 | Grad inf. norm: 0.08696 | Max abs param:  0.5801
# ============================================================================================================
#
#
# Epoch  12/150) lr = 6.379e-05
#  b 150/717 >> 2851.0 ms/b | lr: 6.554e-05 | grad norm:  3.34 | inf norm:  0.232 | loss: 4.35 | perp:  77.77
#  b 300/717 >> 2854.8 ms/b | lr: 5.823e-05 | grad norm:  2.75 | inf norm:  0.258 | loss: 4.28 | perp:  72.37
#  b 450/717 >> 2887.7 ms/b | lr: 6.554e-05 | grad norm: 24.07 | inf norm:   2.51 | loss: 4.28 | perp:  72.01
#  b 600/717 >> 2921.3 ms/b | lr: 6.554e-05 | grad norm:  3.43 | inf norm:  0.295 | loss: 4.24 | perp:  69.11
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2062.45 sec | train loss, perp: 4.293,  73.21    | valid loss, perp: 4.153,  63.64
# Grad norm:  2.484 | Grad inf. norm: 0.04374 | Max abs param:  0.5917
# ============================================================================================================
#
#
# Epoch  13/150) lr = 6.129e-05
#  b 150/715 >> 2810.6 ms/b | lr:  6.62e-05 | grad norm:  4.85 | inf norm:  0.173 | loss: 4.18 | perp:  65.61
#  b 300/715 >> 2792.2 ms/b | lr: 5.595e-05 | grad norm:  3.68 | inf norm:  0.277 | loss: 4.12 | perp:  61.63
#  b 450/715 >> 2773.1 ms/b | lr: 5.405e-05 | grad norm:  4.12 | inf norm: 0.0982 | loss: 4.09 | perp:  59.74
#  b 600/715 >> 2699.5 ms/b | lr: 5.956e-05 | grad norm:  6.17 | inf norm:   0.11 | loss: 4.05 | perp:  57.36
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1980.48 sec | train loss, perp: 4.115,  61.25    | valid loss, perp: 3.935,  51.14
# Grad norm:  4.334 | Grad inf. norm:  0.4962 | Max abs param:  0.6024
# ============================================================================================================
#
#
# Epoch  14/150) lr = 5.906e-05
#  b 150/719 >> 2723.3 ms/b | lr: 5.568e-05 | grad norm:  6.92 | inf norm:  0.166 | loss: 4.02 | perp:  55.47
#  b 300/719 >> 2813.0 ms/b | lr: 6.068e-05 | grad norm: 41.93 | inf norm:   4.14 | loss: 3.97 | perp:  53.22
#  b 450/719 >> 2769.4 ms/b | lr: 5.568e-05 | grad norm:  3.96 | inf norm:  0.108 | loss: 3.91 | perp:  50.01
#  b 600/719 >> 2735.6 ms/b | lr: 4.617e-05 | grad norm:  6.51 | inf norm:    0.9 | loss: 3.87 | perp:  47.71
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1977.78 sec | train loss, perp: 3.949,  51.86    | valid loss, perp: 3.664,  39.01
# Grad norm:  3.408 | Grad inf. norm:   0.143 | Max abs param:  0.6119
# ============================================================================================================
#
#
# Epoch  15/150) lr = 5.705e-05
#  b 150/714 >> 2769.3 ms/b | lr: 5.379e-05 | grad norm:  4.49 | inf norm:  0.177 | loss: 3.81 | perp:  45.08
#  b 300/714 >> 2770.1 ms/b | lr: 5.862e-05 | grad norm: 19.55 | inf norm:    1.4 | loss: 3.78 | perp:  43.68
#  b 450/714 >> 2810.5 ms/b | lr: 4.849e-05 | grad norm: 10.36 | inf norm:   1.61 | loss: 3.73 | perp:  41.78
#  b 600/714 >> 2790.3 ms/b | lr: 5.705e-05 | grad norm: 42.29 | inf norm:   4.23 | loss: 3.76 | perp:  42.89
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1983.86 sec | train loss, perp: 3.775,  43.60    | valid loss, perp: 3.483,  32.57
# Grad norm: 11.855 | Grad inf. norm:  0.8914 | Max abs param:  0.6201
# ============================================================================================================
#
#
# Epoch  16/150) lr = 5.524e-05
#  b 150/717 >> 2806.3 ms/b | lr: 5.676e-05 | grad norm: 18.96 | inf norm:    2.6 | loss: 3.65 | perp:  38.36
#  b 300/717 >> 2723.6 ms/b | lr: 5.524e-05 | grad norm:  3.32 | inf norm:  0.109 | loss: 3.59 | perp:  36.28
#  b 450/717 >> 2758.2 ms/b | lr: 5.208e-05 | grad norm: 73.11 | inf norm:   7.54 | loss: 3.62 | perp:  37.27
#  b 600/717 >> 2773.1 ms/b | lr: 5.823e-05 | grad norm:  4.38 | inf norm:  0.123 | loss: 3.60 | perp:  36.45
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1982.93 sec | train loss, perp: 3.617,  37.22    | valid loss, perp: 3.374,  29.20
# Grad norm: 14.685 | Grad inf. norm:   2.309 | Max abs param:  0.6261
# ============================================================================================================
#
#
# Epoch  17/150) lr = 5.359e-05
#  b 150/717 >> 2821.3 ms/b | lr: 5.789e-05 | grad norm:  6.20 | inf norm:   0.61 | loss: 3.64 | perp:  38.21
#  b 300/717 >> 2842.2 ms/b | lr: 5.506e-05 | grad norm: 10.27 | inf norm:  0.226 | loss: 3.49 | perp:  32.87
#  b 450/717 >> 2728.1 ms/b | lr: 5.506e-05 | grad norm:  4.60 | inf norm:  0.259 | loss: 3.50 | perp:  33.09
#  b 600/717 >> 2756.4 ms/b | lr: 4.726e-05 | grad norm:  2.89 | inf norm:  0.358 | loss: 3.67 | perp:  39.42
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1990.76 sec | train loss, perp: 3.597,  36.50    | valid loss, perp: 3.293,  26.93
# Grad norm: 14.157 | Grad inf. norm:   1.743 | Max abs param:    0.63
# ============================================================================================================
#
#
# Epoch  18/150) lr = 5.208e-05
#  b 150/725 >> 2694.3 ms/b | lr: 4.426e-05 | grad norm: 13.92 | inf norm:   2.14 | loss: 3.46 | perp:  31.97
#  b 300/725 >> 2713.6 ms/b | lr: 4.426e-05 | grad norm:  5.49 | inf norm:  0.274 | loss: 3.40 | perp:  29.92
#  b 450/725 >> 2760.4 ms/b | lr: 5.062e-05 | grad norm:  3.23 | inf norm: 0.0626 | loss: 3.37 | perp:  29.13
#  b 600/725 >> 2721.3 ms/b | lr: 5.626e-05 | grad norm: 58.75 | inf norm:   4.97 | loss: 3.41 | perp:  30.16
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1982.71 sec | train loss, perp: 3.443,  31.29    | valid loss, perp: 3.142,  23.16
# Grad norm:  3.318 | Grad inf. norm:  0.2198 | Max abs param:  0.6346
# ============================================================================================================
#
#
# Epoch  19/150) lr = 5.069e-05
#  b 150/716 >> 2808.9 ms/b | lr: 4.927e-05 | grad norm:  3.97 | inf norm:  0.597 | loss: 3.45 | perp:  31.64
#  b 300/716 >> 2850.0 ms/b | lr: 4.927e-05 | grad norm: 12.98 | inf norm:  0.712 | loss: 3.50 | perp:  33.00
#  b 450/716 >> 2748.4 ms/b | lr: 5.344e-05 | grad norm: 16.77 | inf norm:   1.17 | loss: 3.37 | perp:  29.11
#  b 600/716 >> 2727.5 ms/b | lr: 5.476e-05 | grad norm: 180.67 | inf norm:   13.6 | loss: 3.42 | perp:  30.45
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1998.36 sec | train loss, perp: 3.442,  31.25    | valid loss, perp: 3.276,  26.48 :(
# Grad norm: 10.957 | Grad inf. norm:   1.757 | Max abs param:  0.6367
# ============================================================================================================
#
#
# Epoch  20/150) lr = 4.941e-05
#  b 150/715 >> 2744.9 ms/b | lr: 5.076e-05 | grad norm:  7.14 | inf norm:  0.132 | loss: 3.41 | perp:  30.36
#  b 300/715 >> 2780.7 ms/b | lr: 5.076e-05 | grad norm: 10.78 | inf norm:    1.3 | loss: 3.31 | perp:  27.41
#  b 450/715 >> 2799.8 ms/b | lr: 4.941e-05 | grad norm:  8.12 | inf norm:   1.02 | loss: 3.27 | perp:  26.30
#  b 600/715 >> 2776.1 ms/b | lr: 4.941e-05 | grad norm:  2.91 | inf norm: 0.0656 | loss: 3.23 | perp:  25.34
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1989.78 sec | train loss, perp: 3.301,  27.14    | valid loss, perp: 2.969,  19.47
# Grad norm:  7.253 | Grad inf. norm:  0.4595 | Max abs param:  0.6394
# ============================================================================================================
#
#
# Epoch  21/150) lr = 4.822e-05
#  b 150/721 >> 2773.0 ms/b | lr: 5.083e-05 | grad norm:  7.18 | inf norm:   1.22 | loss: 3.33 | perp:  27.85
#  b 300/721 >> 2735.8 ms/b | lr: 4.954e-05 | grad norm:  4.27 | inf norm:  0.385 | loss: 3.21 | perp:  24.66
#  b 450/721 >> 2794.9 ms/b | lr: 5.451e-05 | grad norm: 17.25 | inf norm:    2.2 | loss: 3.19 | perp:  24.32
#  b 600/721 >> 2747.2 ms/b | lr: 5.083e-05 | grad norm: 11.25 | inf norm:   1.07 | loss: 3.20 | perp:  24.44
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1987.10 sec | train loss, perp: 3.254,  25.88    | valid loss, perp: 2.900,  18.18
# Grad norm: 11.388 | Grad inf. norm:   1.216 | Max abs param:  0.6421
# ============================================================================================================
#
#
# Epoch  22/150) lr = 4.711e-05
#  b 150/715 >> 2758.7 ms/b | lr: 4.711e-05 | grad norm:  9.02 | inf norm:   1.55 | loss: 3.18 | perp:  24.13
#  b 300/715 >> 2860.3 ms/b | lr:  4.84e-05 | grad norm: 88.36 | inf norm:   3.94 | loss: 3.18 | perp:  24.03
#  b 450/715 >> 2709.1 ms/b | lr:  4.84e-05 | grad norm: 10.32 | inf norm:  0.251 | loss: 3.11 | perp:  22.46
#  b 600/715 >> 2782.2 ms/b | lr: 4.966e-05 | grad norm: 52.24 | inf norm:   8.48 | loss: 3.07 | perp:  21.63
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1995.01 sec | train loss, perp: 3.149,  23.31    | valid loss, perp: 2.843,  17.17
# Grad norm:  8.032 | Grad inf. norm:  0.8363 | Max abs param:  0.6451
# ============================================================================================================
#
#
# Epoch  23/150) lr = 4.608e-05
#  b 150/718 >> 2707.6 ms/b | lr: 4.478e-05 | grad norm:  3.65 | inf norm:   0.45 | loss: 3.16 | perp:  23.69
#  b 300/718 >> 2778.4 ms/b | lr: 4.478e-05 | grad norm:  3.24 | inf norm:  0.451 | loss: 3.06 | perp:  21.38
#  b 450/718 >> 2796.7 ms/b | lr:  5.43e-05 | grad norm:  3.93 | inf norm:  0.398 | loss: 3.11 | perp:  22.52
#  b 600/718 >> 2735.9 ms/b | lr: 4.608e-05 | grad norm:  4.24 | inf norm:  0.281 | loss: 3.07 | perp:  21.45
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1988.70 sec | train loss, perp: 3.106,  22.34    | valid loss, perp: 2.765,  15.88
# Grad norm: 11.196 | Grad inf. norm:  0.8508 | Max abs param:  0.6473
# ============================================================================================================
#
#
# Epoch  24/150) lr = 4.511e-05
#  b 150/713 >> 2829.2 ms/b | lr: 4.872e-05 | grad norm: 170.20 | inf norm:   24.7 | loss: 3.07 | perp:  21.63
#  b 300/713 >> 2766.6 ms/b | lr: 4.511e-05 | grad norm: 54.10 | inf norm:   1.69 | loss: 3.31 | perp:  27.35
#  b 450/713 >> 2770.9 ms/b | lr: 4.118e-05 | grad norm:  3.13 | inf norm:  0.408 | loss: 2.99 | perp:  19.79
#  b 600/713 >> 2786.8 ms/b | lr: 4.118e-05 | grad norm:  3.09 | inf norm:  0.216 | loss: 3.01 | perp:  20.37
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1996.52 sec | train loss, perp: 3.102,  22.23    | valid loss, perp: 2.701,  14.89
# Grad norm:  3.495 | Grad inf. norm:  0.3176 | Max abs param:  0.6487
# ============================================================================================================
#
#
# Epoch  25/150) lr = 4.419e-05
#  b 150/722 >> 2728.4 ms/b | lr: 4.541e-05 | grad norm: 197.00 | inf norm:   7.99 | loss: 3.12 | perp:  22.68
#  b 300/722 >> 2697.6 ms/b | lr: 4.034e-05 | grad norm:  4.39 | inf norm:  0.726 | loss: 3.02 | perp:  20.41
#  b 450/722 >> 2809.9 ms/b | lr: 4.658e-05 | grad norm: 26.66 | inf norm:   3.12 | loss: 3.04 | perp:  20.92
#  b 600/722 >> 2747.6 ms/b | lr: 4.295e-05 | grad norm:  3.84 | inf norm:  0.071 | loss: 2.93 | perp:  18.73
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1987.65 sec | train loss, perp: 3.034,  20.79    | valid loss, perp: 2.702,  14.91 :(
# Grad norm: 10.676 | Grad inf. norm:   1.808 | Max abs param:  0.6502
# ============================================================================================================
#
#
# Epoch  26/150) lr = 4.334e-05
#  b 150/715 >> 2833.1 ms/b | lr: 4.086e-05 | grad norm:  7.03 | inf norm:   1.27 | loss: 2.94 | perp:  18.95
#  b 300/715 >> 2774.0 ms/b | lr: 3.822e-05 | grad norm:  6.23 | inf norm:  0.382 | loss: 2.93 | perp:  18.81
#  b 450/715 >> 2717.6 ms/b | lr: 4.211e-05 | grad norm:  8.63 | inf norm:  0.785 | loss: 2.92 | perp:  18.52
#  b 600/715 >> 2761.5 ms/b | lr: 5.004e-05 | grad norm:  8.34 | inf norm:  0.293 | loss: 2.89 | perp:  17.92
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1987.68 sec | train loss, perp: 2.932,  18.77    | valid loss, perp: 2.573,  13.11
# Grad norm:  6.346 | Grad inf. norm:  0.5845 | Max abs param:  0.6523
# ============================================================================================================
#
#
# Epoch  27/150) lr = 4.253e-05
#  b 150/719 >> 2823.6 ms/b | lr: 4.009e-05 | grad norm: 70.76 | inf norm:   13.5 | loss: 2.92 | perp:  18.45
#  b 300/719 >> 2755.3 ms/b | lr: 4.253e-05 | grad norm: 37.27 | inf norm:   6.16 | loss: 2.85 | perp:  17.29
#  b 450/719 >> 2812.7 ms/b | lr: 4.133e-05 | grad norm:  7.37 | inf norm:  0.615 | loss: 2.91 | perp:  18.37
#  b 600/719 >> 2769.1 ms/b | lr: 3.882e-05 | grad norm:  4.10 | inf norm:  0.129 | loss: 2.86 | perp:  17.41
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1994.82 sec | train loss, perp: 2.889,  17.98    | valid loss, perp: 2.541,  12.69
# Grad norm:  3.855 | Grad inf. norm:  0.4949 | Max abs param:  0.6539
# ============================================================================================================
#
#
# Epoch  28/150) lr = 4.176e-05
#  b 150/720 >> 2728.4 ms/b | lr: 3.812e-05 | grad norm:  3.29 | inf norm:   0.36 | loss: 2.78 | perp:  16.13
#  b 300/720 >> 2787.6 ms/b | lr:  3.41e-05 | grad norm: 39.34 | inf norm:   7.13 | loss: 2.90 | perp:  18.09
#  b 450/720 >> 2781.0 ms/b | lr: 4.058e-05 | grad norm:  3.08 | inf norm:  0.372 | loss: 2.78 | perp:  16.10
#  b 600/720 >> 2758.9 ms/b | lr: 4.058e-05 | grad norm:  4.20 | inf norm:  0.245 | loss: 2.74 | perp:  15.47
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1985.48 sec | train loss, perp: 2.807,  16.55    | valid loss, perp: 2.489,  12.05
# Grad norm:  3.722 | Grad inf. norm:  0.4906 | Max abs param:  0.6555
# ============================================================================================================
#
#
# Epoch  29/150) lr = 4.103e-05
#  b 150/717 >> 2677.3 ms/b | lr: 4.103e-05 | grad norm: 56.12 | inf norm:   7.37 | loss: 2.79 | perp:  16.28
#  b 300/717 >> 2771.2 ms/b | lr: 4.216e-05 | grad norm: 14.76 | inf norm:  0.983 | loss: 2.78 | perp:  16.08
#  b 450/717 >> 2807.2 ms/b | lr: 3.869e-05 | grad norm:  3.41 | inf norm:   0.16 | loss: 2.72 | perp:  15.19
#  b 600/717 >> 2855.0 ms/b | lr: 3.487e-05 | grad norm:  6.27 | inf norm:   1.11 | loss: 2.74 | perp:  15.45
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 1991.77 sec | train loss, perp: 2.776,  16.05    | valid loss, perp: 2.445,  11.53
# Grad norm: 24.219 | Grad inf. norm:  0.4945 | Max abs param:  0.6576
# ============================================================================================================
#
#
# Epoch  30/150) lr = 4.034e-05
#  b 150/718 >> 2789.4 ms/b | lr: 4.145e-05 | grad norm:  7.43 | inf norm:   1.15 | loss: 2.74 | perp:  15.56
#  b 300/718 >> 2774.9 ms/b | lr: 4.034e-05 | grad norm:  2.59 | inf norm:  0.294 | loss: 2.71 | perp:  14.96
#  b 450/718 >> 2782.4 ms/b | lr: 3.429e-05 | grad norm:  5.46 | inf norm:  0.873 | loss: 2.75 | perp:  15.57
#  b 600/718 >> 3145.1 ms/b | lr: 3.921e-05 | grad norm:  8.20 | inf norm:   1.12 | loss: 2.72 | perp:  15.19
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2100.89 sec | train loss, perp: 2.733,  15.37    | valid loss, perp: 2.389,  10.91
# Grad norm:  5.531 | Grad inf. norm:  0.4976 | Max abs param:  0.6592
# ============================================================================================================
#
#
# Epoch  31/150) lr = 3.969e-05
#  b 150/718 >> 3220.1 ms/b | lr: 3.623e-05 | grad norm: 155.96 | inf norm:   18.2 | loss: 2.64 | perp:  14.04
#  b 300/718 >> 3197.3 ms/b | lr: 3.969e-05 | grad norm: 35.48 | inf norm:    4.9 | loss: 2.72 | perp:  15.25
#  b 450/718 >> 3325.0 ms/b | lr: 4.078e-05 | grad norm:  2.60 | inf norm:  0.166 | loss: 2.71 | perp:  14.99
#  b 600/718 >> 3208.8 ms/b | lr: 4.583e-05 | grad norm: 13.84 | inf norm:   2.26 | loss: 2.69 | perp:  14.73
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2309.01 sec | train loss, perp: 2.703,  14.92    | valid loss, perp: 2.445,  11.53 :(
# Grad norm: 12.645 | Grad inf. norm:  0.8904 | Max abs param:  0.6607
# ============================================================================================================
#
#
# Epoch  32/150) lr = 3.906e-05
#  b 150/721 >> 3239.4 ms/b | lr: 3.796e-05 | grad norm: 38.53 | inf norm:   2.26 | loss: 2.68 | perp:  14.61
#  b 300/721 >> 3123.1 ms/b | lr: 4.219e-05 | grad norm: 14.05 | inf norm:   2.14 | loss: 2.58 | perp:  13.25
#  b 450/721 >> 3279.1 ms/b | lr: 4.319e-05 | grad norm:  6.68 | inf norm:   1.03 | loss: 2.59 | perp:  13.31
#  b 600/721 >> 3135.9 ms/b | lr: 3.566e-05 | grad norm:  3.10 | inf norm:  0.326 | loss: 2.61 | perp:  13.57
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2288.54 sec | train loss, perp: 2.614,  13.65    | valid loss, perp: 2.289,   9.86
# Grad norm:  3.014 | Grad inf. norm:  0.1417 | Max abs param:  0.6618
# ============================================================================================================
#
#
# Epoch  33/150) lr = 3.847e-05
#  b 150/718 >> 3021.8 ms/b | lr: 3.738e-05 | grad norm: 10.05 | inf norm:   1.49 | loss: 2.73 | perp:  15.26
#  b 300/718 >> 3261.1 ms/b | lr: 3.627e-05 | grad norm:  3.28 | inf norm:  0.446 | loss: 2.60 | perp:  13.44
#  b 450/718 >> 3168.2 ms/b | lr: 3.738e-05 | grad norm: 14.14 | inf norm:   1.62 | loss: 2.63 | perp:  13.88
#  b 600/718 >> 3191.8 ms/b | lr: 3.627e-05 | grad norm: 36.80 | inf norm:   5.78 | loss: 2.66 | perp:  14.26
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2268.12 sec | train loss, perp: 2.685,  14.66 :( | valid loss, perp: 2.272,   9.70
# Grad norm:  5.997 | Grad inf. norm:    0.25 | Max abs param:  0.6628
# ============================================================================================================
#
#
# Epoch  34/150) lr = 3.79e-05
#  b 150/714 >> 3245.0 ms/b | lr: 3.573e-05 | grad norm: 28.82 | inf norm:   4.63 | loss: 2.75 | perp:  15.69
#  b 300/714 >> 3193.4 ms/b | lr: 3.893e-05 | grad norm:  9.63 | inf norm:   1.21 | loss: 2.57 | perp:  13.12
#  b 450/714 >> 3194.9 ms/b | lr:  3.79e-05 | grad norm:  6.92 | inf norm:  0.632 | loss: 2.78 | perp:  16.14
#  b 600/714 >> 3236.7 ms/b | lr: 3.573e-05 | grad norm:  4.28 | inf norm:  0.207 | loss: 2.65 | perp:  14.09
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2298.74 sec | train loss, perp: 2.675,  14.52 :( | valid loss, perp: 2.240,   9.39
# Grad norm:  4.012 | Grad inf. norm:  0.1093 | Max abs param:  0.6638
# ============================================================================================================
#
#
# Epoch  35/150) lr = 3.735e-05
#  b 150/713 >> 3156.9 ms/b | lr: 3.837e-05 | grad norm:  4.18 | inf norm:  0.673 | loss: 2.58 | perp:  13.19
#  b 300/713 >> 3092.1 ms/b | lr: 3.735e-05 | grad norm:  2.34 | inf norm:  0.101 | loss: 2.62 | perp:  13.71
#  b 450/713 >> 3049.3 ms/b | lr: 4.313e-05 | grad norm: 34.42 | inf norm:   6.26 | loss: 2.59 | perp:  13.38
#  b 600/713 >> 3046.4 ms/b | lr: 3.937e-05 | grad norm:  3.24 | inf norm:  0.459 | loss: 2.58 | perp:  13.26
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2203.63 sec | train loss, perp: 2.599,  13.45    | valid loss, perp: 2.201,   9.04
# Grad norm:  4.555 | Grad inf. norm:  0.6311 | Max abs param:   0.665
# ============================================================================================================
#
#
# Epoch  36/150) lr = 3.683e-05
#  b 150/717 >> 2968.3 ms/b | lr: 3.978e-05 | grad norm: 23.47 | inf norm:   3.49 | loss: 2.52 | perp:  12.39
#  b 300/717 >> 3030.8 ms/b | lr: 3.683e-05 | grad norm:  4.41 | inf norm:  0.598 | loss: 2.47 | perp:  11.87
#  b 450/717 >> 3105.1 ms/b | lr:  3.13e-05 | grad norm:  9.76 | inf norm:   1.56 | loss: 2.45 | perp:  11.63
#  b 600/717 >> 3116.4 ms/b | lr: 3.579e-05 | grad norm: 51.13 | inf norm:   6.61 | loss: 2.55 | perp:  12.84
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2187.29 sec | train loss, perp: 2.509,  12.30    | valid loss, perp: 2.172,   8.78
# Grad norm: 32.648 | Grad inf. norm:   4.917 | Max abs param:  0.6661
# ============================================================================================================
#
#
# Epoch  37/150) lr = 3.633e-05
#  b 150/713 >> 3036.4 ms/b | lr: 3.316e-05 | grad norm:  3.27 | inf norm: 0.0677 | loss: 2.66 | perp:  14.24
#  b 300/713 >> 3251.6 ms/b | lr: 3.425e-05 | grad norm: 11.84 | inf norm:   1.26 | loss: 2.42 | perp:  11.28
#  b 450/713 >> 3141.8 ms/b | lr: 3.316e-05 | grad norm:  8.52 | inf norm:   1.36 | loss: 2.41 | perp:  11.16
#  b 600/713 >> 3301.6 ms/b | lr: 3.924e-05 | grad norm: 12.23 | inf norm:   2.28 | loss: 2.42 | perp:  11.25
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2290.26 sec | train loss, perp: 2.483,  11.97    | valid loss, perp: 2.125,   8.37
# Grad norm:  2.860 | Grad inf. norm:  0.2566 | Max abs param:  0.6674
# ============================================================================================================
#
#
# Epoch  38/150) lr = 3.585e-05
#  b 150/716 >> 3190.2 ms/b | lr: 3.272e-05 | grad norm:  6.10 | inf norm:   0.59 | loss: 2.44 | perp:  11.44
#  b 300/716 >> 2989.9 ms/b | lr:  3.38e-05 | grad norm:  8.94 | inf norm:   1.32 | loss: 2.52 | perp:  12.45
#  b 450/716 >> 3076.7 ms/b | lr: 4.139e-05 | grad norm: 20.76 | inf norm:   3.75 | loss: 2.61 | perp:  13.60
#  b 600/716 >> 3141.8 ms/b | lr:  3.38e-05 | grad norm: 10.85 | inf norm:   1.81 | loss: 2.47 | perp:  11.83
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2222.09 sec | train loss, perp: 2.524,  12.48 :( | valid loss, perp: 2.105,   8.21
# Grad norm: 17.920 | Grad inf. norm:   2.145 | Max abs param:  0.6681
# ============================================================================================================
#
#
# Epoch  39/150) lr = 3.538e-05
#  b 150/712 >> 3147.9 ms/b | lr: 3.912e-05 | grad norm: 17.60 | inf norm:   1.86 | loss: 2.53 | perp:  12.52
#  b 300/712 >> 3131.9 ms/b | lr: 3.538e-05 | grad norm: 12.60 | inf norm:   1.68 | loss: 2.39 | perp:  10.91
#  b 450/712 >> 3147.8 ms/b | lr:  3.73e-05 | grad norm:  2.32 | inf norm: 0.0546 | loss: 2.44 | perp:  11.47
#  b 600/712 >> 3087.7 ms/b | lr: 3.635e-05 | grad norm:  7.62 | inf norm:  0.891 | loss: 2.35 | perp:  10.50
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2210.21 sec | train loss, perp: 2.452,  11.61    | valid loss, perp: 2.100,   8.16
# Grad norm:  4.411 | Grad inf. norm:  0.3897 | Max abs param:   0.669
# ============================================================================================================
# Epoch  40/150) lr = 3.494e-05
#  b 150/722 >> 3031.3 ms/b | lr: 3.395e-05 | grad norm:  8.80 | inf norm:   1.11 | loss: 2.55 | perp:  12.81
#  b 300/722 >> 3081.5 ms/b | lr: 3.395e-05 | grad norm:  4.25 | inf norm:  0.312 | loss: 2.40 | perp:  11.03
#  b 450/722 >> 3248.7 ms/b | lr: 3.863e-05 | grad norm: 12.30 | inf norm:   1.36 | loss: 2.36 | perp:  10.60
#  b 600/722 >> 3134.4 ms/b | lr:  3.59e-05 | grad norm:  3.06 | inf norm:  0.325 | loss: 2.43 | perp:  11.39
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2314.26 sec | train loss, perp: 2.433,  11.40    | valid loss, perp: 2.239,   9.38 :(
# Grad norm: 19.440 | Grad inf. norm:   2.341 | Max abs param:  0.6699
# ============================================================================================================
#
#
# Epoch  41/150) lr = 3.451e-05
#  b 150/721 >> 3671.0 ms/b | lr: 3.254e-05 | grad norm:  2.85 | inf norm:  0.304 | loss: 2.59 | perp:  13.32
#  b 300/721 >> 3449.2 ms/b | lr: 3.546e-05 | grad norm:  4.56 | inf norm:  0.141 | loss: 2.42 | perp:  11.25
#  b 450/721 >> 3378.6 ms/b | lr: 3.638e-05 | grad norm:  6.01 | inf norm:   0.62 | loss: 2.32 | perp:  10.21
#  b 600/721 >> 3593.3 ms/b | lr: 3.451e-05 | grad norm:  2.72 | inf norm: 0.0907 | loss: 2.31 | perp:  10.03
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2526.08 sec | train loss, perp: 2.411,  11.15    | valid loss, perp: 2.027,   7.59
# Grad norm: 27.001 | Grad inf. norm:   2.089 | Max abs param:  0.6706
# ============================================================================================================
#
#
# Epoch  42/150) lr = 3.41e-05
#  b 150/723 >> 3374.5 ms/b | lr: 3.215e-05 | grad norm:  5.21 | inf norm:  0.549 | loss: 2.43 | perp:  11.32
#  b 300/723 >> 3494.5 ms/b | lr:  3.41e-05 | grad norm:  6.64 | inf norm:  0.901 | loss: 2.28 | perp:   9.73
#  b 450/723 >> 3529.5 ms/b | lr: 2.784e-05 | grad norm: 38.70 | inf norm:   4.29 | loss: 2.35 | perp:  10.49
#  b 600/723 >> 3707.0 ms/b | lr:  3.77e-05 | grad norm:  9.57 | inf norm:   1.74 | loss: 2.29 | perp:   9.92
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2579.38 sec | train loss, perp: 2.363,  10.62    | valid loss, perp: 2.011,   7.47
# Grad norm:  9.763 | Grad inf. norm:  0.5997 | Max abs param:  0.6714
# ============================================================================================================
#
#
# Epoch  43/150) lr = 3.37e-05
#  b 150/720 >> 3717.5 ms/b | lr: 3.177e-05 | grad norm:  3.39 | inf norm:  0.333 | loss: 2.36 | perp:  10.63
#  b 300/720 >> 3499.5 ms/b | lr: 3.275e-05 | grad norm:  2.70 | inf norm: 0.0774 | loss: 2.24 | perp:   9.39
#  b 450/720 >> 3723.1 ms/b | lr: 3.177e-05 | grad norm: 10.73 | inf norm:   1.36 | loss: 2.37 | perp:  10.67
#  b 600/720 >> 4166.0 ms/b | lr: 3.275e-05 | grad norm:  8.08 | inf norm:   1.21 | loss: 2.30 | perp:   9.95
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2710.98 sec | train loss, perp: 2.328,  10.25    | valid loss, perp: 1.993,   7.34
# Grad norm: 12.459 | Grad inf. norm:   1.322 | Max abs param:  0.6727
# ============================================================================================================
#
#
# Epoch  44/150) lr = 3.331e-05
#  b 150/714 >> 4023.6 ms/b | lr: 3.141e-05 | grad norm:  3.00 | inf norm:  0.298 | loss: 2.39 | perp:  10.94
#  b 300/714 >> 3722.9 ms/b | lr: 3.331e-05 | grad norm:  4.87 | inf norm:  0.818 | loss: 2.31 | perp:  10.07
#  b 450/714 >> 3836.2 ms/b | lr: 3.141e-05 | grad norm:  4.48 | inf norm:   0.54 | loss: 2.39 | perp:  10.88
#  b 600/714 >> 3884.7 ms/b | lr: 3.598e-05 | grad norm:  5.69 | inf norm:  0.858 | loss: 2.28 | perp:   9.78
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2750.14 sec | train loss, perp: 2.346,  10.45 :( | valid loss, perp: 1.973,   7.19
# Grad norm:  2.447 | Grad inf. norm: 0.05499 | Max abs param:  0.6736
# ============================================================================================================
#
#
# Epoch  45/150) lr = 3.294e-05
#  b 150/715 >> 3742.6 ms/b | lr: 3.201e-05 | grad norm:  3.87 | inf norm:  0.118 | loss: 2.35 | perp:  10.48
#  b 300/715 >> 3649.5 ms/b | lr: 2.905e-05 | grad norm:  5.23 | inf norm:  0.709 | loss: 2.25 | perp:   9.50
#  b 450/715 >> 3916.5 ms/b | lr: 3.201e-05 | grad norm:  3.93 | inf norm: 0.0864 | loss: 2.27 | perp:   9.71
#  b 600/715 >> 3772.6 ms/b | lr: 3.201e-05 | grad norm: 12.10 | inf norm:   1.82 | loss: 2.31 | perp:  10.10
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2705.81 sec | train loss, perp: 2.323,  10.20    | valid loss, perp: 1.948,   7.01
# Grad norm:  2.824 | Grad inf. norm:  0.1004 | Max abs param:  0.6744
# ============================================================================================================
#
#
# Epoch  46/150) lr = 3.258e-05
#  b 150/710 >> 4113.6 ms/b | lr: 3.347e-05 | grad norm:  3.06 | inf norm:  0.336 | loss: 2.30 | perp:   9.98
#  b 300/710 >> 4291.2 ms/b | lr: 3.434e-05 | grad norm:  3.60 | inf norm:  0.471 | loss: 2.20 | perp:   9.01
#  b 450/710 >> 4044.2 ms/b | lr: 3.347e-05 | grad norm:  2.34 | inf norm:  0.093 | loss: 2.15 | perp:   8.59
#  b 600/710 >> 3945.2 ms/b | lr: 3.683e-05 | grad norm: 15.21 | inf norm:   3.09 | loss: 2.43 | perp:  11.41
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2877.36 sec | train loss, perp: 2.288,   9.85    | valid loss, perp: 1.923,   6.84
# Grad norm:  8.029 | Grad inf. norm:  0.3515 | Max abs param:  0.6752
# ============================================================================================================
#
#
# Epoch  47/150) lr = 3.223e-05
#  b 150/716 >> 3807.4 ms/b | lr: 3.312e-05 | grad norm:  3.20 | inf norm:  0.315 | loss: 2.26 | perp:   9.62
#  b 300/716 >> 3963.5 ms/b | lr: 3.223e-05 | grad norm:  6.31 | inf norm:  0.471 | loss: 2.12 | perp:   8.30
#  b 450/716 >> 3786.5 ms/b | lr: 3.398e-05 | grad norm:  2.95 | inf norm:  0.396 | loss: 2.28 | perp:   9.75
#  b 600/716 >> 4008.5 ms/b | lr: 3.481e-05 | grad norm: 12.63 | inf norm:   1.51 | loss: 2.23 | perp:   9.29
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2794.13 sec | train loss, perp: 2.240,   9.39    | valid loss, perp: 1.938,   6.94 :(
# Grad norm: 21.809 | Grad inf. norm:   2.808 | Max abs param:  0.6763
# ============================================================================================================
#
#
# Epoch  48/150) lr = 3.189e-05
#  b 150/722 >> 3440.7 ms/b | lr: 3.007e-05 | grad norm:  3.38 | inf norm:  0.353 | loss: 2.22 | perp:   9.22
#  b 300/722 >> 3161.8 ms/b | lr: 3.277e-05 | grad norm: 26.28 | inf norm:   2.42 | loss: 2.32 | perp:  10.18
#  b 450/722 >> 3179.1 ms/b | lr: 3.189e-05 | grad norm:  4.00 | inf norm:  0.547 | loss: 2.16 | perp:   8.70
#  b 600/722 >> 3164.9 ms/b | lr: 3.445e-05 | grad norm: 13.06 | inf norm:   2.09 | loss: 2.16 | perp:   8.67
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2337.03 sec | train loss, perp: 2.222,   9.23    | valid loss, perp: 1.889,   6.61
# Grad norm:  3.472 | Grad inf. norm:  0.3457 | Max abs param:  0.6766
# ============================================================================================================
#
#
# Epoch  49/150) lr = 3.157e-05
#  b 150/725 >> 3243.8 ms/b | lr: 3.645e-05 | grad norm:  2.25 | inf norm: 0.0809 | loss: 2.26 | perp:   9.61
#  b 300/725 >> 3259.3 ms/b | lr: 2.976e-05 | grad norm:  2.41 | inf norm: 0.0609 | loss: 2.13 | perp:   8.44
#  b 450/725 >> 3281.8 ms/b | lr: 2.683e-05 | grad norm:  5.21 | inf norm:  0.718 | loss: 2.20 | perp:   9.03
#  b 600/725 >> 3432.7 ms/b | lr: 2.577e-05 | grad norm:  6.53 | inf norm:   1.18 | loss: 2.26 | perp:   9.62
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2404.50 sec | train loss, perp: 2.227,   9.28 :( | valid loss, perp: 1.912,   6.77 :(
# Grad norm:  5.078 | Grad inf. norm:  0.4541 | Max abs param:   0.677
# ============================================================================================================
#
#
# Epoch  50/150) lr = 3.125e-05
#  b 150/712 >> 3485.1 ms/b | lr: 3.294e-05 | grad norm:  6.85 | inf norm:   0.27 | loss: 2.19 | perp:   8.98
#  b 300/712 >> 3482.8 ms/b | lr: 3.037e-05 | grad norm:  2.61 | inf norm: 0.0861 | loss: 2.25 | perp:   9.49
#  b 450/712 >> 3785.1 ms/b | lr: 3.211e-05 | grad norm: 20.59 | inf norm:   2.49 | loss: 2.30 | perp:  10.01
#  b 600/712 >> 3809.9 ms/b | lr: 2.853e-05 | grad norm: 21.18 | inf norm:  0.799 | loss: 2.37 | perp:  10.65
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2618.37 sec | train loss, perp: 2.263,   9.62 :( | valid loss, perp: 1.885,   6.59
# Grad norm: 30.669 | Grad inf. norm:   4.482 | Max abs param:  0.6777
# ============================================================================================================
#
#
# Epoch  51/150) lr = 3.094e-05
#  b 150/723 >> 3837.2 ms/b | lr: 3.262e-05 | grad norm:  2.65 | inf norm:  0.054 | loss: 2.24 | perp:   9.37
#  b 300/723 >> 4297.9 ms/b | lr: 2.526e-05 | grad norm: 10.57 | inf norm:    2.2 | loss: 2.05 | perp:   7.76
#  b 450/723 >> 4179.8 ms/b | lr: 3.342e-05 | grad norm:  3.65 | inf norm:  0.589 | loss: 2.18 | perp:   8.84
#  b 600/723 >> 3913.1 ms/b | lr: 3.094e-05 | grad norm:  6.90 | inf norm:  0.865 | loss: 2.09 | perp:   8.06
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2939.41 sec | train loss, perp: 2.134,   8.44    | valid loss, perp: 1.844,   6.32
# Grad norm:  2.836 | Grad inf. norm: 0.07089 | Max abs param:  0.6782
# ============================================================================================================
#
#
# Epoch  52/150) lr = 3.064e-05
#  b 150/716 >> 4276.5 ms/b | lr:  3.31e-05 | grad norm:  8.70 | inf norm:  0.187 | loss: 2.21 | perp:   9.09
#  b 300/716 >> 3960.7 ms/b | lr: 3.388e-05 | grad norm: 14.24 | inf norm:   1.95 | loss: 2.16 | perp:   8.67
#  b 450/716 >> 3915.7 ms/b | lr: 3.148e-05 | grad norm:  3.17 | inf norm:  0.174 | loss: 2.17 | perp:   8.73
#  b 600/716 >> 3629.2 ms/b | lr:  3.31e-05 | grad norm:  7.60 | inf norm:  0.423 | loss: 2.05 | perp:   7.78
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2787.00 sec | train loss, perp: 2.158,   8.65 :( | valid loss, perp: 1.832,   6.25
# Grad norm:  4.689 | Grad inf. norm:  0.2064 | Max abs param:   0.679
# ============================================================================================================
#
#
# Epoch  53/150) lr = 3.035e-05
#  b 150/718 >> 3561.2 ms/b | lr: 2.677e-05 | grad norm:  3.93 | inf norm:  0.588 | loss: 2.15 | perp:   8.60
#  b 300/718 >> 3701.5 ms/b | lr: 3.278e-05 | grad norm:  9.83 | inf norm:   1.36 | loss: 2.08 | perp:   8.00
#  b 450/718 >> 3642.0 ms/b | lr: 3.035e-05 | grad norm:  9.65 | inf norm:  0.866 | loss: 2.06 | perp:   7.88
#  b 600/718 >> 3813.3 ms/b | lr: 3.199e-05 | grad norm: 17.18 | inf norm:   2.95 | loss: 2.09 | perp:   8.05
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2675.52 sec | train loss, perp: 2.106,   8.21    | valid loss, perp: 1.819,   6.17
# Grad norm: 19.830 | Grad inf. norm:   3.798 | Max abs param:  0.6797
# ============================================================================================================
#
#
# Epoch  54/150) lr = 3.007e-05
#  b 150/716 >> 4009.2 ms/b | lr: 3.007e-05 | grad norm:  4.41 | inf norm:  0.443 | loss: 2.11 | perp:   8.28
#  b 300/716 >> 4305.2 ms/b | lr: 2.745e-05 | grad norm:  8.38 | inf norm:   1.27 | loss: 2.24 | perp:   9.43
#  b 450/716 >> 4226.5 ms/b | lr: 3.089e-05 | grad norm: 24.64 | inf norm:   3.56 | loss: 2.26 | perp:   9.55
#  b 600/716 >> 4373.6 ms/b | lr: 2.922e-05 | grad norm:  2.59 | inf norm:  0.205 | loss: 2.09 | perp:   8.12
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 3040.17 sec | train loss, perp: 2.200,   9.03 :( | valid loss, perp: 1.815,   6.14
# Grad norm:  6.400 | Grad inf. norm:  0.6509 | Max abs param:  0.6801
# ============================================================================================================
#
#
# Epoch  55/150) lr = 2.98e-05
#  b 150/714 >> 4388.7 ms/b | lr: 3.294e-05 | grad norm:  7.71 | inf norm:   1.03 | loss: 2.11 | perp:   8.24
#  b 300/714 >> 4503.8 ms/b | lr: 3.218e-05 | grad norm:  2.89 | inf norm:  0.354 | loss: 2.04 | perp:   7.72
#  b 450/714 >> 4508.3 ms/b | lr: 2.433e-05 | grad norm: 15.57 | inf norm:    2.7 | loss: 2.09 | perp:   8.07
#  b 600/714 >> 4781.0 ms/b | lr: 3.368e-05 | grad norm: 124.84 | inf norm:   20.8 | loss: 2.12 | perp:   8.32
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 3238.21 sec | train loss, perp: 2.098,   8.15    | valid loss, perp: 1.781,   5.94
# Grad norm:  2.621 | Grad inf. norm: 0.06254 | Max abs param:  0.6807
# ============================================================================================================
#
#
# Epoch  56/150) lr = 2.953e-05
#  b 150/716 >> 4493.6 ms/b | lr: 2.604e-05 | grad norm:  3.17 | inf norm:   0.31 | loss: 2.07 | perp:   7.96
#  b 300/716 >> 4329.3 ms/b | lr: 3.034e-05 | grad norm:  3.58 | inf norm: 0.0648 | loss: 2.03 | perp:   7.63
#  b 450/716 >> 4392.8 ms/b | lr: 2.784e-05 | grad norm:  6.23 | inf norm:  0.858 | loss: 2.01 | perp:   7.44
#  b 600/716 >> 4335.5 ms/b | lr: 2.784e-05 | grad norm:  2.84 | inf norm:  0.227 | loss: 2.09 | perp:   8.12
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 3139.52 sec | train loss, perp: 2.063,   7.87    | valid loss, perp: 1.760,   5.81
# Grad norm: 79.653 | Grad inf. norm:   11.86 | Max abs param:  0.6811
# ============================================================================================================
#
#
# Epoch  57/150) lr = 2.927e-05
#  b 150/720 >> 4514.3 ms/b | lr: 3.007e-05 | grad norm: 10.82 | inf norm:   1.49 | loss: 2.08 | perp:   8.04
#  b 300/720 >> 4371.8 ms/b | lr: 3.007e-05 | grad norm:  6.64 | inf norm:  0.378 | loss: 2.04 | perp:   7.73
# ...
#  b 450/722 >> 3648.3 ms/b | lr: 1.976e-05 | grad norm:  8.64 | inf norm:  0.608 | loss: 1.57 | perp:   4.83
#  b 600/722 >> 3581.1 ms/b | lr: 2.027e-05 | grad norm:  6.18 | inf norm:    0.6 | loss: 1.62 | perp:   5.07
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2601.45 sec | train loss, perp: 1.596,   4.93 :( | valid loss, perp: 1.334,   3.80
# Grad norm:  2.347 | Grad inf. norm: 0.09532 | Max abs param:  0.8161
# ============================================================================================================
#
#
# Epoch 133/150) lr = 1.916e-05
#  b 150/719 >> 3579.6 ms/b | lr: 1.628e-05 | grad norm:  3.90 | inf norm:   0.47 | loss: 1.63 | perp:   5.11
#  b 300/719 >> 3677.6 ms/b | lr:  2.02e-05 | grad norm: 11.07 | inf norm:  0.214 | loss: 1.53 | perp:   4.61
#  b 450/719 >> 3481.6 ms/b | lr:  1.69e-05 | grad norm:  2.79 | inf norm:  0.109 | loss: 1.47 | perp:   4.37
#  b 600/719 >> 3570.7 ms/b | lr: 1.862e-05 | grad norm:  2.66 | inf norm:  0.153 | loss: 1.54 | perp:   4.66
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2552.21 sec | train loss, perp: 1.541,   4.67    | valid loss, perp: 1.327,   3.77
# Grad norm:  2.725 | Grad inf. norm: 0.06915 | Max abs param:  0.8186
# ============================================================================================================
#
#
# Epoch 134/150) lr = 1.909e-05
#  b 150/724 >> 3288.0 ms/b | lr: 2.012e-05 | grad norm:  5.21 | inf norm:  0.122 | loss: 1.62 | perp:   5.08
#  b 300/724 >> 3343.1 ms/b | lr: 1.909e-05 | grad norm:  2.42 | inf norm: 0.0737 | loss: 1.56 | perp:   4.74
#  b 450/724 >> 3293.7 ms/b | lr: 1.492e-05 | grad norm: 21.06 | inf norm:   3.53 | loss: 1.51 | perp:   4.55
#  b 600/724 >> 3384.8 ms/b | lr: 1.855e-05 | grad norm:  5.88 | inf norm:  0.602 | loss: 1.55 | perp:   4.73
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2406.46 sec | train loss, perp: 1.559,   4.75 :( | valid loss, perp: 1.324,   3.76
# Grad norm:  2.548 | Grad inf. norm:  0.1022 | Max abs param:   0.821
# ============================================================================================================
#
#
# Epoch 135/150) lr = 1.902e-05
#  b 150/722 >> 3348.1 ms/b | lr: 1.736e-05 | grad norm: 17.84 | inf norm:   2.36 | loss: 1.56 | perp:   4.77
#  b 300/722 >> 3353.2 ms/b | lr: 2.196e-05 | grad norm: 43.51 | inf norm:   7.15 | loss: 1.53 | perp:   4.62
#  b 450/722 >> 3346.7 ms/b | lr: 1.902e-05 | grad norm:  2.65 | inf norm:  0.149 | loss: 1.50 | perp:   4.49
#  b 600/722 >> 3361.4 ms/b | lr: 1.793e-05 | grad norm:  9.11 | inf norm:   1.13 | loss: 1.54 | perp:   4.69
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2412.30 sec | train loss, perp: 1.548,   4.70 :( | valid loss, perp: 1.335,   3.80 :(
# Grad norm:  2.990 | Grad inf. norm: 0.06472 | Max abs param:  0.8238
# ============================================================================================================
#
#
# Epoch 136/150) lr = 1.895e-05
#  b 150/723 >> 3327.9 ms/b | lr: 2.095e-05 | grad norm:  4.94 | inf norm:  0.306 | loss: 1.63 | perp:   5.10
#  b 300/723 >> 3269.0 ms/b | lr: 1.671e-05 | grad norm:  3.96 | inf norm:  0.301 | loss: 1.53 | perp:   4.64
#  b 450/723 >> 3294.0 ms/b | lr: 1.841e-05 | grad norm:  2.38 | inf norm: 0.0741 | loss: 1.56 | perp:   4.76
#  b 600/723 >> 3309.9 ms/b | lr: 1.671e-05 | grad norm: 394.67 | inf norm:   43.3 | loss: 1.53 | perp:   4.62
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2386.18 sec | train loss, perp: 1.571,   4.81 :( | valid loss, perp: 1.326,   3.77 :(
# Grad norm:  2.625 | Grad inf. norm: 0.08324 | Max abs param:  0.8255
# ============================================================================================================
#
#
# Epoch 137/150) lr = 1.888e-05
#  b 150/711 >> 3259.6 ms/b | lr: 1.835e-05 | grad norm:  2.45 | inf norm: 0.0668 | loss: 1.51 | perp:   4.51
#  b 300/711 >> 3399.6 ms/b | lr: 1.835e-05 | grad norm:  2.67 | inf norm: 0.0719 | loss: 1.62 | perp:   5.05
#  b 450/711 >> 3415.5 ms/b | lr: 1.665e-05 | grad norm:  4.52 | inf norm:  0.367 | loss: 1.52 | perp:   4.57
#  b 600/711 >> 3420.0 ms/b | lr: 1.723e-05 | grad norm:  2.71 | inf norm:  0.101 | loss: 1.49 | perp:   4.44
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2409.45 sec | train loss, perp: 1.524,   4.59    | valid loss, perp: 1.316,   3.73
# Grad norm:  3.187 | Grad inf. norm: 0.07819 | Max abs param:  0.8275
# ============================================================================================================
#
#
# Epoch 138/150) lr = 1.881e-05
#  b 150/718 >> 3360.3 ms/b | lr: 1.983e-05 | grad norm:  3.13 | inf norm:  0.224 | loss: 1.75 | perp:   5.78
#  b 300/718 >> 3329.4 ms/b | lr: 1.659e-05 | grad norm:  2.87 | inf norm: 0.0826 | loss: 1.49 | perp:   4.45
#  b 450/718 >> 3243.4 ms/b | lr: 2.032e-05 | grad norm:  7.07 | inf norm:   0.92 | loss: 1.47 | perp:   4.35
#  b 600/718 >> 3401.3 ms/b | lr: 1.983e-05 | grad norm:  4.00 | inf norm:   0.36 | loss: 1.65 | perp:   5.21
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2391.59 sec | train loss, perp: 1.598,   4.94 :( | valid loss, perp: 1.320,   3.74 :(
# Grad norm: 13.291 | Grad inf. norm:    1.44 | Max abs param:  0.8292
# ============================================================================================================
#
#
# Epoch 139/150) lr = 1.874e-05
#  b 150/719 >> 3326.8 ms/b | lr: 1.653e-05 | grad norm:  3.00 | inf norm:  0.131 | loss: 1.56 | perp:   4.78
#  b 300/719 >> 3358.3 ms/b | lr: 1.926e-05 | grad norm:  2.52 | inf norm: 0.0969 | loss: 1.55 | perp:   4.69
#  b 450/719 >> 3359.0 ms/b | lr: 1.976e-05 | grad norm:  3.85 | inf norm:  0.397 | loss: 1.61 | perp:   5.00
#  b 600/719 >> 3213.4 ms/b | lr: 1.926e-05 | grad norm:  2.21 | inf norm:  0.079 | loss: 1.53 | perp:   4.63
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2392.74 sec | train loss, perp: 1.575,   4.83 :( | valid loss, perp: 1.323,   3.75 :(
# Grad norm:  2.599 | Grad inf. norm:  0.1047 | Max abs param:  0.8314
# ============================================================================================================
#
#
# Epoch 140/150) lr = 1.868e-05
#  b 150/718 >> 3267.8 ms/b | lr: 1.705e-05 | grad norm:  2.99 | inf norm: 0.0836 | loss: 1.53 | perp:   4.60
#  b 300/718 >> 3324.3 ms/b | lr: 1.919e-05 | grad norm:  2.55 | inf norm: 0.0659 | loss: 1.50 | perp:   4.47
#  b 450/718 >> 3324.7 ms/b | lr: 1.705e-05 | grad norm:  3.30 | inf norm:   0.27 | loss: 1.48 | perp:   4.40
#  b 600/718 >> 3393.9 ms/b | lr: 1.868e-05 | grad norm:  2.46 | inf norm: 0.0991 | loss: 1.50 | perp:   4.49
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2391.20 sec | train loss, perp: 1.513,   4.54    | valid loss, perp: 1.315,   3.73
# Grad norm:  2.586 | Grad inf. norm: 0.06741 | Max abs param:  0.8345
# ============================================================================================================
#
#
# Epoch 141/150) lr = 1.861e-05
#  b 150/718 >> 3364.2 ms/b | lr: 1.581e-05 | grad norm: 23.92 | inf norm:   1.87 | loss: 1.52 | perp:   4.59
#  b 300/718 >> 3336.9 ms/b | lr: 1.861e-05 | grad norm:  2.81 | inf norm:  0.193 | loss: 1.54 | perp:   4.68
#  b 450/718 >> 3336.5 ms/b | lr: 1.754e-05 | grad norm:  2.56 | inf norm: 0.0975 | loss: 1.50 | perp:   4.47
#  b 600/718 >> 3397.6 ms/b | lr: 1.581e-05 | grad norm:  3.82 | inf norm:  0.228 | loss: 1.51 | perp:   4.54
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2366.08 sec | train loss, perp: 1.525,   4.60 :( | valid loss, perp: 1.310,   3.71
# Grad norm:  2.683 | Grad inf. norm: 0.09625 | Max abs param:  0.8368
# ============================================================================================================
#
#
# Epoch 142/150) lr = 1.854e-05
#  b 150/723 >> 3069.3 ms/b | lr: 1.955e-05 | grad norm: 10.67 | inf norm:    1.3 | loss: 1.59 | perp:   4.89
#  b 300/723 >> 3150.9 ms/b | lr: 1.854e-05 | grad norm:  2.62 | inf norm: 0.0871 | loss: 1.47 | perp:   4.34
#  b 450/723 >> 3100.0 ms/b | lr: 1.955e-05 | grad norm:  2.74 | inf norm:   0.15 | loss: 1.48 | perp:   4.39
#  b 600/723 >> 3101.5 ms/b | lr: 1.748e-05 | grad norm:  2.56 | inf norm: 0.0646 | loss: 1.53 | perp:   4.62
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2261.78 sec | train loss, perp: 1.525,   4.59 :( | valid loss, perp: 1.311,   3.71 :(
# Grad norm:  2.905 | Grad inf. norm:  0.2015 | Max abs param:  0.8385
# ============================================================================================================
#
#
# Epoch 143/150) lr = 1.848e-05
#  b 150/717 >> 3106.3 ms/b | lr: 1.742e-05 | grad norm:  2.55 | inf norm: 0.0751 | loss: 1.58 | perp:   4.84
#  b 300/717 >> 3037.1 ms/b | lr: 1.742e-05 | grad norm:  2.86 | inf norm:  0.158 | loss: 1.51 | perp:   4.55
#  b 450/717 >> 3105.9 ms/b | lr: 1.848e-05 | grad norm:  2.48 | inf norm: 0.0993 | loss: 1.51 | perp:   4.53
#  b 600/717 >> 3088.1 ms/b | lr: 1.067e-05 | grad norm: 13.65 | inf norm:  0.718 | loss: 1.47 | perp:   4.36
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2216.17 sec | train loss, perp: 1.534,   4.64 :( | valid loss, perp: 1.304,   3.69
# Grad norm: 59.989 | Grad inf. norm:   5.772 | Max abs param:  0.8401
# ============================================================================================================
#
#
# Epoch 144/150) lr = 1.841e-05
#  b 150/719 >> 3246.5 ms/b | lr: 1.624e-05 | grad norm:  4.21 | inf norm:  0.378 | loss: 1.53 | perp:   4.61
#  b 300/719 >> 3227.3 ms/b | lr: 1.841e-05 | grad norm: 246.29 | inf norm:   24.6 | loss: 1.58 | perp:   4.87
#  b 450/719 >> 3096.8 ms/b | lr: 1.565e-05 | grad norm:  4.14 | inf norm:  0.336 | loss: 1.58 | perp:   4.84
#  b 600/719 >> 3159.5 ms/b | lr: 1.841e-05 | grad norm:  2.77 | inf norm:  0.181 | loss: 1.50 | perp:   4.50
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2275.26 sec | train loss, perp: 1.546,   4.69 :( | valid loss, perp: 1.315,   3.73 :(
# Grad norm:  2.383 | Grad inf. norm: 0.08325 | Max abs param:  0.8419
# ============================================================================================================
#
#
# Epoch 145/150) lr = 1.835e-05
#  b 150/720 >> 3138.4 ms/b | lr: 1.675e-05 | grad norm:  4.76 | inf norm:   0.28 | loss: 1.53 | perp:   4.61
#  b 300/720 >> 3153.6 ms/b | lr: 1.835e-05 | grad norm:  5.27 | inf norm:  0.556 | loss: 1.52 | perp:   4.58
#  b 450/720 >> 3162.3 ms/b | lr: 1.885e-05 | grad norm:  3.53 | inf norm:  0.245 | loss: 1.49 | perp:   4.43
#  b 600/720 >> 3191.3 ms/b | lr: 1.618e-05 | grad norm:  3.16 | inf norm:  0.227 | loss: 1.46 | perp:   4.31
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2270.55 sec | train loss, perp: 1.497,   4.47    | valid loss, perp: 1.303,   3.68
# Grad norm:  6.847 | Grad inf. norm:  0.2536 | Max abs param:   0.843
# ============================================================================================================
#
#
# Epoch 146/150) lr = 1.829e-05
#  b 150/723 >> 3012.5 ms/b | lr: 1.724e-05 | grad norm:  2.90 | inf norm:  0.166 | loss: 1.49 | perp:   4.43
#  b 300/723 >> 3000.8 ms/b | lr: 1.554e-05 | grad norm:  4.59 | inf norm:  0.514 | loss: 1.47 | perp:   4.33
#  b 450/723 >> 3093.5 ms/b | lr: 1.928e-05 | grad norm:  6.28 | inf norm:  0.724 | loss: 1.53 | perp:   4.61
#  b 600/723 >> 3032.9 ms/b | lr: 1.724e-05 | grad norm:  2.62 | inf norm: 0.0747 | loss: 1.47 | perp:   4.34
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2217.74 sec | train loss, perp: 1.491,   4.44    | valid loss, perp: 1.301,   3.67
# Grad norm:  3.444 | Grad inf. norm: 0.09866 | Max abs param:  0.8456
# ============================================================================================================
#
#
# Epoch 147/150) lr = 1.823e-05
#  b 150/715 >> 3166.9 ms/b | lr: 1.771e-05 | grad norm:  4.53 | inf norm:  0.362 | loss: 1.51 | perp:   4.51
#  b 300/715 >> 3034.2 ms/b | lr: 1.718e-05 | grad norm:  2.49 | inf norm: 0.0955 | loss: 1.43 | perp:   4.17
#  b 450/715 >> 3153.6 ms/b | lr: 1.823e-05 | grad norm:  2.60 | inf norm: 0.0911 | loss: 1.53 | perp:   4.64
#  b 600/715 >> 3052.0 ms/b | lr: 1.607e-05 | grad norm:  2.96 | inf norm:  0.091 | loss: 1.49 | perp:   4.44
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2203.99 sec | train loss, perp: 1.501,   4.48 :( | valid loss, perp: 1.298,   3.66
# Grad norm:  2.811 | Grad inf. norm: 0.09098 | Max abs param:   0.847
# ============================================================================================================
#
#
# Epoch 148/150) lr = 1.816e-05
#  b 150/723 >> 2996.4 ms/b | lr: 1.658e-05 | grad norm:  4.83 | inf norm:  0.408 | loss: 1.55 | perp:   4.70
#  b 300/723 >> 3005.1 ms/b | lr: 1.544e-05 | grad norm:  4.75 | inf norm:  0.351 | loss: 1.54 | perp:   4.65
#  b 450/723 >> 2978.9 ms/b | lr: 1.765e-05 | grad norm:  2.55 | inf norm: 0.0707 | loss: 1.49 | perp:   4.44
#  b 600/723 >> 3112.2 ms/b | lr: 2.008e-05 | grad norm:  3.14 | inf norm:  0.244 | loss: 1.54 | perp:   4.67
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2192.96 sec | train loss, perp: 1.531,   4.62 :( | valid loss, perp: 1.299,   3.67 :(
# Grad norm:  2.396 | Grad inf. norm: 0.05795 | Max abs param:  0.8487
# ============================================================================================================
#
#
# Epoch 149/150) lr = 1.81e-05
#  b 150/717 >> 3146.9 ms/b | lr: 1.908e-05 | grad norm: 58.33 | inf norm:   6.22 | loss: 1.51 | perp:   4.54
#  b 300/717 >> 3070.6 ms/b | lr: 1.538e-05 | grad norm:  5.20 | inf norm:   0.62 | loss: 1.45 | perp:   4.25
#  b 450/717 >> 2988.2 ms/b | lr: 1.759e-05 | grad norm:  3.62 | inf norm:  0.318 | loss: 1.50 | perp:   4.50
#  b 600/717 >> 3069.0 ms/b | lr: 1.908e-05 | grad norm:  5.40 | inf norm:  0.511 | loss: 1.50 | perp:   4.50
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2188.69 sec | train loss, perp: 1.502,   4.49 :( | valid loss, perp: 1.296,   3.66
# Grad norm:  2.617 | Grad inf. norm: 0.06976 | Max abs param:  0.8506
# ============================================================================================================
# Epoch 150/150) lr = 1.804e-05
#  b 150/712 >> 3111.6 ms/b | lr: 1.753e-05 | grad norm:  2.51 | inf norm: 0.0731 | loss: 1.50 | perp:   4.47
#  b 300/712 >> 3080.1 ms/b | lr: 1.701e-05 | grad norm:  2.95 | inf norm:  0.185 | loss: 1.52 | perp:   4.59
#  b 450/712 >> 3068.0 ms/b | lr: 1.902e-05 | grad norm:  2.75 | inf norm:  0.201 | loss: 1.59 | perp:   4.92
#  b 600/712 >> 3113.5 ms/b | lr: 1.701e-05 | grad norm:  2.59 | inf norm: 0.0688 | loss: 1.41 | perp:   4.11
# ------------------------------------------------------------------------------------------------------------
# Elapsed time: 2195.89 sec | train loss, perp: 1.509,   4.52 :( | valid loss, perp: 1.291,   3.64
# Grad norm:  3.912 | Grad inf. norm:  0.4348 | Max abs param:  0.8514
# ============================================================================================================

# %%
CAUSES = ['output', 'grad']
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    _states = states
    if model.n_enc_layers > 0:
        enc_states = states[0]
        states = states[1:]
    if model.n_dec_layers > 0:
        dec_states = states[-1]
        states = states[:-1]
    attn_states = states[0]
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])
else:
    # Save training stats
    with open(os.path.join('stats', model_test_name+'.pkl'), 'wb') as f:
        pickle.dump(train_stats, f)
    with open(os.path.join('models', model_test_name+'.pt'), 'wb') as f:
        torch.save(model.state_dict(), f)

# %%
test_loss = evaluate(
    model, test_data, eval_batch_size, seq_len,
    ntokens, eval_criterion, save_wts = True
)
print('test_loss: {:5.3f} | test_perplexity: {:7.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss: 1.200 | test_perplexity:    3.32

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 18 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#  1655   935   935    32   935    32    32    32    32    32    32    32    32
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#    32    32    32    32    32
# [torch.LongTensor of size 2x18]
#
# 14 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#  1691    27    27    27    27    27    27    27    27    27    27    27    27
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#    27    27    27    27    27
# [torch.LongTensor of size 2x18]
#
# 16 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   119   119   119   119   119   119   119   119   119   119   119   119   119
#
# Columns 13 to 17
#    26  5463   119    26    26
#   119   119   119   119   119
# [torch.LongTensor of size 2x18]
#
# 17 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#  1479  1479    35    35    35    35    35    35    35    35    35    35    35
#
# Columns 13 to 17
#    35    27    27  1479   108
#    35    35    35    35    35
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
#
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(model.embedding.weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_norm, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = model.attn

# %%
align_wts = np.array(attn.alignment.weight.data)
plt.imshow(align_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_align_in'); plt.ylabel('d_align_out')
plt.title('Alignment sublayer weights')
plt.colorbar()
align_wts.shape
# Out:
# (256, 768)

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Attention sublayer weights (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 768)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()

# %% [markdown]
# ## Plot training stat curves

# %%
epoch_range = range(1, train_stats['epochs']+1)
train_stats.keys()
# Out:
# dict_keys(['epochs', 'train_loss', 'val_loss', 'grad_norm', 'grad_inf_norm', 'max_param', 'best_losses'])

# %%
plt.plot(epoch_range, train_stats['train_loss'])
plt.plot(epoch_range, train_stats['val_loss'])
plt.xlabel('Epoch'); plt.ylabel('Loss')
plt.title('Loss over training time')
plt.legend(['Train loss', 'Validation loss'])

# %%
plt.plot(epoch_range, train_stats['max_param'])
plt.xlabel('Epoch'); plt.ylabel('Largest parameter magnitude')
plt.title('Largest parameter magnitude over training time')
# Out:
# Text(0.5,1,'Largest parameter magnitude over training time')

# %%
fig, pnorm_ax = plt.subplots()
pnorm_ax.plot(epoch_range, train_stats['grad_norm'], 'b')
pnorm_ax.set_xlabel('Epoch');
pnorm_ax.set_ylabel('2-norm', color = 'b')

infnorm_ax = pnorm_ax.twinx()
infnorm_ax.plot(epoch_range, train_stats['grad_inf_norm'], 'r')
infnorm_ax.set_ylabel('infinite norm', color = 'r')

plt.title('Gradient norms over training time')
#fig.tight_layout()
