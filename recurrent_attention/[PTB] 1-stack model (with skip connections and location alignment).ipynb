# %%
import os
import pickle
import time

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
# %matplotlib inline

from torch.autograd import Variable

import data
from model import *
from trainer import *

# %% [markdown]
# ## Initialize data

# %%
corpus = data.Corpus('./data/ptb')
ntokens = len(corpus.dictionary)

# %% [markdown]
# ## Overhead stuff
#
# Helper functions for batching, resetting hidden states, etc.

# %%
model_test_name = '1_encoder_1_decoder_with_skips_localign'

# Training hyperparameters
eval_batch_size = 10
batch_size = 74
seq_len = 18
dropout = 0.1
clip = 4
lr = 0.02
warmup_steps = 10
decay_factor = 0.5
smoothing = 0.05

epochs = 150
early_stopping = 5
log_interval = 150  # Print log every `log_interval` batches

# %%
# Model hyperparameters
embed_size = 512
encode_size = 256
h_size = 256
loc_align_size = 256
loc_align_kernel = 5
decode_size = 256
decode_out_size = 512
n_enc_layers = 1
attn_rnn_layers = 1
n_dec_layers = 1
smooth_align = True
align_location = True
skip_connections = True

# %% [markdown]
# The learning rate scheduler sets the learning rate factor according to:
#
# $$\text{lr} = d_{\text{model}}^{-0.5}\cdot\min{(\text{epoch}^{-0.5}, \text{epoch}\cdot\text{warmup}^{-1.5})}$$
#
# This corresponds to increasing the learning rate linearly for the first $\text{warmup}$ epochs, then decreasing it proportionally to the inverse square root of the epoch number.

# %%
lrate = lambda factor, h_size, warmup: lambda e: factor*(h_size**(-0.5) * min(e**(-decay_factor), e * warmup**(-(decay_factor+1))))
opts = [
    lrate(2*lr, embed_size, warmup_steps), 
    lrate(lr, embed_size*2, warmup_steps),
    lrate(lr, embed_size, warmup_steps//2),
    lrate(lr, embed_size, warmup_steps*2),
    lrate(lr, embed_size, warmup_steps),
]
plt.plot(np.arange(1, epochs+1), [[opt(i) for opt in opts] for i in range(1, epochs+1)])
plt.legend([
    "%.4g:%d:%d" % (2*lr, embed_size, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size*2, warmup_steps),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps//2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps*2),
    "%.4g:%d:%d" % (lr, embed_size, warmup_steps),
])

# %% [markdown]
# ## Initialize model, criterion, optimizer, and learning rate scheduler

# %%
model = RNNModel(
    src_vocab = ntokens, tgt_vocab = ntokens, embed_size = embed_size,
    encode_size = encode_size, h_size = h_size, decode_size = decode_size,
    decode_out_size = decode_out_size, n_enc_layers = n_enc_layers,
    attn_rnn_layers = attn_rnn_layers, n_dec_layers = n_dec_layers,
    align_location = align_location, loc_align_size = loc_align_size,
    loc_align_kernel = loc_align_kernel, smooth_align = smooth_align,
    skip_connections = skip_connections, dropout = dropout
)
criterion = LabelSmoothing(ntokens, smoothing = smoothing)
eval_criterion = LabelSmoothing(ntokens, smoothing = 0)
optimizer = optim.Adam(
    model.parameters(), lr = lr, betas = (0.9, 0.98), eps = 1e-9
)
lr_scheduler = get_lr_scheduler(embed_size, warmup_steps, decay_factor, optimizer)
# Reference
nparams = sum([p.numel() for p in model.parameters()])
print('Model parameters: %d' % nparams)
# Out:
# Model parameters: 8746001

# %% [markdown]
# ## Train
# Ready the data

# %%
train_data = batchify(corpus.train, batch_size)
val_data = batchify(corpus.valid, eval_batch_size)
test_data = batchify(corpus.test, eval_batch_size)
train_data.size(), val_data.size(), test_data.size()
# Out:
# (torch.Size([12562, 74]), torch.Size([7376, 10]), torch.Size([8243, 10]))

# %% [markdown]
# Train and evaluate

# %%
train_stats, stat, train_loss, data, targets, states, nstates = train_eval_loop(
    model, train_data, val_data, batch_size, eval_batch_size,
    seq_len, ntokens, criterion, eval_criterion, optimizer,
    lr_scheduler, epochs, warmup_steps, early_stopping,
    clip, log_interval
)
# Out:
# Epoch   1/ 50) lr = 2.795e-05 (warmup)
#  b 150/718 >> 2537.5 ms/b | lr:  2.6e-05 | grad norm: 1.89 | max abs grad:   0.110 | loss: 7.22 | perp.: 1370.37
#  b 300/718 >> 2524.7 ms/b | lr:    3e-05 | grad norm: 1.43 | max abs grad:   0.058 | loss: 6.19 | perp.: 488.05
#  b 450/718 >> 2505.9 ms/b | lr:  2.9e-05 | grad norm: 1.31 | max abs grad:   0.056 | loss: 6.16 | perp.: 473.74
#  b 600/718 >> 2401.8 ms/b | lr:  2.6e-05 | grad norm: 1.22 | max abs grad:   0.039 | loss: 6.12 | perp.: 457.13
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1785.04 sec | train_loss:  6.36 | train_perp: 579.44 | valid_loss:  6.03 | valid_perp.: 417.58
# ================================================================================================================
#
#
# Epoch   2/ 50) lr = 5.59e-05 (warmup)
#  b 150/719 >> 2447.7 ms/b | lr:  4.8e-05 | grad norm: 1.41 | max abs grad:   0.052 | loss: 6.10 | perp.: 447.35
#  b 300/719 >> 2508.7 ms/b | lr:  5.4e-05 | grad norm: 0.97 | max abs grad:   0.027 | loss: 6.03 | perp.: 415.77
#  b 450/719 >> 2421.9 ms/b | lr:  4.9e-05 | grad norm: 1.07 | max abs grad:   0.027 | loss: 5.98 | perp.: 395.32
#  b 600/719 >> 2452.0 ms/b | lr:  5.6e-05 | grad norm: 0.91 | max abs grad:   0.022 | loss: 5.95 | perp.: 384.44
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1765.66 sec | train_loss:  5.99 | train_perp: 400.44 | valid_loss:  5.86 | valid_perp.: 351.94
# ================================================================================================================
#
#
# Epoch   3/ 50) lr = 8.385e-05 (warmup)
#  b 150/723 >> 2431.8 ms/b | lr:  8.6e-05 | grad norm: 1.12 | max abs grad:   0.026 | loss: 5.92 | perp.: 374.23
#  b 300/723 >> 2418.0 ms/b | lr:  8.6e-05 | grad norm: 0.89 | max abs grad:   0.020 | loss: 5.84 | perp.: 344.39
#  b 450/723 >> 2468.1 ms/b | lr:  8.6e-05 | grad norm: 1.01 | max abs grad:   0.026 | loss: 5.79 | perp.: 327.21
#  b 600/723 >> 2500.0 ms/b | lr:  8.4e-05 | grad norm: 0.94 | max abs grad:   0.019 | loss: 5.76 | perp.: 316.64
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1766.67 sec | train_loss:  5.80 | train_perp: 331.49 | valid_loss:  5.66 | valid_perp.: 286.02
# ================================================================================================================
#
#
# Epoch   4/ 50) lr = 0.0001118 (warmup)
#  b 150/717 >> 2513.3 ms/b | lr:  0.00011 | grad norm: 0.95 | max abs grad:   0.022 | loss: 5.69 | perp.: 297.14
#  b 300/717 >> 2420.9 ms/b | lr:  0.00011 | grad norm: 1.18 | max abs grad:   0.042 | loss: 5.63 | perp.: 277.79
#  b 450/717 >> 2445.7 ms/b | lr:  0.00011 | grad norm: 1.11 | max abs grad:   0.025 | loss: 5.56 | perp.: 261.08
#  b 600/717 >> 2420.7 ms/b | lr:   0.0001 | grad norm: 1.33 | max abs grad:   0.039 | loss: 5.52 | perp.: 250.24
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1766.94 sec | train_loss:  5.59 | train_perp: 266.41 | valid_loss:  5.44 | valid_perp.: 229.79
# ================================================================================================================
#
#
# Epoch   5/ 50) lr = 0.0001398 (warmup)
#  b 150/724 >> 2469.0 ms/b | lr:  0.00014 | grad norm: 1.17 | max abs grad:   0.027 | loss: 5.45 | perp.: 233.51
#  b 300/724 >> 2418.2 ms/b | lr:  0.00013 | grad norm: 1.27 | max abs grad:   0.032 | loss: 5.35 | perp.: 210.93
#  b 450/724 >> 2488.9 ms/b | lr:  0.00014 | grad norm: 1.52 | max abs grad:   0.036 | loss: 5.34 | perp.: 208.36
#  b 600/724 >> 2405.8 ms/b | lr:  0.00013 | grad norm: 1.48 | max abs grad:   0.035 | loss: 5.27 | perp.: 194.03
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1770.09 sec | train_loss:  5.34 | train_perp: 207.95 | valid_loss:  5.17 | valid_perp.: 175.77
# ================================================================================================================
#
#
# Epoch   6/ 50) lr = 0.0001677 (warmup)
#  b 150/714 >> 2508.9 ms/b | lr:  0.00017 | grad norm: 1.23 | max abs grad:   0.035 | loss: 5.18 | perp.: 178.48
#  b 300/714 >> 2453.7 ms/b | lr:  0.00015 | grad norm: 1.55 | max abs grad:   0.038 | loss: 5.11 | perp.: 166.00
#  b 450/714 >> 2532.0 ms/b | lr:  0.00016 | grad norm: 1.63 | max abs grad:   0.073 | loss: 5.09 | perp.: 163.19
#  b 600/714 >> 2452.6 ms/b | lr:  0.00016 | grad norm: 1.77 | max abs grad:   0.034 | loss: 5.04 | perp.: 154.77
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1772.43 sec | train_loss:  5.10 | train_perp: 163.87 | valid_loss:  4.93 | valid_perp.: 138.97
# ================================================================================================================
#
#
# Epoch   7/ 50) lr = 0.0001957 (warmup)
#  b 150/724 >> 2516.7 ms/b | lr:  0.00018 | grad norm: 1.83 | max abs grad:   0.054 | loss: 4.96 | perp.: 142.10
#  b 300/724 >> 2421.7 ms/b | lr:   0.0002 | grad norm: 1.98 | max abs grad:   0.045 | loss: 4.90 | perp.: 133.74
#  b 450/724 >> 2456.4 ms/b | lr:  0.00019 | grad norm: 2.69 | max abs grad:   0.063 | loss: 4.86 | perp.: 128.87
#  b 600/724 >> 2401.1 ms/b | lr:  0.00018 | grad norm: 1.69 | max abs grad:   0.046 | loss: 4.82 | perp.: 123.82
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1773.48 sec | train_loss:  4.88 | train_perp: 131.36 | valid_loss:  4.73 | valid_perp.: 112.86
# ================================================================================================================
#
#
# Epoch   8/ 50) lr = 0.0002236 (warmup)
#  b 150/724 >> 2553.0 ms/b | lr:  0.00019 | grad norm: 2.97 | max abs grad:   0.071 | loss: 4.77 | perp.: 118.09
#  b 300/724 >> 2442.8 ms/b | lr:  0.00022 | grad norm: 2.18 | max abs grad:   0.041 | loss: 4.67 | perp.: 106.41
#  b 450/724 >> 2391.5 ms/b | lr:  0.00019 | grad norm: 2.21 | max abs grad:   0.051 | loss: 4.67 | perp.: 107.14
#  b 600/724 >> 2496.7 ms/b | lr:  0.00021 | grad norm: 2.00 | max abs grad:   0.038 | loss: 4.65 | perp.: 104.68
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1776.79 sec | train_loss:  4.69 | train_perp: 109.16 | valid_loss:  4.57 | valid_perp.:  96.84
# ================================================================================================================
#
#
# Epoch   9/ 50) lr = 0.0002516 (warmup)
#  b 150/724 >> 2461.3 ms/b | lr:  0.00026 | grad norm: 2.25 | max abs grad:   0.091 | loss: 4.57 | perp.:  96.24
#  b 300/724 >> 2407.9 ms/b | lr:  0.00028 | grad norm: 1.68 | max abs grad:   0.034 | loss: 4.50 | perp.:  89.76
#  b 450/724 >> 2473.5 ms/b | lr:  0.00025 | grad norm: 2.76 | max abs grad:   0.092 | loss: 4.52 | perp.:  91.55
#  b 600/724 >> 2471.6 ms/b | lr:  0.00023 | grad norm: 2.33 | max abs grad:   0.076 | loss: 4.46 | perp.:  86.12
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1773.76 sec | train_loss:  4.51 | train_perp:  91.16 | valid_loss:  4.42 | valid_perp.:  83.37
# ================================================================================================================
#
#
# Epoch  10/ 50) lr = 0.0002795 (warmup)
#  b 150/714 >> 2499.7 ms/b | lr:  0.00029 | grad norm: 3.64 | max abs grad:   0.078 | loss: 4.41 | perp.:  82.11
#  b 300/714 >> 2497.8 ms/b | lr:  0.00029 | grad norm: 2.78 | max abs grad:   0.112 | loss: 4.33 | perp.:  76.25
#  b 450/714 >> 2518.5 ms/b | lr:  0.00029 | grad norm: 3.16 | max abs grad:   0.083 | loss: 4.31 | perp.:  74.28
#  b 600/714 >> 2448.9 ms/b | lr:  0.00029 | grad norm: 3.57 | max abs grad:   0.153 | loss: 4.23 | perp.:  68.57
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1778.10 sec | train_loss:  4.33 | train_perp:  75.58 | valid_loss:  4.11 | valid_perp.:  60.90
# ================================================================================================================
#
#
# Epoch  11/ 50) lr = 0.0002665
#  b 150/714 >> 2525.4 ms/b | lr:  0.00027 | grad norm: 3.07 | max abs grad:   0.107 | loss: 4.14 | perp.:  62.49
#  b 300/714 >> 2479.6 ms/b | lr:  0.00027 | grad norm: 3.75 | max abs grad:   0.163 | loss: 4.05 | perp.:  57.46
#  b 450/714 >> 2466.1 ms/b | lr:  0.00027 | grad norm: 7.37 | max abs grad:   0.415 | loss: 4.00 | perp.:  54.85
#  b 600/714 >> 2490.0 ms/b | lr:  0.00024 | grad norm: 3.39 | max abs grad:   0.134 | loss: 4.04 | perp.:  56.66
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1781.40 sec | train_loss:  4.08 | train_perp:  59.03 | valid_loss:  3.89 | valid_perp.:  48.73
# ================================================================================================================
#
#
# Epoch  12/ 50) lr = 0.0002552
#  b 150/721 >> 2517.6 ms/b | lr:  0.00024 | grad norm: 3.56 | max abs grad:   0.233 | loss: 3.92 | perp.:  50.47
#  b 300/721 >> 2450.4 ms/b | lr:  0.00024 | grad norm: 3.11 | max abs grad:   0.194 | loss: 3.81 | perp.:  45.26
#  b 450/721 >> 2469.3 ms/b | lr:  0.00026 | grad norm: 3.86 | max abs grad:   0.322 | loss: 3.79 | perp.:  44.30
#  b 600/721 >> 2471.5 ms/b | lr:  0.00028 | grad norm: 7.28 | max abs grad:   0.578 | loss: 3.76 | perp.:  42.99
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1780.13 sec | train_loss:  3.84 | train_perp:  46.41 | valid_loss:  3.52 | valid_perp.:  33.89
# ================================================================================================================
#
#
# Epoch  13/ 50) lr = 0.0002451
#  b 150/709 >> 2527.2 ms/b | lr:  0.00023 | grad norm: 3.34 | max abs grad:   0.289 | loss: 3.76 | perp.:  43.15
#  b 300/709 >> 2524.9 ms/b | lr:  0.00026 | grad norm: 3.57 | max abs grad:   0.257 | loss: 3.69 | perp.:  39.99
#  b 450/709 >> 2431.6 ms/b | lr:  0.00025 | grad norm: 3.79 | max abs grad:   0.207 | loss: 3.63 | perp.:  37.53
#  b 600/709 >> 2551.2 ms/b | lr:  0.00023 | grad norm: 3.69 | max abs grad:   0.262 | loss: 3.69 | perp.:  40.24
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1782.95 sec | train_loss:  3.71 | train_perp:  40.96 | valid_loss:  3.41 | valid_perp.:  30.32
# ================================================================================================================
#
#
# Epoch  14/ 50) lr = 0.0002362
#  b 150/722 >> 2485.7 ms/b | lr:  0.00023 | grad norm: 3.74 | max abs grad:   0.351 | loss: 3.56 | perp.:  35.30
#  b 300/722 >> 2516.0 ms/b | lr:  0.00024 | grad norm: 9.30 | max abs grad:   0.998 | loss: 3.51 | perp.:  33.34
#  b 450/722 >> 2668.2 ms/b | lr:  0.00024 | grad norm: 5.29 | max abs grad:   0.565 | loss: 3.55 | perp.:  34.86
#  b 600/722 >> 2541.9 ms/b | lr:  0.00025 | grad norm: 6.26 | max abs grad:   0.556 | loss: 3.45 | perp.:  31.49
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1842.29 sec | train_loss:  3.54 | train_perp:  34.58 | valid_loss:  3.30 | valid_perp.:  27.12
# ================================================================================================================
#
#
# Epoch  15/ 50) lr = 0.0002282
#  b 150/725 >> 2497.1 ms/b | lr:  0.00023 | grad norm: 21.47 | max abs grad:   1.931 | loss: 3.40 | perp.:  30.00
#  b 300/725 >> 2398.4 ms/b | lr:  0.00022 | grad norm: 3.00 | max abs grad:   0.326 | loss: 3.39 | perp.:  29.66
#  b 450/725 >> 2461.2 ms/b | lr:   0.0002 | grad norm: 3.48 | max abs grad:   0.204 | loss: 3.45 | perp.:  31.58
#  b 600/725 >> 2488.3 ms/b | lr:  0.00022 | grad norm: 2.94 | max abs grad:   0.267 | loss: 3.46 | perp.:  31.79
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1786.76 sec | train_loss:  3.46 | train_perp:  31.89 | valid_loss:  3.16 | valid_perp.:  23.67
# ================================================================================================================
#
#
# Epoch  16/ 50) lr = 0.000221
#  b 150/719 >> 2492.2 ms/b | lr:  0.00021 | grad norm: 5.02 | max abs grad:   0.293 | loss: 3.38 | perp.:  29.42
#  b 300/719 >> 2532.7 ms/b | lr:  0.00022 | grad norm: 7.92 | max abs grad:   0.622 | loss: 3.42 | perp.:  30.71
#  b 450/719 >> 2495.6 ms/b | lr:  0.00014 | grad norm: 4.48 | max abs grad:   0.123 | loss: 3.41 | perp.:  30.34
#  b 600/719 >> 2388.1 ms/b | lr:  0.00022 | grad norm: 3.50 | max abs grad:   0.346 | loss: 3.30 | perp.:  27.20
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1781.10 sec | train_loss:  3.40 | train_perp:  30.09 | valid_loss:  3.09 | valid_perp.:  21.94
# ================================================================================================================
#
#
# Epoch  17/ 50) lr = 0.0002144
#  b 150/710 >> 2539.6 ms/b | lr:   0.0002 | grad norm: 7.15 | max abs grad:   0.947 | loss: 3.33 | perp.:  27.89
#  b 300/710 >> 2500.1 ms/b | lr:  0.00024 | grad norm: 10.82 | max abs grad:   1.188 | loss: 3.28 | perp.:  26.58
#  b 450/710 >> 2488.7 ms/b | lr:  0.00021 | grad norm: 75.55 | max abs grad:  10.712 | loss: 3.33 | perp.:  28.07
#  b 600/710 >> 2513.6 ms/b | lr:  0.00023 | grad norm: 9.40 | max abs grad:   1.038 | loss: 3.33 | perp.:  27.82
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1778.31 sec | train_loss:  3.35 | train_perp:  28.38 | valid_loss:  3.20 | valid_perp.:  24.50
# ================================================================================================================
#
#
# Epoch  18/ 50) lr = 0.0002083
#  b 150/718 >> 2495.1 ms/b | lr:  0.00023 | grad norm: 9.76 | max abs grad:   0.558 | loss: 3.28 | perp.:  26.61
#  b 300/718 >> 2550.8 ms/b | lr:  0.00022 | grad norm: 6.09 | max abs grad:   0.313 | loss: 3.32 | perp.:  27.57
#  b 450/718 >> 2489.3 ms/b | lr:  0.00023 | grad norm: 15.44 | max abs grad:   0.741 | loss: 3.30 | perp.:  27.24
#  b 600/718 >> 2447.5 ms/b | lr:  0.00018 | grad norm: 3.46 | max abs grad:   0.307 | loss: 3.24 | perp.:  25.55
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1802.53 sec | train_loss:  3.30 | train_perp:  27.15 | valid_loss:  3.07 | valid_perp.:  21.58
# ================================================================================================================
#
#
# Epoch  19/ 50) lr = 0.0002028
#  b 150/717 >> 2666.7 ms/b | lr:  0.00021 | grad norm: 5.63 | max abs grad:   0.550 | loss: 3.24 | perp.:  25.52
#  b 300/717 >> 2551.3 ms/b | lr:  0.00021 | grad norm: 9.71 | max abs grad:   0.936 | loss: 3.15 | perp.:  23.32
#  b 450/717 >> 2615.6 ms/b | lr:  0.00021 | grad norm: 46.23 | max abs grad:   3.844 | loss: 3.27 | perp.:  26.21
#  b 600/717 >> 2574.4 ms/b | lr:   0.0002 | grad norm: 10.45 | max abs grad:   0.875 | loss: 3.27 | perp.:  26.20
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1847.22 sec | train_loss:  3.27 | train_perp:  26.20 | valid_loss:  3.05 | valid_perp.:  21.03
# ================================================================================================================
#
#
# Epoch  20/ 50) lr = 0.0001976
#  b 150/712 >> 2524.3 ms/b | lr:  0.00019 | grad norm: 7.79 | max abs grad:   0.514 | loss: 3.22 | perp.:  24.92
#  b 300/712 >> 2507.9 ms/b | lr:   0.0002 | grad norm: 3.78 | max abs grad:   0.304 | loss: 3.18 | perp.:  24.05
#  b 450/712 >> 2442.6 ms/b | lr:   0.0002 | grad norm: 7.32 | max abs grad:   0.764 | loss: 3.12 | perp.:  22.59
#  b 600/712 >> 2501.0 ms/b | lr:  0.00021 | grad norm: 10.51 | max abs grad:   0.827 | loss: 3.25 | perp.:  25.80
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1778.64 sec | train_loss:  3.24 | train_perp:  25.45 | valid_loss:  2.91 | valid_perp.:  18.43
# ================================================================================================================
#
#
# Epoch  21/ 50) lr = 0.0001929
#  b 150/718 >> 2492.4 ms/b | lr:  0.00021 | grad norm: 17.59 | max abs grad:   1.204 | loss: 3.13 | perp.:  22.79
#  b 300/718 >> 2510.1 ms/b | lr:  0.00018 | grad norm: 4.78 | max abs grad:   0.361 | loss: 3.20 | perp.:  24.52
#  b 450/718 >> 2416.3 ms/b | lr:  0.00016 | grad norm: 3.49 | max abs grad:   0.257 | loss: 3.10 | perp.:  22.29
#  b 600/718 >> 2445.1 ms/b | lr:  0.00022 | grad norm: 13.65 | max abs grad:   0.774 | loss: 3.08 | perp.:  21.85
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1774.57 sec | train_loss:  3.15 | train_perp:  23.40 | valid_loss:  3.04 | valid_perp.:  20.81
# ================================================================================================================
#
#
# Epoch  22/ 50) lr = 0.0001884
#  b 150/716 >> 2526.2 ms/b | lr:  0.00018 | grad norm: 4.83 | max abs grad:   0.466 | loss: 3.11 | perp.:  22.40
#  b 300/716 >> 2460.2 ms/b | lr:  0.00019 | grad norm: 18.33 | max abs grad:   0.864 | loss: 3.05 | perp.:  21.16
#  b 450/716 >> 2453.9 ms/b | lr:  0.00017 | grad norm: 5.82 | max abs grad:   0.555 | loss: 3.10 | perp.:  22.11
#  b 600/716 >> 2501.5 ms/b | lr:   0.0002 | grad norm: 27.90 | max abs grad:   1.001 | loss: 3.06 | perp.:  21.43
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1774.81 sec | train_loss:  3.12 | train_perp:  22.54 | valid_loss:  2.96 | valid_perp.:  19.27
# ================================================================================================================
#
#
# Epoch  23/ 50) lr = 0.0001843
#  b 150/717 >> 2450.2 ms/b | lr:  0.00019 | grad norm: 8.17 | max abs grad:   0.747 | loss: 2.99 | perp.:  19.96
#  b 300/717 >> 2466.4 ms/b | lr:  0.00016 | grad norm: 5.93 | max abs grad:   0.668 | loss: 2.99 | perp.:  19.96
#  b 450/717 >> 2482.5 ms/b | lr:  0.00018 | grad norm: 10.71 | max abs grad:   0.930 | loss: 3.12 | perp.:  22.59
#  b 600/717 >> 2490.9 ms/b | lr:  0.00017 | grad norm: 6.87 | max abs grad:   0.771 | loss: 3.06 | perp.:  21.43
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1775.95 sec | train_loss:  3.07 | train_perp:  21.60 | valid_loss:  2.75 | valid_perp.:  15.65
# ================================================================================================================
#
#
# Epoch  24/ 50) lr = 0.0001804
#  b 150/723 >> 2474.1 ms/b | lr:  0.00019 | grad norm: 6.06 | max abs grad:   0.325 | loss: 3.07 | perp.:  21.55
#  b 300/723 >> 2422.6 ms/b | lr:  0.00019 | grad norm: 49.01 | max abs grad:   3.419 | loss: 2.96 | perp.:  19.21
#  b 450/723 >> 2448.6 ms/b | lr:  0.00018 | grad norm: 12.36 | max abs grad:   1.013 | loss: 3.00 | perp.:  20.01
#  b 600/723 >> 2537.8 ms/b | lr:  0.00015 | grad norm: 6.02 | max abs grad:   0.732 | loss: 3.00 | perp.:  20.01
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1795.52 sec | train_loss:  3.03 | train_perp:  20.72 | valid_loss:  2.68 | valid_perp.:  14.54
# ================================================================================================================
#
#
# Epoch  25/ 50) lr = 0.0001768
#  b 150/720 >> 2671.8 ms/b | lr:  0.00017 | grad norm: 6.53 | max abs grad:   0.714 | loss: 2.90 | perp.:  18.19
#  b 300/720 >> 2797.1 ms/b | lr:  0.00016 | grad norm: 4.89 | max abs grad:   0.502 | loss: 2.96 | perp.:  19.23
#  b 450/720 >> 2547.7 ms/b | lr:  0.00017 | grad norm: 46.53 | max abs grad:   3.790 | loss: 2.95 | perp.:  19.11
#  b 600/720 >> 2675.6 ms/b | lr:  0.00019 | grad norm: 8.78 | max abs grad:   0.433 | loss: 3.01 | perp.:  20.36
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1927.88 sec | train_loss:  2.99 | train_perp:  19.98 | valid_loss:  2.75 | valid_perp.:  15.64
# ================================================================================================================
#
#
# Epoch  26/ 50) lr = 0.0001733
#  b 150/721 >> 2555.1 ms/b | lr:   0.0002 | grad norm: 9.94 | max abs grad:   0.502 | loss: 2.92 | perp.:  18.59
#  b 300/721 >> 2479.8 ms/b | lr:  0.00016 | grad norm: 4.53 | max abs grad:   0.388 | loss: 2.90 | perp.:  18.20
#  b 450/721 >> 2465.4 ms/b | lr:  0.00017 | grad norm: 10.40 | max abs grad:   0.474 | loss: 2.96 | perp.:  19.20
#  b 600/721 >> 2500.7 ms/b | lr:  0.00017 | grad norm: 6.88 | max abs grad:   0.553 | loss: 3.03 | perp.:  20.66
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1803.06 sec | train_loss:  2.97 | train_perp:  19.56 | valid_loss:  2.65 | valid_perp.:  14.18
# ================================================================================================================
#
#
# Epoch  27/ 50) lr = 0.0001701
#  b 150/711 >> 2593.2 ms/b | lr:  0.00018 | grad norm: 13.88 | max abs grad:   0.835 | loss: 3.01 | perp.:  20.31
#  b 300/711 >> 2465.3 ms/b | lr:  0.00017 | grad norm: 5.73 | max abs grad:   0.578 | loss: 2.90 | perp.:  18.21
#  b 450/711 >> 2512.1 ms/b | lr:  0.00015 | grad norm: 3.42 | max abs grad:   0.253 | loss: 2.98 | perp.:  19.70
#  b 600/711 >> 2499.1 ms/b | lr:  0.00017 | grad norm: 4.73 | max abs grad:   0.494 | loss: 2.89 | perp.:  18.00
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1783.87 sec | train_loss:  2.96 | train_perp:  19.27 | valid_loss:  2.76 | valid_perp.:  15.79
# ================================================================================================================
#
#
# Epoch  28/ 50) lr = 0.000167
#  b 150/714 >> 2464.9 ms/b | lr:  0.00017 | grad norm: 7.64 | max abs grad:   0.337 | loss: 2.84 | perp.:  17.17
#  b 300/714 >> 2534.0 ms/b | lr:  0.00015 | grad norm: 8.77 | max abs grad:   0.914 | loss: 3.09 | perp.:  22.01
#  b 450/714 >> 2493.0 ms/b | lr:  0.00014 | grad norm: 5.15 | max abs grad:   0.514 | loss: 2.90 | perp.:  18.22
#  b 600/714 >> 2496.7 ms/b | lr:  0.00018 | grad norm: 11.29 | max abs grad:   1.026 | loss: 2.81 | perp.:  16.68
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1782.12 sec | train_loss:  2.94 | train_perp:  18.87 | valid_loss:  2.74 | valid_perp.:  15.54
# ================================================================================================================
#
#
# Epoch  29/ 50) lr = 0.0001641
#  b 150/710 >> 2504.8 ms/b | lr:  0.00016 | grad norm: 8.48 | max abs grad:   0.680 | loss: 2.95 | perp.:  19.17
#  b 300/710 >> 2498.1 ms/b | lr:  0.00017 | grad norm: 5.82 | max abs grad:   0.366 | loss: 2.92 | perp.:  18.52
#  b 450/710 >> 2531.3 ms/b | lr:  0.00015 | grad norm: 12.28 | max abs grad:   0.472 | loss: 2.89 | perp.:  18.03
#  b 600/710 >> 2501.7 ms/b | lr:  0.00017 | grad norm: 6.05 | max abs grad:   0.514 | loss: 2.85 | perp.:  17.32
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1779.71 sec | train_loss:  2.93 | train_perp:  18.67 | valid_loss:  2.65 | valid_perp.:  14.21
# ================================================================================================================
#
#
# Epoch  30/ 50) lr = 0.0001614
#  b 150/720 >> 2470.6 ms/b | lr:  0.00017 | grad norm: 7.24 | max abs grad:   0.348 | loss: 2.81 | perp.:  16.59
#  b 300/720 >> 2506.8 ms/b | lr:  0.00016 | grad norm: 8.65 | max abs grad:   0.378 | loss: 2.82 | perp.:  16.73
#  b 450/720 >> 2495.4 ms/b | lr:  0.00016 | grad norm: 23.29 | max abs grad:   3.281 | loss: 2.84 | perp.:  17.14
#  b 600/720 >> 2444.0 ms/b | lr:  0.00016 | grad norm: 7.34 | max abs grad:   0.768 | loss: 2.86 | perp.:  17.43
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1782.21 sec | train_loss:  2.86 | train_perp:  17.42 | valid_loss:  2.58 | valid_perp.:  13.23
# ================================================================================================================
#
#
# Epoch  31/ 50) lr = 0.0001588
#  b 150/729 >> 2462.6 ms/b | lr:  0.00017 | grad norm: 135.98 | max abs grad:  18.271 | loss: 2.80 | perp.:  16.46
#  b 300/729 >> 2466.3 ms/b | lr:  0.00016 | grad norm: 5.34 | max abs grad:   0.447 | loss: 2.81 | perp.:  16.61
#  b 450/729 >> 2415.6 ms/b | lr:  0.00016 | grad norm: 6.40 | max abs grad:   0.237 | loss: 2.78 | perp.:  16.14
#  b 600/729 >> 2405.5 ms/b | lr:  0.00014 | grad norm: 4.06 | max abs grad:   0.203 | loss: 2.75 | perp.:  15.60
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1776.80 sec | train_loss:  2.84 | train_perp:  17.19 | valid_loss:  2.71 | valid_perp.:  15.00
# ================================================================================================================
#
#
# Epoch  32/ 50) lr = 0.0001563
#  b 150/722 >> 2503.1 ms/b | lr:  0.00016 | grad norm: 15.89 | max abs grad:   1.954 | loss: 2.81 | perp.:  16.68
#  b 300/722 >> 2445.7 ms/b | lr:  0.00016 | grad norm: 44.49 | max abs grad:   1.419 | loss: 2.82 | perp.:  16.72
#  b 450/722 >> 2459.4 ms/b | lr:  0.00014 | grad norm: 3.36 | max abs grad:   0.290 | loss: 2.78 | perp.:  16.10
#  b 600/722 >> 2485.4 ms/b | lr:  0.00016 | grad norm: 87.98 | max abs grad:   4.855 | loss: 2.76 | perp.:  15.82
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1785.46 sec | train_loss:  2.84 | train_perp:  17.13 | valid_loss:  2.68 | valid_perp.:  14.60
# ================================================================================================================
#
#
# Epoch  33/ 50) lr = 0.0001539
#  b 150/708 >> 2494.1 ms/b | lr:  0.00017 | grad norm: 12.47 | max abs grad:   0.496 | loss: 3.94 | perp.:  51.56
#  b 300/708 >> 2446.9 ms/b | lr:  0.00016 | grad norm: 42.58 | max abs grad:   7.454 | loss: 2.76 | perp.:  15.78
#  b 450/708 >> 2502.1 ms/b | lr:  0.00015 | grad norm: 8.96 | max abs grad:   0.591 | loss: 2.79 | perp.:  16.30
#  b 600/708 >> 2575.3 ms/b | lr:  0.00016 | grad norm: 14.71 | max abs grad:   1.244 | loss: 2.82 | perp.:  16.73
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1783.28 sec | train_loss:  3.13 | train_perp:  22.99 | valid_loss:  2.56 | valid_perp.:  12.88
# ================================================================================================================
#
#
# Epoch  34/ 50) lr = 0.0001516
#  b 150/718 >> 2521.3 ms/b | lr:  0.00015 | grad norm: 9.27 | max abs grad:   0.631 | loss: 2.74 | perp.:  15.46
#  b 300/718 >> 2464.4 ms/b | lr:  0.00015 | grad norm: 99.05 | max abs grad:   7.329 | loss: 2.81 | perp.:  16.60
#  b 450/718 >> 2437.6 ms/b | lr:  0.00015 | grad norm: 19.73 | max abs grad:   3.321 | loss: 2.65 | perp.:  14.11
#  b 600/718 >> 2473.4 ms/b | lr:  0.00016 | grad norm: 8.11 | max abs grad:   0.429 | loss: 2.84 | perp.:  17.09
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1780.87 sec | train_loss:  2.79 | train_perp:  16.21 | valid_loss:  2.48 | valid_perp.:  11.95
# ================================================================================================================
#
#
# Epoch  35/ 50) lr = 0.0001494
#  b 150/718 >> 2508.1 ms/b | lr:  0.00015 | grad norm: 16.02 | max abs grad:   1.336 | loss: 2.70 | perp.:  14.81
#  b 300/718 >> 2472.2 ms/b | lr:  0.00012 | grad norm: 6.39 | max abs grad:   0.414 | loss: 2.60 | perp.:  13.45
#  b 450/718 >> 2461.3 ms/b | lr:  0.00015 | grad norm: 7.54 | max abs grad:   0.494 | loss: 2.69 | perp.:  14.70
#  b 600/718 >> 2500.3 ms/b | lr:  0.00014 | grad norm: 7.35 | max abs grad:   0.345 | loss: 2.68 | perp.:  14.60
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1782.68 sec | train_loss:  2.70 | train_perp:  14.86 | valid_loss:  2.74 | valid_perp.:  15.51
# ================================================================================================================
#
#
# Epoch  36/ 50) lr = 0.0001473
#  b 150/725 >> 2443.9 ms/b | lr:  0.00016 | grad norm: 21.09 | max abs grad:   2.527 | loss: 2.67 | perp.:  14.44
#  b 300/725 >> 2435.4 ms/b | lr:  0.00015 | grad norm: 11.14 | max abs grad:   1.393 | loss: 2.66 | perp.:  14.29
#  b 450/725 >> 2487.5 ms/b | lr:  0.00013 | grad norm: 8.25 | max abs grad:   1.250 | loss: 2.75 | perp.:  15.72
#  b 600/725 >> 2498.9 ms/b | lr:  0.00016 | grad norm: 68.41 | max abs grad:   6.296 | loss: 2.67 | perp.:  14.51
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1785.47 sec | train_loss:  2.72 | train_perp:  15.23 | valid_loss:  2.47 | valid_perp.:  11.83
# ================================================================================================================
#
#
# Epoch  37/ 50) lr = 0.0001453
#  b 150/721 >> 2529.5 ms/b | lr:  0.00014 | grad norm: 14.97 | max abs grad:   1.265 | loss: 2.78 | perp.:  16.09
#  b 300/721 >> 2506.7 ms/b | lr:  0.00014 | grad norm: 24.34 | max abs grad:   1.375 | loss: 2.62 | perp.:  13.71
#  b 450/721 >> 2480.8 ms/b | lr:  0.00015 | grad norm: 14.61 | max abs grad:   1.277 | loss: 2.71 | perp.:  15.06
#  b 600/721 >> 2482.7 ms/b | lr:  0.00014 | grad norm: 4.67 | max abs grad:   0.301 | loss: 2.61 | perp.:  13.62
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1798.78 sec | train_loss:  2.71 | train_perp:  14.96 | valid_loss:  2.42 | valid_perp.:  11.20
# ================================================================================================================
#
#
# Epoch  38/ 50) lr = 0.0001434
#  b 150/714 >> 2540.8 ms/b | lr:  0.00013 | grad norm: 19.50 | max abs grad:   2.218 | loss: 2.63 | perp.:  13.90
#  b 300/714 >> 2456.7 ms/b | lr:  0.00015 | grad norm: 18.20 | max abs grad:   0.777 | loss: 2.58 | perp.:  13.15
#  b 450/714 >> 2541.3 ms/b | lr:  0.00015 | grad norm: 6.65 | max abs grad:   0.898 | loss: 2.99 | perp.:  19.83
#  b 600/714 >> 2439.0 ms/b | lr:  0.00015 | grad norm: 10.12 | max abs grad:   0.641 | loss: 2.65 | perp.:  14.20
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1778.24 sec | train_loss:  2.72 | train_perp:  15.22 | valid_loss:  2.27 | valid_perp.:   9.69
# ================================================================================================================
#
#
# Epoch  39/ 50) lr = 0.0001415
#  b 150/717 >> 2511.0 ms/b | lr:  0.00014 | grad norm: 6.69 | max abs grad:   0.800 | loss: 2.57 | perp.:  13.13
#  b 300/717 >> 2472.9 ms/b | lr:  0.00013 | grad norm: 5.14 | max abs grad:   0.522 | loss: 2.66 | perp.:  14.35
#  b 450/717 >> 2474.4 ms/b | lr:  0.00013 | grad norm: 9.20 | max abs grad:   0.371 | loss: 2.54 | perp.:  12.73
#  b 600/717 >> 2478.9 ms/b | lr:  0.00016 | grad norm: 16.29 | max abs grad:   1.003 | loss: 2.58 | perp.:  13.23
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1778.40 sec | train_loss:  2.63 | train_perp:  13.88 | valid_loss:  2.41 | valid_perp.:  11.16
# ================================================================================================================
#
#
# Epoch  40/ 50) lr = 0.0001398
#  b 150/719 >> 2554.6 ms/b | lr:  0.00015 | grad norm: 18.84 | max abs grad:   1.064 | loss: 2.67 | perp.:  14.39
#  b 300/719 >> 2480.2 ms/b | lr:  0.00014 | grad norm: 7.11 | max abs grad:   0.539 | loss: 2.62 | perp.:  13.77
#  b 450/719 >> 2421.5 ms/b | lr:  0.00015 | grad norm: 9.61 | max abs grad:   1.287 | loss: 2.59 | perp.:  13.39
#  b 600/719 >> 2430.9 ms/b | lr:  0.00013 | grad norm: 3.57 | max abs grad:   0.251 | loss: 2.56 | perp.:  12.95
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1778.10 sec | train_loss:  2.65 | train_perp:  14.22 | valid_loss:  2.67 | valid_perp.:  14.43
# ================================================================================================================
#
#
# Epoch  41/ 50) lr = 0.000138
#  b 150/721 >> 2507.0 ms/b | lr:  0.00015 | grad norm: 64.34 | max abs grad:   2.809 | loss: 2.60 | perp.:  13.41
#  b 300/721 >> 2462.2 ms/b | lr:  0.00014 | grad norm: 8.61 | max abs grad:   0.625 | loss: 2.65 | perp.:  14.10
#  b 450/721 >> 2422.0 ms/b | lr:  0.00011 | grad norm: 11.10 | max abs grad:   0.587 | loss: 2.58 | perp.:  13.17
#  b 600/721 >> 2483.4 ms/b | lr:  0.00015 | grad norm: 11.23 | max abs grad:   0.569 | loss: 2.57 | perp.:  13.01
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1776.67 sec | train_loss:  2.62 | train_perp:  13.78 | valid_loss:  2.44 | valid_perp.:  11.46
# ================================================================================================================
#
#
# Epoch  42/ 50) lr = 0.0001364
#  b 150/723 >> 2440.4 ms/b | lr:  0.00013 | grad norm: 7.51 | max abs grad:   0.595 | loss: 2.51 | perp.:  12.33
#  b 300/723 >> 2410.0 ms/b | lr:  0.00013 | grad norm: 13.65 | max abs grad:   0.640 | loss: 2.43 | perp.:  11.38
#  b 450/723 >> 2495.3 ms/b | lr:  0.00012 | grad norm: 5.53 | max abs grad:   0.459 | loss: 2.57 | perp.:  13.03
#  b 600/723 >> 2507.9 ms/b | lr:  0.00012 | grad norm: 4.30 | max abs grad:   0.167 | loss: 2.54 | perp.:  12.67
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1777.54 sec | train_loss:  2.55 | train_perp:  12.78 | valid_loss:  2.32 | valid_perp.:  10.19
# ================================================================================================================
#
#
# Epoch  43/ 50) lr = 0.0001348
#  b 150/720 >> 2471.5 ms/b | lr:  0.00015 | grad norm: 12.05 | max abs grad:   0.957 | loss: 2.56 | perp.:  12.92
#  b 300/720 >> 2456.1 ms/b | lr:  0.00013 | grad norm: 8.10 | max abs grad:   0.657 | loss: 2.57 | perp.:  13.05
#  b 450/720 >> 2468.1 ms/b | lr:  0.00011 | grad norm: 13.70 | max abs grad:   0.599 | loss: 2.51 | perp.:  12.36
#  b 600/720 >> 2442.3 ms/b | lr:  0.00012 | grad norm: 15.33 | max abs grad:   1.576 | loss: 2.65 | perp.:  14.17
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1779.18 sec | train_loss:  2.64 | train_perp:  14.08 | valid_loss:  2.32 | valid_perp.:  10.22
# ================================================================================================================
#
#
# Epoch  44/ 50) lr = 0.0001333
#  b 150/714 >> 2507.8 ms/b | lr:  0.00013 | grad norm: 11.04 | max abs grad:   1.258 | loss: 2.50 | perp.:  12.15
#  b 300/714 >> 2491.9 ms/b | lr:  0.00012 | grad norm: 4.59 | max abs grad:   0.395 | loss: 2.47 | perp.:  11.82
#  b 450/714 >> 2537.8 ms/b | lr:  0.00011 | grad norm: 5.67 | max abs grad:   0.510 | loss: 2.57 | perp.:  13.07
#  b 600/714 >> 2517.9 ms/b | lr:  0.00013 | grad norm: 42.44 | max abs grad:   1.737 | loss: 2.70 | perp.:  14.95
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1785.89 sec | train_loss:  2.60 | train_perp:  13.46 | valid_loss:  2.89 | valid_perp.:  17.99
# ================================================================================================================
#
#
# Epoch  45/ 50) lr = 0.0001318
#  b 150/721 >> 2464.1 ms/b | lr:  9.8e-05 | grad norm: 9.75 | max abs grad:   1.053 | loss: 2.45 | perp.:  11.64
#  b 300/721 >> 2486.3 ms/b | lr:  0.00015 | grad norm: 8.75 | max abs grad:   0.614 | loss: 2.47 | perp.:  11.84
#  b 450/721 >> 2518.2 ms/b | lr:  0.00012 | grad norm: 10.26 | max abs grad:   0.859 | loss: 2.60 | perp.:  13.47
#  b 600/721 >> 2445.2 ms/b | lr:  0.00013 | grad norm: 7.49 | max abs grad:   0.287 | loss: 2.44 | perp.:  11.46
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1780.77 sec | train_loss:  2.54 | train_perp:  12.69 | valid_loss:  2.42 | valid_perp.:  11.23
# ================================================================================================================
#
#
# Epoch  46/ 50) lr = 0.0001303
#  b 150/716 >> 2469.7 ms/b | lr:  0.00013 | grad norm: 8.15 | max abs grad:   1.032 | loss: 2.57 | perp.:  13.08
#  b 300/716 >> 2522.8 ms/b | lr:  0.00011 | grad norm: 6.12 | max abs grad:   0.602 | loss: 2.44 | perp.:  11.51
#  b 450/716 >> 2453.1 ms/b | lr:  0.00011 | grad norm: 3.59 | max abs grad:   0.236 | loss: 2.50 | perp.:  12.16
#  b 600/716 >> 2541.6 ms/b | lr:  0.00014 | grad norm: 48.75 | max abs grad:   1.838 | loss: 2.54 | perp.:  12.62
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1781.90 sec | train_loss:  2.55 | train_perp:  12.77 | valid_loss:  2.07 | valid_perp.:   7.95
# ================================================================================================================
#
#
# Epoch  47/ 50) lr = 0.0001289
#  b 150/712 >> 2498.6 ms/b | lr:  0.00013 | grad norm: 6.38 | max abs grad:   0.688 | loss: 2.74 | perp.:  15.47
#  b 300/712 >> 2423.3 ms/b | lr:  0.00013 | grad norm: 32.57 | max abs grad:   1.197 | loss: 2.46 | perp.:  11.67
#  b 450/712 >> 2532.7 ms/b | lr:  0.00013 | grad norm: 10.99 | max abs grad:   0.453 | loss: 2.38 | perp.:  10.79
#  b 600/712 >> 2511.0 ms/b | lr:  0.00014 | grad norm: 37.34 | max abs grad:   1.959 | loss: 2.54 | perp.:  12.63
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1783.04 sec | train_loss:  2.58 | train_perp:  13.17 | valid_loss:  3.71 | valid_perp.:  40.65
# ================================================================================================================
#
#
# Epoch  48/ 50) lr = 0.0001276
#  b 150/721 >> 2383.2 ms/b | lr:  0.00011 | grad norm: 15.65 | max abs grad:   0.725 | loss: 2.51 | perp.:  12.35
#  b 300/721 >> 2508.0 ms/b | lr:  0.00013 | grad norm: 9.91 | max abs grad:   0.424 | loss: 2.48 | perp.:  11.97
#  b 450/721 >> 2508.5 ms/b | lr:  0.00013 | grad norm: 41.51 | max abs grad:   4.915 | loss: 2.46 | perp.:  11.76
#  b 600/721 >> 2500.7 ms/b | lr:  0.00013 | grad norm: 25.19 | max abs grad:   3.866 | loss: 2.43 | perp.:  11.38
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1781.59 sec | train_loss:  2.48 | train_perp:  11.99 | valid_loss:  2.38 | valid_perp.:  10.81
# ================================================================================================================
#
#
# Epoch  49/ 50) lr = 0.0001263
#  b 150/712 >> 2551.1 ms/b | lr:  0.00013 | grad norm: 5.84 | max abs grad:   0.283 | loss: 2.51 | perp.:  12.35
#  b 300/712 >> 2494.1 ms/b | lr:  0.00013 | grad norm: 24.59 | max abs grad:   3.188 | loss: 2.38 | perp.:  10.75
#  b 450/712 >> 2521.1 ms/b | lr:  0.00012 | grad norm: 73.48 | max abs grad:   3.713 | loss: 2.43 | perp.:  11.35
#  b 600/712 >> 2506.7 ms/b | lr:  0.00012 | grad norm: 6.64 | max abs grad:   0.692 | loss: 2.39 | perp.:  10.95
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1781.19 sec | train_loss:  2.46 | train_perp:  11.71 | valid_loss:  2.18 | valid_perp.:   8.87
# ================================================================================================================
#
#
# Epoch  50/ 50) lr = 0.000125
#  b 150/725 >> 2467.6 ms/b | lr:  0.00011 | grad norm: 11.74 | max abs grad:   0.703 | loss: 2.49 | perp.:  12.09
#  b 300/725 >> 2471.7 ms/b | lr:  0.00013 | grad norm: 6.46 | max abs grad:   0.636 | loss: 2.44 | perp.:  11.48
#  b 450/725 >> 2441.2 ms/b | lr:  0.00012 | grad norm: 6.52 | max abs grad:   0.762 | loss: 2.45 | perp.:  11.56
#  b 600/725 >> 2435.7 ms/b | lr:  0.00011 | grad norm: 6.46 | max abs grad:   0.556 | loss: 2.37 | perp.:  10.73
# ----------------------------------------------------------------------------------------------------------------
# Elapsed time: 1778.81 sec | train_loss:  2.45 | train_perp:  11.63 | valid_loss:  2.33 | valid_perp.:  10.25
# ================================================================================================================

# %%
CAUSES = ['output', 'grad']
if stat in list(range(len(CAUSES))):
    params = [p for p in model.parameters() if p.grad is not None]
    print(any([np.isnan(p.data).any() for p in params]), any([np.isnan(p.grad.data).any() for p in params]))
    
    _states = states
    if model.n_enc_layers > 0:
        enc_states = states[0]
        states = states[1:]
    if model.n_dec_layers > 0:
        dec_states = states[-1]
        states = states[:-1]
    attn_states = states[0]
    relu = nn.ReLU()
    log_softmax = nn.LogSoftmax(dim = -1)
    
    embeddings = model.embedding(data)
    enc_out, new_enc_states = model.encoder(model.drop(embeddings))
    attn_out, new_attn_states = model.attn(enc_out, attn_states)
    dec_out, new_dec_states = model.decoder(relu(attn_out))
    output = model.projection(dec_out)
    
    print([
        np.isnan(p.data).any() for p in [embeddings, enc_out, attn_out, dec_out, output]
    ])
else:
    # Save training stats
    with open(os.path.join('stats', model_test_name+'.pkl'), 'wb') as f:
        pickle.dump(train_stats, f)
    with open(os.path.join('models', model_test_name+'.pt'), 'wb') as f:
        torch.save(model.state_dict(), f)

# %%
test_loss = evaluate(test_data, save_wts = True)
print('test_loss: {:5.2f} | test_perplexity: {:5.2f}'.format(
    test_loss, np.exp(test_loss)
))
# Out:
# test_loss:  2.24 | test_perplexity:  9.40

# %% [markdown]
# ## Evaluate predictions

# %%
nb = 4
model.eval(save_wts = True)
# Get some data from a random point in the test_data set
states = model.init_states(nb)
data, targets = get_batch(test_data, 120, seq_len, evaluate = True)
data = data[:,:nb].contiguous()
targets = targets.view(seq_len, -1)[:,:nb].contiguous()

# %%
# Run the model forward
output, states = model(data, states)
# Convert the output log probabilities to normal probabilities
output = output.exp()
# Get the argmax of each step in the output
output_p, output_idx = output.max(dim = -1)

# %% [markdown]
# Compare the predicted output word indices to the targets

# %%
targets = targets.t()
output_idx = output_idx.t()
for i in range(nb):
    # Print the output with the targets
    seqs = torch.cat([targets[i].unsqueeze(0), output_idx[i].unsqueeze(0)], 0)
    # Number incorrectly predicted
    num_incorrect = (targets[i] != output_idx[i]).sum()
    print('%d incorrectly predicted\n' % num_incorrect[0], seqs)
# Out:
# 6 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   229  1655   812  4676    42   935  3257   674    24   804  2373    42   252
#    42  2373   812    42    42   935  3257   674    24  2373  2373    42   252
#
# Columns 13 to 17
#   230  1038   119  4561  1890
#   230  1038   119   935  2373
# [torch.LongTensor of size 2x18]
#
# 7 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#    64  1573   109  4931    64   133    27    27   169    27    27   549    24
#    27    27   109    27    64    27    27    27   169    27    27    24    24
#
# Columns 13 to 17
#  1041    32  5941  1256  1257
#    32    32  5941  1256    27
# [torch.LongTensor of size 2x18]
#
# 6 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   204  1452  1725    42    32  1847   119  5463   798  1656    35  3509  2680
#   119   119  1725    42    32   119   119  5463   596    35    35  3509    26
#
# Columns 13 to 17
#    26  5463   119    26    26
#    26  5463   119    26    26
# [torch.LongTensor of size 2x18]
#
# 4 incorrectly predicted
#  Variable containing:
#
# Columns 0 to 12
#   853   955    26   535   311   312  3790    42  4467    26    99   227   448
#    27   955    26   535   311   312    42    42  4467    99    99   227   448
#
# Columns 13 to 17
#    35    27    27  1479   108
#    35    27    27  1479   955
# [torch.LongTensor of size 2x18]

# %% [markdown]
# ## Visualizations
#
# Some basic weight heat maps to start:

# %%
embed_wts = np.array(model.embedding.weight.data)
embed_norm = (embed_wts - embed_wts.mean()) / (embed_wts.max() - embed_wts.min())
plt.imshow(embed_norm, aspect = 'auto', cmap = 'jet')
plt.xlabel('dim'); plt.ylabel('word index');
plt.title('Embedding layer')
plt.colorbar()
embed_wts.shape
# Out:
# (10000, 512)

# %%
attn = model.attn

# %%
attn_wts = np.array(attn.attention.weight.data)
attn_norm = (attn_wts - attn_wts.mean()) / (attn_wts.max() - attn_wts.min())
plt.imshow(attn_wts, aspect = 'auto', cmap = 'jet')
plt.xlabel('d_input+d_state'); plt.ylabel('d_output')
plt.title('Output attention sublayer (in attention mechanism)')
plt.colorbar()
attn_wts.shape
# Out:
# (256, 768)

# %% [markdown]
# Sequence attention visualization by mapping the alignment weights (in the attention mechanism) at each step of the input:

# %%
cols = 2
rows = nb//cols
fig, axs = plt.subplots(rows, cols, figsize = (30, 20))
for b in range(nb):
    wts = attn.attn_wts[:,b,:]
    wts_mean = wts.mean()
    wts_max = wts.max()
    wts_min = wts.min()
    norm = (wts - wts_mean) / (wts_max - wts_min)
    r = b // cols
    c = b % cols
    ax = axs[r, c]
    im = ax.imshow(wts, aspect = 'auto', cmap = 'jet')
    # Fix labels
    xlabels = list(targets[b].data)
    ax.set_xticks(range(seq_len))
    ax.set_xticklabels(xlabels)
    ax.set_xlabel('Targets')
    ylabels = list(data[:,b].data)
    ax.set_yticks(range(seq_len))
    ax.set_yticklabels(ylabels)
    ax.set_ylabel('Inputs')
    ax.set_title('Example %d' % b)
    fig.colorbar(im, ax = ax)
plt.show()
